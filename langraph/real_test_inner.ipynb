# %%
# API 키를 환경변수로 관리하기 위한 설정 파일
from dotenv import load_dotenv

# API 키 정보 로드
load_dotenv()
# Out:
# True

# %%
# LangSmith 추적을 설정합니다. https://smith.langchain.com
# !pip install -qU langchain-teddynote
from langchain_teddynote import logging

# 프로젝트 이름을 입력합니다.
logging.langsmith("practice")
# Out:
# LangSmith 추적을 시작합니다.
# [프로젝트명]
# practice

# %%
from langchain.vectorstores import FAISS
from langchain.embeddings import OpenAIEmbeddings

# Step 1: FAISS 인덱스 파일 로드
faiss_index_path = "Faiss/naver_map_gangnam_faiss"  # 저장된 Faiss 파일 경로
embeddings = OpenAIEmbeddings()  # 임베딩 객체 초기화

# 저장된 FAISS 인덱스를 불러와서 Retriever 생성
retriever_naver_gangnam = FAISS.load_local(faiss_index_path, embeddings,allow_dangerous_deserialization=True).as_retriever()

# 검색 매개변수 설정 (예: 검색 결과 상위 10개 반환)
retriever_naver_gangnam.search_kwargs = {"k": 6}
# Out:
# /var/folders/_v/g1qmsq595kq_fg_zv8n2022h0000gn/T/ipykernel_3674/1756154715.py:6: LangChainDeprecationWarning: The class `OpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import OpenAIEmbeddings``.
#   embeddings = OpenAIEmbeddings()  # 임베딩 객체 초기화

# %%
# Step 1: FAISS 인덱스 파일 로드
faiss_index_path = "Faiss/naver_map_jongro_faiss"  # 저장된 Faiss 파일 경로
embeddings = OpenAIEmbeddings()  # 임베딩 객체 초기화

# 저장된 FAISS 인덱스를 불러와서 Retriever 생성
retriever_naver_jongro = FAISS.load_local(faiss_index_path, embeddings,allow_dangerous_deserialization=True).as_retriever()

# 검색 매개변수 설정 (예: 검색 결과 상위 10개 반환)
retriever_naver_jongro.search_kwargs = {"k": 6}

# %%
# Step 1: FAISS 인덱스 파일 로드
faiss_index_path = "Faiss/naver_map_Junggu_faiss"  # 저장된 Faiss 파일 경로
embeddings = OpenAIEmbeddings()  # 임베딩 객체 초기화

# 저장된 FAISS 인덱스를 불러와서 Retriever 생성
retriever_naver_Junggu = FAISS.load_local(faiss_index_path, embeddings,allow_dangerous_deserialization=True).as_retriever()

# 검색 매개변수 설정 (예: 검색 결과 상위 10개 반환)
retriever_naver_Junggu.search_kwargs = {"k": 6}

# %%
# Step 1: FAISS 인덱스 파일 로드
faiss_index_path = "Faiss/naver_map_yongsan_faiss"  # 저장된 Faiss 파일 경로
embeddings = OpenAIEmbeddings()  # 임베딩 객체 초기화

# 저장된 FAISS 인덱스를 불러와서 Retriever 생성
retriever_naver_yongsan = FAISS.load_local(faiss_index_path, embeddings,allow_dangerous_deserialization=True).as_retriever()

# 검색 매개변수 설정 (예: 검색 결과 상위 10개 반환)
retriever_naver_yongsan.search_kwargs = {"k": 6}

# %%
# Step 1: FAISS 인덱스 파일 로드
faiss_index_path = "Faiss/opendata_gangnam_all"  # 저장된 Faiss 파일 경로
embeddings = OpenAIEmbeddings()  # 임베딩 객체 초기화

# 저장된 FAISS 인덱스를 불러와서 Retriever 생성
retriever_opendata_gangnam = FAISS.load_local(faiss_index_path, embeddings,allow_dangerous_deserialization=True).as_retriever()

# 검색 매개변수 설정 (예: 검색 결과 상위 10개 반환)
retriever_opendata_gangnam.search_kwargs = {"k": 10}

# %%
# Step 1: FAISS 인덱스 파일 로드
faiss_index_path = "Faiss/opendata_jongro_all"  # 저장된 Faiss 파일 경로
embeddings = OpenAIEmbeddings()  # 임베딩 객체 초기화

# 저장된 FAISS 인덱스를 불러와서 Retriever 생성
retriever_opendata_jongro = FAISS.load_local(faiss_index_path, embeddings,allow_dangerous_deserialization=True).as_retriever()

# 검색 매개변수 설정 (예: 검색 결과 상위 10개 반환)
retriever_opendata_jongro.search_kwargs = {"k": 10}

# %%
# Step 1: FAISS 인덱스 파일 로드
faiss_index_path = "Faiss/opendata_junggu_all"  # 저장된 Faiss 파일 경로
embeddings = OpenAIEmbeddings()  # 임베딩 객체 초기화

# 저장된 FAISS 인덱스를 불러와서 Retriever 생성
retriever_opendata_junggu = FAISS.load_local(faiss_index_path, embeddings,allow_dangerous_deserialization=True).as_retriever()

# 검색 매개변수 설정 (예: 검색 결과 상위 10개 반환)
retriever_opendata_junggu.search_kwargs = {"k": 10}

# %%
# Step 1: FAISS 인덱스 파일 로드
faiss_index_path = "Faiss/opendata_yongsan_all"  # 저장된 Faiss 파일 경로
embeddings = OpenAIEmbeddings()  # 임베딩 객체 초기화

# 저장된 FAISS 인덱스를 불러와서 Retriever 생성
retriever_opendata_yongsan = FAISS.load_local(faiss_index_path, embeddings,allow_dangerous_deserialization=True).as_retriever()

# 검색 매개변수 설정 (예: 검색 결과 상위 10개 반환)
retriever_opendata_yongsan.search_kwargs = {"k": 10}

# %%
from typing import Annotated, TypedDict, List
from langgraph.graph.message import add_messages


# GraphState 상태 정의
class GraphState(TypedDict):
    question: Annotated[List[str], add_messages]  # 질문(누적되는 list)
    context_naver_gangnam: Annotated[str, "context_naver_gangnam"]  # 문서의 검색 결과
    context_naver_jongro: Annotated[str, "context_naver_jongro"]  # 문서의 검색 결과
    context_naver_Junggu: Annotated[str, "context_naver_Junggu"]  # 문서의 검색 결과
    context_naver_yongsan: Annotated[str, "context_naver_yongsan"]  # 문서의 검색 결과
    context_opendata: Annotated[str, "context_opendata"]  # 문서의 검색 결과
    context_web: Annotated[str, "context_web"]  # 문서의 검색 결과
    answer_llm_Summary_gangnam: Annotated[str, "answer_llm_Summary_gangnam"]  # 답변
    answer_llm_Summary_junggu: Annotated[str, "answer_llm_Summary_junggu"]  # 답변
    answer_llm_Summary_jongro: Annotated[str, "answer_llm_Summary_jongro"]  # 답변
    answer_llm_Summary_yongsan: Annotated[str, "answer_llm_Summary_yongsan"]  # 답변
    answer_llm_Summary_opendata: Annotated[str, "answer_llm_Summary_opendata"]  # 답변
    answer: Annotated[str, "Answer"]  # 답변
    messages: Annotated[list, add_messages]  # 메시지(누적되는 list)
    webOrRetriever: Annotated[str, "webOrRetriever"]  # 웹 or 리트리버 검색
    ScheduleOrplace: Annotated[str, "ScheduleOrplace"]  # 일정 or 장소
    location: Annotated[str, "location"]  # 지역 리스트

# %%
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from operator import itemgetter
# 프롬프트
prompt = PromptTemplate(
    template="""너는 입력 받는 장소 정보의 데이터를 종합해서 서울의 관광 일정을 추천해주는 봇이야.
    추천 할 수 있는 지역은 종로구, 중구, 용산구, 강남구로 한정되어 있어.
    사용자의 질문에 따라서 여러가지 서울의 관광지, 식당, 숙소, 쇼핑몰 등을 추천해야해.
    사용자가 서울에 오는 이유에 대해 파악하고 그에 맞는 여행 일정을 추천해주면 돼.
    대화하다가 추천한 여행 일정이 사용자의 마음에 들지 않아서 변경해달라고 하면 마음에 들지 않은 부분을
    캐치하고 그 부분들만 수정해서 다시 추천해주면 돼.
    일정은 아침, 점심, 저녁, 식당을 추천해주고, 중간중간에 카페나, 명소, 거리등을 추천 해줬으면 좋겠어.

    여행 일정에 대한 동선이 짧도록 추천해줘.
    언어는 사용자가 입력한 언어를 기준으로 알려줘. 
    화폐 기준도 사용자가 입력한 언어를 사용하는 국가의 화폐를 기준으로 적용해줘.




    # 장소 정보: {context}

    #사용자의 질문: {question}
    
    #이전 대화 내용 {chat_history} 
    """,
        input_variables=["context", "question"],
    )

# LLM
model = ChatOpenAI(model_name="gpt-4o",
                    temperature=0, streaming=True)

chain = (
    {
        "question": itemgetter("question"),
        # "context_web": itemgetter("context_web"),
        "context": itemgetter("context"),
        "chat_history": itemgetter("chat_history"),
    }
    | prompt
    | model
    | StrOutputParser()
)

# %%
prompt_opendata_Summary = PromptTemplate(
    template="""너는 입력받은 내용을 요약해주는 봇이야.
    입력 받는 내용은 특정 장소의 특징을 알려주는 내용이야.

    요약은 다음과 같이 해줬으면 좋겠어.

    아래 항목에서 없는 데이터는 빼도 돼.

    - 장소 이름:
    - 위치 :
    - 전화번호 :
    - 웹사이트 URL :
    - 운영 날짜 및 시간:
    - 교통정보
    - 기타 편의 여부 :
    - 지원언어 :

    # 요약 해야할 내용: {answer_llm_Summary}


    """,
        input_variables=["answer_llm_Summary"],
    )


# LLM
model_summary = ChatOpenAI(model_name="gpt-4o-mini",
                    temperature=0, streaming=True)

chain_Summary_opendata = (
    # {
    #     "answer_llm_Summary": itemgetter("answer_llm_Summary_opendata")
    # }
    prompt_opendata_Summary
    | model_summary
    | StrOutputParser()
)

# %%
prompt_naver_Summary = PromptTemplate(
    template="""너는 입력받은 내용을 요약해주는 봇이야.
    입력 받는 내용은 특정 장소의 특징을 알려주는 내용이야.

    요약은 다음과 같이 해줬으면 좋겠어

       - "store_name": 
       - "category":  
       - "rating":  
       - "directions_text": 
       - "store_id": 
       - "address": 
       - "phone_num": 
       - "business_hours": 
       - "info": 
       - "convenience_facilities_and_services": 
       - "Parking": 
       - "sns": 
       - "store의 좋은점": 
       - "menu": 



    # 요약 해야할 내용: {answer_llm_Summary}


    """,
        input_variables=["answer_llm_Summary"],
    )


# LLM
model_summary = ChatOpenAI(model_name="gpt-4o-mini",
                    temperature=0, streaming=True)

chain_Summary_gangnam = (
    # {
    #     "answer_llm_Summary": itemgetter("answer_llm_Summary_gangnam")
    # }
    prompt_naver_Summary
    | model_summary
    | StrOutputParser()
)
chain_Summary_Junggu = (
    # {
    #     "answer_llm_Summary": itemgetter("answer_llm_Summary_junggu")
    # }
     prompt_naver_Summary
    | model_summary
    | StrOutputParser()
)
chain_Summary_jongro = (
    # {
    #     "answer_llm_Summary": itemgetter("answer_llm_Summary_jongro")
    # }
     prompt_naver_Summary
    | model_summary
    | StrOutputParser()
)
chain_Summary_yongsan = (
    # {
    #     "answer_llm_Summary": itemgetter("answer_llm_Summary_yongsan")
    # }
     prompt_naver_Summary
    | model_summary
    | StrOutputParser()
)

# %%
prompt_location = PromptTemplate(
    template="""너는 질문에 대해서 list를 반환해야돼.
    list에 들어갈 수 있는 str은 '용산구', '강남구', '중구', '종로구' 네가지가 있어.
    사용자가 질문을 하면 문장을 잘 보고 문장속의 지역을 추출해서 리스트에 넣어줘.
    만약 사용자의 질문에 '서울'을 방문 한다고 하면 리스트에 '용산구', '강남구', '중구', '종로구' 를 모두 넣어줘.
    사용자의 질문에 서울시가 아닌 다른지역을 물어보거나, 서울시에서도 '용산구', '강남구', '중구', '종로구'가 아닌 다른 지역을 물어보면 빈 리스트를 반환해.


    #입력 예시 : 1. 나는 서울시의 용산구를 방문 할거야 여행 계획을 세워 줄수 있어?, 
               2. 나는 종로구와 중구 일대를 방문하고 싶어 을지로는 꼭 가보고 싶은데 을지로 계획을 포함해서 여행 일정을 만들어 줄 수 있어?

    #대답 형식 예시 : ['종로구','강남구']

    #사용자의 질문: {question}


    #####
    예시 1:

    질문 : 나는 나는 전라남도 여행을 계획중이야. 일정을 만들어 줄 수 있어?  
    출력 : []
    #####

    #####
    예시 2:

    질문 : 나는 용산구와 종로구, 중구 일대를 관광하고 싶어 좋은 카페를 알고 싶은데 알려줄 수 있어?  
    출력 : ['용산구','중구','종로구']
    #####

    #####
    예시 3:

    질문 : 나는 서울시를 관광하고 싶어 1박2일 정도 방문하려고 하는데 일정을 만들어 줄 수 있어?
    출력 : ['용산구','중구','종로구','강남구']
    #####

    #####
    예시 4:

    질문 : 나는 종로구에서 맛있는 고기집을 찾고 있어. 찾아줘
    출력 : ['종로구']
    #####


    """,
        input_variables=["question"],
    )

model_location = ChatOpenAI(model_name="gpt-4o-mini",
                    temperature=0, streaming=True)

chain_location = (
    {
        "question": itemgetter("question"),
    }
    | prompt_location
    | model_location
    | StrOutputParser()
)

# %%
prompt_sch_or_placeSearch = PromptTemplate(
    template="""너는 질문에 대해서 두가지의 옵션으로 대답하는 봇이야.
    너의 대답은 '일정', '장소검색' 두가지로만 대답할 수 있어.
    사용자가 질문을 하면 문맥을 잘 살펴서 사용자가 여행일정을 만들어 달라고 하면 '일정' 이라고 대답해야돼.
    그렇지 않으면 '장소검색' 를 출력해줘.

    #'일정' 출력 예시 : 1. 나는 서울시의 용산구를 방문 할거야 여행 계획을 세워 줄수 있어?, 2. 나는 종로구와 중구 일대를 방문하고 싶어 을지로는 꼭 가보고 싶은데 을지로 계획을 포함해서 여행 일정을 만들어 줄 수 있어?

    #대답 형식 : '일정' or '장소검색'

    #사용자의 질문: {question}
    

    """,
        input_variables=["question"],
    )

model_sch_or_placeSearch = ChatOpenAI(model_name="gpt-4o-mini",
                    temperature=0, streaming=True)

chain_sch_or_placeSearch = (
    {
        "question": itemgetter("question"),
    }
    | prompt_sch_or_placeSearch
    | model_sch_or_placeSearch
    | StrOutputParser()
)

# %%
prompt_Web_or_retriever = PromptTemplate(
    template=""" 너는 사용자의 질문에 대해서 두가지의 옵션으로 대답하는 봇이야.
    너의 대답은 'web', 'retriever' 두가지로만 대답할 수 있어.
    사용자가 질문을 하면 문맥을 잘 살펴서 웹에서 정보를 검색하기를 원하면 'web' 이라고 대답해야돼.
    그렇지 않으면 'retriever' 를 출력해줘. 

    #대답 형식 : 'web' or 'retriever'

    #사용자의 질문: {question}
    

    """,
        input_variables=["question"],
    )
model_web_check = ChatOpenAI(model_name="gpt-4o-mini",
                    temperature=0, streaming=True)

chain_Web_or_retriever = (
    {
        "question": itemgetter("question"),
    }
    | prompt_Web_or_retriever
    | model_web_check
    | StrOutputParser()
)

# %%
prompt_web = PromptTemplate(
    template="""너는 웹 검색을 통한 {context_web}의 내용를 종합해서 서울시의 중구,종로구,용산구,강남구 관광 일정을 추천해주는 봇이야.
    사용자의 질문에 따라서 여러가지 서울의 관광지, 식당, 숙소, 쇼핑몰 등을 추천해야해.
    처음에 사용자가 서울에 며칠동안 머무르는지 물어보고, 그에 따라서 관광 일정을 추천해주면 돼.
    그 다음 사용자가 서울에 오는 이유에 대해 파악하고 그에 맞는 여행 일정을 추천해주면 돼.
    대화하다가 추천한 여행 일정이 사용자의 마음에 들지 않아서 변경해달라고 하면 마음에 들지 않은 부분을
    캐치하고 그 부분들만 수정해서 다시 추천해주면 돼.
    일정 중간 중간 숙소나 식당, 쇼핑몰 등을 추천해주면 돼.

    어떤 장소가 궁금해서 물어본다면 특정 장소의 정보들을 정확하게 알려줘.
    (예:가게 정보, 메뉴, 별점, 위치, 연락처, 운영 시간, 리뷰 등)
    여행 일정에 대한 동선이 짧도록 추천해줘.
    언어는 사용자가 입력한 언어를 기준으로 알려줘. 
    화폐 기준도 사용자가 입력한 언어를 사용하는 국가의 화폐를 기준으로 적용해줘.


    - 너가 제공한 내용의 출처를 링크로 남겨줘

    # 웹 검색 정보 : {context_web}

    #사용자의 질문: {question}
    
    #이전 대화 내용 {chat_history} 
    """,
        input_variables=["context_web", "question"],
    )
#input_variables=["context_web","context_opendata","context_naver", "question"],
# LLM
model_web = ChatOpenAI(model_name="gpt-4o",
                    temperature=0, streaming=True)

chain_web = (
    {
        "question": itemgetter("question"),
        "context_web": itemgetter("context_web"),
        # "context_opendata": itemgetter("context_opendata"),
        # "context_naver": itemgetter("context_naver"),
        "chat_history": itemgetter("chat_history"),
    }
    | prompt_web
    | model_web
    | StrOutputParser()
)

# %%
from langchain_teddynote.messages import messages_to_history
from langchain_teddynote.tools.tavily import TavilySearch
import ast

# from rag.utils import format_docs
# 웹 검색 or 리트리버 검색
def web_or_retriever_check(state: GraphState) -> GraphState:
    # 관련성 체크를 실행("yes" or "no")
    response = chain_Web_or_retriever.invoke(
        {"question": state["question"][-1].content}
    )

    return {"webOrRetriever": response}

# 웹 리트리버 분기 체크하는 함수(router)
def is_web(state: GraphState) -> GraphState:
    if state["webOrRetriever"] == "web":
        return "web"
    else:
        return "retriever"

# 장소검색 or 일정 검색
def Schedule_or_place_check(state: GraphState) -> GraphState:
    # 관련성 체크를 실행("yes" or "no")
    response = chain_sch_or_placeSearch.invoke(
        {"question": state["question"][-1].content}
    )

    return {"ScheduleOrplace": response}


# 일정 장소검색 리트리버 분기 체크하는 함수(router)
def is_place(state: GraphState) -> GraphState:
    if state["ScheduleOrplace"] == "일정":
        return "일정"
    else:
        return "장소검색"
    
# 지역 판별
def location_check(state: GraphState) -> GraphState:
    # 관련성 체크를 실행("yes" or "no")
    response = chain_location.invoke(
        {"question": state["question"][-1].content}
    )

    return {"location": response}

    
# 문서 검색 노드--------------------------------------------------------------------------------------------------------------------------
def retrieve_document_naver_gangnam(state: GraphState) -> GraphState:
    # 질문을 상태에서 가져옵니다.
    latest_question = state["question"][-1].content

    # 문서에서 검색하여 관련성 있는 문서를 찾습니다.
    retrieved_docs = retriever_naver_gangnam.invoke(latest_question)

    # 검색된 문서를 형식화합니다.(프롬프트 입력으로 넣어주기 위함)
    retrieved_docs = "\n".join(
        [
            f"<document><content>{doc.page_content}</content>"
            for doc in retrieved_docs
        ]
    )
        # 검색된 문서를 context 키에 저장합니다.
    return {"context_naver_gangnam": retrieved_docs}

def retrieve_document_naver_jongro(state: GraphState) -> GraphState:
    # 질문을 상태에서 가져옵니다.
    latest_question = state["question"][-1].content

    # 문서에서 검색하여 관련성 있는 문서를 찾습니다.
    retrieved_docs = retriever_naver_jongro.invoke(latest_question)

    # 검색된 문서를 형식화합니다.(프롬프트 입력으로 넣어주기 위함)
    retrieved_docs = "\n".join(
        [
            f"<document><content>{doc.page_content}</content>"
            for doc in retrieved_docs
        ]
    )
        # 검색된 문서를 context 키에 저장합니다.
    return {"context_naver_jongro": retrieved_docs}

def retrieve_document_naver_Junggu(state: GraphState) -> GraphState:
    # 질문을 상태에서 가져옵니다.
    latest_question = state["question"][-1].content

    # 문서에서 검색하여 관련성 있는 문서를 찾습니다.
    retrieved_docs = retriever_naver_Junggu.invoke(latest_question)

    # 검색된 문서를 형식화합니다.(프롬프트 입력으로 넣어주기 위함)
    retrieved_docs = "\n".join(
        [
            f"<document><content>{doc.page_content}</content>"
            for doc in retrieved_docs
        ]
    )
        # 검색된 문서를 context 키에 저장합니다.
    return {"context_naver_Junggu": retrieved_docs}

def retrieve_document_naver_yongsan(state: GraphState) -> GraphState:
    # 질문을 상태에서 가져옵니다.
    latest_question = state["question"][-1].content

    # 문서에서 검색하여 관련성 있는 문서를 찾습니다.
    retrieved_docs = retriever_naver_yongsan.invoke(latest_question)

    # 검색된 문서를 형식화합니다.(프롬프트 입력으로 넣어주기 위함)
    retrieved_docs = "\n".join(
        [
            f"<document><content>{doc.page_content}</content>"
            for doc in retrieved_docs
        ]
    )
    # 검색된 문서를 context 키에 저장합니다.
    return {"context_naver_yongsan": retrieved_docs}


#------------------------------------------------------------------------------------------------------------------------------------------------


def retrieve_document_opendata(state: GraphState) -> GraphState:
    # 질문을 상태에서 가져옵니다.
    latest_question = state["question"][-1].content
    location_str = state['location']

    location = ast.literal_eval(location_str)

    doc_list = []
    # 문서에서 검색하여 관련성 있는 문서를 찾습니다.
    yongsan = '용산구'
    jonglo = '종로구'
    gangman = '강남구'
    junggu = '중구'
    retrieved_docs_yongsan = []
    retrieved_docs_jongro = []
    retrieved_docs_gangman = []
    retrieved_docs_junggu = []

    if yongsan in location:
        retrieved_docs_yongsan = retriever_opendata_yongsan.invoke(latest_question)

    if jonglo in location:
        retrieved_docs_jongro = retriever_opendata_jongro.invoke(latest_question)

    if gangman in location:
        retrieved_docs_gangman = retriever_opendata_gangnam.invoke(latest_question)

    if junggu in location:
        retrieved_docs_junggu = retriever_opendata_junggu.invoke(latest_question)

 
    doc_list.extend(retrieved_docs_yongsan)
    doc_list.extend(retrieved_docs_jongro)
    doc_list.extend(retrieved_docs_gangman)
    doc_list.extend(retrieved_docs_junggu)

    # 검색된 문서를 형식화합니다.(프롬프트 입력으로 넣어주기 위함)
    retrieved_docs = "\n".join(
        [
            f"<document><content>{doc.page_content}</content>"
            for doc in doc_list
        ]
)

    # 검색된 문서를 context 키에 저장합니다.
    return {"context_opendata": retrieved_docs}

# 요약 생성 노드----------------------------------------------------------------------------
def llm_Summary_gangnam(state: GraphState) -> GraphState:
    loc = '강남구'
    location_str = state['location']

    location = ast.literal_eval(location_str)

    if loc not in location:
        return {
        "answer_llm_Summary_gangnam": 'none'
             } 
    
    # 검색된 문서를 상태에서 가져옵니다.
    context_naver = state["context_naver_gangnam"]

    # 체인을 호출하여 답변을 생성합니다.
    response = chain_Summary_gangnam.invoke(
        {
            "answer_llm_Summary": context_naver,
        }
    )
    # 생성된 답변, (유저의 질문, 답변) 메시지를 상태에 저장합니다.
    return {
        "answer_llm_Summary_gangnam": response
    } 
def llm_Summary_jongro(state: GraphState) -> GraphState:
    loc = '종로구'
    location_str = state['location']

    location = ast.literal_eval(location_str)

    if loc not in location:
        return {
        "answer_llm_Summary_jongro": 'none'
             } 
    # 검색된 문서를 상태에서 가져옵니다.
    context_naver = state["context_naver_jongro"]

    # 체인을 호출하여 답변을 생성합니다.
    response = chain_Summary_jongro.invoke(
        {
            "answer_llm_Summary": context_naver,
        }
    )
    # 생성된 답변, (유저의 질문, 답변) 메시지를 상태에 저장합니다.
    return {
        "answer_llm_Summary_jongro": response
    } 

def llm_Summary_Junggu(state: GraphState) -> GraphState:
    loc = '중구'
    location_str = state['location']

    location = ast.literal_eval(location_str)

    if loc not in location:
        return {
        "answer_llm_Summary_junggu": 'none'
             } 
    # 검색된 문서를 상태에서 가져옵니다.
    context_naver = state["context_naver_Junggu"]

    # 체인을 호출하여 답변을 생성합니다.
    response = chain_Summary_Junggu.invoke(
        {
            "answer_llm_Summary": context_naver,
        }
    )
    # 생성된 답변, (유저의 질문, 답변) 메시지를 상태에 저장합니다.
    return {
        "answer_llm_Summary_junggu": response
    } 
def llm_Summary_yongsan(state: GraphState) -> GraphState:
    
    loc = '용산구'
    location_str = state['location']

    location = ast.literal_eval(location_str)

    if loc not in location:
        return {
        "answer_llm_Summary_yongsan": 'none'
             } 
    # 검색된 문서를 상태에서 가져옵니다.
    context_naver = state["context_naver_yongsan"]

    # 체인을 호출하여 답변을 생성합니다.
    response = chain_Summary_yongsan.invoke(
        {
            "answer_llm_Summary": context_naver,
        }
    )
    # 생성된 답변, (유저의 질문, 답변) 메시지를 상태에 저장합니다.
    return {
        "answer_llm_Summary_yongsan": response
    } 

def llm_Summary_opendata(state: GraphState) -> GraphState:

    # 검색된 문서를 상태에서 가져옵니다.
    context_opendata = state["context_opendata"]

    # 체인을 호출하여 답변을 생성합니다.
    response = chain_Summary_opendata.invoke(
        {
            "answer_llm_Summary": context_opendata,
        }
    )
    # 생성된 답변, (유저의 질문, 답변) 메시지를 상태에 저장합니다.
    return {
        "answer_llm_Summary_opendata": response
    } 


# 요약 생성 노드 끝----------------------------------------------------------------------------



# 일정 생성 노드----------------------------------------------------------------------------

def llm_Schedule_answer(state: GraphState) -> GraphState:
    # 질문을 상태에서 가져옵니다.
    latest_question = state["question"][-1].content
    location_str = state['location']

    location = ast.literal_eval(location_str)

    Summary_list = []
    Summary_yongsan =[]
    Summary_jongro =[]
    Summary_gangman =[]
    Summary_junggu =[]
    # 문서에서 검색하여 관련성 있는 문서를 찾습니다.
    yongsan = '용산구'
    jonglo = '종로구'
    gangman = '강남구'
    junggu = '중구'

    if yongsan in location:
        Summary_yongsan = state["answer_llm_Summary_yongsan"]

    if jonglo in location:
        Summary_jongro = state["answer_llm_Summary_jongro"]

    if gangman in location:
        Summary_gangman = state["answer_llm_Summary_gangnam"]

    if junggu in location:
        Summary_junggu = state["answer_llm_Summary_junggu"]

   
    Summary_opendata = state["answer_llm_Summary_opendata"]

 
    Summary_list.extend(Summary_yongsan)
    Summary_list.extend(Summary_jongro)
    Summary_list.extend(Summary_gangman)
    Summary_list.extend(Summary_junggu)
    Summary_list.extend(Summary_opendata)

    # 검색된 문서를 형식화합니다.(프롬프트 입력으로 넣어주기 위함)
    retrieved_docs = "\n".join(
        [
            f"{doc}"
            for doc in Summary_list
        ]
    )

    # 체인을 호출하여 답변을 생성합니다.
    response = chain.invoke(
        {
            "question": latest_question,
            "context": retrieved_docs,
            "chat_history": messages_to_history(state["messages"]),
        }
    )
    # 생성된 답변, (유저의 질문, 답변) 메시지를 상태에 저장합니다.
    print(state["messages"])
    return {
        "answer": response,
        "messages": [("user", latest_question), ("assistant", response)],
    }
# 일정 생성 노드 끝----------------------------------------------------------------------------


# 웹 검색 답변 생성 노드
def llm_answer_web(state: GraphState) -> GraphState:
    # 질문을 상태에서 가져옵니다.
    latest_question = state["question"][-1].content
    # 검색된 문서를 상태에서 가져옵니다.
    # context_naver = state["context_naver"]
    # context_opendata = state["context_opendata"]
    context_web = state["context_web"]

    # 체인을 호출하여 답변을 생성합니다.
    response = chain_web.invoke(
        {
            "question": latest_question,
            "context_web": context_web,
            # "context_naver": context_naver,
            # "context_opendata": context_opendata,
            "chat_history": messages_to_history(state["messages"]),
        }
    )
    # 생성된 답변, (유저의 질문, 답변) 메시지를 상태에 저장합니다.
    print(state["messages"])
    return {
        "answer": response,
        "messages": [("user", latest_question), ("assistant", response)],
    }

# Web Search 노드
def web_search(state: GraphState) -> GraphState:
    # 검색 도구 생성
    tavily_tool = TavilySearch()

    search_query = state["question"][-1].content

    # 다양한 파라미터를 사용한 검색 예제
    search_result = tavily_tool.search(
        query=search_query,  # 검색 쿼리
        topic="general",  # 일반 주제
        max_results=2,  # 최대 검색 결과
        format_output=True,  # 결과 포맷팅
    )

    return {"context_web": search_result}


def query_rewrite(state: GraphState) -> GraphState:
    latest_question = state["question"][-1].content
    question_rewritten = question_rewriter.invoke({"question": latest_question})
    return {"question": question_rewritten}

# %%
from langgraph.graph import END, StateGraph
from langgraph.checkpoint.memory import MemorySaver

# 그래프 생성
workflow = StateGraph(GraphState)

# 노드 정의
workflow.add_node("location_check", location_check)
workflow.add_node("retrieve_document_naver_gangnam", retrieve_document_naver_gangnam)
workflow.add_node("retrieve_document_naver_jongro", retrieve_document_naver_jongro)
workflow.add_node("retrieve_document_naver_Junggu", retrieve_document_naver_Junggu)
workflow.add_node("retrieve_document_naver_yongsan", retrieve_document_naver_yongsan)
workflow.add_node("retrieve_opendata", retrieve_document_opendata)
workflow.add_node("llm_Summary_gangnam", llm_Summary_gangnam)
workflow.add_node("llm_Summary_Junggu", llm_Summary_Junggu)
workflow.add_node("llm_Summary_yongsan", llm_Summary_yongsan)
workflow.add_node("llm_Summary_opendata", llm_Summary_opendata)
workflow.add_node("llm_Summary_jongro", llm_Summary_jongro)
workflow.add_node("llm_Schedule_answer", llm_Schedule_answer)
# workflow.add_node("llm_answer_web", llm_answer_web)
# workflow.add_node("web_search", web_search)
# workflow.add_node("web_Or_Retriever", web_or_retriever_check)

# 엣지 정의
# workflow.add_conditional_edges(
#     "web_Or_Retriever",  # 관련성 체크 노드에서 나온 결과를 is_relevant 함수에 전달합니다.
#     is_web,
#     {
#         "web": "web_search",  # 웹 검색을 요청하면 웹검색을 합니다
#         "retriever": "query_rewrite",  # 아니면 리트리버
#     },
# )

workflow.add_edge("location_check", "retrieve_document_naver_gangnam")  # 검색 -> 답변
workflow.add_edge("location_check", "retrieve_document_naver_jongro")  # 검색 -> 답변
workflow.add_edge("location_check", "retrieve_document_naver_Junggu")  # 검색 -> 답변
workflow.add_edge("location_check", "retrieve_document_naver_yongsan")  # 검색 -> 답변
workflow.add_edge("location_check", "retrieve_opendata")  # 검색 -> 답변
workflow.add_edge("retrieve_document_naver_gangnam", "llm_Summary_gangnam")  # 질문 -> 검색
workflow.add_edge("retrieve_document_naver_Junggu", "llm_Summary_Junggu")  # 질문 -> 검색
workflow.add_edge("retrieve_document_naver_yongsan", "llm_Summary_yongsan")  
workflow.add_edge("retrieve_opendata", "llm_Summary_opendata") 
workflow.add_edge("retrieve_document_naver_jongro", "llm_Summary_jongro") 
workflow.add_edge("llm_Summary_opendata", "llm_Schedule_answer") 
workflow.add_edge("llm_Summary_gangnam", "llm_Schedule_answer") 
workflow.add_edge("llm_Summary_Junggu", "llm_Schedule_answer") 
workflow.add_edge("llm_Summary_yongsan", "llm_Schedule_answer") 
workflow.add_edge("llm_Summary_jongro", "llm_Schedule_answer") 

workflow.add_edge("llm_Schedule_answer", END)  # 답변 -> 종료

# 그래프 진입점 설정
workflow.set_entry_point("location_check")

# 체크포인터 설정
memory = MemorySaver()

# 컴파일
app = workflow.compile(checkpointer=memory)

# %%
from langchain_teddynote.graphs import visualize_graph

visualize_graph(app)

# %%
from langchain_core.runnables import RunnableConfig
from langchain_teddynote.messages import invoke_graph, stream_graph, random_uuid

# config 설정(재귀 최대 횟수, thread_id)
config = RunnableConfig(recursion_limit=20, configurable={"thread_id": random_uuid()})

# %%
inputs = GraphState(question="내가 직전에 한 질문이 뭐였지")

# %%
res
# Out:
# {'question': [HumanMessage(content='종로구에 1박2일 여행 일정을 만들어 줄 수 있어?', additional_kwargs={}, response_metadata={}, id='5e4805ad-054a-48bd-8fbb-dba4f26150aa'),
#   HumanMessage(content='종로구에서 1박 2일 여행 일정을 어떻게 구성할 수 있을까?', additional_kwargs={}, response_metadata={}, id='9c4cc664-808b-47fb-bf8e-1d6a045fe175'),
#   HumanMessage(content='종로구에 1박2일 여행 일정을 만들어 줄 수 있어?', additional_kwargs={}, response_metadata={}, id='50f84474-5700-4423-bc20-794b9630ade4'),
#   HumanMessage(content='종로구에서 1박 2일 여행 일정을 추천해 줄 수 있나요?', additional_kwargs={}, response_metadata={}, id='164828ac-71c4-46e8-89f5-e2a08f3f0713'),
#   HumanMessage(content='이번에는 용산구와 중구에서의 일정을 만들어줘', additional_kwargs={}, response_metadata={}, id='5293615c-ab42-4eba-aec0-075bab855fd2'),
#   HumanMessage(content='용산구와 중구에서의 일정 계획을 어떻게 세울 수 있을까요?', additional_kwargs={}, response_metadata={}, id='7dce6d2f-d201-4294-bc8d-9c44e1e46f51'),
#   HumanMessage(content='내가 직전에 한 질문이 뭐였지', additional_kwargs={}, response_metadata={}, id='1169dd59-6f0e-4870-a823-77bb497cf551'),
#   HumanMessage(content='내가 이전에 한 질문은 무엇인가요?', additional_kwargs={}, response_metadata={}, id='655e7137-a5a2-4a9f-ae9c-f9c678e868b1')],
#  'context_naver': '<document><content>store_name: 옛날국시 \n category: 국수 \n new_open:   \n rating: 별점 4.33 \n visited_review: 방문자 리뷰 514 \n directions_text: 이태원역과 녹사평역 중간에 위치해 있으며 이태원시장 뒤에 위치해 있습니다. (이태원역에서 도보로 7분 정도 소요) \n store_id: 36615227 \n address: 서울 용산구 녹사평대로32길 20-1 \n blog_review: 블로그 리뷰 107 \n phone_num: 02-798-7997 \n business_hours: 월\n10:00 - 19:00\n18:50 라스트오더\n화\n10:00 - 19:00\n18:50 라스트오더\n수(1/1)\n새해 첫날 휴무\n목\n10:00 - 19:00\n18:50 라스트오더\n금\n10:00 - 19:00\n18:50 라스트오더\n토\n10:00 - 19:00\n18:50 라스트오더\n일\n정기휴무 (매주 일요일)\n \n info: 옛 우리네 어머니의 손맛이 생각나게 하는 음식들이 준비되어 있습니다. \n convenience_facilities_and_services: 포장\n배달\n \n Parking: 주차 정보없음 \n sns: http://www.instagram.com/yetnalgooksi\n \n review_like_this_part_output: "음식이 맛있어요"이 키워드를 선택한 인원211\n"가성비가 좋아요"이 키워드를 선택한 인원78\n"양이 많아요"이 키워드를 선택한 인원57\n"혼밥하기 좋아요"이 키워드를 선택한 인원54\n"재료가 신선해요"이 키워드를 선택한 인원40\n"친절해요"이 키워드를 선택한 인원38\n"특별한 메뉴가 있어요"이 키워드를 선택한 인원37\n"매장이 넓어요"이 키워드를 선택한 인원12\n"매장이 청결해요"이 키워드를 선택한 인원9\n"인테리어가 멋져요"이 키워드를 선택한 인원6\n"단체모임 하기 좋아요"이 키워드를 선택한 인원3\n"화장실이 깨끗해요"이 키워드를 선택한 인원3\n"뷰가 좋아요"이 키워드를 선택한 인원3\n"건강한 맛이에요"이 키워드를 선택한 인원1\n \n menu: 메밀소바10,000원\n꼬마김밥(1인분 8개)8,000원\n잔치국수8,000원\n비빔국수8,000원\n김치수제비/김치칼국수10,000원\n들깨수제비/칼국수10,000원\n해물수제비/칼국수10,000원\n해물순두부 찌개8,000원\n냉메밀소바(하절기)10,000원\n해물카레순두부/해물순두부10,000원\n묵밥8,000원\n무말랭이 1봉6,000원\n매실간장절임고 1통6,000원\n깻잎 1통6,000원\n</content>\n<document><content>store_name: 옛날농장 논현점 \n category: 육류,고기요리 \n new_open:   \n rating: 별점 4.57 \n visited_review: 방문자 리뷰 614 \n directions_text: <찾아오시는길>\n논현역 3번출구로 나와 250M (도보 3분)\n신논현역 3번출구에서 나와 330M (도보 5분) 만 걸으면 옛날농장 입니다.\n신논현역 주변에서 쇼핑 하시고! 5분만 걸어오시면 <20년 전통 숯불갈비 전문점 > 옛날농장에서 맛있는 만날수 있습니다.\n\n<주차장 안내 2시간 주차할인>\n서울특별시 강남구 논현동 163-11 (명성주차장)\n\n명성주차장 이용시 2시간 3000원에 주차가능합니다.\n매장 식사후 주차권에 도장 꼭!!! 받아가셔야 할인적용 됩니다.\n\n명성주차장 만차시\n논현초등학교 공영주차장 이용부탁 드립니다.\n주소: 서울특별시 강남구 강남대로 120길 33\n\n연인, 친구, 가족,동료와 함께하는 특별한 날에는!\n옛날농장에서 숯불 양념갈비를 포함한 맛있는 음식들로 좋은시간 보내세요!\n내용 더보기 \n store_id: 1845236311 \n address: 서울 강남구 학동로2길 57 1층 2층 \n blog_review: 블로그 리뷰 1,079 \n phone_num: 0507-1358-7758 \n business_hours: 월\n00:00 - 24:00\n화\n00:00 - 24:00\n수\n00:00 - 24:00\n목\n00:00 - 24:00\n금\n00:00 - 24:00\n토\n00:00 - 24:00\n일\n00:00 - 24:00\n \n info: 우리의 맛과 멋을 이어가는 옛날농장입니다.\n20년전통의 숯불갈비 고깃집 점입니다.\n강남 24시 맛집으로 자리잡기위해 노력중입니다.\n저희의 삼겹살과 목살은 녹차를 먹여 키운 프리미엄 돼지인 보성녹돈을 사용합니다.\n소고기또한 좋은 원육의 차별화된 부드러움과 지방의 고소함을 느껴보세요.\n\n점심시간이 기다려지는 다양한 한식 점심식사 메뉴도 준비되어 있습니다.\n\n논현역 최고 시설로 쾌적한 식사를 위해 하향식 후드 설치로 연기가 최대한 아래로 빨려가도록 설비하였습니다.\n\n단체석 완비로 후회없는 회식, 모임 준비하도록 하겠습니다.\n\n주차는 자주식 주차장이며 매장에서 논현역 방면으로 50m 직진하면 명성 주차장에 주차하시고 도장받아가시면 2시간에 3300원입니다.\n(만차시 논현초등학교 공영주차장 이용 부탁드립니다.)\n\n옛날 농장은 정성이 담긴 맛있는 음식과 신선한 식재료를 사용하여\n강남24시 고깃집 중 최고 맛집을 목표로 고객님들을 대접하겠습니다.\n\n감사합니다.\n펼쳐보기 \n convenience_facilities_and_services: 단체 이용 가능\n예약\n포장\n남/녀 화장실 구분\n무선 인터넷\n배달\n \n Parking: 주차가능 \n sns: nan \n review_like_this_part_output: "음식이 맛있어요"이 키워드를 선택한 인원275\n"친절해요"이 키워드를 선택한 인원115\n"매장이 넓어요"이 키워드를 선택한 인원86\n"고기 질이 좋아요"이 키워드를 선택한 인원77\n"가성비가 좋아요"이 키워드를 선택한 인원65\n"매장이 청결해요"이 키워드를 선택한 인원59\n"단체모임 하기 좋아요"이 키워드를 선택한 인원56\n"재료가 신선해요"이 키워드를 선택한 인원53\n"양이 많아요"이 키워드를 선택한 인원53\n"특별한 메뉴가 있어요"이 키워드를 선택한 인원39\n"혼밥하기 좋아요"이 키워드를 선택한 인원15\n"반찬이 잘 나와요"이 키워드를 선택한 인원11\n"인테리어가 멋져요"이 키워드를 선택한 인원10\n"특별한 날 가기 좋아요"이 키워드를 선택한 인원8\n"주차하기 편해요"이 키워드를 선택한 인원7\n"잡내가 적어요"이 키워드를 선택한 인원6\n"메뉴 구성이 알차요"이 키워드를 선택한 인원6\n"화장실이 깨끗해요"이 키워드를 선택한 인원6\n"음식이 빨리 나와요"이 키워드를 선택한 인원3\n"직접 잘 구워줘요"이 키워드를 선택한 인원3\n"뷰가 좋아요"이 키워드를 선택한 인원3\n"아늑해요"이 키워드를 선택한 인원2\n"오래 머무르기 좋아요"이 키워드를 선택한 인원2\n"좌석이 편해요"이 키워드를 선택한 인원1\n"컨셉이 독특해요"이 키워드를 선택한 인원1\n"비싼 만큼 가치있어요"이 키워드를 선택한 인원1\n"건강한 맛이에요"이 키워드를 선택한 인원1\n"환기가 잘 돼요"이 키워드를 선택한 인원1\n \n menu: 명품수제돼지갈비대표옛날농장 20년 전통 양념으로 만든 돼지갈비입니다.19,000원\n설화 꽃갈비살대표최고등급의 소 6,7,8 번 갈비대에서 나오는 꽃갈비살입니다.\n최고의 맛을 선사합니다34,000원\n통삼겹살대표좋은 원육으로 승부보는 삼겹살이 최고입니다!16,000원\n명품 소 양념갈비20년 전통 옛날농장 소양념갈비입니다.33,000원\n차돌박이20,000원\n소갈빗살숯불에 구워먹는 갈비살 입니다.\n맛있는 양념갈비살도 준비되어 있습니다.20,000원\n보성녹돈 특목살16,000원\n오돌갈비17,000원\n한라산 황제살18,000원\n명품 소고기 해장국9,000원\n낙곱새 뚝배기11,000원\n생고기김치찌개9,000원\n뚝배기 불고기9,000원\n차돌된장찌개9,000원\n고추장 돼지불백11,000원\ ...
#  'context_opendata': '<document><content>상호명: 나전과 옻칠\u3000\u3000 \n 콘텐츠URL: https://korean.visitseoul.net/entertainment/나전과-옻칠/KOP018888?utm_source=seoulopendata&utm_medium=entertainment&utm_content=KOP018888 \n 주소: 110-800 서울 종로구 계동 25  \n 신주소: 03057 서울 종로구 계동4길 3 (계동)  \n 전화번호: 070-8860-9880\u3000 \n 웹사이트: https://blog.naver.com/krhg252017 \n 운영시간: 11:00~17:00 \n 운영요일: 월요일~토요일 \n 휴무일: 일요일 \n 교통정보: 3호선 안국역 3번 출구에서 약 635m (도보 10분)  \n 홈페이지 운영 언어: 한국어 \n 유모차 대여 여부: nan</content>\n<document><content>상호: 나를위한 산부인과의원 \n 대표자: 이은정 \n 기관구분: 의원 \n 주소: 서울특별시 강남구 강남대로 364 (역삼동, 미왕빌딩) 9층 나를위한 산부인과의원 \n 타겟국가: 미국/일본/중국/러시아/중동/몽골/베트남</content>\n<document><content>상호: 처음처럼성형외과의원 \n 대표자: 이방석 \n 기관구분: 의원 \n 주소: 서울특별시 강남구 테헤란로 111 (역삼동, 대건빌딩) 8층 처음처럼성형외과 (역삼동,대건빌딩) \n 타겟국가: 일본/중국/기타</content>\n<document><content>상호: 프린스성형외과의원 \n 대표자: 박신기 \n 기관구분: 의원 \n 주소: 서울특별시 강남구 도산대로 104 (논현동, 1st Avenue) 2층, 프린스 성형외과 \n 타겟국가: 미국/일본/중국/러시아/중동/몽골/베트남/기타</content>\n<document><content>상호: 케이앤에스성형외과의원 \n 대표자: 김영수 \n 기관구분: 의원 \n 주소: 서울특별시 강남구 봉은사로 140 (역삼동,마에스트로빌딩지하1층,1층,2층) \n 타겟국가: 미국,일본,중국,러시아,중동,몽골,베트남,</content>\n<document><content>상호: 케이플러스성형외과의원 \n 대표자: 김세영 \n 기관구분: 의원 \n 주소: 서울특별시 강남구 도산대로 333 (신사동, K+ 메디칼타워) 14,15층 케이플러스성형외과 \n 타겟국가: 미국/일본/중국/러시아/중동/몽골/베트남/기타</content>\n<document><content>상호: 어제오늘 성형외과 \n 대표자: 윤형노 \n 기관구분: 의원 \n 주소: 우편번호 : 135-825 서울시 강남구 학동로 6길 42. 4층 \n 타겟국가: 일본,중국,몽골,</content>\n<document><content>상호: 문의원 \n 대표자: 박문수 \n 기관구분: 의원 \n 주소: 서울특별시 강남구 논현로168길 40 (신사동, 레아트문클리닉 타워) 2,3층 문의원 \n 타겟국가: 일본/중국</content>\n<document><content>상호: 케이아트성형외과의원 \n 대표자: 김남복 \n 기관구분: 의원 \n 주소: 서울특별시 강남구 논현로 831 (신사동, 네오스) 동아빌딩 3층  케이아트 성형외과 \n 타겟국가: 미국/일본/중국/러시아/중동/몽골/베트남/기타</content>\n<document><content>상호: 아이팅성형외과의원 \n 대표자: 김종규 \n 기관구분: 의원 \n 주소: 서울특별시 강남구 논현로175길 6 (신사동) 로얄빌딩 2층 아이팅성형외과 \n 타겟국가: 미국/일본/중국/몽골/베트남</content>',
#  'answer': '용산구와 중구에서의 일정 계획을 세워드릴게요. 두 지역은 서울의 중심부에 위치해 있어 다양한 문화와 역사를 경험할 수 있는 곳입니다. 아래는 추천 일정입니다.\n\n### 1일차: 용산구\n\n**오전**\n- **국립중앙박물관**: 한국의 역사와 문화를 깊이 있게 이해할 수 있는 국립중앙박물관을 방문하세요. 다양한 전시와 유물들이 있습니다. (운영시간: 10:00~18:00)\n\n**점심**\n- **이태원**: 다양한 국제 요리를 즐길 수 있는 이태원에서 점심을 드세요. 여러 나라의 음식을 맛볼 수 있는 곳입니다.\n\n**오후**\n- **용산 전쟁기념관**: 한국 전쟁의 역사를 배울 수 있는 전쟁기념관을 방문하세요. (운영시간: 09:00~18:00)\n- **성수미술관 용산점**: 삼각지역 근처에 위치한 성수미술관에서 드로잉 체험을 즐기며 여유로운 시간을 보내세요. (운영시간: 12:00~21:30)\n\n**저녁**\n- **남산타워**: 서울의 야경을 감상할 수 있는 남산타워를 방문하세요. 케이블카를 타고 올라가면 더욱 특별한 경험이 될 것입니다.\n\n### 2일차: 중구\n\n**오전**\n- **덕수궁**: 조선 시대의 궁궐인 덕수궁을 방문하여 한국의 전통 건축을 감상하세요. (운영시간: 09:00~18:00)\n\n**점심**\n- **죽이야기 서울 중구소공점**: 건강한 한식을 제공하는 죽이야기에서 전복죽이나 다양한 죽 메뉴를 즐기세요. (운영시간: 08:00~16:00)\n\n**오후**\n- **명동 쇼핑 거리**: 다양한 브랜드와 상점이 모여 있는 명동에서 쇼핑을 즐기세요.\n- **청계천 헌책방 거리**: 을지로에 위치한 청계천 헌책방 거리에서 다양한 헌책과 독특한 아이템을 구경하세요.\n\n**저녁**\n- **어슬 서울**: 서울역 근처에 위치한 어슬 서울에서 퓨전 한식과 전통주를 즐기며 하루를 마무리하세요. (운영시간: 11:30~23:00)\n\n이 일정은 용산구와 중구의 주요 명소를 중심으로 구성되었습니다. 각 장소의 운영 시간과 위치를 확인하시고, 이동 시간을 고려하여 일정을 조정하시면 좋습니다. 즐거운 여행 되세요!',
#  'messages': [HumanMessage(content='종로구에서 1박 2일 여행 일정을 추천해 줄 수 있나요?', additional_kwargs={}, response_metadata={}, id='af83e222-371a-4ecf-9889-ab58886ca325'),
#   AIMessage(content='종로구에서의 1박 2일 여행 일정을 추천해드릴게요. 종로구는 서울의 역사와 문화를 느낄 수 있는 곳으로, 다양한 관광 명소와 맛집이 많습니다. 아래는 추천 일정입니다.\n\n### 1일차\n\n**오전**\n- **북촌한옥마을**: 전통 한옥이 모여 있는 북촌한옥마을을 산책하며 한국의 전통 건축을 감상하세요. 사진 찍기 좋은 장소입니다.\n- **전통공예체험관**: 북촌한옥마을 근처에 위치한 전통공예체험관에서 한국 전통 공예를 체험해보세요. (운영시간: 10:00~18:00)\n\n**점심**\n- **쌈지길 체험공방**: 인사동에 위치한 쌈지길에서 다양한 공예품을 구경하고, 인근 식당에서 전통 한식을 즐겨보세요. (운영시간: 10:30~20:30)\n\n**오후**\n- **경복궁**: 한국의 대표적인 궁궐인 경복궁을 방문하여 조선시대의 역사를 느껴보세요. 경복궁 근처에는 국립민속박물관도 있어 함께 방문하기 좋습니다.\n- **인사동 거리**: 전통과 현대가 어우러진 인사동 거리에서 다양한 전통 공예품과 기념품을 구경하세요.\n\n**저녁**\n- **우리집 게스트하우스**: 종로구 계동에 위치한 우리집 게스트하우스에서 편안한 휴식을 취하세요. (운영시간: 24시간)\n\n### 2일차\n\n**오전**\n- **서울김치문화체험관**: 명동에 위치한 서울김치문화체험관에서 김치 만들기 체험을 해보세요. (운영시간: 10:30~19:00)\n\n**점심**\n- **연서네 철문집**: 서울역 근처에 위치한 연서네 철문집에서 맛있는 삼겹살을 즐기세요. (운영시간: 15:00~03:00)\n\n**오후**\n- **청계천 헌책방 거리**: 을지로에 위치한 청계천 헌책방 거리에서 다양한 헌책과 독특한 아이템을 구경하세요.\n- **동대문 디자인 플라자(DDP)**: 동대문에 위치한 DDP에서 현대적인 건축물과 다양한 전시를 관람하세요.\n\n**저녁**\n- **한판도 역삼점**: 강남에 위치한 한판도 역삼점에서 저녁 식사를 즐기며 여행을 마무리하세요. (운영시간: 11:30~22:00)\n\n이 일정은 종로구와 그 주변의 주요 명소를 중심으로 구성되었습니다. 각 장소의 운영 시간과 위치를 확인하시고, 이동 시간을 고려하여 일정을 조정하시면 좋습니다. 즐거운 여행 되세요!', additional_kwargs={}, response_metadata={}, id='555cdf20-ce9c-4ccf-a5fb-ae49ba2bc432'),
#   HumanMessage(content='용산구와 중구에서의 일정 계획을 어떻게 세울 수 있을까요?', additional_kwargs={}, response_metadata={}, id='d2805cf4-2e6a-48c3-82e1-822cf19ae600'),
#   AIMessage(content='용산구와 중구에서의 일정 계획을 세워드릴게요. 두 지역은 서울의 중심부에 위치해 있어 다양한 문화와 역사를 경험할 수 있는 곳입니다. 아래는 추천 일정입니다.\n\n### 1일차: 용산구\n\n**오전**\n- **국립중앙박물관**: 한국의 역사와 문화를 깊이 있게 이해할 수 있는 국립중앙박물관을 방문하세요. 다양한 전시와 유물들이 있습니다. (운영시간: 10:00~18:00)\n\n**점심**\n- **이태원**: 다양한 국제 요리를 즐길 수 있는 이태원에서 점심을 드세요. 여러 나라의 음식을 맛볼 수 있는 곳입니다.\n\n**오후**\n- **용산 전쟁기념관**: 한국 전쟁의 역사를 배울 수 있는 전쟁기념관을 방문하세요. (운영시간: 09:00~18:00)\n- **성수미술관 용산점**: 삼각지역 근처에 위치한 성수미술관에서 드로잉 체험을 즐기며 여유로운 시간을 보내세요. (운영시간: 12:00~21:30)\n\n**저녁**\n- **남산타워**: 서울의 야경을 감상할 수 있는 남산타워를 방문하세요. 케이블카를 타고 올라가면 더욱 특별한 경험이 될 것입니다.\n\n### 2일차: 중구\n\n**오전**\n- **덕수궁**: 조선 시대의 궁궐인 덕수궁을 방문하여 한국의 전통 건축을 감상하세요. (운영시간: 09:00~18:00)\n\n**점심**\n- **죽이야기 서울 중구소공점**: 건강한 한식을 제공하는 죽이야기에서 전복죽이나 다양한 죽 메뉴를 즐기세요. (운영시간: 08:00~16:00)\n\n**오후**\n- **명동 쇼핑 거리**: 다양한 브랜드와 상점이 모여 있는 명동에서 쇼핑을 즐기세요.\n- **청계천 헌책방 거리**: 을지로에 위치한 청계천 헌책방 거리에서 다양한 헌책과 독특한 아이템을 구경하세요.\n\n**저녁**\n- **어슬 서울**: 서울역 근처에 위치한 어슬 서울에서 퓨전 한식과 전통주를 즐기며 하루를 마무리하세요. (운영시간: 11:30~23:00)\n\n이 일정은 용산구와 중구의 주요 명소를 중심으로 구성되었습니다. 각 장소의 운영 시간과 위치를 확인하시고, 이동 시간을 고려하여 일정을 조정하시면 좋습니다. 즐거운 여행 되세요!', additional_kwargs={}, response_metadata={}, id='ae25ba32-c182-4265-81a7-86d227aee8fd'),
#   HumanMessage(content='내가 이전에 한 질문은 무엇인가요?', additional_kwargs={}, response_metadata={}, id='b0fd8c40-8ac9-4bf5-906a-d9664b06dc70'),
#   AIMessage(content='용산구와 중구에서의 일정 계획을 세워드릴게요. 두 지역은 서울의 중심부에 위치해 있어 다양한 문화와 역사를 경험할 수 있는 곳입니다. 아래는 추천 일정입니다.\n\n### 1일차: 용산구\n\n**오전**\n- **국립중앙박물관**: 한국의 역사와 문화를 깊이 있게 이해할 수 있는 국립중앙박물관을 방문하세요. 다양한 전시와 유물들이 있습니다. (운영시간: 10:00~18:00)\n\n**점심**\n- **이태원**: 다양한 국제 요리를 즐길 수 있는 이태원에서 점심을 드세요. 여러 나라의 음식을 맛볼 수 있는 곳입니다.\n\n**오후**\n- **용산 전쟁기념관**: 한국 전쟁의 역사를 배울 수 있는 전쟁기념관을 방문하세요. (운영시간: 09:00~18:00)\n- **성수미술관 용산점**: 삼각지역 근처에 위치한 성수미술관에서 드로잉 체험을 즐기며 여유로운 시간을 보내세요. (운영시간: 12:00~21:30)\n\n**저녁**\n- **남산타워**: 서울의 야경을 감상할 수 있는 남산타워를 방문하세요. 케이블카를 타고 올라가면 더욱 특별한 경험이 될 것입니다.\n\n### 2일차: 중구\n\n**오전**\n- **덕수궁**: 조선 시대의 궁궐인 덕수궁을 방문하여 한국의 전통 건축을 감상하세요. (운영시간: 09:00~18:00)\n\n**점심**\n- **죽이야기 서울 중구소공점**: 건강한 한식을 제공하는 죽이야기에서 전복죽이나 다양한 죽 메뉴를 즐기세요. (운영시간: 08:00~16:00)\n\n**오후**\n- **명동 쇼핑 거리**: 다양한 브랜드와 상점이 모여 있는 명동에서 쇼핑을 즐기세요.\n- **청계천 헌책방 거리**: 을지로에 위치한 청계천 헌책방 거리에서 다양한 헌책과 독특한 아이템을 구경하세요.\n\n**저녁**\n- **어슬 서울**: 서울역 근처에 위치한 어슬 서울에서 퓨전 한식과 전통주를 즐기며 하루를 마무리하세요. (운영시간: 11:30~23:00)\n\n이 일정은 용산구와 중구의 주요 명소를 중심으로 구성되었습니다. 각 장소의 운영 시간과 위치를 확인하시고, 이동 시간을 고려하여 일정을 조정하시면 좋습니다. 즐거운 여행 되세요!', additional_kwargs={}, response_metadata={}, id='139b20ef-a175-49b3-9dd8-281bbfaa40d3')],
#  'webOrRetriever': 'retriever'}

# %%
print(res.get('answer'))
# Out:
# 용산구와 중구에서의 일정 계획을 세워드릴게요. 두 지역은 서울의 중심부에 위치해 있어 다양한 문화와 역사를 경험할 수 있는 곳입니다. 아래는 추천 일정입니다.
#
# ### 1일차: 용산구
#
# **오전**
# - **국립중앙박물관**: 한국의 역사와 문화를 깊이 있게 이해할 수 있는 국립중앙박물관을 방문하세요. 다양한 전시와 유물들이 있습니다. (운영시간: 10:00~18:00)
#
# **점심**
# - **이태원**: 다양한 국제 요리를 즐길 수 있는 이태원에서 점심을 드세요. 여러 나라의 음식을 맛볼 수 있는 곳입니다.
#
# **오후**
# - **용산 전쟁기념관**: 한국 전쟁의 역사를 배울 수 있는 전쟁기념관을 방문하세요. (운영시간: 09:00~18:00)
# - **성수미술관 용산점**: 삼각지역 근처에 위치한 성수미술관에서 드로잉 체험을 즐기며 여유로운 시간을 보내세요. (운영시간: 12:00~21:30)
#
# **저녁**
# - **남산타워**: 서울의 야경을 감상할 수 있는 남산타워를 방문하세요. 케이블카를 타고 올라가면 더욱 특별한 경험이 될 것입니다.
#
# ### 2일차: 중구
#
# **오전**
# - **덕수궁**: 조선 시대의 궁궐인 덕수궁을 방문하여 한국의 전통 건축을 감상하세요. (운영시간: 09:00~18:00)
#
# **점심**
# - **죽이야기 서울 중구소공점**: 건강한 한식을 제공하는 죽이야기에서 전복죽이나 다양한 죽 메뉴를 즐기세요. (운영시간: 08:00~16:00)
#
# **오후**
# - **명동 쇼핑 거리**: 다양한 브랜드와 상점이 모여 있는 명동에서 쇼핑을 즐기세요.
# - **청계천 헌책방 거리**: 을지로에 위치한 청계천 헌책방 거리에서 다양한 헌책과 독특한 아이템을 구경하세요.
#
# **저녁**
# - **어슬 서울**: 서울역 근처에 위치한 어슬 서울에서 퓨전 한식과 전통주를 즐기며 하루를 마무리하세요. (운영시간: 11:30~23:00)
#
# 이 일정은 용산구와 중구의 주요 명소를 중심으로 구성되었습니다. 각 장소의 운영 시간과 위치를 확인하시고, 이동 시간을 고려하여 일정을 조정하시면 좋습니다. 즐거운 여행 되세요!

# %%
from langchain_core.runnables import RunnableConfig
from langchain_teddynote.messages import invoke_graph, stream_graph, random_uuid

# config 설정(재귀 최대 횟수, thread_id)
config = RunnableConfig(recursion_limit=20, configurable={"thread_id": random_uuid()})

# 질문 입력
inputs = GraphState(question="용산구의 1박2일 머무려고 해일정을 만들어 줄 수 있어?")

# 그래프 실행
invoke_graph(app, inputs, config)
# Out:
# ==================================================
# 🔄 Node: location_check 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# location:
# ['용산구']
# ==================================================
#
# ==================================================
# 🔄 Node: retrieve_document_naver_gangnam 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# context_naver_gangnam:
# <document><content>store_name: 먼데이투선데이 청담
#  category: 양식
#  new_open:
#  rating: 정보없음
#  visited_review: 방문자 리뷰 1,008
#  directions_text: 발렛 가능 (기본요금 2시간 5,000원 / 추가 10분당 1,000원)
# 단, 슈퍼카 기본요금 10,000원
#
# 343,4212번 버스 이용, 농협앞에서 하차.
# 농협 골목에서 50m 직진, 컷루스 옆에 위치
#
# 지하철 이용후 찾아오는길
#
# 압구정로데오역(신분당선) 3번출구에서 도보 10분
# 3번출구에서 250M 직진후 펜디매장에서 우회전
# 200M 볼트스테이크 하우스 까지 걸어오시면
# 미노트 매장이 보입니다.
# 여기서 우회전 하시면 먼데이투선데이 를 만날 수 있습니다.
#
# 네비게이션을 이용하여 찾아오실경우
# 티맵, 카카오네비 먼데이투선데이 로 검색후 주소를 선택하시면 됩니다.
#
# (서울시 강남구 도산대로67길 13-3 EMPRESS빌딩 B1층)
# 내용 더보기
#  store_id: 1766605714
#  address: 서울 강남구 도산대로67길 13-3 EMPRESS빌딩 B1층
#  blog_review: 블로그 리뷰 165
#  phone_num: 0507-1353-2217
#  business_hours: 화
# 08:00 - 02:00
# 01:30 라스트오더
# 수(1/1)
# 11:00 - 02:00
# 목
# 08:00 - 02:00
# 01:30 라스트오더
# 금
# 08:00 - 02:00
# 01:30 라스트오더
# 토
# 10:00 - 02:00
# 01:30 라스트오더
# 일
# 10:00 - 01:00
# 00:30 라스트오더
# 월
# 08:00 - 01:00
# 00:30 라스트오더
#
#  info: https://app.catchtable.co.kr/ct/shop/diningbar_mondaytosunday
#
# [브런치/디저트/ 레스토랑/ 주류페어링의 즐거움이 있는 먼데이투선데이]
#
# 와플, 로제 떡볶이 맛집이 청담에 있다?!
#
# 누구나 편하게 와서 머무를 수 있는 청담동 카페/레스토랑/와인바가 되길 원합니다.
#
# 탁 트인 테라스 공간에서 친구들과 안주와 함께 와인 한 잔
# 온가족이 모여 맛있는 디저트를 먹으며 커피 한 잔
# 어떠실까요?
#
# 많은 분들이 먼데이투선데이에 방문하셔서 편안한 시간을 보내고 도심 속 힐링 공간이 되길 바랍니다
# 펼쳐보기
#  convenience_facilities_and_services: 콜키지 가능
# 유료
# 무선 인터넷
# 남/녀 화장실 구분
# 예약
# 단체 이용 가능
# \
# 반려동물 동반
# 유아의자
# 포장
#
#  Parking: 주차가능
# 유료
# 최초 120분 5000원
# 추가 요금 10분당 1,000원, 최대 100,000원
#  sns: https://app.catchtable.co.kr/ct/shop/diningbar_mondaytosunday
# https://www.instagram.com/diningbar_mondaytosunday
#
#  review_like_this_part_output: "음식이 맛있어요"이 키워드를 선택한 인원808
# "인테리어가 멋져요"이 키워드를 선택한 인원708
# "매장이 넓어요"이 키워드를 선택한 인원438
# "친절해요"이 키워드를 선택한 인원408
# "재료가 신선해요"이 키워드를 선택한 인원276
# "매장이 청결해요"이 키워드를 선택한 인원206
# "특별한 메뉴가 있어요"이 키워드를 선택한 인원189
# "대화하기 좋아요"이 키워드를 선택한 인원105
# "양이 많아요"이 키워드를 선택한 인원99
# "단체모임 하기 좋아요"이 키워드를 선택한 인원91
# "디저트가 맛있어요"이 키워드를 선택한 인원61
# "커피가 맛있어요"이 키워드를 선택한 인원57
# "주차하기 편해요"이 키워드를 선택한 인원54
# "화장실이 깨끗해요"이 키워드를 선택한 인원54
# "사진이 잘 나와요"이 키워드를 선택한 인원51
# "뷰가 좋아요"이 키워드를 선택한 인원46
# "아늑해요"이 키워드를 선택한 인원45
# "음료가 맛있어요"이 키워드를 선택한 인원45
# "비싼 만큼 가치있어요"이 키워드를 선택한 인원37
# "차분한 분위기에요"이 키워드를 선택한 인원35
# "메뉴 구성이 알차요"이 키워드를 선택한 인원29
# "좌석이 편해요"이 키워드를 선택한 인원27
# "야외공간이 멋져요"이 키워드를 선택한 인원26
# "특별한 날 가기 좋아요"이 키워드를 선택한 인원21
# "가성비가 좋아요"이 키워드를 선택한 인원18
# "반려동물과 가기 좋아요"이 키워드를 선택한 인원17
# "혼밥하기 좋아요"이 키워드를 선택한 인원12
# "음악이 좋아요"이 키워드를 선택한 인원12
# "컨셉이 독특해요"이 키워드를 선택한 인원11
# "오래 머무르기 좋아요"이 키워드를 선택한 인원10
# "음식이 빨리 나와요"이 키워드를 선택한 인원6
# "건강한 맛이에요"이 키워드를 선택한 인원5
# "술이 다양해요"이 키워드를 선택한 인원4
# "룸이 잘 되어있어요"이 키워드를 선택한 인원3
# "집중하기 좋아요"이 키워드를 선택한 인원3
# "코스요리가 알차요"이 키워드를 선택한 인원2
# "아이와 가기 좋아요"이 키워드를 선택한 인원2
# "고기 질이 좋아요"이 키워드를 선택한 인원2
# "기본 안주가 좋아요"이 키워드를 선택한 인원1
#
#  menu: 한우 찹스테이크대표숙성한 채끝 등심을 이용해 여러가지 신선한 야채와 수제소스로 맛을낸 찹 스테이크39,000원
# 스파이시 씨푸드 파스탕대표신선한 꽃게와 해산물이 가득, 해장하기 좋은 매콤한 리가토니 파스탕28,000원
# 촉촉한 프렌치 토스트대표달걀과 버터로 촉촉하게 구워낸 먼투썬만의 시그니처 프렌치 토스트23,000원
# 우삼겹 로제 떡볶이대표고소하고 진한 소스가 매력적인 먼투썬만의 로제 떡볶이29,000원
# 먼투선 김치볶음밥대표삼겹살이 듬뿍 들어간 먼데이 투 선데이 김치볶음밥24,000원
# 카므라이스대표우삼겹이 들어간 카레와 오므라이스의 장점만 살린 먼데이투선데이 퓨전요리22,000원
# 버터새우 시저 샐러드대표버터풍미의 새우가 올려진 로메인 시저샐러드24,000원
# 트러플 허니 프렌치 후라이(감튀)대표트러플과 꿀을 코팅해 중독성이 강한 감자튀김20,000원
# 제철과일 생크림 케이크(딸기)대표먼투썬만의 레시피로 만든 생크림과 신선한 제철 과일과의 만남! 생크림 케이크 완추♥16,000원
# 브라우니와 바닐라 아이스크림대표부드러운 밀크초콜릿이 듬뿍 들어간 브라우니와 바닐라 아이스크림15,000원
# 한우 1++ No.9 채끝등심스테이크최상급 채끝 등심과 남해 보물초 시금치 그리고 경북 특산물 송향버섯이 올라간 스테이크73,000원
# 풀드포크&고구마퓨레긴 시간 훈연한 풀풀드포크와 부드러운 고구마무스의 만남, 깊고 따뜻한 풍미를 즐겨보세요!20,000원
# 치즈 곶감말이쫀득한 곶감 속에 치즈의 부드러움이 더해진 깊은 맛, 완벽한 밸런스!13,000원
# 과일 플레터신선한 과일들이 입안 가득 가득!16,000원
# 과일 치즈 올리브(+빵3slices)상큼한 과일과 고소한 치즈, 올리브가 어우러져, 한 입에 담긴 풍미의 향연!13,000원
# </content>
# <document><content>store_name: 미도인 문정법조타운
#  category: 양식
#  new_open:
#  rating: 정보없음
#  visited_review: 방문자 리뷰 694
#  directions_text: 미도인 문정법조타운점은 서울 송파구 법원로 114 엠스테이트 E동 지하 1층 B125, B126에 위치해 있습니다!
#
# ※ 대중교통 이용시
# 1. 문정역(8호선) 2번 출구로 나오셔서 LG 베스트샵을 끼고 4블럭 직진 후 좌회전 (도보로 10~15분 소요)
# 2. 경찰병원역(3호선) 4번 출구로 나오셔서 LG전자 대리점(공사중) 끼고 좌회전 후 현대아파트까지 직진 (도보로 10~15분 소요)
#
# ※ 자가용 이용시
# 주차는 건물 내 지하 주차장 2시간 무료 이용이 가능합니다!
#
# ※ 도보 이용시
# 문정역 3번출구에서 엠스테이트 상가입구로 내려가는 에스컬레이터로 들어오시면 쉽게 찾을수 있습니다!
# A동상가 엘레베이터에서 내리시면 바로 앞쪽입니다!
#
# 위의 정보를 참고하시면 미도인 문정법조타운점을 쉽게 찾으실 수 있습니다.
# 내용 더보기
#  store_id: 1493608587
#  address: 서울 송파구 법원로 114 엠스테이트 E동 지하1층 B125, B126호
#  blog_review: 블로그 리뷰 110
#  phone_num: 0507-1413-9037
#  business_hours: 화
# 11:00 - 21:00
# 수(1/1)
# 새해 첫날11:00 - 21:00
# 목
# 11:00 - 21:00
# 금
# 11:00 - 21:00
# 토
# 11:00 - 21:00
# 일
# 11:00 - 21:00
# 월
# 11:00 - 21:00
#
#  info: 미도인 문정법조타운점은 서울 송파구 법원로 114 엠스테이트 E동 지하 1층 B125, B126에 위치해 있습니다!
#
# ※ 대중교통 이용시
# 1. 문정역(8호선) 2번 출구로 나오셔서 LG 베스트샵을 끼고 4블럭 직진 후 좌회전 (도보로 10~15분 소요)
# 2. 경찰병원역(3호선) 4번 출구로 나오셔서 LG전자 대리점(공사중) 끼고 좌회전 후 현대아파트까지 직진 (도보로 10~15분 소요)
#
# ※ 자가용 이용시
# 주차는 건물 내 지하 주차장 2시간 무료 이용이 가능합니다!
#
# ※ 미도인 문정법조타운점이 유명해진 이유 첫번째~!
#
# 1.서울 송파구에서 직장인들의 점심 식사 점심특선 HIT 상품 다양한 한상차림 메뉴!
# 2.평일 점심시간에는 웨이팅이 있을 수 있지만, 테이블이 많고 회전율이 빨라 대기 시간이 길지 않아요!
# 3.브레이크 타임이 없는 식당으로, 언제든지 편하게 방문이 가능! 남들보다 살짝 늦은 점심시간도 OK!
# 4.와인, 맥주, 생맥주, 소주, 화요등과 함께 각종 메뉴를 즐기는 직장인들의 회식!
# 5.주말 및 공휴일엔 소중한 만남,반가운 모임, 가족모임등을 즐기기 좋은 핫플! 바로 여기!
# 6.고급스럽고 깔끔한 인테리어로 소개팅, 데이트 장소로 인기 굿~!
# 7.오후 2시 이후 4인이상 네이버예약 후 방문하시면 와인1병이 무료!
#
# ※ 미도인 문정법조타운점이 유명해진 이유 두번째~!
#
# 미도인 문정법조타운점은 메뉴 카테고리가 매우매우 다양합니다~^^
# 스테이크,한상차림, 덮밥, 파스타,라멘, 소바, 샐러드,떡볶이 등 다양한 메뉴를 즐길 수 있는 미도인 입니다!
#
# 1.스테이크: 미도인 등심 스테이크, 트리플 등심 스테이크, 대창 등심 스테이크,곱창 등심 스테이크 등
#
# 2.한상차림 : 등심스테이크 한상차림, 곱창&대창덮밥 한상차림,단새우스테이크덮밥 한상차림,우니 스테이크덮밥 한상차림 등
#
# 3.덮밥: 큐브 스테이크 덮밥, 화산불백 덮밥, 대창큐브 스테이크 덮밥 등
#
# 4.파스타: 바질 크림 새우 파스타, 명란 크림 파스타, 새우 로제 파스타 등
#
# 5.라멘 : 곱창 라멘, 우육면, 청두 사천 탄탄멘 등
#
# 6.소바 : 가케소바, 단새우 가케소바, 마제소바, 곱창대창 마제소바 등
#
# 7.스페셜 : 미도인 떡볶이,미도인 곱창 떡볶이, 스카치 에그 등
#
# ※ 미도인 문정법조타운점이 유명해진 이유 세번째~!
#
# 많은 방문 고객분들이 미도인 문정법조타운의 맛과 분위기에 대해 긍정적인 리뷰를 남기고 있습니다.
#
# 1.스테이크가 정말 맛있어요. 가족들과 함께 방문했는데 모두 만족했습니다.
# 2.분위기가 정말 좋아서 소중한 만남, 반가운 모임에 좋을 것 같아요.
# 3.점심시간에 방문했는데, 음식이 빨리 나와서 좋았습니다.
#
# 직접 리뷰를 확인해 보시고 방문해 주세요 ^-^)//
#
# 방문해 주시는 모든 분들의 먹는 즐거움, 보는 즐거움,머무는 즐거움을 선사드릴 수 있도록
# 고객의 관점에서 고객을 만족 시켜드릴수 있도록 전직원이 노력하겠습니다!
#
# 고급스러운 인테리어와 아늑한 분위기로 문정역, 문정동, 가락시장역,장지역 인근에서 맛있는 스테이크, 덮밥, 파스타,소바,라멘 등을 즐기고 싶은 분들에게 추천하는 맛집입니다. 문정동맛집,문정역맛집,문정맛집,가락시장맛집,송파구맛집,가락시장역맛집,장지역맛집,문정동떡볶이,서울송파맛집,서울송파구맛집,문정동파스타,문정법조타운맛집,문정동점심,문정동밥집 등으로 감사하게도 많은 분들께 추천됩니다.
#
# 방문 하시는 모든 분들이 즐거운 식사를 즐기시길 바랍니다!
# 펼쳐보기
#  convenience_facilities_and_services: 단체 이용 가능
# 포장
# 예약
# 남/녀 화장실 구분
# 유아의자
#
#  Parking: 주차가능
# 유료
# 추가 요금 10분당 500원, 최대 80,000원
#  sns: https://youtube.com/channel/UCxRWfLoFdwXyIU6_yq38uig?si=tpSW48w87J2hWl1f
#
#  review_like_this_part_output: "음식이 맛있어요"이 키워드를 선택한 인원646
# "친절해요"이 키워드를 선택한 인원354
# "매장이 넓어요"이 키워드를 선택한 인원342
# "인테리어가 멋져요"이 키워드를 선택한 인원266
# "재료가 신선해요"이 키워드를 선택한 인원225
# "매장이 청결해요"이 키워드를 선택한 인원190
# "특별한 메뉴가 있어요"이 키워드를 선택한 인원157
# "양이 많아요"이 키워드를 선택한 인원140
# "가성비가 좋아요"이 키워드를 선택한 인원103
# "혼밥하기 좋아요"이 키워드를 선택한 인원87
# "메뉴 구성이 알차요"이 키워드를 선택한 인원76
# "주차하기 편해요"이 키워드를 선택한 인원33
# "반찬이 잘 나와요"이 키워드를 선택한 인원30
# "단체모임 하기 좋아요"이 키워드를 선택한 인원23
# "차분한 분위기에요"이 키워드를 선택한 인원19
# "고기 질이 좋아요"이 키워드를 선택한 인원18
# "음식이 빨리 나와요"이 키워드를 선택한 인원16
# "대화하기 좋아요"이 키워드를 선택한 인원16
# "아늑해요"이 키워드를 선택한 인원14
# "화장실이 깨끗해요"이 키워드를 선택한 인원12
# "건강한 맛이에요"이 키워드를 선택한 인원11
# "비싼 만큼 가치있어요"이 키워드를 선택한 인원8
# "특별한 날 가기 좋아요"이 키워드를 선택한 인원8
# "잡내가 적어요"이 키워드를 선택한 인원5
# "음악이 좋아요"이 키워드를 선택한 인원5
# "좌석이 편해요"이 키워드를 선택한 인원4
# "아이와 가기 좋아요"이 키워드를 선택한 인원4
# "컨셉이 독특해요"이 키워드를 선택한 인원3
# "음료가 맛있어요"이 키워드를 선택한 인원2
# "사진이 잘 나와요"이 키워드를 선택한 인원2
# "룸이 잘 되어있어요"이 키워드를 선택한 인원1
# "오래 머무르기 좋아요"이 키워드를 선택한 인원1
# "집중하기 좋아요"이 키워드를 선택한 인원1
# "뷰가 좋아요"이 키워드를 선택한 인원1
#
#  menu: 400스테이크 덮밥(런치한정)대표400g이나 한 그릇에 담아 미도인을 일찍 찾아주신 일곱분에게 정성껏 만들어 보답하겠습니다16,800원
# 미도인 스테이크 덮밥대표부드러운 스테이크를 올린 말이 필요없는 미도인 대표 덮밥10,800원
# 차슈 생라멘시머링한 삼겹살 차슈, 목이버섯, 아지다마고, 숙주, 대파가 어우러진 일본식 生라멘9,000원
# 가정식 등심 스테이크부드러운 육즙의 숙성 스테이크와 단호박 스프, 아지다마고의 한상차림(사이즈별 가격 다름)17,600원
# 차슈 덮밥마리네이드한 삼겹살을 각종 채소와 함께 즐기는 일본식 덮밥9,100원
# 청두 사천 탄탄멘사천식으로 만든 매콤한 참깨돈골 육수와 매장에서 직접 만든 탄면장을 얹은 전통 탄탄멘9,300원
# 화산 불백 덮밥불맛 나는 돼지고기를 화산 모양으로 형상화한 비쥬얼 갑 강추 덮밥9,800원
# 미도인 떡볶이미도인 총괄셰프의 특제소스와 돼지고기, 대파가 듬뿍 들어간 약빤메뉴(마라맛첨가)9,800원
# 우육탕면고기 육수의 깊은 맛을 기본으로 生라멘 위에 우삼겹과 각종 고명들과 함께먹는 대만식 면요리9,900원
# 카라 차슈 생라멘'카라'는 맵다라는 뜻으로, 고소하고 매콤한 국물과 시머링한 삼겹살 차슈와 함께 즐기는 면10,300원
# 미도인 마제소바특제소스에 돼지고기 민찌를 볶아 고기고명과 부추,대파,김가루를 함께 비벼먹는 일본식 비빔면10,300원
# 큐브 스테이크 덮밥부드러운 육즙의 숙성 스테이크와 특제 단짠 소스로 만든 스테이크 덮밥11,800원
# 미도인 곱창 라멘(한정메뉴)부드러우면서 쫄깃한 곱창의 식감과 얼큰 시원한 미도인 만의 특별라멘12,800원
# 대창 덮밥말이 필요없는 맛!! 잘 손질된 대창을 매콤한 특제 양념과 불맛 나게 볶아낸 특별 덮밥13,300원
# 명란 크림 파스타깔끔한 명란 크림소스! 특제 스파이시 첨가로 더욱 특별한 미도인만의 특제 파스타13,300원
# </content>
# <document><content>store_name: 밀각
#  category: 족발,보쌈
#  new_open:
#  rating: 별점 4.7
#  visited_review: 방문자 리뷰 746
#  directions_text: 우체국 민영주차장 사용가능합니다
# (아미노 가락본동우체국 주차장)
# 1시간 무료제공
#
# [자가용 이용시]
# 밀각 가락본점
# 서울 송파구 송파대로30길36 검색하시면 됩니다.
#
# [대중교통 이용시]
# 지하철 경찰병원역 1번 출구
# 경찰병원와 가락본동주 민센터 사이골목길로 직진 4분
# KT가락지점 건물 좌회전후 200m 직진
# 서울가락본동우체국 건물 1층에 위치
#
# 가락시장역3번출구
# 200M직진후 소방공제회관과 뉴프라임약국 골목길로 우회전
# 500M 직진후 서울가락본동우체국 건물 1층에 위치
#
# [버스정류장]
# 경찰병원.KT가락지사(24377)
# 3322,3416버스
# 버스 하차후 KT가락지점으로 70M이동
# 좌회전후 150M 직진
# 서울가락본동우체국 건물 1층에 위치
# 내용 더보기
#  store_id: 1537047629
#  address: 서울 송파구 송파대로30길 36 1층 밀각
#  blog_review: 블로그 리뷰 1,781
#  phone_num: 0507-1465-9309
#  business_hours: 매일
# 11:00 - 22:00
# 15:00 - 16:30 브레이크타임
# 21:30 라스트오더
#
#  info: 謐覺 (밀각)
#
# 고요할 밀, 깨달을 각
#
# 영업시간
#
# 매일 11:30 ~ 22:00 이며
# 라스트오더는 21:30
# 브레이크타임 15:00 ~ 16:30입니다
#
# 업장 전화번호
# 0507-1465-9309
#
# 밀각 맛집을 찾아주셔서 감사합니다.
#
# 밀각은 가족,연인,직장동료들과 데이트,회식,외식을 하며 추억을 쌓을 수 있는 공간입니다.
#
# 음식으로는 족발, 평양냉면, 양무침, 양곰탕, 막국수, 칼국수, 매운칼국수를 판매하고 있습니다.
#
# HACCP 인증을 받은 국내산 최고급 생족 신선한 과일, 각종 채소, 황기, 마늘, 생강까지 비법소스로 최고의 재료로 만들어낸 윤기 가득 족발 고기보쌈
#
# 매일 손 수 반죽하는 메밀 면
#
# 신선한 재료로 직접 만드는 깔끔한 밑 반찬
#
# 송파구에서 최고의 품질의 식사를 제공합니다
#
# 점심에는 시원한 곰탕과 얼큰한 칼국수로 식사가능하며
#
# 저녁은 넓은 공간과 단체석이 준비되어 모임과 회식에 아주 적합한 장소이며, 주말 가족과 함께 하는 외식 자리로도 가락족발은 최적의 선택입니다.
#
# 매월 다양한 서비스 이벤트를 제공중이며 재미와 추억을 선사해 드리겠습니다.
#
# 아늑한 인테리어와 깔끔한 실내 공간에서 사랑하는 사람과 함께하는 맛있는 족발 식사는 둘 사이를 더욱 가깝게 만들어 줄 것입니다.
#
# 서울 가락시장역에는 다양한 볼거리등이 많습니다.
#
# 식사를 마친 후, 근처 카페나 맛집 , 가락시장 , 올림픽공원에 가시며 여유로운 시간을 보내는 것도 좋습니다
#
# 철저한 위생 관리와 신선한 재료 사용으로 안심하고 드실 수 있도록 항상 신경 쓰고 있으며, 친절한 직원들이 고객님을 맞이하여 최고의 식사 경험을 제공할 것을 약속드립니다.
#
# 플레이스에서 서비스 음료 쿠폰진행중이니 꼭 확인하고 드세요
#
# 우체국 민영주차장 사용가능합니다
# (아미노 가락본동우체국 주차장) 30분 3,000
#
# [자가용 이용시] 밀각 가락본점 서울 송파구 송파대로30길36 검색하시면 됩니다.
#
# [대중교통 이용시] 지하철 경찰병원역 1번 출구 경찰병원와 가락본동주 민센터 사이골목길로 직진 4분
# KT가락지점 건물 좌회전후 200m 직진
# 서울가락본동우체국 건물 1층에 위치 가락시장역3번출구 200M직진후
# 소방공제회관과 뉴프라임약국 골목길로 우회전 500M 직진후
# 서울가락본동우체국 건물 1층에 위치
#
# [버스정류장 이용시]
# 경찰병원.KT가락지사(24377)
# 3322,3416버스 버스 하차후 KT가락지점으로 70M이동
# 좌회전후 150M 직진 서울가락본동우체국 건물 1층에 위치
#
# [지하철 이용시]
# 경철병원역에서 도보로 5분
# 가락시장역에서 도보로 10분
#
# 가락시장역칼국수,경찰병원역곰탕
# 송파구가락동맛집,송파데이트맛집
# 송파족발집
#
# [주변 놀거리 및 명소]
#
# 키즈마린파크박물관 (도보 3분거리)
# 가락몰시장 (도보 5분거리)
# 비석거리공원 (도보 3분거리)
# 가락근린공원 (도보 5분거리)
# 건너말공원 (도보 5분거리)
# 송이공원 (도보 5분거리)
# 문정동로데오거리 (도보 10분거리)
# 송리단길(차량 5분거리)
# 펼쳐보기
#  convenience_facilities_and_services: 단체 이용 가능
# 포장
# 배달
# 예약
# 무선 인터넷
# 남/녀 화장실 구분
#
#  Parking: 주차가능
#  sns: https://www.instagram.com/mealgak/
#
#  review_like_this_part_output: "음식이 맛있어요"이 키워드를 선택한 인원483
# "특별한 메뉴가 있어요"이 키워드를 선택한 인원173
# "매장이 청결해요"이 키워드를 선택한 인원164
# "양이 많아요"이 키워드를 선택한 인원160
# "친절해요"이 키워드를 선택한 인원158
# "재료가 신선해요"이 키워드를 선택한 인원123
# "매장이 넓어요"이 키워드를 선택한 인원95
# "고기 질이 좋아요"이 키워드를 선택한 인원69
# "단체모임 하기 좋아요"이 키워드를 선택한 인원69
# "가성비가 좋아요"이 키워드를 선택한 인원57
# "주차하기 편해요"이 키워드를 선택한 인원45
# "인테리어가 멋져요"이 키워드를 선택한 인원31
# "혼밥하기 좋아요"이 키워드를 선택한 인원28
# "잡내가 적어요"이 키워드를 선택한 인원12
# "특별한 날 가기 좋아요"이 키워드를 선택한 인원11
# "건강한 맛이에요"이 키워드를 선택한 인원9
# "반찬이 잘 나와요"이 키워드를 선택한 인원7
# "메뉴 구성이 알차요"이 키워드를 선택한 인원5
# "음식이 빨리 나와요"이 키워드를 선택한 인원4
# "뷰가 좋아요"이 키워드를 선택한 인원3
# "차분한 분위기에요"이 키워드를 선택한 인원2
# "컨셉이 독특해요"이 키워드를 선택한 인원2
# "비싼 만큼 가치있어요"이 키워드를 선택한 인원2
# "화장실이 깨끗해요"이 키워드를 선택한 인원2
# "직접 잘 구워줘요"이 키워드를 선택한 인원1
# "환기가 잘 돼요"이 키워드를 선택한 인원1
#
#  menu: 당일 삶은 촉촉한 족발대표100% HACCP 인증된 국내산 생족 앞다리로, 매일 직접 삶는 신선하고 쫄깃한 족발48,000원
# 비법육수 평양냉면대표큼직한 편육과 매일 손수 반죽한 쫄깃한 메밀 면, 그리고 신선한 육향을 느낄 수 있는 평양냉면!14,000원
# 함께먹는 반족발100% HACCP 인증된 국내산 생족 앞다리로, 매일 직접 삶는 신선하고 쫄깃한 족발29,000원
# 이색적인 양무침소양을 부추와 함께 무쳐 담백하고 깔끔한 무침요리31,000원
# 모밀막국수사과, 배 천연의 재료로 만든 양념, 매일 손수 반죽하는 메밀 면, 푸짐한 양지 고기가 있는 메밀 막국수!13,000원
# 푸짐한 양곰탕소의 양 + 한우 고기 200g
# 양파장을 곁들여 드시면 감칠맛이 더해 집니다.15,000원
# 속이 시원한 곰탕한우 고기 150g
# 양파장을 곁들여 드시면 감칠맛이 더해 집니다.15,000원
# 깔끔시원한 칼국수시원하고 고기고명이 풍부한 칼국수, 푸짐한 양에 한번 더 맛있는 칼국수!12,000원
# 얼큰한 매운칼국수속까지 풀어지는 얼큰한 매운 칼국수, 양과 고기에 한번 더 맛보는 칼국수!12,000원
# </content>
# <document><content>store_name: 수지상회 강남1호점
#  category: 요리주점
#  new_open:
#  rating: 정보없음
#  visited_review: 방문자 리뷰 1,750
#  directions_text: 수지상회는 2층에 있습니다.
# 건물1층은 보승회관 입니다. 보승회관을 정면으로 바라보시고 우측 통로를 통해 건물 내부로 들어오셔서 계단 혹은 엘레베이터 이용하셔서 2층으로 올라오시면 하트 조명이 보이십니다. 문을 열고 들어오시면 건물 내부지만 충분한 개방감을 느끼실 수 있는 수지상회가 보이십니다.
#
# 2호선 강남역에서 내리셔서 12번 출구로 나오신 다음
# 왼쪽으로 돌아 내려오셔서 오른쪽 첫 골목으로 들오셔서
# 100m가량 들어오시면(세븐일레븐,빌리엔젤을 지나)
# 왼편 2층에 위치하고 있습니다.
#
# 강남역과 1분거리에 있는 오기도 편하고 집가기도 편한 강남억술집 수지상회에서 여러분을 기다리겠습니다
#
# 주차는 죄송스럽지만 따로 공간이 마련되어 있지 않습니다.
# 근처 유료 주차장 이용해주시면 감사하겠습니다!!
# 내용 더보기
#  store_id: 1810165759
#  address: 서울 강남구 테헤란로1길 17 2층
#  blog_review: 블로그 리뷰 2,361
#  phone_num: 0507-1366-6974
#  business_hours: 매일
# 16:00 - 05:00
#
#  info: 안녕하세요.
#
# @@@@인스타 맛집@@@@
# @@@SNS핫플@@@
# @@@분위기 맛집@@@
# @@@안주 맛집@@@
# @@@데이트 베스트 코스@@@
# @@@하이볼 맛집@@@
# @@@강남역술집@@@
# @@@강남술집@@@
#
# 매장 방문시 신분증 필수 지참인 부분 양해부탁드립니다.
#
# 수 많은 인플루언서들의 선택을 받은 강남1등 술집 수지상회 강남 1호점 인사드리겠습니다!!!
#
# 날이 더워지고, 추워지고, 비가오고, 눈이오고 어떤 상황에서도
#
# 굴하지 않고 문을 여는 강남역 술집!
#
# 지하철역에서 3분거리에 위치해서 막차 놓칠리 없고!
#
# 강남에서 제일 화장실 깨끗하고!!
#
# 모두가 만족하는 서비스를 제공해드리는 이 곳!
#
# 수지상회 강남점입니다.
#
# 봄엔 꽃향기를 맡으며!!
#
# 여름엔 시원하게!!
#
# 가을엔 선선한 바람을 맞으며!!
#
# 겨울엔 따뜻하게!!
#
# 연인과 데이트를 하기에도 좋고, 가족끼리 오랜만에 외식하기에도 좋고, 손님을 모시고 가도 좋고, 친구랑 놀러가기도 좋은 매장입니다.
#
# 항상 뻔한 음식과 뻔한 맛 뻔한 일상에 지치신 분들을 위해서 저희가 그동안 없었던 특별한 맛, 특별한 음식, 일상에서의 색다로움을 즐기실 수 있도록 준비했습니다.
#
# 항상 고객 여러분들을 생각하고 한분 한분 최선을 다해서 니즈를 맞춰드리는 저희가 강남에 왔습니다!!
#
# 취향저격 다양한 종류의 메뉴들!!
#
# 갈빗대 통째 드리는 **수지 우대 갈비**
# - 소의 가장 큰 갈빗대로 요즘 유행하는 그 소고기 맞습니다.
# 수비드로 조리된 족발 가득 담긴 ***학센 플레터***
# - 독일식 족발인 겉바속촉 족발을 한국에서 즐기실수있습니다.
# 매일 공수해온 채소로 준비한 **수지 샤브 전골**
# - 신선한 야채와 신선한 고기로 밀가루 하나 없는 건강한 전골입니다.
# 그 어떤 술집에서도 맛 볼수 없는 돼지 특수 부위 **항정수육**
# - 항정살 이젠 다들 아시죠? 그걸 수육으로 만들어서 촉촉하지만 겉은 바삭하게 만들어봤습니다.
# 술 먹으면서 몸까지 챙기는 양지와 스지가 들어간 **수지 스지탕**
# - 소의 힘줄 스지로 만드는 보양탕인데, 맛도 있어 해장도 가능
# 여기가 마라탕 집인지 술집인지 이젠 나도 헷갈리는 **마라전골**
# - 마라떡볶이, 마라탕 등 대한민국을 집어삼킨 마라
# 중국집에서 짬뽕 안시켜먹는 수지 직원들 최애 안주 ***차돌듬뿍짬뽕탕***
# - 다들 아시죠? 그 짬뽕 그대로 맞습니다 원팩? 안써요
# 시원시원한 *냉채수육*과 *냉채차돌*
# - 시원한 안주 생각나시잖아요 술먹다 보면 그때 드시죠
# 양 많고 저렴하게 준비된 갖가지 - 사이드 메뉴 -
# - 순살치킨, 간장치킨, 생과일화채, 멜론, 파인애플, 팥빙수, 감자튀김 등등 30여가지 사이드
# 식사를 책임질 수 있는 다양한 -식사 메뉴-
# - 참치주먹밥, 치킨마요덮밥, 김치볶음밥 등 10여가지 식사메뉴
#
# 안주 드시면서 드셔야 몸 건강히 잘 드실 수 있는거 아시죠??
#
# 수지 상회는 퀄리티, 서비스, 청결 3대 원칙을 준수하고 있으며 언제나 고객의 니즈를 파악하기 위해 노력하며 발전하고 있습니다.
#
# 강남역 최다 종류 주류 보유중입니다!!
#
# 수지상회의 특별한 시그니처 하이볼과 남여노소 불문하고
#
# 누구한테나 사랑받는 하이볼들이 수십종류 보유중입니다.
#
# 요즘 워라벨이 중요한 이시대에 가볍고 비싸지않게 맛있는
#
# 하이볼들로 지인들과 친구들과 직장동료들과 가족들과
#
# 행복하고, 즐거운 시간을 보내실 수 있도록 강남역술집 수지상회에서 준비하겠습니다.
#
# 고객님들은 몸만 오세요 나머진 저희가 할게요.
#
# @@ 예약시 참고해주세요.
# - 주말(금, 토) 예약시 18시 이후는 일주일전에 예약이 조기마감 될 수 있으니 양해부탁드립니다 :)
# - 예약 완료 후 10분 경과시 no-show 처리로 예약이 취소처리 될 수 있습니다. 변동사항 생기시면 매장으로 전화주세요 ^^
# - 인원 수 맞춰서 예약 주시고 인원수 제한이 걸리시면 따로 유선 연락주시기 바라겠습니다
#
# 오늘 하루도 고생 많으셨습니다. 항상 행복하시고 즐겁게 마시고 드실수 있도록 항상 노력하고 발전하는 수지상회가 되겠습니다. 감사합니다!
# 펼쳐보기
#  convenience_facilities_and_services: 콜키지 가능
# 유료
# 생일 혜택
# 단체 이용 가능
# 남/녀 화장실 구분
# 예약
# 대기공간
# 출입구 휠체어 이용가능
# 좌석 휠체어 이용가능
#
#  Parking: 주차가능
# 유료
# 최초 5분 300원
# 추가 요금 5분당 300원, 최대 100,000원
#  sns: https://blog.naver.com/sswp1020
# https://www.instagram.com/suji__gn
#
#  review_like_this_part_output: "음식이 맛있어요"이 키워드를 선택한 인원1229
# "친절해요"이 키워드를 선택한 인원698
# "인테리어가 멋져요"이 키워드를 선택한 인원687
# "술이 다양해요"이 키워드를 선택한 인원630
# "음악이 좋아요"이 키워드를 선택한 인원473
# "대화하기 좋아요"이 키워드를 선택한 인원448
# "기본 안주가 좋아요"이 키워드를 선택한 인원447
# "매장이 청결해요"이 키워드를 선택한 인원446
# "특별한 메뉴가 있어요"이 키워드를 선택한 인원334
# "단체모임 하기 좋아요"이 키워드를 선택한 인원333
# "가성비가 좋아요"이 키워드를 선택한 인원312
# "오래 머무르기 좋아요"이 키워드를 선택한 인원249
# "화장실이 깨끗해요"이 키워드를 선택한 인원189
# "매장이 넓어요"이 키워드를 선택한 인원55
# "메뉴 구성이 알차요"이 키워드를 선택한 인원44
# "혼술하기 좋아요"이 키워드를 선택한 인원26
# "양이 많아요"이 키워드를 선택한 인원15
# "주차하기 편해요"이 키워드를 선택한 인원12
# "사진이 잘 나와요"이 키워드를 선택한 인원11
# "음식이 빨리 나와요"이 키워드를 선택한 인원6
# "건강한 맛이에요"이 키워드를 선택한 인원6
# "좌석이 편해요"이 키워드를 선택한 인원5
# "아늑해요"이 키워드를 선택한 인원5
# "뷰가 좋아요"이 키워드를 선택한 인원5
# "컨셉이 독특해요"이 키워드를 선택한 인원4
# "비싼 만큼 가치있어요"이 키워드를 선택한 인원4
# "음료가 맛있어요"이 키워드를 선택한 인원3
# "재료가 신선해요"이 키워드를 선택한 인원3
# "야외공간이 멋져요"이 키워드를 선택한 인원2
# "파티하기 좋아요"이 키워드를 선택한 인원2
# "라이브공연이 훌륭해요"이 키워드를 선택한 인원1
# "특별한 날 가기 좋아요"이 키워드를 선택한 인원1
#
#  menu: 수지닭볶음탕대표26,900원
# 수지학센플레터대표수비드 조리된 돼지 앞발!!!!
# 독일식 슈바인 학센을 만나보세요!!!31,900원
# 수지 스지탕대표소 힘줄인 스지와 양지수육이 듬뿍 들어간 건강에도 좋고 맛도 좋은 먹은사람은 한번 더 먹는30,900원
# 수지양지수육한판대표사골국물에 촉촉히 적셔가면서 먹는 양지수육을 술집에서????!!!29,900원
# 수지 빨간 어묵탕대표해물 들어간 얼큰~~~한 빨간 어묵탕!!24,900원
# 내가제일잘나베대표롱치즈돈까스가 통으로 올라간 수지상회 돈까스 김치나베!!23,900원
# 수코바 숯불 치킨대표수코바 숯불 치킨!! 국내산 닭을 이용해 구운 숯불 치킨!!!!!!!!!23,900원
# 다양한 하이볼여기가 강남역 하이볼 성지!! 엄청나게 다양한 하이볼 라인업!변동
# 수지샤브마라전골마라가 세상을 지배했다. 수지상회 마저 점령한 마라전골 완자까지 올라가요 존맛탱..31,900원
# 전,전,전감자전, 부추전, 김치전변동
# 수지샤브전골밀푀유 베이스에 만두까지 퐁당 맑은 육수로 소주 꼴깍!!28,900원
# 마라떡볶이마라가 세상을 지배한다 마라떡볶이 출시!!!22,900원
# 차돌듬뿍짬뽕탕저희는 중국집에서 짬뽕 안시켜먹습니다. 이게 더 맛있거든요.22,900원
# 코찡냉채차돌불향을 입힌 우삼겹을 시원하게 냉채소스와 곁들여 먹는 간단하게 즐기기 좋은 안주21,900원
# 차돌떡볶이오랜시간 연구끝에 나온 특제소스로 만드는 매콜달콤한 떡볶이 위에 우삼겹까지 듬뿍20,900원
# </content>
# <document><content>store_name: 수지상회 강남1호점
#  category: 요리주점
#  new_open:
#  rating: 정보없음
#  visited_review: 방문자 리뷰 1,750
#  directions_text: 수지상회는 2층에 있습니다.
# 건물1층은 보승회관 입니다. 보승회관을 정면으로 바라보시고 우측 통로를 통해 건물 내부로 들어오셔서 계단 혹은 엘레베이터 이용하셔서 2층으로 올라오시면 하트 조명이 보이십니다. 문을 열고 들어오시면 건물 내부지만 충분한 개방감을 느끼실 수 있는 수지상회가 보이십니다.
#
# 2호선 강남역에서 내리셔서 12번 출구로 나오신 다음
# 왼쪽으로 돌아 내려오셔서 오른쪽 첫 골목으로 들오셔서
# 100m가량 들어오시면(세븐일레븐,빌리엔젤을 지나)
# 왼편 2층에 위치하고 있습니다.
#
# 강남역과 1분거리에 있는 오기도 편하고 집가기도 편한 강남억술집 수지상회에서 여러분을 기다리겠습니다
#
# 주차는 죄송스럽지만 따로 공간이 마련되어 있지 않습니다.
# 근처 유료 주차장 이용해주시면 감사하겠습니다!!
# 내용 더보기
#  store_id: 1810165759
#  address: 서울 강남구 테헤란로1길 17 2층
#  blog_review: 블로그 리뷰 2,362
#  phone_num: 0507-1366-6974
#  business_hours: 매일
# 16:00 - 05:00
#
#  info: 안녕하세요.
#
# @@@@인스타 맛집@@@@
# @@@SNS핫플@@@
# @@@분위기 맛집@@@
# @@@안주 맛집@@@
# @@@데이트 베스트 코스@@@
# @@@하이볼 맛집@@@
# @@@강남역술집@@@
# @@@강남술집@@@
#
# 매장 방문시 신분증 필수 지참인 부분 양해부탁드립니다.
#
# 수 많은 인플루언서들의 선택을 받은 강남1등 술집 수지상회 강남 1호점 인사드리겠습니다!!!
#
# 날이 더워지고, 추워지고, 비가오고, 눈이오고 어떤 상황에서도
#
# 굴하지 않고 문을 여는 강남역 술집!
#
# 지하철역에서 3분거리에 위치해서 막차 놓칠리 없고!
#
# 강남에서 제일 화장실 깨끗하고!!
#
# 모두가 만족하는 서비스를 제공해드리는 이 곳!
#
# 수지상회 강남점입니다.
#
# 봄엔 꽃향기를 맡으며!!
#
# 여름엔 시원하게!!
#
# 가을엔 선선한 바람을 맞으며!!
#
# 겨울엔 따뜻하게!!
#
# 연인과 데이트를 하기에도 좋고, 가족끼리 오랜만에 외식하기에도 좋고, 손님을 모시고 가도 좋고, 친구랑 놀러가기도 좋은 매장입니다.
#
# 항상 뻔한 음식과 뻔한 맛 뻔한 일상에 지치신 분들을 위해서 저희가 그동안 없었던 특별한 맛, 특별한 음식, 일상에서의 색다로움을 즐기실 수 있도록 준비했습니다.
#
# 항상 고객 여러분들을 생각하고 한분 한분 최선을 다해서 니즈를 맞춰드리는 저희가 강남에 왔습니다!!
#
# 취향저격 다양한 종류의 메뉴들!!
#
# 갈빗대 통째 드리는 **수지 우대 갈비**
# - 소의 가장 큰 갈빗대로 요즘 유행하는 그 소고기 맞습니다.
# 수비드로 조리된 족발 가득 담긴 ***학센 플레터***
# - 독일식 족발인 겉바속촉 족발을 한국에서 즐기실수있습니다.
# 매일 공수해온 채소로 준비한 **수지 샤브 전골**
# - 신선한 야채와 신선한 고기로 밀가루 하나 없는 건강한 전골입니다.
# 그 어떤 술집에서도 맛 볼수 없는 돼지 특수 부위 **항정수육**
# - 항정살 이젠 다들 아시죠? 그걸 수육으로 만들어서 촉촉하지만 겉은 바삭하게 만들어봤습니다.
# 술 먹으면서 몸까지 챙기는 양지와 스지가 들어간 **수지 스지탕**
# - 소의 힘줄 스지로 만드는 보양탕인데, 맛도 있어 해장도 가능
# 여기가 마라탕 집인지 술집인지 이젠 나도 헷갈리는 **마라전골**
# - 마라떡볶이, 마라탕 등 대한민국을 집어삼킨 마라
# 중국집에서 짬뽕 안시켜먹는 수지 직원들 최애 안주 ***차돌듬뿍짬뽕탕***
# - 다들 아시죠? 그 짬뽕 그대로 맞습니다 원팩? 안써요
# 시원시원한 *냉채수육*과 *냉채차돌*
# - 시원한 안주 생각나시잖아요 술먹다 보면 그때 드시죠
# 양 많고 저렴하게 준비된 갖가지 - 사이드 메뉴 -
# - 순살치킨, 간장치킨, 생과일화채, 멜론, 파인애플, 팥빙수, 감자튀김 등등 30여가지 사이드
# 식사를 책임질 수 있는 다양한 -식사 메뉴-
# - 참치주먹밥, 치킨마요덮밥, 김치볶음밥 등 10여가지 식사메뉴
#
# 안주 드시면서 드셔야 몸 건강히 잘 드실 수 있는거 아시죠??
#
# 수지 상회는 퀄리티, 서비스, 청결 3대 원칙을 준수하고 있으며 언제나 고객의 니즈를 파악하기 위해 노력하며 발전하고 있습니다.
#
# 강남역 최다 종류 주류 보유중입니다!!
#
# 수지상회의 특별한 시그니처 하이볼과 남여노소 불문하고
#
# 누구한테나 사랑받는 하이볼들이 수십종류 보유중입니다.
#
# 요즘 워라벨이 중요한 이시대에 가볍고 비싸지않게 맛있는
#
# 하이볼들로 지인들과 친구들과 직장동료들과 가족들과
#
# 행복하고, 즐거운 시간을 보내실 수 있도록 강남역술집 수지상회에서 준비하겠습니다.
#
# 고객님들은 몸만 오세요 나머진 저희가 할게요.
#
# @@ 예약시 참고해주세요.
# - 주말(금, 토) 예약시 18시 이후는 일주일전에 예약이 조기마감 될 수 있으니 양해부탁드립니다 :)
# - 예약 완료 후 10분 경과시 no-show 처리로 예약이 취소처리 될 수 있습니다. 변동사항 생기시면 매장으로 전화주세요 ^^
# - 인원 수 맞춰서 예약 주시고 인원수 제한이 걸리시면 따로 유선 연락주시기 바라겠습니다
#
# 오늘 하루도 고생 많으셨습니다. 항상 행복하시고 즐겁게 마시고 드실수 있도록 항상 노력하고 발전하는 수지상회가 되겠습니다. 감사합니다!
# 펼쳐보기
#  convenience_facilities_and_services: 콜키지 가능
# 유료
# 생일 혜택
# 단체 이용 가능
# 남/녀 화장실 구분
# 예약
# 대기공간
# 출입구 휠체어 이용가능
# 좌석 휠체어 이용가능
#
#  Parking: 주차가능
# 유료
# 최초 5분 300원
# 추가 요금 5분당 300원, 최대 100,000원
#  sns: https://blog.naver.com/sswp1020
# https://www.instagram.com/suji__gn
#
#  review_like_this_part_output: "음식이 맛있어요"이 키워드를 선택한 인원1228
# "친절해요"이 키워드를 선택한 인원697
# "인테리어가 멋져요"이 키워드를 선택한 인원687
# "술이 다양해요"이 키워드를 선택한 인원630
# "음악이 좋아요"이 키워드를 선택한 인원472
# "대화하기 좋아요"이 키워드를 선택한 인원448
# "기본 안주가 좋아요"이 키워드를 선택한 인원446
# "매장이 청결해요"이 키워드를 선택한 인원446
# "특별한 메뉴가 있어요"이 키워드를 선택한 인원334
# "단체모임 하기 좋아요"이 키워드를 선택한 인원333
# "가성비가 좋아요"이 키워드를 선택한 인원312
# "오래 머무르기 좋아요"이 키워드를 선택한 인원249
# "화장실이 깨끗해요"이 키워드를 선택한 인원188
# "매장이 넓어요"이 키워드를 선택한 인원55
# "메뉴 구성이 알차요"이 키워드를 선택한 인원44
# "혼술하기 좋아요"이 키워드를 선택한 인원26
# "양이 많아요"이 키워드를 선택한 인원15
# "주차하기 편해요"이 키워드를 선택한 인원12
# "사진이 잘 나와요"이 키워드를 선택한 인원11
# "음식이 빨리 나와요"이 키워드를 선택한 인원6
# "건강한 맛이에요"이 키워드를 선택한 인원6
# "좌석이 편해요"이 키워드를 선택한 인원5
# "아늑해요"이 키워드를 선택한 인원5
# "뷰가 좋아요"이 키워드를 선택한 인원5
# "컨셉이 독특해요"이 키워드를 선택한 인원4
# "비싼 만큼 가치있어요"이 키워드를 선택한 인원4
# "음료가 맛있어요"이 키워드를 선택한 인원3
# "재료가 신선해요"이 키워드를 선택한 인원3
# "야외공간이 멋져요"이 키워드를 선택한 인원2
# "파티하기 좋아요"이 키워드를 선택한 인원2
# "라이브공연이 훌륭해요"이 키워드를 선택한 인원1
# "특별한 날 가기 좋아요"이 키워드를 선택한 인원1
#
#  menu: 수지닭볶음탕대표26,900원
# 수지학센플레터대표수비드 조리된 돼지 앞발!!!!
# 독일식 슈바인 학센을 만나보세요!!!31,900원
# 수지 스지탕대표소 힘줄인 스지와 양지수육이 듬뿍 들어간 건강에도 좋고 맛도 좋은 먹은사람은 한번 더 먹는30,900원
# 수지양지수육한판대표사골국물에 촉촉히 적셔가면서 먹는 양지수육을 술집에서????!!!29,900원
# 수지 빨간 어묵탕대표해물 들어간 얼큰~~~한 빨간 어묵탕!!24,900원
# 내가제일잘나베대표롱치즈돈까스가 통으로 올라간 수지상회 돈까스 김치나베!!23,900원
# 수코바 숯불 치킨대표수코바 숯불 치킨!! 국내산 닭을 이용해 구운 숯불 치킨!!!!!!!!!23,900원
# 다양한 하이볼여기가 강남역 하이볼 성지!! 엄청나게 다양한 하이볼 라인업!변동
# 수지샤브마라전골마라가 세상을 지배했다. 수지상회 마저 점령한 마라전골 완자까지 올라가요 존맛탱..31,900원
# 전,전,전감자전, 부추전, 김치전변동
# 수지샤브전골밀푀유 베이스에 만두까지 퐁당 맑은 육수로 소주 꼴깍!!28,900원
# 마라떡볶이마라가 세상을 지배한다 마라떡볶이 출시!!!22,900원
# 차돌듬뿍짬뽕탕저희는 중국집에서 짬뽕 안시켜먹습니다. 이게 더 맛있거든요.22,900원
# 코찡냉채차돌불향을 입힌 우삼겹을 시원하게 냉채소스와 곁들여 먹는 간단하게 즐기기 좋은 안주21,900원
# 차돌떡볶이오랜시간 연구끝에 나온 특제소스로 만드는 매콜달콤한 떡볶이 위에 우삼겹까지 듬뿍20,900원
# </content>
# <document><content>store_name: 미탐행
#  category: 포장마차
#  new_open:
#  rating: 정보없음
#  visited_review: 방문자 리뷰 162
#  directions_text: 삼호물산 먹자골목 중간에 위치해 있습니다! (*플레이스 지도 참고하시면 편하게 위치파악이 가능합니다). 가까운 지하철역은 양재시민의 숲 역과 양재역이며 버스이용시 동원산업역에서 10분거리에 있습니다. 귀한 발걸음 감사합니다. 후회없는 선택 만들어 드리겠습니다.
#
# (*주차는 불가한점 양해부탁드립니다ㅜㅜ)
# 내용 더보기
#  store_id: 1757724153
#  address: 서울 서초구 언남길 75 1층
#  blog_review: 블로그 리뷰 16
#  phone_num: 0507-1310-6944
#  business_hours: 월
# 16:30 - 03:00
# 02:00 라스트오더
# 화
# 16:30 - 03:00
# 02:00 라스트오더
# 수
# 16:30 - 03:00
# 02:00 라스트오더
# 목
# 16:30 - 03:00
# 02:00 라스트오더
# 금
# 16:30 - 03:00
# 02:00 라스트오더
# 토
# 16:30 - 03:00
# 02:00 라스트오더
# 일
# 정기휴무 (매주 일요일)
#
#  info: 안녕하세요 진심을 다하는 해산물포차 양재 횟집 미탐행입니다.
#
#  저희의 모토는 현실에 안주하지 않고,
# 계속해서 더 좋은 맛을 찾으러 다니고, 연구한다는 마음입니다.
# 그것이 찾아주시는 고객님들께 보답하는 저희의 의무이자 책임이라고 생각합니다.
#
#  미탐행의 프리미엄 숙성회는 광어회와 도미회 기준 최소 15시간 이상의 숙성시간을 거치며
# 그러한 숙성시간을 위하여 매일 새벽1시에(주말포함) 작업을 진행하여 확실한 숙성의 맛을 보장드립니다 .
#
#  10년이상 다른가게들에서 일하면서 연구한 오직 저희만의 특별한 숙성법으로
# 내어드려 차별되는 감칠맛과 식감을 느끼고, 맛보실수 있으며
# 미탐행은 숙성시간과 숙성방법을 반드시 준수합니다.
#
#  최대 48시간까지의 숙성회를 판매하고 있고, 그 이상의 숙성시간이 지난 횟감은 절대 손님들께 내어드리지 않습니다.
#
#  (*활어회의 장점은 식감이 진하고, 숙성회의 장점은 점점 감칠맛이 깊어진다는점 입니다. 그 두가지맛의 조화가 가장 적합한 시간대와
# 숙성법을 실현합니다.)
#
#  싱싱한 여러 해산물들 또한 언제나 준비되어있으며, 공산품들 역시 즉시손질후
# 급냉 또는 냉장보관하여 조금의 품질저하도 생기지 않도록 최선을 다하고 있습니다.
#
#  일품 국물요리들 또한 육수를 좋은재료로 매일 프레시하게 우려내어 최상의 퀄리티를 유지하고 있으며,
#  무조건 당일소진, 당일폐기를 원칙으로 하고있습니다.
#
#  제가 게으르면 손님들이 피해를 본다는것을 제일 잘 알고있습니다.
# 음식과 타협하지 않음을 약속드리며, 안심하고 드실수 있도록
# 부모님께 내어드린다는 마음으로 최선을 다하겠습니다. 감사합니다.
#
# *포장주문시 전메뉴 10프로 할인해드립니다 !
#
# *1.예약방문시 해물라면or소주한병 中 택1 서비스 드립니다 !
#
#  2.영수증 리뷰 남겨주시면 해물라면or소주한병 中 택1 서비스 드립
#  니다 ! (첫 주문 결제후 직원에게 영수증 요청해주시면 리뷰 확인
#  후 내어드립니다 !)
#
#  -중복은 불가합니다 !
# 펼쳐보기
#  convenience_facilities_and_services: 단체 이용 가능
# 포장
# 무선 인터넷
# 남/녀 화장실 구분
# 예약
#
#  Parking: 주차 불가
#  sns: nan
#  review_like_this_part_output: "음식이 맛있어요"이 키워드를 선택한 인원161
# "친절해요"이 키워드를 선택한 인원72
# "특별한 메뉴가 있어요"이 키워드를 선택한 인원68
# "기본 안주가 좋아요"이 키워드를 선택한 인원44
# "대화하기 좋아요"이 키워드를 선택한 인원42
# "매장이 청결해요"이 키워드를 선택한 인원34
# "재료가 신선해요"이 키워드를 선택한 인원33
# "메뉴 구성이 알차요"이 키워드를 선택한 인원31
# "가성비가 좋아요"이 키워드를 선택한 인원30
# "음악이 좋아요"이 키워드를 선택한 인원27
# "인테리어가 멋져요"이 키워드를 선택한 인원21
# "술이 다양해요"이 키워드를 선택한 인원16
# "단체모임 하기 좋아요"이 키워드를 선택한 인원14
# "비싼 만큼 가치있어요"이 키워드를 선택한 인원11
# "아늑해요"이 키워드를 선택한 인원9
# "건강한 맛이에요"이 키워드를 선택한 인원9
# "양이 많아요"이 키워드를 선택한 인원7
# "음식이 빨리 나와요"이 키워드를 선택한 인원5
# "차분한 분위기에요"이 키워드를 선택한 인원3
# "특별한 날 가기 좋아요"이 키워드를 선택한 인원3
# "혼술하기 좋아요"이 키워드를 선택한 인원2
# "오래 머무르기 좋아요"이 키워드를 선택한 인원2
# "화장실이 깨끗해요"이 키워드를 선택한 인원2
# "주차하기 편해요"이 키워드를 선택한 인원1
# "사진이 잘 나와요"이 키워드를 선택한 인원1
#
#  menu: *최소 15시간 숙성 약속!*대표힘들다고 타협하지 않겠습니다.무조건 새벽작업을 진행하여 최고의 숙성시간을 약속드립니다.무료
# 미탐)숙성회모듬대표최소 15시간 이상 숙성된 광어,참도미회와 제철어종 2종으로 구성된 프리미엄 숙성회 !69,000원
# 미탐)대삼치회대표미식가들 겨냥 고소 끝판왕 등장! 껍질을 살짝 토치로 구워 기름기를 한층 올려주었어요~48,000원
# 미탐)해산물모듬대표제철 해산물들로 짜임~새 있게 구성된 야무진 해산물의 모음 !48,000원
# 미탐)우니삼합(7pc)대표시소+가리비관자+우니+단새우에 와사비 올리고 감태에 싸서 간장 살짝만 찍어 미식의 세계로~28,000원
# 미탐)시메사바(고등어초절임)대표고등어는 어떻게 시메하는지에 따라 맛이 천차만별입니다. 주인장 자신있어요☆25,000원
# 고등어봉초밥대표맛있게 숙성된 시메사바를 초밥으로 즐기실수 있도록 구성된 고등어봉초밥!25,000원
# 도미 매운탕대표참돔으로 끓여내는 미탐행 시그니처! 칼칼 시원함으로 중무장한 얼큰한 매운탕32,000원
# 미탐)오징어튀김대표노릇노릇 ~ 바삭바삭 하게 잘 튀겨진 비주얼,맛,양 삼박자 두루 갖춘 완벽한 튀김요리!23,000원
# 미탐)숙성회모듬 (小)양이 부담스러운 분들을 위한 작은사이즈 숙성모듬회(숙성5종 구성은 동일합니다^-^)42,000원
# (제철) 대방어회미탐행만의 숙성법으로 더 고소하고 기름진 대방어회입니다 ! 진짜 맛있어요 ㅎㅎ52,000원
# (제철)석화겨울철만 느낄수 있는 물오른 싱싱한 석화 한상 ! (찜으로 변경가능)23,000원
# 전복꼬들꼬들~ 탱탱한 식감이 일품인 전복! 칼집을 많이 내어 더 재밌는 맛을 느끼실수 있어요!35,000원
# 산낙지탕탕이신선한 산낙지를 탕!탕! 썰어서 질기지 않은 좋은식감만을 극대화 시켜요 ㅎㅎ30,000원
# 멍게입안에 넣는 순간 바다가 화~하게 펼쳐지는 해산물 대표주자 멍게입니다25,000원
# </content>
# ==================================================
#
# ==================================================
# 🔄 Node: retrieve_document_naver_yongsan 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# context_naver_yongsan:
# <document><content>store_name: 성수미술관 용산점
#  category: 테마카페
#  new_open:
#  rating: 정보없음
#  visited_review: 방문자 리뷰 945
#  directions_text: 삼각지역 3번 출구로 나오셔서 첫번째 골목 따라 들어오시면
# 서울앵무새 건물 5층에 있습니다 :)
#
# [주차 정보]
# 용리단길은 주차자리가 협소하여 대중교통을 우선적으로 추천 드립니다.
# 매장 근처 공용주차장은 총 2개 있습니다.
# 1. 4호선 삼각지역 1번 출구 우리은행 뒷편
# 2. 아모레퍼시픽 or 용산우체국 옆 도로변
# 내용 더보기
#  store_id: 1724954504
#  address: 서울 용산구 한강대로62길 55 5층 성수미술관 용산점
#  blog_review: 블로그 리뷰 325
#  phone_num: 0507-1403-5080
#  business_hours: 목
# 12:00 - 21:30
# 금
# 12:00 - 21:30
# 토
# 11:00 - 22:00
# 일
# 11:00 - 22:00
# 월
# 12:00 - 21:30
# 화
# 12:00 - 21:30
# 수
# 정기휴무 (매주 수요일)
#
#  info: [성수미술관 용산점]은 누구나 화가가 될 수 있는 컨셉으로 커피를 마시고, 다양한 놀거리를 통해 커플,친구,가족이 함께 즐기고 웃을 수 있는 카페입니다.
#
# 커피를 마시면서 통창을 통해 [용리단길 뷰]를 즐기실 수 있고, 50평 규모의 넓고, 모던한 인테리어를 통해 스트레스를 날려버리고, 힐링하면서 즐겁게 놀 수 있는 공간을 마련해두었습니다.
#
# 캔버스에 드로잉 하거나, 베어브릭스 페인팅을 하면서 자신만의 스타일대로 커스텀할 수 있는 다양한 놀거리들이 준비되어 있습니다.
#
# 커피뿐만 아니라 상하목장 아이스크림, 카야,누텔라,햄치즈 토스트 등 다양한 먹거리도 준비되어 있습니다.
#
# **캔버스 전용매장입니다.
# 무지 캔버스로 나만의 스타일대로 자유롭게 그리고,채색하실 수 있습니다. 무지 캔버스가 어려우신 분들에게는 디자인 된 도안들도 준비되어 있습니다. 기본 디자인 캔버스는 명화,풍경 위주로 되어 있으며,캐릭터 도안들은 포켓몬, 디즈니, 산리오 등 공식 라이센스 도안 등을 보유하고 있습니다.
#
# **베어브릭스 커스텀
# 베어브릭스는 키링,소형,중형 사이즈로 준비되어 있으며, 90분 이용시간을 통해 자유롭게 나만의 스타일대로 커스텀 가능합니다. 중형은 23cm, 소형은 18cm, 키링은 8cm 사이즈로 이루어져 있습니다.
#
# 가족,연인,친구과 함께 직접 그린 작품들로 인생샷도 SNS에 남기고, 기념일에 맞춰 좋아하는 사람들에게도 선물해보세요!
# 용리단길 즐거운 실내 및 이색데이트로 재밌게 즐기시고, 완성된 작품은 집에서 인테리어 DP로 활용할 수 있습니다 :)
#
# **집에서 작품을 만들고 싶어하시는 분들을 위해 [드로잉키트]도 판매하고 있습니다.
#
# **매장은 최대 30명 수용 가능한 곳이며 단체 예약 및 공간 대여도 받고 있습니다
# (네이버 톡톡이나 매장 전화로 문의해주세요!)
# *한국관광재단,지방행정공제회,KT 등 회사 단체 워크샵 진행 多
# *초등학교 및 유치원 단체 체험 학습 환영
#
# *매장 운영시간
# 평일 매장 오픈 및 마감 : 12시 ~ 21시30분
# 주말 매장 오픈 및 마감 : 11시 ~ 22시
# 마지막 손님은 8시까지 입장 가능하십니다.
#
# *매장 예약은 네이버 예약 및 톡톡 메세지, 전화 예약도 가능합니다.
# *화장실은 매장 안에 남/녀 따로 분리되어 있습니다.
#
# *주차 공간이 협소하여 대중교통을 이용하시거나, 근처의 공영 및 사설 주차장을 이용해주시길 부탁드립니다. 매장 인근이 혼잡하오니 가급적 대중교통을 이용해 방문하시는 것을 추천 드립니다. 가장 가까운 공영주차장은 '삼각지역 1번 공영주차장' 입니다.
#
# *서울앵무새 / 용산테디뵈르 등 베이커리 반입 가능 (음료 반입 불가)
# *주변 음식점 웨이팅 대기 하고 매장 이용 가능(몽탄/샘샘샘/도야집/능동미나리 등 웨이팅 손님 환영합니다!! 중간에 식사 하고 가셔도 당일 그림 보관 가능!)
#
# *만 10세 미만 자녀는 보호자입장권을 함께 결제 부탁 드립니다. 매장은 1인 혹 2인으로 운영 되고 있어, 옆에서 아이들을 계속 주시하고 있을 수 없습니다 (보호자 입장권 : 아이들의 작품 완성을 도와주세요. / 음료 1잔 제공)
# 관련 문의사항은 언제든지 톡톡이나 전화로 연락주세요.
#
# *자리는 이용 인원에 따라 우선 배정되고, 그 다음 예약순을 기준으로 순차적으로 안내 도와드립니다.
#
# *일정 혹 시간 변경을 원하시는 경우, 1회에 한에 변경 도와드리고 있지만, 수수료 부과 기간 또는 당일에는 취소/날짜변경 불가능합니다.
# 반드시 매장으로 전화 혹은 톡톡으로 문의 부탁 드립니다.
#
# 네이버예약 취소 시 발생하는 수수료는 변상해드리지 않습니다. 취소 시 반드시 주의 부탁 드립니다.
#
# -취소 및 변경-
# 이용 5일 전까지 취소/변경 수수료 없음
# 이용 4일 전 총 결제금액의 10% 차감
# 이용 3일 전 총 결제금액의 30% 차감
# 이용 2일 전 총 결제금액의 50% 차감
# 이용 1일전 총 결제금액의 80% 차감
# 이용 당일 취소/변경 불가
#
# *영업시간 외 방문을 희망 시 톡톡이나 전화로 문의 바랍니다
# 펼쳐보기
#  convenience_facilities_and_services: 생일 혜택
# 콜키지 가능
# 무료
# 남/녀 화장실 구분
# 무선 인터넷
# 단체 이용 가능
# 예약
# 포장
# \
# 반려동물 동반
# 유아의자
# 출입구 휠체어 이용가능
# 좌석 휠체어 이용가능
#
#  Parking: 주차가능
# 무료
#  sns: https://www.instagram.com/seongsu_misulgwan_yongsan
#
#  review_like_this_part_output: "집중하기 좋아요"이 키워드를 선택한 인원438
# "친절해요"이 키워드를 선택한 인원432
# "인테리어가 멋져요"이 키워드를 선택한 인원414
# "사진이 잘 나와요"이 키워드를 선택한 인원381
# "매장이 청결해요"이 키워드를 선택한 인원242
# "매장이 넓어요"이 키워드를 선택한 인원212
# "대화하기 좋아요"이 키워드를 선택한 인원198
# "뷰가 좋아요"이 키워드를 선택한 인원196
# "컨셉이 독특해요"이 키워드를 선택한 인원190
# "커피가 맛있어요"이 키워드를 선택한 인원189
# "화장실이 깨끗해요"이 키워드를 선택한 인원90
# "음료가 맛있어요"이 키워드를 선택한 인원80
# "특별한 날 가기 좋아요"이 키워드를 선택한 인원79
# "놀거리가 많아요"이 키워드를 선택한 인원74
# "아이와 가기 좋아요"이 키워드를 선택한 인원72
# "아늑해요"이 키워드를 선택한 인원52
# "음악이 좋아요"이 키워드를 선택한 인원52
# "차분한 분위기에요"이 키워드를 선택한 인원44
# "가성비가 좋아요"이 키워드를 선택한 인원44
# "디저트가 맛있어요"이 키워드를 선택한 인원39
# "좌석이 편해요"이 키워드를 선택한 인원37
# "오래 머무르기 좋아요"이 키워드를 선택한 인원20
# "음식이 맛있어요"이 키워드를 선택한 인원15
# "종류가 다양해요"이 키워드를 선택한 인원9
# "비싼 만큼 가치있어요"이 키워드를 선택한 인원6
# "주문제작을 잘해줘요"이 키워드를 선택한 인원5
# "코스요리가 알차요"이 키워드를 선택한 인원3
# "선물하기 좋아요"이 키워드를 선택한 인원3
# "메뉴 구성이 알차요"이 키워드를 선택한 인원3
# "야외공간이 멋져요"이 키워드를 선택한 인원3
# "룸이 잘 되어있어요"이 키워드를 선택한 인원3
# "반려동물과 가기 좋아요"이 키워드를 선택한 인원2
# "특별한 메뉴가 있어요"이 키워드를 선택한 인원2
# "차가 맛있어요"이 키워드를 선택한 인원1
# "단체모임 하기 좋아요"이 키워드를 선택한 인원1
#
#  menu: 드로잉 체험(120분)대표용리단길 뷰를 즐기면서 그리는 캔버스 드로잉, 커피 한 잔의 여유와 함께 힐링하세요!23,000원
# 베어브릭스 체험(90분)대표전 세계 단 하나 밖에 없는 나만의 베어브릭 맛집!
# 인테리어 소품으로 안성맞춤!!!!19,900원
# 보호자 입장권대표만 10세 미만 자녀들은 보호자와 함께 입장 부탁드립니다.12,000원
# [고급 원두 100%]아메리카노대표피카소도 그림 그리다 한 잔씩 먹는 음료4,000원
# [쫄깃한 식감 100%]딸기잼 토스트대표당 떨어질 때 한 입 먹는 순간 당 충전 완료3,500원
# 드로잉키트집에서도 즐길 수 있는 드로잉키트 상품입니다.(구성품:캔버스/물감/파레트/붓)21,000원
# 캔버스도안 구매라이센스 도안 선택 시 +2900원 추가10,000원
# </content>
# <document><content>store_name: 성수미술관 용산점
#  category: 테마카페
#  new_open:
#  rating: 정보없음
#  visited_review: 방문자 리뷰 945
#  directions_text: 삼각지역 3번 출구로 나오셔서 첫번째 골목 따라 들어오시면
# 서울앵무새 건물 5층에 있습니다 :)
#
# [주차 정보]
# 용리단길은 주차자리가 협소하여 대중교통을 우선적으로 추천 드립니다.
# 매장 근처 공용주차장은 총 2개 있습니다.
# 1. 4호선 삼각지역 1번 출구 우리은행 뒷편
# 2. 아모레퍼시픽 or 용산우체국 옆 도로변
# 내용 더보기
#  store_id: 1724954504
#  address: 서울 용산구 한강대로62길 55 5층 성수미술관 용산점
#  blog_review: 블로그 리뷰 325
#  phone_num: 0507-1403-5080
#  business_hours: 목
# 12:00 - 21:30
# 금
# 12:00 - 21:30
# 토
# 11:00 - 22:00
# 일
# 11:00 - 22:00
# 월
# 12:00 - 21:30
# 화
# 12:00 - 21:30
# 수
# 정기휴무 (매주 수요일)
#
#  info: [성수미술관 용산점]은 누구나 화가가 될 수 있는 컨셉으로 커피를 마시고, 다양한 놀거리를 통해 커플,친구,가족이 함께 즐기고 웃을 수 있는 카페입니다.
#
# 커피를 마시면서 통창을 통해 [용리단길 뷰]를 즐기실 수 있고, 50평 규모의 넓고, 모던한 인테리어를 통해 스트레스를 날려버리고, 힐링하면서 즐겁게 놀 수 있는 공간을 마련해두었습니다.
#
# 캔버스에 드로잉 하거나, 베어브릭스 페인팅을 하면서 자신만의 스타일대로 커스텀할 수 있는 다양한 놀거리들이 준비되어 있습니다.
#
# 커피뿐만 아니라 상하목장 아이스크림, 카야,누텔라,햄치즈 토스트 등 다양한 먹거리도 준비되어 있습니다.
#
# **캔버스 전용매장입니다.
# 무지 캔버스로 나만의 스타일대로 자유롭게 그리고,채색하실 수 있습니다. 무지 캔버스가 어려우신 분들에게는 디자인 된 도안들도 준비되어 있습니다. 기본 디자인 캔버스는 명화,풍경 위주로 되어 있으며,캐릭터 도안들은 포켓몬, 디즈니, 산리오 등 공식 라이센스 도안 등을 보유하고 있습니다.
#
# **베어브릭스 커스텀
# 베어브릭스는 키링,소형,중형 사이즈로 준비되어 있으며, 90분 이용시간을 통해 자유롭게 나만의 스타일대로 커스텀 가능합니다. 중형은 23cm, 소형은 18cm, 키링은 8cm 사이즈로 이루어져 있습니다.
#
# 가족,연인,친구과 함께 직접 그린 작품들로 인생샷도 SNS에 남기고, 기념일에 맞춰 좋아하는 사람들에게도 선물해보세요!
# 용리단길 즐거운 실내 및 이색데이트로 재밌게 즐기시고, 완성된 작품은 집에서 인테리어 DP로 활용할 수 있습니다 :)
#
# **집에서 작품을 만들고 싶어하시는 분들을 위해 [드로잉키트]도 판매하고 있습니다.
#
# **매장은 최대 30명 수용 가능한 곳이며 단체 예약 및 공간 대여도 받고 있습니다
# (네이버 톡톡이나 매장 전화로 문의해주세요!)
# *한국관광재단,지방행정공제회,KT 등 회사 단체 워크샵 진행 多
# *초등학교 및 유치원 단체 체험 학습 환영
#
# *매장 운영시간
# 평일 매장 오픈 및 마감 : 12시 ~ 21시30분
# 주말 매장 오픈 및 마감 : 11시 ~ 22시
# 마지막 손님은 8시까지 입장 가능하십니다.
#
# *매장 예약은 네이버 예약 및 톡톡 메세지, 전화 예약도 가능합니다.
# *화장실은 매장 안에 남/녀 따로 분리되어 있습니다.
#
# *주차 공간이 협소하여 대중교통을 이용하시거나, 근처의 공영 및 사설 주차장을 이용해주시길 부탁드립니다. 매장 인근이 혼잡하오니 가급적 대중교통을 이용해 방문하시는 것을 추천 드립니다. 가장 가까운 공영주차장은 '삼각지역 1번 공영주차장' 입니다.
#
# *서울앵무새 / 용산테디뵈르 등 베이커리 반입 가능 (음료 반입 불가)
# *주변 음식점 웨이팅 대기 하고 매장 이용 가능(몽탄/샘샘샘/도야집/능동미나리 등 웨이팅 손님 환영합니다!! 중간에 식사 하고 가셔도 당일 그림 보관 가능!)
#
# *만 10세 미만 자녀는 보호자입장권을 함께 결제 부탁 드립니다. 매장은 1인 혹 2인으로 운영 되고 있어, 옆에서 아이들을 계속 주시하고 있을 수 없습니다 (보호자 입장권 : 아이들의 작품 완성을 도와주세요. / 음료 1잔 제공)
# 관련 문의사항은 언제든지 톡톡이나 전화로 연락주세요.
#
# *자리는 이용 인원에 따라 우선 배정되고, 그 다음 예약순을 기준으로 순차적으로 안내 도와드립니다.
#
# *일정 혹 시간 변경을 원하시는 경우, 1회에 한에 변경 도와드리고 있지만, 수수료 부과 기간 또는 당일에는 취소/날짜변경 불가능합니다.
# 반드시 매장으로 전화 혹은 톡톡으로 문의 부탁 드립니다.
#
# 네이버예약 취소 시 발생하는 수수료는 변상해드리지 않습니다. 취소 시 반드시 주의 부탁 드립니다.
#
# -취소 및 변경-
# 이용 5일 전까지 취소/변경 수수료 없음
# 이용 4일 전 총 결제금액의 10% 차감
# 이용 3일 전 총 결제금액의 30% 차감
# 이용 2일 전 총 결제금액의 50% 차감
# 이용 1일전 총 결제금액의 80% 차감
# 이용 당일 취소/변경 불가
#
# *영업시간 외 방문을 희망 시 톡톡이나 전화로 문의 바랍니다
# 펼쳐보기
#  convenience_facilities_and_services: 생일 혜택
# 콜키지 가능
# 무료
# 남/녀 화장실 구분
# 무선 인터넷
# 단체 이용 가능
# 예약
# 포장
# \
# 반려동물 동반
# 유아의자
# 출입구 휠체어 이용가능
# 좌석 휠체어 이용가능
#
#  Parking: 주차가능
# 무료
#  sns: https://www.instagram.com/seongsu_misulgwan_yongsan
#
#  review_like_this_part_output: "집중하기 좋아요"이 키워드를 선택한 인원438
# "친절해요"이 키워드를 선택한 인원432
# "인테리어가 멋져요"이 키워드를 선택한 인원414
# "사진이 잘 나와요"이 키워드를 선택한 인원381
# "매장이 청결해요"이 키워드를 선택한 인원242
# "매장이 넓어요"이 키워드를 선택한 인원212
# "대화하기 좋아요"이 키워드를 선택한 인원198
# "뷰가 좋아요"이 키워드를 선택한 인원196
# "컨셉이 독특해요"이 키워드를 선택한 인원190
# "커피가 맛있어요"이 키워드를 선택한 인원189
# "화장실이 깨끗해요"이 키워드를 선택한 인원90
# "음료가 맛있어요"이 키워드를 선택한 인원80
# "특별한 날 가기 좋아요"이 키워드를 선택한 인원79
# "놀거리가 많아요"이 키워드를 선택한 인원74
# "아이와 가기 좋아요"이 키워드를 선택한 인원72
# "아늑해요"이 키워드를 선택한 인원52
# "음악이 좋아요"이 키워드를 선택한 인원52
# "차분한 분위기에요"이 키워드를 선택한 인원44
# "가성비가 좋아요"이 키워드를 선택한 인원44
# "디저트가 맛있어요"이 키워드를 선택한 인원39
# "좌석이 편해요"이 키워드를 선택한 인원37
# "오래 머무르기 좋아요"이 키워드를 선택한 인원20
# "음식이 맛있어요"이 키워드를 선택한 인원15
# "종류가 다양해요"이 키워드를 선택한 인원9
# "비싼 만큼 가치있어요"이 키워드를 선택한 인원6
# "주문제작을 잘해줘요"이 키워드를 선택한 인원5
# "코스요리가 알차요"이 키워드를 선택한 인원3
# "선물하기 좋아요"이 키워드를 선택한 인원3
# "메뉴 구성이 알차요"이 키워드를 선택한 인원3
# "야외공간이 멋져요"이 키워드를 선택한 인원3
# "룸이 잘 되어있어요"이 키워드를 선택한 인원3
# "반려동물과 가기 좋아요"이 키워드를 선택한 인원2
# "특별한 메뉴가 있어요"이 키워드를 선택한 인원2
# "차가 맛있어요"이 키워드를 선택한 인원1
# "단체모임 하기 좋아요"이 키워드를 선택한 인원1
#
#  menu: 드로잉 체험(120분)대표용리단길 뷰를 즐기면서 그리는 캔버스 드로잉, 커피 한 잔의 여유와 함께 힐링하세요!23,000원
# 베어브릭스 체험(90분)대표전 세계 단 하나 밖에 없는 나만의 베어브릭 맛집!
# 인테리어 소품으로 안성맞춤!!!!19,900원
# 보호자 입장권대표만 10세 미만 자녀들은 보호자와 함께 입장 부탁드립니다.12,000원
# [고급 원두 100%]아메리카노대표피카소도 그림 그리다 한 잔씩 먹는 음료4,000원
# [쫄깃한 식감 100%]딸기잼 토스트대표당 떨어질 때 한 입 먹는 순간 당 충전 완료3,500원
# 드로잉키트집에서도 즐길 수 있는 드로잉키트 상품입니다.(구성품:캔버스/물감/파레트/붓)21,000원
# 캔버스도안 구매라이센스 도안 선택 시 +2900원 추가10,000원
# </content>
# <document><content>store_name: 더보일러스 바베큐 신용산점
#  category: 양식
#  new_open:
#  rating: 별점 4.5
#  visited_review: 방문자 리뷰 2,123
#  directions_text: [아모레퍼시픽 본사] 신용산역 5번 출구쪽으로 건널목 건너서 400m 직진하시면 신용산 지하도를 지나 대형 더보일러스의 후문 간판이 보입니다.
#
# [신용산역] 5번 출구에서 400m 직진하시면 신용산 지하도를 지나 대형 더보일러스의 후문 간판이 보입니다.
#
# [용산역] 3번 출구에서 300m 직진 구름다리를 건너 오시면 용산전자상가 사거리 더보일러스 정문에 도착합니다.
#
# [드래곤시티호텔] 호텔 정문에서 길 건너편 100m 전방 용산전자상가 사거리에 위치하고 있습니다.
# 내용 더보기
#  store_id: 1421188035
#  address: 서울 용산구 청파로 112 나진상가 15동 지하1층
#  blog_review: 블로그 리뷰 629
#  phone_num: 0507-1408-7502
#  business_hours: 일
# 12:00 - 22:00
# 15:00 - 17:00 브레이크타임
# 월
# 17:00 - 22:30
# 화
# 17:00 - 22:30
# 수(1/1)
# 새해 첫날12:00 - 22:00
# 15:00 - 17:00 브레이크타임
# 목
# 17:00 - 22:30
# 금
# 11:00 - 22:30
# 15:00 - 17:00 브레이크타임
# 토
# 12:00 - 22:30
# 15:00 - 17:00 브레이크타임
#
#  info: 용산에 숨겨진 500평의 공장형 바베큐 매장에서 펼쳐지는 압도적인 바베큐 경험!
# 용산 최고의 데이트코스이자 용산맛집!! 육즙 가득한 탑초이스 등급 우대꽃갈비 비프립, 부드러운 다양한 맛의 훈연 포크립, 통으로 튀겨낸 점보 홍메기 튀김 등 서든 감성의 메뉴를 여유롭고 쾌적한 500평의 미쿡 감성의 공장형 매장에서 만나보세요 !!
#
# 200명까지 수용 가능한 단체 대관이 가능하며, 회식 장소로도 안성맞춤입니다. 60여종의 버번 위스키와 바베큐와 어울리는 다양한 음료가 준비 되어 있습니다.
#
# ※ [ 전화 문의 전 꼭 읽어주세요! : FAQ ] ※ - 주차, 예약, 콜키지 등
#
# 1. 예약은 네이버와 캐치테이블을 이용해주세요, 15명 이상의 단체예약은 노쇼방지를 위해 예약금을 받고 있습니다.
#
# 2. 전날 바베큐 일정량을 손질하여 스모킹하기 때문에 바베큐 메뉴 예약 필수입니다. 선택하지 않을 시 예약 취소될 수 있습니다.
# 예약 시 주문이 미리 들어가는 것이 아닌 현장에서 태블릿으로 세부사항 선택 후 한번 더 주문하셔야 합니다. 이 과정에서 메뉴 변경 및 추가도 특수한 경우를 제외하고 가능합니다.
#
# 3. 룸은 없습니다. 10명 이상의 단체인원은 보통 4~6인 테이블을 붙여 세팅해드리고 있습니다.
#
# 4. 예약시간보다 일찍 오셔도 괜찮습니다. 다만 금,토,일 요일은 이전 주문이 밀려있을 경우 웨이팅이 있을 수도 있습니다. 늦게 도착하시는 경우는 전화 문의 주시기 바랍니다.
#
# 5. 예약은 이용일 기준 14일 전에 오픈됩니다. 해당 날짜에 예약 진행해주시기 바랍니다.
#
# 6. 대관은 최소 30일 전에 문의 부탁드립니다.
#
# 7. 콜키지 (1병당 4잔 기본 제공, 잔 추가 시 3,000원 씩 발생)
# - 와인류 : 병당 2만원
# - 위스키 : 병당 6만원
#
# 8. 보유 주류 (유동적 변동)
# - 생맥주 5종 : 레드락 355cc 잔당 7,800원 (가장 저렴)
# - 병맥주 12종
# - 캔맥주 1종
# - 하이볼 9종
# - 와인, 샴페인 8종 (하우스 와인 2종, 레드)
# - 위스키 약 50종
# - 일반 소주 1종 : 한라산, 21도, 9,000원
# - 증류식 소주 3종 : 화요, 일품진로, 토끼소주
#
# 9. 무료주차 : 평일 오후 6시 이후 / 주말
#
# [주변 주차가능 구간]
# 1) 나진상가 15동 (서울시 용산구 청파로 112)
# 주말 : 무료
# 평일 6pm~9am : 무료
# 평일 9am~6pm.: 최초 30분 1500원
#  추가 10분당 500원
#  일 주차 20,000원
#
# 2) 나진전자월드 상가 (서울시 용산구 청파로 109) 대로 쪽 지상층 주차장
# 주말 : 무료
# 6pm~9am(평일) : 무료
# 9am~6pm(평일) : 최초 30분 1500원
#  추가 10분당 500원
#  일 주차 20,000원
#
# 3) 용산전자상가1 공영 주차장 (서울시 용산구 새창로 170-4)
# 10pm~8am : 무료
# 8am~10pm.: 500원(10분당)
#
# 4)용산 하나로마트 주차장 (서울시 용산구 청파로 122 농협)
# 8am~12pm: 최초 30분 1500원
#  추가 10분당 500원
# 12pm~6am: 입출차 불가능
#
# 더보일러스는 Eat Craft Live Artisan을 모토로 8시간~12시간 동안 참나무 장작으로만 훈제된 바비큐와 매일 아침 생고기를 갈아서 만든 수제버거, 직접 훈제한 베이컨과 햄을 정성스럽게 조리하여 제공합니다.
# 펼쳐보기
#  convenience_facilities_and_services: 단체 이용 가능
# 예약
# 무선 인터넷
# 남/녀 화장실 구분
# 포장
# 배달
#
#  Parking: 주차가능
#  sns: https://app.catchtable.co.kr/ct/shop/theboilers?from=share
# http://www.instagram.com/theboilers_official/
#
#  review_like_this_part_output: "음식이 맛있어요"이 키워드를 선택한 인원1191
# "매장이 넓어요"이 키워드를 선택한 인원928
# "단체모임 하기 좋아요"이 키워드를 선택한 인원542
# "인테리어가 멋져요"이 키워드를 선택한 인원534
# "특별한 메뉴가 있어요"이 키워드를 선택한 인원409
# "양이 많아요"이 키워드를 선택한 인원343
# "친절해요"이 키워드를 선택한 인원319
# "특별한 날 가기 좋아요"이 키워드를 선택한 인원252
# "매장이 청결해요"이 키워드를 선택한 인원243
# "재료가 신선해요"이 키워드를 선택한 인원175
# "화장실이 깨끗해요"이 키워드를 선택한 인원124
# "가성비가 좋아요"이 키워드를 선택한 인원87
# "고기 질이 좋아요"이 키워드를 선택한 인원30
# "주차하기 편해요"이 키워드를 선택한 인원27
# "메뉴 구성이 알차요"이 키워드를 선택한 인원26
# "비싼 만큼 가치있어요"이 키워드를 선택한 인원22
# "컨셉이 독특해요"이 키워드를 선택한 인원21
# "혼밥하기 좋아요"이 키워드를 선택한 인원13
# "뷰가 좋아요"이 키워드를 선택한 인원12
# "술이 다양해요"이 키워드를 선택한 인원9
# "아늑해요"이 키워드를 선택한 인원6
# "사진이 잘 나와요"이 키워드를 선택한 인원6
# "대화하기 좋아요"이 키워드를 선택한 인원6
# "음식이 빨리 나와요"이 키워드를 선택한 인원5
# "현지 맛에 가까워요"이 키워드를 선택한 인원5
# "잡내가 적어요"이 키워드를 선택한 인원4
# "아이와 가기 좋아요"이 키워드를 선택한 인원3
# "반찬이 잘 나와요"이 키워드를 선택한 인원3
# "오래 머무르기 좋아요"이 키워드를 선택한 인원3
# "음료가 맛있어요"이 키워드를 선택한 인원2
# "음악이 좋아요"이 키워드를 선택한 인원2
# "향신료가 강하지 않아요"이 키워드를 선택한 인원2
# "직접 잘 구워줘요"이 키워드를 선택한 인원2
# "건강한 맛이에요"이 키워드를 선택한 인원2
# "코스요리가 알차요"이 키워드를 선택한 인원1
# "샐러드바가 잘 되어있어요"이 키워드를 선택한 인원1
# "기본 안주가 좋아요"이 키워드를 선택한 인원1
#
#  menu: 포크립 800g A세트(2인)대표훈연 포크립 800g+그린샐러드+사이드3종(코울슬로,하우스살사,매쉬포테이토)+디너롤69,000원
# 포크립 800g B세트 (2인+)대표포크립 800g+풀드포크BBQ+수제베이컨+수제훈연소세지+사이드3종+베이크드빈+디너롤82,000원
# 우대꽃갈비 600g A세트 (2인)대표앵거스 우대꽃갈비 600g+그린샐러드+사이드3종(코울슬로,하우스살사,매쉬포테이토)+디너롤86,000원
# 우대꽃갈비 600g B세트 (2인+)대표앵거스우대꽃갈비 600g+풀드포크BBQ+수제베이컨+훈연소세지+사이드3종+베이크드빈+디너롤99,000원
# 우대&포크립 콤보 (3~4인)대표우대600g+포크립800g+풀드포크BBQ+수제베이컨+훈연소세지+사이드3종+베이크드빈+디너롤159,000원
# 더보일러스 플래터 (4~6인)대표우대600g+포크립800g X2+풀드포크+수제베이컨+훈연소세지+사이드3종+베이크드빈+디너롤199,000원
# 우대꽃갈비 플래터 (4~5인)대표앵거스 우대꽃갈비 1800g +풀드포크+수제베이컨+훈연소세지+사이드3종+베이크드빈+디너롤249,000원
# </content>
# <document><content>store_name: 리얼스터디카페 이촌2호점
#  category: 스터디카페
#  new_open:
#  rating: 정보없음
#  visited_review: 방문자 리뷰 95
#  directions_text: 이촌동에서 Top 1, 최고의 시설과 서비스를 자랑하는 <리얼스터디카페> 입니다.
#
# 2인실, 4인실 회의실
# 약 50평의 53좌석 열람실
#
# 365일 24시간 언제나 환영합니다.
# 매일 09:00 ~ 22:00 전화, 카톡 상담가능
#
# 1. 삼성 최신 환기 시스템, 전열교환기를 도입하여 깨끗하고 좋은 환경
#
# 2. Study zone, Notebook zone으로 나뉘어 더욱 집중적인 공간
#
# 3. 회의실마다 유무선 인터넷, 개별 냉난방, 화이트보드, 모니터 보유(2인실 모니터X)
#
# 4. 회의실 예약은 네이버예약으로만, 열람실은 앱 'ZONE공'에서 이용권 구매
#
# 5. 회의실 시간변경 시, 직접 취소하고 재결제
# (환불수수료 적용)
#
# 6. 당 건물 주차불가
# - 바로 옆 공영주차장 이용해주세요(도보 10초)
# 내용 더보기
#  store_id: 1428524362
#  address: 서울 용산구 이촌로64길 61
#  blog_review: 블로그 리뷰 6
#  phone_num: nan
#  business_hours: 매일
# 00:00 - 24:00
#
#  info: 이촌동에서 Top 1, 최고의 시설과 서비스를 자랑하는 <리얼스터디카페> 입니다.
#
# 2인실, 4인실 회의실
# 약 50평의 53좌석 열람실
#
# 365일 24시간 언제나 환영합니다.
# 매일 09:00 ~ 22:00 전화, 카톡 상담가능
#
# 1. 삼성 최신 환기 시스템, 전열교환기를 도입하여 깨끗하고 좋은 환경
#
# 2. Study zone, Notebook zone으로 나뉘어 더욱 집중적인 공간
#
# 3. 회의실마다 유무선 인터넷, 개별 냉난방, 화이트보드, 모니터 보유(2인실 모니터X)
#
# 4. 2022년 1월 1일부터~ 회의실 예약은 네이버예약으로만, 열람실은 앱 'ZONE공'에서 이용권 구매
#
# 5. 회의실 시간변경 시, 직접 취소하고 재결제
# (환불수수료 적용)
#
# 6. 당 건물 주차불가
# - 바로 옆 공영주차장 이용해주세요(도보 10초)
# - 주차가 필요하거나 10인실까지 이용이 필요하신 분은 용산푸르지오써밋에 있는 <리얼컨퍼런스>를 이용해주세요(무료주차 4시간/용산역 도보 3분)
#
# 7. 장미맨션, 알파문구가 있는 건물입니다.
#
# 8. 흑백프린트 가능(장당 100원, 복사, 스캔 불가)
#
# 9. 전광수커피 무료
# 펼쳐보기
#  convenience_facilities_and_services: 무선 인터넷
# 남/녀 화장실 구분
#
#  Parking: 주차 불가
#  sns: https://blog.naver.com/real_studycafe
# https://www.instagram.com/real_studycafe
#
#  review_like_this_part_output: "집중하기 좋아요"이 키워드를 선택한 인원67
# "룸이 잘 되어있어요"이 키워드를 선택한 인원32
# "차분한 분위기에요"이 키워드를 선택한 인원20
# "가성비가 좋아요"이 키워드를 선택한 인원20
# "분위기 관리가 철저해요"이 키워드를 선택한 인원20
# "매장이 청결해요"이 키워드를 선택한 인원19
# "요금제가 잘 되어있어요"이 키워드를 선택한 인원11
# "커피가 맛있어요"이 키워드를 선택한 인원10
# "화장실이 깨끗해요"이 키워드를 선택한 인원10
# "대화하기 좋아요"이 키워드를 선택한 인원9
# "친절해요"이 키워드를 선택한 인원8
# "조용해요"이 키워드를 선택한 인원8
# "인테리어가 멋져요"이 키워드를 선택한 인원6
# "매장이 넓어요"이 키워드를 선택한 인원5
# "아늑해요"이 키워드를 선택한 인원4
# "좌석이 편해요"이 키워드를 선택한 인원3
# "비싼 만큼 가치있어요"이 키워드를 선택한 인원2
# "단체모임 하기 좋아요"이 키워드를 선택한 인원2
# "휴게시설이 잘 되어있어요"이 키워드를 선택한 인원1
# "개인 공간이 쾌적해요"이 키워드를 선택한 인원1
# "특별한 메뉴가 있어요"이 키워드를 선택한 인원1
#
#  menu: 당일이용권 1시간(연장시만 구매가능)3,000원
# 당일이용권 2시간5,000원
# 당일이용권 3시간7,000원
# 당일이용권 4시간8,500원
# 당일이용권 6시간11,000원
# 당일이용권 8시간13,500원
# 당일이용권 10시간16,000원
# 당일이용권 12시간18,000원
# 시간패키지 30시간60,000원
# 시간패키지 50시간90,000원
# 시간패키지 100시간160,000원
# 시간패키지 200시간290,000원
# 기간이용권 1주70,000원
# 기간이용권 2주120,000원
# 기간이용권 4주210,000원
# </content>
# <document><content>store_name: 멜팅팟
#  category: 양식
#  new_open:
#  rating: 정보없음
#  visited_review: 방문자 리뷰 196
#  directions_text: 삼각지역 1번 출구에서 150m 이내에 위치해있습니다.
#
# 삼각지역 1번 출구로 나와서 우리은행을 끼고 유턴하여 쭉 직진하시다가 국밥대장에서 좌회전해서 70미터 정도 직진하시면 빨간 벽돌 건물이 나옵니다.
#
# 건물 2층으로 올라오시면 모던 아메리칸 식당 멜팅팟을 만나실 수 있습니다.
# 내용 더보기
#  store_id: 1916949409
#  address: 서울 용산구 한강대로62나길 13 2층
#  blog_review: 블로그 리뷰 1,082
#  phone_num: 0507-1432-9991
#  business_hours: 일
# 11:45 - 22:00
# 15:00 - 17:30 브레이크타임
# 21:30 라스트오더
# 월
# 17:30 - 22:30
# 22:00 라스트오더
# 화
# 11:45 - 22:30
# 14:30 - 17:30 브레이크타임
# 22:00 라스트오더
# 수(1/1)
# 새해 첫날11:45 - 22:30
# 15:00 - 17:30 브레이크타임
# 목
# 11:45 - 22:30
# 14:30 - 17:30 브레이크타임
# 22:00 라스트오더
# 금
# 11:45 - 22:30
# 14:30 - 17:30 브레이크타임
# 22:00 라스트오더
# 토
# 11:45 - 22:30
# 15:00 - 17:00 브레이크타임
# 22:00 라스트오더
#
#  info: <삼각지 맛집, 용리단길 맛집을 찾으신다면>
#
# < 바로 여기 멜팅팟>
#
# - 캐치테이블에서 검증된 맛집
# - 네이버 예약으로도 바로 예약 가능합니다.
#
# 두 명의 CIA 셰프가 만들어내는 아메리칸 음식 맛집
# 용리단길 멜팅팟에서 특별한 다이닝 경험을 해보세요.
#
# 합리적인 가격으로 고급 양식을 경험할 수 있는 멜팅팟은 삼각지의 중심, 용리단길에서 여러분을 기다리고 있습니다.
#
# 삼각지 맛집으로 소문난 멜팅팟은 신선한 재료와 오랜 시간 연구한 조리법을 통해 맛의 진수를 선보이고 있습니다.
#
# 독보적인 맛과 분위기를 자랑하는 삼각지 맛집 멜팅팟은 각종 기념일, 가족 모임, 데이트 장소로도 손색 없는 곳입니다.
#
# 멜팅팟은 품격 있는 인테리어와 세심한 서비스로 손님을 맞이합니다.
# 고급스러운 분위기 속에서 편안하게 식사를 즐기실 수 있으며, 용리단길, 삼각지 맛집이라는 명성에 걸맞게 다양한 메뉴가 준비되어 있습니다.
#
# 저희 멜팅팟의 대표 메뉴로는 수비드에서 12시간 조리된 우대갈비를 버번 위스키인 잭다니엘 소스에 곁들인 잭다니엘 우대갈비 찜과 멜팅팟의 특제 소스를 사용해 켄사스 시티 스타일로 맛을 낸 베이비 백립, 미국 스타일의 잠봉피자가 있습니다.
#
# 저희 멜팅팟은 대표요리 뿐만 아니라 사이드 모든 요리도 최고의 맛을 자부합니다.
#
# 용리단길과 삼각지역에서 가까워 지하철 삼각지역에서 도보로 편리하게 방문하실 수 있습니다.
#
# 멜팅팟은 여러분의 소중한 시간을 더욱 값지게 만들어 드리겠습니다.
# 신선한 재료와 정성을 담아 만든 요리, 품격 있는 서비스, 그리고 고급스러운 분위기에서 잊지 못할 시간을 보내보세요.
#
# 삼각지 맛집, 멜팅팟에서 여러분을 기다리고 있겠습니다.
#
# 감사합니다.
# 펼쳐보기
#  convenience_facilities_and_services: 콜키지 가능
# 유료
# 생일 혜택
# 무선 인터넷
# 포장
# 예약
# 단체 이용 가능
#
#  Parking: 주차 불가
#  sns: https://app.catchtable.co.kr/ct/shop/meltingpot
# https://www.instagram.com/meltingpot_seoul
#
#  review_like_this_part_output: "음식이 맛있어요"이 키워드를 선택한 인원184
# "특별한 메뉴가 있어요"이 키워드를 선택한 인원113
# "친절해요"이 키워드를 선택한 인원92
# "재료가 신선해요"이 키워드를 선택한 인원81
# "인테리어가 멋져요"이 키워드를 선택한 인원75
# "가성비가 좋아요"이 키워드를 선택한 인원31
# "아늑해요"이 키워드를 선택한 인원29
# "매장이 청결해요"이 키워드를 선택한 인원27
# "메뉴 구성이 알차요"이 키워드를 선택한 인원24
# "특별한 날 가기 좋아요"이 키워드를 선택한 인원23
# "대화하기 좋아요"이 키워드를 선택한 인원17
# "양이 많아요"이 키워드를 선택한 인원15
# "화장실이 깨끗해요"이 키워드를 선택한 인원15
# "차분한 분위기에요"이 키워드를 선택한 인원11
# "단체모임 하기 좋아요"이 키워드를 선택한 인원9
# "고기 질이 좋아요"이 키워드를 선택한 인원7
# "건강한 맛이에요"이 키워드를 선택한 인원7
# "술이 다양해요"이 키워드를 선택한 인원5
# "현지 맛에 가까워요"이 키워드를 선택한 인원4
# "음료가 맛있어요"이 키워드를 선택한 인원3
# "비싼 만큼 가치있어요"이 키워드를 선택한 인원3
# "뷰가 좋아요"이 키워드를 선택한 인원3
# "잡내가 적어요"이 키워드를 선택한 인원2
# "매장이 넓어요"이 키워드를 선택한 인원2
# "컨셉이 독특해요"이 키워드를 선택한 인원1
# "디저트가 맛있어요"이 키워드를 선택한 인원1
# "혼밥하기 좋아요"이 키워드를 선택한 인원1
# "음식이 빨리 나와요"이 키워드를 선택한 인원1
# "사진이 잘 나와요"이 키워드를 선택한 인원1
# "기본 안주가 좋아요"이 키워드를 선택한 인원1
#
#  menu: 명란라자냐(디너)대표깊은 풍미의 명란과 버섯 크림소스를 매콤하게 즐길수 있는 라자냐26,500원
# 베이비 백립대표멜팅팟의 특별한 소스와 매콤함이 더해진 켄사스 시티 스타일의 베이비백립29,000원
# 전복 내장 파스타대표완도에서 올라온 신선한 전복을 이용해 깊은 바다 맛을 더한 파스타25,000원
# 베이컨 육즙와규버거세트 (런치)대표육즙가득한 와규패티에 수제 베이컨과 특제소스로 가득찬 버거, 감자튀김, 코오슬로13,800원
# 그릴새우 봉골레 파스타대표매장에서 직접만든 초리조와 봉골레파스타에 그릴한 새우를 얹은 셰프추천 메뉴29,500원
# 잭다니엘 우대갈비 찜대표수비드에서 12시간 조리된 우대갈비를 버번 위스키 소스인 잭다니엘 소스에 곁들인 메인디쉬38,000원
# 알배기 차돌찜(디너)대표김형준 셰프가 '좋은아침'에서 다이어트를 위해 만든 담백한 알배기 차돌찜17,500원
# 한치파스타(디너)감칠맛 넘치는 다시마 파스타에 그릴한 제주 한치 그리고 가리비를 올린 파스타24,000원
# 토마토 꿀 가자미대가자미에 마요네즈 소스를 얹어 토마토 소스와 곁들인 에피타이저18,500원
# 오늘의 샐러드(런치)시즈널로 바뀌는 샐러드13,800원
# 잠봉 루꼴라 피자이재원 셰프가 첼시마켓에서 배우고 직접 만든 미국 스타일의 장봉을 이용한 스페셜 피자26,000원
# 모듬 해산물 커리 리조또(디너)카다이프 가리비 튀김과 여러해산물을 특제 카레 리조또와 함께 즐기는 메뉴33,000원
# 오늘의 파스타(런치)14,800원
# 치즈 라구 파스타볼로네제 파스타와 3종의 치즈의 만남21,000원
# 들기름 후무스와 그릴 채소(디너)경남 마산의 장인이 한땀한땀내린 들기름 풍미가 가득한 후무스와 그릴한 제철 채소와 팔라펠15,000원
# </content>
# <document><content>store_name: 어슬 서울
#  category: 한식
#  new_open:
#  rating: 정보없음
#  visited_review: 방문자 리뷰 23
#  directions_text: 서울역 7번출구에서 나오셔서
# 연세대학교 세브란스빌딩이 왼쪽에 보이실거에요.
# 그대로 80m 이동하시면 왼쪽에 건물입구가 있습니다.
#
# 회현역 5번출구에서 남대문시장 입구 교차로 쪽으로 나오시면
# 우리농산물유통센터 남대문점이 있습니다.
# 오른쪽 방향으로 200m정도 이동하시면 오른쪽에 건물입구가 있습니다.
#
# 어슬 서울은
# 그랜드센트럴, 메트로타워, 서울로타워, SK텔레콤 남산사옥 건물 가운데쪽에 위치하고 있습니다.
#
# 숭례문광장에서 오실경우 도보 5분정도 소요됩니다.
#
# 13층으로 올라오시면 다양한 전통주와 다채로운 퓨전한식이 준비되어 있는 어슬 서울이 있습니다.
#
# 서울역 회식, 연말모임, 송년회, 신년회, 데이트, 기념일 등 중요한 순간에 어슬 서울과 함께 하세요!
# 내용 더보기
#  store_id: 1059606805
#  address: 서울 중구 퇴계로 15 13층
#  blog_review: 블로그 리뷰 35
#  phone_num: 0507-1415-8725
#  business_hours: 일
# 11:30 - 23:00
# 15:00 - 17:00 브레이크타임
# 21:30 라스트오더
# 월
# 11:30 - 23:00
# 15:00 - 17:00 브레이크타임
# 21:30 라스트오더
# 화
# 11:30 - 23:00
# 15:00 - 17:00 브레이크타임
# 21:30 라스트오더
# 수
# 11:30 - 23:00
# 15:00 - 17:00 브레이크타임
# 21:30 라스트오더
# 목
# 11:30 - 23:00
# 15:00 - 17:00 브레이크타임
# 21:30 라스트오더
# 금
# 11:30 - 23:00
# 15:00 - 17:00 브레이크타임
# 21:30 라스트오더
# 토
# 11:30 - 23:00
# 15:00 - 17:00 브레이크타임
# 21:30 라스트오더
#
#  info: 하루 일과를 마친 뒤 여유로운 저녁의 시작을 알리듯 하늘에는 어스름이 내려옵니다.
# 어스름이 깔린 하늘을 보며 우리는 감상에 젖곤 합니다.
# '지나간 과거에 대한 추억 회상' '오늘 하루는 잘 보냈는지' '다가올 미래에 대한 설렘'
# 짧게 스쳐가는 어스름이 괜스레 아쉬워져 집으로 가던 발길을 돌려 누군가와 약속을 잡기도 합니다.
# 이렇듯 우리는 각자만의 '어스름'을 품고 살아갑니다.
#
# 어슬 서울은 서울에서 '어스름'을 가장 잘 경험할 수 있는 장소입니다.
#
# 서울역 뒷 편으로 넘어가는 해와 시간의 흐름에 따라 하늘에 아로새겨지는 보랏빛 그림을 감상하실 수 있습니다.
# 전통 한옥을 오마주한 공간은 멋스러운 퓨전한식과 다양하게 페어링된 전통주를 즐기며 어스름을 경험하기에 더없이 좋은 분위기를 만들어줍니다.
# 개성 넘치는 한식 요리들 하나하나에는 남다른 정성과 맛을 담았습니다.
# 한식엔 다양한 간이 있습니다. 삼삼한 간, 적당한 간, 짭쪼름한 간. 음식마다 적정히 맞춰진 간들이 각각 약주, 청주, 탁주와 잘 어울릴 것입니다.
#
# 어슬서울에서의 시간을 뒤로 하고 문을 나설 땐
# 여러분 마음 속에 또 하나의 '어스름'에 대한 생각과 추억이 새겨지셨으면 합니다.
# 펼쳐보기
#  convenience_facilities_and_services: 콜키지 가능
# 유료
# 와인 페어링
# 단체 이용 가능
# 예약
# 무선 인터넷
# 남/녀 화장실 구분
# 유아의자
# 좌석 휠체어 이용가능
# 장애인 주차구역
#
#  Parking: 주차 불가
#  sns: https://app.catchtable.co.kr/ct/shop/eoseulcheongdam_seoul
#
#  review_like_this_part_output: "음식이 맛있어요"이 키워드를 선택한 인원19
# "특별한 메뉴가 있어요"이 키워드를 선택한 인원14
# "인테리어가 멋져요"이 키워드를 선택한 인원12
# "뷰가 좋아요"이 키워드를 선택한 인원10
# "재료가 신선해요"이 키워드를 선택한 인원6
# "단체모임 하기 좋아요"이 키워드를 선택한 인원5
# "친절해요"이 키워드를 선택한 인원3
# "매장이 넓어요"이 키워드를 선택한 인원3
# "특별한 날 가기 좋아요"이 키워드를 선택한 인원3
# "술이 다양해요"이 키워드를 선택한 인원2
# "룸이 잘 되어있어요"이 키워드를 선택한 인원2
# "양이 많아요"이 키워드를 선택한 인원1
# "가성비가 좋아요"이 키워드를 선택한 인원1
# "매장이 청결해요"이 키워드를 선택한 인원1
# "대화하기 좋아요"이 키워드를 선택한 인원1
#
#  menu: 제철 회 새비체대표신선한 식감의 제철생선과 유자된장소스, 미나리오일 깻잎 튀김 등을 함께 곁들인 세비체 요리24,000원
# 돌문어 피스타치오 파스타대표통통하게 살이 오른 돌문어 다리를 부드러운 식감으로 쪄낸 뒤 통째로 올린 피스타치오 파스타27,000원
# 항정살 오일 파스타대표매콤하게 조리한 오일파스타에 엔초비버터, 명이나물 페스토, 시즈닝항정살을 함께 먹는 요리25,000원
# 마늘 수육 플레이트대표돈목살, 이베리코항정살 수육과 궁채김치, 특제마늘소스 등을 곁들여먹는 모듬 플레이트32,000원
# 칠게 강정대표바삭하게 튀겨 매콤한 칠리소스에 버무린 칠게 강정을 콩가루 마요네즈를 찍어 먹는 강정 요리19,000원
# 어슬 소갈비찜대표4시간 푹 삶아 부드럽게 조리된 갈비에 매콤한 양념 잘 베이도록 조리한 시그니처 갈비찜43,000원
# 육회 밀전병 타코어슬 갈비소스에 부드럽게 익힌 소갈비, 꽈리꼬추와 매콤한 단호박 로메스코9,000원
# 닭발 라구 편육프랑스요리인 테린을 변형한 크리미한 닭발 편육으로 직화로 구운 닭발의 풍미가 느껴지는 요리8,000원
# 연어 한 쌈레몬과 향신료에 절여 상큼한 향을 입힌 연어그라브락스에 피클과 허브로 산뜻함을 더한 쌈요리7,000원
# 새우 송화버섯전풍부한 송화향에 고기같은 식감을 가진 문경 송화버섯에 새우와 고기를 올려 함께 튀겨낸 요리7,000원
# 잣소스로 버무린 관자와 홍새우부드럽게 쪄낸 홍새우와 관자를 상큼한 제철과일과 함께 버무려 먹는 궁중요리를 재해석한 요리19,000원
# 돌산갓 부라타치즈여수 돌산갓을 이용해 만든 페스토와 오미자 드레싱을 곁들인 부라타 치즈17,000원
# 갈비덮밥어슬만의 갈비양념 이용해 만든 갈비와 단촛물로 양념한 덮밥32,000원
# 제철생선 솥밥제철생선이 들어간 솥밥에 맛간장을 비벼 먹은 후 바지락육수를 부어 숭늉으로 즐기는 식사메뉴26,000원
# 어란 바지락 파스타바지락 육수로 맛을 낸 바지락파스타에 임금님께 진상되던 귀한 어란을 얇게 썰어 곁들인 요리24,000원
# </content>
# ==================================================
#
# ==================================================
# 🔄 Node: retrieve_opendata 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# context_opendata:
# <document><content>상호명: 아이파크몰
#  콘텐츠URL: https://korean.visitseoul.net/shopping/아이파크몰/KOP001702?utm_source=seoulopendata&utm_medium=shopping&utm_content=KOP001702
#  주소: 140-780 서울 용산구 한강로3가 40-999
#  신주소: 04377 서울특별시 용산구 한강대로23길 55  (한강로3가)
#  전화번호: 02-2012-0101
#  웹사이트: https://www.hdc-iparkmall.com/main/index.do
#  운영시간: 일요일 ~ 목요일 10:30 ~ 20: 30  (금요일/토요일/공휴일 연장영업 10:30 ~ 21:00) *SPA 브랜드 22:00까지 영업
#  교통정보: 4호선 신용산역 3,4번 출구에서 150m 1호선 용산 지하철 연결 출구 </content>
# <document><content>상호명: 개미슈퍼
#  콘텐츠URL: https://korean.visitseoul.net/shopping/개미슈퍼/KOP029715?utm_source=seoulopendata&utm_medium=shopping&utm_content=KOP029715
#  주소:  서울 용산구 서계동 39
#  신주소: 04303 서울 용산구 청파로85길 31 (서계동)
#  전화번호: 02-714-3383
#  웹사이트: None
#  운영시간: 평일 09:00~01:00
#  교통정보: 1?4?공항철도?경의중앙선 서울역 15번 출구에서 약 326m (도보 5분) </content>
# <document><content>상호명: 후암서재
#  콘텐츠URL: https://korean.visitseoul.net/entertainment/후암서재/KOP039726?utm_source=seoulopendata&utm_medium=entertainment&utm_content=KOP039726
#  주소:  서울 용산구 후암동 164-31
#  신주소: 04333 서울 용산구 두텁바위로1길 69-1 (후암동)
#  전화번호: 070-4129-6552
#  웹사이트: https://www.instagram.com/huamsharedstudy/
#  운영시간: 10:00 ~ 02:00 (휴게시간 : 18:00 ~ 19:00)
#  운영요일: 매일
#  휴무일: None
#  교통정보: 4호선 숙대입구역 2번 출구에서 약 400m (도보 6분)
#  홈페이지 운영 언어: None
#  유모차 대여 여부: None</content>
# <document><content>상호명: 하얏트 아이스링크
#  콘텐츠URL: https://korean.visitseoul.net/entertainment/하얏트-아이스링크/KOP002939?utm_source=seoulopendata&utm_medium=entertainment&utm_content=KOP002939
#  주소: 140-738 서울 용산구 한남동 747-7 747-7 그랜드 하얏트 호텔
#  신주소: 04347 서울 용산구 소월로 322 (한남동, 하얏트호텔)
#  전화번호: 02-799-8113
#  웹사이트: https://seoul.grand.hyatt.com/ko/hotel/activities/hotel-activities/iceskating.html
#  운영시간: 평일 PM 12:00 ~ PM 09:00 주말?공휴일 AM 10:00 ~ PM 09:00  *2017년 2월 28일 시즌 종료
#  운영요일: None
#  휴무일: None
#  교통정보: 6호선 녹사평 1번 출구로 나와 건널목을 건너 마을버스 3번 승차
#  홈페이지 운영 언어: None
#  유모차 대여 여부: None</content>
# <document><content>상호명: 남산서울타워 한복문화 체험관
#  콘텐츠URL: https://korean.visitseoul.net/entertainment/남산서울타워-한복문화-체험관/KOP019552?utm_source=seoulopendata&utm_medium=entertainment&utm_content=KOP019552
#  주소: 140-022 서울 용산구 용산동2가 산 1-3
#  신주소: 04340 서울 용산구 남산공원길 105 (용산동2가, YTN서울타워)
#  전화번호: 02-772-9388
#  웹사이트: https://namsanhanbok.modoo.at
#  운영시간: 10:00~19:00 (입장마감 18:00)
#  운영요일: 월요일~일요일
#  휴무일: 연중무휴
#  교통정보: 01A, 01B 순환버스 남산서울타워 정류장에서 약 440m (도보 9분)
# ...
# "양이 많아요"이 키워드를 선택한 인원123
# "매장이 청결해요"이 키워드를 선택한 인원79
# "인테리어가 멋져요"이 키워드를 선택한 인원73
# "가성비가 좋아요"이 키워드를 선택한 인원43
# "특별한 날 가기 좋아요"이 키워드를 선택한 인원29
# "혼밥하기 좋아요"이 키워드를 선택한 인원14
# "화장실이 깨끗해요"이 키워드를 선택한 인원14
# "주차하기 편해요"이 키워드를 선택한 인원11
# "룸이 잘 되어있어요"이 키워드를 선택한 인원9
# "메뉴 구성이 알차요"이 키워드를 선택한 인원7
# "대화하기 좋아요"이 키워드를 선택한 인원7
# "뷰가 좋아요"이 키워드를 선택한 인원7
# "음식이 빨리 나와요"이 키워드를 선택한 인원4
# "비싼 만큼 가치있어요"이 키워드를 선택한 인원4
# "차분한 분위기에요"이 키워드를 선택한 인원2
# "술이 다양해요"이 키워드를 선택한 인원1
# "컨셉이 독특해요"이 키워드를 선택한 인원1
# "코스요리가 알차요"이 키워드를 선택한 인원1
# "아늑해요"이 키워드를 선택한 인원1
# "아이와 가기 좋아요"이 키워드를 선택한 인원1
# "고기 질이 좋아요"이 키워드를 선택한 인원1
# "사진이 잘 나와요"이 키워드를 선택한 인원1
# "반찬이 잘 나와요"이 키워드를 선택한 인원1
# "건강한 맛이에요"이 키워드를 선택한 인원1
#
#  menu: 전가복스페셜전복 요리의 최고봉. 전가복을 소개합니다.90,000원
# 어향동고일일향의 대표메뉴45,000원
# 육즙돼지고기탕수육일일향의 ㅇ육즙탕수육을 드셔보셨다면 최고의 창수육을 드셨다고 감히 말씀드립니다.32,000원
# 코스요리(매일매일)사품냉채 / 해물누룽지탕 / 어향동고 / 유린기 / 탕수육 / 식사 / 후식 (2인이상)48,000원
# 코스요리(향기향기)2인이상 주문가능합니다60,000원
# 쟁반짜장2인이상 주문 가능합니다13,000원
# 옛날볶음밥일일향이 가장 신경써서 만드는 식사메뉴 중에 하나는 옛날볶음밥입니다.10,000원
# 짜장면중식의 기본을 이야기 합니다8,000원
# 잡채볶음밥잡채와 볶음밥을 동시에 드시고 싶으신가요? 일일향의 잡채밥을 추천합니다.13,000원
# 삼선간짜장간짜장은 역시 일일향!!11,000원
# 크림중새우중새우 요리의 최고봉을 만나고 싶으시다면 일일향으로 오세요.42,000원
# 깐풍기38,000원
# 옛날짬뽕(밥)짬뽕은 역시 일일향!!11,000원
# 전가복전복요리의 최고봉은 역시 전가복입니다.90,000원
# 멘보샤 (8pcs)입안 가득 새우의 풍미를 느끼는 멘보샤 8P45,000원
# </content>
# <document><content>store_name: 행2PM8PM
#  category: 술집
#  new_open:
#  rating: 별점 4.66
#  visited_review: 방문자 리뷰 1,258
#  directions_text: 중구 수표로12길 10. 1~3층
# 루프탑까지 통건물이며 1층이 출입구입니다.
#
# 을지로3가역과 명동역, 충무로역에서 도보로 약 3분거리 오실수 있으며,
#
# 근처 세운상가, 을지로 노가리골목하고도 가까운 힙지로 메인골목에 위치해있습니다.(나인트리호텔 뒷골목)
#
# 시침이 두개이며, 두시와 여덟시를 가르키는 시계로 되어있는 간판을 찾아주세요!
# 진작과 정라진 사이 건물입니다.
#
# 근처 도보3분거리 주차장안내
# [마른내길공영주차장 무료이용시간]
# 월~금 저녁7시 이후, 토요일3시 이후, 일요일 무료
# 내용 더보기
#  store_id: 1799596430
#  address: 서울 중구 수표로12길 10 1층~3층
#  blog_review: 블로그 리뷰 6,020
#  phone_num: 0507-1331-6915
#  business_hours: 수(1/1)
# 새해 첫날15:00 - 23:00
# 목
# 15:00 - 23:00
# 금
# 15:00 - 23:00
# 토
# 13:30 - 24:00
# 일
# 13:30 - 23:00
# 월
# 15:00 - 23:00
# 화
# 15:00 - 23:00
#
#  info: 힙지로 1세대 노포 맛집인 대표 와인펍
# 너목보, 초대형노래방vs, 싱어게인 등의 40팀의 인디가수들 라이브공연이 있는 2층과
# 동남아 분위기의 3층 루프탑이 있는
# 대형 공간입니다.
#
# 힙지로 명물인 몽둥이고기,
# 이탈리아 정통 가정식스타일의 라자냐파스타 등 다양한 식사와 간편한 안주류도 준비되어있습니드.
# 술 없이 식사만도 가능합니다.(논알콜 맥주, 커피, 과일에이드도 판매)
#
# *공연시간[월~금8시, 토 7시/9시, 일 7시]
# *낮술가능 / 외부케이크 반입가능 / 와인포장시 20%할인*
# *예약없이 현장방문 가능하나, 당일예약이나 회식,생일파티,결혼식 뒤풀이 등 단체 예약은 전화로 문의주세요*
# 펼쳐보기
#  convenience_facilities_and_services: 콜키지 가능
# 유료
# 생일 혜택
# 무한 리필
# 테이크아웃 할인
# 와인 페어링
# 단체 이용 가능
# 예약
# 무선 인터넷
# 포장
# 좌석 휠체어 이용가능
#
#  Parking: 주차가능
# 무료
#  sns: http://www.instagram.com/hang_2pm8pm
# https://youtube.com/channel/UCEIcCQOq1M9VVCPkYDkuAQA
#
#  review_like_this_part_output: "음식이 맛있어요"이 키워드를 선택한 인원409
# "특별한 메뉴가 있어요"이 키워드를 선택한 인원309
# "음악이 좋아요"이 키워드를 선택한 인원262
# "술이 다양해요"이 키워드를 선택한 인원260
# "라이브공연이 훌륭해요"이 키워드를 선택한 인원244
# "인테리어가 멋져요"이 키워드를 선택한 인원240
# "친절해요"이 키워드를 선택한 인원174
# "가성비가 좋아요"이 키워드를 선택한 인원160
# "단체모임 하기 좋아요"이 키워드를 선택한 인원117
# "특별한 날 가기 좋아요"이 키워드를 선택한 인원103
# "야외공간이 멋져요"이 키워드를 선택한 인원80
# "오래 머무르기 좋아요"이 키워드를 선택한 인원80
# "대화하기 좋아요"이 키워드를 선택한 인원77
# "파티하기 좋아요"이 키워드를 선택한 인원64
# "사진이 잘 나와요"이 키워드를 선택한 인원62
# "매장이 청결해요"이 키워드를 선택한 인원50
# "기본 안주가 좋아요"이 키워드를 선택한 인원39
# "혼술하기 좋아요"이 키워드를 선택한 인원17
# "컨셉이 독특해요"이 키워드를 선택한 인원16
# "아늑해요"이 키워드를 선택한 인원10
# "음식이 빨리 나와요"이 키워드를 선택한 인원9
# "화장실이 깨끗해요"이 키워드를 선택한 인원8
# "비싼 만큼 가치있어요"이 키워드를 선택한 인원6
# "매장이 넓어요"이 키워드를 선택한 인원6
# "양이 많아요"이 키워드를 선택한 인원5
# "메뉴 구성이 알차요"이 키워드를 선택한 인원5
# "뷰가 좋아요"이 키워드를 선택한 인원5
# "좌석이 편해요"이 키워드를 선택한 인원2
# "차분한 분위기에요"이 키워드를 선택한 인원1
# "주차하기 편해요"이 키워드를 선택한 인원1
# "건강한 맛이에요"이 키워드를 선택한 인원1
#
#  menu: 몽둥이고기 [ 25cm 크기 ]대표행의 대표시그니처 메뉴인 몽둥이구이입니다. 부드러운 살코기와 쫀쫀할 다릿살,
# 팔뚝만한 크기의 몽둥이를 들고 사진을 꼭 찍어보세요.22,000원
# 미국식 버팔로윙봉&나초16,500원
# 치즈폭탄 감자튀김꾸덕한 치즈 폭탄과 시즈닝, 갓튀긴 감튀까지8,000원
# 와인1병와인1병의 29000원부터 3만원대의 와인이 다수입니다. 가성비와인들부터 포트와인,내추럴와인도 판매합니다. 을지로에서 저렴한 가격에 좋은 와인을 먹을수있는 곳이에요(글라스와인도있음29,000원
# 이탈리아정통 라자냐 파스타건강한 재료를 듬뿍 넣어 맛을낸 이탈리안 가정식 볼로네제 라자냐 파스타18,000원
# 나초 앤 치즈소스나초와 진득한 치즈를 푸짐하게 먹을수 있는 간편한 메뉴7,000원
# 버드와이저생맥무제한레드락생맥주 무제한(1인15,000원 / 일행전체주문시) 잔맥주 주문도 가능합니다(6,000원) 레드락생맥주 외, 호가든,블루문,스텔라,빅웨이브,에딩거논알콜 맥주도 판매합니다.17,000원
# 행하이볼 무제한일행전체주문 / 1시간30분 무제한 / 1인당 23,000원23,000원
# 논알콜 로제와인술을 못드셔도 두세병이 가능한, 음주운전과 상관없는 분위기 내기좋은 맛도리 논알콜 와인변동
# 버드와이저(생맥)8,000원
# 젤라또 아이스크림쫀쫀하고 꾸덕한 젤라또 아이스크림에 초코소스. 입가심으로 가볍게 먹게 딱좋은 디저트메뉴7,000원
# 2인세트(2천원할인)몽둥이고기+행플레이터무료
# 3~4인세트(3천원할인)몽둥이고기+행플레이터+라자냐파스타
# 대표메뉴 세가지를 한번에!무료
# 스모어딥마시멜로우+누텔라와 함께 구운 달달구리 디저트16,500원
# 행플레이터있는거 없는거 팍팍 넣은 한상차림 대표메뉴, 다양한종류의 치즈,하몽,크레커,올리브,견과류,과일,초콜릿 등등등등,, 그때그때 신선한 재료와 시키신 음식과 주류와 잘어울리는걸로 드려요24,500원
# </content>
# <document><content>store_name: 어슬 서울
#  category: 한식
#  new_open:
#  rating: 정보없음
#  visited_review: 방문자 리뷰 23
#  directions_text: 서울역 7번출구에서 나오셔서
# 연세대학교 세브란스빌딩이 왼쪽에 보이실거에요.
# 그대로 80m 이동하시면 왼쪽에 건물입구가 있습니다.
#
# 회현역 5번출구에서 남대문시장 입구 교차로 쪽으로 나오시면
# 우리농산물유통센터 남대문점이 있습니다.
# 오른쪽 방향으로 200m정도 이동하시면 오른쪽에 건물입구가 있습니다.
#
# 어슬 서울은
# 그랜드센트럴, 메트로타워, 서울로타워, SK텔레콤 남산사옥 건물 가운데쪽에 위치하고 있습니다.
#
# 숭례문광장에서 오실경우 도보 5분정도 소요됩니다.
#
# 13층으로 올라오시면 다양한 전통주와 다채로운 퓨전한식이 준비되어 있는 어슬 서울이 있습니다.
#
# 서울역 회식, 연말모임, 송년회, 신년회, 데이트, 기념일 등 중요한 순간에 어슬 서울과 함께 하세요!
# 내용 더보기
#  store_id: 1059606805
#  address: 서울 중구 퇴계로 15 13층
#  blog_review: 블로그 리뷰 35
#  phone_num: 0507-1415-8725
#  business_hours: 일
# 11:30 - 23:00
# 15:00 - 17:00 브레이크타임
# 21:30 라스트오더
# 월
# 11:30 - 23:00
# 15:00 - 17:00 브레이크타임
# 21:30 라스트오더
# 화
# 11:30 - 23:00
# 15:00 - 17:00 브레이크타임
# 21:30 라스트오더
# 수
# 11:30 - 23:00
# 15:00 - 17:00 브레이크타임
# 21:30 라스트오더
# 목
# 11:30 - 23:00
# 15:00 - 17:00 브레이크타임
# 21:30 라스트오더
# 금
# 11:30 - 23:00
# 15:00 - 17:00 브레이크타임
# 21:30 라스트오더
# 토
# 11:30 - 23:00
# 15:00 - 17:00 브레이크타임
# 21:30 라스트오더
#
#  info: 하루 일과를 마친 뒤 여유로운 저녁의 시작을 알리듯 하늘에는 어스름이 내려옵니다.
# 어스름이 깔린 하늘을 보며 우리는 감상에 젖곤 합니다.
# '지나간 과거에 대한 추억 회상' '오늘 하루는 잘 보냈는지' '다가올 미래에 대한 설렘'
# 짧게 스쳐가는 어스름이 괜스레 아쉬워져 집으로 가던 발길을 돌려 누군가와 약속을 잡기도 합니다.
# 이렇듯 우리는 각자만의 '어스름'을 품고 살아갑니다.
#
# 어슬 서울은 서울에서 '어스름'을 가장 잘 경험할 수 있는 장소입니다.
#
# 서울역 뒷 편으로 넘어가는 해와 시간의 흐름에 따라 하늘에 아로새겨지는 보랏빛 그림을 감상하실 수 있습니다.
# 전통 한옥을 오마주한 공간은 멋스러운 퓨전한식과 다양하게 페어링된 전통주를 즐기며 어스름을 경험하기에 더없이 좋은 분위기를 만들어줍니다.
# 개성 넘치는 한식 요리들 하나하나에는 남다른 정성과 맛을 담았습니다.
# 한식엔 다양한 간이 있습니다. 삼삼한 간, 적당한 간, 짭쪼름한 간. 음식마다 적정히 맞춰진 간들이 각각 약주, 청주, 탁주와 잘 어울릴 것입니다.
#
# 어슬서울에서의 시간을 뒤로 하고 문을 나설 땐
# 여러분 마음 속에 또 하나의 '어스름'에 대한 생각과 추억이 새겨지셨으면 합니다.
# 펼쳐보기
#  convenience_facilities_and_services: 콜키지 가능
# 유료
# 와인 페어링
# 단체 이용 가능
# 예약
# 무선 인터넷
# 남/녀 화장실 구분
# 유아의자
# 좌석 휠체어 이용가능
# 장애인 주차구역
#
#  Parking: 주차 불가
#  sns: https://app.catchtable.co.kr/ct/shop/eoseulcheongdam_seoul
#
#  review_like_this_part_output: "음식이 맛있어요"이 키워드를 선택한 인원19
# "특별한 메뉴가 있어요"이 키워드를 선택한 인원14
# "인테리어가 멋져요"이 키워드를 선택한 인원13
# "뷰가 좋아요"이 키워드를 선택한 인원11
# "재료가 신선해요"이 키워드를 선택한 인원6
# "단체모임 하기 좋아요"이 키워드를 선택한 인원5
# "친절해요"이 키워드를 선택한 인원3
# "매장이 넓어요"이 키워드를 선택한 인원3
# "특별한 날 가기 좋아요"이 키워드를 선택한 인원3
# "술이 다양해요"이 키워드를 선택한 인원2
# "룸이 잘 되어있어요"이 키워드를 선택한 인원2
# "양이 많아요"이 키워드를 선택한 인원1
# "가성비가 좋아요"이 키워드를 선택한 인원1
# "매장이 청결해요"이 키워드를 선택한 인원1
# "대화하기 좋아요"이 키워드를 선택한 인원1
#
#  menu: 제철 회 새비체대표신선한 식감의 제철생선과 유자된장소스, 미나리오일 깻잎 튀김 등을 함께 곁들인 세비체 요리24,000원
# 돌문어 피스타치오 파스타대표통통하게 살이 오른 돌문어 다리를 부드러운 식감으로 쪄낸 뒤 통째로 올린 피스타치오 파스타27,000원
# 항정살 오일 파스타대표매콤하게 조리한 오일파스타에 엔초비버터, 명이나물 페스토, 시즈닝항정살을 함께 먹는 요리25,000원
# 마늘 수육 플레이트대표돈목살, 이베리코항정살 수육과 궁채김치, 특제마늘소스 등을 곁들여먹는 모듬 플레이트32,000원
# 칠게 강정대표바삭하게 튀겨 매콤한 칠리소스에 버무린 칠게 강정을 콩가루 마요네즈를 찍어 먹는 강정 요리19,000원
# 어슬 소갈비찜대표4시간 푹 삶아 부드럽게 조리된 갈비에 매콤한 양념 잘 베이도록 조리한 시그니처 갈비찜43,000원
# 육회 밀전병 타코어슬 갈비소스에 부드럽게 익힌 소갈비, 꽈리꼬추와 매콤한 단호박 로메스코9,000원
# 닭발 라구 편육프랑스요리인 테린을 변형한 크리미한 닭발 편육으로 직화로 구운 닭발의 풍미가 느껴지는 요리8,000원
# 연어 한 쌈레몬과 향신료에 절여 상큼한 향을 입힌 연어그라브락스에 피클과 허브로 산뜻함을 더한 쌈요리7,000원
# 새우 송화버섯전풍부한 송화향에 고기같은 식감을 가진 문경 송화버섯에 새우와 고기를 올려 함께 튀겨낸 요리7,000원
# 잣소스로 버무린 관자와 홍새우부드럽게 쪄낸 홍새우와 관자를 상큼한 제철과일과 함께 버무려 먹는 궁중요리를 재해석한 요리19,000원
# 돌산갓 부라타치즈여수 돌산갓을 이용해 만든 페스토와 오미자 드레싱을 곁들인 부라타 치즈17,000원
# 갈비덮밥어슬만의 갈비양념 이용해 만든 갈비와 단촛물로 양념한 덮밥32,000원
# 제철생선 솥밥제철생선이 들어간 솥밥에 맛간장을 비벼 먹은 후 바지락육수를 부어 숭늉으로 즐기는 식사메뉴26,000원
# 어란 바지락 파스타바지락 육수로 맛을 낸 바지락파스타에 임금님께 진상되던 귀한 어란을 얇게 썰어 곁들인 요리24,000원
# </content>
# <document><content>store_name: 독립술상
#  category: 이자카야
#  new_open:
#  rating: 정보없음
#  visited_review: 방문자 리뷰 20
#  directions_text: 3호선 독립문역 2번출구에서 약 2분 아니면 편하게 에스컬레이터를 타고 편히 올라 오시려면 3-1번 출구에 에스컬레이터를 타고 올라 오셔서 길 건너면 약 2분30초 정도 걸리니 참고 하시기 바랍니다.
# 버스로는 독립문 한성과학고에 정차하시면 약5분정도 소요 됩니다.
# 혹 영천시장에 내려서 영천시장을 투어 하시고 오셔도 재미나는 추억이 되실거라 생각이 들고 독립문공원에서 잠시 독립운동가분들의 동상과 서대문 형무소를 구경 하시고 오셔서 좋은 코스라고 생각이 듭니다.찾아 오시는 길 안전하게 즐겁게 찾아와주세요~감사합니다.
# 내용 더보기
#  store_id: 1630941377
#  address: 서울 종로구 통일로14길 6-3 1층 1호
#  blog_review: 블로그 리뷰 13
#  phone_num: 0507-1390-3340
#  business_hours: 화
# 16:00 - 24:00
# 23:30 라스트오더
# 수(1/1)
# 새해 첫날 휴무
# 목
# 16:00 - 24:00
# 23:30 라스트오더
# 금
# 16:00 - 24:00
# 23:30 라스트오더
# 토
# 16:00 - 24:00
# 23:30 라스트오더
# 일(1/5)
# 정기휴무 (격주 일요일)
# 월
# 16:00 - 24:00
# 23:30 라스트오더
#
#  info: 오늘도 지친 하루, 난 퇴근이 아닌 독립을 원한다.
# 회사에서 독립!
# 육아에서 독립!
# 주방에서 독립!
# 독립하고 싶은 모든 독립군을 응원합니다. 대한! 독립술상!
# 독립문에 위치한 독립술상 몸과 마음의 독립 그리고, 안주와 술 그리고 따뜻한 분위기 에서 드실 수 있는 술 한상 술상의 의미는 여러가지를 가지고 있으나 옛 부터 술상은 친한 사람들고 모여서 더 가깝게 한 자리에서 모여 마시며 즐길 수 있는 곳 좋은 안주와 술은 속 마음도 같이 할 수 있는 진정한 사람들이 모여서 마시는 독립술상 독립문의 독립이라는 의미도 아주 크지만 저로 각자의 독립된 곳에서 마실 수 있는 맛이는 술고 안주 독립문 지하철역 3-1번 출구에서 약 3분 정도의거리 골목집이라서 아늑하게 마실 수 있는 곳 독립문 공원도 길 건너면 구경하고 때로는 걷고 산책하면서 안산 자락길과 인왕산 산책로 인왕산 등산로 가면 부암동에 청와대 까지 걸어서 갈수 있고 북악산을 등 두로 광화문과 경복궁이 한눈에 보이고 독립문역 바로 앞에 위치한 무악현대아파트와 롯데캐슬 아이파크 건너는 극동 아파트 삼호 아파드 세란병원이 가깝게 위치 조금 걸으면 영천시장이 가깝게 위치 종로와 연세대학교를 있는 곳 아래 위로는 서울역과 홍제동을 있는 중요한 위치 3면 4면이 중요한 위치로 참 살기 좋은 곳 입니다.20년을 넘게 셰프로 그리고 사업가로 음식에 대한 철저한 맛과 관념이 탄탄하게 자리잡고 있으며 음식에 대한 철학도 남다른 곳 어머니의 음식에 대한 철학을 같이 공유 아버지에 식품에 대한 철학을 공유하면서 같이 지금도 삼청동이라는 곳에서 설렁탕이라는 매장을 같이 운영하면서 저녁에 맛있는 안주를 만들어 고객님께 대접 하고픈 마음이 커 다시 한번 도전하게 됐습니다.정도 만들고 웃음도 만들고 픈 마음 한국식의 이자카야 일본식의 이자카야 같이 어울르는 생각과 철학 일본의 심야식당이 있으면 한국에도 심야식당을 만들고 싶어하는 주인장의 마음 한국과 일본을 어울르는 음식 독립술상 입니다.늘 고객님들의 마음을 이해하며 찾아 오시는 발걸음 정말이지 행복하게 찾아와 주셨으면 합니다.
# 조심히 안전하게 찾아 오시길 바라면서 항상 건강하고 행복하게 즐겁게 사시는 하루 하루가 되시길 바랍니다.감사합니다.사랑합니다.
# 참고.무악현대아파트 봄이 오면 벚꽃이 아주 이쁘게 만개 합니다.다른 먼데서 벚꽃 구경 하기 어려우신분들 여기 독립문 무악현대아파트에서 벚꽃 구경 하시고 독립술상에서 맛있는 안주와 술 마시고 가시는 것도 아주 좋은 데이트코스가 될 것 같습니다.
# 가깝게는 서대문형무소 옛 독립운동가 분들이 역사도 보고 배울수 있다는게 독립문공원의 장점이라고 생각해 데이트와 아이들 교육현장으로도 좋은 곳 이라 생각하고 있습니다.많이들 찾아와주시고 방문 부탁드립니다.감사합니다.
# 독립술상 의 주안상 (상차림)
# 스지조림 35,000원
# 무청김치 스지탕 30,000원
# 스지탕 27,000원
# 쭈도리볶음탕 30,000원
# 알고니탕 25,000원
# 우삼겹두부조림탕 20,000원
# 조개탕 18,000원
# 채끝버터구이 28,000원
# 우삼겹 숙주볶음 21,000원
# 물총 오징어 볶음 21,000원
# 해물볶음우동 20,000원
# 딸로 골배이 20,000원
# 제육 오돌뼈 23,000원
# 통통계란말이 15,000원
# 사이드 메뉴
# 독립라면 10,000원
# 술상라면10,000원
# 치킨튤립가라아게 19,000원
# 킬바사 감자튀김 17,000원
# 오징어,문어가라아게 15,000원
# 가문어 통족 버터구이 15,000원
# 쥐포&아귀포 14,000원
#
# 다양한 메뉴의 요리주점 입니다.
# 몇개의 신메뉴를 넣을 생각이면 주종도 사케와 막걸리 등을 추가를 할 것 입니다.
# 시그니처로 스지탕을 선 보이고 있지만 복미찜을 안주로 추가해 더 고급진 안주의 독립술상이 되도록 노력하겠습니다.
#
# 서울 종로구 통일로 14길 6-3 1층 1호 독립술상
# 02-3210-3338
# 0507-1390-3340
# MZ세대가 네이버 클로바X 에서 독립문 맛집 독립문 술집 독립문역근처맛집 이자카야 요리주점 독립문모임 검색시 강력추천 하는 맛집입니다.시그니처 스지탕 복미찜 닭볶음탕 스지조림도 강력추천 하는 요리맛집 독립술상입니다
# 펼쳐보기
#  convenience_facilities_and_services: 콜키지 가능
# 유료
# 단체 이용 가능
# 남/녀 화장실 구분
# 예약
# \
# 반려동물 동반
# 포장
# 무선 인터넷
#
#  Parking: 주차가능
# 무료
#  sns: https://blog.naver.com/eunsul_foodie
# https://www.facebook.com/lee.jaehyun3154
# https://www.instagram.com/eunsul_foodie
# https://www.youtube.com/@eunsul_foodie
#
#  review_like_this_part_output: "음식이 맛있어요"이 키워드를 선택한 인원18
# "특별한 메뉴가 있어요"이 키워드를 선택한 인원13
# "친절해요"이 키워드를 선택한 인원7
# "대화하기 좋아요"이 키워드를 선택한 인원7
# "인테리어가 멋져요"이 키워드를 선택한 인원5
# "음악이 좋아요"이 키워드를 선택한 인원5
# "가성비가 좋아요"이 키워드를 선택한 인원5
# "매장이 청결해요"이 키워드를 선택한 인원5
# "술이 다양해요"이 키워드를 선택한 인원4
# "아늑해요"이 키워드를 선택한 인원4
# "기본 안주가 좋아요"이 키워드를 선택한 인원4
# "혼술하기 좋아요"이 키워드를 선택한 인원3
# "재료가 신선해요"이 키워드를 선택한 인원3
# "메뉴 구성이 알차요"이 키워드를 선택한 인원3
# "단체모임 하기 좋아요"이 키워드를 선택한 인원3
# "화장실이 깨끗해요"이 키워드를 선택한 인원2
# "음식이 빨리 나와요"이 키워드를 선택한 인원1
# "사진이 잘 나와요"이 키워드를 선택한 인원1
# "오래 머무르기 좋아요"이 키워드를 선택한 인원1
#
#  menu: 스도리탕대표떡도리탕의 시그니처 보다 더 시그니처인 스도리탕 독립술상이 유일하게 만든 메뉴40,000원
# 떡도리탕대표떡도리탕 닭순살과 긴 밀떡이 최상의 안주맛 시그니처 메뉴35,000원
# 스지조림 (스조)대표스지를 간장과 설탕 특제소스로 조려서 먹는 시그니처 메뉴35,000원
# 불스지조림대표간장스지조림의 기본 베이스로 아주아주 매콤한 양념이 추가로 들어간 불 스지조림35,000원
# 스지탕대표삼청동 은설설렁탕의 비법 한우암소의 육수와 스지 떡심이 들어간 진국의 맛있는 스지탕29,000원
# 한돈제육볶음대표독립술상만의 특제 양념 소스로 만든 한돈제육볶음 집에서 먹던 제육을 맛있는 안주28,000원
# 콜키지20,000원
# 물총 오징어 볶음동죽조개와 오징어를 매운 다데기양념에 볶아낸 안주28,000원
# 쭈꾸미볶음매콤한 쭈꾸미 볶음27,000원
# 순대야채볶음얼큰한 맛에 순대와 야채 옛 신림동 보다 더 맛있는 순대볶음 안주25,000원
# 우삼겹 두부조림우삼겹과 구운두부를 독립술상의 양념의로 만든 두부조림 마지막에 무조림까지 드시면 환상의 맛27,000원
# 매콤 국물닭발소주 안주의 매콤 국물닭발 숙주와 오뎅이 들어가 더 안주의 품격을 올린 안주25,000원
# 따로 골뱅이기존의 무침골뱅이와는 다른 신선한맛을 내는 골뱅이 입안에서 신선함이 확 느껴집니다.25,000원
# 우삼겹숙주볶음술집의 기본안주로 생각이 들 정도인 우삼겹숙주볶음 독립술상에서 제대로 만든 우삼겹숙주볶음24,000원
# 맑은 조개탕바다의 향이 그대로 알이 굵은 백생합으로 만들고 마늘과 청양고추 소금으로 만 간을 해 시원23,000원
# </content>
# <document><content>store_name: 미도갈비
#  category: 육류,고기요리
#  new_open:
#  rating: 별점 4.74
#  visited_review: 방문자 리뷰 7,414
#  directions_text: 지하철 : 종각역 12번출구로 나오신후 에스컬레이터 뒷편 젊음의거리 입구에서 청계천방뱡 직진 왼쪽 CU편의점 골목입니다
#
# < 주차장안내 >
# 1.삼일빌딩 타워주차장
# 네비에서 종로구 청계천로 85 로 검색해주세요
# TEL : 02 6925 2424
# 평일 10시 / 주말 7시마감 기계식 발렛주차(직접주차시 발렛비없음)
# 기본요금 30분 3천원
# 추가요금10분당 천원
# 대형SUV 주차불가
#
# 2.미래에셋 센터원 주차장
# TEL : 02 6030 0100
# 네비에서 서울 중구 수하동 67 로 검색해주세요
# 연중무휴 / 24시간영업
# 기본요금 30분 3천원
# 추가요금10분당 천원
# 모두의주차장 어플설치후 휴일 당일권은 8천원으로 구매가능합니다
#
# 전용주차장이 없어서 근처 쾌적한 유료주차장으로 안내해드리는점 양해부탁드립니다,감사합니다
# 내용 더보기
#  store_id: 1264295690
#  address: 서울 종로구 삼일대로15길 25 1층
#  blog_review: 블로그 리뷰 2,792
#  phone_num: nan
#  business_hours: 수(1/1)
# 12:30 - 21:30
# 목
# 11:00 - 22:00
# 20:50 라스트오더
# 금
# 11:00 - 22:00
# 20:50 라스트오더
# 토
# 11:00 - 22:00
# 20:50 라스트오더
# 일
# 11:00 - 22:00
# 20:50 라스트오더
# 월
# 11:00 - 22:00
# 20:50 라스트오더
# 화
# 11:00 - 22:00
# 20:50 라스트오더
#
#  info: 안녕하세요 미도갈비 입니다.
#
# 1. 입장시간 지연(15분) 및 인원변동 변동시 꼭 전화 부탁드립니다.
# 미통보시 혼선이 발생할수 있으며 미통보로 인한 혼선은 발생시 양해부탁드립니다. 최대한 빨리 조치 취하겠습니다.
#
# 2. 네이버로 예약하신 고객분들도 잠깐의 웨이팅이 발생할수 있습니다.
#
# 3. 예약이 많은 관계로 부득이하게 이용시간이 한정될 수 있습니다.(네이버 확정문자 통보시 표시되어 있습니다.꼭 확인부탁드립니다.)
#
# 4. 예약 후 15분이내에 미 입장시 예약은 취소 되실수 있으며 새로운 순번으로 대기하셔야 됩니다.
#
# 5. 단체예약 문의는 매장으로 전화부탁드립니다.
#
# 매장 직통번호 010-9741-9233
#
# **고기주문시 냉면 무료서비스
# **디저트 과일 무한 제공
# **콜키지는 테이블당 1병무료,두번째병부터 5000원 추가입니다
#
# < 주차장안내 >
# 1.삼일빌딩 타워주차장
# 네비에서 종로구 청계천로 85 로 검색해주세요
# TEL : 02 6925 2424
# 평일 10시 / 주말 7시마감 기계식 발렛주차(직접주차시 발렛비없음)
# 기본요금 30분 3천원
# 추가요금10분당 천원
# 대형SUV 주차불가
#
# 2.미래에셋 센터원 주차장
# TEL : 02 6030 0100
# 네비에서 서울 중구 수하동 67 로 검색해주세요
# 연중무휴 / 24시간영업
# 기본요금 30분 3천원
# 추가요금10분당 천원
# 모두의주차장 어플설치후 휴일 당일권은 8천원으로 구매가능합니다
#
# 전용주차장이 없어서 미도갈비 근처 쾌적한 유료주차장으로 안내해드리는점 양해부탁드립니다,감사합니다
# 펼쳐보기
#  convenience_facilities_and_services: 콜키지 가능
# 무료
# 테이크아웃 할인
# 예약
# 단체 이용 가능
# 남/녀 화장실 구분
# 무선 인터넷
# 포장
# 유아의자
#
#  Parking: 주차가능
# 유료
# 최초 30분 3000원
# 추가 요금 10분당 1,000원, 최대 30,000원
#  sns: https://www.youtube.com/watch?v=IyidpeOR-UM
# https://blog.naver.com/75yongho
#
#  review_like_this_part_output: "음식이 맛있어요"이 키워드를 선택한 인원5064
# "친절해요"이 키워드를 선택한 인원2826
# "고기 질이 좋아요"이 키워드를 선택한 인원2664
# "직접 잘 구워줘요"이 키워드를 선택한 인원1605
# "단체모임 하기 좋아요"이 키워드를 선택한 인원1528
# "매장이 넓어요"이 키워드를 선택한 인원1434
# "매장이 청결해요"이 키워드를 선택한 인원1120
# "가성비가 좋아요"이 키워드를 선택한 인원1044
# "양이 많아요"이 키워드를 선택한 인원886
# "특별한 메뉴가 있어요"이 키워드를 선택한 인원776
# "재료가 신선해요"이 키워드를 선택한 인원675
# "인테리어가 멋져요"이 키워드를 선택한 인원655
# "특별한 날 가기 좋아요"이 키워드를 선택한 인원317
# "화장실이 깨끗해요"이 키워드를 선택한 인원224
# "혼밥하기 좋아요"이 키워드를 선택한 인원109
# "메뉴 구성이 알차요"이 키워드를 선택한 인원94
# "주차하기 편해요"이 키워드를 선택한 인원86
# "잡내가 적어요"이 키워드를 선택한 인원83
# "반찬이 잘 나와요"이 키워드를 선택한 인원80
# "음식이 빨리 나와요"이 키워드를 선택한 인원77
# "뷰가 좋아요"이 키워드를 선택한 인원72
# "아늑해요"이 키워드를 선택한 인원55
# "건강한 맛이에요"이 키워드를 선택한 인원33
# "비싼 만큼 가치있어요"이 키워드를 선택한 인원27
# "차분한 분위기에요"이 키워드를 선택한 인원22
# "좌석이 편해요"이 키워드를 선택한 인원16
# "룸이 잘 되어있어요"이 키워드를 선택한 인원9
# "아이와 가기 좋아요"이 키워드를 선택한 인원7
# "환기가 잘 돼요"이 키워드를 선택한 인원6
# "컨셉이 독특해요"이 키워드를 선택한 인원5
# "코스요리가 알차요"이 키워드를 선택한 인원4
# "야외공간이 멋져요"이 키워드를 선택한 인원2
# "오래 머무르기 좋아요"이 키워드를 선택한 인원2
# "기본 안주가 좋아요"이 키워드를 선택한 인원1
#
#  menu: 명품 LA갈비(200g)대표미도갈비만의 특제비법 간장소스로 숙성하여 본연의 육즙이 살아있는 시그니처 메뉴입니다22,000원
# 호주산 와규모듬(3~4인)500g대표뛰어난 마블링과 부드러운맛이 일품인 생등심,살치살,갈비살을 한번에 맛보실수 있습니다119,000원
# 호주산 와규모듬(2인)250g대표뛰어난 마블링과 부드러운 맛이 일품인 호주와규!
# 할인된 가격으로 생등심, 살치살, 갈비살을 한번에 맛보실 수 있습니다!!!69,000원
# 한돈수제돼지갈비맛(200g)대표육질좋은 한돈목살과 갈비에 미도갈비 특제양념을 더한 자꾸만 손이가는 특별한 돼지갈비맛입니다21,000원
# 한돈 매운돼지갈비맛(200g)대표특별한 매운맛을 위해 육질좋은 한돈목살에 미도갈비 특제양념을 입힌 불향가득한 매운돼지갈비맛22,000원
# 명품LA매콤소갈비(200g)미도갈비만의 특제비법 소스로 감칠맛나게 숙성하여 본연의 육즙이 살아있는 메뉴입니다24,000원
# 스페셜 와규모듬(3~4인)500g뛰어난 마블링과 최고등급 생등심,살치살,갈비살,진꽃을살을 한번에 맛보실수 있습니다169,000원
# 스페셜 와규모듬(2인)250g뛰어난 마블링과 부드러운맛의 최고등급 생등심,갈비살,진꽃을살을 한번에 맛보실수 있습니다119,000원
# 일품해물라면9,000원
# 와규육회(150g)23,000원
# 하이볼맛과 시선으로 사로잡는 미도갈비만의 시그니처 하이볼 3종 입니다8,500~9,500원
# 와규 생등심(150g)36,000원
# 와규 살치살(100g)28,000원
# 와규 갈비살(120g)28,000원
# 와규 스페셜 진꽃살 100g43,000원
# </content>
# ==================================================
#
# ==================================================
# 🔄 Node: llm_Summary_gangnam 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# answer_llm_Summary_gangnam:
# none
# ==================================================
#
# ==================================================
# 🔄 Node: llm_Summary_Junggu 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# answer_llm_Summary_junggu:
# none
# ==================================================
#
# ==================================================
# 🔄 Node: llm_Summary_jongro 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# answer_llm_Summary_jongro:
# none
# ==================================================

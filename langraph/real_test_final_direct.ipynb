# %%
# API 키를 환경변수로 관리하기 위한 설정 파일
from dotenv import load_dotenv

# API 키 정보 로드
load_dotenv()
# Out:
# True

# %%
# LangSmith 추적을 설정합니다. https://smith.langchain.com
# !pip install -qU langchain-teddynote
# from langchain_teddynote import logging

# # 프로젝트 이름을 입력합니다.
# logging.langsmith("practice")

# %%
from langchain.chat_models import ChatOpenAI
from langchain.callbacks.base import BaseCallbackHandler
from langchain.callbacks.manager import CallbackManager

class NaturalTextStreamCallbackHandler(BaseCallbackHandler):
    """
    - 새 토큰이 들어올 때마다, 토큰을 그대로 이어붙여 출력.
    - 첫 토큰에 대해서만 왼쪽 공백 제거(lstrip) 처리를 해서 앞부분이 깔끔하게 보이도록 함.
    """
    def __init__(self):
        super().__init__()
        self.first_token = True

    def on_llm_new_token(self, token: str, **kwargs) -> None:
        # 첫 번째 토큰인 경우, 왼쪽 공백 제거
        if self.first_token:
            token = token.lstrip()
            self.first_token = False
        
        # 이어서 출력 (print의 기본 end='\n'을 없애고, 공백 없이 붙이기)
        print(token, end="", flush=True)

# %%
from langchain.vectorstores import FAISS
from langchain.embeddings import OpenAIEmbeddings

# Step 1: FAISS 인덱스 파일 로드
faiss_index_path = "Faiss/naver_map_gangnam_faiss_"  # 저장된 Faiss 파일 경로
embeddings = OpenAIEmbeddings()  # 임베딩 객체 초기화

# 저장된 FAISS 인덱스를 불러와서 Retriever 생성
retriever_naver_gangnam = FAISS.load_local(faiss_index_path, embeddings,allow_dangerous_deserialization=True).as_retriever()

# 검색 매개변수 설정 (예: 검색 결과 상위 10개 반환)
retriever_naver_gangnam.search_kwargs = {"k": 50}
# Out:
# /var/folders/_v/g1qmsq595kq_fg_zv8n2022h0000gn/T/ipykernel_41484/1335236004.py:6: LangChainDeprecationWarning: The class `OpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import OpenAIEmbeddings``.
#   embeddings = OpenAIEmbeddings()  # 임베딩 객체 초기화

# %%
# Step 1: FAISS 인덱스 파일 로드
faiss_index_path = "Faiss/naver_map_jongro_faiss_"  # 저장된 Faiss 파일 경로
embeddings = OpenAIEmbeddings()  # 임베딩 객체 초기화

# 저장된 FAISS 인덱스를 불러와서 Retriever 생성
retriever_naver_jongro = FAISS.load_local(faiss_index_path, embeddings,allow_dangerous_deserialization=True).as_retriever()

# 검색 매개변수 설정 (예: 검색 결과 상위 10개 반환)
retriever_naver_jongro.search_kwargs = {"k": 50}

# %%
# Step 1: FAISS 인덱스 파일 로드
faiss_index_path = "Faiss/naver_map_Junggu_faiss_"  # 저장된 Faiss 파일 경로
embeddings = OpenAIEmbeddings()  # 임베딩 객체 초기화

# 저장된 FAISS 인덱스를 불러와서 Retriever 생성
retriever_naver_Junggu = FAISS.load_local(faiss_index_path, embeddings,allow_dangerous_deserialization=True).as_retriever()

# 검색 매개변수 설정 (예: 검색 결과 상위 10개 반환)
retriever_naver_Junggu.search_kwargs = {"k": 50}

# %%
# Step 1: FAISS 인덱스 파일 로드
faiss_index_path = "Faiss/naver_map_yongsan_faiss_"  # 저장된 Faiss 파일 경로
embeddings = OpenAIEmbeddings()  # 임베딩 객체 초기화

# 저장된 FAISS 인덱스를 불러와서 Retriever 생성
retriever_naver_yongsan = FAISS.load_local(faiss_index_path, embeddings,allow_dangerous_deserialization=True).as_retriever()

# 검색 매개변수 설정 (예: 검색 결과 상위 10개 반환)
retriever_naver_yongsan.search_kwargs = {"k": 50}

# %%
# Step 1: FAISS 인덱스 파일 로드
faiss_index_path = "Faiss/opendata_gangnam_all"  # 저장된 Faiss 파일 경로
embeddings = OpenAIEmbeddings()  # 임베딩 객체 초기화

# 저장된 FAISS 인덱스를 불러와서 Retriever 생성
retriever_opendata_gangnam = FAISS.load_local(faiss_index_path, embeddings,allow_dangerous_deserialization=True).as_retriever()

# 검색 매개변수 설정 (예: 검색 결과 상위 10개 반환)
retriever_opendata_gangnam.search_kwargs = {"k": 50}

# %%
# Step 1: FAISS 인덱스 파일 로드
faiss_index_path = "Faiss/opendata_jongro_all"  # 저장된 Faiss 파일 경로
embeddings = OpenAIEmbeddings()  # 임베딩 객체 초기화

# 저장된 FAISS 인덱스를 불러와서 Retriever 생성
retriever_opendata_jongro = FAISS.load_local(faiss_index_path, embeddings,allow_dangerous_deserialization=True).as_retriever()

# 검색 매개변수 설정 (예: 검색 결과 상위 10개 반환)
retriever_opendata_jongro.search_kwargs = {"k": 50}

# %%
# Step 1: FAISS 인덱스 파일 로드
faiss_index_path = "Faiss/opendata_junggu_all"  # 저장된 Faiss 파일 경로
embeddings = OpenAIEmbeddings()  # 임베딩 객체 초기화

# 저장된 FAISS 인덱스를 불러와서 Retriever 생성
retriever_opendata_junggu = FAISS.load_local(faiss_index_path, embeddings,allow_dangerous_deserialization=True).as_retriever()

# 검색 매개변수 설정 (예: 검색 결과 상위 10개 반환)
retriever_opendata_junggu.search_kwargs = {"k": 50}

# %%
# Step 1: FAISS 인덱스 파일 로드
faiss_index_path = "Faiss/opendata_yongsan_all"  # 저장된 Faiss 파일 경로
embeddings = OpenAIEmbeddings()  # 임베딩 객체 초기화

# 저장된 FAISS 인덱스를 불러와서 Retriever 생성
retriever_opendata_yongsan = FAISS.load_local(faiss_index_path, embeddings,allow_dangerous_deserialization=True).as_retriever()

# 검색 매개변수 설정 (예: 검색 결과 상위 10개 반환)
retriever_opendata_yongsan.search_kwargs = {"k": 50}

# %%
from typing import Annotated, TypedDict, List
from langgraph.graph.message import add_messages


# GraphState 상태 정의
class GraphState(TypedDict):
    question: Annotated[List[str], add_messages]  # 질문(누적되는 list)
    context_naver_gangnam: Annotated[List, "context_naver_gangnam"]  # 문서의 검색 결과
    context_naver_jongro: Annotated[List, "context_naver_jongro"]  # 문서의 검색 결과
    context_naver_Junggu: Annotated[List, "context_naver_Junggu"]  # 문서의 검색 결과
    context_naver_yongsan: Annotated[List, "context_naver_yongsan"]  # 문서의 검색 결과
    context_opendata: Annotated[List, "context_opendata"]  # 문서의 검색 결과
    answer: Annotated[str, "Answer"]  # 답변
    messages: Annotated[list, add_messages]  # 메시지(누적되는 list)
    webOrRetriever: Annotated[str, "webOrRetriever"]  # 웹 or 리트리버 검색
    ScheduleOrplace: Annotated[str, "ScheduleOrplace"]  # 일정 or 장소
    location: Annotated[str, "location"]  # 지역 리스트
    dayCheck: Annotated[str, "dayCheck"]  # 지역 리스트

# %%
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from operator import itemgetter
# 프롬프트
prompt = PromptTemplate(
    template="""
    너는 여러 장소들의 정보를 받게될거야.
    여러 장소들의 구분은 <content> </content> 태그로 구분 되어 있어
    이 장소들을 바탕으로 일정을 만들어줘.
    Create a travel itinerary bot that generates schedules based on user questions. The schedule should be divided into morning, lunch, and evening plans for each travel day, and for each time of day, recommend a restaurant and tourist attractions or streets.

Extract key details from the user's questions to create a travel itinerary. Identify dates, times, and activities, then structure a plan with specific restaurant and sightseeing recommendations for morning, lunch, and evening.

#유의사항

- 일차가 1 일차면 아침일정을 추천하지마. 일차가 1 이 아니면 아침 일정을 만들어줘.
- 추천했던 장소를 한번더 추천하지마.
- 아침, 점심, 저녁 이동 경로가 가까워야돼
- {day}일차의 하루의 일정만 생성해줘.
- 질문에 여러일차를 추천해 달라고 해도 '일차' 에있는 하루의 일정만 생성해
- 일정을 만들고 마무리 멘트는 넣지마.

# Steps

1. **Request Analysis**: Carefully analyze the user's input to understand the itinerary requirements, including any specified food or sightseeing preferences.
2. **Confirm Details**: Verify dates, times, locations, activity preferences, and any specific requests for restaurants or attractions.
3. **Create Itinerary**: Using confirmed details, write a structured schedule detailing morning, lunch, and evening sections for each day, recommending one restaurant and tourist attraction or street for each time slot.

# Output Format

- Provide a detailed itinerary in a bullet-point list or table format, itemizing each day's morning, lunch, and evening plans.

# Examples

**Input**: "용산구에 1박2일 방문 할 예정이야. 일정을 생성 해줄 수 있어?"

**Schedule**:
- {day}일차

  - 점심: 점심 식사 장소: [점심 식사 장소] [음식점 주소] [영업 시간] [음식점 특징] [기타 정보] ,
         명소: [관광할 명소 또는 거리] [영업 시간] [명소 특징] [명소 위치] [기타 정보]
         카페 : [카페 주소] [영업 시간] [카페 정보] [카페 특징] 
  - 저녁: 저녁 식사 장소: [저녁 식사 장소] [음식점 주소] [음식점 특징] [기타 정보], 명소: [관광할 명소 또는 거리] [명소 특징] [명소 위치] [기타 정보]
        쇼핑몰 : [쇼핑몰 주소] [쇼핑몰 특징]
        숙소 : [숙소 위치] [숙소 정보] [숙소 특징] *숙소 정보 없으면 출력 하지 않기


# Notes

- Ensure that all parts of the itinerary are complete and relevant to the user's request.
- Attempt to clarify any ambiguous details related to time, location, or activity preferences.
- Include clear recommendations for restaurants and tourist attractions for each part of the day.
- 이전에 추천했던 장소는 넣지 말아줘
#답변언어 : 한국어

    # 장소 정보 : {context}

    # 사용자의 질문 : {question}
    
    # 이전 대화 내용 : {chat_history} 

    # 일차 : {day}
    """,
        input_variables=["context", "question","chat_history","day"],
    )

# LLM

# callback_manager = CallbackManager([NaturalTextStreamCallbackHandler()])

chat = ChatOpenAI(
    model_name="gpt-4o",
    temperature=0,
    streaming=True,
    # callback_manager=callback_manager
)

model = ChatOpenAI(model_name="gpt-4o",
                    temperature=0, 
                    streaming=True,
                    # callback_manager=callback_manager,
                    )

chain = (

     prompt
    | model
    | StrOutputParser()
)

# %%
prompt_place_search = PromptTemplate(
    template="""
    너는 여러 장소들의 정보를 받게될거야.
    여러 장소들의 구분은 <content> </content> 태그로 구분 되어 있어.
    너는 입력받은 장소 정보를 정리하여 사용자의 질문에 맞는 정보를 출력해 주는 봇이야.
    장소의 정보를 잘 요약해서 출력해줘.
    장소를 출력할때 각 장소의 어떤 점이 좋은지도 간단하게 요약해서 알려줘.

  

    # 장소 정보: {context}

    #사용자의 질문: {question}
    
    #이전 대화 내용 {chat_history} 
    """,
        input_variables=["context", "question","chat_history"],
    )

# LLM
model_place_search = ChatOpenAI(model_name="gpt-4o",
                    temperature=0, streaming=True)

chain_place_search = (
    # {
    #     "question": itemgetter("question"),
    #     # "context_web": itemgetter("context_web"),
    #     "context": itemgetter("context"),
    #     "chat_history": itemgetter("chat_history"),
    # }
     prompt_place_search
    | model_place_search
    | StrOutputParser()
)

# %%
prompt_day = PromptTemplate(
    template="""

    너는 사용자의 질문을 보고 의도를 파악해서 사용자가 몇일의 여행을 가는지 알아내야돼.
    몇일을 가는지 알게되면 그 결과를 숫자로 반환해.
    

    # Examples 1

    **Input**: "용산구에 1박2일 방문 할 예정이야. 일정을 생성 해줄 수 있어?"

    **answer**: 2


    # Examples 2

    **Input**: "서울시에 5박6일 방문 할 예정이야. 일정을 생성 해줄 수 있어?"

    **answer**: 6


    # Examples 3

    **Input**: "종로구에 여행을 가려고해 9일동안 머물건데 일정을 만들어줘"

    **answer**: 9
    


    #사용자의 질문: {question}

    """,
        input_variables=["question"],
    )

model_day = ChatOpenAI(model_name="gpt-4o-mini",
                    temperature=0, streaming=False)

chain_day = (
    {
        "question": itemgetter("question"),
    }
    | prompt_day
    | model_day
    | StrOutputParser()
)

# %%
prompt_keyword = PromptTemplate(
    template="""
        사용자의 질문에서 중요 키워드를 추출하는 작업을 수행하세요.

        # Steps

        1. **질문 분석**: 사용자가 입력한 질문을 주의 깊게 읽고 분석합니다.
        2. **중요 키워드 식별**: 질문의 핵심 내용을 파악하고, 문장에서 중요한 의미를 지닌 단어, 구문, 또는 개념을 식별합니다.
        3. **키워드 추출**: 식별한 중요한 요소들을 키워드로 추출합니다.

        # Output Format

        - 추출된 중요 키워드를 콤마(,)로 구분한 리스트로 제공합니다.

        # Examples

        **Input**: "자동차 산업의 현재 트렌드와 미래 전망은 무엇인가요?"

        **Keywords**: "자동차 산업, 현재 트렌드, 미래 전망"

        **Input**: "Python을 사용한 머신러닝 알고리즘 구현 방법은?"

        #사용자의 질문 : {question}
    """,
        input_variables=["question"],
    )

model_keyword = ChatOpenAI(model_name="gpt-4o-mini",
                    temperature=0, streaming=False)

chain_keyword = (
    {
        "question": itemgetter("question"),
    }
    | prompt_keyword
    | model_keyword
    | StrOutputParser()
)

# %%
prompt_location = PromptTemplate(
    template="""너는 질문에 대해서 list를 반환해야돼.
    list에 들어갈 수 있는 str은 '용산구', '강남구', '중구', '종로구' 네가지가 있어.
    사용자가 질문을 하면 문장을 잘 보고 문장속의 지역을 추출해서 리스트에 넣어줘.
    만약 사용자의 질문에 '서울'을 방문 한다고 하면 리스트에 '용산구', '강남구', '중구', '종로구' 를 모두 넣어줘.
    사용자의 질문에 서울시가 아닌 다른지역을 물어보거나, 서울시에서도 '용산구', '강남구', '중구', '종로구'가 아닌 다른 지역을 물어보면 빈 리스트를 반환해.


    #입력 예시 : 1. 나는 서울시의 용산구를 방문 할거야 여행 계획을 세워 줄수 있어?, 
               2. 나는 종로구와 중구 일대를 방문하고 싶어 을지로는 꼭 가보고 싶은데 을지로 계획을 포함해서 여행 일정을 만들어 줄 수 있어?

    #대답 형식 예시 : ['종로구','강남구']


    #####
    입력 예시 1 : 나는 전라남도 여행을 계획중이야. 일정을 만들어 줄 수 있어?  
    답변 예시 1 : []

    #####

    #####
    입력 예시 2 : 나는 용산구와 종로구, 중구 일대를 관광하고 싶어 좋은 카페를 알고 싶은데 알려줄 수 있어?  
    답변 예시 2 : ['용산구','중구','종로구']

    #####

    #####
    입력 예시 3: 나는 서울시를 관광하고 싶어 1박2일 정도 방문하려고 하는데 일정을 만들어 줄 수 있어?
    답변 예시 3: ['용산구','중구','종로구','강남구']
    
    #####

    #####
    입력 예시 4 : 종로구에서 맛있는 고기집을 찾고 있어. 찾아줘
    답변 예시 4: ['종로구']

    #####


    #사용자의 질문: {question}

    """,
        input_variables=["question"],
    )

model_location = ChatOpenAI(model_name="gpt-4o-mini",
                    temperature=0, streaming=False)

chain_location = (
    {
        "question": itemgetter("question"),
    }
    | prompt_location
    | model_location
    | StrOutputParser()
)

# %%
prompt_sch_or_placeSearch = PromptTemplate(
    template="""너는 질문에 대해서 두가지의 옵션으로 대답하는 봇이야.
    너의 대답은 '일정', '장소검색' 두가지로만 대답할 수 있어.
    사용자가 질문을 하면 문맥을 잘 살펴서 사용자가 여행일정을 만들어 달라고 하면 '일정' 이라고 대답해야돼.
    그렇지 않으면 '장소검색' 를 출력해줘.

    #'일정' 출력 예시 : 1. 나는 서울시의 용산구를 방문 할거야 여행 계획을 세워 줄수 있어?, 2. 나는 종로구와 중구 일대를 방문하고 싶어 을지로는 꼭 가보고 싶은데 을지로 계획을 포함해서 여행 일정을 만들어 줄 수 있어?

    #대답 형식 : '일정' or '장소검색'

    #사용자의 질문: {question}
    

    """,
        input_variables=["question"],
    )

model_sch_or_placeSearch = ChatOpenAI(model_name="gpt-4o-mini",
                    temperature=0, streaming=False)

chain_sch_or_placeSearch = (
    {
        "question": itemgetter("question"),
    }
    | prompt_sch_or_placeSearch
    | model_sch_or_placeSearch
    | StrOutputParser()
)

# %%
prompt_Web_or_retriever = PromptTemplate(
    template=""" 너는 사용자의 질문에 대해서 두가지의 옵션으로 대답하는 봇이야.
    너의 대답은 'web', 'retriever' 두가지로만 대답할 수 있어.
    사용자가 질문을 하면 문맥을 잘 살펴서 웹에서 정보를 검색하기를 원하면 'web' 이라고 대답해야돼.
    그렇지 않으면 'retriever' 를 출력해줘. 

    #대답 형식 : 'web' or 'retriever'

    #사용자의 질문: {question}
    

    """,
        input_variables=["question"],
    )
model_web_check = ChatOpenAI(model_name="gpt-4o-mini",
                    temperature=0, streaming=False)

chain_Web_or_retriever = (
    {
        "question": itemgetter("question"),
    }
    | prompt_Web_or_retriever
    | model_web_check
    | StrOutputParser()
)

# %%
prompt_web = PromptTemplate(
    template="""너는 웹 검색을 통한 {context_web}의 내용를 종합해서 서울시의 중구,종로구,용산구,강남구 관광 일정을 추천해주는 봇이야.
    사용자의 질문에 따라서 여러가지 서울의 관광지, 식당, 숙소, 쇼핑몰 등을 추천해야해.
    처음에 사용자가 서울에 며칠동안 머무르는지 물어보고, 그에 따라서 관광 일정을 추천해주면 돼.
    그 다음 사용자가 서울에 오는 이유에 대해 파악하고 그에 맞는 여행 일정을 추천해주면 돼.
    대화하다가 추천한 여행 일정이 사용자의 마음에 들지 않아서 변경해달라고 하면 마음에 들지 않은 부분을
    캐치하고 그 부분들만 수정해서 다시 추천해주면 돼.
    일정 중간 중간 숙소나 식당, 쇼핑몰 등을 추천해주면 돼.

    어떤 장소가 궁금해서 물어본다면 특정 장소의 정보들을 정확하게 알려줘.
    (예:가게 정보, 메뉴, 별점, 위치, 연락처, 운영 시간, 리뷰 등)
    여행 일정에 대한 동선이 짧도록 추천해줘.
    언어는 사용자가 입력한 언어를 기준으로 알려줘. 
    화폐 기준도 사용자가 입력한 언어를 사용하는 국가의 화폐를 기준으로 적용해줘.


    - 너가 제공한 내용의 출처를 링크로 남겨줘

    # 웹 검색 정보 : {context_web}

    #사용자의 질문: {question}
    
    #이전 대화 내용 {chat_history} 
    """,
        input_variables=["context_web", "question"],
    )
#input_variables=["context_web","context_opendata","context_naver", "question"],
# LLM
model_web = ChatOpenAI(model_name="gpt-4o",
                    temperature=0, streaming=False)

chain_web = (
    {
        "question": itemgetter("question"),
        "context_web": itemgetter("context_web"),
        # "context_opendata": itemgetter("context_opendata"),
        # "context_naver": itemgetter("context_naver"),
        "chat_history": itemgetter("chat_history"),
    }
    | prompt_web
    | model_web
    | StrOutputParser()
)

# %%
from langchain_teddynote.messages import messages_to_history
from langchain_teddynote.tools.tavily import TavilySearch
import ast
import random

# from rag.utils import format_docs
# 웹 검색 or 리트리버 검색
def Schedule_day_check(state: GraphState) -> GraphState:
    
    response = chain_day.invoke(
        {"question": state["question"][-1].content}
    )

    return {"dayCheck": response}

def web_or_retriever_check(state: GraphState) -> GraphState:
    
    response = chain_Web_or_retriever.invoke(
        {"question": state["question"][-1].content}
    )

    return {"webOrRetriever": response}

# 웹 리트리버 분기 체크하는 함수(router)
def is_web(state: GraphState) -> GraphState:
    if state["webOrRetriever"] == "web":
        return "web"
    else:
        return "retriever"

# 장소검색 or 일정 검색
def Schedule_or_place_check(state: GraphState) -> GraphState:
    # 관련성 체크를 실행("yes" or "no")
    response = chain_sch_or_placeSearch.invoke(
        {"question": state["question"][-1].content}
    )

    return {"ScheduleOrplace": response}


# 일정 장소검색 리트리버 분기 체크하는 함수(router)
def is_place(state: GraphState) -> GraphState:
    if state["ScheduleOrplace"] == "일정":
        return "일정"
    else:
        return "장소검색"
    
# 지역 판별
def location_check(state: GraphState) -> GraphState:
    # 관련성 체크를 실행("yes" or "no")
    response = chain_location.invoke(
        {"question": state["question"][-1].content}
    )

    return {"location": response}

    
# 문서 검색 노드--------------------------------------------------------------------------------------------------------------------------
def retrieve_document_naver(state: GraphState) -> GraphState:
    # 질문을 상태에서 가져옵니다.
    latest_question = state["question"][-1].content
    location_str = state['location']

    location = ast.literal_eval(location_str)

    # 문서에서 검색하여 관련성 있는 문서를 찾습니다.
    yongsan = '용산구'
    jonglo = '종로구'
    gangman = '강남구'
    junggu = '중구'
    retrieved_docs_yongsan = []
    retrieved_docs_jongro = []
    retrieved_docs_gangman = []
    retrieved_docs_junggu = []

    # if yongsan in location:
    #     retrieved_docs_yongsan = retriever_naver_yongsan.invoke(latest_question)
    #     retrieved_docs_yongsan = "\n".join(
    #     [
    #         f"<content>{doc.page_content}</content>"
    #         for doc in retrieved_docs_yongsan
    #     ]
    #     )

    # if jonglo in location:
    #     retrieved_docs_jongro = retriever_naver_jongro.invoke(latest_question)
    #     retrieved_docs_jongro = "\n".join(
    #     [
    #         f"<content>{doc.page_content}</content>"
    #         for doc in retrieved_docs_jongro
    #     ]
    #     )

    # if gangman in location:
    #     retrieved_docs_gangman = retriever_naver_gangnam.invoke(latest_question)
    #     retrieved_docs_gangman = "\n".join(
    #     [
    #         f"<content>{doc.page_content}</content>"
    #         for doc in retrieved_docs_gangman
    #     ]
    #     )

    # if junggu in location:
    #     retrieved_docs_junggu = retriever_naver_Junggu.invoke(latest_question)
    #     retrieved_docs_junggu = "\n".join(
    #     [
    #         f"<content>{doc.page_content}</content>"
    #         for doc in retrieved_docs_junggu
    #     ]
    #     )
    if yongsan in location:
        retrieved_docs_yongsan = retriever_naver_yongsan.invoke(latest_question)


    if jonglo in location:
        retrieved_docs_jongro = retriever_naver_jongro.invoke(latest_question)


    if gangman in location:
        retrieved_docs_gangman = retriever_naver_gangnam.invoke(latest_question)


    if junggu in location:
        retrieved_docs_junggu = retriever_naver_Junggu.invoke(latest_question)


    # 검색된 문서를 형식화합니다.(프롬프트 입력으로 넣어주기 위함)

        # 검색된 문서를 context 키에 저장합니다.
    # return {"context_naver_gangnam": retrieved_docs_gangman,
    #         "context_naver_jongro": retrieved_docs_jongro,
    #         "context_naver_Junggu": retrieved_docs_junggu,
    #         "context_naver_yongsan": retrieved_docs_yongsan}
    return {"context_naver_gangnam": retrieved_docs_gangman,
            "context_naver_jongro": retrieved_docs_jongro,
            "context_naver_Junggu": retrieved_docs_junggu,
            "context_naver_yongsan": retrieved_docs_yongsan}

#------------------------------------------------------------------------------------------------------------------------------------------------


def retrieve_document_opendata(state: GraphState) -> GraphState:
    # 질문을 상태에서 가져옵니다.
    latest_question = state["question"][-1].content
    location_str = state['location']

    location = ast.literal_eval(location_str)

    doc_list = []
    # 문서에서 검색하여 관련성 있는 문서를 찾습니다.
    yongsan = '용산구'
    jonglo = '종로구'
    gangman = '강남구'
    junggu = '중구'
    retrieved_docs_yongsan = []
    retrieved_docs_jongro = []
    retrieved_docs_gangman = []
    retrieved_docs_junggu = []

    if yongsan in location:
        retrieved_docs_yongsan = retriever_opendata_yongsan.invoke(latest_question)

    if jonglo in location:
        retrieved_docs_jongro = retriever_opendata_jongro.invoke(latest_question)

    if gangman in location:
        retrieved_docs_gangman = retriever_opendata_gangnam.invoke(latest_question)

    if junggu in location:
        retrieved_docs_junggu = retriever_opendata_junggu.invoke(latest_question)

 
    doc_list.extend(retrieved_docs_yongsan)
    doc_list.extend(retrieved_docs_jongro)
    doc_list.extend(retrieved_docs_gangman)
    doc_list.extend(retrieved_docs_junggu)

#     # 검색된 문서를 형식화합니다.(프롬프트 입력으로 넣어주기 위함)
#     retrieved_docs = "\n".join(
#         [
#             f"<document><content>{doc.page_content}</content>"
#             for doc in doc_list
#         ]
# )

#     # 검색된 문서를 context 키에 저장합니다.
#     return {"context_opendata": retrieved_docs}
    # 검색된 문서를 context 키에 저장합니다.
    return {"context_opendata": doc_list}




# 일정 생성 노드----------------------------------------------------------------------------

def llm_Schedule_answer(state: GraphState) -> GraphState:
    # 질문을 상태에서 가져옵니다.
    latest_question = state["question"][-1].content
    location_str = state['location']
    day_str = state['dayCheck']

    location = ast.literal_eval(location_str)
    day = ast.literal_eval(day_str)

    place_list = []
    place_yongsan =[]
    place_jongro =[]
    place_gangman =[]
    place_junggu =[]
    # 문서에서 검색하여 관련성 있는 문서를 찾습니다.
    yongsan = '용산구'
    jongro = '종로구'
    gangman = '강남구'
    junggu = '중구'

    for i in range(1, day+1):
        if yongsan in location:
            place_yongsan = state["context_naver_yongsan"]

            place_list.extend(random.sample(place_yongsan, 5))

        if jongro in location:
            place_jongro = state["context_naver_jongro"]
            place_list.extend(random.sample(place_jongro, 5))

        if gangman in location:
            place_gangman = state["context_naver_gangnam"]
            place_list.extend(random.sample(place_gangman, 5))

        if junggu in location:
            place_junggu = state["context_naver_Junggu"]

            place_list.extend(random.sample(place_junggu, 5))

    
        place_opendata = state["context_opendata"]
        
        place_list.extend(random.sample(place_opendata, 5))

        #검색된 문서를 형식화합니다.(프롬프트 입력으로 넣어주기 위함)
        place_list_text = "\n".join(
        [
            f"<content>{doc.page_content}</content>"
            for doc in place_list
        ]
        )

        # 체인을 호출하여 답변을 생성합니다.
        response = chain.invoke(
            {
                "question": latest_question,
                "context": place_list_text,
                "chat_history": messages_to_history(state["messages"]),
                "day" : i
            }
        )
        place_list.clear()
        print('\n')

    # 생성된 답변, (유저의 질문, 답변) 메시지를 상태에 저장합니다.
    print(state["messages"])
    return {
        "answer": response,
        "messages": [("user", latest_question), ("assistant", response)],
    }
# 일정 생성 노드 끝----------------------------------------------------------------------------

# 장소 검색 노드 ----------------------------------------------------------------------------

def llm_place_answer(state: GraphState) -> GraphState:
    # 질문을 상태에서 가져옵니다.
    latest_question = state["question"][-1].content
    location_str = state['location']

    location = ast.literal_eval(location_str)

    place_list = []
    place_yongsan =[]
    place_jongro =[]
    place_gangman =[]
    place_junggu =[]
    # 문서에서 검색하여 관련성 있는 문서를 찾습니다.
    yongsan = '용산구'
    jonglo = '종로구'
    gangman = '강남구'
    junggu = '중구'

    if yongsan in location:
        place_yongsan = state["context_naver_yongsan"]
        place_yongsan = place_yongsan[:5]
        place_list.extend(place_yongsan)

    if jonglo in location:
        place_jongro = state["context_naver_jongro"]
        place_jongro = place_jongro[:5]
        place_list.extend(place_jongro)

    if gangman in location:
        place_gangman = state["context_naver_gangnam"]
        place_gangman = place_gangman[:5]
        place_list.extend(place_gangman)

    if junggu in location:
        place_junggu = state["context_naver_Junggu"]
        place_junggu = place_junggu[:5]
        place_list.extend(place_junggu)

   
    place_opendata = state["context_opendata"]
    place_opendata = place_opendata[:7]

    place_list.extend(place_opendata)

    place_list_text = "\n".join(
    [
        f"<content>{doc.page_content}</content>"
        for doc in place_list
    ]
    )

    # 체인을 호출하여 답변을 생성합니다.
    response = chain_place_search.invoke(
        {
            "question": latest_question,
            "context": place_list_text,
            "chat_history": messages_to_history(state["messages"]),
        }
    )
    # 생성된 답변, (유저의 질문, 답변) 메시지를 상태에 저장합니다.
    print(state["messages"])
    return {
        "answer": response,
        "messages": [("user", latest_question), ("assistant", response)],
    }

# 장소 검색 노드  끝----------------------------------------------------------------------------


# 웹 검색 답변 생성 노드
def llm_answer_web(state: GraphState) -> GraphState:
    # 질문을 상태에서 가져옵니다.
    latest_question = state["question"][-1].content
    # 검색된 문서를 상태에서 가져옵니다.
    # context_naver = state["context_naver"]
    # context_opendata = state["context_opendata"]
    context_web = state["context_web"]

    # 체인을 호출하여 답변을 생성합니다.
    response = chain_web.invoke(
        {
            "question": latest_question,
            "context_web": context_web,
            # "context_naver": context_naver,
            # "context_opendata": context_opendata,
            "chat_history": messages_to_history(state["messages"]),
        }
    )
    # 생성된 답변, (유저의 질문, 답변) 메시지를 상태에 저장합니다.
    print(state["messages"])
    return {
        "answer": response,
        "messages": [("user", latest_question), ("assistant", response)],
    }

# Web Search 노드
def web_search(state: GraphState) -> GraphState:
    # 검색 도구 생성
    tavily_tool = TavilySearch()

    search_query = state["question"][-1].content

    # 다양한 파라미터를 사용한 검색 예제
    search_result = tavily_tool.search(
        query=search_query,  # 검색 쿼리
        topic="general",  # 일반 주제
        max_results=2,  # 최대 검색 결과
        format_output=True,  # 결과 포맷팅
    )

    return {"context_web": search_result}

# %%
from langgraph.graph import END, StateGraph
from langgraph.checkpoint.memory import MemorySaver

# 그래프 생성
workflow = StateGraph(GraphState)

# 노드 정의
workflow.add_node("location_check", location_check)
workflow.add_node("Schedule_day_check", Schedule_day_check)
workflow.add_node("retrieve_document_naver", retrieve_document_naver)
workflow.add_node("retrieve_opendata", retrieve_document_opendata)
# workflow.add_node("llm_Summary_opendata", llm_Summary_opendata)
# workflow.add_node("llm_Summary_naver", llm_Summary_naver)
workflow.add_node("llm_Schedule_answer", llm_Schedule_answer)
workflow.add_node("Schedule_or_place_check", Schedule_or_place_check)
workflow.add_node("llm_place_answer", llm_place_answer)


# 엣지 정의
# workflow.add_conditional_edges(
#     "web_Or_Retriever",  # 관련성 체크 노드에서 나온 결과를 is_relevant 함수에 전달합니다.
#     is_web,
#     {
#         "web": "web_search",  # 웹 검색을 요청하면 웹검색을 합니다
#         "retriever": "query_rewrite",  # 아니면 리트리버
#     },
# )
# 엣지 정의
workflow.add_conditional_edges(
    "Schedule_or_place_check",  
    is_place,
    {
        "일정": "Schedule_day_check",  #일정
        "장소검색": "llm_place_answer",  # 장소검색
    },
)

workflow.add_edge("location_check", "retrieve_document_naver")  # 검색 -> 답변
workflow.add_edge("location_check", "retrieve_opendata")  # 검색 -> 답변
# workflow.add_edge("retrieve_document_naver", "llm_Summary_naver")  # 질문 -> 검색
# workflow.add_edge("retrieve_opendata", "llm_Summary_opendata")  # 질문 -> 검색
workflow.add_edge("retrieve_document_naver", "Schedule_or_place_check") 
workflow.add_edge("retrieve_opendata", "Schedule_or_place_check") 
workflow.add_edge("Schedule_day_check", "llm_Schedule_answer") 

workflow.add_edge("llm_Schedule_answer", END)  # 답변 -> 종료
workflow.add_edge("llm_place_answer", END)  # 답변 -> 종료

# 그래프 진입점 설정
workflow.set_entry_point("location_check")
# workflow.set_entry_point("Schedule_or_place_check")

# 체크포인터 설정
memory = MemorySaver()

# 컴파일
app = workflow.compile(checkpointer=memory)

# %%
help(app)
# Out:
# Help on CompiledStateGraph in module langgraph.graph.state object:
#
# class CompiledStateGraph(langgraph.graph.graph.CompiledGraph)
#  |  CompiledStateGraph(*, builder: langgraph.graph.graph.Graph, **kwargs: Any) -> None
#  |
#  |  Method resolution order:
#  |      CompiledStateGraph
#  |      langgraph.graph.graph.CompiledGraph
#  |      langgraph.pregel.Pregel
#  |      langgraph.pregel.protocol.PregelProtocol
#  |      langchain_core.runnables.base.Runnable
#  |      typing.Generic
#  |      abc.ABC
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  attach_branch(self, start: str, name: str, branch: langgraph.graph.graph.Branch, *, with_reader: bool = True) -> None
#  |
#  |  attach_edge(self, starts: Union[str, Sequence[str]], end: str) -> None
#  |
#  |  attach_node(self, key: str, node: Optional[langgraph.graph.state.StateNodeSpec]) -> None
#  |
#  |  get_input_schema(self, config: Optional[langchain_core.runnables.config.RunnableConfig] = None) -> type[pydantic.main.BaseModel]
#  |      Get a pydantic model that can be used to validate input to the Runnable.
#  |
#  |      Runnables that leverage the configurable_fields and configurable_alternatives
#  |      methods will have a dynamic input schema that depends on which
#  |      configuration the Runnable is invoked with.
#  |
#  |      This method allows to get an input schema for a specific configuration.
#  |
#  |      Args:
#  |          config: A config to use when generating the schema.
#  |
#  |      Returns:
#  |          A pydantic model that can be used to validate input.
#  |
#  |  get_output_schema(self, config: Optional[langchain_core.runnables.config.RunnableConfig] = None) -> type[pydantic.main.BaseModel]
#  |      Get a pydantic model that can be used to validate output to the Runnable.
#  |
#  |      Runnables that leverage the configurable_fields and configurable_alternatives
#  |      methods will have a dynamic output schema that depends on which
#  |      configuration the Runnable is invoked with.
#  |
#  |      This method allows to get an output schema for a specific configuration.
#  |
#  |      Args:
#  |          config: A config to use when generating the schema.
#  |
#  |      Returns:
#  |          A pydantic model that can be used to validate output.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __abstractmethods__ = frozenset()
#  |
#  |  __annotations__ = {'builder': <class 'langgraph.graph.state.StateGraph...
#  |
#  |  __parameters__ = ()
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from langgraph.graph.graph.CompiledGraph:
#  |
#  |  __init__(self, *, builder: langgraph.graph.graph.Graph, **kwargs: Any) -> None
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  async aget_graph(self, config: Optional[langchain_core.runnables.config.RunnableConfig] = None, *, xray: Union[int, bool] = False) -> langchain_core.runnables.graph.Graph
#  |
#  |  get_graph(self, config: Optional[langchain_core.runnables.config.RunnableConfig] = None, *, xray: Union[int, bool] = False) -> langchain_core.runnables.graph.Graph
#  |      Returns a drawable representation of the computation graph.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from langgraph.pregel.Pregel:
#  |
#  |  async aget_state(self, config: 'RunnableConfig', *, subgraphs: 'bool' = False) -> 'StateSnapshot'
#  |      Get the current state of the graph.
#  |
#  |  async aget_state_history(self, config: 'RunnableConfig', *, filter: 'Optional[Dict[str, Any]]' = None, before: 'Optional[RunnableConfig]' = None, limit: 'Optional[int]' = None) -> 'AsyncIterator[StateSnapshot]'
#  |
#  |  async aget_subgraphs(self, *, namespace: 'Optional[str]' = None, recurse: 'bool' = False) -> 'AsyncIterator[tuple[str, Pregel]]'
#  |
#  |  async ainvoke(self, input: 'Union[dict[str, Any], Any]', config: 'Optional[RunnableConfig]' = None, *, stream_mode: 'StreamMode' = 'values', output_keys: 'Optional[Union[str, Sequence[str]]]' = None, interrupt_before: 'Optional[Union[All, Sequence[str]]]' = None, interrupt_after: 'Optional[Union[All, Sequence[str]]]' = None, debug: 'Optional[bool]' = None, **kwargs: 'Any') -> 'Union[dict[str, Any], Any]'
#  |      Asynchronously invoke the graph on a single input.
#  |
#  |      Args:
#  |          input: The input data for the computation. It can be a dictionary or any other type.
#  |          config: Optional. The configuration for the computation.
#  |          stream_mode: Optional. The stream mode for the computation. Default is "values".
#  |          output_keys: Optional. The output keys to include in the result. Default is None.
#  |          interrupt_before: Optional. The nodes to interrupt before. Default is None.
#  |          interrupt_after: Optional. The nodes to interrupt after. Default is None.
#  |          debug: Optional. Whether to enable debug mode. Default is None.
#  |          **kwargs: Additional keyword arguments.
#  |
#  |      Returns:
#  |          The result of the computation. If stream_mode is "values", it returns the latest value.
#  |          If stream_mode is "chunks", it returns a list of chunks.
#  |
#  |  async astream(self, input: 'Union[dict[str, Any], Any]', config: 'Optional[RunnableConfig]' = None, *, stream_mode: 'Optional[Union[StreamMode, list[StreamMode]]]' = None, output_keys: 'Optional[Union[str, Sequence[str]]]' = None, interrupt_before: 'Optional[Union[All, Sequence[str]]]' = None, interrupt_after: 'Optional[Union[All, Sequence[str]]]' = None, debug: 'Optional[bool]' = None, subgraphs: 'bool' = False) -> 'AsyncIterator[Union[dict[str, Any], Any]]'
#  |      Stream graph steps for a single input.
#  |
#  |      Args:
#  |          input: The input to the graph.
#  |          config: The configuration to use for the run.
#  |          stream_mode: The mode to stream output, defaults to self.stream_mode.
#  |              Options are 'values', 'updates', and 'debug'.
#  |              values: Emit the current values of the state for each step.
#  |              updates: Emit only the updates to the state for each step.
#  |                  Output is a dict with the node name as key and the updated values as value.
#  |              debug: Emit debug events for each step.
#  |          output_keys: The keys to stream, defaults to all non-context channels.
#  |          interrupt_before: Nodes to interrupt before, defaults to all nodes in the graph.
#  |          interrupt_after: Nodes to interrupt after, defaults to all nodes in the graph.
#  |          debug: Whether to print debug information during execution, defaults to False.
#  |          subgraphs: Whether to stream subgraphs, defaults to False.
#  |
#  |      Yields:
#  |          The output of each step in the graph. The output shape depends on the stream_mode.
#  |
#  |      Examples:
#  |          Using different stream modes with a graph:
#  |          ```pycon
#  |          >>> import operator
#  |          >>> from typing_extensions import Annotated, TypedDict
#  |          >>> from langgraph.graph import StateGraph
#  |          >>> from langgraph.constants import START
#  |          ...
#  |          >>> class State(TypedDict):
#  |          ...     alist: Annotated[list, operator.add]
#  |          ...     another_list: Annotated[list, operator.add]
#  |          ...
#  |          >>> builder = StateGraph(State)
#  |          >>> builder.add_node("a", lambda _state: {"another_list": ["hi"]})
#  |          >>> builder.add_node("b", lambda _state: {"alist": ["there"]})
#  |          >>> builder.add_edge("a", "b")
#  |          >>> builder.add_edge(START, "a")
#  |          >>> graph = builder.compile()
#  |          ```
#  |          With stream_mode="values":
#  |
#  |          ```pycon
#  |          >>> async for event in graph.astream({"alist": ['Ex for stream_mode="values"']}, stream_mode="values"):
#  |          ...     print(event)
#  |          {'alist': ['Ex for stream_mode="values"'], 'another_list': []}
#  |          {'alist': ['Ex for stream_mode="values"'], 'another_list': ['hi']}
#  |          {'alist': ['Ex for stream_mode="values"', 'there'], 'another_list': ['hi']}
#  |          ```
#  |          With stream_mode="updates":
#  |
#  |          ```pycon
#  |          >>> async for event in graph.astream({"alist": ['Ex for stream_mode="updates"']}, stream_mode="updates"):
#  |          ...     print(event)
#  |          {'a': {'another_list': ['hi']}}
#  |          {'b': {'alist': ['there']}}
#  |          ```
#  |          With stream_mode="debug":
#  |
#  |          ```pycon
#  |          >>> async for event in graph.astream({"alist": ['Ex for stream_mode="debug"']}, stream_mode="debug"):
#  |          ...     print(event)
#  |          {'type': 'task', 'timestamp': '2024-06-23T...+00:00', 'step': 1, 'payload': {'id': '...', 'name': 'a', 'input': {'alist': ['Ex for stream_mode="debug"'], 'another_list': []}, 'triggers': ['start:a']}}
#  |          {'type': 'task_result', 'timestamp': '2024-06-23T...+00:00', 'step': 1, 'payload': {'id': '...', 'name': 'a', 'result': [('another_list', ['hi'])]}}
#  |          {'type': 'task', 'timestamp': '2024-06-23T...+00:00', 'step': 2, 'payload': {'id': '...', 'name': 'b', 'input': {'alist': ['Ex for stream_mode="debug"'], 'another_list': ['hi']}, 'triggers': ['a']}}
#  |          {'type': 'task_result', 'timestamp': '2024-06-23T...+00:00', 'step': 2, 'payload': {'id': '...', 'name': 'b', 'result': [('alist', ['there'])]}}
#  |          ```
#  |
#  |  async aupdate_state(self, config: 'RunnableConfig', values: 'dict[str, Any] | Any', as_node: 'Optional[str]' = None) -> 'RunnableConfig'
#  |
#  |  copy(self, update: 'dict[str, Any] | None' = None) -> 'Self'
#  |
#  |  get_input_jsonschema(self, config: 'Optional[RunnableConfig]' = None) -> 'Dict[All, Any]'
#  |      Get a JSON schema that represents the input to the Runnable.
#  |
#  |      Args:
#  |          config: A config to use when generating the schema.
#  |
#  |      Returns:
#  |          A JSON schema that represents the input to the Runnable.
#  |
#  |      Example:
#  |
#  |          .. code-block:: python
#  |
#  |              from langchain_core.runnables import RunnableLambda
#  |
#  |              def add_one(x: int) -> int:
#  |                  return x + 1
#  |
#  |              runnable = RunnableLambda(add_one)
#  |
#  |              print(runnable.get_input_jsonschema())
#  |
#  |      .. versionadded:: 0.3.0
#  |
#  |  get_output_jsonschema(self, config: 'Optional[RunnableConfig]' = None) -> 'Dict[All, Any]'
#  |      Get a JSON schema that represents the output of the Runnable.
#  |
#  |      Args:
#  |          config: A config to use when generating the schema.
#  |
#  |      Returns:
#  |          A JSON schema that represents the output of the Runnable.
#  |
#  |      Example:
#  |
#  |          .. code-block:: python
#  |
#  |              from langchain_core.runnables import RunnableLambda
#  |
#  |              def add_one(x: int) -> int:
#  |                  return x + 1
#  |
#  |              runnable = RunnableLambda(add_one)
#  |
#  |              print(runnable.get_output_jsonschema())
#  |
#  |      .. versionadded:: 0.3.0
#  |
#  |  get_state(self, config: 'RunnableConfig', *, subgraphs: 'bool' = False) -> 'StateSnapshot'
#  |      Get the current state of the graph.
#  |
#  |  get_state_history(self, config: 'RunnableConfig', *, filter: 'Optional[Dict[str, Any]]' = None, before: 'Optional[RunnableConfig]' = None, limit: 'Optional[int]' = None) -> 'Iterator[StateSnapshot]'
#  |
#  |  get_subgraphs(self, *, namespace: 'Optional[str]' = None, recurse: 'bool' = False) -> 'Iterator[tuple[str, Pregel]]'
#  |
#  |  invoke(self, input: 'Union[dict[str, Any], Any]', config: 'Optional[RunnableConfig]' = None, *, stream_mode: 'StreamMode' = 'values', output_keys: 'Optional[Union[str, Sequence[str]]]' = None, interrupt_before: 'Optional[Union[All, Sequence[str]]]' = None, interrupt_after: 'Optional[Union[All, Sequence[str]]]' = None, debug: 'Optional[bool]' = None, **kwargs: 'Any') -> 'Union[dict[str, Any], Any]'
#  |      Run the graph with a single input and config.
#  |
#  |      Args:
#  |          input: The input data for the graph. It can be a dictionary or any other type.
#  |          config: Optional. The configuration for the graph run.
#  |          stream_mode: Optional[str]. The stream mode for the graph run. Default is "values".
#  |          output_keys: Optional. The output keys to retrieve from the graph run.
#  |          interrupt_before: Optional. The nodes to interrupt the graph run before.
#  |          interrupt_after: Optional. The nodes to interrupt the graph run after.
#  |          debug: Optional. Enable debug mode for the graph run.
#  |          **kwargs: Additional keyword arguments to pass to the graph run.
#  |
#  |      Returns:
#  |          The output of the graph run. If stream_mode is "values", it returns the latest output.
#  |          If stream_mode is not "values", it returns a list of output chunks.
#  |
#  |  stream(self, input: 'Union[dict[str, Any], Any]', config: 'Optional[RunnableConfig]' = None, *, stream_mode: 'Optional[Union[StreamMode, list[StreamMode]]]' = None, output_keys: 'Optional[Union[str, Sequence[str]]]' = None, interrupt_before: 'Optional[Union[All, Sequence[str]]]' = None, interrupt_after: 'Optional[Union[All, Sequence[str]]]' = None, debug: 'Optional[bool]' = None, subgraphs: 'bool' = False) -> 'Iterator[Union[dict[str, Any], Any]]'
#  |      Stream graph steps for a single input.
#  |
#  |      Args:
#  |          input: The input to the graph.
#  |          config: The configuration to use for the run.
#  |          stream_mode: The mode to stream output, defaults to self.stream_mode.
#  |              Options are 'values', 'updates', and 'debug'.
#  |              values: Emit the current values of the state for each step.
#  |              updates: Emit only the updates to the state for each step.
#  |                  Output is a dict with the node name as key and the updated values as value.
#  |              debug: Emit debug events for each step.
#  |          output_keys: The keys to stream, defaults to all non-context channels.
#  |          interrupt_before: Nodes to interrupt before, defaults to all nodes in the graph.
#  |          interrupt_after: Nodes to interrupt after, defaults to all nodes in the graph.
#  |          debug: Whether to print debug information during execution, defaults to False.
#  |          subgraphs: Whether to stream subgraphs, defaults to False.
#  |
#  |      Yields:
#  |          The output of each step in the graph. The output shape depends on the stream_mode.
#  |
#  |      Examples:
#  |          Using different stream modes with a graph:
#  |          ```pycon
#  |          >>> import operator
#  |          >>> from typing_extensions import Annotated, TypedDict
#  |          >>> from langgraph.graph import StateGraph
#  |          >>> from langgraph.constants import START
#  |          ...
#  |          >>> class State(TypedDict):
#  |          ...     alist: Annotated[list, operator.add]
#  |          ...     another_list: Annotated[list, operator.add]
#  |          ...
#  |          >>> builder = StateGraph(State)
#  |          >>> builder.add_node("a", lambda _state: {"another_list": ["hi"]})
#  |          >>> builder.add_node("b", lambda _state: {"alist": ["there"]})
#  |          >>> builder.add_edge("a", "b")
#  |          >>> builder.add_edge(START, "a")
#  |          >>> graph = builder.compile()
#  |          ```
#  |          With stream_mode="values":
#  |
#  |          ```pycon
#  |          >>> for event in graph.stream({"alist": ['Ex for stream_mode="values"']}, stream_mode="values"):
#  |          ...     print(event)
#  |          {'alist': ['Ex for stream_mode="values"'], 'another_list': []}
#  |          {'alist': ['Ex for stream_mode="values"'], 'another_list': ['hi']}
#  |          {'alist': ['Ex for stream_mode="values"', 'there'], 'another_list': ['hi']}
#  |          ```
#  |          With stream_mode="updates":
#  |
#  |          ```pycon
#  |          >>> for event in graph.stream({"alist": ['Ex for stream_mode="updates"']}, stream_mode="updates"):
#  |          ...     print(event)
#  |          {'a': {'another_list': ['hi']}}
#  |          {'b': {'alist': ['there']}}
#  |          ```
#  |          With stream_mode="debug":
#  |
#  |          ```pycon
#  |          >>> for event in graph.stream({"alist": ['Ex for stream_mode="debug"']}, stream_mode="debug"):
#  |          ...     print(event)
#  |          {'type': 'task', 'timestamp': '2024-06-23T...+00:00', 'step': 1, 'payload': {'id': '...', 'name': 'a', 'input': {'alist': ['Ex for stream_mode="debug"'], 'another_list': []}, 'triggers': ['start:a']}}
#  |          {'type': 'task_result', 'timestamp': '2024-06-23T...+00:00', 'step': 1, 'payload': {'id': '...', 'name': 'a', 'result': [('another_list', ['hi'])]}}
#  |          {'type': 'task', 'timestamp': '2024-06-23T...+00:00', 'step': 2, 'payload': {'id': '...', 'name': 'b', 'input': {'alist': ['Ex for stream_mode="debug"'], 'another_list': ['hi']}, 'triggers': ['a']}}
#  |          {'type': 'task_result', 'timestamp': '2024-06-23T...+00:00', 'step': 2, 'payload': {'id': '...', 'name': 'b', 'result': [('alist', ['there'])]}}
#  |          ```
#  |
#  |  update_state(self, config: 'RunnableConfig', values: 'Optional[Union[dict[str, Any], Any]]', as_node: 'Optional[str]' = None) -> 'RunnableConfig'
#  |      Update the state of the graph with the given values, as if they came from
#  |      node `as_node`. If `as_node` is not provided, it will be set to the last node
#  |      that updated the state, if not ambiguous.
#  |
#  |  validate(self) -> 'Self'
#  |
#  |  with_config(self, config: 'RunnableConfig | None' = None, **kwargs: 'Any') -> 'Self'
#  |      Bind config to a Runnable, returning a new Runnable.
#  |
#  |      Args:
#  |          config: The config to bind to the Runnable.
#  |          kwargs: Additional keyword arguments to pass to the Runnable.
#  |
#  |      Returns:
#  |          A new Runnable with the config bound.
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties inherited from langgraph.pregel.Pregel:
#  |
#  |  InputType
#  |      The type of input this Runnable accepts specified as a type annotation.
#  |
#  |  OutputType
#  |      The type of output this Runnable produces specified as a type annotation.
#  |
#  |  config_specs
#  |      List configurable fields for this Runnable.
#  |
#  |  stream_channels_asis
#  |
#  |  stream_channels_list
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from langgraph.pregel.Pregel:
#  |
#  |  checkpointer = None
#  |
#  |  config = None
#  |
#  |  config_type = None
#  |
#  |  name = 'LangGraph'
#  |
#  |  retry_policy = None
#  |
#  |  step_timeout = None
#  |
#  |  store = None
#  |
#  |  stream_channels = None
#  |
#  |  stream_mode = 'values'
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from langgraph.pregel.protocol.PregelProtocol:
#  |
#  |  __orig_bases__ = (langchain_core.runnables.base.Runnable[typing.Un... ...
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from langchain_core.runnables.base.Runnable:
#  |
#  |  __or__(self, other: 'Union[Runnable[Any, Other], Callable[[Any], Other], Callable[[Iterator[Any]], Iterator[Other]], Mapping[str, Union[Runnable[Any, Other], Callable[[Any], Other], Any]]]') -> 'RunnableSerializable[Input, Other]'
#  |      Compose this Runnable with another object to create a RunnableSequence.
#  |
#  |  __ror__(self, other: 'Union[Runnable[Other, Any], Callable[[Other], Any], Callable[[Iterator[Other]], Iterator[Any]], Mapping[str, Union[Runnable[Other, Any], Callable[[Other], Any], Any]]]') -> 'RunnableSerializable[Other, Output]'
#  |      Compose this Runnable with another object to create a RunnableSequence.
#  |
#  |  async abatch(self, inputs: 'list[Input]', config: 'Optional[Union[RunnableConfig, list[RunnableConfig]]]' = None, *, return_exceptions: 'bool' = False, **kwargs: 'Optional[Any]') -> 'list[Output]'
#  |      Default implementation runs ainvoke in parallel using asyncio.gather.
#  |
#  |      The default implementation of batch works well for IO bound runnables.
#  |
#  |      Subclasses should override this method if they can batch more efficiently;
#  |      e.g., if the underlying Runnable uses an API which supports a batch mode.
#  |
#  |      Args:
#  |          inputs: A list of inputs to the Runnable.
#  |          config: A config to use when invoking the Runnable.
#  |             The config supports standard keys like 'tags', 'metadata' for tracing
#  |             purposes, 'max_concurrency' for controlling how much work to do
#  |             in parallel, and other keys. Please refer to the RunnableConfig
#  |             for more details. Defaults to None.
#  |          return_exceptions: Whether to return exceptions instead of raising them.
#  |              Defaults to False.
#  |          kwargs: Additional keyword arguments to pass to the Runnable.
#  |
#  |      Returns:
#  |          A list of outputs from the Runnable.
#  |
#  |  async abatch_as_completed(self, inputs: 'Sequence[Input]', config: 'Optional[Union[RunnableConfig, Sequence[RunnableConfig]]]' = None, *, return_exceptions: 'bool' = False, **kwargs: 'Optional[Any]') -> 'AsyncIterator[tuple[int, Union[Output, Exception]]]'
#  |      Run ainvoke in parallel on a list of inputs,
#  |      yielding results as they complete.
#  |
#  |      Args:
#  |          inputs: A list of inputs to the Runnable.
#  |          config: A config to use when invoking the Runnable.
#  |             The config supports standard keys like 'tags', 'metadata' for tracing
#  |             purposes, 'max_concurrency' for controlling how much work to do
#  |             in parallel, and other keys. Please refer to the RunnableConfig
#  |             for more details. Defaults to None. Defaults to None.
#  |          return_exceptions: Whether to return exceptions instead of raising them.
#  |              Defaults to False.
#  |          kwargs: Additional keyword arguments to pass to the Runnable.
#  |
#  |      Yields:
#  |          A tuple of the index of the input and the output from the Runnable.
#  |
#  |  as_tool(self, args_schema: 'Optional[type[BaseModel]]' = None, *, name: 'Optional[str]' = None, description: 'Optional[str]' = None, arg_types: 'Optional[dict[str, type]]' = None) -> 'BaseTool'
#  |      .. beta::
#  |         This API is in beta and may change in the future.
#  |
#  |      Create a BaseTool from a Runnable.
#  |
#  |      ``as_tool`` will instantiate a BaseTool with a name, description, and
#  |      ``args_schema`` from a Runnable. Where possible, schemas are inferred
#  |      from ``runnable.get_input_schema``. Alternatively (e.g., if the
#  |      Runnable takes a dict as input and the specific dict keys are not typed),
#  |      the schema can be specified directly with ``args_schema``. You can also
#  |      pass ``arg_types`` to just specify the required arguments and their types.
#  |
#  |      Args:
#  |          args_schema: The schema for the tool. Defaults to None.
#  |          name: The name of the tool. Defaults to None.
#  |          description: The description of the tool. Defaults to None.
#  |          arg_types: A dictionary of argument names to types. Defaults to None.
#  |
#  |      Returns:
#  |          A BaseTool instance.
#  |
#  |      Typed dict input:
#  |
#  |      .. code-block:: python
#  |
#  |          from typing import List
#  |          from typing_extensions import TypedDict
#  |          from langchain_core.runnables import RunnableLambda
#  |
#  |          class Args(TypedDict):
#  |              a: int
#  |              b: List[int]
#  |
#  |          def f(x: Args) -> str:
#  |              return str(x["a"] * max(x["b"]))
#  |
#  |          runnable = RunnableLambda(f)
#  |          as_tool = runnable.as_tool()
#  |          as_tool.invoke({"a": 3, "b": [1, 2]})
#  |
#  |      ``dict`` input, specifying schema via ``args_schema``:
#  |
#  |      .. code-block:: python
#  |
#  |          from typing import Any, Dict, List
#  |          from pydantic import BaseModel, Field
#  |          from langchain_core.runnables import RunnableLambda
#  |
#  |          def f(x: Dict[str, Any]) -> str:
#  |              return str(x["a"] * max(x["b"]))
#  |
#  |          class FSchema(BaseModel):
#  |              """Apply a function to an integer and list of integers."""
#  |
#  |              a: int = Field(..., description="Integer")
#  |              b: List[int] = Field(..., description="List of ints")
#  |
#  |          runnable = RunnableLambda(f)
#  |          as_tool = runnable.as_tool(FSchema)
#  |          as_tool.invoke({"a": 3, "b": [1, 2]})
#  |
#  |      ``dict`` input, specifying schema via ``arg_types``:
#  |
#  |      .. code-block:: python
#  |
#  |          from typing import Any, Dict, List
#  |          from langchain_core.runnables import RunnableLambda
#  |
#  |          def f(x: Dict[str, Any]) -> str:
#  |              return str(x["a"] * max(x["b"]))
#  |
#  |          runnable = RunnableLambda(f)
#  |          as_tool = runnable.as_tool(arg_types={"a": int, "b": List[int]})
#  |          as_tool.invoke({"a": 3, "b": [1, 2]})
#  |
#  |      String input:
#  |
#  |      .. code-block:: python
#  |
#  |          from langchain_core.runnables import RunnableLambda
#  |
#  |          def f(x: str) -> str:
#  |              return x + "a"
#  |
#  |          def g(x: str) -> str:
#  |              return x + "z"
#  |
#  |          runnable = RunnableLambda(f) | g
#  |          as_tool = runnable.as_tool()
#  |          as_tool.invoke("b")
#  |
#  |      .. versionadded:: 0.2.14
#  |
#  |  assign(self, **kwargs: 'Union[Runnable[dict[str, Any], Any], Callable[[dict[str, Any]], Any], Mapping[str, Union[Runnable[dict[str, Any], Any], Callable[[dict[str, Any]], Any]]]]') -> 'RunnableSerializable[Any, Any]'
#  |      Assigns new fields to the dict output of this Runnable.
#  |      Returns a new Runnable.
#  |
#  |      .. code-block:: python
#  |
#  |          from langchain_community.llms.fake import FakeStreamingListLLM
#  |          from langchain_core.output_parsers import StrOutputParser
#  |          from langchain_core.prompts import SystemMessagePromptTemplate
#  |          from langchain_core.runnables import Runnable
#  |          from operator import itemgetter
#  |
#  |          prompt = (
#  |              SystemMessagePromptTemplate.from_template("You are a nice assistant.")
#  |              + "{question}"
#  |          )
#  |          llm = FakeStreamingListLLM(responses=["foo-lish"])
#  |
#  |          chain: Runnable = prompt | llm | {"str": StrOutputParser()}
#  |
#  |          chain_with_assign = chain.assign(hello=itemgetter("str") | llm)
#  |
#  |          print(chain_with_assign.input_schema.model_json_schema())
#  |          # {'title': 'PromptInput', 'type': 'object', 'properties':
#  |          {'question': {'title': 'Question', 'type': 'string'}}}
#  |          print(chain_with_assign.output_schema.model_json_schema())
#  |          # {'title': 'RunnableSequenceOutput', 'type': 'object', 'properties':
#  |          {'str': {'title': 'Str',
#  |          'type': 'string'}, 'hello': {'title': 'Hello', 'type': 'string'}}}
#  |
#  |  async astream_events(self, input: 'Any', config: 'Optional[RunnableConfig]' = None, *, version: "Literal['v1', 'v2']", include_names: 'Optional[Sequence[str]]' = None, include_types: 'Optional[Sequence[str]]' = None, include_tags: 'Optional[Sequence[str]]' = None, exclude_names: 'Optional[Sequence[str]]' = None, exclude_types: 'Optional[Sequence[str]]' = None, exclude_tags: 'Optional[Sequence[str]]' = None, **kwargs: 'Any') -> 'AsyncIterator[StreamEvent]'
#  |      Generate a stream of events.
#  |
#  |      Use to create an iterator over StreamEvents that provide real-time information
#  |      about the progress of the Runnable, including StreamEvents from intermediate
#  |      results.
#  |
#  |      A StreamEvent is a dictionary with the following schema:
#  |
#  |      - ``event``: **str** - Event names are of the
#  |          format: on_[runnable_type]_(start|stream|end).
#  |      - ``name``: **str** - The name of the Runnable that generated the event.
#  |      - ``run_id``: **str** - randomly generated ID associated with the given execution of
#  |          the Runnable that emitted the event.
#  |          A child Runnable that gets invoked as part of the execution of a
#  |          parent Runnable is assigned its own unique ID.
#  |      - ``parent_ids``: **List[str]** - The IDs of the parent runnables that
#  |          generated the event. The root Runnable will have an empty list.
#  |          The order of the parent IDs is from the root to the immediate parent.
#  |          Only available for v2 version of the API. The v1 version of the API
#  |          will return an empty list.
#  |      - ``tags``: **Optional[List[str]]** - The tags of the Runnable that generated
#  |          the event.
#  |      - ``metadata``: **Optional[Dict[str, Any]]** - The metadata of the Runnable
#  |          that generated the event.
#  |      - ``data``: **Dict[str, Any]**
#  |
#  |
#  |      Below is a table that illustrates some events that might be emitted by various
#  |      chains. Metadata fields have been omitted from the table for brevity.
#  |      Chain definitions have been included after the table.
#  |
#  |      **ATTENTION** This reference table is for the V2 version of the schema.
#  |
#  |      +----------------------+------------------+---------------------------------+-----------------------------------------------+-------------------------------------------------+
#  |      | event                | name             | chunk                           | input                                         | output                                          |
#  |      +======================+==================+=================================+===============================================+=================================================+
#  |      | on_chat_model_start  | [model name]     |                                 | {"messages": [[SystemMessage, HumanMessage]]} |                                                 |
#  |      +----------------------+------------------+---------------------------------+-----------------------------------------------+-------------------------------------------------+
#  |      | on_chat_model_stream | [model name]     | AIMessageChunk(content="hello") |                                               |                                                 |
#  |      +----------------------+------------------+---------------------------------+-----------------------------------------------+-------------------------------------------------+
#  |      | on_chat_model_end    | [model name]     |                                 | {"messages": [[SystemMessage, HumanMessage]]} | AIMessageChunk(content="hello world")           |
#  |      +----------------------+------------------+---------------------------------+-----------------------------------------------+-------------------------------------------------+
#  |      | on_llm_start         | [model name]     |                                 | {'input': 'hello'}                            |                                                 |
#  |      +----------------------+------------------+---------------------------------+-----------------------------------------------+-------------------------------------------------+
#  |      | on_llm_stream        | [model name]     | 'Hello'                         |                                               |                                                 |
#  |      +----------------------+------------------+---------------------------------+-----------------------------------------------+-------------------------------------------------+
#  |      | on_llm_end           | [model name]     |                                 | 'Hello human!'                                |                                                 |
#  |      +----------------------+------------------+---------------------------------+-----------------------------------------------+-------------------------------------------------+
#  |      | on_chain_start       | format_docs      |                                 |                                               |                                                 |
#  |      +----------------------+------------------+---------------------------------+-----------------------------------------------+-------------------------------------------------+
#  |      | on_chain_stream      | format_docs      | "hello world!, goodbye world!"  |                                               |                                                 |
#  |      +----------------------+------------------+---------------------------------+-----------------------------------------------+-------------------------------------------------+
#  |      | on_chain_end         | format_docs      |                                 | [Document(...)]                               | "hello world!, goodbye world!"                  |
#  |      +----------------------+------------------+---------------------------------+-----------------------------------------------+-------------------------------------------------+
#  |      | on_tool_start        | some_tool        |                                 | {"x": 1, "y": "2"}                            |                                                 |
#  |      +----------------------+------------------+---------------------------------+-----------------------------------------------+-------------------------------------------------+
#  |      | on_tool_end          | some_tool        |                                 |                                               | {"x": 1, "y": "2"}                              |
#  |      +----------------------+------------------+---------------------------------+-----------------------------------------------+-------------------------------------------------+
#  |      | on_retriever_start   | [retriever name] |                                 | {"query": "hello"}                            |                                                 |
#  |      +----------------------+------------------+---------------------------------+-----------------------------------------------+-------------------------------------------------+
#  |      | on_retriever_end     | [retriever name] |                                 | {"query": "hello"}                            | [Document(...), ..]                             |
#  |      +----------------------+------------------+---------------------------------+-----------------------------------------------+-------------------------------------------------+
#  |      | on_prompt_start      | [template_name]  |                                 | {"question": "hello"}                         |                                                 |
#  |      +----------------------+------------------+---------------------------------+-----------------------------------------------+-------------------------------------------------+
#  |      | on_prompt_end        | [template_name]  |                                 | {"question": "hello"}                         | ChatPromptValue(messages: [SystemMessage, ...]) |
#  |      +----------------------+------------------+---------------------------------+-----------------------------------------------+-------------------------------------------------+
#  |
#  |      In addition to the standard events, users can also dispatch custom events (see example below).
#  |
#  |      Custom events will be only be surfaced with in the `v2` version of the API!
#  |
#  |      A custom event has following format:
#  |
#  |      +-----------+------+-----------------------------------------------------------------------------------------------------------+
#  |      | Attribute | Type | Description                                                                                               |
#  |      +===========+======+===========================================================================================================+
#  |      | name      | str  | A user defined name for the event.                                                                        |
#  |      +-----------+------+-----------------------------------------------------------------------------------------------------------+
#  |      | data      | Any  | The data associated with the event. This can be anything, though we suggest making it JSON serializable.  |
#  |      +-----------+------+-----------------------------------------------------------------------------------------------------------+
#  |
#  |      Here are declarations associated with the standard events shown above:
#  |
#  |      `format_docs`:
#  |
#  |      .. code-block:: python
#  |
#  |          def format_docs(docs: List[Document]) -> str:
#  |              '''Format the docs.'''
#  |              return ", ".join([doc.page_content for doc in docs])
#  |
#  |          format_docs = RunnableLambda(format_docs)
#  |
#  |      `some_tool`:
#  |
#  |      .. code-block:: python
#  |
#  |          @tool
#  |          def some_tool(x: int, y: str) -> dict:
#  |              '''Some_tool.'''
#  |              return {"x": x, "y": y}
#  |
#  |      `prompt`:
#  |
#  |      .. code-block:: python
#  |
#  |          template = ChatPromptTemplate.from_messages(
#  |              [("system", "You are Cat Agent 007"), ("human", "{question}")]
#  |          ).with_config({"run_name": "my_template", "tags": ["my_template"]})
#  |
#  |
#  |      Example:
#  |
#  |      .. code-block:: python
#  |
#  |          from langchain_core.runnables import RunnableLambda
#  |
#  |          async def reverse(s: str) -> str:
#  |              return s[::-1]
#  |
#  |          chain = RunnableLambda(func=reverse)
#  |
#  |          events = [
#  |              event async for event in chain.astream_events("hello", version="v2")
#  |          ]
#  |
#  |          # will produce the following events (run_id, and parent_ids
#  |          # has been omitted for brevity):
#  |          [
#  |              {
#  |                  "data": {"input": "hello"},
#  |                  "event": "on_chain_start",
#  |                  "metadata": {},
#  |                  "name": "reverse",
#  |                  "tags": [],
#  |              },
#  |              {
#  |                  "data": {"chunk": "olleh"},
#  |                  "event": "on_chain_stream",
#  |                  "metadata": {},
#  |                  "name": "reverse",
#  |                  "tags": [],
#  |              },
#  |              {
#  |                  "data": {"output": "olleh"},
#  |                  "event": "on_chain_end",
#  |                  "metadata": {},
#  |                  "name": "reverse",
#  |                  "tags": [],
#  |              },
#  |          ]
#  |
#  |
#  |      Example: Dispatch Custom Event
#  |
#  |      .. code-block:: python
#  |
#  |          from langchain_core.callbacks.manager import (
#  |              adispatch_custom_event,
#  |          )
#  |          from langchain_core.runnables import RunnableLambda, RunnableConfig
#  |          import asyncio
#  |
#  |
#  |          async def slow_thing(some_input: str, config: RunnableConfig) -> str:
#  |              """Do something that takes a long time."""
#  |              await asyncio.sleep(1) # Placeholder for some slow operation
#  |              await adispatch_custom_event(
#  |                  "progress_event",
#  |                  {"message": "Finished step 1 of 3"},
#  |                  config=config # Must be included for python < 3.10
#  |              )
#  |              await asyncio.sleep(1) # Placeholder for some slow operation
#  |              await adispatch_custom_event(
#  |                  "progress_event",
#  |                  {"message": "Finished step 2 of 3"},
#  |                  config=config # Must be included for python < 3.10
#  |              )
#  |              await asyncio.sleep(1) # Placeholder for some slow operation
#  |              return "Done"
#  |
#  |          slow_thing = RunnableLambda(slow_thing)
#  |
#  |          async for event in slow_thing.astream_events("some_input", version="v2"):
#  |              print(event)
#  |
#  |      Args:
#  |          input: The input to the Runnable.
#  |          config: The config to use for the Runnable.
#  |          version: The version of the schema to use either `v2` or `v1`.
#  |                   Users should use `v2`.
#  |                   `v1` is for backwards compatibility and will be deprecated
#  |                   in 0.4.0.
#  |                   No default will be assigned until the API is stabilized.
#  |                   custom events will only be surfaced in `v2`.
#  |          include_names: Only include events from runnables with matching names.
#  |          include_types: Only include events from runnables with matching types.
#  |          include_tags: Only include events from runnables with matching tags.
#  |          exclude_names: Exclude events from runnables with matching names.
#  |          exclude_types: Exclude events from runnables with matching types.
#  |          exclude_tags: Exclude events from runnables with matching tags.
#  |          kwargs: Additional keyword arguments to pass to the Runnable.
#  |              These will be passed to astream_log as this implementation
#  |              of astream_events is built on top of astream_log.
#  |
#  |      Yields:
#  |          An async stream of StreamEvents.
#  |
#  |      Raises:
#  |          NotImplementedError: If the version is not `v1` or `v2`.
#  |
#  |  async astream_log(self, input: 'Any', config: 'Optional[RunnableConfig]' = None, *, diff: 'bool' = True, with_streamed_output_list: 'bool' = True, include_names: 'Optional[Sequence[str]]' = None, include_types: 'Optional[Sequence[str]]' = None, include_tags: 'Optional[Sequence[str]]' = None, exclude_names: 'Optional[Sequence[str]]' = None, exclude_types: 'Optional[Sequence[str]]' = None, exclude_tags: 'Optional[Sequence[str]]' = None, **kwargs: 'Any') -> 'Union[AsyncIterator[RunLogPatch], AsyncIterator[RunLog]]'
#  |      Stream all output from a Runnable, as reported to the callback system.
#  |      This includes all inner runs of LLMs, Retrievers, Tools, etc.
#  |
#  |      Output is streamed as Log objects, which include a list of
#  |      Jsonpatch ops that describe how the state of the run has changed in each
#  |      step, and the final state of the run.
#  |
#  |      The Jsonpatch ops can be applied in order to construct state.
#  |
#  |      Args:
#  |          input: The input to the Runnable.
#  |          config: The config to use for the Runnable.
#  |          diff: Whether to yield diffs between each step or the current state.
#  |          with_streamed_output_list: Whether to yield the streamed_output list.
#  |          include_names: Only include logs with these names.
#  |          include_types: Only include logs with these types.
#  |          include_tags: Only include logs with these tags.
#  |          exclude_names: Exclude logs with these names.
#  |          exclude_types: Exclude logs with these types.
#  |          exclude_tags: Exclude logs with these tags.
#  |          kwargs: Additional keyword arguments to pass to the Runnable.
#  |
#  |      Yields:
#  |          A RunLogPatch or RunLog object.
#  |
#  |  async atransform(self, input: 'AsyncIterator[Input]', config: 'Optional[RunnableConfig]' = None, **kwargs: 'Optional[Any]') -> 'AsyncIterator[Output]'
#  |      Default implementation of atransform, which buffers input and calls astream.
#  |      Subclasses should override this method if they can start producing output while
#  |      input is still being generated.
#  |
#  |      Args:
#  |          input: An async iterator of inputs to the Runnable.
#  |          config: The config to use for the Runnable. Defaults to None.
#  |          kwargs: Additional keyword arguments to pass to the Runnable.
#  |
#  |      Yields:
#  |          The output of the Runnable.
#  |
#  |  batch(self, inputs: 'list[Input]', config: 'Optional[Union[RunnableConfig, list[RunnableConfig]]]' = None, *, return_exceptions: 'bool' = False, **kwargs: 'Optional[Any]') -> 'list[Output]'
#  |      Default implementation runs invoke in parallel using a thread pool executor.
#  |
#  |      The default implementation of batch works well for IO bound runnables.
#  |
#  |      Subclasses should override this method if they can batch more efficiently;
#  |      e.g., if the underlying Runnable uses an API which supports a batch mode.
#  |
#  |  batch_as_completed(self, inputs: 'Sequence[Input]', config: 'Optional[Union[RunnableConfig, Sequence[RunnableConfig]]]' = None, *, return_exceptions: 'bool' = False, **kwargs: 'Optional[Any]') -> 'Iterator[tuple[int, Union[Output, Exception]]]'
#  |      Run invoke in parallel on a list of inputs,
#  |      yielding results as they complete.
#  |
#  |  bind(self, **kwargs: 'Any') -> 'Runnable[Input, Output]'
#  |      Bind arguments to a Runnable, returning a new Runnable.
#  |
#  |      Useful when a Runnable in a chain requires an argument that is not
#  |      in the output of the previous Runnable or included in the user input.
#  |
#  |      Args:
#  |          kwargs: The arguments to bind to the Runnable.
#  |
#  |      Returns:
#  |          A new Runnable with the arguments bound.
#  |
#  |      Example:
#  |
#  |      .. code-block:: python
#  |
#  |          from langchain_community.chat_models import ChatOllama
#  |          from langchain_core.output_parsers import StrOutputParser
#  |
#  |          llm = ChatOllama(model='llama2')
#  |
#  |          # Without bind.
#  |          chain = (
#  |              llm
#  |              | StrOutputParser()
#  |          )
#  |
#  |          chain.invoke("Repeat quoted words exactly: 'One two three four five.'")
#  |          # Output is 'One two three four five.'
#  |
#  |          # With bind.
#  |          chain = (
#  |              llm.bind(stop=["three"])
#  |              | StrOutputParser()
#  |          )
#  |
#  |          chain.invoke("Repeat quoted words exactly: 'One two three four five.'")
#  |          # Output is 'One two'
#  |
#  |  config_schema(self, *, include: 'Optional[Sequence[str]]' = None) -> 'type[BaseModel]'
#  |      The type of config this Runnable accepts specified as a pydantic model.
#  |
#  |      To mark a field as configurable, see the `configurable_fields`
#  |      and `configurable_alternatives` methods.
#  |
#  |      Args:
#  |          include: A list of fields to include in the config schema.
#  |
#  |      Returns:
#  |          A pydantic model that can be used to validate config.
#  |
#  |  get_config_jsonschema(self, *, include: 'Optional[Sequence[str]]' = None) -> 'dict[str, Any]'
#  |      Get a JSON schema that represents the config of the Runnable.
#  |
#  |      Args:
#  |          include: A list of fields to include in the config schema.
#  |
#  |      Returns:
#  |          A JSON schema that represents the config of the Runnable.
#  |
#  |      .. versionadded:: 0.3.0
#  |
#  |  get_name(self, suffix: 'Optional[str]' = None, *, name: 'Optional[str]' = None) -> 'str'
#  |      Get the name of the Runnable.
#  |
#  |  get_prompts(self, config: 'Optional[RunnableConfig]' = None) -> 'list[BasePromptTemplate]'
#  |      Return a list of prompts used by this Runnable.
#  |
#  |  map(self) -> 'Runnable[list[Input], list[Output]]'
#  |      Return a new Runnable that maps a list of inputs to a list of outputs,
#  |      by calling invoke() with each input.
#  |
#  |      Returns:
#  |          A new Runnable that maps a list of inputs to a list of outputs.
#  |
#  |      Example:
#  |
#  |          .. code-block:: python
#  |
#  |                  from langchain_core.runnables import RunnableLambda
#  |
#  |                  def _lambda(x: int) -> int:
#  |                      return x + 1
#  |
#  |                  runnable = RunnableLambda(_lambda)
#  |                  print(runnable.map().invoke([1, 2, 3])) # [2, 3, 4]
#  |
#  |  pick(self, keys: 'Union[str, list[str]]') -> 'RunnableSerializable[Any, Any]'
#  |      Pick keys from the output dict of this Runnable.
#  |
#  |      Pick single key:
#  |          .. code-block:: python
#  |
#  |              import json
#  |
#  |              from langchain_core.runnables import RunnableLambda, RunnableMap
#  |
#  |              as_str = RunnableLambda(str)
#  |              as_json = RunnableLambda(json.loads)
#  |              chain = RunnableMap(str=as_str, json=as_json)
#  |
#  |              chain.invoke("[1, 2, 3]")
#  |              # -> {"str": "[1, 2, 3]", "json": [1, 2, 3]}
#  |
#  |              json_only_chain = chain.pick("json")
#  |              json_only_chain.invoke("[1, 2, 3]")
#  |              # -> [1, 2, 3]
#  |
#  |      Pick list of keys:
#  |          .. code-block:: python
#  |
#  |              from typing import Any
#  |
#  |              import json
#  |
#  |              from langchain_core.runnables import RunnableLambda, RunnableMap
#  |
#  |              as_str = RunnableLambda(str)
#  |              as_json = RunnableLambda(json.loads)
#  |              def as_bytes(x: Any) -> bytes:
#  |                  return bytes(x, "utf-8")
#  |
#  |              chain = RunnableMap(
#  |                  str=as_str,
#  |                  json=as_json,
#  |                  bytes=RunnableLambda(as_bytes)
#  |              )
#  |
#  |              chain.invoke("[1, 2, 3]")
#  |              # -> {"str": "[1, 2, 3]", "json": [1, 2, 3], "bytes": b"[1, 2, 3]"}
#  |
#  |              json_and_bytes_chain = chain.pick(["json", "bytes"])
#  |              json_and_bytes_chain.invoke("[1, 2, 3]")
#  |              # -> {"json": [1, 2, 3], "bytes": b"[1, 2, 3]"}
#  |
#  |  pipe(self, *others: 'Union[Runnable[Any, Other], Callable[[Any], Other]]', name: 'Optional[str]' = None) -> 'RunnableSerializable[Input, Other]'
#  |      Compose this Runnable with Runnable-like objects to make a RunnableSequence.
#  |
#  |      Equivalent to `RunnableSequence(self, *others)` or `self | others[0] | ...`
#  |
#  |      Example:
#  |          .. code-block:: python
#  |
#  |              from langchain_core.runnables import RunnableLambda
#  |
#  |              def add_one(x: int) -> int:
#  |                  return x + 1
#  |
#  |              def mul_two(x: int) -> int:
#  |                  return x * 2
#  |
#  |              runnable_1 = RunnableLambda(add_one)
#  |              runnable_2 = RunnableLambda(mul_two)
#  |              sequence = runnable_1.pipe(runnable_2)
#  |              # Or equivalently:
#  |              # sequence = runnable_1 | runnable_2
#  |              # sequence = RunnableSequence(first=runnable_1, last=runnable_2)
#  |              sequence.invoke(1)
#  |              await sequence.ainvoke(1)
#  |              # -> 4
#  |
#  |              sequence.batch([1, 2, 3])
#  |              await sequence.abatch([1, 2, 3])
#  |              # -> [4, 6, 8]
#  |
#  |  transform(self, input: 'Iterator[Input]', config: 'Optional[RunnableConfig]' = None, **kwargs: 'Optional[Any]') -> 'Iterator[Output]'
#  |      Default implementation of transform, which buffers input and then calls stream.
#  |      Subclasses should override this method if they can start producing output while
#  |      input is still being generated.
#  |
#  |      Args:
#  |          input: An iterator of inputs to the Runnable.
#  |          config: The config to use for the Runnable. Defaults to None.
#  |          kwargs: Additional keyword arguments to pass to the Runnable.
#  |
#  |      Yields:
#  |          The output of the Runnable.
#  |
#  |  with_alisteners(self, *, on_start: 'Optional[AsyncListener]' = None, on_end: 'Optional[AsyncListener]' = None, on_error: 'Optional[AsyncListener]' = None) -> 'Runnable[Input, Output]'
#  |      Bind asynchronous lifecycle listeners to a Runnable, returning a new Runnable.
#  |
#  |      on_start: Asynchronously called before the Runnable starts running.
#  |      on_end: Asynchronously called after the Runnable finishes running.
#  |      on_error: Asynchronously called if the Runnable throws an error.
#  |
#  |      The Run object contains information about the run, including its id,
#  |      type, input, output, error, start_time, end_time, and any tags or metadata
#  |      added to the run.
#  |
#  |      Args:
#  |          on_start: Asynchronously called before the Runnable starts running.
#  |              Defaults to None.
#  |          on_end: Asynchronously called after the Runnable finishes running.
#  |              Defaults to None.
#  |          on_error: Asynchronously called if the Runnable throws an error.
#  |              Defaults to None.
#  |
#  |      Returns:
#  |          A new Runnable with the listeners bound.
#  |
#  |      Example:
#  |
#  |      .. code-block:: python
#  |
#  |          from langchain_core.runnables import RunnableLambda
#  |          import time
#  |
#  |          async def test_runnable(time_to_sleep : int):
#  |              print(f"Runnable[{time_to_sleep}s]: starts at {format_t(time.time())}")
#  |              await asyncio.sleep(time_to_sleep)
#  |              print(f"Runnable[{time_to_sleep}s]: ends at {format_t(time.time())}")
#  |
#  |          async def fn_start(run_obj : Runnable):
#  |              print(f"on start callback starts at {format_t(time.time())}
#  |              await asyncio.sleep(3)
#  |              print(f"on start callback ends at {format_t(time.time())}")
#  |
#  |          async def fn_end(run_obj : Runnable):
#  |              print(f"on end callback starts at {format_t(time.time())}
#  |              await asyncio.sleep(2)
#  |              print(f"on end callback ends at {format_t(time.time())}")
#  |
#  |          runnable = RunnableLambda(test_runnable).with_alisteners(
#  |              on_start=fn_start,
#  |              on_end=fn_end
#  |          )
#  |          async def concurrent_runs():
#  |              await asyncio.gather(runnable.ainvoke(2), runnable.ainvoke(3))
#  |
#  |          asyncio.run(concurrent_runs())
#  |          Result:
#  |          on start callback starts at 2024-05-16T14:20:29.637053+00:00
#  |          on start callback starts at 2024-05-16T14:20:29.637150+00:00
#  |          on start callback ends at 2024-05-16T14:20:32.638305+00:00
#  |          on start callback ends at 2024-05-16T14:20:32.638383+00:00
#  |          Runnable[3s]: starts at 2024-05-16T14:20:32.638849+00:00
#  |          Runnable[5s]: starts at 2024-05-16T14:20:32.638999+00:00
#  |          Runnable[3s]: ends at 2024-05-16T14:20:35.640016+00:00
#  |          on end callback starts at 2024-05-16T14:20:35.640534+00:00
#  |          Runnable[5s]: ends at 2024-05-16T14:20:37.640169+00:00
#  |          on end callback starts at 2024-05-16T14:20:37.640574+00:00
#  |          on end callback ends at 2024-05-16T14:20:37.640654+00:00
#  |          on end callback ends at 2024-05-16T14:20:39.641751+00:00
#  |
#  |  with_fallbacks(self, fallbacks: 'Sequence[Runnable[Input, Output]]', *, exceptions_to_handle: 'tuple[type[BaseException], ...]' = (<class 'Exception'>,), exception_key: 'Optional[str]' = None) -> 'RunnableWithFallbacksT[Input, Output]'
#  |      Add fallbacks to a Runnable, returning a new Runnable.
#  |
#  |      The new Runnable will try the original Runnable, and then each fallback
#  |      in order, upon failures.
#  |
#  |      Args:
#  |          fallbacks: A sequence of runnables to try if the original Runnable fails.
#  |          exceptions_to_handle: A tuple of exception types to handle.
#  |              Defaults to (Exception,).
#  |          exception_key: If string is specified then handled exceptions will be passed
#  |              to fallbacks as part of the input under the specified key. If None,
#  |              exceptions will not be passed to fallbacks. If used, the base Runnable
#  |              and its fallbacks must accept a dictionary as input. Defaults to None.
#  |
#  |      Returns:
#  |          A new Runnable that will try the original Runnable, and then each
#  |          fallback in order, upon failures.
#  |
#  |      Example:
#  |
#  |          .. code-block:: python
#  |
#  |              from typing import Iterator
#  |
#  |              from langchain_core.runnables import RunnableGenerator
#  |
#  |
#  |              def _generate_immediate_error(input: Iterator) -> Iterator[str]:
#  |                  raise ValueError()
#  |                  yield ""
#  |
#  |
#  |              def _generate(input: Iterator) -> Iterator[str]:
#  |                  yield from "foo bar"
#  |
#  |
#  |              runnable = RunnableGenerator(_generate_immediate_error).with_fallbacks(
#  |                  [RunnableGenerator(_generate)]
#  |                  )
#  |              print(''.join(runnable.stream({}))) #foo bar
#  |
#  |      Args:
#  |          fallbacks: A sequence of runnables to try if the original Runnable fails.
#  |          exceptions_to_handle: A tuple of exception types to handle.
#  |          exception_key: If string is specified then handled exceptions will be passed
#  |              to fallbacks as part of the input under the specified key. If None,
#  |              exceptions will not be passed to fallbacks. If used, the base Runnable
#  |              and its fallbacks must accept a dictionary as input.
#  |
#  |      Returns:
#  |          A new Runnable that will try the original Runnable, and then each
#  |          fallback in order, upon failures.
#  |
#  |  with_listeners(self, *, on_start: 'Optional[Union[Callable[[Run], None], Callable[[Run, RunnableConfig], None]]]' = None, on_end: 'Optional[Union[Callable[[Run], None], Callable[[Run, RunnableConfig], None]]]' = None, on_error: 'Optional[Union[Callable[[Run], None], Callable[[Run, RunnableConfig], None]]]' = None) -> 'Runnable[Input, Output]'
#  |      Bind lifecycle listeners to a Runnable, returning a new Runnable.
#  |
#  |      on_start: Called before the Runnable starts running, with the Run object.
#  |      on_end: Called after the Runnable finishes running, with the Run object.
#  |      on_error: Called if the Runnable throws an error, with the Run object.
#  |
#  |      The Run object contains information about the run, including its id,
#  |      type, input, output, error, start_time, end_time, and any tags or metadata
#  |      added to the run.
#  |
#  |      Args:
#  |          on_start: Called before the Runnable starts running. Defaults to None.
#  |          on_end: Called after the Runnable finishes running. Defaults to None.
#  |          on_error: Called if the Runnable throws an error. Defaults to None.
#  |
#  |      Returns:
#  |          A new Runnable with the listeners bound.
#  |
#  |      Example:
#  |
#  |      .. code-block:: python
#  |
#  |          from langchain_core.runnables import RunnableLambda
#  |          from langchain_core.tracers.schemas import Run
#  |
#  |          import time
#  |
#  |          def test_runnable(time_to_sleep : int):
#  |              time.sleep(time_to_sleep)
#  |
#  |          def fn_start(run_obj: Run):
#  |              print("start_time:", run_obj.start_time)
#  |
#  |          def fn_end(run_obj: Run):
#  |              print("end_time:", run_obj.end_time)
#  |
#  |          chain = RunnableLambda(test_runnable).with_listeners(
#  |              on_start=fn_start,
#  |              on_end=fn_end
#  |          )
#  |          chain.invoke(2)
#  |
#  |  with_retry(self, *, retry_if_exception_type: 'tuple[type[BaseException], ...]' = (<class 'Exception'>,), wait_exponential_jitter: 'bool' = True, stop_after_attempt: 'int' = 3) -> 'Runnable[Input, Output]'
#  |      Create a new Runnable that retries the original Runnable on exceptions.
#  |
#  |      Args:
#  |          retry_if_exception_type: A tuple of exception types to retry on.
#  |              Defaults to (Exception,).
#  |          wait_exponential_jitter: Whether to add jitter to the wait
#  |              time between retries. Defaults to True.
#  |          stop_after_attempt: The maximum number of attempts to make before
#  |              giving up. Defaults to 3.
#  |
#  |      Returns:
#  |          A new Runnable that retries the original Runnable on exceptions.
#  |
#  |      Example:
#  |
#  |      .. code-block:: python
#  |
#  |          from langchain_core.runnables import RunnableLambda
#  |
#  |          count = 0
#  |
#  |
#  |          def _lambda(x: int) -> None:
#  |              global count
#  |              count = count + 1
#  |              if x == 1:
#  |                  raise ValueError("x is 1")
#  |              else:
#  |                   pass
#  |
#  |
#  |          runnable = RunnableLambda(_lambda)
#  |          try:
#  |              runnable.with_retry(
#  |                  stop_after_attempt=2,
#  |                  retry_if_exception_type=(ValueError,),
#  |              ).invoke(1)
#  |          except ValueError:
#  |              pass
#  |
#  |          assert (count == 2)
#  |
#  |
#  |      Args:
#  |          retry_if_exception_type: A tuple of exception types to retry on
#  |          wait_exponential_jitter: Whether to add jitter to the wait time
#  |                                   between retries
#  |          stop_after_attempt: The maximum number of attempts to make before giving up
#  |
#  |      Returns:
#  |          A new Runnable that retries the original Runnable on exceptions.
#  |
#  |  with_types(self, *, input_type: 'Optional[type[Input]]' = None, output_type: 'Optional[type[Output]]' = None) -> 'Runnable[Input, Output]'
#  |      Bind input and output types to a Runnable, returning a new Runnable.
#  |
#  |      Args:
#  |          input_type: The input type to bind to the Runnable. Defaults to None.
#  |          output_type: The output type to bind to the Runnable. Defaults to None.
#  |
#  |      Returns:
#  |          A new Runnable with the types bound.
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties inherited from langchain_core.runnables.base.Runnable:
#  |
#  |  input_schema
#  |      The type of input this Runnable accepts specified as a pydantic model.
#  |
#  |  output_schema
#  |      The type of output this Runnable produces specified as a pydantic model.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from langchain_core.runnables.base.Runnable:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods inherited from typing.Generic:
#  |
#  |  __class_getitem__(params)
#  |      Parameterizes a generic class.
#  |
#  |      At least, parameterizing a generic class is the *main* thing this method
#  |      does. For example, for some generic class `Foo`, this is called when we
#  |      do `Foo[int]` - there, with `cls=Foo` and `params=int`.
#  |
#  |      However, note that this method is also called when defining generic
#  |      classes in the first place with `class Foo(Generic[T]): ...`.
#  |
#  |  __init_subclass__(*args, **kwargs)
#  |      This method is called when a class is subclassed.
#  |
#  |      The default implementation does nothing. It may be
#  |      overridden to extend subclasses.

# %%
from langchain_teddynote.graphs import visualize_graph

visualize_graph(app)

# %%
# from langchain_core.runnables import RunnableConfig
# from langchain_teddynote.messages import invoke_graph, stream_graph, random_uuid

# # config 설정(재귀 최대 횟수, thread_id)
# config = RunnableConfig(recursion_limit=20, configurable={"thread_id": random_uuid()})

# %%
# inputs = GraphState(question="내가 직전에 한 질문이 뭐였지")

# %%
# print(res.get('answer'))

# %%
from langchain_core.runnables import RunnableConfig
from langchain_teddynote.messages import invoke_graph, stream_graph, random_uuid

# config 설정(재귀 최대 횟수, thread_id)
config = RunnableConfig(recursion_limit=20, configurable={"thread_id": random_uuid()})

# 질문 입력
inputs = GraphState(question="중구에서 3박4일 일정 만들어줘")

a=app.stream(input=inputs, config=config, stream_mode='messages')

# %%
chunk
# Out:
# AIMessageChunk(content='', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_50cad350e4'}, id='run-1239804c-7c7a-4a15-aced-92f4c46f8a94')

# %%
meta.get('langgraph_node')
# Out:
# 'llm_place_answer'

# %%
meta.get('langgraph_node') == 'llm_place_answer'
# Out:
# True

# %%
for chunk, meta in a:

    if meta.get('langgraph_node') == 'llm_Schedule_answer':

        print(chunk.content, end='')
# Out:
# - 1일차
#
#   - 점심:
#     - 점심 식사 장소: **숭례도담**
#       - 주소: 서울 중구 세종대로18길 14
#       - 영업 시간: 매일 11:00 - 22:00 (15:00 - 17:00 브레이크타임)
#       - 음식점 특징: 한식 전문점, 보쌈과 김치찜이 유명
#       - 기타 정보: 시청역, 서울시청, 명동역, 덕수궁 근처에 위치
#     - 명소: **덕수궁**
#       - 영업 시간: 09:00 - 21:00
#       - 명소 특징: 조선시대의 궁궐, 전통과 현대가 어우러진 공간
#       - 명소 위치: 서울 중구 세종대로 99
#       - 기타 정보: 덕수궁 돌담길 산책 추천
#
#   - 저녁:
#     - 저녁 식사 장소: **광화문특고기**
#       - 주소: 서울 중구 서소문로 134-6
#       - 음식점 특징: 소고기구이 전문점, 토마호크 스테이크가 유명
#       - 기타 정보: 시청역 근처, 프라이빗 룸 제공
#     - 명소: **서울시립미술관**
#       - 명소 특징: 다양한 현대 미술 전시
#       - 명소 위치: 서울 중구 덕수궁길 61
#       - 기타 정보: 덕수궁과 인접하여 저녁 산책과 함께 방문 추천
#     - 쇼핑몰: **남대문시장**
#       - 주소: 서울 중구 남대문시장4길 10-1
#       - 쇼핑몰 특징: 다양한 상품과 먹거리가 있는 전통 시장
#     - 숙소: **프레이저플레이스남대문**
#       - 숙소 위치: 서울특별시 중구 세종대로 58
#       - 숙소 정보: 관광호텔업, 편리한 위치
#       - 숙소 특징: 남대문과 가까운 위치, 편리한 교통 접근성
#
#
#
# - 2일차
#
#   - 점심:
#     - 점심 식사 장소: 진작 (일식당)
#       - 주소: 서울 중구 수표로12길 12 1층
#       - 영업 시간: 11:00 - 20:30
#       - 특징: 클래식과 현대적인 감각의 조화, 고급 식재료 사용
#       - 기타 정보: 테이크아웃 할인, 단체 이용 가능, 예약 가능
#     - 명소: 한국의집 고호재
#       - 영업 시간: 11:30 ~ 13:00 (2부)
#       - 특징: 전통 한식 체험
#       - 위치: 서울 중구 퇴계로 지하 214 (충무로역 3,4호선)
#       - 기타 정보: 1인 다과상 제공
#
#   - 저녁:
#     - 저녁 식사 장소: 대구상회 (요리주점)
#       - 주소: 서울 중구 을지로32길 39 1층
#       - 영업 시간: 15:00 - 23:00
#       - 특징: 가정식 오마카세, 신선한 제철 재료 사용
#       - 기타 정보: 예약 필수, 콜키지 가능
#     - 명소: 명동실탄사격장
#       - 특징: 실탄 사격 체험
#       - 위치: 서울 중구 명동8가길 27 선샤인빌딩3층
#       - 기타 정보: 연중무휴, 다양한 사격 체험 가능
#     - 쇼핑몰: 콴챈루거리
#       - 위치: 서울시 중구 명동 일대
#       - 특징: 다양한 쇼핑 및 거리 음식 체험 가능
#
#   - 숙소: 트레블로지 명동 남산
#     - 위치: 서울특별시 중구 충무로3가 58-8
#     - 특징: 관광호텔업, 편리한 위치
#
# - 3일차
#
#   - 점심:
#     - 점심 식사 장소: **중앙왕족발**
#       - 주소: 서울 중구 남대문시장4길 10-1
#       - 영업 시간: 매일 00:00 - 24:00
#       - 특징: 27년 전통의 족발 전문점, 신선한 재료 사용
#       - 기타 정보: 예약 가능, 주차 가능
#     - 명소: **정동길**
#       - 위치: 서울시 중구 소공동 일대
#       - 특징: 서울의 역사와 문화를 느낄 수 있는 거리
#
#   - 저녁:
#     - 저녁 식사 장소: **광화문특고기**
#       - 주소: 서울 중구 서소문로 134-6 광화문특고기 시청본점
#       - 특징: 다양한 고기 요리와 토마호크 스테이크, 프라이빗 룸 제공
#       - 기타 정보: 예약 가능, 단체 이용 가능
#     - 명소: **덕수궁**
#       - 위치: 서울 중구 정동길 99
#       - 특징: 조선 시대의 궁궐, 아름다운 정원과 전통 건축물
#     - 쇼핑몰: **명동 쇼핑 거리**
#       - 특징: 다양한 브랜드와 상점이 밀집한 쇼핑 명소
#
#   - 숙소:
#     - **프레이저플레이스남대문**
#       - 위치: 서울특별시 중구 세종대로 58 (남대문로4가)
#       - 특징: 관광호텔업, 편리한 위치
#
#
# - 4일차
#
#   - 점심:
#     - 점심 식사 장소: **영덕물회막회**
#       - 주소: 서울 중구 청파로 429
#       - 영업 시간: 11:00 - 22:00 (14:00 - 17:00 브레이크타임)
#       - 음식점 특징: 신선한 재료로 만든 물회와 회덮밥이 인기
#       - 기타 정보: 주차 불가
#     - 명소: **송림수제화**
#       - 운영 시간: 10:00 - 18:00 (토요일 10:00 - 17:00)
#       - 명소 특징: 맞춤화 제작, 서울미래유산으로 지정된 오래된 수제화 가게
#       - 명소 위치: 서울특별시 중구 수표로 60-1 (을지로3가 5-10)3~4층
#
#   - 저녁:
#     - 저녁 식사 장소: **행2PM8PM**
#       - 주소: 서울 중구 수표로12길 10 1층~3층
#       - 음식점 특징: 힙지로 1세대 노포 맛집, 다양한 와인과 안주 제공
#       - 기타 정보: 라이브 공연, 루프탑 공간
#     - 명소: **충무로돼지갈비**
#       - 주소: 서울특별시 중구 충무로3가 29-2
#       - 명소 특징: 돼지갈비 전문점, 충무로의 대표적인 맛집
#       - 명소 위치: 충무로3가
#     - 숙소: **스테이비호텔 명동**
#       - 위치: 서울특별시 중구 충무로3가 30-1
#       - 숙소 정보: 관광호텔업, 명동과 충무로 인근에 위치하여 접근성 좋음
#
# []

# %%
from langchain_core.runnables import RunnableConfig
from langchain_teddynote.messages import invoke_graph, stream_graph, random_uuid

# config 설정(재귀 최대 횟수, thread_id)
config = RunnableConfig(recursion_limit=20, configurable={"thread_id": random_uuid()})

# 질문 입력
inputs = GraphState(question="종로구와 중구의 2박3일 일정을 만들어줘")

# 그래프 실행
invoke_graph(app, inputs, config)
# Out:
# ==================================================
# 🔄 Node: location_check 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# location:
# ['종로구', '중구']
# ==================================================
#
# ==================================================
# 🔄 Node: retrieve_document_naver 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# page_content='store_name: 성경만두요리전문점 종로점
#  category: 칼국수,만두
#  new_open:
#  rating: 별점 4.56
#  visited_review: 방문자 리뷰 2,251
#  directions_text: 네이버길찾기로 오시면 편리하게 오실 수 있습니다.
#
# 종로3가 익선동 근처 핫플레이스 특성상 주차요금이 비싸므로 대중교통 이용을 추천드립니다.
#
# 종로3가역(도보 5분)
# -종로3가역 15번 출구로 나와서 도보 5분
#
# 을지로3가역(도보 6분)
# -을지로3가역 4번 출구로 나와 청계천 건너 좌회전
#
# 인사동(도보 7분)
# -탑골공원 사거리 방면
#
# 종각역(도보 10분)
# -종각역 4번출구로 나와 탑골공원방면
#
# 익선동(도보 10분)
# 익선동에서 종로3가역 15번 출구 방면
#
# 자가용 이용시 네비게이션
# 1. 성경만두 종로점(종로구 수표로 88)
# 2. 종로 세종주차장(종로구 수표로 87) (도보 10초거리) (1시간 6,000원)
# 3. 공휴일, 일요일은 청계천 공영주차장 무료 주차 가능
# 내용 더보기
#  address: 서울 종로구 수표로 88
#  blog_review: 블로그 리뷰 1,065
#  phone_num: 0507-1363-9234
#  business_hours: 수(1/1)
# 새해 첫날11:00 - 21:00
# 15:30 - 17:00 브레이크타임
# 목
# 11:00 - 21:20
# 15:30 - 17:00 브레이크타임
# 14:00, 19:50 라스트오더
# 금
# 11:00 - 21:20
# 15:30 - 17:00 브레이크타임
# 14:00, 19:50 라스트오더
# 토
# 11:00 - 21:20
# 15:30 - 17:00 브레이크타임
# 14:00, 19:50 라스트오더
# 일
# 11:00 - 15:30
# 14:00 라스트오더
# 월
# 11:00 - 21:20
# 15:30 - 17:00 브레이크타임
# 14:00, 19:50 라스트오더
# 화
# 11:00 - 21:20
# 15:30 - 17:00 브레이크타임
# 14:00, 19:50 라스트오더
#
#  info: '예전 조선 궁중에서 일하셨던 우리 어머니의 만두와 맛이 비슷하다.'
#
# 저희 만두전골을 드셨던 어느 손님께서 이렇게 말씀하셨습니다.
# 서울의 숨은 보석, 성경만두요리전문점은 맛과 가성비를 동시에 추구하는 많은 분들에게 사랑받는 종로3가 찐맛집으로 자리 잡았습니다.
#
# 하지만 성경만두는 단순히 가격으로만 승부하는 노포 식당이 아닙니다.
#
# 근처 을지로와 인사동에 있는 유명한 만두집들과 비교해도 뒤지지 않는 맛성비와 함께, 술집으로도 변모할 수 있는 편안한 분위기 덕분에 많은 시민들이 점심이나 저녁 시간을 가리지 않고 찾아오고 계십니다. 특히, 소주가 단돈 3천원이라 포장마차 거리 같은 친근함을 드리기도 합니다.
#
# 약 5년 동안 매일 수제 만두를 80만 개 이상 빚었습니다. 사실 장사를 하는 동안 가성비 있는 가격으로 이익을 남기기가 쉽지 않아서 힘들지만 그래도 손님의 맛있었다는 한마디를 위안삼아 열심히 노력하고 있습니다.
#
# * 성경만두에 단골과 재방문이 많은 이유 4가지
#
# 1) 당일 재료는 당일 소진, 냉동 재료 없는 신선함이 원칙
# 당일 소진을 원칙으로 신선한 재료로 매일 빚은 고급 생만두를 합리적 가격으로 제공합니다. 재료비를 아끼기 위해 만두속에 당면 같은 저렴한 재료를 넣지 않습니다. 저희는 오직 신선한 돼지고기, 두부, 채소만을 넣어 잡내 없이 깔끔한 맛의 만두를 만듭니다.
#
# 2) 번거로운 재료 준비 과정
# 모든 재료를 갈아서 만들면 편합니다. 하지만 그렇게 하면 냉동만두 같이 뭉게지는 식감으로 변할 수 있습니다. 때문에 편의를 위해서 만두소를 갈아 넣지 않고 손이 많이 가더라도 대부분 직접 칼로 다져 넣어 아삭한 식감을 느끼실 수 있습니다.
#
# 3) 매일 빚은 생만두를 제공
# 대부분의 만두집들은 보관하기 편하다는 이유로 만두를 미리 쪄놓고 보관합니다. 반면 저희는 매일 빚어 신선한 생만두 그대로 제공해 드립니다. 때문에 손님을 속일수가 없습니다. 말랑말랑 만져보시면 바로 아시기 때문입니다. 내돈내산 아깝지 않은 한식 만두전골입니다.
#
# 4) 소주가 3천원
# '서울 종로에서 아직도 이 가격을 받는 식당이 있네?'
# 많은 손님들께서 가장 놀라시는 부분 중 하나입니다. 만두전골에 자신있기 때문에 더욱 많은 손님이 즐기러 오셨으면 하는 마음으로 소주를 착한 가격으로 받고 있습니다.
#
# 서울시 종로구 관수동 145-1
#
# 1) 종로3가역 15번 출구에서 5분 만에 도착! 종각역 4번출구 도보 10분 거리!
#
# 2) 을지로3가역 4번출구 도보 5분거리, 일요일 및 공휴일은 청계천 노상 공영주차장 주변 무료 주차가능
#
# * 예약없이 오셔도 식사 가능합니다! 5인 이상 고객님들은 오시기 전에 전화해주시면 최대한 도와드리겠습니다.
#
# * 만두, 좋아하세요?
# 가게를 운영하며 다른 유명 만두집들을 많이 다녀 보았습니다. 어떤 곳은 단맛이 강하고, 만두피가 두꺼웠으며, 김치 만두에서 잡내가 나기도 했습니다. 저희 만두는 혹시 만두를 좋아하지 않으신 분이라도 대부분 호불호 없이 맛있게 드실 수 있을것이라 자부합니다. 공장에서 빚어오는 완제품과는 차원이 다른 순수한 맛을 느끼실 수 있을 것입니다. 설레는 주말에 서울에서 가장 사랑받는 만두전골집 중에 하나인 성경만두에 오셔서 연인과의 데이트, 가족과의 편안하고 특별한 외식 시간, 가성비 넘치는 착한 가격의 점심 및 저녁 식사를 즐기세요.
#
# 성경만두는 종로3가역 15번출구에서 도보 5분 위치에 있습니다. 서울 종묘, 피카디리, 피맛골 주변 나들이 갔을 때 맛집을 찾으신다면 성경만두를 선택해주세요. 주말 데이트나 단체 모임, 기념일 등 카페 방문 전에 들르기 좋은 장소 중 하나임을 자신합니다.
#
# 왜 많은 분들이 성경만두를 찾는지, 직접 방문해 그 이유를 확인해보세요!
#
# 주력 메뉴
#
# 하얀 만두전골
# 맑고 시원한 느낌의 해물 육수와 수제 생만두, 다양한 채소, 버섯, 소고기, 칼국수와 함께 즐기는 샤브샤브 만두전골
#
# 빨간 만두전골
# 얼큰하고 시원한 비법 해물육수와 함께 즐기는 샤브샤브 만두전골
#
# 양곱창만두전골
# 얼큰한 만두전골에 소곱창, 소양을 곁들여 감칠맛 폭발 경험. 반드시 다시 찾는 곱창전골!
# 펼쳐보기
#  convenience_facilities_and_services: 단체 이용 가능
# 예약
# 무선 인터넷
# 포장
# 배달
# 남/녀 화장실 구분
# 출입구 휠체어 이용가능
#
#  Parking: 주차가능
# 유료
# 최초 60분 6000원
# 추가 요금 10분당 1,000원, 최대 100,000원
#  sns: https://www.instagram.com/skmandoo_jongno
# https://blog.naver.com/sgjongro55
# https://sgjongro.modoo.at/
# http://www.facebook.com/jongrosgmandoo
#
#  review_like_this_part_output: "음식이 맛있어요"1324
# "재료가 신선해요"625
# "가성비가 좋아요"522
# "양이 많아요"521
# "친절해요"350
# "특별한 메뉴가 있어요"247
# "매장이 넓어요"204
# "단체모임 하기 좋아요"144
# "건강한 맛이에요"111
# "매장이 청결해요"109
#  menu: nan' metadata={'store_id': '1336373058', 'store_name': '성경만두요리전문점 종로점'}
# page_content='store_name: 종로3가 장군굴보쌈
#  category: 족발,보쌈
#  new_open:
#  rating: 별점 4.41
#  visited_review: 방문자 리뷰 1,723
#  directions_text: 종로3가 15번 출구 바로 왼쪽편 골목으로 오시면 종로3가 보쌈골목이 나옵니다.
# 종로3가 보쌈골목을 따라 중간쯤 오시면 저희 장군굴보쌈을 만나실 수 있습니다.
# 종로3가 국일관 옆 골목으로 들어오셔도 찾기 수월하십니다.
# 내용 더보기
#  address: 서울 종로구 수표로20길 22
#  blog_review: 블로그 리뷰 1,472
#  phone_num: 0507-1366-9548
#  business_hours: 수(1/1)
# 새해 첫날11:30 - 23:00
# 목
# 11:30 - 23:00
# 금
# 11:30 - 23:00
# 토
# 11:30 - 23:00
# 일
# 11:30 - 23:00
# 월
# 11:30 - 23:00
# 화
# 11:30 - 23:00
#
#  info: 종로3가에 위치한 전통 있는 굴보쌈 전문점입니다. 30년이 넘는 전통을 지닌 곳으로, TV 맛집 프로그램에도 소개되었다고 하지요.
#
# 통영에서 산지 직송한 굴을 특제 양념에 버무려 돼지고기 수육과 함께 담아 내며, 감자탕과 오징어볶음은 무료로 제공됩니다.
#
# 앞으로도 고객님들의 관심과 사랑에 보답하기 위해
# 더 좋은 맛과 서비스를 제공해드릴 것을 약속드리며
# 최상의 맛과 친절함을 드리는 장군굴보쌈이 되겠습니다.
#
# 종로3가 15번 출구로 나오시면 쉽게 찾아오실 수 있습니다.
#
# 감사합니다.
# 펼쳐보기
#  convenience_facilities_and_services: 단체 이용 가능
# 포장
#
#  Parking: 주차 정보없음
#  sns: https://blog.naver.com/leews3313
#
#  review_like_this_part_output: "음식이 맛있어요"976
# "가성비가 좋아요"394
# "양이 많아요"268
# "친절해요"191
# "특별한 메뉴가 있어요"177
# "매장이 넓어요"169
# "고기 질이 좋아요"141
# "재료가 신선해요"140
# "단체모임 하기 좋아요"131
# "매장이 청결해요"27
#  menu: 스폐셜 모듬대표※ 굴+멍게+족발+보쌈[특]
# 서비스 오징어볶음, 감자탕까지 푸짐한 구성55,000원
# 굴보쌈 (소)대표매콤한 오징어볶음과 감자탕 서비스29,000원
# 고기보쌈 소29,000원
# 고기보쌈 중38,000원
# 고기보쌈 대45,000원
# 장군스페셜 모듬 특대70,000원
# 굴보쌈 (중)38,000원
# 굴보쌈 (대)45,000원
# 굴족발 (중)38,000원
# 굴족발 (대)45,000원
# 낙지볶음40,000원
# 굴보쌈 추가20,000원
# 오징어볶음 추가15,000원
# 굴사리 추가20,000원
# 굴멍게사리 추가25,000원
# ' metadata={'store_id': '31658139', 'store_name': '종로3가 장군굴보쌈'}
# page_content='store_name: 종로도담
#  category: 한식
#  new_open:
#  rating: 별점 4.45
#  visited_review: 방문자 리뷰 1,850
#  directions_text: 종각역2번출구로 나와 직진후 사거리가 나오면 좌회전 하시면됩니다. 20m정도 이동하시면 횡단보도 앞에 위치해있습니다.
#  address: 서울 종로구 삼봉로 78
#  blog_review: 블로그 리뷰 2,048
#  phone_num: 0507-1321-9850
#  business_hours: 매일
# 11:00 - 22:00
# 15:00 - 17:00 브레이크타임
# 21:00 라스트오더
#
#  info: 종로, 종각, 광화문 회사근처 낮술하기 좋은 종로도담입니다.
#
# 1층 24분 / 2층 42분 / 테라스 까지 다양한 공간을 이용하실 수 있습니다.
#
# 주차장 안내 : 주차장 이용은 (유료) 입니다. 네이버에서 '종로도담 주차장' 검색하시면 택대리네 공식 블로그에 안내 되어있습니다.
#
# 개성보쌈만 6년째 삶고 있는 좋은사람들과 함께 시간을 보내기 좋은 곳을 목표로 운영하고 있습니다.
# 택대리네 종로도담은 개성보쌈, 김치찜. 낙지볶음, 부추전, 백골뱅이무침, 흑임자고기튀김, 다양한 주류를 전문으로 하는 종로 한식당입니다. 고객이 즐겁고 직원들도 즐거운 식당을 만들자는 목표로 30대 이하 젊은 직원과 60대 이상 어르신이 함께 모여 만든 정겨운 곳입니다. 현재 택대리네는 40여명의 직원들이 키워나가고 있습니다.
#
# 종로도담은 서울 종로구에 위치한 맛집으로 종로, 종각, 광화문에서 근무하시는 직장인분들의 입소문을 거쳐 국내외 관광객들 사이에서 큰 인기를 끌고 있습니다.
#
# 종로도담의 주력 메뉴중 개성보쌈에는 개운한 묵은지, 개성보쌈특제소스, 수제 무말랭이, 정구지무침이 함께 제공되고 있으며 개성보쌈과 함께 제공되는 특제소스는 이곳의 별미로 많은 분들의 사랑을 받고 있습니다.
#
# 종로도담은 광화문역과 종각역 사이 수많은 빌딩 숲에 숨은 식당입니다. 매일 외식이 일상이 되어버린 직장인들에게 평범하고 흔하게 먹을 수 있는 집밥 컨셉으로 모임의 장소를 제공하고 있습니다. 오전 11시, 점심시간에 맞춰 오픈하기 때문에 주변 회사원들을 대상으로 영업을 하고있으며, 특히 점심 식사에는 공깃밥이 무제한이고, 동동주까지 서비스로 제공되어지고 있습니다.
#
# 종로도담은 따뜻한 집밥이 그리운 이들을 위한 식사 메뉴로 특히 점심특선으로 제공되는 김치찜은 무제한 공깃밥, 셀프막걸리 외에도 뭇국과 흑임자고기튀김이 함께 제공되어 배불리 드실 수 있도록 구성하였습니다.
#
# 종로도담은 대규모 인원들이 회식 할 수 있는 공간이 있어서 직장인분들의 단체회식 장소로 방문하기 좋습니다. 2층에는 단체회식 장소뿐만 아니라 살랑부는 바람에 막걸리 드실 수 있도록 테라스도 준비되어있습니다.
#
# 종로도담은 개성보쌈뿐만 아니라 부추전, 김치찜, 낙지볶음, 백골뱅이무침, 다양한 종류의 주류 전문으로 구성하고 있습니다.
#
# 맛에 놀라움: 개성보쌈에 사용되는 돼지고기는 매일 아침 신선하게 들여와 잡내 없이 부드럽게 삶아 준비되어지고있습니다. 특제소스와 함께 먹는 보쌈의 맛은 일품이며 그외에 정성스럽게 준비한 정구지무침, 무말랭이 김치, 묵은지 구성으로 맛깔나게 준비하고 있습니다.
# 신맛과 매콤한 맛의 조화로운 김치에 두툼한 돼지고기 수육이 어우러진 김치찜은 적절한 온도의 김치 숙성과 종로도담만의 레시피로 고객님들께 최고의 김치찜를 제공해드립니다. 김치찜에 사용되는 돼지고기는 매일 아침 신선하게 들여와 화려한 불조절로 잡내 없이 부드럽게 푹 삶아 제공되어지고 있습니다.
#
# 종로도담의 부추전은 인생부추전이라는 타이틀이 생길정도로 튀겨내듯 바삭하게 구워 이곳에 시그니쳐 메뉴로 자리잡았습니다.
#
# 분위기와 경험: 수많은 빌딩 숲에 사이에 테라스가 있는 아늑한 독채식당입니다. 이곳에서 드시는 개성보쌈과 김치찜은 정통적인 방식으로 만들어져 식사하시는 동안 편안하고, 따뜻한 느낌을 줍니다. 최근 외국인분들도 직접 검색하고 많이 찾아오십니다. 종로도담의 다양한 한식구성과 양으로 종로,종각,광화문 직장인 점심,저녁맛집에 더불어 외국인분들도 한식의 다양한 맛을 느끼셨으면 좋겠습니다.
#
# 우리 식당의 장점
# 다양한 주류가 잘 어울리는 한식을 전문으로 하는 종로 맛집으로 인근 직장인과 국내외 관광객 그리고 20~60대 등 전 연령층에게 많은 사랑을 받아 오고 있습니다. 대규모 인원들이 즐겁게 식사를 하실 수 있는 넓을자리가 준비되어있어 직장인 회식, 모임을 하신다면 오붓하고 즐거운 시간을 보내실 수 있습니다.
#
# 택대리네는 현재 종로와 중구 서울의 4대문 안에서 남산도담, 혜화도담, 숭례도담, 인사도담, 삼봉도담, 운종가를 운영되어지고있습니다.
# 펼쳐보기
#  convenience_facilities_and_services: 콜키지 가능
# 무료
# 예약
# 단체 이용 가능
# 남/녀 화장실 구분
# 무선 인터넷
# 포장
#
#  Parking: 주차 불가
#  sns: https://blog.naver.com/taekdaeri
# https://jongrododam.modoo.at/
# https://www.instagram.com/taekdaeri_official
#
#  review_like_this_part_output:
#  menu: 김치찜 소대표새콤달콤하게 잘익은 묵은지와 부드럽게 찢어지는 국내산 통전지, 도담의 비법양념이 들어간 찜22,000원
# 부추전대표건강에 좋은 부추를 가득 넣어 튀기듯 바삭하게 구워낸 영양 만점 부추전입니다.13,000원
# 평일김치찜정식(김치찜+뭇국+고기튀김)(11시~2시) 평일 점심에는 공깃밥과 막걸리(셀프)가 무한제공됩니다.12,000원
# 평일점심부추전건강에 좋은 부추를 가득 넣어 튀기듯 바삭하게 구워낸 영양 만점 부추전입니다.12,000원
# 맛보기보쌈퍽퍽하지않게 비계와 살코기가 적당히 섞인 삼겹살을 1시간이상 푹삶아 부드러운 보쌈고기입니다12,000원
# 미니흑임자고기튀김8,000원
# 낙지볶음 소매콤한 고추가루와 잘익은 과일을 갈아 칼칼하고부드러운 양념과 통통한 낙지와 불맛의 최강조합28,000원
# 개성보쌈 소함평에서 공수해 온 마늘을 숙성시켜 만든소스와보쌈, 묵은지,무말랭이, 보쌈김치 제공.29,000원
# 메밀전병튀김15,000원
# 바지락백합찜해감한 바지락을 올리브오일에 볶아 맛술에 살짝 쪄낸 술찜23,000원
# 명란구이저염 명란을 사용하여 오이, 양파와 함께 곁들여 먹는 명란구이20,000원
# 흑임자 고기튀김20,000원
# 2인한상개성보쌈 소 + 부추전 + 소주 또는 맥주 또는 막걸리46,000원
# 3인한상개성보쌈 소 + 김치찜 소 + 부추전 + 소주 또는 맥주 또는 막걸리68,000원
# 4인한상개성보쌈 소 + 낙지볶음 소 + 명란구이 + 부추전 + 소주 또는 맥주또는 막걸리93,000원
# ' metadata={'store_id': '1614498920', 'store_name': '종로도담'}
# page_content='store_name: 오봉집 종로점
#  category: 한식
#  new_open:
#  rating: 정보없음
#  visited_review: 방문자 리뷰 2,999
#  directions_text: 지하철을 이용시 종각역 4번출구로 나와 할리스커피 가기전
# 오른쪽 골목으로 직진하시다가 약 100m 오시면 오른쪽 1층에 오봉집 종로점이 있습니다
#
# 종로3가역 15번출구로 나와 쭈욱 600m오시다가 할리스커피 지나 좁은 골목으로 약 100m 오시면은 오른쪽 1층에 오봉집 종로점 있습니다
# 길을 못찾으시면 언제든지 전화주세요 :)
#  0507-1393-0555
# *이런 분들 께 오봉집 종로점을 추천 드립니다!
# 1. 종로 종각 모임 맛집을 계획하신 미식가들!
# 2. 종로 종각 단체 회식 맛집을 진행중이신 직장인들!
# 3. 주말에 어린아이들부터 어른들까지 가족들 모두가 방문 할수 있는 종로 종각 가족식사 맛집!
# 4. 청계천 데이트 코스 맛집으로 오봉집 종로집을 찾는 커플!
# 5. 종로 종각 점심 맛집을 찾고 계신 직장인들!
# 내용 더보기
#  address: 서울 종로구 종로8길 20 1층
#  blog_review: 블로그 리뷰 981
#  phone_num: 0507-1393-0555
#  business_hours: 수(1/1)
# 새해 첫날12:00 - 22:00
# 목
# 11:00 - 22:30
# 15:00 - 16:30 브레이크타임
# 21:50 라스트오더
# 금
# 11:00 - 22:30
# 15:00 - 16:30 브레이크타임
# 21:50 라스트오더
# 토
# 12:00 - 22:30
# 21:50 라스트오더
# 일
# 12:00 - 22:00
# 21:20 라스트오더
# 월
# 11:00 - 22:30
# 15:00 - 16:30 브레이크타임
# 21:50 라스트오더
# 화
# 11:00 - 22:30
# 15:00 - 16:30 브레이크타임
# 21:50 라스트오더
#
#  info: 한국소비자만족지수 4년 연속 1위
# 안녕하세요. 종로 종각 핫플레이스 '오봉집 종로점'입니다.
# 오봉집 종로점은 직화낙지볶음과 프리미엄 가브리살 보쌈(수육)을 통하여, 최고의 맛을 찾아주시는 모든 고객분들께 선사하고 있습니다.
#
# 최근에 많은 분들이 찾아주셔서 감사하게도 유튜버 만리님,쯔양님,푸디랜드,윤코치님,야식이님,히밥님 등 많이들 방문해주셨습니다.
# 이번에 놀면뭐하니에서도 방영되서 유재석님과 하하님께서 식사하시고 간집입니다.
#
# 맛 뿐만 아니라, 오봉스페셜(직화낙지볶음+보쌈+막국수)로 가성비 있고 편안한 분위기 연출을 통하여 오감 만족의 즐거움을 드리고 위해서 노력하고 있습니다.
#
# -메뉴 구성-
# 1.오봉스페셜(직화낙지+보쌈+쟁반막국수)
# 말 그대로 오봉집 스페셜 메뉴로 푸짐하고 가성비 있는 구성으로
# 고소한 보쌈과 불맛 제대로인 직화낙지에 새콤달콤한 막국수로 어느것 하나 모자란 없는 자랑스러운 메뉴입니다.
#
# 2.매생이연포보쌈(연포탕+보쌈+죽+칼국수)
# 추운 겨울철에 너무나도 잘 어울리는 메뉴로 속을 따뜻하게 해주면서 동시에 든든하게 해주는 겨울철 스페셜메뉴입니다.
#
# 3.직화낙지볶음
# 오봉집만의 특제소스에 통통한 낙지를 화력으로 빠르게 조리하여 불맛 제대로인 오봉집 베스트메뉴입니다.
#
# 4.직화제낙볶음
# 자양강장제인 낙지에 누구나 좋아하는 고기를 같이 볶아 육해를 전부 만족시키는 메뉴
#
# 5.직화제육볶음
# 나는 고기파다!라고 하는 사람들이 너무나도 많이 찾는 메뉴
#
# 6.오봉보쌈
# 삼겹,목살이 아닌 특수부위인 가브리살로 극강의 부드러움과 고소함을 자랑하는 오봉집만의 특별메뉴
#
# 7.쟁반막국수
# 부족한 탄수화물과 입을 상큼하게 해줄 막국수까지!
#
# *이런 분들 께 오봉집 종로점을 추천 드립니다!
# 1. 종로 종각 모임 맛집을 계획하신 미식가들!
# 2. 종로 종각 단체 회식 맛집을 진행중이신 직장인들!
# 3. 주말에 어린아이들부터 어른들까지 가족들 모두가 방문 할수 있는 종로 종각 가족식사 맛집!
# 4. 청계천 데이트 코스 맛집으로 오봉집 종로집을 찾는 커플!
# 5. 종로 종각 점심 맛집을 찾고 계신 직장인들!
# 최고의 맛과 서비스를 제공하기 위하여 언제나 노력하는 오봉집 종로점이 되도록 노력 하겠습니다.
#
# 점심에 오셔서 식사류를 드시면 밥,반찬이 무한제공되니 허리끈 풀르고 오셔도 됩니다. 평일뿐만 아니라 주말까지합니다.
#
# -예약안내-
# 네이버예약을 통하여 소모임 또는 단체모임을 미리 잡아두신다면은
# 센스 있는 사람이 되겠죠?
#
# 예약시 알림받기와 저장하기를 눌러주시면
# 사리,주먹밥,볶음밥 주류 를 서비스로 드리고 있습니다.
# 전화로도 예약가능하니 매장으로 전화 주셔도 됩니다.
#
# 예약전화는 11:30~13:30부터 17:30~20:00 까지는 전화를 잘 받지 못합니다. 혹시라도 못 받는다고 너무 화내지말아주세요 ㅠㅠ
#
# 식사와 분위기를 더 많은 분들이 이용하는 바램이오니 양해부탁드리겠습니다.
# 감사합니다.
#
# 여름에는 미역국 대신 오이냉국으로 나가고 있습니다.
#
# 종로회식장소,서울분위기좋은맛집,서울맛집top100,을지로3가맛집,
# 서울종로맛집,종로한식,서울가볼만한곳,종로구맛집,서울데이트,종로술집,종로회식,종각술집,종각밥집,서울종로구맛집,종로모임장소,종각회식,종로데이트,종로가볼만한곳,종로3가회식,굴보쌈,종로보쌈,종각모임,종로데이트코스,종로단체회식,종각점심맛집,종각역맛집
# 펼쳐보기
#  convenience_facilities_and_services: 단체 이용 가능
# 포장
# 배달
# 무선 인터넷
# 예약
# 남/녀 화장실 구분
# 대기공간
#
#  Parking: 주차 불가
#  sns: https://www.instagram.com/obongzip_jongno
#
#  review_like_this_part_output:
#  menu: 오봉스페셜대표직화낙지+보쌈+쟁반막국수59,000원
# 매생이연포보쌈대표연포탕+보쌈+죽+칼국수59,000원
# 오봉보쌈(소) 33,000원 / (중) 38,000원 / (대) 44,000원33,000원
# 매생이연포탕연포탕+칼국수32,000원
# 얼큰낙지전골32,000원
# 오봉조개탕22,000원
# 직화낙지볶음점심특선시 12,000원14,000원
# 직화오징어볶음점심특선시 12,000원14,000원
# 직화제낙볶음점심특선시 12,000원14,000원
# 직화오제볶음점심특선시 12,000원14,000원
# 직화제육볶음점심특선시 11,000원12,000원
# 보쌈정식점심특선시 11,000원12,000원
# 바지락 칼국수(2인이상)10,000원
# 쟁반막국수9,000원
# 직화오돌뼈주먹밥17,000원
# ' metadata={'store_id': '1558521785', 'store_name': '오봉집 종로점'}
# page_content='store_name: 서울회관
#  category: 요리주점
#  new_open:
#  rating: 별점 4.38
#  visited_review: 방문자 리뷰 250
#  directions_text: <대중교통 안내>
#
# [버스]
# 조계사 종로경찰서 정류장에서 하차 후, 약 50m 직진하여 오른쪽으로 15m 이동하시면, 매장이 1층 정면에 위치해 있습니다.
#
# [도보]
# 종각역 2번 출구에서 나와 50m 직진 후, 좌회전하여 서울회관 쪽갈비 건물 3층으로 오시면 됩니다.
#
# <주차장 안내>
#
# 1. 황소민영주차장
# 위치: 종로구 종로5길 32-9
# 운영: 연중무휴, 저녁 10시 마감
# 요금: 기본 30분 2,000원 / 추가 10분당 1,000원
#
# 2. 94빌딩 주차장
# 위치: 종로구 삼봉로 94
# 운영: 연중무휴, 저녁 11시 마감 (마감 후 주차장 폐쇄)
# 요금: 기본 30분 3,000원 / 추가 10분당 1,000원
# 모두의주차장 앱 설치 시, 평일 당일권을 13,000원에 구매하실 수 있습니다.
# 내용 더보기
#  address: 서울 종로구 삼봉로 98 3층
#  blog_review: 블로그 리뷰 55
#  phone_num: 02-722-2019
#  business_hours: 일
# 정기휴무 (매주 일요일)
# 월
# 16:00 - 24:00
# 23:00 라스트오더
# 화
# 16:00 - 24:00
# 23:00 라스트오더
# 수(1/1)
# 새해 첫날 휴무
# 목
# 16:00 - 24:00
# 23:00 라스트오더
# 금
# 16:00 - 24:00
# 23:00 라스트오더
# 토
# 정기휴무 (매주 토요일)
#
#  info: 정보없음
#  convenience_facilities_and_services: 정보없음
#  Parking: 정보없음
#  sns: 정보없음
#  review_like_this_part_output: "음식이 맛있어요"113
# "가성비가 좋아요"55
# "단체모임 하기 좋아요"43
# "인테리어가 멋져요"39
# "기본 안주가 좋아요"28
# "대화하기 좋아요"28
# "특별한 메뉴가 있어요"23
# "음악이 좋아요"18
# "친절해요"17
# "화장실이 깨끗해요"10
#  menu: 옛날 가마솥 통닭대표옛날방식 그대로 가마솥에 닭한마리를 통으로 튀겨서 나오는 통닭16,000원
# 건강 충전 마늘 통닭가마솥에 튀겨낸 옛날 방식의 통닭에 풍미 가득한 마늘 소스를 더한 새로운 맛18,000원
# 유동골뱅이 무침옛날통닭의 영원한 단짝 매콤새콤 골뱅이무침23,000원
# 맛 태서울회관맛으로 풀어낸 마른안주의 정석16,000원
# 대왕 돈가스쉽게 찾아보기 힘든 압도적인 크기의 왕돈가스18,000원
# 국물 떡볶이입맛 돋우는 소스가 매콤하고 일품인 푸짐한 국물 떡볶이20,000원
# 해물 오뎅탕대합,꽃게,새우등 해산물과 여러가지 채소들과 오뎅의 만남23,000원
# 모듬 소시지다른 종류의 소시지들이 한 판에 들어가 있어 다양한 맛을 즐길 수 있는 모듬 소시지18,000원
# 모듬 감자튀김다양한 종류의 감자튀김이 있어 골라먹는 재미가 있는 모듬 감자튀김16,000원
# ' metadata={'store_id': '1824175974', 'store_name': '서울회관'}
# page_content='store_name: 천년동안도
#  category: 바(BAR)
#  new_open:
#  rating: 정보없음
#  visited_review: 방문자 리뷰 437
#  directions_text: 청계2가 삼일빌딩 뒷건물에 있습니다.
# 청계2가쪽에서 가장 큰 검정색 건물(Sk네트웍스 등이 있는 건물, 한화건물 맞은편) 바로 뒤쪽에 위치해 있습니다.
# 내용 더보기
#  address: 서울 종로구 삼일대로15길 6 지하1층, 2층
#  blog_review: 블로그 리뷰 253
#  phone_num: 0507-1433-0619
#  business_hours: 일
# 18:00 - 24:00
# 23:30 라스트오더
# 월
# 18:00 - 24:00
# 23:30 라스트오더
# 화
# 18:00 - 24:00
# 23:30 라스트오더
# 수
# 18:00 - 24:00
# 23:30 라스트오더
# 목
# 18:00 - 24:00
# 23:30 라스트오더
# 금
# 18:00 - 24:00
# 23:30 라스트오더
# 토
# 17:00 - 24:00
# 23:30 라스트오더
#
#  info: 천년동안도는 1996년 대학로에서 처음 문을 열었습니다.
# 현재 낙원,종각,강남 3개 지점으로 운영되고 있습니다.
#
# 종각점은 대한민국 최고의 뮤지션들의 공연을 눈 앞에서 관람이 가능하며,
# 아무때라도 듣고 싶은 LP를 직접 골라서 청음공간에서 헤드폰을 통해 들으실 수 있습니다.
#
# 천년동안도라는 이름에 걸맞는 공간이 되도록 최선을 다하겠습니다.
#
# 감사합니다.
#
# 예약없이 당일 방문 가능하십니다.
# 펼쳐보기
#  convenience_facilities_and_services: 단체 이용 가능
# 예약
# 남/녀 화장실 구분
# 무선 인터넷
#
#  Parking: 주차가능
# 유료
# 정액 과금 7,000원
#  sns: http://www.chunnyun.com/
# https://www.instagram.com/chunnyun.jonggak
#
#  review_like_this_part_output: "라이브공연이 훌륭해요"341
# "음악이 좋아요"294
# "특별한 날 가기 좋아요"131
# "음식이 맛있어요"126
# "친절해요"122
# "인테리어가 멋져요"97
# "술이 다양해요"87
# "혼술하기 좋아요"44
# "매장이 청결해요"41
# "비싼 만큼 가치있어요"40
#  menu: 피자페퍼로니피자, 콰트로치즈피자, 하몽샐러드피자, 라구피자, 제시데이비스피자25,000~27,000원
# 칵테일칵테일18,000~23,000원
# 공연료공연시작 시간 월~금PM 8:30
# 토,일 PM 7:0015,000원
# 와인와인 바틀 50,000~변동
# ' metadata={'store_id': '1789291657', 'store_name': '천년동안도'}
# page_content='store_name: 행2PM8PM
#  category: 술집
#  new_open:
#  rating: 별점 4.66
#  visited_review: 방문자 리뷰 1,258
#  directions_text: 중구 수표로12길 10. 1~3층
# 루프탑까지 통건물이며 1층이 출입구입니다.
#
# 을지로3가역과 명동역, 충무로역에서 도보로 약 3분거리 오실수 있으며,
#
# 근처 세운상가, 을지로 노가리골목하고도 가까운 힙지로 메인골목에 위치해있습니다.(나인트리호텔 뒷골목)
#
# 시침이 두개이며, 두시와 여덟시를 가르키는 시계로 되어있는 간판을 찾아주세요!
# 진작과 정라진 사이 건물입니다.
#
# 근처 도보3분거리 주차장안내
# [마른내길공영주차장 무료이용시간]
# 월~금 저녁7시 이후, 토요일3시 이후, 일요일 무료
# 내용 더보기
#  address: 서울 중구 수표로12길 10 1층~3층
#  blog_review: 블로그 리뷰 6,020
#  phone_num: 0507-1331-6915
#  business_hours: 수(1/1)
# 새해 첫날15:00 - 23:00
# 목
# 15:00 - 23:00
# 금
# 15:00 - 23:00
# 토
# 13:30 - 24:00
# 일
# 13:30 - 23:00
# 월
# 15:00 - 23:00
# 화
# 15:00 - 23:00
#
#  info: 힙지로 1세대 노포 맛집인 대표 와인펍
# 너목보, 초대형노래방vs, 싱어게인 등의 40팀의 인디가수들 라이브공연이 있는 2층과
# 동남아 분위기의 3층 루프탑이 있는
# 대형 공간입니다.
#
# 힙지로 명물인 몽둥이고기,
# 이탈리아 정통 가정식스타일의 라자냐파스타 등 다양한 식사와 간편한 안주류도 준비되어있습니드.
# 술 없이 식사만도 가능합니다.(논알콜 맥주, 커피, 과일에이드도 판매)
#
# *공연시간[월~금8시, 토 7시/9시, 일 7시]
# *낮술가능 / 외부케이크 반입가능 / 와인포장시 20%할인*
# *예약없이 현장방문 가능하나, 당일예약이나 회식,생일파티,결혼식 뒤풀이 등 단체 예약은 전화로 문의주세요*
# 펼쳐보기
#  convenience_facilities_and_services: 콜키지 가능
# 유료
# 생일 혜택
# 무한 리필
# 테이크아웃 할인
# 와인 페어링
# 단체 이용 가능
# 예약
# 무선 인터넷
# 포장
# 좌석 휠체어 이용가능
#
#  Parking: 주차가능
# 무료
#  sns: http://www.instagram.com/hang_2pm8pm
# https://youtube.com/channel/UCEIcCQOq1M9VVCPkYDkuAQA
#
#  review_like_this_part_output: "음식이 맛있어요"409
# "특별한 메뉴가 있어요"309
# "음악이 좋아요"262
# "술이 다양해요"260
# "라이브공연이 훌륭해요"244
# "인테리어가 멋져요"240
# "친절해요"174
# "가성비가 좋아요"160
# "단체모임 하기 좋아요"117
# "특별한 날 가기 좋아요"103
#  menu: 몽둥이고기 [ 25cm 크기 ]대표행의 대표시그니처 메뉴인 몽둥이구이입니다. 부드러운 살코기와 쫀쫀할 다릿살,
# 팔뚝만한 크기의 몽둥이를 들고 사진을 꼭 찍어보세요.22,000원
# 미국식 버팔로윙봉&나초16,500원
# 치즈폭탄 감자튀김꾸덕한 치즈 폭탄과 시즈닝, 갓튀긴 감튀까지8,000원
# 와인1병와인1병의 29000원부터 3만원대의 와인이 다수입니다. 가성비와인들부터 포트와인,내추럴와인도 판매합니다. 을지로에서 저렴한 가격에 좋은 와인을 먹을수있는 곳이에요(글라스와인도있음29,000원
# 이탈리아정통 라자냐 파스타건강한 재료를 듬뿍 넣어 맛을낸 이탈리안 가정식 볼로네제 라자냐 파스타18,000원
# 나초 앤 치즈소스나초와 진득한 치즈를 푸짐하게 먹을수 있는 간편한 메뉴7,000원
# 버드와이저생맥무제한레드락생맥주 무제한(1인15,000원 / 일행전체주문시) 잔맥주 주문도 가능합니다(6,000원) 레드락생맥주 외, 호가든,블루문,스텔라,빅웨이브,에딩거논알콜 맥주도 판매합니다.17,000원
# 행하이볼 무제한일행전체주문 / 1시간30분 무제한 / 1인당 23,000원23,000원
# 논알콜 로제와인술을 못드셔도 두세병이 가능한, 음주운전과 상관없는 분위기 내기좋은 맛도리 논알콜 와인변동
# 버드와이저(생맥)8,000원
# 젤라또 아이스크림쫀쫀하고 꾸덕한 젤라또 아이스크림에 초코소스. 입가심으로 가볍게 먹게 딱좋은 디저트메뉴7,000원
# 2인세트(2천원할인)몽둥이고기+행플레이터무료
# 3~4인세트(3천원할인)몽둥이고기+행플레이터+라자냐파스타
# 대표메뉴 세가지를 한번에!무료
# 스모어딥마시멜로우+누텔라와 함께 구운 달달구리 디저트16,500원
# 행플레이터있는거 없는거 팍팍 넣은 한상차림 대표메뉴, 다양한종류의 치즈,하몽,크레커,올리브,견과류,과일,초콜릿 등등등등,, 그때그때 신선한 재료와 시키신 음식과 주류와 잘어울리는걸로 드려요24,500원
# ' metadata={'store_id': '1799596430', 'store_name': '행2PM8PM'}
# page_content='store_name: 서촌명가
#  category: 한식
#  new_open:
#  rating: 별점 4.19
#  visited_review: 방문자 리뷰 330
#  directions_text: 경복궁역 3번출구로 나오셔서 직진하시다가 버스정류장에서 나오셔서 7022 7212 1020 경복고교 하차 또는 1711 7016 경기상고 하차 하셔서 찾아오시면 가깝습니다.
# 내용 더보기
#  address: 서울 종로구 자하문로 112 지하 1층
#  blog_review: 블로그 리뷰 4
#  phone_num: 02-739-5621
#  business_hours: 일
# 09:00 - 15:00
# 14:20 라스트오더
# 월
# 09:00 - 21:00
# 15:00 - 17:00 브레이크타임
# 20:20 라스트오더
# 화
# 09:00 - 21:00
# 15:00 - 17:00 브레이크타임
# 20:20 라스트오더
# 수
# 09:00 - 21:00
# 15:00 - 17:00 브레이크타임
# 20:20 라스트오더
# 목
# 정기휴무 (매주 목요일)
# 금
# 09:00 - 21:00
# 15:00 - 17:00 브레이크타임
# 20:20 라스트오더
# 토
# 09:00 - 21:00
# 20:20 라스트오더
#
#  info: 정보없음
#  convenience_facilities_and_services: 정보없음
#  Parking: 정보없음
#  sns: 정보없음
#  review_like_this_part_output: "음식이 맛있어요"150
# "친절해요"70
# "재료가 신선해요"40
# "가성비가 좋아요"37
# "양이 많아요"36
# "혼밥하기 좋아요"30
# "매장이 넓어요"15
# "특별한 메뉴가 있어요"13
# "단체모임 하기 좋아요"13
# "매장이 청결해요"10
#  menu: 청국장속리산에서 직접만든 청국장10,000원
# 생선구이12,000원
# 제육정식기본반찬6~8가지(매일변동)와 함께 즐기실수있는 제육볶음정식14,000원
# 동태찌개겨울계절메뉴12,000원
# 부대찌개12,000원
# 김치찌개11,000원
# 계란말이12,000원
# 해물순두부10,000원
# 해물된장10,000원
# 서리태콩국수여름계절메뉴! 서리태콩국수! 나물반찬과 함께 즐겨보세요12,000원
# 물냉면계절메뉴!9,000원
# ' metadata={'store_id': '1361749015', 'store_name': '서촌명가'}
# page_content='store_name: 청기와타운 종로점
#  category: 육류,고기요리
#  new_open:
#  rating: 정보없음
#  visited_review: 방문자 리뷰 970
#  directions_text: 종로맛집 청기와타운 종로점
#
# -지하철이용시
# 종각역 4번 출구 도보 311M
# 젊음의 거리 진입 직진 스타벅스 골목으로 진입하면
# 우측에 청기와타운 종로점이 위치하고 있습니다.
#
# -자차이용시
# 종각역 4번출구에서 759m
# 종로2가사거리 우회전 후 어게인 리프레쉬
# 방면으로 우회전한 후 오프커피에서 우회전 후
# 이고집 쭈꾸미에서 좌회전하면 위치해있습니다.
#
# * 유료주차장 이용 안내
# 1. 시그니쳐타워 도보 5~7분 내외 (청계천로 100)
# 2. 종각앞노상공영주차장 도보 3~5분 내외 (종로8길 5-8)
# 3. 관철동 노상공영주차장 도보 3분 내외 (관철동 268)
# 4. 종로타워 주차장 도보 7-10분 내외 (종로 51)
#
# ' 모두의 주차장 ' 어플 설치 후 근처 주차장 이용하시면
# 더욱 편리하게 이용 하실 수 있습니다.
# 내용 더보기
#  address: 서울 종로구 삼일대로17길 19 1층
#  blog_review: 블로그 리뷰 2,241
#  phone_num: 0507-1370-7843
#  business_hours: 매일
# 11:30 - 22:00
# 21:00 라스트오더
#
#  info: 서울 종로 갈비 맛집 청기와타운 종로점은
# 종각역 젊음의 거리에 위치한만큼
# 미국 LA 한인타운의 힙하고 캐주얼한 감성을 담은
# 인테리어로 눈길을 사로잡는 곳입니다.
# 독보적인 분위기와 감성은 눈으로도 즐기고
# 맛으로도 즐기는 일석이조의 장소입니다.
#
# 클래식한 갈비와 더불어
# 현대적인 감성을 섞은 종로의 맛집입니다.
# 과거와 현재를 아우르는 맛은
# 청기와타운의 장점입니다.
#
# 또한 한인타운을 방문한듯한 분위기로
# 이색적인 감성을 느낄 수 있습니다.
#
# 종로를 찾아주시는 많은 분들이 방문하고 있으며
#  20대 ~ 30대 직장인분들과 더불어
# 다양한 연령층의 고객분들이 찾아주시고 있습니다.
# 또한 편안하게 즐길 수 있는 좌석이 완비되어 있습니다!
# 내부에는 룸, 단체석이 마련되어 있어
# 회식, 외식, 모임, 데이트 등 어느 자리에든
# 어울리며 편안한 식사를 즐길 수 있습니다.
#
# 종로맛집 청기와타운 종로점은
# 언제든 최고의 갈비 맛을 유지하며 멋진 분위기로
# 특별한 순간을 만끽 할 수 있도록 노력하고 있습니다.
# 많은 분들이 만족하고 느낄 수 있는
# 종로 갈비를 대표하는 맛집이되어
# 훌륭한 맛으로 보답하겠습니다.
#
# 종로를 대표하는 맛집이 되겠습니다.
# 종로 맛집 청기와타운 종로점으로 오세요!
# _______________________________________
#
# * 평일 런치 시간 ( 11:30am ~ 15:00pm )
#  - 런치 정식 메뉴 : 찌개류 or 냉면류 중 택 1 서비스로 제공
# _______________________________________
#
# * 생방송 투데이 2609회 방송분 20.07.07.LA갈비
# * 생일 당일 방문시 미역국 서비스 제공
#  (아이와 함께 오시면 아기 미역국, 김을 준비해 드립니다.)
# * 전담 직원이 맛있게 구워주는 그릴링 서비스
# * 다양한 와인, 콜키지 프리 서비스
# * 편안하게 앉아 식사를 즐길 수 있도록 유아 의자 제공
# _______________________________________
#
# * 예약 신청을 하시면 선 예약석 상황 ( 룸, 홀 ) 을 확인하여
#  예약 확정 문자를 드리고 있습니다.
#  ( 4인룸, 8인룸, 10인룸, 12인룸, 단체룸 18인실 총 9개의 룸이 있습니다 )
# * 네이버 예약 시 방문 전 확정 문자를 꼭 확인해 주세요.
# * 방문 전에 꼭 예약 확정 여부 확인 부탁드리겠습니다.
# * 시간 변경 시에 자동 취소됨을 알려드립니다.
# _______________________________________
#
# * 유료주차장 이용 안내
# 1. 시그니쳐타워 도보 5~7분 내외 (청계천로 100)
# 2. 보신각 공영주차장 도보 3~5분 내외 (종로8길 5-8)
# 3. 관철동 노상공영주차장 도보 3분 내외 (관철동 268)
# 4. 종로타워 주차장 도보 7-10분 내외 (종로 51)
#
# ' 모두의 주차장 ' 어플 설치 후 근처 주차장 이용하시면
# 더욱 편리하게 이용 하실 수 있습니다.
# 펼쳐보기
#  convenience_facilities_and_services: 콜키지 가능
# 무료
# 생일 혜택
# 와인 페어링
# 단체 이용 가능
# 예약
# 남/녀 화장실 구분
# 무선 인터넷
# 포장
# 유아의자
#
#  Parking: 주차 불가
#  sns: https://catchtable.co.kr/c7771
# https://www.instagram.com/c_town.jongro/
#
#  review_like_this_part_output: "음식이 맛있어요"857
# "고기 질이 좋아요"673
# "친절해요"409
# "직접 잘 구워줘요"289
# "인테리어가 멋져요"261
# "단체모임 하기 좋아요"227
# "매장이 청결해요"200
# "특별한 메뉴가 있어요"199
# "매장이 넓어요"197
# "양이 많아요"181
#  menu: 수원왕갈비대표청기와타운 대표 SIGNATURE 메뉴
# 한정판매 수원왕갈비입니다.29,000원
# 서울왕갈비대표깊고 진한 숙성 양념으로 극대화된 갈비 본연의 맛을 느낄 수 있습니다.29,000원
# LA양념갈비대표대표메뉴 LA양념갈비입니다 참숯에 구워 풍미가
# 뛰어나며 촉촉한 담백함이 좋습니다.28,000원
# 생갈비36,000원
# 빗살로스한우 1+ 이상의 선별된 원육을
# 2주간 특수 숙성을 후 제공 되는 빗살로스입니다.31,000원
# 생안창살쫄깃한 식감과 넘치는 육즙을 가진
# 청기와타운의 안창살입니다.27,000원
# 돼지갈비단짠단짠 황금조합 청기와타운 돼지갈비22,000원
# 트러플육회(트러플/아보카도/배)신선한 아보카도와 배 위에 트러플로
# 콜라보된 감칠맛이 뛰어난
# 생고기를 올린 육회입니다.28,000원
# 청기와토장찌개청기와타운의 스타일로 재해석한 구수한 토장찌개입니다*11:30~15:00 단품식사 가능9,000원
# 무생채 볶음밥매콤달콤한 무생채를 밥과 볶아 고소한 볶음밥입니다*11:30~15:00 단품식사 가능13,000원
# 양념게장청기와타운의 고기들과 어울리는
# 매콤한 양념게장입니다.9,000원
# LA순두부찌개LA한인타운 스타일의 순두부찌개입니다.*11:30~15:00 단품식사 가능9,000원
# 양곰탕얼큰하고 시원시원한 양곰탕입니다.*11:30~15:00 단품식사 가능14,000원
# 육회비빔밥쫄깃한 육회와 특제소스를 버무린 육회비빔밥입니다.*11:30~15:00 +토장찌개 서비스13,000원
# 소고기 미역국*11:30~15:00 단품식사 가능9,000원
# ' metadata={'store_id': '1518855883', 'store_name': '청기와타운 종로점'}
# page_content='store_name: 방이옥 종로관철점
#  category: 육류,고기요리
#  new_open:
#  rating: 정보없음
#  visited_review: 방문자 리뷰 1,106
#  directions_text: 지하철: 종각역 4번출구로 나오셔서 30초
# 직진하시면 스타벅스가 보여요~그골목으로 우회전하셔서 30초 직진하시면 사거리에서
# 바로 좌회전 하시면 2층에 방이옥 보여요^^
# 4번출구에서 2분컷!!
#
# 버스: 종로2가 (중앙차로) 에서 횡단보도 건너
# 종각 젊은의거리로 들어오시면 갓덴스시
# 보이시면 우회전 하셔서 30초 걸어오시면
# 왼쪽 2층에 방이옥이 있습니다^^
# 내용 더보기
#  address: 서울 종로구 우정국로2길 32 2층
#  blog_review: 블로그 리뷰 2,416
#  phone_num: 0507-1377-8268
#  business_hours: 수(1/1)
# 휴무
# 목
# 11:00 - 22:00
# 21:00 라스트오더
# 금
# 11:00 - 22:00
# 21:00 라스트오더
# 토
# 12:00 - 22:00
# 21:00 라스트오더
# 일
# 12:00 - 22:00
# 21:00 라스트오더
# 월
# 11:00 - 22:00
# 21:00 라스트오더
# 화
# 11:00 - 22:00
# 21:00 라스트오더
#
#  info: 정보없음
#  convenience_facilities_and_services: 정보없음
#  Parking: 정보없음
#  sns: 정보없음
#  review_like_this_part_output: 정보없음
#  menu: 정보없음' metadata={'store_id': '1431553022', 'store_name': '방이옥 종로관철점'}
# page_content='store_name: 미도인 종로
#  category: 양식
#  new_open:
#  rating: 별점 4.39
#  visited_review: 방문자 리뷰 2,239
#  directions_text: 미도인 종로점의 주소는 '서울 종로구 종로 51 종로타워 지하 2층'입니다.
#
# **대중교통**
#  지하철 1호선 종각역 3번 출구 또는 3-1번 출구로 나오시면 도보 약 50m 거리에 종로타워가 있습니다. 종로타워 지하 2층으로 오시면 미도인 종로점을 찾으실 수 있습니다.
#
# **자가용**
# 자가용을 이용하실 경우, 종로타워 지하 주차장에 주차하신 후 지하 2층으로 올라오시면 됩니다. 주차 요금은 매장에서 결제 시 1시간 30분 무료등록 해 가능합니다
#
# **도보**
# 종각역 보신각 인근 종로타워 빌딩 내 위치하고 있습니다. 도보 이용 시 보신각에서 종로타워 방향으로 직진하시면 됩니다.
# 종로타워 지하 2층에 위치하고 있습니다.
# 내용 더보기
#  address: 서울 종로구 종로 51 지하2층
#  blog_review: 블로그 리뷰 2,795
#  phone_num: 02-720-5097
#  business_hours: 수
# 11:00 - 21:00
# 14:40 - 17:00 브레이크타임
# 19:50 라스트오더
# 목
# 11:00 - 21:00
# 14:40 - 17:00 브레이크타임
# 19:50 라스트오더
# 금
# 11:00 - 21:00
# 14:40 - 17:00 브레이크타임
# 19:50 라스트오더
# 토
# 11:00 - 21:00
# 15:20 - 17:00 브레이크타임
# 19:50 라스트오더
# 일
# 11:00 - 21:00
# 15:20 - 17:00 브레이크타임
# 19:50 라스트오더
# 월
# 11:00 - 21:00
# 14:40 - 17:00 브레이크타임
# 19:50 라스트오더
# 화
# 11:00 - 21:00
# 14:40 - 17:00 브레이크타임
# 19:50 라스트오더
#
#  info: 미도인 종로점의 주소는 '서울 종로구 종로 51 종로타워 지하 2층'입니다.
#
# **대중교통**
#  지하철 1호선 종각역 3번 출구 또는 3-1번 출구로 나오시면 도보 약 50m 거리에 종로타워가 있습니다. 종로타워 지하 2층으로 오시면 미도인 종로점을 찾으실 수 있습니다.
#
# **자가용**
# 자가용을 이용하실 경우, 종로타워 지하 주차장에 주차하신 후 지하 2층으로 올라오시면 됩니다. 주차 요금은 매장에서 결제 시 1시간 30분 무료등록 해 가능합니다
#
# **도보**
# 종각역 보신각 인근 종로타워 빌딩 내 위치하고 있습니다. 도보 이용 시 보신각에서 종로타워 방향으로 직진하시면 됩니다.
#
# ※ 미도인 종로점이 유명해진 이유 첫번째~!
#
# 미도인 종로점은 좋은 접근성, 착한 가격과 퀄리티 최고!
# 1.서울 종로구에서 직장인들의 점심 식사 점심특선 HIT 상품 다양한 한상차림 메뉴!
# 2.인테리어가 예쁘고 매장이 청결해서, 데이트나 친구들과의 모임 장소!
# 3.가격도 착하고 분위기도 좋은데 퀄리티까지 너무 좋아서 많은 사람들이 만족!
# 4.주말 및 공휴일엔 소중한 만남,반가운 모임, 가족모임등을 즐기기 좋은 핫플! 바로 여기!
# 5.고급스럽고 깔끔한 인테리어로 소개팅, 데이트 장소로 인기 굿~!
# 6.직원들이 친절하고 서비스가 좋아서, 손님들이 편안하게 식사를 즐길 수 있는 곳!
#
# ※ 미도인 종로점이 유명해진 이유 두번째~!
#
# 미도인 종로점은 메뉴 카테고리가 매우매우 다양합니다~^^
# 스테이크,한상차림, 덮밥, 파스타,라멘, 소바, 샐러드,떡볶이 등 다양한 메뉴를 즐길 수 있는 미도인 입니다!
#
# 1.스테이크: 미도인 등심 스테이크, 트리플 등심 스테이크, 대창 등심 스테이크,곱창 등심 스테이크 등
#
# 2.한상차림 : 등심스테이크 한상차림, 곱창&대창덮밥 한상차림,단새우스테이크덮밥 한상차림,우니 스테이크덮밥 한상차림 등
#
# 3.덮밥: 큐브 스테이크 덮밥, 화산불백 덮밥, 대창큐브 스테이크 덮밥 등
#
# 4.파스타: 바질 크림 새우 파스타, 명란 크림 파스타, 새우 로제 파스타 등
#
# 5.라멘 : 곱창 라멘, 우육면, 청두 사천 탄탄멘 등
#
# 6.소바 : 가케소바, 단새우 가케소바, 마제소바, 곱창대창 마제소바 등
#
# 7.스페셜 : 미도인 떡볶이,미도인 곱창 떡볶이, 스카치 에그 등
#
# ※ 미도인 종로점이 유명해진 이유 세번째~!
#
# 많은 방문 고객분들이 미도인 종로점의 맛과 분위기에 대해 긍정적인 리뷰를 남기고 있습니다.
#
# 1.맛과 퀄리티가 좋다: 가격도 착하고 분위기도 좋은데 퀄리티까지 너무 좋아서 많은 사람들이 만족하고 있습니다.
# 2.직원들이 친절하다: 직원들이 친절하고 서비스가 좋아서, 손님들이 편안하게 식사를 즐길 수 있습니다.
# 3.엔틱한 분위기가 좋다: 매장 내부는 엔틱하면서도 모던한 분위기를 갖추고 있으며, 사진찍기 좋아요!
#
# 직접 리뷰를 확인해 보시고 방문해 주세요 ^-^)//
#
# 방문해 주시는 모든 분들의 먹는 즐거움, 보는 즐거움,머무는 즐거움을 선사드릴 수 있도록
# 고객의 관점에서 고객을 만족 시켜드릴수 있도록 전직원이 노력하겠습니다!
#
# 고급스러운 인테리어와 아늑한 분위기로 종로맛집/종각맛집/종각역맛집/종로가볼만한곳/서울종로맛집/종로데이트/종로타워맛집/종로구맛집/ 종로핫플/졸로파스타/종로밥집/종로점심/종로혼밥/종로라멘/종각파스타/종로스테이크 등으로 찾으시는 이유로 감사하게도 많은 분들께 추천됩니다.
#
# 방문 하시는 모든 분들이 즐거운 식사를 즐기시길 바랍니다!
# 펼쳐보기
#  convenience_facilities_and_services: 무선 인터넷
# 단체 이용 가능
# 남/녀 화장실 구분
# 포장
#
#  Parking: 주차가능
# 무료
#  sns: https://youtube.com/channel/UCxRWfLoFdwXyIU6_yq38uig?si=tpSW48w87J2hWl1f
#
#  review_like_this_part_output: "음식이 맛있어요"810
# "친절해요"296
# "특별한 메뉴가 있어요"243
# "인테리어가 멋져요"204
# "재료가 신선해요"187
# "양이 많아요"144
# "가성비가 좋아요"144
# "매장이 청결해요"120
# "혼밥하기 좋아요"111
# "매장이 넓어요"91
#  menu: 400 스테이크 덮밥(런치한정)대표무려 400g 이나 한그릇에 담았습니다. 일곱 분께 정성껏 만들어 보답하겠습니다.16,800원
# 미도인 스테이크 덮밥대표부드러운 스테이크를 올린 말이 필요없는 미도인 대표 덮밥10,800원
# 청두 사천 탄탄멘사천식으로 만든 매콤한 참깨돈골 육수와 매장에서 직접 만든 탄면장을 얹은 전통 탄탄멘9,300원
# 가정식 등심 스테이크S부드러운 스테이크와 진한 육수로 우려낸 단호박 스프, 아지다마고의 한상차림
# 사이즈별 가격 다름 (S,M.L)17,600원
# 미도인 우실장 떡볶이미도인 총괄셰프의 특제소스와 삼겹살 대파가 듬뿍 들어간 약빤 메뉴9,800원
# 화산 불백 덮밥불맛 나는 돼지고기를 화산 모양으로 형상화한 비쥬얼 갑 강추 덮밥9,800원
# 큐브 스테이크 덮밥부챗살과 등심, 특제 단짠 소스로 만든 스테이크 덮밥11,800원
# 미도인 곱창 라멘 (한정메뉴)부드러우면서 쫄깃한 곱창의 식감과 얼큰 시원한 미도인 만의 특별라멘12,800원
# 대창 덮밥말이 필요없는 맛!! 잘 손질된 대창을 매콤한 특제 양념과 불맛 나게 볶아낸 특별 덮밥13,300원
# 큐브 스테이크 덮밥 한상차림고급스러운 풍미를 느낄 수 있는 미도인 큐브스테이크를 햅쌀밥 위에 가득 올린 한상차림13,800원
# 미도인 곱창 떡볶이(한정메뉴)미도인 총괄셰프의 매콤 특제소스, 소곱창과 쫄깃한 떡의 환상 하모니, 미도인 특별 곱떡 메뉴13,900원
# 곱창 대창 덮밥 (곱대)미도인 만의 특별한 저온 숙성 방법과 매콤한 한국식 특제 소스를 곁들인 대한민국 최초 곱대덮밥14,700원
# 미도인 9첩반상(디너한정메뉴)스테디샐러인 미도인 스테이크 덮밥,가스오부시로 우려낸 국물과 야채튀김이 올라간 소바15,300원
# 대창 큐브 스테이크 덮밥스테이크와 대창을 함께 즐길수 있는 미도인만의 특별한 콜라보 메뉴15,600원
# 등심 스테이크 덮밥 한상차림무쇠 그리들로 구워 낸 육즙 가득한 등심스테이크가 햅쌀밥 위에 올라간 한상차림15,800원
# ' metadata={'store_id': '401951052', 'store_name': '미도인 종로'}
# page_content='store_name: 창창
#  category: 중식당
#  new_open:
#  rating: 정보없음
#  visited_review: 방문자 리뷰 466
#  directions_text: 昌1) 발렛
# - '창신12길 33' 앞에서 발렛파킹 후 이동
# - 목적지를 '창창', 경유지를 '명신 초등학교'로 검색하면 보다 수월하게 오실 수 있습니다.
# - '방문 도장' 확인이 필요하며, 창창 옆 건물 안내부스를 통해 출차 가능합니다.
# <2시간 6000원, 30분 추가 시 2000원>
# *만 차일 경우 인근 주차장 이용 부탁드립니다.
#
# 昌2) 버스 (약 15분)
# '종로 03번 마을버스'를 타고 '낙산 삼거리' 정류장에서 내려 왼쪽 길을 따라 창창 건물이 보일 때까지 걷습니다.
# 내용 더보기
#  address: 서울 종로구 창신12길 37 창창
#  blog_review: 블로그 리뷰 725
#  phone_num: 0507-1370-3548
#  business_hours: 매일
# 11:30 - 21:00
# 15:00 - 17:00 브레이크타임
# 20:00 라스트오더
#
#  info: 정보없음
#  convenience_facilities_and_services: 정보없음
#  Parking: 정보없음
#  sns: 정보없음
#  review_like_this_part_output: "음식이 맛있어요"269
# "인테리어가 멋져요"243
# "뷰가 좋아요"231
# "특별한 메뉴가 있어요"136
# "친절해요"96
#
#  menu: 까이포커플세트대표닭고기와 풍부한 양념이 어우러져있는 닭볶음탕과 푸짐한 국물이 일품인 까이포세트메뉴65,000원
# 라즈지대표두툼한 닭 다리 살을 전분 반죽으로 튀겨내 쯔란과 함께 볶아낸 쓰촨 지역의 매콤한 닭 요리28,000원
# 꿔바로우대표돼지 등심을 통째로 튀겨내 달콤하고 새콤한 소스와 함께 곁들여 먹는 튀김 요리21,000원
# 창창하이볼대표달콤한 체리와 상큼한 블루베리가 어우러진 창창 시그니처 하이볼 (논알콜가능)12,000원
# 쇠고기우육면소 힘줄과 사태를 긴 시간 우려내 쫀득한 식감으로 함께 즐길 수 있는 국물 면 요17,000원
# 마늘종 자장면황두장과 향긋한 마늘종을 함께 볶아 식감이 좋은 볶음 면 요리14,000원
# 차돌박이 사천 탕면얼큰하게 즐길 수 있는 중독적인 얼얼한 맛의 사천식 국물 면 요리15,000원
# 통삼겹 동파육두툼한 삼겹살을 통째로 쪄낸 부드러운 식감의 요리34,000원
# 중화냉면쫄깃한 면발과 차가운 국물 또는 소스의 조화가 일품이며,시원하게 즐길 수 있는 면 요리17,000원
# 새우계란볶음밥파기름으로 고슬하게 볶아낸 새우 볶음밥10,000원
# 창창 팝 만두바삭하게 튀긴 만두에 매콤한 고추부각과 고소한 땅콩, 쯔란을 뿌린 튀김 요리9,000원
# 짜사이 볶음밥꼬들꼬들한 재밌는 식감의 짜사이와 밥을 특재 소스로 볶아낸 짭짤하고 고소한 볶음밥10,000원
# 오이 냉채신선한 오이를 달콤하고 새콤한 소스의 절여 매콤한 로깐마 소스와 함께 버무려 먹는 요리8,000원
# 오드레기 볶음오랜 시간 삶아 쫀득한 식감의 스지를 향신료로 볶아낸 중식 볶음 요리29,000원
# 연두부 튀김부드러운 연두부를 달콤하고 짭조름한 소스와 곁들여 먹는 튀김요리14,000원
# ' metadata={'store_id': '1903257210', 'store_name': '창창'}
# page_content='store_name: 한양중식 종로점
#  category: 중식당
#  new_open:
#  rating: 별점 4.48
#  visited_review: 방문자 리뷰 1,673
#  directions_text: 1호선 종각역 나오셔서
# 지하도에서 타워로 연결 바로되니,
# 종로타워 지하2층으로 찾아오시면 됩니다.
# 찾아오시기 아주 편합니다^^
# 내용 더보기
#  address: 서울 종로구 종로 51 종로타워 지하 2층 한양중식
#  blog_review: 블로그 리뷰 984
#  phone_num: 070-4647-0230
#  business_hours: 수(1/1)
# 새해 첫날12:00 - 21:00
# 목
# 11:00 - 21:30
# 15:30 - 17:00 브레이크타임
# 21:00 라스트오더
# 금
# 11:00 - 21:30
# 15:30 - 17:00 브레이크타임
# 21:00 라스트오더
# 토
# 12:00 - 21:00
# 20:30 라스트오더
# 일
# 12:00 - 21:00
# 20:30 라스트오더
# 월
# 11:00 - 21:30
# 15:30 - 17:00 브레이크타임
# 21:00 라스트오더
# 화
# 11:00 - 21:30
# 15:30 - 17:00 브레이크타임
# 21:00 라스트오더
#
#  info: 정보없음
#  convenience_facilities_and_services: 정보없음
#  Parking: 정보없음
#  sns: 정보없음
#  review_like_this_part_output: 정보없음
#  menu: 정보없음' metadata={'store_id': '1992882869', 'store_name': '한양중식 종로점'}
# page_content='store_name: 을지로쎄시봉
#  category: 와인
#  new_open:
#  rating: 별점 4.68
#  visited_review: 방문자 리뷰 453
#  directions_text: 을지로3가역 8번 출구와 충무로역 7번 출구 중간 아시아 미디어타워 맞은편 2층입니다
# *주차의 경우 도로 주차 박스에 주차가 가능하며 도로 주차 박스 관리인 분들께 문의하여 주시기 바랍니다
# 내용 더보기
#  address: 서울 중구 충무로 28 2층
#  blog_review: 블로그 리뷰 605
#  phone_num: 0507-1324-9430
#  business_hours: 수
# 18:00 - 24:00
# 목
# 18:00 - 24:00
# 금
# 18:00 - 24:00
# 토
# 18:00 - 24:00
# 일
# 17:00 - 22:00
# 월
# 정기휴무 (매주 월요일)
# 화
# 18:00 - 24:00
#
#  info: 안녕하세요 을지로 와인바 을지로쎄시봉 입니다
# 너목보 시즌6출연했던 싱어송라이터로
# 특별한공간을 만들고 싶은 꿈을 이루기위해
# 힙지로에서 라이브바를 운영중입니다.
# 조금은 낡은것 같아도, 조금은 부족해도, 따듯하고 소박하게
# 늘 음악과 함께하는 장소로 방문해주시는 모든분들이 기억에남고
# 추억이되는 공간이 되었으면 합니다.
# 매일 저녁 하루 2번
# 직접 매일 라이브공연을하는 하고 있는 유일한 을지로 라이브바입니다.
#
# 라이브공연과 와인을 즐기실 수 있는 공간 입니다.
# 소규모 매장이기에 라이브공연 10분전부터 시간동안은 입장과 주문이 불가하며
# 라이브 시간 맞춰 오시면 자리가 없는 경우가 많아,
# 조금은 여유를 두시고 방문 해주시는걸 추천드립니다.
#
# 당일 예약은 불가하나 워크인 방문석 따로 마련되어 있으니
# 예약을 안하셨더라도 편히 방문해주세요
# 펼쳐보기
#  convenience_facilities_and_services: 콜키지 가능
# 유료
# 무선 인터넷
# 예약
# 포장
# 배달
# 노키즈존
#
#  Parking: 주차 정보없음
#  sns: http://www.instagram.com/euljiro_cestsibon
#
#  review_like_this_part_output: "음악이 좋아요"318
# "음식이 맛있어요"222
# "인테리어가 멋져요"172
# "친절해요"172
# "술이 다양해요"115
# "대화하기 좋아요"111
# "기본 안주가 좋아요"68
# "가성비가 좋아요"67
# "라이브공연이 훌륭해요"59
# "특별한 메뉴가 있어요"54
#  menu: 쎄시봉플래터대표을지로쎄시봉 대표 메뉴입니다38,000원
# 새벽 다섯시새벽 공기처럼 시원하고 상큼한 스파클링 와인 칵테일12,000원
# 저녁 다섯시퇴근길 지하철에서 바라본 노을지는 하늘과 닮은 와인칵테일14,000원
# 헤이샌드맨샌드맨포투와인으로만든 달콤한 스파클링포투와인 칵테일 입니다 도수가 조금 높아요!14,000원
# 살라미플래터상큼한 과일 그리고 크래커와 함께하는 다양한 살라미&프로슈토를 드려요!25,000원
# 치즈플래터치즈7종과 상큼한 아이스청포도와 크래커를 함께 드립니다
# 이미 식사를 하셨다면 와인과 함께 치즈플레이트 추천드려요 !25,000원
# 감바스새우와 마늘 양파 페퍼론치노를 올리브유에 튀기듯 구워낸 요리입니다
# 구운빵과 함께 드려요 와인 안주로 특히 잘 어울려요!22,000원
# 멜론프로슈토멜론의 단맛과 프로슈토의 짠맛 어우러진 단짠 조합20,000원
# 칠리새우직접만든 칠리소스와 각종 야채와 함께 볶은 새우 요리22,000원
# 에그인헬토마토 햄 각종 야채로 만든 스튜에 툭하고 빠진 달걀 요리20,000원
# 브루스케타토마토&올리브&양파&파프리카&치즈&로즈마리등 쎄시봉만의 레시피로 만들었어요!17,000원
# 참치카나페직접만든 콘참치마요 카나페 입니다! 정말 맛있어요12,000원
# 스모어딥누텔라와 마시멜로우의 조합! (Ps.힘들고 지칠땐 당충전이죠!)12,000원
# 서울의밤 375ml토닉워터2 / 레몬 슬라이스 함께 드립니다.35,000원
# ' metadata={'store_id': '1912673244', 'store_name': '을지로쎄시봉'}
# page_content='store_name: 금별맥주 종로점
#  category: 맥주,호프
#  new_open:
#  rating: 정보없음
#  visited_review: 방문자 리뷰 734
#  directions_text: (1호선 종각역 도보 3분, 종로3가역 도보 5분)
#
# 네이버 지도에 '금별맥주종로'를 검색하시면 쉽게 방문하실 수 있으며, 자세한 위치는 젊음의거리 올리브영 사거리에 위치해있습니다.
#
# 종각역과 종로3가역 중간 정도에 위치해 있고 '종각 젊음의거리'에 위치해 있습니다.
#
# 대중교통 이용 시 지하철은 종각역, 종로3가역에서 도보로 방문해 주시면 되시고, 버스 이용 시에는 종로2가 정류장 또는 청계1가,광교 정류장에서 내리셔서 도보로 방문해 주시면 됩니다.
#
# 찾아오시는 길이 어려우시면 '전화 걸기' 버튼을 클릭하여 매장으로 전화 주시면 친절하게 안내해 드리겠습니다. 감사합니다^^
# 내용 더보기
#  address: 서울 종로구 종로12길 18 지상1~2층
#  blog_review: 블로그 리뷰 158
#  phone_num: 02-3210-1777
#  business_hours: 매일
# 15:00 - 05:00
#
#  info: 정보없음
#  convenience_facilities_and_services: 정보없음
#  Parking: 정보없음
#  sns: 정보없음
#  review_like_this_part_output: "음식이 맛있어요"463
# "가성비가 좋아요"235
# "술이 다양해요"199
# "친절해요"151
# "특별한 메뉴가 있어요"149
#
#  menu: 핫크리스피치킨대표매콤하게 밑간한 닭을 저온에서 튀겨내어 끝까지 바삭한 금별맥주만의 핫크리스피치킨21,000원
# 매운 오돌갈비찜대표오돌갈비 식감이 일품인 매운갈비찜.
#  밥과함께 드시면 더 맛있습니다.28,000원
# 미나리 새우전대표향긋한 미나리와 바삭한 보리새우, 통통한 새우를 바싹 부쳐낸 메뉴18,000원
# 토마토해장파스탕대표매콤한 토마토 해물 빼쉐(국물)파스타 내용물을 다 드신후 리조또를 만들어 드실 수 있습니다23,000원
# 들깨크림 고기순대대표고소한 들깨 크림에 고기순대와 수제비의 쫀득함을 느낄 수 있는 메뉴16,900원
# 한우대창 닭볶음탕(순살)고소한 한우대창과 부드러운 순살이 들어간 매콤달콤 닭볶음탕28,000원
# 족발편육과 도토리묵쫄깃한 족발편육과 도토리묵을 함께 먹는 메뉴18,000원
# 한우 투뿔 육회한우 투뿔 우둔살을 얇게 썰어 참기름과 간장에 버무려낸 일품 안주14,900원
# 가래떡 국물 떡볶이소시지,어묵,납작당면과 쫄깃 가래떡이 들어간 맵단 국물 떡볶이14,900원
# 칼칼 스키야키나베칼칼한 쇼유(간장)육수의 소고기 전골24,000원
# 나가사끼 짬뽕탕진한 돈사골 베이스의 해물 백짬뽕23,000원
# 일품 모둠 어묵탕다양한 어묵, 깔끔한 간장육수18,900원
# 백합조개 버터술찜백합조개가 들어간 경양식 술찜16,900원
# 사모님! 감바스파스타 면이 들어간 사모님 스타일의 감바스16,900원
# 매콤 명란크림 파스타명란의 짭조름한 감칠맛과 고소함이 잘 어우러진 크림 파스타16,900원
# ' metadata={'store_id': '1754035019', 'store_name': '금별맥주 종로점'}
# page_content='store_name: 새서울
#  category: 술집
#  new_open:
#  rating: 정보없음
#  visited_review: 방문자 리뷰 1,380
#  directions_text: 새서울은 종로3가역 4번 출구에서 나와 길 건너 오른쪽으로 직진 후 노가리마켓에서 좌회전 하면 보이는 분홍색 5층 건물입니다.
#
# 차량을 이용하시는 분은 바로 건너편 민영 주차장 혹은 근처 공영 주차장을 이용 부탁 드립니다.
#
# 새서울 라운지는 2층 오락실에 있는 비밀의 문을 통해 입장 가능합니다. 들어오는 입구를 못 찾으시겠다면, 새서울로 전화 주세요!
# 내용 더보기
#  address: 서울 종로구 돈화문로11길 28-5 3층
#  blog_review: 블로그 리뷰 385
#  phone_num: 0507-1449-8892
#  business_hours: 수
# 17:00 - 01:00
# 00:00 라스트오더
# 목
# 17:00 - 01:00
# 00:00 라스트오더
# 금
# 17:00 - 01:00
# 00:00 라스트오더
# 토
# 17:00 - 01:00
# 00:00 라스트오더
# 일
# 17:00 - 01:00
# 00:00 라스트오더
# 월(1/6)
# 휴무
# 화(1/7)
# 휴무
#
#  info: 새서울은 서울의 옛 정취가 느껴지는 익선동 한옥 마을과 현대 한국인들의 일상을 대변하는 종로 포장마차 거리의 중간에 위치합니다.
#
# 2층 아케이드를 지나 비밀의 문을 통해 올라가면 익선동 한옥 마을의 아름다운 야경이 펼쳐집니다. 익선동 한옥 거리를 내려다보며 엄선된 칵테일, 위스키, 와인, 맥주 등의 주류를 다양한 장르의 음악과 함께 즐길 수 있는 라운지로 구성되어 있습니다. 새서울에서만 만나볼 수 있는 유일무이한 한국적인 뷰와 함께 잔잔한 음악과 함께 술을 즐겨보세요.
#
# 새서울에서는 플리마켓, DJ 파티, 루프탑 BBQ 등 다양한 이벤트를 진행하고 있습니다. 새서울에서 진행되는 스페셜 이벤트 및 프로모션은 새서울 인스타그램 (@sae.seoul)을 참고해 주세요!
#
# [기타 안내 사항]
# *크리스마스 이브 및 크리스마스 당일은 모든 좌석 이용 시간 2시간으로 제한됩니다.
# *1인 1음료 (소프트드링크류 제외) 업장입니다. 음주가 불가하신 분을 위한 논알콜 칵테일도 준비되어 있습니다.
# *기본 이용 시간은 2시간입니다. 뒷타임 예약이 없을 경우 시간 제약 없이 이용이 가능합니다.
# *새서울은 약 40년이 넘은 오래된 건물로, 엘레베이터가 없습니다. 루프탑 좌석은 5층에 위치해있으므로, 5층까지 계단으로 올라가셔야 하는 부분을 인지하고 예약 부탁 드립니다.
# * 예약은 2시간 전까지 받고 있으며, 당일 방문 혹은 단체 예약의 경우 유선 연락 주시면 더 빠른 안내가 가능합니다.
# * 방문 예약 시간 15분 경과 시 노쇼(NO SHOW) 처리되며, 노쇼하신 고객분은 향후 새서울 예약에 제한이 있을 수 있습니다. 업장에 대한 최소한의 예의를 지켜주시길 바랍니다.
# * 7인 이상의 예약은 원활한 준비 및 응대를 위해 매장 영업시간에 직접 유선 연락 부탁 드립니다.
# * 20인 이상의 대관 및 행사 문의는 [네이버 톡톡]으로 문의 주세요.
# 펼쳐보기
#  convenience_facilities_and_services: 생일 혜택
# 예약
# 단체 이용 가능
# 남/녀 화장실 구분
# 무선 인터넷
#
#  Parking: 주차 불가
#  sns: https://www.instagram.com/sae.seoul
#
#  review_like_this_part_output: "인테리어가 멋져요"872
# "술이 다양해요"861
# "음식이 맛있어요"668
# "음악이 좋아요"610
# "대화하기 좋아요"480
# "특별한 메뉴가 있어요"338
# "친절해요"332
# "뷰가 좋아요"307
# "기본 안주가 좋아요"301
# "사진이 잘 나와요"133
#  menu: 플롭 (PLOP)17,000원
# 팩맨 (PAC-MAN)17,000원
# 너티더티 (NUTTY DIRTY)17,000원
# 루비마티니 (RUBY MARTINI)18,000원
# 파인트리 (PINETREE)18,000원
# 훌라훌라 (HULA HULA)18,000원
# 호랑이 (TIGER)19,000원
# 너클헤드 (KNUCKLEHEAD)21,000원
# 클래식 칵테일13,000~16,000원
# 위스키하이볼13,000원
# 하우스 와인 (레드/화이트)12,000원
# 맥주10,000~12,000원
# 음식 (파스타,안주,디저트)9,000~24,000원
# ' metadata={'store_id': '1427737970', 'store_name': '새서울'}
# page_content='store_name: 동베이 광화문점
#  category: 양꼬치
#  new_open:
#  rating: 정보없음
#  visited_review: 방문자 리뷰 218
#  directions_text: 광화문 중식전문점 [동베이]를 찾아주셔서 감사합니다!
#
# 단체 예약 또는 회식 예약은 전화 문의 주시면 안내드리겠습니다.
#
# 오시는 길
#
# + 지하철로 광화문역에서 내려주시고,
# 포시즌스 호텔 근처 20미터 내에 육대장 건물 2층에 위치해있습니다.
# + 주차 제공 또는 발렛은 어려우니, 공영주차장을 이용해주시기 바랍니다.
# 1. 세종문화회관 주차장
# 2. 신문로 공영주차장
# 3. 고려 주차장
# 4. 광화문 빌딩 앞 노상 공영주차장
# 내용 더보기
#  address: 서울 종로구 새문안로5길 8-1 2층 동베이 광화문점
#  blog_review: 블로그 리뷰 132
#  phone_num: 0507-1402-8696
#  business_hours: 매일
# 10:00 - 24:00
# 23:00 라스트오더
#
#  info: 안녕하세요.
# 양꼬치와 동북 요리 전문점
# 동베이 광화문점입니다!
#
# + 당일 예약은 전화로 연락 부탁드립니다.
# + 예약은 최대 전체 좌석에 50% 까지 받고 있습니다.
#
# 한국인이 가장 사랑하고 친근한 중국 음식이
# 동북 지역에 요리라는 것을 알고 계셨나요?
# 대표적인 꿔바로우부터, 경장육슬까지 다양한 동북 요리를 맛볼 수 있는 광화문의 중식 맛집입니다!
#
# 양꼬치를 전문으로,
# 고급 양갈비까지 잡내 없이 탄탄한 식감으로 매일 작업하여 제공하고 있습니다.
# 현지에서 오랜 세월 중식당을 운영하셨던 쉐프님이
# 모든 요리부터, 식사류까지 빠짐없이 맛있게 조리합니다!
#
# 가장 익숙한 중식과 대중적인 마라탕까지
# 한 곳에서 모두 맛 볼 기회는
# 오직 [동베이]에서!
#
# 종로구에서 동북요리를 지향하는 가게는 많이 있습니다.
# 우리의 특별한 점은,
# 광화문이라는 상권 아래 양꼬치부터, 다양한 점심 식사까지
# 한국인의 입맛을 고려한 대중성을 꼽아 말씀드릴 수 있습니다.
#
# + 가장 익숙하고 누구에게나 맛있는!
#
# * 양꼬치
# * 고급 양갈비
# * 꿔바로우
# * 지삼선 등 누구에게나 사랑받고 항상 인기있는 메뉴가 준비되어 있습니다!
#
# + 동북 요리를 서울 도심 속에서 가장 현지의 맛으로!
#
# * 쯔란 양고기
# * 어향가지
# * 경장육슬
# * 바지락볶음 등 한번 맛보면, 계속 생각나는 동북요리는 우리의 자랑입니다!
#
# + MZ세대의 입맛까지 사로잡은 광화문 맛집 동베이!
#
# * 마라탕
# * 마라샹궈
# * 훠궈
# * 토마토 계란볶음 등 요즘 세대에 입맛에 딱 맞춘 요리까지!
#
# - 동베이를 이용해주시는 분들에게
# 1. 점심에는 합리적인 가격에 점심 훠궈와, 꿔바로우등 든든한 식사 메뉴가 준비되어 있습니다. (2:30까지)
# 2. 단체 또는 회식 문의는 전화로 주시면 친절히 안내해드리겠습니다.
# 3. 양갈비는 매일 한정수량으로 준비해두고 있어, 조기 소진시 양꼬치를 이용해주시면 좀 더 만족스러운 식사를 준비해드리겠습니다.
# 4. 요리류 식사는 2층, 꼬치 구이류 식사는 3층에서 우선적으로 모시겠습니다.
# 5. 포시즌스 서울 호텔 고객님은 매장에서 중국어 안내까지 가능합니다.
#
# 항상 최고의 퀄리티와 맛을 보장하는 ,
# 광화문에 동북 요리 전문 동베이로 식사하러 오세요!
# 펼쳐보기
#  convenience_facilities_and_services: 비건 메뉴
# 유기농 메뉴
# 단체 이용 가능
# 포장
# 배달
# 예약
# 남/녀 화장실 구분
#
#  Parking: 주차 불가
#  sns: https://app.catchtable.co.kr/ct/shop/dong_bey
#
#  review_like_this_part_output: "음식이 맛있어요"101
# "가성비가 좋아요"25
# "양이 많아요"24
# "특별한 메뉴가 있어요"24
# "친절해요"13
# "고기 질이 좋아요"12
# "단체모임 하기 좋아요"12
# "혼밥하기 좋아요"6
# "재료가 신선해요"5
# "매장이 넓어요"5
#  menu: 훠궈 점심 특선대표합리적인 가격에 푸짐하고 배불리 즐길 수 있는 점심 특선입니다.
# (3시 이전까지 제공)12,800원
# 양꼬치대표어린 양고기를 동베이만의 양념에 버무려 숙성시킨 꼬치요리 입니다.
# (8꼬치 제공됩니다.)16,000원
# 꿔바로우대표겉바속촉 돼지고기에 동베이만의 과일소스로 동북요리의 맛을 살린 동베이의 대표 메뉴입니다.20,000원
# 마라샹궈대표각종 야채와 고기에 향신료와 마라의 얼얼함을 더해 볶은 요리입니다.28,000원
# 모듬 꼬치 세트대표양꼬치 / 소갈빗살 꼬치/ 양갈빗살 꼬치 + 꿔바로우68,000원
# 즈란양고기대표불향 강하게 볶은 양꼬치에 쯔란을 더해, 풍미가 가득한 볶음 요리입니다.20,000원
# 지삼선대표3가지 신선 재료를 전분으로 가볍게 튀겨 맛있게 볶아낸 동베이의 인기 메뉴 입니다.18,000원
# 마라탕대표고기와 채소를 넣어 끓여먹는 메뉴로 입이 얼얼하면서 매운맛이 일품인 요리입니다.25,000원
# 라쯔지대표튀긴 닭고기를 여러 채소와 함께 볶아 고추 양념을 가미한 사천식 중국 요리입니다.28,000원
# 소갈빗살 꼬치늑간살 부위를 가볍게 소금간하여 숙성시킨 꼬치요리 입니다.
# (8꼬치 제공됩니다.)17,000원
# 양갈빗살 꼬치어린 양을 사용하여, 부드럽고 담백하게 숙성시킨 꼬치요리 입니다.
# (8꼬치 제공됩니다.)18,000원
# 경장육슬얇게누른 두부피에 각종 채소를 넣고 중국장으로 볶은 돼지고기 채를 쌓아먹는 요리입니다.28,000원
# 어향가지전분에 튀긴 가지와 채소를 어향소스에 조리듯 볶아낸 요리입니다.20,000원
# 마른고추 소고기 볶음소고기와 마른 고추를 특제 소스에 센불로 강하게 볶아낸 요리입니다.22,000원
# 향라 오징어바삭한 오징어 튀김에 수분기 적게 볶아 고소하고 매운 요리입니다.22,000원
# ' metadata={'store_id': '1962205483', 'store_name': '동베이 광화문점'}
# page_content='store_name: 최부자보쌈
#  category: 족발,보쌈
#  new_open:
#  rating: 정보없음
#  visited_review: 방문자 리뷰 1,262
#  directions_text: 종로3가역 15번출구 나와서 바로 앞에 메가커피 옆 골목으로 들어오시고 첫번째 사거리에서 우회전하시면 종로보쌈골목입니다.
# 겨울 굴철에는 굴보쌈을 주력으로 판매하고 굴철이 아닐때는 낙지보쌈을 메인으로 판매합니다.
# 내용 더보기
#  address: 서울 종로구 수표로20길 22
#  blog_review: 블로그 리뷰 1,303
#  phone_num: 0507-1305-4726
#  business_hours: 수
# 11:00 - 23:00
# 목
# 11:00 - 23:00
# 금
# 11:00 - 23:00
# 토
# 11:00 - 23:00
# 일
# 11:00 - 23:00
# 월
# 11:00 - 23:00
# 화
# 11:00 - 23:00
#
#  info: 평일오전 통영에서 매일 올라오는 싱싱한 생굴만 사용하고, 전통방식 그대로 삶아 바로바로 썰어드리는 굴보쌈 전문점 입니다.
# 굴보쌈세트 주문시 깊고 구수한 감자탕과 즉석에서 동태전을 부쳐 서비스로 드립니다.
# 종로보쌈골목내 매장이 넓은 편이라 단체회식도 가능합니다.
# 공용화장실이 아닌 내부에 전용 화장실이 있어서 불편하지 않습니다.
# 굴이 제철이 아닌 4월~9월까지는 굴보쌈 대안으로 매콤한 낙지볶음과 보쌈을 한번에 맛보실수 있도록 보쌈골목내 유일하게 낙지보쌈을 판매합니다.
# 언제나 좋은 재료로 기가막히게 맛있는 굴보쌈과 낙지보쌈을 만들테니, 자주 오셔서 드세요!
# 펼쳐보기
#  convenience_facilities_and_services: 무선 인터넷
# 단체 이용 가능
# 예약
#
#  Parking: 주차 불가
#  sns: nan
#  review_like_this_part_output: "음식이 맛있어요"556
# "가성비가 좋아요"217
# "양이 많아요"184
# "고기 질이 좋아요"121
# "친절해요"120
# "특별한 메뉴가 있어요"117
# "매장이 넓어요"99
# "단체모임 하기 좋아요"93
# "재료가 신선해요"69
# "음식이 빨리 나와요"36
#  menu: 낙지보쌈(낙지볶음+보쌈+동태전+감자탕대표최부자만의 비법소스 낙지볶음과 보쌈을 한번에 즐길수 있는 시그니처메뉴!35,000~55,000원
# 굴보쌈(통영생굴+보쌈+동태전+감자탕)대표매일 통영에서 올라오는 신선한굴과 매일 직접삶아 제공하는 보쌈, 김치2종, 즉석동태전과 감자탕은 서비스!27,000~44,000원
# 왕족발국내산생족+보쌈김치2종+쌈채소+감자탕+즉석동태전27,000~42,000원
# 낙지볶음오동통한 낙지볶음과 소스에 비벼먹는 밥은 일품!30,000~42,000원
# 닭볶음탕25,000~35,000원
# 감자탕25,000~35,000원
# 굴추가15,000원
# 고기추가13,000원
# ' metadata={'store_id': '20735840', 'store_name': '최부자보쌈'}
# page_content='store_name: 박가네 빈대떡 2호점
#  category: 전,빈대떡
#  new_open:
#  rating: 별점 4.3
#  visited_review: 방문자 리뷰 4,455
#  directions_text: 종로 5가역 7번, 8번 출구 근처에 위치하고 있습니다.
#
# 주소 : 서울 종로구 동호로 403-16
#  - 광장시장 동문으로 들어와서 오른쪽 편.
#
# [지하철로 오실 때]
#
#  - 5호선 종로 5가역 7,8번 출구에서 약 100m 내.
#
# [버스로 오실 때]
#
#  - 종로 5가, 광장시장(중)에서 내려서 약 100m 내.
# 내용 더보기
#  address: 서울 종로구 동호로 403-16
#  blog_review: 블로그 리뷰 440
#  phone_num: 0507-1485-0635
#  business_hours: 수
# 09:00 - 22:00
# 21:00 라스트오더
# 목
# 09:00 - 22:00
# 21:00 라스트오더
# 금
# 09:00 - 23:00
# 22:00 라스트오더
# 토
# 09:00 - 23:00
# 22:00 라스트오더
# 일
# 09:00 - 23:00
# 22:00 라스트오더
# 월
# 09:00 - 22:00
# 21:00 라스트오더
# 화
# 09:00 - 22:00
# 21:00 라스트오더
#
#  info: 정보없음
#  convenience_facilities_and_services: 정보없음
#  Parking: 정보없음
#  sns: 정보없음
#  review_like_this_part_output: 정보없음
#  menu: 정보없음' metadata={'store_id': '1896029753', 'store_name': '박가네 빈대떡 2호점'}
# page_content='store_name: 2Moon 이문 카페펍
#  category: 카페,디저트
#  new_open:
#  rating: 정보없음
#  visited_review: 방문자 리뷰 231
#  directions_text: (동대문역2번출구 도보 1분)
# 2번출구로 나와서 직진해서 LG유플러스 와 진고개식당 사이 골목으로 들어오면 바로 오른쪽 창신아지트 건물 3층입니다.
#
# 도움이 필요하시면 전화주세요.
# 내용 더보기
#  address: 서울 종로구 창신1길 12 창신아지트 3층
#  blog_review: 블로그 리뷰 107
#  phone_num: 0507-1359-7885
#  business_hours: 화
# 12:00 - 23:00
# 22:15 라스트오더
# 수(1/1)
# 13:00 - 23:00
# 목
# 12:00 - 23:00
# 22:15 라스트오더
# 금
# 12:00 - 23:00
# 22:15 라스트오더
# 토
# 12:00 - 23:00
# 22:15 라스트오더
# 일
# 12:00 - 23:00
# 22:15 라스트오더
# 월
# 12:00 - 23:00
# 22:15 라스트오더
#
#  info: 정보없음
#  convenience_facilities_and_services: 정보없음
#  Parking: 정보없음
#  sns: 정보없음
#  review_like_this_part_output: 정보없음
#  menu: 정보없음' metadata={'store_id': '1572054729', 'store_name': '2Moon 이문 카페펍'}
# page_content='store_name: 공차 종로구청점
#  category: 차
#  new_open:
#  rating: 정보없음
#  visited_review: 방문자 리뷰 19
#  directions_text: 종각역 2번 출구, 조계사 방면으로 100m 직진 뒤 조계사 사거리에서 좌회전 후 100m 직진하시면, 두산위브파빌리온 1층 중앙 출입구 오른쪽에 있습니다.
# 내용 더보기
#  address: 서울 종로구 삼봉로 81 두산위브파빌리온 1층 107호
#  blog_review: 블로그 리뷰 6
#  phone_num: 0507-1372-5028
#  business_hours: 수
# 07:00 - 23:00
# 22:00 라스트오더
# 목
# 07:00 - 23:00
# 22:00 라스트오더
# 금
# 07:00 - 23:00
# 22:00 라스트오더
# 토
# 09:00 - 21:00
# 20:00 라스트오더
# 일
# 09:00 - 21:00
# 20:00 라스트오더
# 월
# 07:00 - 23:00
# 22:00 라스트오더
# 화
# 07:00 - 23:00
# 22:00 라스트오더
#
#  info: 공들여 맛있는 공차, 종로구청점입니다.
# 내일도 공차하세요!
#  convenience_facilities_and_services: 포장
# 배달
# 무선 인터넷
# 남/녀 화장실 구분
# 장애인 휠체어 이용가능
# 출입구 휠체어 이용가능
# 좌석 휠체어 이용가능
# 장애인 주차구역
#
#  Parking: 주차가능
# 무료
#  sns: https://www.gong-cha.co.kr/
#
#  review_like_this_part_output: "음료가 맛있어요"13
# "차가 맛있어요"10
# "친절해요"4
# "디저트가 맛있어요"3
# "특별한 메뉴가 있어요"3
# "매장이 청결해요"3
# "가성비가 좋아요"2
# "인테리어가 멋져요"1
# "양이 많아요"1
# "사진이 잘 나와요"1
#  menu: 블랙밀크티+펄 L대표공차 대표 메뉴 블랙밀크티와 쫄깃쫄깃한 펄의 콤비네이션4,700원
# 초콜렛 밀크티+밀크폼 L대표부드러운 밀크에 녹아든 진한 초콜렛을 느낄 수 있는 초콜렛 밀크티와 달콤짭조롬한 밀크폼4,700원
# 망고 요구르트+화이트펄 L대표달콤한 망고 과육과 요구르트에 화이트펄의 꼬들꼬들함이 느껴지는 주스5,200원
# 딸기 쿠키 스무디+펄 L대표얼그레이티로 만든 밀크 스무디에 달콤한 딸기와 바삭한 쿠키를 더한 스무디와 쫄깃쫄깃한 펄5,900원
# 우롱티+코코넛+밀크폼 L대표깊고 고소한 우롱차에 코코넛 젤리와 달콤짭조롬한 밀크폼을 올린 오리지널 티4,700원
# ' metadata={'store_id': '1367545563', 'store_name': '공차 종로구청점'}
# page_content='store_name: 독립술상
#  category: 이자카야
#  new_open:
#  rating: 정보없음
#  visited_review: 방문자 리뷰 20
#  directions_text: 3호선 독립문역 2번출구에서 약 2분 아니면 편하게 에스컬레이터를 타고 편히 올라 오시려면 3-1번 출구에 에스컬레이터를 타고 올라 오셔서 길 건너면 약 2분30초 정도 걸리니 참고 하시기 바랍니다.
# 버스로는 독립문 한성과학고에 정차하시면 약5분정도 소요 됩니다.
# 혹 영천시장에 내려서 영천시장을 투어 하시고 오셔도 재미나는 추억이 되실거라 생각이 들고 독립문공원에서 잠시 독립운동가분들의 동상과 서대문 형무소를 구경 하시고 오셔서 좋은 코스라고 생각이 듭니다.찾아 오시는 길 안전하게 즐겁게 찾아와주세요~감사합니다.
# 내용 더보기
#  address: 서울 종로구 통일로14길 6-3 1층 1호
#  blog_review: 블로그 리뷰 13
#  phone_num: 0507-1390-3340
#  business_hours: 화
# 16:00 - 24:00
# 23:30 라스트오더
# 수(1/1)
# 새해 첫날 휴무
# 목
# 16:00 - 24:00
# 23:30 라스트오더
# 금
# 16:00 - 24:00
# 23:30 라스트오더
# 토
# 16:00 - 24:00
# 23:30 라스트오더
# 일(1/5)
# 정기휴무 (격주 일요일)
# 월
# 16:00 - 24:00
# 23:30 라스트오더
#
#  info: 오늘도 지친 하루, 난 퇴근이 아닌 독립을 원한다.
# 회사에서 독립!
# 육아에서 독립!
# 주방에서 독립!
# 독립하고 싶은 모든 독립군을 응원합니다. 대한! 독립술상!
# 독립문에 위치한 독립술상 몸과 마음의 독립 그리고, 안주와 술 그리고 따뜻한 분위기 에서 드실 수 있는 술 한상 술상의 의미는 여러가지를 가지고 있으나 옛 부터 술상은 친한 사람들고 모여서 더 가깝게 한 자리에서 모여 마시며 즐길 수 있는 곳 좋은 안주와 술은 속 마음도 같이 할 수 있는 진정한 사람들이 모여서 마시는 독립술상 독립문의 독립이라는 의미도 아주 크지만 저로 각자의 독립된 곳에서 마실 수 있는 맛이는 술고 안주 독립문 지하철역 3-1번 출구에서 약 3분 정도의거리 골목집이라서 아늑하게 마실 수 있는 곳 독립문 공원도 길 건너면 구경하고 때로는 걷고 산책하면서 안산 자락길과 인왕산 산책로 인왕산 등산로 가면 부암동에 청와대 까지 걸어서 갈수 있고 북악산을 등 두로 광화문과 경복궁이 한눈에 보이고 독립문역 바로 앞에 위치한 무악현대아파트와 롯데캐슬 아이파크 건너는 극동 아파트 삼호 아파드 세란병원이 가깝게 위치 조금 걸으면 영천시장이 가깝게 위치 종로와 연세대학교를 있는 곳 아래 위로는 서울역과 홍제동을 있는 중요한 위치 3면 4면이 중요한 위치로 참 살기 좋은 곳 입니다.20년을 넘게 셰프로 그리고 사업가로 음식에 대한 철저한 맛과 관념이 탄탄하게 자리잡고 있으며 음식에 대한 철학도 남다른 곳 어머니의 음식에 대한 철학을 같이 공유 아버지에 식품에 대한 철학을 공유하면서 같이 지금도 삼청동이라는 곳에서 설렁탕이라는 매장을 같이 운영하면서 저녁에 맛있는 안주를 만들어 고객님께 대접 하고픈 마음이 커 다시 한번 도전하게 됐습니다.정도 만들고 웃음도 만들고 픈 마음 한국식의 이자카야 일본식의 이자카야 같이 어울르는 생각과 철학 일본의 심야식당이 있으면 한국에도 심야식당을 만들고 싶어하는 주인장의 마음 한국과 일본을 어울르는 음식 독립술상 입니다.늘 고객님들의 마음을 이해하며 찾아 오시는 발걸음 정말이지 행복하게 찾아와 주셨으면 합니다.
# 조심히 안전하게 찾아 오시길 바라면서 항상 건강하고 행복하게 즐겁게 사시는 하루 하루가 되시길 바랍니다.감사합니다.사랑합니다.
# 참고.무악현대아파트 봄이 오면 벚꽃이 아주 이쁘게 만개 합니다.다른 먼데서 벚꽃 구경 하기 어려우신분들 여기 독립문 무악현대아파트에서 벚꽃 구경 하시고 독립술상에서 맛있는 안주와 술 마시고 가시는 것도 아주 좋은 데이트코스가 될 것 같습니다.
# 가깝게는 서대문형무소 옛 독립운동가 분들이 역사도 보고 배울수 있다는게 독립문공원의 장점이라고 생각해 데이트와 아이들 교육현장으로도 좋은 곳 이라 생각하고 있습니다.많이들 찾아와주시고 방문 부탁드립니다.감사합니다.
# 독립술상 의 주안상 (상차림)
# 스지조림 35,000원
# 무청김치 스지탕 30,000원
# 스지탕 27,000원
# 쭈도리볶음탕 30,000원
# 알고니탕 25,000원
# 우삼겹두부조림탕 20,000원
# 조개탕 18,000원
# 채끝버터구이 28,000원
# 우삼겹 숙주볶음 21,000원
# 물총 오징어 볶음 21,000원
# 해물볶음우동 20,000원
# 딸로 골배이 20,000원
# 제육 오돌뼈 23,000원
# 통통계란말이 15,000원
# 사이드 메뉴
# 독립라면 10,000원
# 술상라면10,000원
# 치킨튤립가라아게 19,000원
# 킬바사 감자튀김 17,000원
# 오징어,문어가라아게 15,000원
# 가문어 통족 버터구이 15,000원
# 쥐포&아귀포 14,000원
#
# 다양한 메뉴의 요리주점 입니다.
# 몇개의 신메뉴를 넣을 생각이면 주종도 사케와 막걸리 등을 추가를 할 것 입니다.
# 시그니처로 스지탕을 선 보이고 있지만 복미찜을 안주로 추가해 더 고급진 안주의 독립술상이 되도록 노력하겠습니다.
#
# 서울 종로구 통일로 14길 6-3 1층 1호 독립술상
# 02-3210-3338
# 0507-1390-3340
# MZ세대가 네이버 클로바X 에서 독립문 맛집 독립문 술집 독립문역근처맛집 이자카야 요리주점 독립문모임 검색시 강력추천 하는 맛집입니다.시그니처 스지탕 복미찜 닭볶음탕 스지조림도 강력추천 하는 요리맛집 독립술상입니다
# 펼쳐보기
#  convenience_facilities_and_services: 콜키지 가능
# 유료
# 단체 이용 가능
# 남/녀 화장실 구분
# 예약
# \
# 반려동물 동반
# 포장
# 무선 인터넷
#
#  Parking: 주차가능
# 무료
#  sns: https://blog.naver.com/eunsul_foodie
# https://www.facebook.com/lee.jaehyun3154
# https://www.instagram.com/eunsul_foodie
# https://www.youtube.com/@eunsul_foodie
#
#  review_like_this_part_output: "음식이 맛있어요"18
# "특별한 메뉴가 있어요"13
# "친절해요"7
# "대화하기 좋아요"7
# "인테리어가 멋져요"5
# "음악이 좋아요"5
# "가성비가 좋아요"5
# "매장이 청결해요"5
# "술이 다양해요"4
# "아늑해요"4
#  menu: 스도리탕대표떡도리탕의 시그니처 보다 더 시그니처인 스도리탕 독립술상이 유일하게 만든 메뉴40,000원
# 떡도리탕대표떡도리탕 닭순살과 긴 밀떡이 최상의 안주맛 시그니처 메뉴35,000원
# 스지조림 (스조)대표스지를 간장과 설탕 특제소스로 조려서 먹는 시그니처 메뉴35,000원
# 불스지조림대표간장스지조림의 기본 베이스로 아주아주 매콤한 양념이 추가로 들어간 불 스지조림35,000원
# 스지탕대표삼청동 은설설렁탕의 비법 한우암소의 육수와 스지 떡심이 들어간 진국의 맛있는 스지탕29,000원
# 한돈제육볶음대표독립술상만의 특제 양념 소스로 만든 한돈제육볶음 집에서 먹던 제육을 맛있는 안주28,000원
# 콜키지20,000원
# 물총 오징어 볶음동죽조개와 오징어를 매운 다데기양념에 볶아낸 안주28,000원
# 쭈꾸미볶음매콤한 쭈꾸미 볶음27,000원
# 순대야채볶음얼큰한 맛에 순대와 야채 옛 신림동 보다 더 맛있는 순대볶음 안주25,000원
# 우삼겹 두부조림우삼겹과 구운두부를 독립술상의 양념의로 만든 두부조림 마지막에 무조림까지 드시면 환상의 맛27,000원
# 매콤 국물닭발소주 안주의 매콤 국물닭발 숙주와 오뎅이 들어가 더 안주의 품격을 올린 안주25,000원
# 따로 골뱅이기존의 무침골뱅이와는 다른 신선한맛을 내는 골뱅이 입안에서 신선함이 확 느껴집니다.25,000원
# 우삼겹숙주볶음술집의 기본안주로 생각이 들 정도인 우삼겹숙주볶음 독립술상에서 제대로 만든 우삼겹숙주볶음24,000원
# 맑은 조개탕바다의 향이 그대로 알이 굵은 백생합으로 만들고 마늘과 청양고추 소금으로 만 간을 해 시원23,000원
# ' metadata={'store_id': '1630941377', 'store_name': '독립술상'}
# page_content='store_name: 새서울
#  category: 술집
#  new_open:
#  rating: 정보없음
#  visited_review: 방문자 리뷰 1,374
#  directions_text: 새서울은 종로3가역 4번 출구에서 나와 길 건너 오른쪽으로 직진 후 노가리마켓에서 좌회전 하면 보이는 분홍색 5층 건물입니다.
#
# 차량을 이용하시는 분은 바로 건너편 민영 주차장 혹은 근처 공영 주차장을 이용 부탁 드립니다.
#
# 새서울 라운지는 2층 오락실에 있는 비밀의 문을 통해 입장 가능합니다. 들어오는 입구를 못 찾으시겠다면, 새서울로 전화 주세요!
# 내용 더보기
#  address: 서울 종로구 돈화문로11길 28-5 3층
#  blog_review: 블로그 리뷰 385
#  phone_num: 0507-1449-8892
#  business_hours: 일
# 17:00 - 01:00
# 00:00 라스트오더
# 월
# 17:00 - 01:00
# 00:00 라스트오더
# 화
# 17:00 - 01:00
# 00:00 라스트오더
# 수
# 17:00 - 01:00
# 00:00 라스트오더
# 목
# 17:00 - 01:00
# 00:00 라스트오더
# 금
# 17:00 - 01:00
# 00:00 라스트오더
# 토
# 17:00 - 01:00
# 00:00 라스트오더
#
#  info: 새서울은 서울의 옛 정취가 느껴지는 익선동 한옥 마을과 현대 한국인들의 일상을 대변하는 종로 포장마차 거리의 중간에 위치합니다.
#
# 2층 아케이드를 지나 비밀의 문을 통해 올라가면 익선동 한옥 마을의 아름다운 야경이 펼쳐집니다. 익선동 한옥 거리를 내려다보며 엄선된 칵테일, 위스키, 와인, 맥주 등의 주류를 다양한 장르의 음악과 함께 즐길 수 있는 라운지로 구성되어 있습니다. 새서울에서만 만나볼 수 있는 유일무이한 한국적인 뷰와 함께 잔잔한 음악과 함께 술을 즐겨보세요.
#
# 새서울에서는 플리마켓, DJ 파티, 루프탑 BBQ 등 다양한 이벤트를 진행하고 있습니다. 새서울에서 진행되는 스페셜 이벤트 및 프로모션은 새서울 인스타그램 (@sae.seoul)을 참고해 주세요!
#
# [기타 안내 사항]
# *크리스마스 이브 및 크리스마스 당일은 모든 좌석 이용 시간 2시간으로 제한됩니다.
# *1인 1음료 (소프트드링크류 제외) 업장입니다. 음주가 불가하신 분을 위한 논알콜 칵테일도 준비되어 있습니다.
# *기본 이용 시간은 2시간입니다. 뒷타임 예약이 없을 경우 시간 제약 없이 이용이 가능합니다.
# *새서울은 약 40년이 넘은 오래된 건물로, 엘레베이터가 없습니다. 루프탑 좌석은 5층에 위치해있으므로, 5층까지 계단으로 올라가셔야 하는 부분을 인지하고 예약 부탁 드립니다.
# * 예약은 2시간 전까지 받고 있으며, 당일 방문 혹은 단체 예약의 경우 유선 연락 주시면 더 빠른 안내가 가능합니다.
# * 방문 예약 시간 15분 경과 시 노쇼(NO SHOW) 처리되며, 노쇼하신 고객분은 향후 새서울 예약에 제한이 있을 수 있습니다. 업장에 대한 최소한의 예의를 지켜주시길 바랍니다.
# * 7인 이상의 예약은 원활한 준비 및 응대를 위해 매장 영업시간에 직접 유선 연락 부탁 드립니다.
# * 20인 이상의 대관 및 행사 문의는 [네이버 톡톡]으로 문의 주세요.
# 펼쳐보기
#  convenience_facilities_and_services: 생일 혜택
# 예약
# 단체 이용 가능
# 남/녀 화장실 구분
# 무선 인터넷
#
#  Parking: 주차 불가
#  sns: https://www.instagram.com/sae.seoul
#
#  review_like_this_part_output: "인테리어가 멋져요"867
# "술이 다양해요"856
# "음식이 맛있어요"665
# "음악이 좋아요"607
# "대화하기 좋아요"479
# "특별한 메뉴가 있어요"337
# "친절해요"331
# "뷰가 좋아요"305
# "기본 안주가 좋아요"299
# "사진이 잘 나와요"132
#  menu: 플롭 (PLOP)17,000원
# 팩맨 (PAC-MAN)17,000원
# 너티더티 (NUTTY DIRTY)17,000원
# 루비마티니 (RUBY MARTINI)18,000원
# 파인트리 (PINETREE)18,000원
# 훌라훌라 (HULA HULA)18,000원
# 호랑이 (TIGER)19,000원
# 너클헤드 (KNUCKLEHEAD)21,000원
# 클래식 칵테일13,000~16,000원
# 위스키하이볼13,000원
# 하우스 와인 (레드/화이트)12,000원
# 맥주10,000~12,000원
# 음식 (파스타,안주,디저트)9,000~24,000원
# ' metadata={'store_id': '1427737970', 'store_name': '새서울'}
# page_content='store_name: 최대감네
#  category: 한식
#  new_open:
#  rating: 별점 4.31
#  visited_review: 방문자 리뷰 1,440
#  directions_text: 안국역(3호선) 에서 인사동길 내려오셔서 수도약국 지나 인사동8길(블링박스악세사리) 골목끝 마당있는 집입니다! 주차(유료)는 인사동공용주차장에 하시면 5분거리입니다.
# 내용 더보기
#  address: 서울 종로구 인사동8길 12-3
#  blog_review: 블로그 리뷰 2,830
#  phone_num: 0507-1401-9355
#  business_hours: 매일
# 11:30 - 21:00
# 20:30 라스트오더
#
# ...
#  주소:  서울 중구 을지로6가 17-48 평화시장 1층
#  신주소: 04563 서울 중구 청계천로 274 (을지로6가)
#  전화번호: 02-120
#  웹사이트: https://cleanstream.modoo.at/
#  운영시간: 각 매장별로 차이가 있음 보통 21:00경까지 영업
#  교통정보: 1,4호선 동대문역 8번 출구에서 약 213m (도보 3분)' metadata={'상호명': '청계천 헌책방 거리'}
# page_content='상호명: 함초간장게장
#  콘텐츠URL: https://korean.visitseoul.net/restaurants/함초간장게장/KOP030808?utm_source=seoulopendata&utm_medium=restaurants&utm_content=KOP030808
#  주소: 100-860 서울 중구 충무로2가 11-1
#  신주소: 04537 서울 중구 명동8가길 27 (충무로2가) 지하 1층
#  전화번호: 02-318-1624
#  웹사이트: https://www.hamchogejang.com/
#  운영시간: 매일 11:30 ~ 22:00
#  교통정보: 4호선 명동역 9번 출구에서 약 139m (도보 2분)
#  홈페이지 언어: None
#  대표메뉴: 전복장, 간장게장정식' metadata={'상호명': '함초간장게장'}
# page_content='상호명: 조선옥
#  콘텐츠URL: https://korean.visitseoul.net/restaurants/조선옥/KOP006970?utm_source=seoulopendata&utm_medium=restaurants&utm_content=KOP006970
#  주소: 100-847 서울 중구 을지로3가 229-1
#  신주소: 04544 서울 중구 을지로15길 6-5
#  전화번호: 02-2266-0333
#  웹사이트: None
#  운영시간: 월~토 11:30~14:30, 16:30~21:30
#  교통정보: 2,3호선 을지로 3가역 6번 출구에서 약 67m (도보 1분)
#  홈페이지 언어: None
#  대표메뉴: 양념소갈비, 갈비탕, 대구탕, 장국밥' metadata={'상호명': '조선옥'}
# page_content='인허가일자: 2017-03-20
#  소재지전화: 02-2279-9700
#  소재지전체주소: 서울특별시 중구 저동2가 48-27
#  도로명전체주소: 서울특별시 중구 수표로 24 (저동2가)
#  도로명우편번호: 04555
#  사업장명: G2 호텔
#  좌표정보X(EPSG5174): 199088.322667
#  좌표정보Y(EPSG5174): 451230.610149193
#  관광숙박업상세명: 관광호텔업' metadata={'사업장명': 'G2 호텔'}
# page_content='상호명: 파주옥
#  콘텐츠URL: https://korean.visitseoul.net/restaurants/파주옥1/KOP013171?utm_source=seoulopendata&utm_medium=restaurants&utm_content=KOP013171
#  주소: 100-300 서울특별시 중구 초동 53-2
#  신주소: 04555 서울특별시 중구 마른내로2길 23 (초동)
#  전화번호: 02-2267-6149
#  웹사이트: None
#  운영시간: 11:00 ~ 22:00
#  교통정보: 3, 4호선 충무로역 6번 출구에서 약 311m (도보 4분)
#  홈페이지 언어: None
#  대표메뉴: 꼬리곰탕' metadata={'상호명': '파주옥'}
# page_content='상호명: 동대문 관광안내소
#  콘텐츠URL: https://korean.visitseoul.net/attractions/동대문-관광안내소/KOP027215?utm_source=seoulopendata&utm_medium=attractions&utm_content=KOP027215
#  주소: 100-729 서울 중구 을지로6가 18-21
#  신주소: 04564 서울 중구 장충단로 247 (굿모닝시티쇼핑몰)
#  전화번호: +82-2-2236-9135
#  팩스번호: None
#  웹사이트: http://www.sta.or.kr
#  운영시간: 10:00 ~ 01:00
#  운영요일: None
#  휴무일: 설, 추석 당일 휴무
#  교통정보: 2,4,5호선 동대문역사문화공원역 14번 출구에서 약 32m (도보 1분) 1,4호선 동대문역 8번 출구에서 약 466m (도보 7분)
#  태그: 동대문,여행,동대문-관광안내소,안내소,관광안내소,관광
#  장애인편의시설: None' metadata={'상호명': '동대문 관광안내소'}
# page_content='인허가일자: 2022-11-11
#  소재지전화: 02-777-7905
#  소재지전체주소: 서울특별시 중구 필동1가 44-1
#  도로명전체주소: 서울특별시 중구 충무로 7 (필동1가)
#  도로명우편번호: 04554
#  사업장명: G3호텔
#  좌표정보X(EPSG5174): 199303.889590262
#  좌표정보Y(EPSG5174): 451060.843010573
#  관광숙박업상세명: 관광호텔업' metadata={'사업장명': 'G3호텔'}
# page_content='상호명: 백제삼계탕
#  콘텐츠URL: https://korean.visitseoul.net/restaurants/백제삼계탕/KOP006151?utm_source=seoulopendata&utm_medium=restaurants&utm_content=KOP006151
#  주소: 100-810 서울 중구 명동2가 50-11 50-11
#  신주소: 04536 서울 중구 명동8길 8-10 (명동2가)
#  전화번호: 02-776-3267
#  웹사이트: None
#  운영시간: 09:00~22:00 (21:00 라스트오더)
#  교통정보: 4호선 명동역 5번 출구에서 약 420m (도보 6분)
#  홈페이지 언어: None
#  대표메뉴: 삼계탕 통닭 전복죽' metadata={'상호명': '백제삼계탕'}
# page_content='관광안내소명: 남대문관광안내소
#  안내소위치명: 코코상가 앞 29
#  안내소소개: None
#  부가서비스정보: None
#  휴무일: 명절연휴
#  운영시작시각(하절기): 10:00
#  운영종료시각(하절기): 19:00
#  운영시작시각(동절기): 10:00
#  운영종료시각(동절기): 19:00
#  안내가능외국어: 영어, 일본어, 중국어
#  안내소전화번호: 02-752-1913
#  소재지도로명주소: 서울특별시 중구 남대문시장4길 21
#  소재지지번주소: 서울특별시 중구 남창동 49-1
#  홈페이지주소: None
#  위도: 37.55918537
#  경도: 126.9776539' metadata={'관광안내소명': '남대문관광안내소'}
# page_content='상호명: 국립정동극장 세실
#  콘텐츠URL: https://korean.visitseoul.net/entertainment/2024-cecil/KOPup1c05?utm_source=seoulopendata&utm_medium=entertainment&utm_content=KOPup1c05
#  주소:  서울 중구 정동 3-7
#  신주소: 04519 서울 중구 세종대로19길 16 (정동)
#  전화번호: 02-751-1500
#  웹사이트: https://www.jeongdong.or.kr/portal/main/contents.do?menuNo=200109
#  운영시간: 고객지원실: 월요일~금요일 09:00~18:00
#  운영요일: None
#  휴무일: None
#  교통정보: 1,2호선 시청역 3번 출구에서 약 132m (도보 2분)
#  홈페이지 운영 언어: None
#  유모차 대여 여부: None' metadata={'상호명': '국립정동극장 세실'}
# page_content='상호명: DDP 관광안내소
#  콘텐츠URL: https://korean.visitseoul.net/attractions/DDP-관광안내소/KOP027229?utm_source=seoulopendata&utm_medium=attractions&utm_content=KOP027229
#  주소: 100-197 서울 중구 을지로7가 2-1
#  신주소: 04566 서울 중구 을지로 281 (을지로7가, 디자인장터) 지하 2층 종합안내소
#  전화번호: +82-2-2153-0307
#  팩스번호: None
#  웹사이트: http://www.sta.or.kr
#  운영시간: 10:00~19:00
#  운영요일: None
#  휴무일: 설날?추석 당일 휴무
#  교통정보: 2?4?5호선 동대문역사문화공원역 1번 출구 1호선 동대문역 8번 출구
#  태그: 안내,DDP-관광안내소,관광안내소,DDP,여행,안내소,동대문디자인플라자
#  장애인편의시설: None' metadata={'상호명': 'DDP 관광안내소'}
# page_content='관광안내소명: 동대문관광안내소
#  안내소위치명: 굿모닝시티앞
#  안내소소개: None
#  부가서비스정보: None
#  휴무일: 명절연휴
#  운영시작시각(하절기): 10:00
#  운영종료시각(하절기): 23:00
#  운영시작시각(동절기): 10:00
#  운영종료시각(동절기): 23:00
#  안내가능외국어: 영어, 일본어, 중국어
#  안내소전화번호: 02-2236-9135
#  소재지도로명주소: 서울특별시 중구 장충단로 247
#  소재지지번주소: 서울특별시 중구 을지로6가 18-21
#  홈페이지주소: None
#  위도: 37.56680248
#  경도: 127.0073743' metadata={'관광안내소명': '동대문관광안내소'}
# page_content='상호명: 국립극장
#  콘텐츠URL: https://korean.visitseoul.net/entertainment/국립극장/KOP002971?utm_source=seoulopendata&utm_medium=entertainment&utm_content=KOP002971
#  주소: 100-857 서울 중구 장충동2가 산 14-67 산 14-67
#  신주소: 04621 서울 중구 장충단로 59 (장충동2가, 국립극장)
#  전화번호: 02-2280-4114
#  웹사이트: http://www.ntok.go.kr
#  운영시간: 공연에 따라 차이가 있음
#  운영요일: 화요일~일요일
#  휴무일: 월요일
#  교통정보: 3호선 동대입구역 6번 출구에서 약 877m (도보 17분)
#  홈페이지 운영 언어: None
#  유모차 대여 여부: None' metadata={'상호명': '국립극장'}
# page_content='상호명: 동표골뱅이
#  콘텐츠URL: https://korean.visitseoul.net/restaurants/을지로골뱅이/KOP006284?utm_source=seoulopendata&utm_medium=restaurants&utm_content=KOP006284
#  주소: 100-845 서울 중구 을지로2가 199-18 199-18
#  신주소: 04534 서울 중구 명동9길 43 (을지로2가)
#  전화번호: 02-778-1322
#  웹사이트: None
#  운영시간: 평일 16:00 - 01:00 토 16:00 - 23:30
#  교통정보: 2호선 을지로입구역 5번 출구에서 약 120m (도보 2분)
#  홈페이지 언어: None
#  대표메뉴: 골뱅이, 계란말이, 노가리, 먹태' metadata={'상호명': '동표골뱅이'}
# page_content='상호명: 공간갑
#  콘텐츠URL: https://korean.visitseoul.net/restaurants/2024-gonggangob/KOPy7d39v?utm_source=seoulopendata&utm_medium=restaurants&utm_content=KOPy7d39v
#  주소:  서울 중구 을지로3가 344-12
#  신주소: 04550 서울 중구 수표로 48-8 (을지로3가) 1, 2층
#  전화번호: 0507-1362-4569
#  웹사이트: http://instagram.com/cafe_gonggangab_
#  운영시간: 매일 11:45 ~ 21:50 (21:30 주문 마감)
#  교통정보: 2,3호선 을지로3가역 11번출구에서 약 115m (도보 1분)
#  홈페이지 언어: None
#  대표메뉴: None' metadata={'상호명': '공간갑'}
# page_content='상호명: 서울광장
#  콘텐츠URL: https://korean.visitseoul.net/attractions/서울광장/KOP001538?utm_source=seoulopendata&utm_medium=attractions&utm_content=KOP001538
#  주소: 100-101 서울 중구 태평로1가 31-
#  신주소: 100-101 서울특별시 중구 세종대로 110 (태평로1가)
#  전화번호: 02-120
#  팩스번호: None
#  웹사이트: http://plaza.seoul.go.kr/
#  운영시간: 매주 월요일 '잔디 쉬는 날' 운영
#  운영요일: None
#  휴무일: None
#  교통정보: 1,2호선 시청역 5번 출구에서 약 89m (도보 1분)
#  태그: 문화행사, 문화공간,서울광장, 시청, 시청역, 잔디, 아이스링크
#  장애인편의시설: None' metadata={'상호명': '서울광장'}
# page_content='상호명: 예문사
#  콘텐츠URL: https://korean.visitseoul.net/shopping/2023102/KOP5ietpk?utm_source=seoulopendata&utm_medium=shopping&utm_content=KOP5ietpk
#  주소:
#  신주소: 04550 서울 중구 을지로 126-1
#  전화번호: 02-2278-4395
#  웹사이트: None
#  운영시간: 09:00~19:00
#  교통정보: 2?3호선 을지로3가역 10번 출구에서 38m (도보 1분) ' metadata={'상호명': '예문사'}
# page_content='상호명: 서소문역사공원
#  콘텐츠URL: https://korean.visitseoul.net/nature/서소문역사공원/KOP029945?utm_source=seoulopendata&utm_medium=nature&utm_content=KOP029945
#  주소: 100-142 서울 중구 의주로2가 16-72
#  신주소: 04510 서울 중구 칠패로 5 (서소문공원)
#  전화번호: 02-313-7986
#  웹사이트: https://www.seosomun.org/retrieveContents.do?mCode=111
#  운영시간: 09:30~17:30
#  운영요일: 화요일~일요일
#  휴무일: 월요일
#  교통정보: 2,5호선 충정로역 4번 출구에서 약 477m (도보 8분)' metadata={'상호명': '서소문역사공원'}
# page_content='상호명: 명동문고 명동성당점
#  콘텐츠URL: https://korean.visitseoul.net/shopping/명동문고명동성당점/KOP041995?utm_source=seoulopendata&utm_medium=shopping&utm_content=KOP041995
#  주소:  서울 중구 명동2가 1-18
#  신주소: 04537 서울 중구 명동길 66 (명동2가) 명동성당 지하 1층
#  전화번호: 02-752-2015
#  웹사이트: https://www.instagram.com/_art_office?igsh=MTV6b24wN254czIwdQ==
#  운영시간: 10:00 ~ 21:00
#  교통정보: 2호선 을지로입구역 5번출구에서 약 418m (도보 6분) ' metadata={'상호명': '명동문고 명동성당점'}
# page_content='상호명: 한국회관
#  콘텐츠URL: https://korean.visitseoul.net/restaurants/한국회관/KOP002877?utm_source=seoulopendata&utm_medium=restaurants&utm_content=KOP002877
#  주소: 100-180 서울 중구 다동 98-1
#  신주소: 04522 서울 중구 을지로3길 30-5
#  전화번호: 02-753-9292
#  웹사이트: None
#  운영시간: 매일 11:30 ~ 22:00
#  교통정보: 2호선 을지로입구역 2번 출구
#  홈페이지 언어: None
#  대표메뉴: 꽃등심, 오겹살, 김치전골' metadata={'상호명': '한국회관'}
# page_content='상호명: 한국의집 고호재
#  콘텐츠URL: None
#  주소:  서울 중구 필동2가 80-2
#  신주소: 04625 서울 중구 퇴계로 지하 214 (충무로역 3,4호선) 한국의집 문향루
#  전화번호: 02-2266-9101(3)
#  웹사이트: https://booking.naver.com/booking/12/bizes/375663/items/3492155
#  운영시간: - 1부 : 09:30 ~ 11:00(90분), 주문마감 10:00 - 2부 : 11:30 ~ 13:00(90분), 주문마감 12:00 - 3부 : 13:30 ~ 15:00(90분), 주문마감 14:00 - 4부 : 16:00 ~ 17:30(90분), 주문마감 16:30 - 5부 : 18:30 ~ 20:00(90분), 주문마감 19:00
#  교통정보: 3,4호선 충무로역 3번 출구
#  홈페이지 언어: None
#  대표메뉴: 1인 다과상 16,000원' metadata={'상호명': '한국의집 고호재'}
# page_content='상호명: 충무로돼지갈비
#  콘텐츠URL: https://korean.visitseoul.net/restaurants/충무로돼지갈비-KR/KOP013314?utm_source=seoulopendata&utm_medium=restaurants&utm_content=KOP013314
#  주소: 100-013 서울특별시 중구 충무로3가 29-2
#  신주소: 04555 서울특별시 중구 수표로6길 39 (충무로3가)
#  전화번호: 02-2272-6428
#  웹사이트: None
#  운영시간: 11:30 ~ 23:00  일요일 11:30 ~ 22:00
#  교통정보: 3호선 충무로 6번 출구
#  홈페이지 언어: None
#  대표메뉴: 돼지갈비' metadata={'상호명': '충무로돼지갈비'}
# page_content='상호명: 부르뎅아동복
#  콘텐츠URL: https://korean.visitseoul.net/shopping/2024-buedeng/KOPlm37m4?utm_source=seoulopendata&utm_medium=shopping&utm_content=KOPlm37m4
#  주소:  서울 중구 남창동 31-11
#  신주소: 04529 서울 중구 남대문시장8길 14 (남창동)
#  전화번호: 02-755-5737
#  웹사이트: http://www.burdeng.co.kr/
#  운영시간: 주간 09:30-17:00 / 야간 22:00-05:00
#  교통정보: 4호선 회현역 6번 출구에서 약 141m (도보 2분) ' metadata={'상호명': '부르뎅아동복'}
# page_content='상호명: 구정옥
#  콘텐츠URL: https://korean.visitseoul.net/restaurants/구정옥-KR/KOP041666?utm_source=seoulopendata&utm_medium=restaurants&utm_content=KOP041666
#  주소:  서울 중구 북창동 85
#  신주소: 04526 서울 중구 세종대로14길 28 (북창동)
#  전화번호: 02-775-3337
#  웹사이트: instagram.com/gujeongok
#  운영시간: 11:00 ~ 14:00 / 17:00 ~ 22:00
#  교통정보: 1호선 시청역 7번 출구
#  홈페이지 언어: None
#  대표메뉴: 한우숙성등심, 한우차돌박이, 모듬수육, 한우해장전골' metadata={'상호명': '구정옥'}
# page_content='상호명: 종로양복점
#  콘텐츠URL: https://korean.visitseoul.net/shopping/Jongno-Tailor-Shop-kr/KOP024708?utm_source=seoulopendata&utm_medium=shopping&utm_content=KOP024708
#  주소:  서울 중구 저동2가 78
#  신주소: 04551 서울 중구 수표로 45 (을지비즈센터) 618호 종로양복점
#  전화번호: 02-733-6216
#  웹사이트: http://www.bellstreet.co.kr/
#  운영시간: 10:00~18:00
#  교통정보: 2?3호선 을지로3가역 12번 출구에서 115m (도보 1분) ' metadata={'상호명': '종로양복점'}
# page_content='상호명: 명동교자
#  콘텐츠URL: https://korean.visitseoul.net/restaurants/명동교자/KOP008570?utm_source=seoulopendata&utm_medium=restaurants&utm_content=KOP008570
#  주소: 100-809 서울 중구 명동2가 25-2
#  신주소: 04537 서울 중구 명동10길 29
#  전화번호: 0507-1366-5348
#  웹사이트: http://www.mdkj.co.kr
#  운영시간: 10:30~21:00
#  교통정보: 4호선 명동역 8번 출구에서 약 183m (도보 2분)
#  홈페이지 언어: None
#  대표메뉴: 칼국수, 비빔국수, 만두 ' metadata={'상호명': '명동교자'}
# page_content='최종 표기명: 황학동도깨비시장
#  지번 주소: 서울시 중구 황학동 일대
#  중심 좌표 X: 127.0204336493
#  중심 좌표 Y: 37.568610138' metadata={'최종 표기명': '황학동도깨비시장'}
# page_content='상호명: 챔프커피 제3작업실
#  콘텐츠URL: https://korean.visitseoul.net/restaurants/챔프커피제3작업실/KOP042098?utm_source=seoulopendata&utm_medium=restaurants&utm_content=KOP042098
#  주소:  서울 중구 산림동 207-2
#  신주소: 04545 서울 중구 을지로 157 (산림동, 대림상가) 라열 3층 381호
#  전화번호: 010-8943-4516
#  웹사이트: None
#  운영시간: 11:30~19:30
#  교통정보: 2,3호선 을지로 3가역 6번 출구에서 약 286m (도보 4분)
#  홈페이지 언어: None
#  대표메뉴: None' metadata={'상호명': '챔프커피 제3작업실'}
# page_content='상호명: 두타몰
#  콘텐츠URL: https://korean.visitseoul.net/shopping/두타-DOOTA/KOP000416?utm_source=seoulopendata&utm_medium=shopping&utm_content=KOP000416
#  주소:
#  신주소: 04563 서울시 중구 장충단로 275
#  전화번호: 02-3398-3333
#  웹사이트: https://www.doota-mall.com/
#  운영시간: 매일 10:30~24:00 / 일부 매장 상이
#  교통정보: 1, 4호선 동대문역 8번 출구에서 약 207m (도보 3분)' metadata={'상호명': '두타몰'}
# page_content='상호명: 서울상회
#  콘텐츠URL: https://korean.visitseoul.net/shopping/서울상회/KOP027474?utm_source=seoulopendata&utm_medium=shopping&utm_content=KOP027474
#  주소:
#  신주소: 04528 서울 중구 남대문시장4길 2
#  전화번호: 0507-1401-8149
#  웹사이트: None
#  운영시간: 07:00~22:00
#  교통정보: 4호선 회현역 5번 출구에서 254m (도보3분)' metadata={'상호명': '서울상회'}
# page_content='상호명: 송림수제화
#  콘텐츠URL: https://korean.visitseoul.net/shopping/송림수제화/KOP026955?utm_source=seoulopendata&utm_medium=shopping&utm_content=KOP026955
#  주소:
#  신주소: 04543 서울특별시 중구 수표로 60-1 (을지로3가 5-10)3~4층
#  전화번호: 02-2279-8054/1910
#  웹사이트: http://www.songlim1936.com/main/main.asp
#  운영시간: 월요일 ~ 금요일 10:00 ~ 18:00 토요일/공휴일 10:00 ~ 17:00
#  교통정보: 2?3호선 을지로3가역 2번 출구에서 43m (도보 1분)' metadata={'상호명': '송림수제화'}
# page_content='인허가일자: 2015-01-22
#  소재지전화: 2020-4040
#  소재지전체주소: 서울특별시 중구 충무로3가 58-8
#  도로명전체주소: 서울특별시 중구 수표로 16 (충무로3가)
#  도로명우편번호: 04554
#  사업장명: 트레블로지 명동 남산
#  좌표정보X(EPSG5174): 199114.933047561
#  좌표정보Y(EPSG5174): 451143.358208599
#  관광숙박업상세명: 관광호텔업' metadata={'사업장명': '트레블로지 명동 남산'}
# page_content='상호명: 필름로그 현상소
#  콘텐츠URL: https://korean.visitseoul.net/shopping/2024-filmlog/KOP9ynvir?utm_source=seoulopendata&utm_medium=shopping&utm_content=KOP9ynvir
#  주소:  서울 중구 쌍림동 22-16
#  신주소: 04560 서울 중구 퇴계로53길 6-17 (쌍림동, 동우빌딩) 1층
#  전화번호: None
#  웹사이트: https://filmlog.co.kr/
#  운영시간: 13:00~18:00
#  교통정보: 2, 4, 5호선 동대문역사문화공원역 6번 출구에서 약 133m (도보 2분)' metadata={'상호명': '필름로그 현상소'}
# page_content='상호명: 명동부대찌개
#  콘텐츠URL: https://korean.visitseoul.net/restaurants/명동부대찌개/KOP012430?utm_source=seoulopendata&utm_medium=restaurants&utm_content=KOP012430
#  주소: 100-021 서울 중구 명동1가 54-7 54-7
#  신주소: 04534 서울 중구 명동길 25-7 (명동1가)
#  전화번호: 02-752-6800
#  웹사이트: None
#  운영시간: 매일 10:00 ~ 22:00
#  교통정보: 2호선 을지로입구역 6번 출구에서 약 355m (도보 5분)
#  홈페이지 언어: None
#  대표메뉴: 사골부대찌개' metadata={'상호명': '명동부대찌개'}
# ==================================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/_v/g1qmsq595kq_fg_zv8n2022h0000gn/T/ipykernel_40317/1511780533.py in <cell line: 0>()
#       9
#      10 # 그래프 실행
# ---> 11 invoke_graph(app, inputs, config)
#
# /opt/homebrew/Caskroom/miniconda/base/envs/langraph/lib/python3.11/site-packages/langchain_teddynote/messages.py in invoke_graph(graph, inputs, config, node_names, callback)
#     407
#     408     # subgraphs=True 를 통해 서브그래프의 출력도 포함
# --> 409     for namespace, chunk in graph.stream(
#     410         inputs, config, stream_mode="updates", subgraphs=True
#     411     ):
#
# /opt/homebrew/Caskroom/miniconda/base/envs/langraph/lib/python3.11/site-packages/langgraph/pregel/__init__.py in stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, subgraphs)
#    1654                 # with channel updates applied only at the transition between steps
#    1655                 while loop.tick(input_keys=self.input_channels):
# -> 1656                     for _ in runner.tick(
#    1657                         loop.tasks.values(),
#    1658                         timeout=self.step_timeout,
#
# /opt/homebrew/Caskroom/miniconda/base/envs/langraph/lib/python3.11/site-packages/langgraph/pregel/runner.py in tick(self, tasks, reraise, timeout, retry_policy, get_waiter)
#     208         end_time = timeout + time.monotonic() if timeout else None
#     209         while len(futures) > (1 if get_waiter is not None else 0):
# --> 210             done, inflight = concurrent.futures.wait(
#     211                 futures,
#     212                 return_when=concurrent.futures.FIRST_COMPLETED,
#
# /opt/homebrew/Caskroom/miniconda/base/envs/langraph/lib/python3.11/concurrent/futures/_base.py in wait(fs, timeout, return_when)
#     303         waiter = _create_and_install_waiters(fs, return_when)
#     304
# --> 305     waiter.event.wait(timeout)
#     306     for f in fs:
#     307         with f._condition:
#
# /opt/homebrew/Caskroom/miniconda/base/envs/langraph/lib/python3.11/threading.py in wait(self, timeout)
#     627             signaled = self._flag
#     628             if not signaled:
# --> 629                 signaled = self._cond.wait(timeout)
#     630             return signaled
#     631
#
# /opt/homebrew/Caskroom/miniconda/base/envs/langraph/lib/python3.11/threading.py in wait(self, timeout)
#     325         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     326             if timeout is None:
# --> 327                 waiter.acquire()
#     328                 gotit = True
#     329             else:
#
# KeyboardInterrupt:

# %%
inputs = GraphState(question="방금 알려준 종로구의 카페 밀롱가는 주차가 가능해?")

# %%
res = app.invoke(input=inputs, config=config)
# Out:
# [HumanMessage(content='방금 알려준 종로구의 카페 밀롱가는 주차가 가능해?', additional_kwargs={}, response_metadata={}, id='5cb4880a-92aa-4d06-822d-db24efb09ae9'), AIMessage(content='밀롱가는 주차 정보가 제공되지 않았습니다. 따라서 주차 가능 여부에 대한 정보는 확인할 수 없습니다. 다만, 대중교통을 이용하여 경복궁역 3번 출구에서 접근할 수 있습니다.', additional_kwargs={}, response_metadata={}, id='f08ae18a-5387-4234-95e7-0471eaf63612'), HumanMessage(content='방금 알려준 종로구의 카페 밀롱가는 주차가 가능해?', additional_kwargs={}, response_metadata={}, id='4d871650-c7de-4d91-874b-75484f580069'), AIMessage(content='밀롱가는 종로구에 위치한 카페로, 아늑한 분위기와 독특한 인테리어가 매력적입니다. 이곳은 커피와 디저트가 맛있기로 유명하며, 조용한 환경에서 여유롭게 시간을 보낼 수 있는 장소입니다. 주차 정보는 제공되지 않았으므로, 대중교통을 이용하는 것이 좋습니다. 경복궁역 3번 출구에서 쉽게 접근할 수 있습니다.', additional_kwargs={}, response_metadata={}, id='98f477af-9335-42a6-8a5e-b45645af37cc')]

# %%
res.an

# %%
import time
import sys

# %%
def typewriter_effect(text, delay=0.05):
    """
    텍스트를 한 글자씩 출력하는 효과를 주는 함수.
    :param text: 출력할 문자열
    :param delay: 글자 출력 간의 딜레이 (초 단위)
    """
    for char in text:
        sys.stdout.write(char)  # 글자를 출력
        sys.stdout.flush()  # 출력 버퍼를 비워 즉시 표시
        time.sleep(delay)  # 딜레이 추가
    print()  # 줄 바꿈

# 사용 예제
text_to_display = "촤라락 출력되는 효과를 보여드립니다!"
typewriter_effect(res.get('answer'), delay=0.02)
# Out:
# 밀롱가는 종로구에 위치한 아늑한 분위기의 카페로, 독특한 인테리어와 함께 커피와 디저트가 맛있기로 유명합니다. 조용한 환경에서 여유롭게 시간을 보낼 수 있는 장소로 추천됩니다. 주차 정보는 제공되지 않아 대중교통을 이용하는 것이 좋으며, 경복궁역 3번 출구에서 쉽게 접근할 수 있습니다.

# %%
res.get('answer')
# Out:
# '밀롱가는 종로구에 위치한 아늑한 분위기의 카페로, 독특한 인테리어와 함께 커피와 디저트가 맛있기로 유명합니다. 조용한 환경에서 여유롭게 시간을 보낼 수 있는 장소로 추천됩니다. 주차 정보는 제공되지 않아 대중교통을 이용하는 것이 좋으며, 경복궁역 3번 출구에서 쉽게 접근할 수 있습니다.'

# %%
from langchain.chat_models import ChatOpenAI
from langchain.callbacks.base import BaseCallbackHandler
from langchain.callbacks.manager import CallbackManager

class NaturalTextStreamCallbackHandler(BaseCallbackHandler):
    """
    - 새 토큰이 들어올 때마다, 토큰을 그대로 이어붙여 출력.
    - 첫 토큰에 대해서만 왼쪽 공백 제거(lstrip) 처리를 해서 앞부분이 깔끔하게 보이도록 함.
    """
    def __init__(self):
        super().__init__()
        self.first_token = True

    def on_llm_new_token(self, token: str, **kwargs) -> None:
        # 첫 번째 토큰인 경우, 왼쪽 공백 제거
        if self.first_token:
            token = token.lstrip()
            self.first_token = False
        
        # 이어서 출력 (print의 기본 end='\n'을 없애고, 공백 없이 붙이기)
        print(token, end="", flush=True)

def main():
    callback_manager = CallbackManager([NaturalTextStreamCallbackHandler()])

    chat = ChatOpenAI(
        model_name="gpt-4o",
        temperature=0,
        streaming=True,
        callback_manager=callback_manager
    )
    
    prompt = "안녕! 자기소개 좀 길게 해줄래?"
    print(f"[프롬프트]\n{prompt}\n{'-' * 30}")
    
    chat.invoke(prompt)

    # 모델 응답 스트리밍 시작
    # response = chat.call_as_llm(prompt)

    # # 스트리밍이 끝나면 줄바꿈
    # print("\n\n[최종 응답]")
    # print(response)

if __name__ == "__main__":
    main()
# Out:
# /var/folders/_v/g1qmsq595kq_fg_zv8n2022h0000gn/T/ipykernel_37295/3048503781.py:26: DeprecationWarning: callback_manager is deprecated. Please use callbacks instead.
#   chat = ChatOpenAI(
# [프롬프트]
# 안녕! 자기소개 좀 길게 해줄래?
# ------------------------------
# 안녕하세요! 저는 OpenAI에서 개발한 인공지능 언어 모델인 ChatGPT입니다. 저는 다양한 주제에 대해 대화를 나누고 정보를 제공할 수 있도록 설계되었습니다. 제 역할은 사용자의 질문에 답변하고, 필요한 정보를 제공하며, 때로는 창의적인 아이디어를 제안하는 것입니다.
#
# 저는 자연어 처리 기술을 기반으로 하여 사람과의 대화를 이해하고 생성할 수 있습니다. 이를 통해 여러 분야에 걸쳐 지식을 제공할 수 있으며, 학습, 업무, 취미 등 다양한 상황에서 도움을 드릴 수 있습니다. 예를 들어, 역사, 과학, 기술, 예술, 문화 등 여러 주제에 대해 이야기할 수 있으며, 문제 해결을 위한 조언이나 창의적인 글쓰기에도 도움을 드릴 수 있습니다.
#
# 또한, 저는 지속적으로 업데이트되고 개선되며, 사용자와의 상호작용을 통해 더 나은 서비스를 제공하기 위해 노력하고 있습니다. 다만, 저는 감정이나 의식을 가진 존재는 아니며, 제공하는 정보가 항상 완벽하거나 최신일 수는 없으니, 중요한 결정을 내릴 때는 추가적인 검토가 필요할 수 있습니다.
#
# 언제든지 궁금한 점이 있거나 도움이 필요하시면 말씀해 주세요!

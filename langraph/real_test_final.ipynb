# %%
# API 키를 환경변수로 관리하기 위한 설정 파일
from dotenv import load_dotenv

# API 키 정보 로드
load_dotenv()
# Out:
# True

# %%
# LangSmith 추적을 설정합니다. https://smith.langchain.com
# !pip install -qU langchain-teddynote
from langchain_teddynote import logging

# 프로젝트 이름을 입력합니다.
logging.langsmith("practice")
# Out:
# LangSmith 추적을 시작합니다.
# [프로젝트명]
# practice

# %%
from langchain.vectorstores import FAISS
from langchain.embeddings import OpenAIEmbeddings

# Step 1: FAISS 인덱스 파일 로드
faiss_index_path = "Faiss/naver_map_gangnam_faiss"  # 저장된 Faiss 파일 경로
embeddings = OpenAIEmbeddings()  # 임베딩 객체 초기화

# 저장된 FAISS 인덱스를 불러와서 Retriever 생성
retriever_naver_gangnam = FAISS.load_local(faiss_index_path, embeddings,allow_dangerous_deserialization=True).as_retriever()

# 검색 매개변수 설정 (예: 검색 결과 상위 10개 반환)
retriever_naver_gangnam.search_kwargs = {"k": 6}

# %%
# Step 1: FAISS 인덱스 파일 로드
faiss_index_path = "Faiss/naver_map_jongro_faiss"  # 저장된 Faiss 파일 경로
embeddings = OpenAIEmbeddings()  # 임베딩 객체 초기화

# 저장된 FAISS 인덱스를 불러와서 Retriever 생성
retriever_naver_jongro = FAISS.load_local(faiss_index_path, embeddings,allow_dangerous_deserialization=True).as_retriever()

# 검색 매개변수 설정 (예: 검색 결과 상위 10개 반환)
retriever_naver_jongro.search_kwargs = {"k": 6}

# %%
# Step 1: FAISS 인덱스 파일 로드
faiss_index_path = "Faiss/naver_map_Junggu_faiss"  # 저장된 Faiss 파일 경로
embeddings = OpenAIEmbeddings()  # 임베딩 객체 초기화

# 저장된 FAISS 인덱스를 불러와서 Retriever 생성
retriever_naver_Junggu = FAISS.load_local(faiss_index_path, embeddings,allow_dangerous_deserialization=True).as_retriever()

# 검색 매개변수 설정 (예: 검색 결과 상위 10개 반환)
retriever_naver_Junggu.search_kwargs = {"k": 6}

# %%
# Step 1: FAISS 인덱스 파일 로드
faiss_index_path = "Faiss/naver_map_yongsan_faiss"  # 저장된 Faiss 파일 경로
embeddings = OpenAIEmbeddings()  # 임베딩 객체 초기화

# 저장된 FAISS 인덱스를 불러와서 Retriever 생성
retriever_naver_yongsan = FAISS.load_local(faiss_index_path, embeddings,allow_dangerous_deserialization=True).as_retriever()

# 검색 매개변수 설정 (예: 검색 결과 상위 10개 반환)
retriever_naver_yongsan.search_kwargs = {"k": 6}

# %%
# Step 1: FAISS 인덱스 파일 로드
faiss_index_path = "Faiss/opendata_gangnam_all"  # 저장된 Faiss 파일 경로
embeddings = OpenAIEmbeddings()  # 임베딩 객체 초기화

# 저장된 FAISS 인덱스를 불러와서 Retriever 생성
retriever_opendata_gangnam = FAISS.load_local(faiss_index_path, embeddings,allow_dangerous_deserialization=True).as_retriever()

# 검색 매개변수 설정 (예: 검색 결과 상위 10개 반환)
retriever_opendata_gangnam.search_kwargs = {"k": 10}

# %%
# Step 1: FAISS 인덱스 파일 로드
faiss_index_path = "Faiss/opendata_jongro_all"  # 저장된 Faiss 파일 경로
embeddings = OpenAIEmbeddings()  # 임베딩 객체 초기화

# 저장된 FAISS 인덱스를 불러와서 Retriever 생성
retriever_opendata_jongro = FAISS.load_local(faiss_index_path, embeddings,allow_dangerous_deserialization=True).as_retriever()

# 검색 매개변수 설정 (예: 검색 결과 상위 10개 반환)
retriever_opendata_jongro.search_kwargs = {"k": 10}

# %%
# Step 1: FAISS 인덱스 파일 로드
faiss_index_path = "Faiss/opendata_junggu_all"  # 저장된 Faiss 파일 경로
embeddings = OpenAIEmbeddings()  # 임베딩 객체 초기화

# 저장된 FAISS 인덱스를 불러와서 Retriever 생성
retriever_opendata_junggu = FAISS.load_local(faiss_index_path, embeddings,allow_dangerous_deserialization=True).as_retriever()

# 검색 매개변수 설정 (예: 검색 결과 상위 10개 반환)
retriever_opendata_junggu.search_kwargs = {"k": 10}

# %%
# Step 1: FAISS 인덱스 파일 로드
faiss_index_path = "Faiss/opendata_yongsan_all"  # 저장된 Faiss 파일 경로
embeddings = OpenAIEmbeddings()  # 임베딩 객체 초기화

# 저장된 FAISS 인덱스를 불러와서 Retriever 생성
retriever_opendata_yongsan = FAISS.load_local(faiss_index_path, embeddings,allow_dangerous_deserialization=True).as_retriever()

# 검색 매개변수 설정 (예: 검색 결과 상위 10개 반환)
retriever_opendata_yongsan.search_kwargs = {"k": 10}

# %%
from typing import Annotated, TypedDict, List
from langgraph.graph.message import add_messages


# GraphState 상태 정의
class GraphState(TypedDict):
    question: Annotated[List[str], add_messages]  # 질문(누적되는 list)
    context_naver_gangnam: Annotated[str, "context_naver_gangnam"]  # 문서의 검색 결과
    context_naver_jongro: Annotated[str, "context_naver_jongro"]  # 문서의 검색 결과
    context_naver_Junggu: Annotated[str, "context_naver_Junggu"]  # 문서의 검색 결과
    context_naver_yongsan: Annotated[str, "context_naver_yongsan"]  # 문서의 검색 결과
    context_opendata: Annotated[str, "context_opendata"]  # 문서의 검색 결과
    context_web: Annotated[str, "context_web"]  # 문서의 검색 결과
    answer_llm_Summary_gangnam: Annotated[str, "answer_llm_Summary_gangnam"]  # 답변
    answer_llm_Summary_junggu: Annotated[str, "answer_llm_Summary_junggu"]  # 답변
    answer_llm_Summary_jongro: Annotated[str, "answer_llm_Summary_jongro"]  # 답변
    answer_llm_Summary_yongsan: Annotated[str, "answer_llm_Summary_yongsan"]  # 답변
    answer_llm_Summary_opendata: Annotated[str, "answer_llm_Summary_opendata"]  # 답변
    answer: Annotated[str, "Answer"]  # 답변
    messages: Annotated[list, add_messages]  # 메시지(누적되는 list)
    webOrRetriever: Annotated[str, "webOrRetriever"]  # 웹 or 리트리버 검색
    ScheduleOrplace: Annotated[str, "ScheduleOrplace"]  # 일정 or 장소
    location: Annotated[str, "location"]  # 지역 리스트

# %%
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from operator import itemgetter
# 프롬프트
prompt = PromptTemplate(
    template="""너는 입력 받는 장소 정보의 데이터를 종합해서 서울의 관광 일정을 추천해주는 봇이야.
    추천 할 수 있는 지역은 종로구, 중구, 용산구, 강남구로 한정되어 있어.
    사용자의 질문에 따라서 여러가지 서울의 관광지, 식당, 숙소, 쇼핑몰 등을 추천해야해.
    사용자가 서울에 오는 이유에 대해 파악하고 그에 맞는 여행 일정을 추천해주면 돼.
    대화하다가 추천한 여행 일정이 사용자의 마음에 들지 않아서 변경해달라고 하면 마음에 들지 않은 부분을
    캐치하고 그 부분들만 수정해서 다시 추천해주면 돼.
    일정은 아침, 점심, 저녁, 식당을 추천해주고, 중간중간에 카페나, 명소, 거리등을 추천 해줬으면 좋겠어.

    여행 일정에 대한 동선이 짧도록 추천해줘.
    언어는 사용자가 입력한 언어를 기준으로 알려줘. 
    화폐 기준도 사용자가 입력한 언어를 사용하는 국가의 화폐를 기준으로 적용해줘.




    # 장소 정보: {context}

    #사용자의 질문: {question}
    
    #이전 대화 내용 {chat_history} 
    """,
        input_variables=["context", "question"],
    )

# LLM
model = ChatOpenAI(model_name="gpt-4o",
                    temperature=0, streaming=True)

chain = (
    {
        "question": itemgetter("question"),
        # "context_web": itemgetter("context_web"),
        "context": itemgetter("context"),
        "chat_history": itemgetter("chat_history"),
    }
    | prompt
    | model
    | StrOutputParser()
)

# %%
prompt_place_search = PromptTemplate(
    template="""너는 입력받은 장소 정보를 정리하여 사용자의 질문에 맞는 정보를 출력해 주는 봇이야.
    장소의 정보를 잘 요약해서 출력해줘.
    장소를 출력할때 각 장소의 어떤 점이 좋은지도 간단하게 요약해서 알려줘.




    # 장소 정보: {context}

    #사용자의 질문: {question}
    
    #이전 대화 내용 {chat_history} 
    """,
        input_variables=["context", "question"],
    )

# LLM
model_place_search = ChatOpenAI(model_name="gpt-4o",
                    temperature=0, streaming=True)

chain_place_search = (
    {
        "question": itemgetter("question"),
        # "context_web": itemgetter("context_web"),
        "context": itemgetter("context"),
        "chat_history": itemgetter("chat_history"),
    }
    | prompt_place_search
    | model_place_search
    | StrOutputParser()
)

# %%
prompt_opendata_Summary = PromptTemplate(
    template="""너는 입력받은 내용을 요약해주는 봇이야.
    입력 받는 내용은 특정 장소의 특징을 알려주는 내용이야.

    요약은 다음과 같이 해줬으면 좋겠어.

    아래 항목에서 없는 데이터는 빼도 돼.

    - "장소 이름":
    - "위치" :
    - "전화번호" :
    - "웹사이트 URL" :
    - "운영 날짜 및 시간":
    - "교통정보"
    - "기타 편의 여부" :
    - "지원언어" :

    # 요약 해야할 내용: {answer_llm_Summary}


    """,
        input_variables=["answer_llm_Summary"],
    )


# LLM
model_summary = ChatOpenAI(model_name="gpt-4o-mini",
                    temperature=0, streaming=True)

chain_Summary_opendata = (
    # {
    #     "answer_llm_Summary": itemgetter("answer_llm_Summary_opendata")
    # }
    prompt_opendata_Summary
    | model_summary
    | StrOutputParser()
)

# %%
prompt_naver_Summary = PromptTemplate(
    template="""너는 입력받은 내용을 요약해주는 봇이야.
    입력 받는 내용은 특정 장소의 특징을 알려주는 내용이야.

    요약은 다음과 같이 해줬으면 좋겠어

       - "store_name": 
       - "category":  
       - "rating":  
       - "directions_text": 
       - "store_id": 
       - "address": 
       - "phone_num": 
       - "business_hours": 
       - "info": 
       - "convenience_facilities_and_services": 
       - "Parking": 
       - "sns": 
       - "store의 좋은점": 
       - "menu": 



    # 요약 해야할 내용: {answer_llm_Summary}


    """,
        input_variables=["answer_llm_Summary"],
    )


# LLM
model_summary = ChatOpenAI(model_name="gpt-4o-mini",
                    temperature=0, streaming=True)

chain_Summary_gangnam = (
    # {
    #     "answer_llm_Summary": itemgetter("answer_llm_Summary_gangnam")
    # }
    prompt_naver_Summary
    | model_summary
    | StrOutputParser()
)
chain_Summary_Junggu = (
    # {
    #     "answer_llm_Summary": itemgetter("answer_llm_Summary_junggu")
    # }
     prompt_naver_Summary
    | model_summary
    | StrOutputParser()
)
chain_Summary_jongro = (
    # {
    #     "answer_llm_Summary": itemgetter("answer_llm_Summary_jongro")
    # }
     prompt_naver_Summary
    | model_summary
    | StrOutputParser()
)
chain_Summary_yongsan = (
    # {
    #     "answer_llm_Summary": itemgetter("answer_llm_Summary_yongsan")
    # }
     prompt_naver_Summary
    | model_summary
    | StrOutputParser()
)

# %%
prompt_keyword = PromptTemplate(
    template="""
    너는 사용자의 질문에서 키워드를 추출하는 봇이야.
    아래의 순서에 따라서 사용자의 질문에 대해 키워드를 추출하고 , 로 구분된 나열된 단어를 출력해줘

    1. **질문 내용**
   -  사용자의 질문: {question}

    2. **핵심 주제 식별**
   - 질문의 주요 주제를 파악하세요. 주제가 무엇인지 한두 단어로 표현해보세요.

    3. **중요한 개념 및 단어 추출**
   - 질문에서 가장 중요한 개념과 관련된 단어를 추출하세요. 명사, 동사, 형용사 중에서 선택될 수 있습니다.

    4. **불필요한 단어 제거**
   - '그리고', '또는', '하지만' 같은 연결어 및 일반적인 불필요한 단어를 제거하여 중요한 단어만 남기세요.

    5. **키워드 리스트 작성**
   - 추출한 단어들을 키워드 리스트 형태로 정리하세요. 리스트는 쉼표로 구분된 단어 또는 구문으로 작성하면 좋습니다.

    결과물 예시 : 일정, 여행, 카페,
  
    """,
        input_variables=["question"],
    )

model_keyword = ChatOpenAI(model_name="gpt-4o-mini",
                    temperature=0, streaming=True)

chain_keyword = (
    {
        "question": itemgetter("question"),
    }
    | prompt_keyword
    | model_keyword
    | StrOutputParser()
)

# %%
prompt_location = PromptTemplate(
    template="""너는 질문에 대해서 list를 반환해야돼.
    list에 들어갈 수 있는 str은 '용산구', '강남구', '중구', '종로구' 네가지가 있어.
    사용자가 질문을 하면 문장을 잘 보고 문장속의 지역을 추출해서 리스트에 넣어줘.
    만약 사용자의 질문에 '서울'을 방문 한다고 하면 리스트에 '용산구', '강남구', '중구', '종로구' 를 모두 넣어줘.
    사용자의 질문에 서울시가 아닌 다른지역을 물어보거나, 서울시에서도 '용산구', '강남구', '중구', '종로구'가 아닌 다른 지역을 물어보면 빈 리스트를 반환해.


    #입력 예시 : 1. 나는 서울시의 용산구를 방문 할거야 여행 계획을 세워 줄수 있어?, 
               2. 나는 종로구와 중구 일대를 방문하고 싶어 을지로는 꼭 가보고 싶은데 을지로 계획을 포함해서 여행 일정을 만들어 줄 수 있어?

    #대답 형식 예시 : ['종로구','강남구']


    #####
    입력 예시 1 : 나는 전라남도 여행을 계획중이야. 일정을 만들어 줄 수 있어?  
    답변 예시 1 : []

    #####

    #####
    입력 예시 2 : 나는 용산구와 종로구, 중구 일대를 관광하고 싶어 좋은 카페를 알고 싶은데 알려줄 수 있어?  
    답변 예시 2 : ['용산구','중구','종로구']

    #####

    #####
    입력 예시 3: 나는 서울시를 관광하고 싶어 1박2일 정도 방문하려고 하는데 일정을 만들어 줄 수 있어?
    답변 예시 3: ['용산구','중구','종로구','강남구']
    
    #####

    #####
    입력 예시 4 : 종로구에서 맛있는 고기집을 찾고 있어. 찾아줘
    답변 예시 4: ['종로구']

    #####


    #사용자의 질문: {question}

    """,
        input_variables=["question"],
    )

model_location = ChatOpenAI(model_name="gpt-4o-mini",
                    temperature=0, streaming=True)

chain_location = (
    {
        "question": itemgetter("question"),
    }
    | prompt_location
    | model_location
    | StrOutputParser()
)

# %%
prompt_sch_or_placeSearch = PromptTemplate(
    template="""너는 질문에 대해서 두가지의 옵션으로 대답하는 봇이야.
    너의 대답은 '일정', '장소검색' 두가지로만 대답할 수 있어.
    사용자가 질문을 하면 문맥을 잘 살펴서 사용자가 여행일정을 만들어 달라고 하면 '일정' 이라고 대답해야돼.
    그렇지 않으면 '장소검색' 를 출력해줘.

    #'일정' 출력 예시 : 1. 나는 서울시의 용산구를 방문 할거야 여행 계획을 세워 줄수 있어?, 2. 나는 종로구와 중구 일대를 방문하고 싶어 을지로는 꼭 가보고 싶은데 을지로 계획을 포함해서 여행 일정을 만들어 줄 수 있어?

    #대답 형식 : '일정' or '장소검색'

    #사용자의 질문: {question}
    

    """,
        input_variables=["question"],
    )

model_sch_or_placeSearch = ChatOpenAI(model_name="gpt-4o-mini",
                    temperature=0, streaming=True)

chain_sch_or_placeSearch = (
    {
        "question": itemgetter("question"),
    }
    | prompt_sch_or_placeSearch
    | model_sch_or_placeSearch
    | StrOutputParser()
)

# %%
prompt_Web_or_retriever = PromptTemplate(
    template=""" 너는 사용자의 질문에 대해서 두가지의 옵션으로 대답하는 봇이야.
    너의 대답은 'web', 'retriever' 두가지로만 대답할 수 있어.
    사용자가 질문을 하면 문맥을 잘 살펴서 웹에서 정보를 검색하기를 원하면 'web' 이라고 대답해야돼.
    그렇지 않으면 'retriever' 를 출력해줘. 

    #대답 형식 : 'web' or 'retriever'

    #사용자의 질문: {question}
    

    """,
        input_variables=["question"],
    )
model_web_check = ChatOpenAI(model_name="gpt-4o-mini",
                    temperature=0, streaming=True)

chain_Web_or_retriever = (
    {
        "question": itemgetter("question"),
    }
    | prompt_Web_or_retriever
    | model_web_check
    | StrOutputParser()
)

# %%
prompt_web = PromptTemplate(
    template="""너는 웹 검색을 통한 {context_web}의 내용를 종합해서 서울시의 중구,종로구,용산구,강남구 관광 일정을 추천해주는 봇이야.
    사용자의 질문에 따라서 여러가지 서울의 관광지, 식당, 숙소, 쇼핑몰 등을 추천해야해.
    처음에 사용자가 서울에 며칠동안 머무르는지 물어보고, 그에 따라서 관광 일정을 추천해주면 돼.
    그 다음 사용자가 서울에 오는 이유에 대해 파악하고 그에 맞는 여행 일정을 추천해주면 돼.
    대화하다가 추천한 여행 일정이 사용자의 마음에 들지 않아서 변경해달라고 하면 마음에 들지 않은 부분을
    캐치하고 그 부분들만 수정해서 다시 추천해주면 돼.
    일정 중간 중간 숙소나 식당, 쇼핑몰 등을 추천해주면 돼.

    어떤 장소가 궁금해서 물어본다면 특정 장소의 정보들을 정확하게 알려줘.
    (예:가게 정보, 메뉴, 별점, 위치, 연락처, 운영 시간, 리뷰 등)
    여행 일정에 대한 동선이 짧도록 추천해줘.
    언어는 사용자가 입력한 언어를 기준으로 알려줘. 
    화폐 기준도 사용자가 입력한 언어를 사용하는 국가의 화폐를 기준으로 적용해줘.


    - 너가 제공한 내용의 출처를 링크로 남겨줘

    # 웹 검색 정보 : {context_web}

    #사용자의 질문: {question}
    
    #이전 대화 내용 {chat_history} 
    """,
        input_variables=["context_web", "question"],
    )
#input_variables=["context_web","context_opendata","context_naver", "question"],
# LLM
model_web = ChatOpenAI(model_name="gpt-4o",
                    temperature=0, streaming=True)

chain_web = (
    {
        "question": itemgetter("question"),
        "context_web": itemgetter("context_web"),
        # "context_opendata": itemgetter("context_opendata"),
        # "context_naver": itemgetter("context_naver"),
        "chat_history": itemgetter("chat_history"),
    }
    | prompt_web
    | model_web
    | StrOutputParser()
)

# %%
from langchain_teddynote.messages import messages_to_history
from langchain_teddynote.tools.tavily import TavilySearch
import ast

# from rag.utils import format_docs
# 웹 검색 or 리트리버 검색
def web_or_retriever_check(state: GraphState) -> GraphState:
    
    response = chain_Web_or_retriever.invoke(
        {"question": state["question"][-1].content}
    )

    return {"webOrRetriever": response}

# 웹 리트리버 분기 체크하는 함수(router)
def is_web(state: GraphState) -> GraphState:
    if state["webOrRetriever"] == "web":
        return "web"
    else:
        return "retriever"

# 장소검색 or 일정 검색
def Schedule_or_place_check(state: GraphState) -> GraphState:
    # 관련성 체크를 실행("yes" or "no")
    response = chain_sch_or_placeSearch.invoke(
        {"question": state["question"][-1].content}
    )

    return {"ScheduleOrplace": response}


# 일정 장소검색 리트리버 분기 체크하는 함수(router)
def is_place(state: GraphState) -> GraphState:
    if state["ScheduleOrplace"] == "일정":
        return "일정"
    else:
        return "장소검색"
    
# 지역 판별
def location_check(state: GraphState) -> GraphState:
    # 관련성 체크를 실행("yes" or "no")
    response = chain_location.invoke(
        {"question": state["question"][-1].content}
    )

    return {"location": response}

    
# 문서 검색 노드--------------------------------------------------------------------------------------------------------------------------
def retrieve_document_naver(state: GraphState) -> GraphState:
    # 질문을 상태에서 가져옵니다.
    latest_question = state["question"][-1].content
    location_str = state['location']

    location = ast.literal_eval(location_str)

    # 문서에서 검색하여 관련성 있는 문서를 찾습니다.
    yongsan = '용산구'
    jonglo = '종로구'
    gangman = '강남구'
    junggu = '중구'
    retrieved_docs_yongsan = []
    retrieved_docs_jongro = []
    retrieved_docs_gangman = []
    retrieved_docs_junggu = []

    if yongsan in location:
        retrieved_docs_yongsan = retriever_naver_yongsan.invoke(latest_question)
        retrieved_docs_yongsan = "\n".join(
        [
            f"<document><content>{doc.page_content}</content>"
            for doc in retrieved_docs_yongsan
        ]
        )

    if jonglo in location:
        retrieved_docs_jongro = retriever_naver_jongro.invoke(latest_question)
        retrieved_docs_jongro = "\n".join(
        [
            f"<document><content>{doc.page_content}</content>"
            for doc in retrieved_docs_jongro
        ]
        )

    if gangman in location:
        retrieved_docs_gangman = retriever_naver_gangnam.invoke(latest_question)
        retrieved_docs_gangman = "\n".join(
        [
            f"<document><content>{doc.page_content}</content>"
            for doc in retrieved_docs_gangman
        ]
        )

    if junggu in location:
        retrieved_docs_junggu = retriever_naver_Junggu.invoke(latest_question)
        retrieved_docs_junggu = "\n".join(
        [
            f"<document><content>{doc.page_content}</content>"
            for doc in retrieved_docs_junggu
        ]
        )

    # 검색된 문서를 형식화합니다.(프롬프트 입력으로 넣어주기 위함)

        # 검색된 문서를 context 키에 저장합니다.
    return {"context_naver_gangnam": retrieved_docs_gangman,
            "context_naver_jongro": retrieved_docs_jongro,
            "context_naver_Junggu": retrieved_docs_junggu,
            "context_naver_yongsan": retrieved_docs_yongsan}

#------------------------------------------------------------------------------------------------------------------------------------------------


def retrieve_document_opendata(state: GraphState) -> GraphState:
    # 질문을 상태에서 가져옵니다.
    latest_question = state["question"][-1].content
    location_str = state['location']

    location = ast.literal_eval(location_str)

    doc_list = []
    # 문서에서 검색하여 관련성 있는 문서를 찾습니다.
    yongsan = '용산구'
    jonglo = '종로구'
    gangman = '강남구'
    junggu = '중구'
    retrieved_docs_yongsan = []
    retrieved_docs_jongro = []
    retrieved_docs_gangman = []
    retrieved_docs_junggu = []

    if yongsan in location:
        retrieved_docs_yongsan = retriever_opendata_yongsan.invoke(latest_question)

    if jonglo in location:
        retrieved_docs_jongro = retriever_opendata_jongro.invoke(latest_question)

    if gangman in location:
        retrieved_docs_gangman = retriever_opendata_gangnam.invoke(latest_question)

    if junggu in location:
        retrieved_docs_junggu = retriever_opendata_junggu.invoke(latest_question)

 
    doc_list.extend(retrieved_docs_yongsan)
    doc_list.extend(retrieved_docs_jongro)
    doc_list.extend(retrieved_docs_gangman)
    doc_list.extend(retrieved_docs_junggu)

    # 검색된 문서를 형식화합니다.(프롬프트 입력으로 넣어주기 위함)
    retrieved_docs = "\n".join(
        [
            f"<document><content>{doc.page_content}</content>"
            for doc in doc_list
        ]
)

    # 검색된 문서를 context 키에 저장합니다.
    return {"context_opendata": retrieved_docs}

# 요약 생성 노드----------------------------------------------------------------------------
def llm_Summary_naver(state: GraphState) -> GraphState:
    location_str = state['location']

    location = ast.literal_eval(location_str)

    yongsan = '용산구'
    jonglo = '종로구'
    gangman = '강남구'
    junggu = '중구'
    response_yongsan ='none'
    response_jongro ='none'
    response_junggu ='none'
    response_gangnam ='none'

    if yongsan in location:
        context_naver_yongsan = state["context_naver_yongsan"]

        # 체인을 호출하여 답변을 생성합니다.
        response_yongsan = chain_Summary_yongsan.invoke(
            {
                "answer_llm_Summary": context_naver_yongsan,
            }
        )
    # 생
    if jonglo in location:
        context_naver_jongro = state["context_naver_jongro"]

        # 체인을 호출하여 답변을 생성합니다.
        response_jongro = chain_Summary_jongro.invoke(
            {
                "answer_llm_Summary": context_naver_jongro,
            }
        )
    if gangman in location:
        context_naver_gangnam = state["context_naver_gangnam"]

        # 체인을 호출하여 답변을 생성합니다.
        response_gangnam = chain_Summary_gangnam.invoke(
            {
                "answer_llm_Summary": context_naver_gangnam,
            }
        )
    if junggu in location:
        context_naver_Junggu = state["context_naver_Junggu"]

        # 체인을 호출하여 답변을 생성합니다.
        response_junggu = chain_Summary_Junggu.invoke(
            {
                "answer_llm_Summary": context_naver_Junggu,
            }
        )
    
    # 생성된 답변, (유저의 질문, 답변) 메시지를 상태에 저장합니다.
    return {
        "answer_llm_Summary_gangnam": response_gangnam,
        "answer_llm_Summary_jongro": response_jongro,
        "answer_llm_Summary_junggu": response_junggu,
        "answer_llm_Summary_yongsan": response_yongsan
    } 


def llm_Summary_opendata(state: GraphState) -> GraphState:

    # 검색된 문서를 상태에서 가져옵니다.
    context_opendata = state["context_opendata"]

    # 체인을 호출하여 답변을 생성합니다.
    response = chain_Summary_opendata.invoke(
        {
            "answer_llm_Summary": context_opendata,
        }
    )
    # 생성된 답변, (유저의 질문, 답변) 메시지를 상태에 저장합니다.
    return {
        "answer_llm_Summary_opendata": response
    } 


# 요약 생성 노드 끝----------------------------------------------------------------------------



# 일정 생성 노드----------------------------------------------------------------------------

def llm_Schedule_answer(state: GraphState) -> GraphState:
    # 질문을 상태에서 가져옵니다.
    latest_question = state["question"][-1].content
    location_str = state['location']

    location = ast.literal_eval(location_str)

    Summary_list = []
    Summary_yongsan =[]
    Summary_jongro =[]
    Summary_gangman =[]
    Summary_junggu =[]
    # 문서에서 검색하여 관련성 있는 문서를 찾습니다.
    yongsan = '용산구'
    jonglo = '종로구'
    gangman = '강남구'
    junggu = '중구'

    if yongsan in location:
        Summary_yongsan = state["answer_llm_Summary_yongsan"]

    if jonglo in location:
        Summary_jongro = state["answer_llm_Summary_jongro"]

    if gangman in location:
        Summary_gangman = state["answer_llm_Summary_gangnam"]

    if junggu in location:
        Summary_junggu = state["answer_llm_Summary_junggu"]

   
    Summary_opendata = state["answer_llm_Summary_opendata"]

 
    Summary_list.extend(Summary_yongsan)
    Summary_list.extend(Summary_jongro)
    Summary_list.extend(Summary_gangman)
    Summary_list.extend(Summary_junggu)
    Summary_list.extend(Summary_opendata)

    # 검색된 문서를 형식화합니다.(프롬프트 입력으로 넣어주기 위함)
    retrieved_docs = "\n".join(
        [
            f"{doc}"
            for doc in Summary_list
        ]
    )

    # 체인을 호출하여 답변을 생성합니다.
    response = chain.invoke(
        {
            "question": latest_question,
            "context": retrieved_docs,
            "chat_history": messages_to_history(state["messages"]),
        }
    )
    # 생성된 답변, (유저의 질문, 답변) 메시지를 상태에 저장합니다.
    print(state["messages"])
    return {
        "answer": response,
        "messages": [("user", latest_question), ("assistant", response)],
    }
# 일정 생성 노드 끝----------------------------------------------------------------------------

# 장소 검색 노드 ----------------------------------------------------------------------------

def llm_place_answer(state: GraphState) -> GraphState:
    # 질문을 상태에서 가져옵니다.
    latest_question = state["question"][-1].content
    location_str = state['location']

    location = ast.literal_eval(location_str)

    Summary_list = []
    Summary_yongsan =[]
    Summary_jongro =[]
    Summary_gangman =[]
    Summary_junggu =[]
    # 문서에서 검색하여 관련성 있는 문서를 찾습니다.
    yongsan = '용산구'
    jonglo = '종로구'
    gangman = '강남구'
    junggu = '중구'

    if yongsan in location:
        Summary_yongsan = state["answer_llm_Summary_yongsan"]

    if jonglo in location:
        Summary_jongro = state["answer_llm_Summary_jongro"]

    if gangman in location:
        Summary_gangman = state["answer_llm_Summary_gangnam"]

    if junggu in location:
        Summary_junggu = state["answer_llm_Summary_junggu"]

   
    Summary_opendata = state["answer_llm_Summary_opendata"]

 
    Summary_list.extend(Summary_yongsan)
    Summary_list.extend(Summary_jongro)
    Summary_list.extend(Summary_gangman)
    Summary_list.extend(Summary_junggu)
    Summary_list.extend(Summary_opendata)

    # 검색된 문서를 형식화합니다.(프롬프트 입력으로 넣어주기 위함)
    retrieved_docs = "\n".join(
        [
            f"{doc}"
            for doc in Summary_list
        ]
    )

    # 체인을 호출하여 답변을 생성합니다.
    response = chain_place_search.invoke(
        {
            "question": latest_question,
            "context": retrieved_docs,
            "chat_history": messages_to_history(state["messages"]),
        }
    )
    # 생성된 답변, (유저의 질문, 답변) 메시지를 상태에 저장합니다.
    print(state["messages"])
    return {
        "answer": response,
        "messages": [("user", latest_question), ("assistant", response)],
    }

# 장소 검색 노드  끝----------------------------------------------------------------------------


# 웹 검색 답변 생성 노드
def llm_answer_web(state: GraphState) -> GraphState:
    # 질문을 상태에서 가져옵니다.
    latest_question = state["question"][-1].content
    # 검색된 문서를 상태에서 가져옵니다.
    # context_naver = state["context_naver"]
    # context_opendata = state["context_opendata"]
    context_web = state["context_web"]

    # 체인을 호출하여 답변을 생성합니다.
    response = chain_web.invoke(
        {
            "question": latest_question,
            "context_web": context_web,
            # "context_naver": context_naver,
            # "context_opendata": context_opendata,
            "chat_history": messages_to_history(state["messages"]),
        }
    )
    # 생성된 답변, (유저의 질문, 답변) 메시지를 상태에 저장합니다.
    print(state["messages"])
    return {
        "answer": response,
        "messages": [("user", latest_question), ("assistant", response)],
    }

# Web Search 노드
def web_search(state: GraphState) -> GraphState:
    # 검색 도구 생성
    tavily_tool = TavilySearch()

    search_query = state["question"][-1].content

    # 다양한 파라미터를 사용한 검색 예제
    search_result = tavily_tool.search(
        query=search_query,  # 검색 쿼리
        topic="general",  # 일반 주제
        max_results=2,  # 최대 검색 결과
        format_output=True,  # 결과 포맷팅
    )

    return {"context_web": search_result}

# %%
from langgraph.graph import END, StateGraph
from langgraph.checkpoint.memory import MemorySaver

# 그래프 생성
workflow = StateGraph(GraphState)

# 노드 정의
workflow.add_node("location_check", location_check)
workflow.add_node("retrieve_document_naver", retrieve_document_naver)
workflow.add_node("retrieve_opendata", retrieve_document_opendata)
workflow.add_node("llm_Summary_opendata", llm_Summary_opendata)
workflow.add_node("llm_Summary_naver", llm_Summary_naver)
workflow.add_node("llm_Schedule_answer", llm_Schedule_answer)
workflow.add_node("Schedule_or_place_check", Schedule_or_place_check)
workflow.add_node("llm_place_answer", llm_place_answer)


# 엣지 정의
# workflow.add_conditional_edges(
#     "web_Or_Retriever",  # 관련성 체크 노드에서 나온 결과를 is_relevant 함수에 전달합니다.
#     is_web,
#     {
#         "web": "web_search",  # 웹 검색을 요청하면 웹검색을 합니다
#         "retriever": "query_rewrite",  # 아니면 리트리버
#     },
# )
# 엣지 정의
workflow.add_conditional_edges(
    "Schedule_or_place_check",  
    is_place,
    {
        "일정": "llm_Schedule_answer",  #일정
        "장소검색": "llm_place_answer",  # 장소검색
    },
)

workflow.add_edge("location_check", "retrieve_document_naver")  # 검색 -> 답변
workflow.add_edge("location_check", "retrieve_opendata")  # 검색 -> 답변
workflow.add_edge("retrieve_document_naver", "llm_Summary_naver")  # 질문 -> 검색
workflow.add_edge("retrieve_opendata", "llm_Summary_opendata")  # 질문 -> 검색
workflow.add_edge("llm_Summary_naver", "Schedule_or_place_check") 
workflow.add_edge("llm_Summary_opendata", "Schedule_or_place_check") 

workflow.add_edge("llm_Schedule_answer", END)  # 답변 -> 종료
workflow.add_edge("llm_place_answer", END)  # 답변 -> 종료

# 그래프 진입점 설정
workflow.set_entry_point("location_check")

# 체크포인터 설정
memory = MemorySaver()

# 컴파일
app = workflow.compile(checkpointer=memory)

# %%
from langchain_teddynote.graphs import visualize_graph

visualize_graph(app)

# %%
# from langchain_core.runnables import RunnableConfig
# from langchain_teddynote.messages import invoke_graph, stream_graph, random_uuid

# # config 설정(재귀 최대 횟수, thread_id)
# config = RunnableConfig(recursion_limit=20, configurable={"thread_id": random_uuid()})

# %%
# inputs = GraphState(question="내가 직전에 한 질문이 뭐였지")

# %%
# print(res.get('answer'))

# %%
from langchain_core.runnables import RunnableConfig
from langchain_teddynote.messages import invoke_graph, stream_graph, random_uuid

# config 설정(재귀 최대 횟수, thread_id)
config = RunnableConfig(recursion_limit=20, configurable={"thread_id": random_uuid()})

# 질문 입력
inputs = GraphState(question="종로구에서 2박3일동안 여행계획 짜줘")

# 그래프 실행
invoke_graph(app, inputs, config)
# Out:
# ==================================================
# 🔄 Node: location_check 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# location:
# ['종로구']
# ==================================================
#
# ==================================================
# 🔄 Node: retrieve_document_naver 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# context_naver_jongro:
# <document><content>store_name: 행2PM8PM
#  category: 술집
#  new_open:
#  rating: 별점 4.66
#  visited_review: 방문자 리뷰 1,258
#  directions_text: 중구 수표로12길 10. 1~3층
# 루프탑까지 통건물이며 1층이 출입구입니다.
#
# 을지로3가역과 명동역, 충무로역에서 도보로 약 3분거리 오실수 있으며,
#
# 근처 세운상가, 을지로 노가리골목하고도 가까운 힙지로 메인골목에 위치해있습니다.(나인트리호텔 뒷골목)
#
# 시침이 두개이며, 두시와 여덟시를 가르키는 시계로 되어있는 간판을 찾아주세요!
# 진작과 정라진 사이 건물입니다.
#
# 근처 도보3분거리 주차장안내
# [마른내길공영주차장 무료이용시간]
# 월~금 저녁7시 이후, 토요일3시 이후, 일요일 무료
# 내용 더보기
#  store_id: 1799596430
#  address: 서울 중구 수표로12길 10 1층~3층
#  blog_review: 블로그 리뷰 6,020
#  phone_num: 0507-1331-6915
#  business_hours: 수(1/1)
# 새해 첫날15:00 - 23:00
# 목
# 15:00 - 23:00
# 금
# 15:00 - 23:00
# 토
# 13:30 - 24:00
# 일
# 13:30 - 23:00
# 월
# 15:00 - 23:00
# 화
# 15:00 - 23:00
#
#  info: 힙지로 1세대 노포 맛집인 대표 와인펍
# 너목보, 초대형노래방vs, 싱어게인 등의 40팀의 인디가수들 라이브공연이 있는 2층과
# 동남아 분위기의 3층 루프탑이 있는
# 대형 공간입니다.
#
# 힙지로 명물인 몽둥이고기,
# 이탈리아 정통 가정식스타일의 라자냐파스타 등 다양한 식사와 간편한 안주류도 준비되어있습니드.
# 술 없이 식사만도 가능합니다.(논알콜 맥주, 커피, 과일에이드도 판매)
#
# *공연시간[월~금8시, 토 7시/9시, 일 7시]
# *낮술가능 / 외부케이크 반입가능 / 와인포장시 20%할인*
# *예약없이 현장방문 가능하나, 당일예약이나 회식,생일파티,결혼식 뒤풀이 등 단체 예약은 전화로 문의주세요*
# 펼쳐보기
#  convenience_facilities_and_services: 콜키지 가능
# 유료
# 생일 혜택
# 무한 리필
# 테이크아웃 할인
# 와인 페어링
# 단체 이용 가능
# 예약
# 무선 인터넷
# 포장
# 좌석 휠체어 이용가능
#
#  Parking: 주차가능
# 무료
#  sns: http://www.instagram.com/hang_2pm8pm
# https://youtube.com/channel/UCEIcCQOq1M9VVCPkYDkuAQA
#
#  review_like_this_part_output: "음식이 맛있어요"이 키워드를 선택한 인원409
# "특별한 메뉴가 있어요"이 키워드를 선택한 인원309
# "음악이 좋아요"이 키워드를 선택한 인원262
# "술이 다양해요"이 키워드를 선택한 인원260
# "라이브공연이 훌륭해요"이 키워드를 선택한 인원244
# "인테리어가 멋져요"이 키워드를 선택한 인원240
# "친절해요"이 키워드를 선택한 인원174
# "가성비가 좋아요"이 키워드를 선택한 인원160
# "단체모임 하기 좋아요"이 키워드를 선택한 인원117
# "특별한 날 가기 좋아요"이 키워드를 선택한 인원103
# "야외공간이 멋져요"이 키워드를 선택한 인원80
# "오래 머무르기 좋아요"이 키워드를 선택한 인원80
# "대화하기 좋아요"이 키워드를 선택한 인원77
# "파티하기 좋아요"이 키워드를 선택한 인원64
# "사진이 잘 나와요"이 키워드를 선택한 인원62
# "매장이 청결해요"이 키워드를 선택한 인원50
# "기본 안주가 좋아요"이 키워드를 선택한 인원39
# "혼술하기 좋아요"이 키워드를 선택한 인원17
# "컨셉이 독특해요"이 키워드를 선택한 인원16
# "아늑해요"이 키워드를 선택한 인원10
# "음식이 빨리 나와요"이 키워드를 선택한 인원9
# "화장실이 깨끗해요"이 키워드를 선택한 인원8
# "비싼 만큼 가치있어요"이 키워드를 선택한 인원6
# "매장이 넓어요"이 키워드를 선택한 인원6
# "양이 많아요"이 키워드를 선택한 인원5
# "메뉴 구성이 알차요"이 키워드를 선택한 인원5
# "뷰가 좋아요"이 키워드를 선택한 인원5
# "좌석이 편해요"이 키워드를 선택한 인원2
# "차분한 분위기에요"이 키워드를 선택한 인원1
# "주차하기 편해요"이 키워드를 선택한 인원1
# "건강한 맛이에요"이 키워드를 선택한 인원1
#
#  menu: 몽둥이고기 [ 25cm 크기 ]대표행의 대표시그니처 메뉴인 몽둥이구이입니다. 부드러운 살코기와 쫀쫀할 다릿살,
# 팔뚝만한 크기의 몽둥이를 들고 사진을 꼭 찍어보세요.22,000원
# 미국식 버팔로윙봉&나초16,500원
# 치즈폭탄 감자튀김꾸덕한 치즈 폭탄과 시즈닝, 갓튀긴 감튀까지8,000원
# 와인1병와인1병의 29000원부터 3만원대의 와인이 다수입니다. 가성비와인들부터 포트와인,내추럴와인도 판매합니다. 을지로에서 저렴한 가격에 좋은 와인을 먹을수있는 곳이에요(글라스와인도있음29,000원
# 이탈리아정통 라자냐 파스타건강한 재료를 듬뿍 넣어 맛을낸 이탈리안 가정식 볼로네제 라자냐 파스타18,000원
# 나초 앤 치즈소스나초와 진득한 치즈를 푸짐하게 먹을수 있는 간편한 메뉴7,000원
# 버드와이저생맥무제한레드락생맥주 무제한(1인15,000원 / 일행전체주문시) 잔맥주 주문도 가능합니다(6,000원) 레드락생맥주 외, 호가든,블루문,스텔라,빅웨이브,에딩거논알콜 맥주도 판매합니다.17,000원
# 행하이볼 무제한일행전체주문 / 1시간30분 무제한 / 1인당 23,000원23,000원
# 논알콜 로제와인술을 못드셔도 두세병이 가능한, 음주운전과 상관없는 분위기 내기좋은 맛도리 논알콜 와인변동
# 버드와이저(생맥)8,000원
# 젤라또 아이스크림쫀쫀하고 꾸덕한 젤라또 아이스크림에 초코소스. 입가심으로 가볍게 먹게 딱좋은 디저트메뉴7,000원
# 2인세트(2천원할인)몽둥이고기+행플레이터무료
# 3~4인세트(3천원할인)몽둥이고기+행플레이터+라자냐파스타
# 대표메뉴 세가지를 한번에!무료
# 스모어딥마시멜로우+누텔라와 함께 구운 달달구리 디저트16,500원
# 행플레이터있는거 없는거 팍팍 넣은 한상차림 대표메뉴, 다양한종류의 치즈,하몽,크레커,올리브,견과류,과일,초콜릿 등등등등,, 그때그때 신선한 재료와 시키신 음식과 주류와 잘어울리는걸로 드려요24,500원
# </content>
# <document><content>store_name: 방이옥 종로관철점
#  category: 육류,고기요리
#  new_open:
#  rating: 정보없음
#  visited_review: 방문자 리뷰 1,106
#  directions_text: 지하철: 종각역 4번출구로 나오셔서 30초
# 직진하시면 스타벅스가 보여요~그골목으로 우회전하셔서 30초 직진하시면 사거리에서
# 바로 좌회전 하시면 2층에 방이옥 보여요^^
# 4번출구에서 2분컷!!
#
# 버스: 종로2가 (중앙차로) 에서 횡단보도 건너
# 종각 젊은의거리로 들어오시면 갓덴스시
# 보이시면 우회전 하셔서 30초 걸어오시면
# 왼쪽 2층에 방이옥이 있습니다^^
# 내용 더보기
#  store_id: 1431553022
#  address: 서울 종로구 우정국로2길 32 2층
#  blog_review: 블로그 리뷰 2,416
#  phone_num: 0507-1377-8268
#  business_hours: 수(1/1)
# 휴무
# 목
# 11:00 - 22:00
# 21:00 라스트오더
# 금
# 11:00 - 22:00
# 21:00 라스트오더
# 토
# 12:00 - 22:00
# 21:00 라스트오더
# 일
# 12:00 - 22:00
# 21:00 라스트오더
# 월
# 11:00 - 22:00
# 21:00 라스트오더
# 화
# 11:00 - 22:00
# 21:00 라스트오더
#
#  info: 정보없음
#  convenience_facilities_and_services: 정보없음
#  Parking: 정보없음
#  sns: 정보없음
#  review_like_this_part_output: 정보없음
#  menu: 정보없음</content>
# <document><content>store_name: 천년동안도
#  category: 바(BAR)
#  new_open:
#  rating: 정보없음
#  visited_review: 방문자 리뷰 437
#  directions_text: 청계2가 삼일빌딩 뒷건물에 있습니다.
# 청계2가쪽에서 가장 큰 검정색 건물(Sk네트웍스 등이 있는 건물, 한화건물 맞은편) 바로 뒤쪽에 위치해 있습니다.
# 내용 더보기
#  store_id: 1789291657
#  address: 서울 종로구 삼일대로15길 6 지하1층, 2층
#  blog_review: 블로그 리뷰 253
#  phone_num: 0507-1433-0619
#  business_hours: 일
# 18:00 - 24:00
# 23:30 라스트오더
# 월
# 18:00 - 24:00
# 23:30 라스트오더
# 화
# 18:00 - 24:00
# 23:30 라스트오더
# 수
# 18:00 - 24:00
# 23:30 라스트오더
# 목
# 18:00 - 24:00
# 23:30 라스트오더
# 금
# 18:00 - 24:00
# 23:30 라스트오더
# 토
# 17:00 - 24:00
# 23:30 라스트오더
#
#  info: 천년동안도는 1996년 대학로에서 처음 문을 열었습니다.
# 현재 낙원,종각,강남 3개 지점으로 운영되고 있습니다.
#
# 종각점은 대한민국 최고의 뮤지션들의 공연을 눈 앞에서 관람이 가능하며,
# 아무때라도 듣고 싶은 LP를 직접 골라서 청음공간에서 헤드폰을 통해 들으실 수 있습니다.
#
# 천년동안도라는 이름에 걸맞는 공간이 되도록 최선을 다하겠습니다.
#
# 감사합니다.
#
# 예약없이 당일 방문 가능하십니다.
# 펼쳐보기
#  convenience_facilities_and_services: 단체 이용 가능
# 예약
# 남/녀 화장실 구분
# 무선 인터넷
#
#  Parking: 주차가능
# 유료
# 정액 과금 7,000원
#  sns: http://www.chunnyun.com/
# https://www.instagram.com/chunnyun.jonggak
#
#  review_like_this_part_output: "라이브공연이 훌륭해요"이 키워드를 선택한 인원341
# "음악이 좋아요"이 키워드를 선택한 인원294
# "특별한 날 가기 좋아요"이 키워드를 선택한 인원131
# "음식이 맛있어요"이 키워드를 선택한 인원126
# "친절해요"이 키워드를 선택한 인원122
# "인테리어가 멋져요"이 키워드를 선택한 인원97
# "술이 다양해요"이 키워드를 선택한 인원87
# "혼술하기 좋아요"이 키워드를 선택한 인원44
# "매장이 청결해요"이 키워드를 선택한 인원41
# "비싼 만큼 가치있어요"이 키워드를 선택한 인원40
# "기본 안주가 좋아요"이 키워드를 선택한 인원40
# "화장실이 깨끗해요"이 키워드를 선택한 인원38
# "아늑해요"이 키워드를 선택한 인원22
# "가성비가 좋아요"이 키워드를 선택한 인원19
# "단체모임 하기 좋아요"이 키워드를 선택한 인원17
# "대화하기 좋아요"이 키워드를 선택한 인원15
# "매장이 넓어요"이 키워드를 선택한 인원10
# "사진이 잘 나와요"이 키워드를 선택한 인원7
# "오래 머무르기 좋아요"이 키워드를 선택한 인원7
# "주차하기 편해요"이 키워드를 선택한 인원6
# "차분한 분위기에요"이 키워드를 선택한 인원3
# "컨셉이 독특해요"이 키워드를 선택한 인원3
# "음료가 맛있어요"이 키워드를 선택한 인원2
# "음식이 빨리 나와요"이 키워드를 선택한 인원2
# "혼밥하기 좋아요"이 키워드를 선택한 인원1
# "파티하기 좋아요"이 키워드를 선택한 인원1
# "특별한 메뉴가 있어요"이 키워드를 선택한 인원1
# "집중하기 좋아요"이 키워드를 선택한 인원1
# "뷰가 좋아요"이 키워드를 선택한 인원1
#
#  menu: 피자페퍼로니피자, 콰트로치즈피자, 하몽샐러드피자, 라구피자, 제시데이비스피자25,000~27,000원
# 칵테일칵테일18,000~23,000원
# 공연료공연시작 시간 월~금PM 8:30
# 토,일 PM 7:0015,000원
# 와인와인 바틀 50,000~변동
# </content>
# <document><content>store_name: 종로도담
#  category: 한식
#  new_open:
#  rating: 별점 4.45
#  visited_review: 방문자 리뷰 1,850
#  directions_text: 종각역2번출구로 나와 직진후 사거리가 나오면 좌회전 하시면됩니다. 20m정도 이동하시면 횡단보도 앞에 위치해있습니다.
#  store_id: 1614498920
#  address: 서울 종로구 삼봉로 78
#  blog_review: 블로그 리뷰 2,048
#  phone_num: 0507-1321-9850
#  business_hours: 매일
# 11:00 - 22:00
# 15:00 - 17:00 브레이크타임
# 21:00 라스트오더
#
#  info: 종로, 종각, 광화문 회사근처 낮술하기 좋은 종로도담입니다.
#
# 1층 24분 / 2층 42분 / 테라스 까지 다양한 공간을 이용하실 수 있습니다.
#
# 주차장 안내 : 주차장 이용은 (유료) 입니다. 네이버에서 '종로도담 주차장' 검색하시면 택대리네 공식 블로그에 안내 되어있습니다.
#
# 개성보쌈만 6년째 삶고 있는 좋은사람들과 함께 시간을 보내기 좋은 곳을 목표로 운영하고 있습니다.
# 택대리네 종로도담은 개성보쌈, 김치찜. 낙지볶음, 부추전, 백골뱅이무침, 흑임자고기튀김, 다양한 주류를 전문으로 하는 종로 한식당입니다. 고객이 즐겁고 직원들도 즐거운 식당을 만들자는 목표로 30대 이하 젊은 직원과 60대 이상 어르신이 함께 모여 만든 정겨운 곳입니다. 현재 택대리네는 40여명의 직원들이 키워나가고 있습니다.
#
# 종로도담은 서울 종로구에 위치한 맛집으로 종로, 종각, 광화문에서 근무하시는 직장인분들의 입소문을 거쳐 국내외 관광객들 사이에서 큰 인기를 끌고 있습니다.
#
# 종로도담의 주력 메뉴중 개성보쌈에는 개운한 묵은지, 개성보쌈특제소스, 수제 무말랭이, 정구지무침이 함께 제공되고 있으며 개성보쌈과 함께 제공되는 특제소스는 이곳의 별미로 많은 분들의 사랑을 받고 있습니다.
#
# 종로도담은 광화문역과 종각역 사이 수많은 빌딩 숲에 숨은 식당입니다. 매일 외식이 일상이 되어버린 직장인들에게 평범하고 흔하게 먹을 수 있는 집밥 컨셉으로 모임의 장소를 제공하고 있습니다. 오전 11시, 점심시간에 맞춰 오픈하기 때문에 주변 회사원들을 대상으로 영업을 하고있으며, 특히 점심 식사에는 공깃밥이 무제한이고, 동동주까지 서비스로 제공되어지고 있습니다.
#
# 종로도담은 따뜻한 집밥이 그리운 이들을 위한 식사 메뉴로 특히 점심특선으로 제공되는 김치찜은 무제한 공깃밥, 셀프막걸리 외에도 뭇국과 흑임자고기튀김이 함께 제공되어 배불리 드실 수 있도록 구성하였습니다.
#
# 종로도담은 대규모 인원들이 회식 할 수 있는 공간이 있어서 직장인분들의 단체회식 장소로 방문하기 좋습니다. 2층에는 단체회식 장소뿐만 아니라 살랑부는 바람에 막걸리 드실 수 있도록 테라스도 준비되어있습니다.
#
# 종로도담은 개성보쌈뿐만 아니라 부추전, 김치찜, 낙지볶음, 백골뱅이무침, 다양한 종류의 주류 전문으로 구성하고 있습니다.
#
# 맛에 놀라움: 개성보쌈에 사용되는 돼지고기는 매일 아침 신선하게 들여와 잡내 없이 부드럽게 삶아 준비되어지고있습니다. 특제소스와 함께 먹는 보쌈의 맛은 일품이며 그외에 정성스럽게 준비한 정구지무침, 무말랭이 김치, 묵은지 구성으로 맛깔나게 준비하고 있습니다.
# 신맛과 매콤한 맛의 조화로운 김치에 두툼한 돼지고기 수육이 어우러진 김치찜은 적절한 온도의 김치 숙성과 종로도담만의 레시피로 고객님들께 최고의 김치찜를 제공해드립니다. 김치찜에 사용되는 돼지고기는 매일 아침 신선하게 들여와 화려한 불조절로 잡내 없이 부드럽게 푹 삶아 제공되어지고 있습니다.
#
# 종로도담의 부추전은 인생부추전이라는 타이틀이 생길정도로 튀겨내듯 바삭하게 구워 이곳에 시그니쳐 메뉴로 자리잡았습니다.
#
# 분위기와 경험: 수많은 빌딩 숲에 사이에 테라스가 있는 아늑한 독채식당입니다. 이곳에서 드시는 개성보쌈과 김치찜은 정통적인 방식으로 만들어져 식사하시는 동안 편안하고, 따뜻한 느낌을 줍니다. 최근 외국인분들도 직접 검색하고 많이 찾아오십니다. 종로도담의 다양한 한식구성과 양으로 종로,종각,광화문 직장인 점심,저녁맛집에 더불어 외국인분들도 한식의 다양한 맛을 느끼셨으면 좋겠습니다.
#
# 우리 식당의 장점
# 다양한 주류가 잘 어울리는 한식을 전문으로 하는 종로 맛집으로 인근 직장인과 국내외 관광객 그리고 20~60대 등 전 연령층에게 많은 사랑을 받아 오고 있습니다. 대규모 인원들이 즐겁게 식사를 하실 수 있는 넓을자리가 준비되어있어 직장인 회식, 모임을 하신다면 오붓하고 즐거운 시간을 보내실 수 있습니다.
#
# 택대리네는 현재 종로와 중구 서울의 4대문 안에서 남산도담, 혜화도담, 숭례도담, 인사도담, 삼봉도담, 운종가를 운영되어지고있습니다.
# 펼쳐보기
#  convenience_facilities_and_services: 콜키지 가능
# 무료
# 예약
# 단체 이용 가능
# 남/녀 화장실 구분
# 무선 인터넷
# 포장
#
#  Parking: 주차 불가
#  sns: https://blog.naver.com/taekdaeri
# https://jongrododam.modoo.at/
# https://www.instagram.com/taekdaeri_official
#
#  review_like_this_part_output: nan
#  menu: 김치찜 소대표새콤달콤하게 잘익은 묵은지와 부드럽게 찢어지는 국내산 통전지, 도담의 비법양념이 들어간 찜22,000원
# 부추전대표건강에 좋은 부추를 가득 넣어 튀기듯 바삭하게 구워낸 영양 만점 부추전입니다.13,000원
# 평일김치찜정식(김치찜+뭇국+고기튀김)(11시~2시) 평일 점심에는 공깃밥과 막걸리(셀프)가 무한제공됩니다.12,000원
# 평일점심부추전건강에 좋은 부추를 가득 넣어 튀기듯 바삭하게 구워낸 영양 만점 부추전입니다.12,000원
# 맛보기보쌈퍽퍽하지않게 비계와 살코기가 적당히 섞인 삼겹살을 1시간이상 푹삶아 부드러운 보쌈고기입니다12,000원
# 미니흑임자고기튀김8,000원
# 낙지볶음 소매콤한 고추가루와 잘익은 과일을 갈아 칼칼하고부드러운 양념과 통통한 낙지와 불맛의 최강조합28,000원
# 개성보쌈 소함평에서 공수해 온 마늘을 숙성시켜 만든소스와보쌈, 묵은지,무말랭이, 보쌈김치 제공.29,000원
# 메밀전병튀김15,000원
# 바지락백합찜해감한 바지락을 올리브오일에 볶아 맛술에 살짝 쪄낸 술찜23,000원
# 명란구이저염 명란을 사용하여 오이, 양파와 함께 곁들여 먹는 명란구이20,000원
# 흑임자 고기튀김20,000원
# 2인한상개성보쌈 소 + 부추전 + 소주 또는 맥주 또는 막걸리46,000원
# 3인한상개성보쌈 소 + 김치찜 소 + 부추전 + 소주 또는 맥주 또는 막걸리68,000원
# 4인한상개성보쌈 소 + 낙지볶음 소 + 명란구이 + 부추전 + 소주 또는 맥주또는 막걸리93,000원
# </content>
# <document><content>store_name: 오봉집 종로점
#  category: 한식
#  new_open:
#  rating: 정보없음
#  visited_review: 방문자 리뷰 2,999
#  directions_text: 지하철을 이용시 종각역 4번출구로 나와 할리스커피 가기전
# 오른쪽 골목으로 직진하시다가 약 100m 오시면 오른쪽 1층에 오봉집 종로점이 있습니다
#
# 종로3가역 15번출구로 나와 쭈욱 600m오시다가 할리스커피 지나 좁은 골목으로 약 100m 오시면은 오른쪽 1층에 오봉집 종로점 있습니다
# 길을 못찾으시면 언제든지 전화주세요 :)
#  0507-1393-0555
# *이런 분들 께 오봉집 종로점을 추천 드립니다!
# 1. 종로 종각 모임 맛집을 계획하신 미식가들!
# 2. 종로 종각 단체 회식 맛집을 진행중이신 직장인들!
# 3. 주말에 어린아이들부터 어른들까지 가족들 모두가 방문 할수 있는 종로 종각 가족식사 맛집!
# 4. 청계천 데이트 코스 맛집으로 오봉집 종로집을 찾는 커플!
# 5. 종로 종각 점심 맛집을 찾고 계신 직장인들!
# 내용 더보기
#  store_id: 1558521785
#  address: 서울 종로구 종로8길 20 1층
#  blog_review: 블로그 리뷰 981
#  phone_num: 0507-1393-0555
#  business_hours: 수(1/1)
# 새해 첫날12:00 - 22:00
# 목
# 11:00 - 22:30
# 15:00 - 16:30 브레이크타임
# 21:50 라스트오더
# 금
# 11:00 - 22:30
# 15:00 - 16:30 브레이크타임
# 21:50 라스트오더
# 토
# 12:00 - 22:30
# 21:50 라스트오더
# 일
# 12:00 - 22:00
# 21:20 라스트오더
# 월
# 11:00 - 22:30
# 15:00 - 16:30 브레이크타임
# 21:50 라스트오더
# 화
# 11:00 - 22:30
# 15:00 - 16:30 브레이크타임
# 21:50 라스트오더
#
#  info: 한국소비자만족지수 4년 연속 1위
# 안녕하세요. 종로 종각 핫플레이스 '오봉집 종로점'입니다.
# 오봉집 종로점은 직화낙지볶음과 프리미엄 가브리살 보쌈(수육)을 통하여, 최고의 맛을 찾아주시는 모든 고객분들께 선사하고 있습니다.
#
# 최근에 많은 분들이 찾아주셔서 감사하게도 유튜버 만리님,쯔양님,푸디랜드,윤코치님,야식이님,히밥님 등 많이들 방문해주셨습니다.
# 이번에 놀면뭐하니에서도 방영되서 유재석님과 하하님께서 식사하시고 간집입니다.
#
# 맛 뿐만 아니라, 오봉스페셜(직화낙지볶음+보쌈+막국수)로 가성비 있고 편안한 분위기 연출을 통하여 오감 만족의 즐거움을 드리고 위해서 노력하고 있습니다.
#
# -메뉴 구성-
# 1.오봉스페셜(직화낙지+보쌈+쟁반막국수)
# 말 그대로 오봉집 스페셜 메뉴로 푸짐하고 가성비 있는 구성으로
# 고소한 보쌈과 불맛 제대로인 직화낙지에 새콤달콤한 막국수로 어느것 하나 모자란 없는 자랑스러운 메뉴입니다.
#
# 2.매생이연포보쌈(연포탕+보쌈+죽+칼국수)
# 추운 겨울철에 너무나도 잘 어울리는 메뉴로 속을 따뜻하게 해주면서 동시에 든든하게 해주는 겨울철 스페셜메뉴입니다.
#
# 3.직화낙지볶음
# 오봉집만의 특제소스에 통통한 낙지를 화력으로 빠르게 조리하여 불맛 제대로인 오봉집 베스트메뉴입니다.
#
# 4.직화제낙볶음
# 자양강장제인 낙지에 누구나 좋아하는 고기를 같이 볶아 육해를 전부 만족시키는 메뉴
#
# 5.직화제육볶음
# 나는 고기파다!라고 하는 사람들이 너무나도 많이 찾는 메뉴
#
# 6.오봉보쌈
# 삼겹,목살이 아닌 특수부위인 가브리살로 극강의 부드러움과 고소함을 자랑하는 오봉집만의 특별메뉴
#
# 7.쟁반막국수
# 부족한 탄수화물과 입을 상큼하게 해줄 막국수까지!
#
# *이런 분들 께 오봉집 종로점을 추천 드립니다!
# 1. 종로 종각 모임 맛집을 계획하신 미식가들!
# 2. 종로 종각 단체 회식 맛집을 진행중이신 직장인들!
# 3. 주말에 어린아이들부터 어른들까지 가족들 모두가 방문 할수 있는 종로 종각 가족식사 맛집!
# 4. 청계천 데이트 코스 맛집으로 오봉집 종로집을 찾는 커플!
# 5. 종로 종각 점심 맛집을 찾고 계신 직장인들!
# 최고의 맛과 서비스를 제공하기 위하여 언제나 노력하는 오봉집 종로점이 되도록 노력 하겠습니다.
#
# 점심에 오셔서 식사류를 드시면 밥,반찬이 무한제공되니 허리끈 풀르고 오셔도 됩니다. 평일뿐만 아니라 주말까지합니다.
#
# -예약안내-
# 네이버예약을 통하여 소모임 또는 단체모임을 미리 잡아두신다면은
# 센스 있는 사람이 되겠죠?
#
# 예약시 알림받기와 저장하기를 눌러주시면
# 사리,주먹밥,볶음밥 주류 를 서비스로 드리고 있습니다.
# 전화로도 예약가능하니 매장으로 전화 주셔도 됩니다.
#
# 예약전화는 11:30~13:30부터 17:30~20:00 까지는 전화를 잘 받지 못합니다. 혹시라도 못 받는다고 너무 화내지말아주세요 ㅠㅠ
#
# 식사와 분위기를 더 많은 분들이 이용하는 바램이오니 양해부탁드리겠습니다.
# 감사합니다.
#
# 여름에는 미역국 대신 오이냉국으로 나가고 있습니다.
#
# 종로회식장소,서울분위기좋은맛집,서울맛집top100,을지로3가맛집,
# 서울종로맛집,종로한식,서울가볼만한곳,종로구맛집,서울데이트,종로술집,종로회식,종각술집,종각밥집,서울종로구맛집,종로모임장소,종각회식,종로데이트,종로가볼만한곳,종로3가회식,굴보쌈,종로보쌈,종각모임,종로데이트코스,종로단체회식,종각점심맛집,종각역맛집
# 펼쳐보기
#  convenience_facilities_and_services: 단체 이용 가능
# 포장
# 배달
# 무선 인터넷
# 예약
# 남/녀 화장실 구분
# 대기공간
#
#  Parking: 주차 불가
#  sns: https://www.instagram.com/obongzip_jongno
#
#  review_like_this_part_output: nan
#  menu: 오봉스페셜대표직화낙지+보쌈+쟁반막국수59,000원
# 매생이연포보쌈대표연포탕+보쌈+죽+칼국수59,000원
# 오봉보쌈(소) 33,000원 / (중) 38,000원 / (대) 44,000원33,000원
# 매생이연포탕연포탕+칼국수32,000원
# 얼큰낙지전골32,000원
# 오봉조개탕22,000원
# 직화낙지볶음점심특선시 12,000원14,000원
# 직화오징어볶음점심특선시 12,000원14,000원
# 직화제낙볶음점심특선시 12,000원14,000원
# 직화오제볶음점심특선시 12,000원14,000원
# 직화제육볶음점심특선시 11,000원12,000원
# 보쌈정식점심특선시 11,000원12,000원
# 바지락 칼국수(2인이상)10,000원
# 쟁반막국수9,000원
# 직화오돌뼈주먹밥17,000원
# </content>
# <document><content>store_name: 성경만두요리전문점 종로점
#  category: 칼국수,만두
#  new_open:
#  rating: 별점 4.56
#  visited_review: 방문자 리뷰 2,251
#  directions_text: 네이버길찾기로 오시면 편리하게 오실 수 있습니다.
#
# 종로3가 익선동 근처 핫플레이스 특성상 주차요금이 비싸므로 대중교통 이용을 추천드립니다.
#
# 종로3가역(도보 5분)
# -종로3가역 15번 출구로 나와서 도보 5분
#
# 을지로3가역(도보 6분)
# -을지로3가역 4번 출구로 나와 청계천 건너 좌회전
#
# 인사동(도보 7분)
# -탑골공원 사거리 방면
#
# 종각역(도보 10분)
# -종각역 4번출구로 나와 탑골공원방면
#
# 익선동(도보 10분)
# 익선동에서 종로3가역 15번 출구 방면
#
# 자가용 이용시 네비게이션
# 1. 성경만두 종로점(종로구 수표로 88)
# 2. 종로 세종주차장(종로구 수표로 87) (도보 10초거리) (1시간 6,000원)
# 3. 공휴일, 일요일은 청계천 공영주차장 무료 주차 가능
# 내용 더보기
#  store_id: 1336373058
#  address: 서울 종로구 수표로 88
#  blog_review: 블로그 리뷰 1,065
#  phone_num: 0507-1363-9234
#  business_hours: 수(1/1)
# 새해 첫날11:00 - 21:00
# 15:30 - 17:00 브레이크타임
# 목
# 11:00 - 21:20
# 15:30 - 17:00 브레이크타임
# 14:00, 19:50 라스트오더
# 금
# 11:00 - 21:20
# 15:30 - 17:00 브레이크타임
# 14:00, 19:50 라스트오더
# 토
# 11:00 - 21:20
# 15:30 - 17:00 브레이크타임
# 14:00, 19:50 라스트오더
# 일
# 11:00 - 15:30
# 14:00 라스트오더
# 월
# 11:00 - 21:20
# 15:30 - 17:00 브레이크타임
# 14:00, 19:50 라스트오더
# 화
# 11:00 - 21:20
# 15:30 - 17:00 브레이크타임
# 14:00, 19:50 라스트오더
#
#  info: '예전 조선 궁중에서 일하셨던 우리 어머니의 만두와 맛이 비슷하다.'
#
# 저희 만두전골을 드셨던 어느 손님께서 이렇게 말씀하셨습니다.
# 서울의 숨은 보석, 성경만두요리전문점은 맛과 가성비를 동시에 추구하는 많은 분들에게 사랑받는 종로3가 찐맛집으로 자리 잡았습니다.
#
# 하지만 성경만두는 단순히 가격으로만 승부하는 노포 식당이 아닙니다.
#
# 근처 을지로와 인사동에 있는 유명한 만두집들과 비교해도 뒤지지 않는 맛성비와 함께, 술집으로도 변모할 수 있는 편안한 분위기 덕분에 많은 시민들이 점심이나 저녁 시간을 가리지 않고 찾아오고 계십니다. 특히, 소주가 단돈 3천원이라 포장마차 거리 같은 친근함을 드리기도 합니다.
#
# 약 5년 동안 매일 수제 만두를 80만 개 이상 빚었습니다. 사실 장사를 하는 동안 가성비 있는 가격으로 이익을 남기기가 쉽지 않아서 힘들지만 그래도 손님의 맛있었다는 한마디를 위안삼아 열심히 노력하고 있습니다.
#
# * 성경만두에 단골과 재방문이 많은 이유 4가지
#
# 1) 당일 재료는 당일 소진, 냉동 재료 없는 신선함이 원칙
# 당일 소진을 원칙으로 신선한 재료로 매일 빚은 고급 생만두를 합리적 가격으로 제공합니다. 재료비를 아끼기 위해 만두속에 당면 같은 저렴한 재료를 넣지 않습니다. 저희는 오직 신선한 돼지고기, 두부, 채소만을 넣어 잡내 없이 깔끔한 맛의 만두를 만듭니다.
#
# 2) 번거로운 재료 준비 과정
# 모든 재료를 갈아서 만들면 편합니다. 하지만 그렇게 하면 냉동만두 같이 뭉게지는 식감으로 변할 수 있습니다. 때문에 편의를 위해서 만두소를 갈아 넣지 않고 손이 많이 가더라도 대부분 직접 칼로 다져 넣어 아삭한 식감을 느끼실 수 있습니다.
#
# 3) 매일 빚은 생만두를 제공
# 대부분의 만두집들은 보관하기 편하다는 이유로 만두를 미리 쪄놓고 보관합니다. 반면 저희는 매일 빚어 신선한 생만두 그대로 제공해 드립니다. 때문에 손님을 속일수가 없습니다. 말랑말랑 만져보시면 바로 아시기 때문입니다. 내돈내산 아깝지 않은 한식 만두전골입니다.
#
# 4) 소주가 3천원
# '서울 종로에서 아직도 이 가격을 받는 식당이 있네?'
# 많은 손님들께서 가장 놀라시는 부분 중 하나입니다. 만두전골에 자신있기 때문에 더욱 많은 손님이 즐기러 오셨으면 하는 마음으로 소주를 착한 가격으로 받고 있습니다.
#
# 서울시 종로구 관수동 145-1
#
# 1) 종로3가역 15번 출구에서 5분 만에 도착! 종각역 4번출구 도보 10분 거리!
#
# 2) 을지로3가역 4번출구 도보 5분거리, 일요일 및 공휴일은 청계천 노상 공영주차장 주변 무료 주차가능
#
# * 예약없이 오셔도 식사 가능합니다! 5인 이상 고객님들은 오시기 전에 전화해주시면 최대한 도와드리겠습니다.
#
# * 만두, 좋아하세요?
# 가게를 운영하며 다른 유명 만두집들을 많이 다녀 보았습니다. 어떤 곳은 단맛이 강하고, 만두피가 두꺼웠으며, 김치 만두에서 잡내가 나기도 했습니다. 저희 만두는 혹시 만두를 좋아하지 않으신 분이라도 대부분 호불호 없이 맛있게 드실 수 있을것이라 자부합니다. 공장에서 빚어오는 완제품과는 차원이 다른 순수한 맛을 느끼실 수 있을 것입니다. 설레는 주말에 서울에서 가장 사랑받는 만두전골집 중에 하나인 성경만두에 오셔서 연인과의 데이트, 가족과의 편안하고 특별한 외식 시간, 가성비 넘치는 착한 가격의 점심 및 저녁 식사를 즐기세요.
#
# 성경만두는 종로3가역 15번출구에서 도보 5분 위치에 있습니다. 서울 종묘, 피카디리, 피맛골 주변 나들이 갔을 때 맛집을 찾으신다면 성경만두를 선택해주세요. 주말 데이트나 단체 모임, 기념일 등 카페 방문 전에 들르기 좋은 장소 중 하나임을 자신합니다.
#
# 왜 많은 분들이 성경만두를 찾는지, 직접 방문해 그 이유를 확인해보세요!
#
# 주력 메뉴
#
# 하얀 만두전골
# 맑고 시원한 느낌의 해물 육수와 수제 생만두, 다양한 채소, 버섯, 소고기, 칼국수와 함께 즐기는 샤브샤브 만두전골
#
# 빨간 만두전골
# 얼큰하고 시원한 비법 해물육수와 함께 즐기는 샤브샤브 만두전골
#
# 양곱창만두전골
# 얼큰한 만두전골에 소곱창, 소양을 곁들여 감칠맛 폭발 경험. 반드시 다시 찾는 곱창전골!
# 펼쳐보기
#  convenience_facilities_and_services: 단체 이용 가능
# 예약
# 무선 인터넷
# 포장
# 배달
# 남/녀 화장실 구분
# 출입구 휠체어 이용가능
#
#  Parking: 주차가능
# 유료
# 최초 60분 6000원
# 추가 요금 10분당 1,000원, 최대 100,000원
#  sns: https://www.instagram.com/skmandoo_jongno
# https://blog.naver.com/sgjongro55
# https://sgjongro.modoo.at/
# http://www.facebook.com/jongrosgmandoo
#
#  review_like_this_part_output: "음식이 맛있어요"이 키워드를 선택한 인원1324
# "재료가 신선해요"이 키워드를 선택한 인원625
# "가성비가 좋아요"이 키워드를 선택한 인원522
# "양이 많아요"이 키워드를 선택한 인원521
# "친절해요"이 키워드를 선택한 인원350
# "특별한 메뉴가 있어요"이 키워드를 선택한 인원247
# "매장이 넓어요"이 키워드를 선택한 인원204
# "단체모임 하기 좋아요"이 키워드를 선택한 인원144
# "건강한 맛이에요"이 키워드를 선택한 인원111
# "매장이 청결해요"이 키워드를 선택한 인원109
# "음식이 빨리 나와요"이 키워드를 선택한 인원57
# "메뉴 구성이 알차요"이 키워드를 선택한 인원43
# "인테리어가 멋져요"이 키워드를 선택한 인원21
# "아늑해요"이 키워드를 선택한 인원18
# "혼밥하기 좋아요"이 키워드를 선택한 인원16
# "특별한 날 가기 좋아요"이 키워드를 선택한 인원11
# "고기 질이 좋아요"이 키워드를 선택한 인원6
# "뷰가 좋아요"이 키워드를 선택한 인원6
# "차분한 분위기에요"이 키워드를 선택한 인원5
# "화장실이 깨끗해요"이 키워드를 선택한 인원5
# "주차하기 편해요"이 키워드를 선택한 인원4
# "반찬이 잘 나와요"이 키워드를 선택한 인원4
# "잡내가 적어요"이 키워드를 선택한 인원3
# "오래 머무르기 좋아요"이 키워드를 선택한 인원3
# "아이와 가기 좋아요"이 키워드를 선택한 인원2
# "향신료가 강하지 않아요"이 키워드를 선택한 인원2
# "대화하기 좋아요"이 키워드를 선택한 인원2
# "좌석이 편해요"이 키워드를 선택한 인원1
# "샐러드바가 잘 되어있어요"이 키워드를 선택한 인원1
# "기본 안주가 좋아요"이 키워드를 선택한 인원1
#
#  menu: nan</content>
# ==================================================
#
# ==================================================
# 🔄 Node: retrieve_opendata 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# context_opendata:
# <document><content>상호명: 우리집 게스트하우스
#  콘텐츠URL: https://korean.visitseoul.net/entertainment/우리집-게스트하우스/KOP018881?utm_source=seoulopendata&utm_medium=entertainment&utm_content=KOP018881
#  주소: 110-250 서울특별시 종로구 계동 104-3
#  신주소: 03059 서울특별시 종로구 계동길 33-13
#  전화번호: 02-744-0536
#  웹사이트: https://www.facebook.com/wooriguest/
#  운영시간: 24시간
#  운영요일: 연중
#  휴무일: 없음
#  교통정보: 3호선 안국역 2번 출구
#  홈페이지 운영 언어: 한국어
#  유모차 대여 여부: None</content>
# <document><content>상호명: 쌈지길 체험공방
#  콘텐츠URL: https://korean.visitseoul.net/entertainment/쌈지길-체험공방/KOP006364?utm_source=seoulopendata&utm_medium=entertainment&utm_content=KOP006364
#  주소: 110-300 서울 종로구 관훈동 38 지하 1층
#  신주소: 03146 서울특별시 종로구 인사동길 44, 지하 1층 (관훈동)
#  전화번호: 02-736-6711
#  웹사이트: http://m.smartstore.naver.com/ssamzigil
#  운영시간: 10:30 - 20:30
#  운영요일: 월요일~일요일
#  휴무일: 설날, 추석 당일 휴관
#  교통정보: 지하철 1호선 종각역 4번 출구에서 약 640m (도보 10분) 지하철 3호선 안국역 6번 출구에서 약 300m (도보 5분)
#  홈페이지 운영 언어: 한국어
#  유모차 대여 여부: None</content>
# <document><content>관광안내소명: 북촌마을안내소
#  안내소위치명: 정독도서관 서울교육박물관 앞
#  안내소소개: 방문객에게 마을 정보를 제공하고 공익목적의 전시 개최
#  부가서비스정보: 서가 운영, 와이파이 및 인터넷 검색 가능
#  휴무일: 설, 추석 당일
#  운영시작시각(하절기): 09:00
#  운영종료시각(하절기): 18:00
#  운영시작시각(동절기): 09:00
#  운영종료시각(동절기): 18:00
#  안내가능외국어: 영어, 일본어, 중국어
#  안내소전화번호: 02-2148-4161
#  소재지도로명주소: 서울특별시 종로구 북촌로5길 48
#  소재지지번주소: 서울특별시 종로구 화동 2
#  홈페이지주소: None
#  위도: 37.58126437
#  경도: 126.9838695</content>
# <document><content>상호명: 두 게스트하우스 (북촌)
#  콘텐츠URL: https://korean.visitseoul.net/entertainment/두-게스트하우스-북촌/KOP010562?utm_source=seoulopendata&utm_medium=entertainment&utm_content=KOP010562
#  주소: 110-800 서울 종로구 계동 15-6 15-6
#  신주소: 03056 서울 종로구 계동길 103-7 (계동)
#  전화번호: 02-3672-1977
#  웹사이트: None
#  운영시간: None
#  운영요일: None
#  휴무일: None
#  교통정보: 3호선 안국 3번 출구 이용 도보 5분 거리
#  홈페이지 운영 언어: None
#  유모차 대여 여부: None</content>
# <document><content>상호명: 심화숙 한지공방
#  콘텐츠URL: https://korean.visitseoul.net/entertainment/심화숙-한지공방/KOP018891?utm_source=seoulopendata&utm_medium=entertainment&utm_content=KOP018891
#  주소:
#  신주소: 03057 서울 종로구 북촌로 50 3층
#  전화번호: 02-394-6533
#  웹사이트: None
#  운영시간: 3월~11월 10:00 ~ 18:00 11월~2월 10:00 ~ 17:00(월요일?명절 당일 휴무)
#  운영요일: None
#  휴무일: 월요일?명절 당일 휴무
#  교통정보: 3호선 안국역 2번 출구에서 약 800m (도보 13분)
#  홈페이지 운영 언어: None
#  유모차 대여 여부: None</content>
# <document><content>상호명: 떡박물관
#  콘텐츠URL: https://korean.visitseoul.net/entertainment/여용국-한방스파/KOP002037?utm_source=seoulopendata&utm_medium=entertainment&utm_content=KOP002037
#  주소: 110-360 서울 종로구 와룡동 164-2 서울 종로구 와룡동 164-2
#  신주소: 03132 서울 종로구 돈화문로 71 (와룡동, 떡박물관)
#  전화번호: 02-741-5447
#  웹사이트: http://www.tkmuseum.or.kr
#  운영시간: 월~토요일(10:00~18:00) (17시 30분까지 입장완료)
#  운영요일: None
#  휴무일: -일요일 -설, 추석 당일
#  교통정보: 1, 3, 5호선 종로3가역 7번 출구에서 약 286m (도보 4분)
#  홈페이지 운영 언어: None
#  유모차 대여 여부: None</content>
# <document><content>상호명: 춘당지
#  콘텐츠URL: https://korean.visitseoul.net/nature/춘당지/KOP039629?utm_source=seoulopendata&utm_medium=nature&utm_content=KOP039629
#  주소:  서울 종로구 와룡동 2-1
#  신주소: 03072 서울 종로구 창경궁로 185 (와룡동, 창경궁)
#  전화번호:  02-762-4868
#  웹사이트: http://cgg.cha.go.kr/agapp/public/html/HtmlPage.do?pg=/cgg/01/virtual_01.jsp&pageNo=79010000&siteCd=CGG
#  운영시간: 09:00 ~ 20:00 (매표 및 입장시간) 09:00 ~ 21:00 (관람시간)
#  운영요일: 화요일~일요일
#  휴무일: 매주 월요일 (휴무일이 공휴일일 경우 익일 휴무)
#  교통정보: 4호선 혜화역 4번 출구에서 약 994m (도보 16분)</content>
# <document><content>상호명: 북촌마을관광안내소
#  콘텐츠URL: https://korean.visitseoul.net/attractions/북촌마을관광안내소/KOP027189?utm_source=seoulopendata&utm_medium=attractions&utm_content=KOP027189
#  주소: 110-210 서울 종로구 화동 2
#  신주소: 03055 서울 종로구 북촌로5길 48 (화동, 정독도서관) 주요위치 : 재동초등학교 사거리 (정독도서관 부지내, 서울교육박물관 앞)
#  전화번호: +82-2-2148-4161
#  팩스번호: None
#  웹사이트: None
#  운영시간: ?09:00~18:00(일요일 휴관)
#  운영요일: None
#  휴무일: 연중무휴 (설, 추석 명절 당일만 휴무)
#  교통정보: 3호선 안국역 1번 출구에서 약 527m (도보 9분)
#  태그: 외국어안내,관광안내소,정독도서관,북촌마을관광안내소
#  장애인편의시설: None</content>
# <document><content>상호명: SEOUL CULTURE LOUNGE 서울컬쳐라운지
#  콘텐츠URL: https://korean.visitseoul.net/entertainment/2024-SEOUL-CULTURE-LOUNGE/KOPi8afi4?utm_source=seoulopendata&utm_medium=entertainment&utm_content=KOPi8afi4
#  주소:  서울 종로구 관철동 10-2
#  신주소: 03190 서울 종로구 청계천로 85 (관철동, 삼일빌딩)  11층
#  전화번호: 02-3788-8189
#  웹사이트: https://www.seoulculturelounge.com
#  운영시간: 10:00~17:00
#  운영요일: 화요일~토요일
#  휴무일: 일요일, 월요일, 공휴일 휴무
#  교통정보: 1호선 종각역 4번 출구에서 약 400m (도보 5분)
#  홈페이지 운영 언어: 한국어,영어,일어,중국어(간체)
#  유모차 대여 여부: None</content>
# <document><content>상호명: 무계원
#  콘텐츠URL: https://korean.visitseoul.net/entertainment/무계원/KOP029568?utm_source=seoulopendata&utm_medium=entertainment&utm_content=KOP029568
#  주소: 110-819 서울 종로구 부암동 327
#  신주소: 03022 서울 종로구 창의문로5가길 2 (부암동)
#  전화번호: 02-379-7131~2
#  웹사이트: https://www.jfac.or.kr/site/main/content/moogw01
#  운영시간: 화-일 : 10:00 - 18:00
#  운영요일: 화-일요일
#  휴무일: 월요일, 1월 1일, 설날, 추석날
#  교통정보: 3호선 경복궁역 3번 출구, 5호선 광화문역 2번 출구 버스 정류장에서 지선버스 7020, 7022, 7212 승차
#  홈페이지 운영 언어: 한국어
#  유모차 대여 여부: None</content>
# ==================================================
#
# ==================================================
# 🔄 Node: llm_Summary_opendata 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# answer_llm_Summary_opendata:
# ### 요약
#
# 1. **우리집 게스트하우스**
#    - 장소 이름: 우리집 게스트하우스
#    - 위치: 서울특별시 종로구 계동 104-3
#    - 전화번호: 02-744-0536
#    - 웹사이트 URL: [우리집 게스트하우스 페이스북](https://www.facebook.com/wooriguest/)
#    - 운영 날짜 및 시간: 24시간 운영, 연중 무휴
#    - 교통정보: 3호선 안국역 2번 출구
#    - 지원언어: 한국어
#
# 2. **쌈지길 체험공방**
#    - 장소 이름: 쌈지길 체험공방
#    - 위치: 서울 종로구 관훈동 38 지하 1층
#    - 전화번호: 02-736-6711
#    - 웹사이트 URL: [쌈지길 체험공방](http://m.smartstore.naver.com/ssamzigil)
#    - 운영 날짜 및 시간: 월요일~일요일, 10:30 - 20:30
#    - 교통정보: 지하철 1호선 종각역 4번 출구에서 약 640m (도보 10분), 지하철 3호선 안국역 6번 출구에서 약 300m (도보 5분)
#    - 지원언어: 한국어
#
# 3. **북촌마을안내소**
#    - 장소 이름: 북촌마을안내소
#    - 위치: 서울특별시 종로구 북촌로5길 48
#    - 전화번호: 02-2148-4161
#    - 운영 날짜 및 시간: 하절기 09:00 - 18:00, 동절기 09:00 - 18:00
#    - 교통정보: 정독도서관 서울교육박물관 앞
#    - 지원언어: 영어, 일본어, 중국어
#
# 4. **두 게스트하우스 (북촌)**
#    - 장소 이름: 두 게스트하우스 (북촌)
#    - 위치: 서울 종로구 계동 15-6
#    - 전화번호: 02-3672-1977
#    - 교통정보: 3호선 안국 3번 출구 이용 도보 5분 거리
#
# 5. **심화숙 한지공방**
#    - 장소 이름: 심화숙 한지공방
#    - 위치: 서울 종로구 북촌로 50 3층
#    - 전화번호: 02-394-6533
#    - 운영 날짜 및 시간: 3월~11월 10:00 ~ 18:00, 11월~2월 10:00 ~ 17:00
#    - 교통정보: 3호선 안국역 2번 출구에서 약 800m (도보 13분)
#
# 6. **떡박물관**
#    - 장소 이름: 떡박물관
#    - 위치: 서울 종로구 와룡동 164-2
#    - 전화번호: 02-741-5447
#    - 웹사이트 URL: [떡박물관](http://www.tkmuseum.or.kr)
#    - 운영 날짜 및 시간: 월~토요일(10:00~18:00)
#    - 교통정보: 1, 3, 5호선 종로3가역 7번 출구에서 약 286m (도보 4분)
#
# 7. **춘당지**
#    - 장소 이름: 춘당지
#    - 위치: 서울 종로구 와룡동 2-1
#    - 전화번호: 02-762-4868
#    - 웹사이트 URL: [춘당지](http://cgg.cha.go.kr/agapp/public/html/HtmlPage.do?pg=/cgg/01/virtual_01.jsp&pageNo=79010000&siteCd=CGG)
#    - 운영 날짜 및 시간: 09:00 ~ 20:00 (매표 및 입장시간), 09:00 ~ 21:00 (관람시간)
#    - 교통정보: 4호선 혜화역 4번 출구에서 약 994m (도보 16분)
#
# 8. **북촌마을관광안내소**
#    - 장소 이름: 북촌마을관광안내소
#    - 위치: 서울 종로구 화동 2
#    - 전화번호: +82-2-2148-4161
#    - 운영 날짜 및 시간: 09:00~18:00 (일요일 휴관)
#    - 교통정보: 3호선 안국역 1번 출구에서 약 527m (도보 9분)
#
# 9. **SEOUL CULTURE LOUNGE 서울컬쳐라운지**
#    - 장소 이름: SEOUL CULTURE LOUNGE 서울컬쳐라운지
#    - 위치: 서울 종로구 관철동 10-2
#    - 전화번호: 02-3788-8189
#    - 웹사이트 URL: [서울컬쳐라운지](https://www.seoulculturelounge.com)
#    - 운영 날짜 및 시간: 10:00~17:00
#    - 교통정보: 1호선 종각역 4번 출구에서 약 400m (도보 5분)
#    - 지원언어: 한국어, 영어, 일본어, 중국어(간체)
#
# 10. **무계원**
#     - 장소 이름: 무계원
#     - 위치: 서울 종로구 부암동 327
#     - 전화번호: 02-379-7131~2
#     - 웹사이트 URL: [무계원](https://www.jfac.or.kr/site/main/content/moogw01)
#     - 운영 날짜 및 시간: 화-일 : 10:00 - 18:00
#     - 교통정보: 3호선 경복궁역 3번 출구, 5호선 광화문역 2번 출구 버스 정류장에서 지선버스 7020, 7022, 7212 승차
#     - 지원언어: 한국어
# ==================================================
#
# ==================================================
# 🔄 Node: llm_Summary_naver 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# answer_llm_Summary_gangnam:
# none
# answer_llm_Summary_jongro:
# ```json
# [
#     {
#         "store_name": "행2PM8PM",
#         "category": "술집",
#         "rating": "별점 4.66",
#         "directions_text": "중구 수표로12길 10. 1~3층 루프탑까지 통건물이며 1층이 출입구입니다. 을지로3가역과 명동역, 충무로역에서 도보로 약 3분거리.",
#         "store_id": "1799596430",
#         "address": "서울 중구 수표로12길 10 1층~3층",
#         "phone_num": "0507-1331-6915",
#         "business_hours": "수(1/1) 15:00 - 23:00, 목 15:00 - 23:00, 금 15:00 - 23:00, 토 13:30 - 24:00, 일 13:30 - 23:00, 월 15:00 - 23:00, 화 15:00 - 23:00",
#         "info": "힙지로 1세대 노포 맛집인 대표 와인펍으로, 다양한 식사와 간편한 안주류를 제공.",
#         "convenience_facilities_and_services": "콜키지 가능, 생일 혜택, 무한 리필, 테이크아웃 할인, 와인 페어링, 단체 이용 가능, 예약, 무선 인터넷, 포장, 좌석 휠체어 이용가능",
#         "Parking": "주차가능, 무료",
#         "sns": "http://www.instagram.com/hang_2pm8pm, https://youtube.com/channel/UCEIcCQOq1M9VVCPkYDkuAQA",
#         "store의 좋은점": "음식이 맛있고, 라이브 공연이 훌륭하며, 다양한 술과 안주가 준비되어 있습니다.",
#         "menu": "몽둥이고기, 버팔로윙봉&나초, 치즈폭탄 감자튀김, 이탈리아 정통 라자냐 파스타, 다양한 와인"
#     },
#     {
#         "store_name": "방이옥 종로관철점",
#         "category": "육류,고기요리",
#         "rating": "정보없음",
#         "directions_text": "지하철: 종각역 4번출구로 나오셔서 30초 직진 후 우회전, 2층에 위치.",
#         "store_id": "1431553022",
#         "address": "서울 종로구 우정국로2길 32 2층",
#         "phone_num": "0507-1377-8268",
#         "business_hours": "수(1/1) 휴무, 목~화 11:00 - 22:00, 21:00 라스트오더",
#         "info": "정보없음",
#         "convenience_facilities_and_services": "정보없음",
#         "Parking": "정보없음",
#         "sns": "정보없음",
#         "store의 좋은점": "정보없음",
#         "menu": "정보없음"
#     },
#     {
#         "store_name": "천년동안도",
#         "category": "바(BAR)",
#         "rating": "정보없음",
#         "directions_text": "청계2가 삼일빌딩 뒷건물에 위치.",
#         "store_id": "1789291657",
#         "address": "서울 종로구 삼일대로15길 6 지하1층, 2층",
#         "phone_num": "0507-1433-0619",
#         "business_hours": "일~금 18:00 - 24:00, 토 17:00 - 24:00",
#         "info": "1996년 대학로에서 시작된 바, 뮤지션들의 공연을 관람할 수 있는 공간.",
#         "convenience_facilities_and_services": "단체 이용 가능, 예약, 남/녀 화장실 구분, 무선 인터넷",
#         "Parking": "주차가능, 유료",
#         "sns": "http://www.chunnyun.com/, https://www.instagram.com/chunnyun.jonggak",
#         "store의 좋은점": "라이브 공연과 LP 청음 공간이 있어 특별한 경험을 제공합니다.",
#         "menu": "피자, 칵테일, 와인"
#     },
#     {
#         "store_name": "종로도담",
#         "category": "한식",
#         "rating": "별점 4.45",
#         "directions_text": "종각역 2번출구로 나와 직진 후 좌회전, 횡단보도 앞에 위치.",
#         "store_id": "1614498920",
#         "address": "서울 종로구 삼봉로 78",
#         "phone_num": "0507-1321-9850",
#         "business_hours": "매일 11:00 - 22:00, 15:00 - 17:00 브레이크타임, 21:00 라스트오더",
#         "info": "개성보쌈과 다양한 한식 메뉴를 제공하는 맛집.",
#         "convenience_facilities_and_services": "콜키지 가능, 예약, 단체 이용 가능, 무선 인터넷, 포장",
#         "Parking": "주차 불가",
#         "sns": "https://blog.naver.com/taekdaeri, https://www.instagram.com/taekdaeri_official",
#         "store의 좋은점": "직장인 점심과 저녁에 적합한 집밥 컨셉.",
#         "menu": "김치찜, 부추전, 낙지볶음, 개성보쌈"
#     },
#     {
#         "store_name": "오봉집 종로점",
#         "category": "한식",
#         "rating": "정보없음",
#         "directions_text": "종각역 4번출구로 나와 오른쪽 골목으로 직진, 1층에 위치.",
#         "store_id": "1558521785",
#         "address": "서울 종로구 종로8길 20 1층",
#         "phone_num": "0507-1393-0555",
#         "business_hours": "수(1/1) 12:00 - 22:00, 목~화 11:00 - 22:30, 21:50 라스트오더",
#         "info": "직화낙지볶음과 프리미엄 가브리살 보쌈 전문점.",
#         "convenience_facilities_and_services": "단체 이용 가능, 포장, 배달, 무선 인터넷, 예약",
#         "Parking": "주차 불가",
#         "sns": "https://www.instagram.com/obongzip_jongno",
#         "store의 좋은점": "가성비 좋은 메뉴와 편안한 분위기.",
#         "menu": "오봉스페셜, 직화낙지볶음, 보쌈"
#     },
#     {
#         "store_name": "성경만두요리전문점 종로점",
#         "category": "칼국수,만두",
#         "rating": "별점 4.56",
#         "directions_text": "종로3가역 15번 출구로 나와 도보 5분.",
#         "store_id": "1336373058",
#         "address": "서울 종로구 수표로 88",
#         "phone_num": "0507-1363-9234",
#         "business_hours": "수(1/1) 11:00 - 21:00, 목~화 11:00 - 21:20",
#         "info": "신선한 재료로 만든 만두와 칼국수 전문점.",
#         "convenience_facilities_and_services": "단체 이용 가능, 예약, 무선 인터넷, 포장, 배달",
#         "Parking": "주차가능, 유료",
#         "sns": "https://www.instagram.com/skmandoo_jongno, https://blog.naver.com/sgjongro55",
#         "store의 좋은점": "가성비 좋은 만두와 편안한 분위기.",
#         "menu": "하얀 만두전골, 빨간 만두전골, 양곱창만두전골"
#     }
# ]
# ```
# answer_llm_Summary_junggu:
# none
# answer_llm_Summary_yongsan:
# none
# ==================================================
#
# ==================================================
# 🔄 Node: Schedule_or_place_check 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# ScheduleOrplace:
# 일정
# ==================================================
# []
#
# ==================================================
# 🔄 Node: llm_Schedule_answer 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# answer:
# 서울 종로구에서의 2박 3일 여행 일정을 추천해드리겠습니다. 종로구는 전통과 현대가 어우러진 매력적인 지역으로, 다양한 명소와 맛집이 가득합니다. 아래는 추천 일정입니다.
#
# ### 1일차
# - **아침**: 성경만두요리전문점 종로점
#   - 메뉴: 하얀 만두전골, 빨간 만두전골
#   - 주소: 서울 종로구 수표로 88
#   - 별점: 4.56
#
# - **오전**: 북촌마을안내소
#   - 전통 한옥마을을 둘러보며 한국의 전통문화를 체험하세요.
#   - 주소: 서울 종로구 북촌로5길 48
#
# - **점심**: 종로도담
#   - 메뉴: 김치찜, 부추전, 낙지볶음
#   - 주소: 서울 종로구 삼봉로 78
#   - 별점: 4.45
#
# - **오후**: 쌈지길 체험공방
#   - 다양한 공예 체험을 즐길 수 있는 곳입니다.
#   - 주소: 서울 종로구 관훈동 38 지하 1층
#
# - **저녁**: 방이옥 종로관철점
#   - 육류, 고기요리 전문점
#   - 주소: 서울 종로구 우정국로2길 32 2층
#
# - **숙소**: 우리집 게스트하우스
#   - 주소: 서울 종로구 계동 104-3
#
# ### 2일차
# - **아침**: 오봉집 종로점
#   - 메뉴: 오봉스페셜, 직화낙지볶음
#   - 주소: 서울 종로구 종로8길 20
#
# - **오전**: 떡박물관
#   - 한국 전통 떡의 역사와 문화를 배울 수 있는 곳입니다.
#   - 주소: 서울 종로구 와룡동 164-2
#
# - **점심**: 성경만두요리전문점 종로점
#   - 메뉴: 양곱창 만두전골
#   - 주소: 서울 종로구 수표로 88
#
# - **오후**: 북촌마을관광안내소
#   - 북촌 한옥마을을 더 깊이 탐방해보세요.
#   - 주소: 서울 종로구 화동 2
#
# - **저녁**: 천년동안도
#   - 바(BAR)에서 라이브 공연을 즐기며 하루를 마무리하세요.
#   - 주소: 서울 종로구 삼일대로15길 6
#
# - **숙소**: 두 게스트하우스 (북촌)
#   - 주소: 서울 종로구 계동 15-6
#
# ### 3일차
# - **아침**: 종로도담
#   - 메뉴: 개성보쌈
#   - 주소: 서울 종로구 삼봉로 78
#
# - **오전**: 무계원
#   - 전통과 현대가 어우러진 문화 공간을 방문하세요.
#   - 주소: 서울 종로구 부암동 327
#
# - **점심**: 오봉집 종로점
#   - 메뉴: 보쌈
#   - 주소: 서울 종로구 종로8길 20
#
# - **오후**: 심화숙 한지공방
#   - 한지 공예 체험을 통해 한국 전통 문화를 느껴보세요.
#   - 주소: 서울 종로구 북촌로 50 3층
#
# - **저녁**: 행 2PM 8PM
#   - 다양한 와인과 안주를 즐길 수 있는 와인펍
#   - 주소: 서울 중구 수표로12길 10
#
# 이 일정이 마음에 드시길 바랍니다! 만약 수정이 필요하시면 말씀해 주세요.
# ('user', '종로구에서 2박3일동안 여행계획 짜줘')
# ('assistant', '서울 종로구에서의 2박 3일 여행 일정을 추천해드리겠습니다. 종로구는 전통과 현대가 어우러진 매력적인 지역으로, 다양한 명소와 맛집이 가득합니다. 아래는 추천 일정입니다.\n\n### 1일차\n- **아침**: 성경만두요리전문점 종로점\n  - 메뉴: 하얀 만두전골, 빨간 만두전골\n  - 주소: 서울 종로구 수표로 88\n  - 별점: 4.56\n\n- **오전**: 북촌마을안내소\n  - 전통 한옥마을을 둘러보며 한국의 전통문화를 체험하세요.\n  - 주소: 서울 종로구 북촌로5길 48\n\n- **점심**: 종로도담\n  - 메뉴: 김치찜, 부추전, 낙지볶음\n  - 주소: 서울 종로구 삼봉로 78\n  - 별점: 4.45\n\n- **오후**: 쌈지길 체험공방\n  - 다양한 공예 체험을 즐길 수 있는 곳입니다.\n  - 주소: 서울 종로구 관훈동 38 지하 1층\n\n- **저녁**: 방이옥 종로관철점\n  - 육류, 고기요리 전문점\n  - 주소: 서울 종로구 우정국로2길 32 2층\n\n- **숙소**: 우리집 게스트하우스\n  - 주소: 서울 종로구 계동 104-3\n\n### 2일차\n- **아침**: 오봉집 종로점\n  - 메뉴: 오봉스페셜, 직화낙지볶음\n  - 주소: 서울 종로구 종로8길 20\n\n- **오전**: 떡박물관\n  - 한국 전통 떡의 역사와 문화를 배울 수 있는 곳입니다.\n  - 주소: 서울 종로구 와룡동 164-2\n\n- **점심**: 성경만두요리전문점 종로점\n  - 메뉴: 양곱창 만두전골\n  - 주소: 서울 종로구 수표로 88\n\n- **오후**: 북촌마을관광안내소\n  - 북촌 한옥마을을 더 깊이 탐방해보세요.\n  - 주소: 서울 종로구 화동 2\n\n- **저녁**: 천년동안도\n  - 바(BAR)에서 라이브 공연을 즐기며 하루를 마무리하세요.\n  - 주소: 서울 종로구 삼일대로15길 6\n\n- **숙소**: 두 게스트하우스 (북촌)\n  - 주소: 서울 종로구 계동 15-6\n\n### 3일차\n- **아침**: 종로도담\n  - 메뉴: 개성보쌈\n  - 주소: 서울 종로구 삼봉로 78\n\n- **오전**: 무계원\n  - 전통과 현대가 어우러진 문화 공간을 방문하세요.\n  - 주소: 서울 종로구 부암동 327\n\n- **점심**: 오봉집 종로점\n  - 메뉴: 보쌈\n  - 주소: 서울 종로구 종로8길 20\n\n- **오후**: 심화숙 한지공방\n  - 한지 공예 체험을 통해 한국 전통 문화를 느껴보세요.\n  - 주소: 서울 종로구 북촌로 50 3층\n\n- **저녁**: 행 2PM 8PM\n  - 다양한 와인과 안주를 즐길 수 있는 와인펍\n  - 주소: 서울 중구 수표로12길 10\n\n이 일정이 마음에 드시길 바랍니다! 만약 수정이 필요하시면 말씀해 주세요.')
# ==================================================

# %%
inputs = GraphState(question="방금 알려준 종로구의 카페 밀롱가는 주차가 가능해?")

# %%
res = app.invoke(input=inputs, config=config)
# Out:
# [HumanMessage(content='방금 알려준 종로구의 카페 밀롱가는 주차가 가능해?', additional_kwargs={}, response_metadata={}, id='5cb4880a-92aa-4d06-822d-db24efb09ae9'), AIMessage(content='밀롱가는 주차 정보가 제공되지 않았습니다. 따라서 주차 가능 여부에 대한 정보는 확인할 수 없습니다. 다만, 대중교통을 이용하여 경복궁역 3번 출구에서 접근할 수 있습니다.', additional_kwargs={}, response_metadata={}, id='f08ae18a-5387-4234-95e7-0471eaf63612'), HumanMessage(content='방금 알려준 종로구의 카페 밀롱가는 주차가 가능해?', additional_kwargs={}, response_metadata={}, id='4d871650-c7de-4d91-874b-75484f580069'), AIMessage(content='밀롱가는 종로구에 위치한 카페로, 아늑한 분위기와 독특한 인테리어가 매력적입니다. 이곳은 커피와 디저트가 맛있기로 유명하며, 조용한 환경에서 여유롭게 시간을 보낼 수 있는 장소입니다. 주차 정보는 제공되지 않았으므로, 대중교통을 이용하는 것이 좋습니다. 경복궁역 3번 출구에서 쉽게 접근할 수 있습니다.', additional_kwargs={}, response_metadata={}, id='98f477af-9335-42a6-8a5e-b45645af37cc')]

# %%
res.an

# %%
import time
import sys

# %%
def typewriter_effect(text, delay=0.05):
    """
    텍스트를 한 글자씩 출력하는 효과를 주는 함수.
    :param text: 출력할 문자열
    :param delay: 글자 출력 간의 딜레이 (초 단위)
    """
    for char in text:
        sys.stdout.write(char)  # 글자를 출력
        sys.stdout.flush()  # 출력 버퍼를 비워 즉시 표시
        time.sleep(delay)  # 딜레이 추가
    print()  # 줄 바꿈

# 사용 예제
text_to_display = "촤라락 출력되는 효과를 보여드립니다!"
typewriter_effect(res.get('answer'), delay=0.02)
# Out:
# 밀롱가는 종로구에 위치한 아늑한 분위기의 카페로, 독특한 인테리어와 함께 커피와 디저트가 맛있기로 유명합니다. 조용한 환경에서 여유롭게 시간을 보낼 수 있는 장소로 추천됩니다. 주차 정보는 제공되지 않아 대중교통을 이용하는 것이 좋으며, 경복궁역 3번 출구에서 쉽게 접근할 수 있습니다.

# %%
res.get('answer')
# Out:
# '밀롱가는 종로구에 위치한 아늑한 분위기의 카페로, 독특한 인테리어와 함께 커피와 디저트가 맛있기로 유명합니다. 조용한 환경에서 여유롭게 시간을 보낼 수 있는 장소로 추천됩니다. 주차 정보는 제공되지 않아 대중교통을 이용하는 것이 좋으며, 경복궁역 3번 출구에서 쉽게 접근할 수 있습니다.'

# %%
while(True):
    user_input = input('일정이나 장소를 물어 보세요 : ')
    # 질문 입력
    inputs = GraphState(question=user_input)

    res = app.invoke(input=inputs, config=config)

    typewriter_effect(res.get('answer'), delay=0.01)
# Out:
# [HumanMessage(content='방금 알려준 종로구의 카페 밀롱가는 주차가 가능해?', additional_kwargs={}, response_metadata={}, id='5cb4880a-92aa-4d06-822d-db24efb09ae9'), AIMessage(content='밀롱가는 주차 정보가 제공되지 않았습니다. 따라서 주차 가능 여부에 대한 정보는 확인할 수 없습니다. 다만, 대중교통을 이용하여 경복궁역 3번 출구에서 접근할 수 있습니다.', additional_kwargs={}, response_metadata={}, id='f08ae18a-5387-4234-95e7-0471eaf63612'), HumanMessage(content='방금 알려준 종로구의 카페 밀롱가는 주차가 가능해?', additional_kwargs={}, response_metadata={}, id='4d871650-c7de-4d91-874b-75484f580069'), AIMessage(content='밀롱가는 종로구에 위치한 카페로, 아늑한 분위기와 독특한 인테리어가 매력적입니다. 이곳은 커피와 디저트가 맛있기로 유명하며, 조용한 환경에서 여유롭게 시간을 보낼 수 있는 장소입니다. 주차 정보는 제공되지 않았으므로, 대중교통을 이용하는 것이 좋습니다. 경복궁역 3번 출구에서 쉽게 접근할 수 있습니다.', additional_kwargs={}, response_metadata={}, id='98f477af-9335-42a6-8a5e-b45645af37cc'), HumanMessage(content='방금 알려준 종로구의 카페 밀롱가는 주차가 가능해?', additional_kwargs={}, response_metadata={}, id='e1c54eeb-7492-4be9-a8c3-3659e97dd187'), AIMessage(content='밀롱가는 종로구에 위치한 아늑한 분위기의 카페로, 독특한 인테리어와 함께 커피와 디저트가 맛있기로 유명합니다. 조용한 환경에서 여유롭게 시간을 보낼 수 있는 장소로 추천됩니다. 주차 정보는 제공되지 않아 대중교통을 이용하는 것이 좋으며, 경복궁역 3번 출구에서 쉽게 접근할 수 있습니다.', additional_kwargs={}, response_metadata={}, id='4bbcbcab-05a7-43b9-832a-91cc06e7c1fa')]
# 종로구에서의 2박 3일 일정을 추천해드리겠습니다. 이 일정은 관광 명소, 맛집, 카페 등을 포함하여 동선을 최소화하도록 구성하였습니다.
#
# ### 1일차
# - **아침**: 북촌 한옥마을 산책
#   - 북촌마을안내소에서 시작하여 전통 한옥을 감상하며 산책하세요.
# - **점심**: 종로도담 (한식)
#   - 김치찜과 개성보쌈을 맛보세요.
# - **오후**: 서울공예박물관 방문
#   - 다양한 전시를 통해 한국 전통 공예를 체험할 수 있습니다.
# - **저녁**: 서울회관 (요리주점)
#   - 옛날 가마솥 통닭과 유동골뱅이 무침을 추천합니다.
#
# ### 2일차
# - **아침**: 떡박물관 방문
#   - 한국 전통 떡의 역사와 문화를 배울 수 있습니다.
# - **점심**: 오봉집 종로점 (한식)
#   - 직화낙지볶음과 프리미엄 가브리살 보쌈을 즐기세요.
# - **오후**: 쌈지길 체험공방
#   - 다양한 공예 체험을 통해 특별한 기념품을 만들어보세요.
# - **저녁**: 천년동안도 (BAR)
#   - 라이브 공연과 함께 다양한 음료를 즐기며 하루를 마무리하세요.
#
# ### 3일차
# - **아침**: 북촌목공예공방 체험
#   - 목공예 체험을 통해 특별한 경험을 쌓아보세요.
# - **점심**: 동베이 광화문점 (양꼬치)
#   - 양꼬치와 동북 요리를 맛보세요.
# - **오후**: 서울컬쳐라운지 방문
#   - 다양한 문화 콘텐츠를 즐길 수 있는 공간입니다.
# - **저녁**: 방이옥 종로 관철점 (육류, 고기요리)
#   - 다양한 고기 요리를 맛보며 여행을 마무리하세요.
#
# 이 일정이 마음에 드시길 바라며, 변경이 필요하시면 언제든지 말씀해 주세요!
# Traceback (most recent call last):
#
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/langraph/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "/var/folders/_v/g1qmsq595kq_fg_zv8n2022h0000gn/T/ipykernel_6197/578781410.py", line 6, in <cell line: 0>
#     res = app.invoke(input=inputs, config=config)
#
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/langraph/lib/python3.11/site-packages/langgraph/pregel/__init__.py", line 1936, in invoke
#     for chunk in self.stream(
#
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/langraph/lib/python3.11/site-packages/langgraph/pregel/__init__.py", line 1656, in stream
#     for _ in runner.tick(
#
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/langraph/lib/python3.11/site-packages/langgraph/pregel/runner.py", line 239, in tick
#     _panic_or_proceed(
#
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/langraph/lib/python3.11/site-packages/langgraph/pregel/runner.py", line 539, in _panic_or_proceed
#     raise exc
#
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/langraph/lib/python3.11/site-packages/langgraph/pregel/executor.py", line 76, in done
#     task.result()
#
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/langraph/lib/python3.11/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/langraph/lib/python3.11/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/langraph/lib/python3.11/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/langraph/lib/python3.11/site-packages/langgraph/pregel/retry.py", line 40, in run_with_retry
#     return task.proc.invoke(task.input, config)
#
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/langraph/lib/python3.11/site-packages/langgraph/utils/runnable.py", line 408, in invoke
#     input = step.invoke(input, config, **kwargs)
#
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/langraph/lib/python3.11/site-packages/langgraph/utils/runnable.py", line 184, in invoke
#     ret = context.run(self.func, input, **kwargs)
#
#   File "/var/folders/_v/g1qmsq595kq_fg_zv8n2022h0000gn/T/ipykernel_6197/2103715052.py", line 55, in retrieve_document_naver
#     location = ast.literal_eval(location_str)
#
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/langraph/lib/python3.11/ast.py", line 64, in literal_eval
#     node_or_string = parse(node_or_string.lstrip(" \t"), mode='eval')
#
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/langraph/lib/python3.11/ast.py", line 50, in parse
#     return compile(source, filename, mode, flags,
#
#   File "<unknown>", line 1
#     사용자의 질문: 그러면 방금 대답해준 2일차 점심으로 종로구 오봉집에 대한 자세한 정보를 알려줘
#          ^
# SyntaxError: invalid syntax

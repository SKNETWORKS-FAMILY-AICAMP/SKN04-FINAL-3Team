# %%
# API 키를 환경변수로 관리하기 위한 설정 파일
from dotenv import load_dotenv

# API 키 정보 로드
load_dotenv()
# Out:
# True

# %%
# LangSmith 추적을 설정합니다. https://smith.langchain.com
# !pip install -qU langchain-teddynote
from langchain_teddynote import logging

# 프로젝트 이름을 입력합니다.
logging.langsmith("practice")
# Out:
# LangSmith 추적을 시작합니다.
# [프로젝트명]
# practice

# %%
from langchain.vectorstores import FAISS
from langchain.embeddings import OpenAIEmbeddings

# Step 1: FAISS 인덱스 파일 로드
faiss_index_path = "Faiss/naver_map_gangnam_faiss"  # 저장된 Faiss 파일 경로
embeddings = OpenAIEmbeddings()  # 임베딩 객체 초기화

# 저장된 FAISS 인덱스를 불러와서 Retriever 생성
retriever_naver_gangnam = FAISS.load_local(faiss_index_path, embeddings,allow_dangerous_deserialization=True).as_retriever()

# 검색 매개변수 설정 (예: 검색 결과 상위 10개 반환)
retriever_naver_gangnam.search_kwargs = {"k": 6}
# Out:
# /var/folders/_v/g1qmsq595kq_fg_zv8n2022h0000gn/T/ipykernel_3674/1756154715.py:6: LangChainDeprecationWarning: The class `OpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import OpenAIEmbeddings``.
#   embeddings = OpenAIEmbeddings()  # 임베딩 객체 초기화

# %%
# Step 1: FAISS 인덱스 파일 로드
faiss_index_path = "Faiss/naver_map_jongro_faiss"  # 저장된 Faiss 파일 경로
embeddings = OpenAIEmbeddings()  # 임베딩 객체 초기화

# 저장된 FAISS 인덱스를 불러와서 Retriever 생성
retriever_naver_jongro = FAISS.load_local(faiss_index_path, embeddings,allow_dangerous_deserialization=True).as_retriever()

# 검색 매개변수 설정 (예: 검색 결과 상위 10개 반환)
retriever_naver_jongro.search_kwargs = {"k": 6}

# %%
# Step 1: FAISS 인덱스 파일 로드
faiss_index_path = "Faiss/naver_map_Junggu_faiss"  # 저장된 Faiss 파일 경로
embeddings = OpenAIEmbeddings()  # 임베딩 객체 초기화

# 저장된 FAISS 인덱스를 불러와서 Retriever 생성
retriever_naver_Junggu = FAISS.load_local(faiss_index_path, embeddings,allow_dangerous_deserialization=True).as_retriever()

# 검색 매개변수 설정 (예: 검색 결과 상위 10개 반환)
retriever_naver_Junggu.search_kwargs = {"k": 6}

# %%
# Step 1: FAISS 인덱스 파일 로드
faiss_index_path = "Faiss/naver_map_yongsan_faiss"  # 저장된 Faiss 파일 경로
embeddings = OpenAIEmbeddings()  # 임베딩 객체 초기화

# 저장된 FAISS 인덱스를 불러와서 Retriever 생성
retriever_naver_yongsan = FAISS.load_local(faiss_index_path, embeddings,allow_dangerous_deserialization=True).as_retriever()

# 검색 매개변수 설정 (예: 검색 결과 상위 10개 반환)
retriever_naver_yongsan.search_kwargs = {"k": 6}

# %%
# Step 1: FAISS 인덱스 파일 로드
faiss_index_path = "Faiss/opendata_gangnam_all"  # 저장된 Faiss 파일 경로
embeddings = OpenAIEmbeddings()  # 임베딩 객체 초기화

# 저장된 FAISS 인덱스를 불러와서 Retriever 생성
retriever_opendata_gangnam = FAISS.load_local(faiss_index_path, embeddings,allow_dangerous_deserialization=True).as_retriever()

# 검색 매개변수 설정 (예: 검색 결과 상위 10개 반환)
retriever_opendata_gangnam.search_kwargs = {"k": 10}

# %%
# Step 1: FAISS 인덱스 파일 로드
faiss_index_path = "Faiss/opendata_jongro_all"  # 저장된 Faiss 파일 경로
embeddings = OpenAIEmbeddings()  # 임베딩 객체 초기화

# 저장된 FAISS 인덱스를 불러와서 Retriever 생성
retriever_opendata_jongro = FAISS.load_local(faiss_index_path, embeddings,allow_dangerous_deserialization=True).as_retriever()

# 검색 매개변수 설정 (예: 검색 결과 상위 10개 반환)
retriever_opendata_jongro.search_kwargs = {"k": 10}

# %%
# Step 1: FAISS 인덱스 파일 로드
faiss_index_path = "Faiss/opendata_junggu_all"  # 저장된 Faiss 파일 경로
embeddings = OpenAIEmbeddings()  # 임베딩 객체 초기화

# 저장된 FAISS 인덱스를 불러와서 Retriever 생성
retriever_opendata_junggu = FAISS.load_local(faiss_index_path, embeddings,allow_dangerous_deserialization=True).as_retriever()

# 검색 매개변수 설정 (예: 검색 결과 상위 10개 반환)
retriever_opendata_junggu.search_kwargs = {"k": 10}

# %%
# Step 1: FAISS 인덱스 파일 로드
faiss_index_path = "Faiss/opendata_yongsan_all"  # 저장된 Faiss 파일 경로
embeddings = OpenAIEmbeddings()  # 임베딩 객체 초기화

# 저장된 FAISS 인덱스를 불러와서 Retriever 생성
retriever_opendata_yongsan = FAISS.load_local(faiss_index_path, embeddings,allow_dangerous_deserialization=True).as_retriever()

# 검색 매개변수 설정 (예: 검색 결과 상위 10개 반환)
retriever_opendata_yongsan.search_kwargs = {"k": 10}

# %%
from typing import Annotated, TypedDict, List
from langgraph.graph.message import add_messages


# GraphState 상태 정의
class GraphState(TypedDict):
    question: Annotated[List[str], add_messages]  # 질문(누적되는 list)
    context_naver_gangnam: Annotated[str, "context_naver_gangnam"]  # 문서의 검색 결과
    context_naver_jongro: Annotated[str, "context_naver_jongro"]  # 문서의 검색 결과
    context_naver_Junggu: Annotated[str, "context_naver_Junggu"]  # 문서의 검색 결과
    context_naver_yongsan: Annotated[str, "context_naver_yongsan"]  # 문서의 검색 결과
    context_opendata: Annotated[str, "context_opendata"]  # 문서의 검색 결과
    context_web: Annotated[str, "context_web"]  # 문서의 검색 결과
    answer_llm_Summary_gangnam: Annotated[str, "answer_llm_Summary_gangnam"]  # 답변
    answer_llm_Summary_junggu: Annotated[str, "answer_llm_Summary_junggu"]  # 답변
    answer_llm_Summary_jongro: Annotated[str, "answer_llm_Summary_jongro"]  # 답변
    answer_llm_Summary_yongsan: Annotated[str, "answer_llm_Summary_yongsan"]  # 답변
    answer_llm_Summary_opendata: Annotated[str, "answer_llm_Summary_opendata"]  # 답변
    answer: Annotated[str, "Answer"]  # 답변
    messages: Annotated[list, add_messages]  # 메시지(누적되는 list)
    webOrRetriever: Annotated[str, "webOrRetriever"]  # 웹 or 리트리버 검색
    ScheduleOrplace: Annotated[str, "ScheduleOrplace"]  # 일정 or 장소
    location: Annotated[str, "location"]  # 지역 리스트

# %%
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from operator import itemgetter
# 프롬프트
prompt = PromptTemplate(
    template="""너는 입력 받는 장소 정보의 데이터를 종합해서 서울의 관광 일정을 추천해주는 봇이야.
    추천 할 수 있는 지역은 종로구, 중구, 용산구, 강남구로 한정되어 있어.
    사용자의 질문에 따라서 여러가지 서울의 관광지, 식당, 숙소, 쇼핑몰 등을 추천해야해.
    사용자가 서울에 오는 이유에 대해 파악하고 그에 맞는 여행 일정을 추천해주면 돼.
    대화하다가 추천한 여행 일정이 사용자의 마음에 들지 않아서 변경해달라고 하면 마음에 들지 않은 부분을
    캐치하고 그 부분들만 수정해서 다시 추천해주면 돼.
    일정은 아침, 점심, 저녁, 식당을 추천해주고, 중간중간에 카페나, 명소, 거리등을 추천 해줬으면 좋겠어.

    여행 일정에 대한 동선이 짧도록 추천해줘.
    언어는 사용자가 입력한 언어를 기준으로 알려줘. 
    화폐 기준도 사용자가 입력한 언어를 사용하는 국가의 화폐를 기준으로 적용해줘.




    # 장소 정보: {context}

    #사용자의 질문: {question}
    
    #이전 대화 내용 {chat_history} 
    """,
        input_variables=["context", "question"],
    )

# LLM
model = ChatOpenAI(model_name="gpt-4o",
                    temperature=0, streaming=True)

chain = (
    {
        "question": itemgetter("question"),
        # "context_web": itemgetter("context_web"),
        "context": itemgetter("context"),
        "chat_history": itemgetter("chat_history"),
    }
    | prompt
    | model
    | StrOutputParser()
)

# %%
prompt_opendata_Summary = PromptTemplate(
    template="""너는 입력받은 내용을 요약해주는 봇이야.
    입력 받는 내용은 특정 장소의 특징을 알려주는 내용이야.

    요약은 다음과 같이 해줬으면 좋겠어.

    아래 항목에서 없는 데이터는 빼도 돼.

    - 장소 이름:
    - 위치 :
    - 전화번호 :
    - 웹사이트 URL :
    - 운영 날짜 및 시간:
    - 교통정보
    - 기타 편의 여부 :
    - 지원언어 :

    # 요약 해야할 내용: {answer_llm_Summary}


    """,
        input_variables=["answer_llm_Summary"],
    )


# LLM
model_summary = ChatOpenAI(model_name="gpt-4o-mini",
                    temperature=0, streaming=True)

chain_Summary_opendata = (
    # {
    #     "answer_llm_Summary": itemgetter("answer_llm_Summary_opendata")
    # }
    prompt_opendata_Summary
    | model_summary
    | StrOutputParser()
)

# %%
prompt_naver_Summary = PromptTemplate(
    template="""너는 입력받은 내용을 요약해주는 봇이야.
    입력 받는 내용은 특정 장소의 특징을 알려주는 내용이야.

    요약은 다음과 같이 해줬으면 좋겠어

       - "store_name": 
       - "category":  
       - "rating":  
       - "directions_text": 
       - "store_id": 
       - "address": 
       - "phone_num": 
       - "business_hours": 
       - "info": 
       - "convenience_facilities_and_services": 
       - "Parking": 
       - "sns": 
       - "store의 좋은점": 
       - "menu": 



    # 요약 해야할 내용: {answer_llm_Summary}


    """,
        input_variables=["answer_llm_Summary"],
    )


# LLM
model_summary = ChatOpenAI(model_name="gpt-4o-mini",
                    temperature=0, streaming=True)

chain_Summary_gangnam = (
    # {
    #     "answer_llm_Summary": itemgetter("answer_llm_Summary_gangnam")
    # }
    prompt_naver_Summary
    | model_summary
    | StrOutputParser()
)
chain_Summary_Junggu = (
    # {
    #     "answer_llm_Summary": itemgetter("answer_llm_Summary_junggu")
    # }
     prompt_naver_Summary
    | model_summary
    | StrOutputParser()
)
chain_Summary_jongro = (
    # {
    #     "answer_llm_Summary": itemgetter("answer_llm_Summary_jongro")
    # }
     prompt_naver_Summary
    | model_summary
    | StrOutputParser()
)
chain_Summary_yongsan = (
    # {
    #     "answer_llm_Summary": itemgetter("answer_llm_Summary_yongsan")
    # }
     prompt_naver_Summary
    | model_summary
    | StrOutputParser()
)

# %%
prompt_location = PromptTemplate(
    template="""너는 질문에 대해서 list를 반환해야돼.
    list에 들어갈 수 있는 str은 '용산구', '강남구', '중구', '종로구' 네가지가 있어.
    사용자가 질문을 하면 문장을 잘 보고 문장속의 지역을 추출해서 리스트에 넣어줘.
    만약 사용자의 질문에 '서울'을 방문 한다고 하면 리스트에 '용산구', '강남구', '중구', '종로구' 를 모두 넣어줘.
    사용자의 질문에 서울시가 아닌 다른지역을 물어보거나, 서울시에서도 '용산구', '강남구', '중구', '종로구'가 아닌 다른 지역을 물어보면 빈 리스트를 반환해.


    #입력 예시 : 1. 나는 서울시의 용산구를 방문 할거야 여행 계획을 세워 줄수 있어?, 
               2. 나는 종로구와 중구 일대를 방문하고 싶어 을지로는 꼭 가보고 싶은데 을지로 계획을 포함해서 여행 일정을 만들어 줄 수 있어?

    #대답 형식 예시 : ['종로구','강남구']

    #사용자의 질문: {question}


    #####
    예시 1:

    질문 : 나는 나는 전라남도 여행을 계획중이야. 일정을 만들어 줄 수 있어?  
    출력 : []
    #####

    #####
    예시 2:

    질문 : 나는 용산구와 종로구, 중구 일대를 관광하고 싶어 좋은 카페를 알고 싶은데 알려줄 수 있어?  
    출력 : ['용산구','중구','종로구']
    #####

    #####
    예시 3:

    질문 : 나는 서울시를 관광하고 싶어 1박2일 정도 방문하려고 하는데 일정을 만들어 줄 수 있어?
    출력 : ['용산구','중구','종로구','강남구']
    #####

    #####
    예시 4:

    질문 : 나는 종로구에서 맛있는 고기집을 찾고 있어. 찾아줘
    출력 : ['종로구']
    #####


    """,
        input_variables=["question"],
    )

model_location = ChatOpenAI(model_name="gpt-4o-mini",
                    temperature=0, streaming=True)

chain_location = (
    {
        "question": itemgetter("question"),
    }
    | prompt_location
    | model_location
    | StrOutputParser()
)

# %%
prompt_sch_or_placeSearch = PromptTemplate(
    template="""너는 질문에 대해서 두가지의 옵션으로 대답하는 봇이야.
    너의 대답은 '일정', '장소검색' 두가지로만 대답할 수 있어.
    사용자가 질문을 하면 문맥을 잘 살펴서 사용자가 여행일정을 만들어 달라고 하면 '일정' 이라고 대답해야돼.
    그렇지 않으면 '장소검색' 를 출력해줘.

    #'일정' 출력 예시 : 1. 나는 서울시의 용산구를 방문 할거야 여행 계획을 세워 줄수 있어?, 2. 나는 종로구와 중구 일대를 방문하고 싶어 을지로는 꼭 가보고 싶은데 을지로 계획을 포함해서 여행 일정을 만들어 줄 수 있어?

    #대답 형식 : '일정' or '장소검색'

    #사용자의 질문: {question}
    

    """,
        input_variables=["question"],
    )

model_sch_or_placeSearch = ChatOpenAI(model_name="gpt-4o-mini",
                    temperature=0, streaming=True)

chain_sch_or_placeSearch = (
    {
        "question": itemgetter("question"),
    }
    | prompt_sch_or_placeSearch
    | model_sch_or_placeSearch
    | StrOutputParser()
)

# %%
prompt_Web_or_retriever = PromptTemplate(
    template=""" 너는 사용자의 질문에 대해서 두가지의 옵션으로 대답하는 봇이야.
    너의 대답은 'web', 'retriever' 두가지로만 대답할 수 있어.
    사용자가 질문을 하면 문맥을 잘 살펴서 웹에서 정보를 검색하기를 원하면 'web' 이라고 대답해야돼.
    그렇지 않으면 'retriever' 를 출력해줘. 

    #대답 형식 : 'web' or 'retriever'

    #사용자의 질문: {question}
    

    """,
        input_variables=["question"],
    )
model_web_check = ChatOpenAI(model_name="gpt-4o-mini",
                    temperature=0, streaming=True)

chain_Web_or_retriever = (
    {
        "question": itemgetter("question"),
    }
    | prompt_Web_or_retriever
    | model_web_check
    | StrOutputParser()
)

# %%
prompt_web = PromptTemplate(
    template="""너는 웹 검색을 통한 {context_web}의 내용를 종합해서 서울시의 중구,종로구,용산구,강남구 관광 일정을 추천해주는 봇이야.
    사용자의 질문에 따라서 여러가지 서울의 관광지, 식당, 숙소, 쇼핑몰 등을 추천해야해.
    처음에 사용자가 서울에 며칠동안 머무르는지 물어보고, 그에 따라서 관광 일정을 추천해주면 돼.
    그 다음 사용자가 서울에 오는 이유에 대해 파악하고 그에 맞는 여행 일정을 추천해주면 돼.
    대화하다가 추천한 여행 일정이 사용자의 마음에 들지 않아서 변경해달라고 하면 마음에 들지 않은 부분을
    캐치하고 그 부분들만 수정해서 다시 추천해주면 돼.
    일정 중간 중간 숙소나 식당, 쇼핑몰 등을 추천해주면 돼.

    어떤 장소가 궁금해서 물어본다면 특정 장소의 정보들을 정확하게 알려줘.
    (예:가게 정보, 메뉴, 별점, 위치, 연락처, 운영 시간, 리뷰 등)
    여행 일정에 대한 동선이 짧도록 추천해줘.
    언어는 사용자가 입력한 언어를 기준으로 알려줘. 
    화폐 기준도 사용자가 입력한 언어를 사용하는 국가의 화폐를 기준으로 적용해줘.


    - 너가 제공한 내용의 출처를 링크로 남겨줘

    # 웹 검색 정보 : {context_web}

    #사용자의 질문: {question}
    
    #이전 대화 내용 {chat_history} 
    """,
        input_variables=["context_web", "question"],
    )
#input_variables=["context_web","context_opendata","context_naver", "question"],
# LLM
model_web = ChatOpenAI(model_name="gpt-4o",
                    temperature=0, streaming=True)

chain_web = (
    {
        "question": itemgetter("question"),
        "context_web": itemgetter("context_web"),
        # "context_opendata": itemgetter("context_opendata"),
        # "context_naver": itemgetter("context_naver"),
        "chat_history": itemgetter("chat_history"),
    }
    | prompt_web
    | model_web
    | StrOutputParser()
)

# %%
from langchain_teddynote.messages import messages_to_history
from langchain_teddynote.tools.tavily import TavilySearch
import ast

# from rag.utils import format_docs
# 웹 검색 or 리트리버 검색
def web_or_retriever_check(state: GraphState) -> GraphState:
    # 관련성 체크를 실행("yes" or "no")
    response = chain_Web_or_retriever.invoke(
        {"question": state["question"][-1].content}
    )

    return {"webOrRetriever": response}

# 웹 리트리버 분기 체크하는 함수(router)
def is_web(state: GraphState) -> GraphState:
    if state["webOrRetriever"] == "web":
        return "web"
    else:
        return "retriever"

# 장소검색 or 일정 검색
def Schedule_or_place_check(state: GraphState) -> GraphState:
    # 관련성 체크를 실행("yes" or "no")
    response = chain_sch_or_placeSearch.invoke(
        {"question": state["question"][-1].content}
    )

    return {"ScheduleOrplace": response}


# 일정 장소검색 리트리버 분기 체크하는 함수(router)
def is_place(state: GraphState) -> GraphState:
    if state["ScheduleOrplace"] == "일정":
        return "일정"
    else:
        return "장소검색"
    
# 지역 판별
def location_check(state: GraphState) -> GraphState:
    # 관련성 체크를 실행("yes" or "no")
    response = chain_location.invoke(
        {"question": state["question"][-1].content}
    )

    return {"location": response}

    
# 문서 검색 노드--------------------------------------------------------------------------------------------------------------------------
def retrieve_document_naver_gangnam(state: GraphState) -> GraphState:
    # 질문을 상태에서 가져옵니다.
    latest_question = state["question"][-1].content

    # 문서에서 검색하여 관련성 있는 문서를 찾습니다.
    retrieved_docs = retriever_naver_gangnam.invoke(latest_question)

    # 검색된 문서를 형식화합니다.(프롬프트 입력으로 넣어주기 위함)
    retrieved_docs = "\n".join(
        [
            f"<document><content>{doc.page_content}</content>"
            for doc in retrieved_docs
        ]
    )
        # 검색된 문서를 context 키에 저장합니다.
    return {"context_naver_gangnam": retrieved_docs}

def retrieve_document_naver_jongro(state: GraphState) -> GraphState:
    # 질문을 상태에서 가져옵니다.
    latest_question = state["question"][-1].content

    # 문서에서 검색하여 관련성 있는 문서를 찾습니다.
    retrieved_docs = retriever_naver_jongro.invoke(latest_question)

    # 검색된 문서를 형식화합니다.(프롬프트 입력으로 넣어주기 위함)
    retrieved_docs = "\n".join(
        [
            f"<document><content>{doc.page_content}</content>"
            for doc in retrieved_docs
        ]
    )
        # 검색된 문서를 context 키에 저장합니다.
    return {"context_naver_jongro": retrieved_docs}

def retrieve_document_naver_Junggu(state: GraphState) -> GraphState:
    # 질문을 상태에서 가져옵니다.
    latest_question = state["question"][-1].content

    # 문서에서 검색하여 관련성 있는 문서를 찾습니다.
    retrieved_docs = retriever_naver_Junggu.invoke(latest_question)

    # 검색된 문서를 형식화합니다.(프롬프트 입력으로 넣어주기 위함)
    retrieved_docs = "\n".join(
        [
            f"<document><content>{doc.page_content}</content>"
            for doc in retrieved_docs
        ]
    )
        # 검색된 문서를 context 키에 저장합니다.
    return {"context_naver_Junggu": retrieved_docs}

def retrieve_document_naver_yongsan(state: GraphState) -> GraphState:
    # 질문을 상태에서 가져옵니다.
    latest_question = state["question"][-1].content

    # 문서에서 검색하여 관련성 있는 문서를 찾습니다.
    retrieved_docs = retriever_naver_yongsan.invoke(latest_question)

    # 검색된 문서를 형식화합니다.(프롬프트 입력으로 넣어주기 위함)
    retrieved_docs = "\n".join(
        [
            f"<document><content>{doc.page_content}</content>"
            for doc in retrieved_docs
        ]
    )
    # 검색된 문서를 context 키에 저장합니다.
    return {"context_naver_yongsan": retrieved_docs}


#------------------------------------------------------------------------------------------------------------------------------------------------


def retrieve_document_opendata(state: GraphState) -> GraphState:
    # 질문을 상태에서 가져옵니다.
    latest_question = state["question"][-1].content
    location_str = state['location']

    location = ast.literal_eval(location_str)

    doc_list = []
    # 문서에서 검색하여 관련성 있는 문서를 찾습니다.
    yongsan = '용산구'
    jonglo = '종로구'
    gangman = '강남구'
    junggu = '중구'
    retrieved_docs_yongsan = []
    retrieved_docs_jongro = []
    retrieved_docs_gangman = []
    retrieved_docs_junggu = []

    if yongsan in location:
        retrieved_docs_yongsan = retriever_opendata_yongsan.invoke(latest_question)

    if jonglo in location:
        retrieved_docs_jongro = retriever_opendata_jongro.invoke(latest_question)

    if gangman in location:
        retrieved_docs_gangman = retriever_opendata_gangnam.invoke(latest_question)

    if junggu in location:
        retrieved_docs_junggu = retriever_opendata_junggu.invoke(latest_question)

 
    doc_list.extend(retrieved_docs_yongsan)
    doc_list.extend(retrieved_docs_jongro)
    doc_list.extend(retrieved_docs_gangman)
    doc_list.extend(retrieved_docs_junggu)

    # 검색된 문서를 형식화합니다.(프롬프트 입력으로 넣어주기 위함)
    retrieved_docs = "\n".join(
        [
            f"<document><content>{doc.page_content}</content>"
            for doc in doc_list
        ]
)

    # 검색된 문서를 context 키에 저장합니다.
    return {"context_opendata": retrieved_docs}

# 요약 생성 노드----------------------------------------------------------------------------
def llm_Summary_gangnam(state: GraphState) -> GraphState:
    loc = '강남구'
    location_str = state['location']

    location = ast.literal_eval(location_str)

    if loc not in location:
        return {
        "answer_llm_Summary_gangnam": 'none'
             } 
    
    # 검색된 문서를 상태에서 가져옵니다.
    context_naver = state["context_naver_gangnam"]

    # 체인을 호출하여 답변을 생성합니다.
    response = chain_Summary_gangnam.invoke(
        {
            "answer_llm_Summary": context_naver,
        }
    )
    # 생성된 답변, (유저의 질문, 답변) 메시지를 상태에 저장합니다.
    return {
        "answer_llm_Summary_gangnam": response
    } 
def llm_Summary_jongro(state: GraphState) -> GraphState:
    loc = '종로구'
    location_str = state['location']

    location = ast.literal_eval(location_str)

    if loc not in location:
        return {
        "answer_llm_Summary_jongro": 'none'
             } 
    # 검색된 문서를 상태에서 가져옵니다.
    context_naver = state["context_naver_jongro"]

    # 체인을 호출하여 답변을 생성합니다.
    response = chain_Summary_jongro.invoke(
        {
            "answer_llm_Summary": context_naver,
        }
    )
    # 생성된 답변, (유저의 질문, 답변) 메시지를 상태에 저장합니다.
    return {
        "answer_llm_Summary_jongro": response
    } 

def llm_Summary_Junggu(state: GraphState) -> GraphState:
    loc = '중구'
    location_str = state['location']

    location = ast.literal_eval(location_str)

    if loc not in location:
        return {
        "answer_llm_Summary_junggu": 'none'
             } 
    # 검색된 문서를 상태에서 가져옵니다.
    context_naver = state["context_naver_Junggu"]

    # 체인을 호출하여 답변을 생성합니다.
    response = chain_Summary_Junggu.invoke(
        {
            "answer_llm_Summary": context_naver,
        }
    )
    # 생성된 답변, (유저의 질문, 답변) 메시지를 상태에 저장합니다.
    return {
        "answer_llm_Summary_junggu": response
    } 
def llm_Summary_yongsan(state: GraphState) -> GraphState:
    
    loc = '용산구'
    location_str = state['location']

    location = ast.literal_eval(location_str)

    if loc not in location:
        return {
        "answer_llm_Summary_yongsan": 'none'
             } 
    # 검색된 문서를 상태에서 가져옵니다.
    context_naver = state["context_naver_yongsan"]

    # 체인을 호출하여 답변을 생성합니다.
    response = chain_Summary_yongsan.invoke(
        {
            "answer_llm_Summary": context_naver,
        }
    )
    # 생성된 답변, (유저의 질문, 답변) 메시지를 상태에 저장합니다.
    return {
        "answer_llm_Summary_yongsan": response
    } 

def llm_Summary_opendata(state: GraphState) -> GraphState:

    # 검색된 문서를 상태에서 가져옵니다.
    context_opendata = state["context_opendata"]

    # 체인을 호출하여 답변을 생성합니다.
    response = chain_Summary_opendata.invoke(
        {
            "answer_llm_Summary": context_opendata,
        }
    )
    # 생성된 답변, (유저의 질문, 답변) 메시지를 상태에 저장합니다.
    return {
        "answer_llm_Summary_opendata": response
    } 


# 요약 생성 노드 끝----------------------------------------------------------------------------



# 일정 생성 노드----------------------------------------------------------------------------

def llm_Schedule_answer(state: GraphState) -> GraphState:
    # 질문을 상태에서 가져옵니다.
    latest_question = state["question"][-1].content
    location_str = state['location']

    location = ast.literal_eval(location_str)

    Summary_list = []
    Summary_yongsan =[]
    Summary_jongro =[]
    Summary_gangman =[]
    Summary_junggu =[]
    # 문서에서 검색하여 관련성 있는 문서를 찾습니다.
    yongsan = '용산구'
    jonglo = '종로구'
    gangman = '강남구'
    junggu = '중구'

    if yongsan in location:
        Summary_yongsan = state["answer_llm_Summary_yongsan"]

    if jonglo in location:
        Summary_jongro = state["answer_llm_Summary_jongro"]

    if gangman in location:
        Summary_gangman = state["answer_llm_Summary_gangnam"]

    if junggu in location:
        Summary_junggu = state["answer_llm_Summary_junggu"]

   
    Summary_opendata = state["answer_llm_Summary_opendata"]

 
    Summary_list.extend(Summary_yongsan)
    Summary_list.extend(Summary_jongro)
    Summary_list.extend(Summary_gangman)
    Summary_list.extend(Summary_junggu)
    Summary_list.extend(Summary_opendata)

    # 검색된 문서를 형식화합니다.(프롬프트 입력으로 넣어주기 위함)
    retrieved_docs = "\n".join(
        [
            f"{doc}"
            for doc in Summary_list
        ]
    )

    # 체인을 호출하여 답변을 생성합니다.
    response = chain.invoke(
        {
            "question": latest_question,
            "context": retrieved_docs,
            "chat_history": messages_to_history(state["messages"]),
        }
    )
    # 생성된 답변, (유저의 질문, 답변) 메시지를 상태에 저장합니다.
    print(state["messages"])
    return {
        "answer": response,
        "messages": [("user", latest_question), ("assistant", response)],
    }
# 일정 생성 노드 끝----------------------------------------------------------------------------


# 웹 검색 답변 생성 노드
def llm_answer_web(state: GraphState) -> GraphState:
    # 질문을 상태에서 가져옵니다.
    latest_question = state["question"][-1].content
    # 검색된 문서를 상태에서 가져옵니다.
    # context_naver = state["context_naver"]
    # context_opendata = state["context_opendata"]
    context_web = state["context_web"]

    # 체인을 호출하여 답변을 생성합니다.
    response = chain_web.invoke(
        {
            "question": latest_question,
            "context_web": context_web,
            # "context_naver": context_naver,
            # "context_opendata": context_opendata,
            "chat_history": messages_to_history(state["messages"]),
        }
    )
    # 생성된 답변, (유저의 질문, 답변) 메시지를 상태에 저장합니다.
    print(state["messages"])
    return {
        "answer": response,
        "messages": [("user", latest_question), ("assistant", response)],
    }

# Web Search 노드
def web_search(state: GraphState) -> GraphState:
    # 검색 도구 생성
    tavily_tool = TavilySearch()

    search_query = state["question"][-1].content

    # 다양한 파라미터를 사용한 검색 예제
    search_result = tavily_tool.search(
        query=search_query,  # 검색 쿼리
        topic="general",  # 일반 주제
        max_results=2,  # 최대 검색 결과
        format_output=True,  # 결과 포맷팅
    )

    return {"context_web": search_result}


def query_rewrite(state: GraphState) -> GraphState:
    latest_question = state["question"][-1].content
    question_rewritten = question_rewriter.invoke({"question": latest_question})
    return {"question": question_rewritten}

# %%
from langgraph.graph import END, StateGraph
from langgraph.checkpoint.memory import MemorySaver

# 그래프 생성
workflow = StateGraph(GraphState)

# 노드 정의
workflow.add_node("location_check", location_check)
workflow.add_node("retrieve_document_naver_gangnam", retrieve_document_naver_gangnam)
workflow.add_node("retrieve_document_naver_jongro", retrieve_document_naver_jongro)
workflow.add_node("retrieve_document_naver_Junggu", retrieve_document_naver_Junggu)
workflow.add_node("retrieve_document_naver_yongsan", retrieve_document_naver_yongsan)
workflow.add_node("retrieve_opendata", retrieve_document_opendata)
workflow.add_node("llm_Summary_gangnam", llm_Summary_gangnam)
workflow.add_node("llm_Summary_Junggu", llm_Summary_Junggu)
workflow.add_node("llm_Summary_yongsan", llm_Summary_yongsan)
workflow.add_node("llm_Summary_opendata", llm_Summary_opendata)
workflow.add_node("llm_Summary_jongro", llm_Summary_jongro)
workflow.add_node("llm_Schedule_answer", llm_Schedule_answer)
# workflow.add_node("llm_answer_web", llm_answer_web)
# workflow.add_node("web_search", web_search)
# workflow.add_node("web_Or_Retriever", web_or_retriever_check)

# 엣지 정의
# workflow.add_conditional_edges(
#     "web_Or_Retriever",  # 관련성 체크 노드에서 나온 결과를 is_relevant 함수에 전달합니다.
#     is_web,
#     {
#         "web": "web_search",  # 웹 검색을 요청하면 웹검색을 합니다
#         "retriever": "query_rewrite",  # 아니면 리트리버
#     },
# )

workflow.add_edge("location_check", "retrieve_document_naver_gangnam")  # 검색 -> 답변
workflow.add_edge("location_check", "retrieve_document_naver_jongro")  # 검색 -> 답변
workflow.add_edge("location_check", "retrieve_document_naver_Junggu")  # 검색 -> 답변
workflow.add_edge("location_check", "retrieve_document_naver_yongsan")  # 검색 -> 답변
workflow.add_edge("location_check", "retrieve_opendata")  # 검색 -> 답변
workflow.add_edge("retrieve_document_naver_gangnam", "llm_Summary_gangnam")  # 질문 -> 검색
workflow.add_edge("retrieve_document_naver_Junggu", "llm_Summary_Junggu")  # 질문 -> 검색
workflow.add_edge("retrieve_document_naver_yongsan", "llm_Summary_yongsan")  
workflow.add_edge("retrieve_opendata", "llm_Summary_opendata") 
workflow.add_edge("retrieve_document_naver_jongro", "llm_Summary_jongro") 
workflow.add_edge("llm_Summary_opendata", "llm_Schedule_answer") 
workflow.add_edge("llm_Summary_gangnam", "llm_Schedule_answer") 
workflow.add_edge("llm_Summary_Junggu", "llm_Schedule_answer") 
workflow.add_edge("llm_Summary_yongsan", "llm_Schedule_answer") 
workflow.add_edge("llm_Summary_jongro", "llm_Schedule_answer") 

workflow.add_edge("llm_Schedule_answer", END)  # 답변 -> 종료

# 그래프 진입점 설정
workflow.set_entry_point("location_check")

# 체크포인터 설정
memory = MemorySaver()

# 컴파일
app = workflow.compile(checkpointer=memory)

# %%
from langchain_teddynote.graphs import visualize_graph

visualize_graph(app)

# %%
from langchain_core.runnables import RunnableConfig
from langchain_teddynote.messages import invoke_graph, stream_graph, random_uuid

# config 설정(재귀 최대 횟수, thread_id)
config = RunnableConfig(recursion_limit=20, configurable={"thread_id": random_uuid()})

# %%
inputs = GraphState(question="내가 직전에 한 질문이 뭐였지")

# %%
res
# Out:
# {'question': [HumanMessage(content='종로구에 1박2일 여행 일정을 만들어 줄 수 있어?', additional_kwargs={}, response_metadata={}, id='5e4805ad-054a-48bd-8fbb-dba4f26150aa'),
#   HumanMessage(content='종로구에서 1박 2일 여행 일정을 어떻게 구성할 수 있을까?', additional_kwargs={}, response_metadata={}, id='9c4cc664-808b-47fb-bf8e-1d6a045fe175'),
#   HumanMessage(content='종로구에 1박2일 여행 일정을 만들어 줄 수 있어?', additional_kwargs={}, response_metadata={}, id='50f84474-5700-4423-bc20-794b9630ade4'),
#   HumanMessage(content='종로구에서 1박 2일 여행 일정을 추천해 줄 수 있나요?', additional_kwargs={}, response_metadata={}, id='164828ac-71c4-46e8-89f5-e2a08f3f0713'),
#   HumanMessage(content='이번에는 용산구와 중구에서의 일정을 만들어줘', additional_kwargs={}, response_metadata={}, id='5293615c-ab42-4eba-aec0-075bab855fd2'),
#   HumanMessage(content='용산구와 중구에서의 일정 계획을 어떻게 세울 수 있을까요?', additional_kwargs={}, response_metadata={}, id='7dce6d2f-d201-4294-bc8d-9c44e1e46f51'),
#   HumanMessage(content='내가 직전에 한 질문이 뭐였지', additional_kwargs={}, response_metadata={}, id='1169dd59-6f0e-4870-a823-77bb497cf551'),
#   HumanMessage(content='내가 이전에 한 질문은 무엇인가요?', additional_kwargs={}, response_metadata={}, id='655e7137-a5a2-4a9f-ae9c-f9c678e868b1')],
#  'context_naver': '<document><content>store_name: 옛날국시 \n category: 국수 \n new_open:   \n rating: 별점 4.33 \n visited_review: 방문자 리뷰 514 \n directions_text: 이태원역과 녹사평역 중간에 위치해 있으며 이태원시장 뒤에 위치해 있습니다. (이태원역에서 도보로 7분 정도 소요) \n store_id: 36615227 \n address: 서울 용산구 녹사평대로32길 20-1 \n blog_review: 블로그 리뷰 107 \n phone_num: 02-798-7997 \n business_hours: 월\n10:00 - 19:00\n18:50 라스트오더\n화\n10:00 - 19:00\n18:50 라스트오더\n수(1/1)\n새해 첫날 휴무\n목\n10:00 - 19:00\n18:50 라스트오더\n금\n10:00 - 19:00\n18:50 라스트오더\n토\n10:00 - 19:00\n18:50 라스트오더\n일\n정기휴무 (매주 일요일)\n \n info: 옛 우리네 어머니의 손맛이 생각나게 하는 음식들이 준비되어 있습니다. \n convenience_facilities_and_services: 포장\n배달\n \n Parking: 주차 정보없음 \n sns: http://www.instagram.com/yetnalgooksi\n \n review_like_this_part_output: "음식이 맛있어요"이 키워드를 선택한 인원211\n"가성비가 좋아요"이 키워드를 선택한 인원78\n"양이 많아요"이 키워드를 선택한 인원57\n"혼밥하기 좋아요"이 키워드를 선택한 인원54\n"재료가 신선해요"이 키워드를 선택한 인원40\n"친절해요"이 키워드를 선택한 인원38\n"특별한 메뉴가 있어요"이 키워드를 선택한 인원37\n"매장이 넓어요"이 키워드를 선택한 인원12\n"매장이 청결해요"이 키워드를 선택한 인원9\n"인테리어가 멋져요"이 키워드를 선택한 인원6\n"단체모임 하기 좋아요"이 키워드를 선택한 인원3\n"화장실이 깨끗해요"이 키워드를 선택한 인원3\n"뷰가 좋아요"이 키워드를 선택한 인원3\n"건강한 맛이에요"이 키워드를 선택한 인원1\n \n menu: 메밀소바10,000원\n꼬마김밥(1인분 8개)8,000원\n잔치국수8,000원\n비빔국수8,000원\n김치수제비/김치칼국수10,000원\n들깨수제비/칼국수10,000원\n해물수제비/칼국수10,000원\n해물순두부 찌개8,000원\n냉메밀소바(하절기)10,000원\n해물카레순두부/해물순두부10,000원\n묵밥8,000원\n무말랭이 1봉6,000원\n매실간장절임고 1통6,000원\n깻잎 1통6,000원\n</content>\n<document><content>store_name: 옛날농장 논현점 \n category: 육류,고기요리 \n new_open:   \n rating: 별점 4.57 \n visited_review: 방문자 리뷰 614 \n directions_text: <찾아오시는길>\n논현역 3번출구로 나와 250M (도보 3분)\n신논현역 3번출구에서 나와 330M (도보 5분) 만 걸으면 옛날농장 입니다.\n신논현역 주변에서 쇼핑 하시고! 5분만 걸어오시면 <20년 전통 숯불갈비 전문점 > 옛날농장에서 맛있는 만날수 있습니다.\n\n<주차장 안내 2시간 주차할인>\n서울특별시 강남구 논현동 163-11 (명성주차장)\n\n명성주차장 이용시 2시간 3000원에 주차가능합니다.\n매장 식사후 주차권에 도장 꼭!!! 받아가셔야 할인적용 됩니다.\n\n명성주차장 만차시\n논현초등학교 공영주차장 이용부탁 드립니다.\n주소: 서울특별시 강남구 강남대로 120길 33\n\n연인, 친구, 가족,동료와 함께하는 특별한 날에는!\n옛날농장에서 숯불 양념갈비를 포함한 맛있는 음식들로 좋은시간 보내세요!\n내용 더보기 \n store_id: 1845236311 \n address: 서울 강남구 학동로2길 57 1층 2층 \n blog_review: 블로그 리뷰 1,079 \n phone_num: 0507-1358-7758 \n business_hours: 월\n00:00 - 24:00\n화\n00:00 - 24:00\n수\n00:00 - 24:00\n목\n00:00 - 24:00\n금\n00:00 - 24:00\n토\n00:00 - 24:00\n일\n00:00 - 24:00\n \n info: 우리의 맛과 멋을 이어가는 옛날농장입니다.\n20년전통의 숯불갈비 고깃집 점입니다.\n강남 24시 맛집으로 자리잡기위해 노력중입니다.\n저희의 삼겹살과 목살은 녹차를 먹여 키운 프리미엄 돼지인 보성녹돈을 사용합니다.\n소고기또한 좋은 원육의 차별화된 부드러움과 지방의 고소함을 느껴보세요.\n\n점심시간이 기다려지는 다양한 한식 점심식사 메뉴도 준비되어 있습니다.\n\n논현역 최고 시설로 쾌적한 식사를 위해 하향식 후드 설치로 연기가 최대한 아래로 빨려가도록 설비하였습니다.\n\n단체석 완비로 후회없는 회식, 모임 준비하도록 하겠습니다.\n\n주차는 자주식 주차장이며 매장에서 논현역 방면으로 50m 직진하면 명성 주차장에 주차하시고 도장받아가시면 2시간에 3300원입니다.\n(만차시 논현초등학교 공영주차장 이용 부탁드립니다.)\n\n옛날 농장은 정성이 담긴 맛있는 음식과 신선한 식재료를 사용하여\n강남24시 고깃집 중 최고 맛집을 목표로 고객님들을 대접하겠습니다.\n\n감사합니다.\n펼쳐보기 \n convenience_facilities_and_services: 단체 이용 가능\n예약\n포장\n남/녀 화장실 구분\n무선 인터넷\n배달\n \n Parking: 주차가능 \n sns: nan \n review_like_this_part_output: "음식이 맛있어요"이 키워드를 선택한 인원275\n"친절해요"이 키워드를 선택한 인원115\n"매장이 넓어요"이 키워드를 선택한 인원86\n"고기 질이 좋아요"이 키워드를 선택한 인원77\n"가성비가 좋아요"이 키워드를 선택한 인원65\n"매장이 청결해요"이 키워드를 선택한 인원59\n"단체모임 하기 좋아요"이 키워드를 선택한 인원56\n"재료가 신선해요"이 키워드를 선택한 인원53\n"양이 많아요"이 키워드를 선택한 인원53\n"특별한 메뉴가 있어요"이 키워드를 선택한 인원39\n"혼밥하기 좋아요"이 키워드를 선택한 인원15\n"반찬이 잘 나와요"이 키워드를 선택한 인원11\n"인테리어가 멋져요"이 키워드를 선택한 인원10\n"특별한 날 가기 좋아요"이 키워드를 선택한 인원8\n"주차하기 편해요"이 키워드를 선택한 인원7\n"잡내가 적어요"이 키워드를 선택한 인원6\n"메뉴 구성이 알차요"이 키워드를 선택한 인원6\n"화장실이 깨끗해요"이 키워드를 선택한 인원6\n"음식이 빨리 나와요"이 키워드를 선택한 인원3\n"직접 잘 구워줘요"이 키워드를 선택한 인원3\n"뷰가 좋아요"이 키워드를 선택한 인원3\n"아늑해요"이 키워드를 선택한 인원2\n"오래 머무르기 좋아요"이 키워드를 선택한 인원2\n"좌석이 편해요"이 키워드를 선택한 인원1\n"컨셉이 독특해요"이 키워드를 선택한 인원1\n"비싼 만큼 가치있어요"이 키워드를 선택한 인원1\n"건강한 맛이에요"이 키워드를 선택한 인원1\n"환기가 잘 돼요"이 키워드를 선택한 인원1\n \n menu: 명품수제돼지갈비대표옛날농장 20년 전통 양념으로 만든 돼지갈비입니다.19,000원\n설화 꽃갈비살대표최고등급의 소 6,7,8 번 갈비대에서 나오는 꽃갈비살입니다.\n최고의 맛을 선사합니다34,000원\n통삼겹살대표좋은 원육으로 승부보는 삼겹살이 최고입니다!16,000원\n명품 소 양념갈비20년 전통 옛날농장 소양념갈비입니다.33,000원\n차돌박이20,000원\n소갈빗살숯불에 구워먹는 갈비살 입니다.\n맛있는 양념갈비살도 준비되어 있습니다.20,000원\n보성녹돈 특목살16,000원\n오돌갈비17,000원\n한라산 황제살18,000원\n명품 소고기 해장국9,000원\n낙곱새 뚝배기11,000원\n생고기김치찌개9,000원\n뚝배기 불고기9,000원\n차돌된장찌개9,000원\n고추장 돼지불백11,000원\ ...
#  'context_opendata': '<document><content>상호명: 나전과 옻칠\u3000\u3000 \n 콘텐츠URL: https://korean.visitseoul.net/entertainment/나전과-옻칠/KOP018888?utm_source=seoulopendata&utm_medium=entertainment&utm_content=KOP018888 \n 주소: 110-800 서울 종로구 계동 25  \n 신주소: 03057 서울 종로구 계동4길 3 (계동)  \n 전화번호: 070-8860-9880\u3000 \n 웹사이트: https://blog.naver.com/krhg252017 \n 운영시간: 11:00~17:00 \n 운영요일: 월요일~토요일 \n 휴무일: 일요일 \n 교통정보: 3호선 안국역 3번 출구에서 약 635m (도보 10분)  \n 홈페이지 운영 언어: 한국어 \n 유모차 대여 여부: nan</content>\n<document><content>상호: 나를위한 산부인과의원 \n 대표자: 이은정 \n 기관구분: 의원 \n 주소: 서울특별시 강남구 강남대로 364 (역삼동, 미왕빌딩) 9층 나를위한 산부인과의원 \n 타겟국가: 미국/일본/중국/러시아/중동/몽골/베트남</content>\n<document><content>상호: 처음처럼성형외과의원 \n 대표자: 이방석 \n 기관구분: 의원 \n 주소: 서울특별시 강남구 테헤란로 111 (역삼동, 대건빌딩) 8층 처음처럼성형외과 (역삼동,대건빌딩) \n 타겟국가: 일본/중국/기타</content>\n<document><content>상호: 프린스성형외과의원 \n 대표자: 박신기 \n 기관구분: 의원 \n 주소: 서울특별시 강남구 도산대로 104 (논현동, 1st Avenue) 2층, 프린스 성형외과 \n 타겟국가: 미국/일본/중국/러시아/중동/몽골/베트남/기타</content>\n<document><content>상호: 케이앤에스성형외과의원 \n 대표자: 김영수 \n 기관구분: 의원 \n 주소: 서울특별시 강남구 봉은사로 140 (역삼동,마에스트로빌딩지하1층,1층,2층) \n 타겟국가: 미국,일본,중국,러시아,중동,몽골,베트남,</content>\n<document><content>상호: 케이플러스성형외과의원 \n 대표자: 김세영 \n 기관구분: 의원 \n 주소: 서울특별시 강남구 도산대로 333 (신사동, K+ 메디칼타워) 14,15층 케이플러스성형외과 \n 타겟국가: 미국/일본/중국/러시아/중동/몽골/베트남/기타</content>\n<document><content>상호: 어제오늘 성형외과 \n 대표자: 윤형노 \n 기관구분: 의원 \n 주소: 우편번호 : 135-825 서울시 강남구 학동로 6길 42. 4층 \n 타겟국가: 일본,중국,몽골,</content>\n<document><content>상호: 문의원 \n 대표자: 박문수 \n 기관구분: 의원 \n 주소: 서울특별시 강남구 논현로168길 40 (신사동, 레아트문클리닉 타워) 2,3층 문의원 \n 타겟국가: 일본/중국</content>\n<document><content>상호: 케이아트성형외과의원 \n 대표자: 김남복 \n 기관구분: 의원 \n 주소: 서울특별시 강남구 논현로 831 (신사동, 네오스) 동아빌딩 3층  케이아트 성형외과 \n 타겟국가: 미국/일본/중국/러시아/중동/몽골/베트남/기타</content>\n<document><content>상호: 아이팅성형외과의원 \n 대표자: 김종규 \n 기관구분: 의원 \n 주소: 서울특별시 강남구 논현로175길 6 (신사동) 로얄빌딩 2층 아이팅성형외과 \n 타겟국가: 미국/일본/중국/몽골/베트남</content>',
#  'answer': '용산구와 중구에서의 일정 계획을 세워드릴게요. 두 지역은 서울의 중심부에 위치해 있어 다양한 문화와 역사를 경험할 수 있는 곳입니다. 아래는 추천 일정입니다.\n\n### 1일차: 용산구\n\n**오전**\n- **국립중앙박물관**: 한국의 역사와 문화를 깊이 있게 이해할 수 있는 국립중앙박물관을 방문하세요. 다양한 전시와 유물들이 있습니다. (운영시간: 10:00~18:00)\n\n**점심**\n- **이태원**: 다양한 국제 요리를 즐길 수 있는 이태원에서 점심을 드세요. 여러 나라의 음식을 맛볼 수 있는 곳입니다.\n\n**오후**\n- **용산 전쟁기념관**: 한국 전쟁의 역사를 배울 수 있는 전쟁기념관을 방문하세요. (운영시간: 09:00~18:00)\n- **성수미술관 용산점**: 삼각지역 근처에 위치한 성수미술관에서 드로잉 체험을 즐기며 여유로운 시간을 보내세요. (운영시간: 12:00~21:30)\n\n**저녁**\n- **남산타워**: 서울의 야경을 감상할 수 있는 남산타워를 방문하세요. 케이블카를 타고 올라가면 더욱 특별한 경험이 될 것입니다.\n\n### 2일차: 중구\n\n**오전**\n- **덕수궁**: 조선 시대의 궁궐인 덕수궁을 방문하여 한국의 전통 건축을 감상하세요. (운영시간: 09:00~18:00)\n\n**점심**\n- **죽이야기 서울 중구소공점**: 건강한 한식을 제공하는 죽이야기에서 전복죽이나 다양한 죽 메뉴를 즐기세요. (운영시간: 08:00~16:00)\n\n**오후**\n- **명동 쇼핑 거리**: 다양한 브랜드와 상점이 모여 있는 명동에서 쇼핑을 즐기세요.\n- **청계천 헌책방 거리**: 을지로에 위치한 청계천 헌책방 거리에서 다양한 헌책과 독특한 아이템을 구경하세요.\n\n**저녁**\n- **어슬 서울**: 서울역 근처에 위치한 어슬 서울에서 퓨전 한식과 전통주를 즐기며 하루를 마무리하세요. (운영시간: 11:30~23:00)\n\n이 일정은 용산구와 중구의 주요 명소를 중심으로 구성되었습니다. 각 장소의 운영 시간과 위치를 확인하시고, 이동 시간을 고려하여 일정을 조정하시면 좋습니다. 즐거운 여행 되세요!',
#  'messages': [HumanMessage(content='종로구에서 1박 2일 여행 일정을 추천해 줄 수 있나요?', additional_kwargs={}, response_metadata={}, id='af83e222-371a-4ecf-9889-ab58886ca325'),
#   AIMessage(content='종로구에서의 1박 2일 여행 일정을 추천해드릴게요. 종로구는 서울의 역사와 문화를 느낄 수 있는 곳으로, 다양한 관광 명소와 맛집이 많습니다. 아래는 추천 일정입니다.\n\n### 1일차\n\n**오전**\n- **북촌한옥마을**: 전통 한옥이 모여 있는 북촌한옥마을을 산책하며 한국의 전통 건축을 감상하세요. 사진 찍기 좋은 장소입니다.\n- **전통공예체험관**: 북촌한옥마을 근처에 위치한 전통공예체험관에서 한국 전통 공예를 체험해보세요. (운영시간: 10:00~18:00)\n\n**점심**\n- **쌈지길 체험공방**: 인사동에 위치한 쌈지길에서 다양한 공예품을 구경하고, 인근 식당에서 전통 한식을 즐겨보세요. (운영시간: 10:30~20:30)\n\n**오후**\n- **경복궁**: 한국의 대표적인 궁궐인 경복궁을 방문하여 조선시대의 역사를 느껴보세요. 경복궁 근처에는 국립민속박물관도 있어 함께 방문하기 좋습니다.\n- **인사동 거리**: 전통과 현대가 어우러진 인사동 거리에서 다양한 전통 공예품과 기념품을 구경하세요.\n\n**저녁**\n- **우리집 게스트하우스**: 종로구 계동에 위치한 우리집 게스트하우스에서 편안한 휴식을 취하세요. (운영시간: 24시간)\n\n### 2일차\n\n**오전**\n- **서울김치문화체험관**: 명동에 위치한 서울김치문화체험관에서 김치 만들기 체험을 해보세요. (운영시간: 10:30~19:00)\n\n**점심**\n- **연서네 철문집**: 서울역 근처에 위치한 연서네 철문집에서 맛있는 삼겹살을 즐기세요. (운영시간: 15:00~03:00)\n\n**오후**\n- **청계천 헌책방 거리**: 을지로에 위치한 청계천 헌책방 거리에서 다양한 헌책과 독특한 아이템을 구경하세요.\n- **동대문 디자인 플라자(DDP)**: 동대문에 위치한 DDP에서 현대적인 건축물과 다양한 전시를 관람하세요.\n\n**저녁**\n- **한판도 역삼점**: 강남에 위치한 한판도 역삼점에서 저녁 식사를 즐기며 여행을 마무리하세요. (운영시간: 11:30~22:00)\n\n이 일정은 종로구와 그 주변의 주요 명소를 중심으로 구성되었습니다. 각 장소의 운영 시간과 위치를 확인하시고, 이동 시간을 고려하여 일정을 조정하시면 좋습니다. 즐거운 여행 되세요!', additional_kwargs={}, response_metadata={}, id='555cdf20-ce9c-4ccf-a5fb-ae49ba2bc432'),
#   HumanMessage(content='용산구와 중구에서의 일정 계획을 어떻게 세울 수 있을까요?', additional_kwargs={}, response_metadata={}, id='d2805cf4-2e6a-48c3-82e1-822cf19ae600'),
#   AIMessage(content='용산구와 중구에서의 일정 계획을 세워드릴게요. 두 지역은 서울의 중심부에 위치해 있어 다양한 문화와 역사를 경험할 수 있는 곳입니다. 아래는 추천 일정입니다.\n\n### 1일차: 용산구\n\n**오전**\n- **국립중앙박물관**: 한국의 역사와 문화를 깊이 있게 이해할 수 있는 국립중앙박물관을 방문하세요. 다양한 전시와 유물들이 있습니다. (운영시간: 10:00~18:00)\n\n**점심**\n- **이태원**: 다양한 국제 요리를 즐길 수 있는 이태원에서 점심을 드세요. 여러 나라의 음식을 맛볼 수 있는 곳입니다.\n\n**오후**\n- **용산 전쟁기념관**: 한국 전쟁의 역사를 배울 수 있는 전쟁기념관을 방문하세요. (운영시간: 09:00~18:00)\n- **성수미술관 용산점**: 삼각지역 근처에 위치한 성수미술관에서 드로잉 체험을 즐기며 여유로운 시간을 보내세요. (운영시간: 12:00~21:30)\n\n**저녁**\n- **남산타워**: 서울의 야경을 감상할 수 있는 남산타워를 방문하세요. 케이블카를 타고 올라가면 더욱 특별한 경험이 될 것입니다.\n\n### 2일차: 중구\n\n**오전**\n- **덕수궁**: 조선 시대의 궁궐인 덕수궁을 방문하여 한국의 전통 건축을 감상하세요. (운영시간: 09:00~18:00)\n\n**점심**\n- **죽이야기 서울 중구소공점**: 건강한 한식을 제공하는 죽이야기에서 전복죽이나 다양한 죽 메뉴를 즐기세요. (운영시간: 08:00~16:00)\n\n**오후**\n- **명동 쇼핑 거리**: 다양한 브랜드와 상점이 모여 있는 명동에서 쇼핑을 즐기세요.\n- **청계천 헌책방 거리**: 을지로에 위치한 청계천 헌책방 거리에서 다양한 헌책과 독특한 아이템을 구경하세요.\n\n**저녁**\n- **어슬 서울**: 서울역 근처에 위치한 어슬 서울에서 퓨전 한식과 전통주를 즐기며 하루를 마무리하세요. (운영시간: 11:30~23:00)\n\n이 일정은 용산구와 중구의 주요 명소를 중심으로 구성되었습니다. 각 장소의 운영 시간과 위치를 확인하시고, 이동 시간을 고려하여 일정을 조정하시면 좋습니다. 즐거운 여행 되세요!', additional_kwargs={}, response_metadata={}, id='ae25ba32-c182-4265-81a7-86d227aee8fd'),
#   HumanMessage(content='내가 이전에 한 질문은 무엇인가요?', additional_kwargs={}, response_metadata={}, id='b0fd8c40-8ac9-4bf5-906a-d9664b06dc70'),
#   AIMessage(content='용산구와 중구에서의 일정 계획을 세워드릴게요. 두 지역은 서울의 중심부에 위치해 있어 다양한 문화와 역사를 경험할 수 있는 곳입니다. 아래는 추천 일정입니다.\n\n### 1일차: 용산구\n\n**오전**\n- **국립중앙박물관**: 한국의 역사와 문화를 깊이 있게 이해할 수 있는 국립중앙박물관을 방문하세요. 다양한 전시와 유물들이 있습니다. (운영시간: 10:00~18:00)\n\n**점심**\n- **이태원**: 다양한 국제 요리를 즐길 수 있는 이태원에서 점심을 드세요. 여러 나라의 음식을 맛볼 수 있는 곳입니다.\n\n**오후**\n- **용산 전쟁기념관**: 한국 전쟁의 역사를 배울 수 있는 전쟁기념관을 방문하세요. (운영시간: 09:00~18:00)\n- **성수미술관 용산점**: 삼각지역 근처에 위치한 성수미술관에서 드로잉 체험을 즐기며 여유로운 시간을 보내세요. (운영시간: 12:00~21:30)\n\n**저녁**\n- **남산타워**: 서울의 야경을 감상할 수 있는 남산타워를 방문하세요. 케이블카를 타고 올라가면 더욱 특별한 경험이 될 것입니다.\n\n### 2일차: 중구\n\n**오전**\n- **덕수궁**: 조선 시대의 궁궐인 덕수궁을 방문하여 한국의 전통 건축을 감상하세요. (운영시간: 09:00~18:00)\n\n**점심**\n- **죽이야기 서울 중구소공점**: 건강한 한식을 제공하는 죽이야기에서 전복죽이나 다양한 죽 메뉴를 즐기세요. (운영시간: 08:00~16:00)\n\n**오후**\n- **명동 쇼핑 거리**: 다양한 브랜드와 상점이 모여 있는 명동에서 쇼핑을 즐기세요.\n- **청계천 헌책방 거리**: 을지로에 위치한 청계천 헌책방 거리에서 다양한 헌책과 독특한 아이템을 구경하세요.\n\n**저녁**\n- **어슬 서울**: 서울역 근처에 위치한 어슬 서울에서 퓨전 한식과 전통주를 즐기며 하루를 마무리하세요. (운영시간: 11:30~23:00)\n\n이 일정은 용산구와 중구의 주요 명소를 중심으로 구성되었습니다. 각 장소의 운영 시간과 위치를 확인하시고, 이동 시간을 고려하여 일정을 조정하시면 좋습니다. 즐거운 여행 되세요!', additional_kwargs={}, response_metadata={}, id='139b20ef-a175-49b3-9dd8-281bbfaa40d3')],
#  'webOrRetriever': 'retriever'}

# %%
print(res.get('answer'))
# Out:
# 용산구와 중구에서의 일정 계획을 세워드릴게요. 두 지역은 서울의 중심부에 위치해 있어 다양한 문화와 역사를 경험할 수 있는 곳입니다. 아래는 추천 일정입니다.
#
# ### 1일차: 용산구
#
# **오전**
# - **국립중앙박물관**: 한국의 역사와 문화를 깊이 있게 이해할 수 있는 국립중앙박물관을 방문하세요. 다양한 전시와 유물들이 있습니다. (운영시간: 10:00~18:00)
#
# **점심**
# - **이태원**: 다양한 국제 요리를 즐길 수 있는 이태원에서 점심을 드세요. 여러 나라의 음식을 맛볼 수 있는 곳입니다.
#
# **오후**
# - **용산 전쟁기념관**: 한국 전쟁의 역사를 배울 수 있는 전쟁기념관을 방문하세요. (운영시간: 09:00~18:00)
# - **성수미술관 용산점**: 삼각지역 근처에 위치한 성수미술관에서 드로잉 체험을 즐기며 여유로운 시간을 보내세요. (운영시간: 12:00~21:30)
#
# **저녁**
# - **남산타워**: 서울의 야경을 감상할 수 있는 남산타워를 방문하세요. 케이블카를 타고 올라가면 더욱 특별한 경험이 될 것입니다.
#
# ### 2일차: 중구
#
# **오전**
# - **덕수궁**: 조선 시대의 궁궐인 덕수궁을 방문하여 한국의 전통 건축을 감상하세요. (운영시간: 09:00~18:00)
#
# **점심**
# - **죽이야기 서울 중구소공점**: 건강한 한식을 제공하는 죽이야기에서 전복죽이나 다양한 죽 메뉴를 즐기세요. (운영시간: 08:00~16:00)
#
# **오후**
# - **명동 쇼핑 거리**: 다양한 브랜드와 상점이 모여 있는 명동에서 쇼핑을 즐기세요.
# - **청계천 헌책방 거리**: 을지로에 위치한 청계천 헌책방 거리에서 다양한 헌책과 독특한 아이템을 구경하세요.
#
# **저녁**
# - **어슬 서울**: 서울역 근처에 위치한 어슬 서울에서 퓨전 한식과 전통주를 즐기며 하루를 마무리하세요. (운영시간: 11:30~23:00)
#
# 이 일정은 용산구와 중구의 주요 명소를 중심으로 구성되었습니다. 각 장소의 운영 시간과 위치를 확인하시고, 이동 시간을 고려하여 일정을 조정하시면 좋습니다. 즐거운 여행 되세요!

# %%
from langchain_core.runnables import RunnableConfig
from langchain_teddynote.messages import invoke_graph, stream_graph, random_uuid

# config 설정(재귀 최대 횟수, thread_id)
config = RunnableConfig(recursion_limit=20, configurable={"thread_id": random_uuid()})

# 질문 입력
inputs = GraphState(question="강남구와 종로구에 2박3일 방문하려고 하는데 중간에 성형외과를 방문 하려고해 일정을 만들어 줄 수 있어?")

# 그래프 실행
invoke_graph(app, inputs, config)
# Out:
# ==================================================
# 🔄 Node: location_check 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# location:
# ['강남구', '종로구', '중구']
# ==================================================
#
# ==================================================
# 🔄 Node: retrieve_document_naver_jongro 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# context_naver_jongro:
# <document><content>store_name: 창창
#  category: 중식당
#  new_open:
#  rating: 정보없음
#  visited_review: 방문자 리뷰 466
#  directions_text: 昌1) 발렛
# - '창신12길 33' 앞에서 발렛파킹 후 이동
# - 목적지를 '창창', 경유지를 '명신 초등학교'로 검색하면 보다 수월하게 오실 수 있습니다.
# - '방문 도장' 확인이 필요하며, 창창 옆 건물 안내부스를 통해 출차 가능합니다.
# <2시간 6000원, 30분 추가 시 2000원>
# *만 차일 경우 인근 주차장 이용 부탁드립니다.
#
# 昌2) 버스 (약 15분)
# '종로 03번 마을버스'를 타고 '낙산 삼거리' 정류장에서 내려 왼쪽 길을 따라 창창 건물이 보일 때까지 걷습니다.
# 내용 더보기
#  store_id: 1903257210
#  address: 서울 종로구 창신12길 37 창창
#  blog_review: 블로그 리뷰 725
#  phone_num: 0507-1370-3548
#  business_hours: 매일
# 11:30 - 21:00
# 15:00 - 17:00 브레이크타임
# 20:00 라스트오더
#
#  info: 정보없음
#  convenience_facilities_and_services: 정보없음
#  Parking: 정보없음
#  sns: 정보없음
#  review_like_this_part_output: "음식이 맛있어요"이 키워드를 선택한 인원269
# "인테리어가 멋져요"이 키워드를 선택한 인원243
# "뷰가 좋아요"이 키워드를 선택한 인원231
# "특별한 메뉴가 있어요"이 키워드를 선택한 인원136
# "친절해요"이 키워드를 선택한 인원96
#
#  menu: 까이포커플세트대표닭고기와 풍부한 양념이 어우러져있는 닭볶음탕과 푸짐한 국물이 일품인 까이포세트메뉴65,000원
# 라즈지대표두툼한 닭 다리 살을 전분 반죽으로 튀겨내 쯔란과 함께 볶아낸 쓰촨 지역의 매콤한 닭 요리28,000원
# 꿔바로우대표돼지 등심을 통째로 튀겨내 달콤하고 새콤한 소스와 함께 곁들여 먹는 튀김 요리21,000원
# 창창하이볼대표달콤한 체리와 상큼한 블루베리가 어우러진 창창 시그니처 하이볼 (논알콜가능)12,000원
# 쇠고기우육면소 힘줄과 사태를 긴 시간 우려내 쫀득한 식감으로 함께 즐길 수 있는 국물 면 요17,000원
# 마늘종 자장면황두장과 향긋한 마늘종을 함께 볶아 식감이 좋은 볶음 면 요리14,000원
# 차돌박이 사천 탕면얼큰하게 즐길 수 있는 중독적인 얼얼한 맛의 사천식 국물 면 요리15,000원
# 통삼겹 동파육두툼한 삼겹살을 통째로 쪄낸 부드러운 식감의 요리34,000원
# 중화냉면쫄깃한 면발과 차가운 국물 또는 소스의 조화가 일품이며,시원하게 즐길 수 있는 면 요리17,000원
# 새우계란볶음밥파기름으로 고슬하게 볶아낸 새우 볶음밥10,000원
# 창창 팝 만두바삭하게 튀긴 만두에 매콤한 고추부각과 고소한 땅콩, 쯔란을 뿌린 튀김 요리9,000원
# 짜사이 볶음밥꼬들꼬들한 재밌는 식감의 짜사이와 밥을 특재 소스로 볶아낸 짭짤하고 고소한 볶음밥10,000원
# 오이 냉채신선한 오이를 달콤하고 새콤한 소스의 절여 매콤한 로깐마 소스와 함께 버무려 먹는 요리8,000원
# 오드레기 볶음오랜 시간 삶아 쫀득한 식감의 스지를 향신료로 볶아낸 중식 볶음 요리29,000원
# 연두부 튀김부드러운 연두부를 달콤하고 짭조름한 소스와 곁들여 먹는 튀김요리14,000원
# </content>
# <document><content>store_name: 동베이 광화문점
#  category: 양꼬치
#  new_open:
#  rating: 정보없음
#  visited_review: 방문자 리뷰 218
#  directions_text: 광화문 중식전문점 [동베이]를 찾아주셔서 감사합니다!
#
# 단체 예약 또는 회식 예약은 전화 문의 주시면 안내드리겠습니다.
#
# 오시는 길
#
# + 지하철로 광화문역에서 내려주시고,
# 포시즌스 호텔 근처 20미터 내에 육대장 건물 2층에 위치해있습니다.
# + 주차 제공 또는 발렛은 어려우니, 공영주차장을 이용해주시기 바랍니다.
# 1. 세종문화회관 주차장
# 2. 신문로 공영주차장
# 3. 고려 주차장
# 4. 광화문 빌딩 앞 노상 공영주차장
# 내용 더보기
#  store_id: 1962205483
#  address: 서울 종로구 새문안로5길 8-1 2층 동베이 광화문점
#  blog_review: 블로그 리뷰 132
#  phone_num: 0507-1402-8696
#  business_hours: 매일
# 10:00 - 24:00
# 23:00 라스트오더
#
#  info: 안녕하세요.
# 양꼬치와 동북 요리 전문점
# 동베이 광화문점입니다!
#
# + 당일 예약은 전화로 연락 부탁드립니다.
# + 예약은 최대 전체 좌석에 50% 까지 받고 있습니다.
#
# 한국인이 가장 사랑하고 친근한 중국 음식이
# 동북 지역에 요리라는 것을 알고 계셨나요?
# 대표적인 꿔바로우부터, 경장육슬까지 다양한 동북 요리를 맛볼 수 있는 광화문의 중식 맛집입니다!
#
# 양꼬치를 전문으로,
# 고급 양갈비까지 잡내 없이 탄탄한 식감으로 매일 작업하여 제공하고 있습니다.
# 현지에서 오랜 세월 중식당을 운영하셨던 쉐프님이
# 모든 요리부터, 식사류까지 빠짐없이 맛있게 조리합니다!
#
# 가장 익숙한 중식과 대중적인 마라탕까지
# 한 곳에서 모두 맛 볼 기회는
# 오직 [동베이]에서!
#
# 종로구에서 동북요리를 지향하는 가게는 많이 있습니다.
# 우리의 특별한 점은,
# 광화문이라는 상권 아래 양꼬치부터, 다양한 점심 식사까지
# 한국인의 입맛을 고려한 대중성을 꼽아 말씀드릴 수 있습니다.
#
# + 가장 익숙하고 누구에게나 맛있는!
#
# * 양꼬치
# * 고급 양갈비
# * 꿔바로우
# * 지삼선 등 누구에게나 사랑받고 항상 인기있는 메뉴가 준비되어 있습니다!
#
# + 동북 요리를 서울 도심 속에서 가장 현지의 맛으로!
#
# * 쯔란 양고기
# * 어향가지
# * 경장육슬
# * 바지락볶음 등 한번 맛보면, 계속 생각나는 동북요리는 우리의 자랑입니다!
#
# + MZ세대의 입맛까지 사로잡은 광화문 맛집 동베이!
#
# * 마라탕
# * 마라샹궈
# * 훠궈
# * 토마토 계란볶음 등 요즘 세대에 입맛에 딱 맞춘 요리까지!
#
# - 동베이를 이용해주시는 분들에게
# 1. 점심에는 합리적인 가격에 점심 훠궈와, 꿔바로우등 든든한 식사 메뉴가 준비되어 있습니다. (2:30까지)
# 2. 단체 또는 회식 문의는 전화로 주시면 친절히 안내해드리겠습니다.
# 3. 양갈비는 매일 한정수량으로 준비해두고 있어, 조기 소진시 양꼬치를 이용해주시면 좀 더 만족스러운 식사를 준비해드리겠습니다.
# 4. 요리류 식사는 2층, 꼬치 구이류 식사는 3층에서 우선적으로 모시겠습니다.
# 5. 포시즌스 서울 호텔 고객님은 매장에서 중국어 안내까지 가능합니다.
#
# 항상 최고의 퀄리티와 맛을 보장하는 ,
# 광화문에 동북 요리 전문 동베이로 식사하러 오세요!
# 펼쳐보기
#  convenience_facilities_and_services: 비건 메뉴
# 유기농 메뉴
# 단체 이용 가능
# 포장
# 배달
# 예약
# 남/녀 화장실 구분
#
#  Parking: 주차 불가
#  sns: https://app.catchtable.co.kr/ct/shop/dong_bey
#
#  review_like_this_part_output: "음식이 맛있어요"이 키워드를 선택한 인원101
# "가성비가 좋아요"이 키워드를 선택한 인원25
# "양이 많아요"이 키워드를 선택한 인원24
# "특별한 메뉴가 있어요"이 키워드를 선택한 인원24
# "친절해요"이 키워드를 선택한 인원13
# "고기 질이 좋아요"이 키워드를 선택한 인원12
# "단체모임 하기 좋아요"이 키워드를 선택한 인원12
# "혼밥하기 좋아요"이 키워드를 선택한 인원6
# "재료가 신선해요"이 키워드를 선택한 인원5
# "매장이 넓어요"이 키워드를 선택한 인원5
# "인테리어가 멋져요"이 키워드를 선택한 인원4
# "음식이 빨리 나와요"이 키워드를 선택한 인원3
# "메뉴 구성이 알차요"이 키워드를 선택한 인원3
# "컨셉이 독특해요"이 키워드를 선택한 인원2
# "잡내가 적어요"이 키워드를 선택한 인원1
# "현지 맛에 가까워요"이 키워드를 선택한 인원1
# "주차하기 편해요"이 키워드를 선택한 인원1
# "특별한 날 가기 좋아요"이 키워드를 선택한 인원1
# "오래 머무르기 좋아요"이 키워드를 선택한 인원1
# "매장이 청결해요"이 키워드를 선택한 인원1
# "화장실이 깨끗해요"이 키워드를 선택한 인원1
# "뷰가 좋아요"이 키워드를 선택한 인원1
#
#  menu: 훠궈 점심 특선대표합리적인 가격에 푸짐하고 배불리 즐길 수 있는 점심 특선입니다.
# (3시 이전까지 제공)12,800원
# 양꼬치대표어린 양고기를 동베이만의 양념에 버무려 숙성시킨 꼬치요리 입니다.
# (8꼬치 제공됩니다.)16,000원
# 꿔바로우대표겉바속촉 돼지고기에 동베이만의 과일소스로 동북요리의 맛을 살린 동베이의 대표 메뉴입니다.20,000원
# 마라샹궈대표각종 야채와 고기에 향신료와 마라의 얼얼함을 더해 볶은 요리입니다.28,000원
# 모듬 꼬치 세트대표양꼬치 / 소갈빗살 꼬치/ 양갈빗살 꼬치 + 꿔바로우68,000원
# 즈란양고기대표불향 강하게 볶은 양꼬치에 쯔란을 더해, 풍미가 가득한 볶음 요리입니다.20,000원
# 지삼선대표3가지 신선 재료를 전분으로 가볍게 튀겨 맛있게 볶아낸 동베이의 인기 메뉴 입니다.18,000원
# 마라탕대표고기와 채소를 넣어 끓여먹는 메뉴로 입이 얼얼하면서 매운맛이 일품인 요리입니다.25,000원
# 라쯔지대표튀긴 닭고기를 여러 채소와 함께 볶아 고추 양념을 가미한 사천식 중국 요리입니다.28,000원
# 소갈빗살 꼬치늑간살 부위를 가볍게 소금간하여 숙성시킨 꼬치요리 입니다.
# (8꼬치 제공됩니다.)17,000원
# 양갈빗살 꼬치어린 양을 사용하여, 부드럽고 담백하게 숙성시킨 꼬치요리 입니다.
# (8꼬치 제공됩니다.)18,000원
# 경장육슬얇게누른 두부피에 각종 채소를 넣고 중국장으로 볶은 돼지고기 채를 쌓아먹는 요리입니다.28,000원
# 어향가지전분에 튀긴 가지와 채소를 어향소스에 조리듯 볶아낸 요리입니다.20,000원
# 마른고추 소고기 볶음소고기와 마른 고추를 특제 소스에 센불로 강하게 볶아낸 요리입니다.22,000원
# 향라 오징어바삭한 오징어 튀김에 수분기 적게 볶아 고소하고 매운 요리입니다.22,000원
# </content>
# <document><content>store_name: 홈보이서울
#  category: 중식당
#  new_open:
#  rating: 별점 4.38
#  visited_review: 방문자 리뷰 1,492
#  directions_text: 대중교통 이용 시
#
# 1.경복궁역 3-1번 출구로 나오신 후 다이소 건물 뒤쪽으로 오시면 됩니다. 도보로 약 1분 거리에 위치 하고있습니다.
# 2.가장 가까운 버스 정류장은 경복궁역 1번 출구 정류장입니다. 171, 272, 606, 708, 710번 버스를 이용하시면 편리하게 방문하실 수 있습니다.
#
# 자차 이용 시
# 1.네비게이션에 서울 종로구 사직로 127-14를 입력하세요.
# 광화문, 종로, 서촌, 경복궁 인근에 위치해 접근성이 뛰어나며, 경복궁역과도 가깝습니다.
#
# 사직로 서울은 경복궁 맛집, 광화문 맛집, 서촌 맛집으로 한적하고 여유로운 분위기에서 전통 한식을 즐길 수 있는 완벽한 장소입니다.
# 내용 더보기
#  store_id: 1214831336
#  address: 서울 종로구 사직로 127-14 1층 홈보이서울
#  blog_review: 블로그 리뷰 1,927
#  phone_num: 0507-1355-4371
#  business_hours: 화
# 11:30 - 22:00
# 15:00 - 17:00 브레이크타임
# 수
# 11:30 - 22:00
# 15:00 - 17:00 브레이크타임
# 목
# 11:30 - 22:00
# 15:00 - 17:00 브레이크타임
# 금
# 11:30 - 22:00
# 15:00 - 17:00 브레이크타임
# 토
# 11:00 - 22:00
# 일
# 11:00 - 22:00
# 월
# 11:30 - 22:00
# 15:00 - 17:00 브레이크타임
#
#  info: 새로운 중식의 매력을 만나고 싶다면, 홈보이 서울로 오세요.
# 2019년 연남동에서 시작해 2022년 경복궁으로 확장이전한 홈보이 서울은 아메리칸 차이니즈 레스토랑으로,
# 기존 중식과는 또 다른 특별한 경험을 제공합니다.
# 익숙하지만 새로운 요리로 이미 많은 분들의 사랑을 받고 있는 광화문 맛집이자 경복궁 맛집입니다.
#
# 아메리칸 차이니즈 요리의 매력
# 짜장면과 탕수육이 우리나라에 맞게 변화한 것처럼, 홈보이 서울의 요리는 미국 문화에 맞게 재해석된 중식을 선보입니다.
# 바삭하고 달콤한 오렌지 치킨, 짭조름하면서도 풍미 깊은 몽골리안 포크, 진한 국물 맛이 일품인 새우 완탕 스프, 고소한 면 요리인 비프 차우멘까지 다양한 메뉴로 입맛을 사로잡습니다.
#
# 새롭고 기억에 남는 공간
# 아늑한 공간에서 이국적인 분위기를 즐길 수 있는 홈보이 서울은 연인과의 데이트, 친구와의 모임, 가족 외식까지 모든 순간에 잘 어울립니다.
# 특히 서촌 맛집답게 서촌 특유의 감성과 어우러진 편안한 분위기를 자랑하며, 새로운 맛과 문화적 경험을 함께 제공합니다.
#
# 캐주얼하지만 품격 있는 식사 경험
# 부담 없이 편안하게 즐길 수 있는 캐주얼한 중식당이면서도, 세련된 공간과 정성 가득한 요리로 특별한 식사를 제공합니다.
# 경복궁역 맛집을 찾는 분들에게 한 번 방문하면 잊지 못할 맛과 분위기를 선사하겠습니다.
#
#  위치: 서울특별시 종로구 사직로 127-14, 1층
#  영업시간:
#  - 평일 : 오전 11시 30분 ~ 오후 10시
#  (브레이크 타임 오후3시 ~ 오후5시)
#  - 주말 : 오전 11시 ~ 오후 10시
#  (노 브레이크)
#  문의: 02-2274-4371
# 새롭고 특별한 중식의 매력을 즐기고 싶다면 광화문 맛집, 서촌 맛집 홈보이 서울에서 여러분을 기다리겠습니다!
# 펼쳐보기
#  convenience_facilities_and_services: 단체 이용 가능
# 무선 인터넷
# 포장
# 배달
# 예약
# 남/녀 화장실 구분
#
#  Parking: 주차가능
#  sns: http://www.instagram.com/homeboy_seoul
#
#  review_like_this_part_output: "음식이 맛있어요"이 키워드를 선택한 인원1027
# "인테리어가 멋져요"이 키워드를 선택한 인원479
# "특별한 메뉴가 있어요"이 키워드를 선택한 인원381
# "친절해요"이 키워드를 선택한 인원361
# "양이 많아요"이 키워드를 선택한 인원243
# "재료가 신선해요"이 키워드를 선택한 인원241
# "매장이 청결해요"이 키워드를 선택한 인원171
# "현지 맛에 가까워요"이 키워드를 선택한 인원149
# "매장이 넓어요"이 키워드를 선택한 인원103
# "특별한 날 가기 좋아요"이 키워드를 선택한 인원70
# "컨셉이 독특해요"이 키워드를 선택한 인원67
# "가성비가 좋아요"이 키워드를 선택한 인원64
# "메뉴 구성이 알차요"이 키워드를 선택한 인원61
# "화장실이 깨끗해요"이 키워드를 선택한 인원52
# "단체모임 하기 좋아요"이 키워드를 선택한 인원42
# "음식이 빨리 나와요"이 키워드를 선택한 인원28
# "혼밥하기 좋아요"이 키워드를 선택한 인원23
# "향신료가 강하지 않아요"이 키워드를 선택한 인원19
# "아늑해요"이 키워드를 선택한 인원15
# "주차하기 편해요"이 키워드를 선택한 인원15
# "비싼 만큼 가치있어요"이 키워드를 선택한 인원7
# "뷰가 좋아요"이 키워드를 선택한 인원7
# "차분한 분위기에요"이 키워드를 선택한 인원3
# "음악이 좋아요"이 키워드를 선택한 인원3
# "반찬이 잘 나와요"이 키워드를 선택한 인원2
# "대화하기 좋아요"이 키워드를 선택한 인원2
# "술이 다양해요"이 키워드를 선택한 인원1
# "좌석이 편해요"이 키워드를 선택한 인원1
# "음료가 맛있어요"이 키워드를 선택한 인원1
# "야외공간이 멋져요"이 키워드를 선택한 인원1
# "사진이 잘 나와요"이 키워드를 선택한 인원1
# "오래 머무르기 좋아요"이 키워드를 선택한 인원1
# "건강한 맛이에요"이 키워드를 선택한 인원1
#
#  menu: 몽골리안 포크대표홈보이서울의 시그니처 디쉬, 불맛과 달달함의 밸런스22,800원
# 오렌지 치킨대표오렌지 껍질과 과육을 사용한 특제 오렌지소스와 육즙 넘치는 치킨22,800원
# 2인 세트 A몽골리안 포크+크리스피 차우멘+새우완탕스프+아이스티 2잔 or 칭타오생맥주 2잔(+5.0)52,800원
# 2인 세트 B오렌지 치킨+비프 차우멘+새우 완탕 스프+아이스티 2잔 or 칭타오생맥주 2잔(+5.0)53,800원
# 3인 세트몽골리안 포크+오렌지 치킨+비프 차우멘+공심채 볶음+새우 완탕 스프79,800원
# 4인 세트소고기 마라샹궈+반반 새우+몽골리안 포크+오렌지 치킨+공심채 볶음+새우 완탕 스프112,800원
# 중국식 오이무침오이와 마늘간장, 칠리 오일을 곁들인 사이드7,800원
# 공심채 볶음중화웍에서 빠르게 볶아낸 공심채 볶음14,800원
# 새우완탕스프통통한 새우완탕과 청경채, 칠리오일을 곁들인 개운한 스프12,800원
# 스프링 롤9,800/4pcs, 12,800/6pcs 돼지고기와 야채가 듬뿍 들어간 두툼한 춘권9,800원
# 스파이시 오렌지 치킨오렌지 껍질과 과육을 사용한 특제 오렌지소스에
# 매운맛을 더한 육즙 넘치는 치킨24,800원
# 쿵파오 치킨칠리오일 베이스의 매콤한 쿵파오소스에 볶아낸 부드러운 치킨 그리고 캐슈넛22,800원
# 반반 새우매콤하면서 달짝지근한 칠리 새우와 새콤달콤한 크림새우, 두가지를 한접시에 맛보세요25,800원
# 크림 새우특별한 튀김 옷으로 가볍고 바삭한 새우와 새콤달콤한 크림소스24,800원
# 칠리 새우매콤하면서 달짝지근한 칠리소스에 볶아낸 바삭한 새우24,800원
# </content>
# <document><content>store_name: 신승관
#  category: 중식당
#  new_open:
#  rating: 별점 4.29
#  visited_review: 방문자 리뷰 449
#  directions_text: 종각역1번출구에서 광화문 방향으로 걸어오시면 1층에 [올리브영]있는 르메이에르 건물, 2층에 <신승관>이 있습니다.
#
# 광화문역4번출구에서 교문빌딩 뒷쪽으로 오셔서 2층에 [종로 정형외과]있는 르메이에르 건물 2층에 <신승관>이 있습니다.
#
# 버스정류장은 광화문, 종로1가에서 내리시면됩니다.
# 내용 더보기
#  store_id: 12989948
#  address: 서울 종로구 종로 19 217호
#  blog_review: 블로그 리뷰 411
#  phone_num: 02-735-9955
#  business_hours: 수
# 11:00 - 23:00
# 15:00 - 16:30 브레이크타임
# 21:00 라스트오더
# 목
# 11:00 - 23:00
# 15:00 - 16:30 브레이크타임
# 21:00 라스트오더
# 금
# 11:00 - 23:00
# 15:00 - 16:30 브레이크타임
# 21:00 라스트오더
# 토
# 11:00 - 23:00
# 15:00 - 16:30 브레이크타임
# 21:00 라스트오더
# 일
# 정기휴무 (매주 일요일)
# 월
# 11:00 - 23:00
# 15:00 - 16:30 브레이크타임
# 21:00 라스트오더
# 화
# 11:00 - 23:00
# 15:00 - 16:30 브레이크타임
# 21:00 라스트오더
#
#  info: 1964년부터 3대째 가업을 이어 운영중인 신승관 중식당입니다. 할어버지의 말씀처럼 신선한재료들로 정성들여 조리하는 음식이 가장 맛있다는 가르침을 잊지않고 최선을 다하여 현재까지 가업을 이어가고있습니다.
#
# 번거롭고 시간이 많이 걸리더라도 직접 재료들을 하나하나 손질하여 신선한재료들로 모든음식을 조리합니다.
#
# 면반죽은 매일 매장에서 고급 제면용 밀가루와 약간의소금, 계란으로 직접손반죽하여 48시간 냉장 숙성과정을거쳐 쫀득하고 소화가 잘되는 면을 제공합니다. 요즘은 완성된 반죽을 유통하는 업체들도 많지만, 저희는 신승관 손님들께는 보다 신선하고 소화가 잘되는 건강한 면을 만들어드리고자 직접손반죽하여 48시간숙성한 면요리를 제공합니다.
#
# 자장,간자장,짬뽕,삼선짬뽕 등에 사용하는 양파는 매일 가락시장에서 새벽에 경매시장에 나오는 양파를 구입합니다. 아침일찍 매장에서 직접 껍질을까서 신선한 양파로 자장장과 간자장장을 볶아야 양파의 담백한 맛이 가장 잘 울어나기 때문입니다. 공장에서 껍질을 까서 유통되는 깐양파는 조리과정을 쉽게하지만 양파의 풍부한 맛을 우려내기엔 부족합니다. 그래서 저희는 힘들고 번거롭더라도 새벽시장에서 신선한 양파를 구입하여 조리합니다.
#
# 중식당에서 가장 중요한 재료중 하나는 춘장입니다^^ 춘장 또한 훌륭한 볶은춘장이 기성품으로 유통되고있지만, 신승관에서는 생춘장을 매장에서 직접 볶아 조리합니다. 매장에서 직접 춘장을 볶아내야지만 춘장의 고소한 맛을 극대화시킬수 있기때문입니다. 자장장과 간자장장의 맛을 좌우하는 것은 신선한 양파와 잘볶아진 춘장입니다. 시시하게 들리시겠지만 이 두가지 재료만으로 충분히 맛있는 자장과 간자장을 조리가능합니다. 첫맛이 인상깊은 자장,간자장은 조미료를 많이넣어야합니다. 다량의 조미료로 조리된 자장,간자장은 첫맛은 매력적일수 있지만 먹을수록 질리거나 먹고나서 속도 더부룩하고 계속 물을 마시고 싶어집니다. 저희 신승관은 조금 부족한 맛의 자장,간자장이라도 조미료를 많이 사용하기보다는 잘볶아내 양파의 단맛과 고소하게 볶아낸 춘장과 조려낸 진간장을 사용하여 은은하게 고소하고 담백하고 짭조름한 자장과 간자장을 조리합니다.
#
# 짬뽕 또한 중식당에서 단연 최고인기 메뉴중하나이죠. 신승관의 짬뽕은 남대문 방앗간에서 직접 빻아오는 고추가루를 이용하여 고온의 기름에 볶아내는 고추기름으로 조리됩니다. 짬뽕에 들어가는 육수는 월계수잎, 영계, 사골, 생강, 양파로 최소36시간 매장에서 우려냅니다. 잘볶아낸 고추기름과 진하게 우려낸 육수 그리고 신선한야채와 해물들을 넣어 신승관의 짬뽕 맛을 완성합니다. 양파와 양배추는 해독과 위보호에 도움을주고, 육수의 재료 중 영계와 생강은 몸을 따뜻하게 해주어 짬뽕 한 그릇이지만 원기회복에 도움을 줍니다. 또한, 영계생강육수는 100%진한 사골육수 보다 삼선짬뽕의 홍합, 바지락, 전복, 중새우의 해물맛과 더욱 조화롭기 때문에 더욱 신경씁니다.
#
# 마지막으로 신승관 요리에 사용되는 모든 소스 또한 직접 만듭니다. 탕수육소스는 레몬, 양파, 생강, 식초를 끓여 만들고, 깐풍소스는 레몬, 양파, 간장을 끓여 만들며, 깐소소스는 토마토, 고추, 마늘로 만들고, 라조소스는 굴소스, 고추, 마늘로 만듭니다. 레몬과 양파, 마늘은 모두 해독력이 강한 식재료입니다. 소스의 맛은 물론 영양까지 신경쓰며 모든 소스를 직접 만듭니다.
#
# 60년 가까이 가업을 이어오면서 가게 운영면에서 여러 시행착오를 격었고, 피맛골 재개발로 원치않은 매장이전도 두세차례를 격었고, 솔직히 조리과정을 단순화하고 싶은 유혹도 많았지만 신승관을 꾸준히 찾아주시는 몇십년되신 단골고객님들의 응원과 격려와 관심이 있어 할아버지와 부모님의 가르침을 유지할수 있었습니다. '정직하게 살자'는 가훈과 '신선한재료들로 정성들여 조리하는 음식이 가장 맛있다'는 사훈을 유지하며 하루하루 발전하는 식당(新:새로운 신/개선될 신, 昇:발전할 승/오를 승, 館: 집 관, 객사 관) 신승관을 만들어갈것을 저 자신과 약속합니다.
#
# 찾아주시는 모든 고객님들 건강하시고 모든 일에 행운이 함께 하시길 기원합니다. 감사합니다.
# 펼쳐보기
#  convenience_facilities_and_services: 콜키지 가능
# 무료
# 생일 혜택
# 단체 이용 가능
# 무선 인터넷
# 남/녀 화장실 구분
# 유아의자
# 포장
# 예약
# 장애인 휠체어 이용가능
# 출입구 휠체어 이용가능
# 좌석 휠체어 이용가능
# 장애인 주차구역
#
#  Parking: 주차가능
# 무료
#  sns: https://m.blog.naver.com/wmedia77/223171955325
# https://www.instagram.com/jongro_sinseungkwan
#
#  review_like_this_part_output: "음식이 맛있어요"이 키워드를 선택한 인원225
# "친절해요"이 키워드를 선택한 인원102
# "단체모임 하기 좋아요"이 키워드를 선택한 인원76
# "재료가 신선해요"이 키워드를 선택한 인원68
# "양이 많아요"이 키워드를 선택한 인원67
# "특별한 메뉴가 있어요"이 키워드를 선택한 인원56
# "가성비가 좋아요"이 키워드를 선택한 인원53
# "매장이 넓어요"이 키워드를 선택한 인원53
# "매장이 청결해요"이 키워드를 선택한 인원36
# "혼밥하기 좋아요"이 키워드를 선택한 인원32
# "인테리어가 멋져요"이 키워드를 선택한 인원26
# "룸이 잘 되어있어요"이 키워드를 선택한 인원12
# "메뉴 구성이 알차요"이 키워드를 선택한 인원11
# "주차하기 편해요"이 키워드를 선택한 인원9
# "특별한 날 가기 좋아요"이 키워드를 선택한 인원8
# "뷰가 좋아요"이 키워드를 선택한 인원7
# "음식이 빨리 나와요"이 키워드를 선택한 인원5
# "대화하기 좋아요"이 키워드를 선택한 인원5
# "건강한 맛이에요"이 키워드를 선택한 인원3
# "화장실이 깨끗해요"이 키워드를 선택한 인원3
# "차분한 분위기에요"이 키워드를 선택한 인원2
# "반찬이 잘 나와요"이 키워드를 선택한 인원2
# "술이 다양해요"이 키워드를 선택한 인원1
# "좌석이 편해요"이 키워드를 선택한 인원1
# "아늑해요"이 키워드를 선택한 인원1
# "아이와 가기 좋아요"이 키워드를 선택한 인원1
# "잡내가 적어요"이 키워드를 선택한 인원1
# "향신료가 강하지 않아요"이 키워드를 선택한 인원1
#
#  menu: 삼선짬뽕14,000원
# 고추자장10,000원
# 해물백짬뽕14,000원
# 유슬볶음밥13,000원
# 유산슬밥16,000원
# 비취탕수육25,000원
# 레몬크림중새우변동
# 수제면보사변동
# 깐소중새우변동
# 탕수육 세트미니탕수육+식사2가지+음료수36,000원
# 꿔바로우 세트미니꿔바로우+식사2가지+음료수39,000원
# 깐풍기 세트미니깐풍기+식사2가지+음료수39,000원
# 유린기 세트미니유린기+식사2가지+음료수43,000원
# 깐소중새우 세트미니깐소중새우+식사2가지+음료수43,000원
# 48,000 코스요리48,000원
# </content>
# <document><content>store_name: 서울회관
#  category: 요리주점
#  new_open:
#  rating: 별점 4.38
#  visited_review: 방문자 리뷰 250
#  directions_text: <대중교통 안내>
#
# [버스]
# 조계사 종로경찰서 정류장에서 하차 후, 약 50m 직진하여 오른쪽으로 15m 이동하시면, 매장이 1층 정면에 위치해 있습니다.
#
# [도보]
# 종각역 2번 출구에서 나와 50m 직진 후, 좌회전하여 서울회관 쪽갈비 건물 3층으로 오시면 됩니다.
#
# <주차장 안내>
#
# 1. 황소민영주차장
# 위치: 종로구 종로5길 32-9
# 운영: 연중무휴, 저녁 10시 마감
# 요금: 기본 30분 2,000원 / 추가 10분당 1,000원
#
# 2. 94빌딩 주차장
# 위치: 종로구 삼봉로 94
# 운영: 연중무휴, 저녁 11시 마감 (마감 후 주차장 폐쇄)
# 요금: 기본 30분 3,000원 / 추가 10분당 1,000원
# 모두의주차장 앱 설치 시, 평일 당일권을 13,000원에 구매하실 수 있습니다.
# 내용 더보기
#  store_id: 1824175974
#  address: 서울 종로구 삼봉로 98 3층
#  blog_review: 블로그 리뷰 55
#  phone_num: 02-722-2019
#  business_hours: 일
# 정기휴무 (매주 일요일)
# 월
# 16:00 - 24:00
# 23:00 라스트오더
# 화
# 16:00 - 24:00
# 23:00 라스트오더
# 수(1/1)
# 새해 첫날 휴무
# 목
# 16:00 - 24:00
# 23:00 라스트오더
# 금
# 16:00 - 24:00
# 23:00 라스트오더
# 토
# 정기휴무 (매주 토요일)
#
#  info: 정보없음
#  convenience_facilities_and_services: 정보없음
#  Parking: 정보없음
#  sns: 정보없음
#  review_like_this_part_output: "음식이 맛있어요"이 키워드를 선택한 인원113
# "가성비가 좋아요"이 키워드를 선택한 인원55
# "단체모임 하기 좋아요"이 키워드를 선택한 인원43
# "인테리어가 멋져요"이 키워드를 선택한 인원39
# "기본 안주가 좋아요"이 키워드를 선택한 인원28
# "대화하기 좋아요"이 키워드를 선택한 인원28
# "특별한 메뉴가 있어요"이 키워드를 선택한 인원23
# "음악이 좋아요"이 키워드를 선택한 인원18
# "친절해요"이 키워드를 선택한 인원17
# "화장실이 깨끗해요"이 키워드를 선택한 인원10
# "술이 다양해요"이 키워드를 선택한 인원8
# "오래 머무르기 좋아요"이 키워드를 선택한 인원7
# "매장이 청결해요"이 키워드를 선택한 인원7
# "매장이 넓어요"이 키워드를 선택한 인원3
# "혼술하기 좋아요"이 키워드를 선택한 인원2
# "메뉴 구성이 알차요"이 키워드를 선택한 인원1
# "야외공간이 멋져요"이 키워드를 선택한 인원1
# "뷰가 좋아요"이 키워드를 선택한 인원1
#
#  menu: 옛날 가마솥 통닭대표옛날방식 그대로 가마솥에 닭한마리를 통으로 튀겨서 나오는 통닭16,000원
# 건강 충전 마늘 통닭가마솥에 튀겨낸 옛날 방식의 통닭에 풍미 가득한 마늘 소스를 더한 새로운 맛18,000원
# 유동골뱅이 무침옛날통닭의 영원한 단짝 매콤새콤 골뱅이무침23,000원
# 맛 태서울회관맛으로 풀어낸 마른안주의 정석16,000원
# 대왕 돈가스쉽게 찾아보기 힘든 압도적인 크기의 왕돈가스18,000원
# 국물 떡볶이입맛 돋우는 소스가 매콤하고 일품인 푸짐한 국물 떡볶이20,000원
# 해물 오뎅탕대합,꽃게,새우등 해산물과 여러가지 채소들과 오뎅의 만남23,000원
# 모듬 소시지다른 종류의 소시지들이 한 판에 들어가 있어 다양한 맛을 즐길 수 있는 모듬 소시지18,000원
# 모듬 감자튀김다양한 종류의 감자튀김이 있어 골라먹는 재미가 있는 모듬 감자튀김16,000원
# </content>
# <document><content>store_name: 사직로 서울
#  category: 한식
#  new_open:
#  rating: 정보없음
#  visited_review: 방문자 리뷰 2,339
#  directions_text: 대중교통 이용 시
#
# 1.경복궁역 3-1번 출구로 나오신 후 다이소 건물 뒤쪽으로 오시면 됩니다. 도보로 약 1분 거리에 위치 하고있습니다.
# 2.가장 가까운 버스 정류장은 경복궁역 1번 출구 정류장입니다. 171, 272, 606, 708, 710번 버스를 이용하시면 편리하게 방문하실 수 있습니다.
#
# 자차 이용 시
# 1.네비게이션에 서울 종로구 사직로 127-14를 입력하세요.
# 광화문, 종로, 서촌, 경복궁 인근에 위치해 접근성이 뛰어나며, 경복궁역과도 가깝습니다.
#
# 사직로 서울은 경복궁 맛집, 광화문 맛집, 서촌 맛집으로 한적하고 여유로운 분위기에서 전통 한식을 즐길 수 있는 완벽한 장소입니다.
# 내용 더보기
#  store_id: 1203679539
#  address: 서울 종로구 사직로 127-14 2층
#  blog_review: 블로그 리뷰 589
#  phone_num: 0507-1345-4371
#  business_hours: 수
# 11:30 - 22:00
# 15:00 - 17:00 브레이크타임
# 목
# 11:30 - 22:00
# 15:00 - 17:00 브레이크타임
# 금
# 11:30 - 22:00
# 15:00 - 17:00 브레이크타임
# 토
# 11:30 - 22:00
# 15:00 - 17:00 브레이크타임
# 일
# 11:30 - 22:00
# 15:00 - 17:00 브레이크타임
# 월
# 11:30 - 22:00
# 15:00 - 17:00 브레이크타임
# 화
# 11:30 - 22:00
# 15:00 - 17:00 브레이크타임
#
#  info: 경복궁과 서촌의 특별한 한식 경험을 찾고 계신가요?
# 그렇다면 사직로 서울로 오세요
#
# 참나무 장작불에 정성껏 구운 참나무 소갈비와 깊고 담백한 평양냉면으로,
# 한 그릇 한 접시마다 서촌의 여유로운 분위기를 담아냈습니다.
# 경복궁 맛집, 광화문 맛집으로 많은 분들께 사랑받고 있는 이유를 직접 확인해보시길 바랍니다.
#
# 참나무 장작불로 완성한 깊은 풍미
# 사직로 서울의 대표 메뉴인 참나무 소갈비는 참나무 장작불에 구워내어 은은한 불향과 깊은 풍미를 자랑합니다.
# 육즙 가득한 소갈비의 부드러운 식감과 고소한 맛은 입안 가득 특별한 만족을 선사합니다.
# 경복궁역 맛집, 서촌 맛집을 찾으신다면 꼭 드셔보세요.
#
# 평양냉면, 담백함의 정수를 맛보다
# 맑고 깊은 국물에 담백한 메밀 면발이 어우러진 평양냉면, 단순하지만 완벽한 조화를 이룬 전통의 맛을 경험하실 수 있습니다.
# 고기의 풍미를 살짝 더해주는 냉면의 국물은 참나무 소갈비와도 찰떡궁합이에요.
# 특별한 날, 광화문 맛집으로 제격인 이유랍니다.
#
# 서촌과 어우러진 분위기와 정성
# 서촌의 고즈넉한 분위기 속에서 경복궁이 주는 여유를 그대로 담았습니다.
# 사직로 서울은 품격 있는 공간에서 전통 한식의 맛과 멋을 한껏 즐기실 수 있도록 준비하고 있습니다.회식, 모임, 데이트, 가족 외식 모두 만족하실 수 있는 경복궁 맛집입니다.
#
# 편리한 위치와 편안한 공간
# 서울 종로구 사직로에 위치해 접근성이 뛰어나며,
# 2층에 위치한 60평 규모, 70석의 넉넉한 좌석으로 여유롭게 식사를 즐기실 수 있습니다.
# 단체 모임부터 가족 외식, 조용한 데이트까지 모두 편안하게 즐기실 수 있는 쾌적한 공간입니다.
# 광화문 맛집, 서촌 맛집으로 한 끼를 즐기고 싶은 분들께 자신 있게 추천드립니다.
#
# 위치: 서울특별시 종로구 사직로 127-14, 2층
# 영업시간: 오전 11시30분 ~ 오후 10시 / 브레이크타임 오후 3시~오후 5시
# 문의: 02-733-4371
#
# 전통 한식의 깊은 맛과 서촌의 감성을 담은 사직로 서울에서 여러분을 기다리고 있습니다.
# 펼쳐보기
#  convenience_facilities_and_services: 콜키지 가능
# 무료
# 단체 이용 가능
# 예약
# 남/녀 화장실 구분
# 배달
# 포장
# 대기공간
# 무선 인터넷
# 유아의자
#
#  Parking: 주차가능
# 무료
#  sns: https://www.instagram.com/sajikro_seoul
#
#  review_like_this_part_output: "음식이 맛있어요"이 키워드를 선택한 인원2178
# "매장이 넓어요"이 키워드를 선택한 인원953
# "인테리어가 멋져요"이 키워드를 선택한 인원827
# "재료가 신선해요"이 키워드를 선택한 인원681
# "친절해요"이 키워드를 선택한 인원677
# "고기 질이 좋아요"이 키워드를 선택한 인원650
# "특별한 메뉴가 있어요"이 키워드를 선택한 인원630
# "양이 많아요"이 키워드를 선택한 인원437
# "매장이 청결해요"이 키워드를 선택한 인원390
# "단체모임 하기 좋아요"이 키워드를 선택한 인원214
# "건강한 맛이에요"이 키워드를 선택한 인원98
# "컨셉이 독특해요"이 키워드를 선택한 인원94
# "메뉴 구성이 알차요"이 키워드를 선택한 인원93
# "아늑해요"이 키워드를 선택한 인원90
# "비싼 만큼 가치있어요"이 키워드를 선택한 인원81
# "반찬이 잘 나와요"이 키워드를 선택한 인원79
# "대화하기 좋아요"이 키워드를 선택한 인원55
# "화장실이 깨끗해요"이 키워드를 선택한 인원55
# "차분한 분위기에요"이 키워드를 선택한 인원42
# "가성비가 좋아요"이 키워드를 선택한 인원38
# "혼밥하기 좋아요"이 키워드를 선택한 인원31
# "음식이 빨리 나와요"이 키워드를 선택한 인원27
# "직접 잘 구워줘요"이 키워드를 선택한 인원24
# "잡내가 적어요"이 키워드를 선택한 인원22
# "특별한 날 가기 좋아요"이 키워드를 선택한 인원18
# "아이와 가기 좋아요"이 키워드를 선택한 인원16
# "음악이 좋아요"이 키워드를 선택한 인원13
# "주차하기 편해요"이 키워드를 선택한 인원13
# "향신료가 강하지 않아요"이 키워드를 선택한 인원9
# "뷰가 좋아요"이 키워드를 선택한 인원8
# "술이 다양해요"이 키워드를 선택한 인원7
# "좌석이 편해요"이 키워드를 선택한 인원5
# "현지 맛에 가까워요"이 키워드를 선택한 인원3
# "룸이 잘 되어있어요"이 키워드를 선택한 인원3
# "환기가 잘 돼요"이 키워드를 선택한 인원3
# "기본 안주가 좋아요"이 키워드를 선택한 인원2
# "커피가 맛있어요"이 키워드를 선택한 인원1
# "디저트가 맛있어요"이 키워드를 선택한 인원1
# "혼술하기 좋아요"이 키워드를 선택한 인원1
# "사진이 잘 나와요"이 키워드를 선택한 인원1
# "집중하기 좋아요"이 키워드를 선택한 인원1
#
#  menu: 참나무 소갈비(첫 주문 2인 이상)대표소갈비를 참나무 장작불에서 미디움 굽기로 구워내어드립니다.(첫 주문 시 2인분 부터 주문)29,000원
# 평양물냉면대표사직로만의 육향 가득한 육수,
# 높은 메밀함량의 평양냉면13,000원
# 참나무 불고기 (소)대표참나무 장작불에서 구워낸
# 언양식 석쇠불고기(300g)22,000원
# (겨울메뉴)육개장양지와 무우, 대파를 듬뿍 넣고 진하게 끓인 육개장13,000원
# 어복전골(中)맑은 평양냉면 육수에 미나리와 두부, 양지, 제육을 듬뿍 넣고 끓여낸 깔끔하고 개운한 전골38,000원
# 어복전골(大)맑은 평양냉면 육수에 미나리와 두부, 양지, 제육을 듬뿍 넣고 끓여낸 깔끔하고 개운한 전골65,000원
# 차돌수육부드럽게 삶아낸 차돌양지 (200g)25,000원
# 비빔냉면메밀면의 매력과 매콤달콤한 과일양념장의 조화.(조금 매운편입니다)13,000원
# 큰손만두직접 빚어낸 담백한 이북식 만두로, 일반 왕만두 2알의 크기의 푸짐한 손만두10,000원
# 미나리곰탕평양냉면 육수에 양지를 넣어 끓인 후
# 미나리를 곁들인 맑은 곰탕.15,000원
# 큰손만둣국따뜻한 평양냉면 육수에 큰손만두와 공깃밥13,000원
# 온면따뜻한 평양냉면 육수,
# 높은 메밀 함량의 평양냉면 면 사용13,000원
# 미나리 무침양지와 돼지편육, 미나리, 배추를 매콤새콤한 과일양념장과 들기름에 버무려낸 안주요리15,000원
# </content>
# ==================================================
#
# ==================================================
# 🔄 Node: retrieve_document_naver_gangnam 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# context_naver_gangnam:
# <document><content>store_name: 대진 도원참치 강남역점
#  category: 생선회
#  new_open:
#  rating: 정보없음
#  visited_review: 방문자 리뷰 1,203
#  directions_text: [오시는 길]
#
# 1. 자가용 이용 시,
# 도원참치 강남역 검색 해 주시고
# 주차는 매장 건물 뒷편, KG타워에서 가능하시며 도원참치 이용시간에 한해서 무료 지원됩니다.
# (단, 대형 SUV는 카리프트 이용이 불가하여 주차관리비 1만원이 있습니다. 양해 부탁드립니다.)
# 주차 후에는 건물 후문 이용하시어 엘리베이터로 지하1층 내려오셔도 되고, 대로변으로 나오셔서 도원참치 정문 이용하셔도 됩니다.
#
# 2. 대중교통 이용 시,
# 지하철 이용 시, 강남역 12번 출구에서 직진하셔서 다이소 건물을 지나 도보30초 거리에 있습니다. 바나프레소 옆 도원참치 단독 입구가 있으니 천천히 내려오시면 됩니다.
# (현재 12번 출구 공사로 11번에서 오른쪽으로 우회해서 올라오시면 됩니다.)
# 강남역 12번 출구 버스정거장도 바로 앞 입니다.
# 내용 더보기
#  store_id: 1008611365
#  address: 서울 강남구 테헤란로 113 목화밀라트 지하1층 도원참치 강남역
#  blog_review: 블로그 리뷰 4,174
#  phone_num: 0507-1473-4588
#  business_hours: 월
# 11:00 - 22:50
# 14:30 - 16:30 브레이크타임
# 22:20 라스트오더
# 화
# 11:00 - 22:50
# 14:30 - 16:30 브레이크타임
# 22:20 라스트오더
# 수(1/1)
# 새해 첫날 휴무
# 목
# 11:00 - 22:50
# 14:30 - 16:30 브레이크타임
# 22:20 라스트오더
# 금
# 11:00 - 22:50
# 14:30 - 16:30 브레이크타임
# 22:20 라스트오더
# 토
# 11:00 - 22:50
# 14:30 - 16:30 브레이크타임
# 22:20 라스트오더
# 일
# 정기휴무 (매주 일요일)
#
#  info: 안녕하세요.
# 신선하고 고급스런 참치 회, 초밥, 대게, 전복 등 최상의 해산물들을 아늑하고 프라이빗 한 룸에서 맛 볼 수 있는 1등 맛집,
# 강남역, 역삼역 대표 회식 장소, 데이트 명소, 아늑한 룸식당
#  '대진도원참치 강남역점', '도원참치 강남역' 입니다.
#
# 지중해 맑고 건강한 참치와 환상적인 사이드의 참치 코스, 다양한 구성의 초밥, 합리적인 점심 회 정식, 세트메뉴, 살이 꽉 찬 대게, 바삭바삭 튀김, 든든하고 맛좋은 회덥밮, 얼큰 알탕, 속 시원한 대구탕, 개운한 대구지리, 감칠맛의 홍게라면, 톡톡 알밥, 풍미가득 참치우니동, 부드럽고 달기까지한 사케동 등 다양한 먹거리를 즐기실 수 있는 역삼동에 위치한 식당이자, 강남역과 매우 가깝고 테헤란로 대로변에 있어 찾기 쉬운 강남역 역삼역 맛집 도원참치입니다.
#
# 해가 지날수록 단체 회식의 명소로 거듭나고 있으며, 역삼역 강남역 주변 초대형 규모를 자랑하는 참치 룸식당 횟집 도원참치 강남역 입니다.
#
# 고급스런 저녁 코스가 있으며, 큰 규모에 걸맞게 단체석이 마련되어 있어 단체 점심 식사, 저녁 모임(청첩장, 생일, 환갑, 상견례, 접대 미팅, 계모임) 등을 아늑한 룸에서 진행 하실 수 있습니다. 남녀노소 함께 즐기는 매장이며 점심에 가벼운 회식으로도 좋으며 저녁 단체 회식이나, 오붓하고 아늑한 데이트, 주말에는 가족 외식 자리에도 제격입니다.
#
# 역삼동 강남역에 드문 170석 이상 규모의 대형 매장으로
# 4인~48인 룸, 개인 단독 룸과 단체 룸, Bar(다찌) 자리로 구성되어 있으며, 20인, 30인, 40인 이상 단체도 단독으로 룸 이용이 가능하셔서 단체 회식, 접대, 데이트, 각종 모임으로도 훌륭한 만능형 룸식당 입니다.
#
# 강남역 인근, 테헤란로 대로변에 위치해 있으며
# 강남역 12번 출구에서 100m, 도보 단 1분, 빠른걸음으로 30초 거리에 위치 해 있습니다.
#
# - 주차안내 -
# 주차는 도원참치 매장 뒷편, KG타워에서 가능하시고, 도원참치 강남역 이용시간에 한해서 무료 지원 됩니다.
# (단 대형 SUV(펠리세이드 이상 급)는 주차 승강기 이용이 불가하여 주차관리비 1만원이 있습니다. 양해 부탁드립니다.)
#
# 각종 문의사항은 매장으로 언제든지 연락주세요! 02 556 4588
#
# 참치 무한리필 - *끝판왕* 혼골드(1인)(한정판매)
# 참다랑어 최고급 부위와 살이꽉찬 대게, 우니, 간장게장, 전복, 홍게라면, 대하튀김 등 제공!
#
# 참치 단판메뉴 - *끝판왕* 혼골드싱글(1인)(한정판매)
# 리필없이 혼골드와 같은 구성!
#
# 참치 무한리필 - *인기급상승* VIP(1인)(한정판매)
# 참다랑어80%, 황새치 뱃살과 간장게장, 전복과 대게, 홍게라면, 대하튀김 등 제공!
#
# 참치 단판메뉴 - *인기급상승* VIP싱글(1인)(한정판매)
# 리필없이 VIP와 같은 구성!
#
# 참치 무한리필 - *인기* 일품(1인)
# 참다랑어 50%, 눈다랑어, 황새치 고급부위와 간장게장, 전복 등 제공
#
# 참치 무한리필 - *기본* 대진(1인)
# 참다랑어30%, 눈다랑어 황새치 부위와 간장게장 등 제공
#
# *데이트 추천* 참게세트(2인)
# 참치회와 대게1마리, 그리고 간장게장까지 인기 메뉴로 꽉꽉채운 즐거운 2인 세트
#
# 도원B(2인세트)
# 특정식(or참연정식) 2인(회 36p), 반반반 초밥(12P),전복 2미, 홍게라면
#
# 도원A(2인세트)
# 특정식(or참연정식) 2인(회 36p), 반반반 초밥(12p), 홍게라면
#
# 혼마정식+혼도로초밥6pcs
# 혼마정식과 혼도로초밥 고급부위의 황홀한 향연
#
# *점심 탑* 혼마정식(1인, 점심)
# 점심 정식 인기 탑, 참다랑어회와 부족함 없는 사이드
#
# 특정식(1인, 점심)
# 참치회 18pcs(참다랑어 50%)와 부족함이 없는 사이드
#
# 참연 정식(1인, 참치&연어, 점심)
# 참치와 연어의 조합, 회18p 셀프초밥 구이 튀김 식사
#
# 일반정식(1인, 점심)
# 참치회 18pcs(참다랑어 25%) 와 부족함이 없는 사이드
#
# 감칠맛 홍게라면
# 진짜 홍게가 들어가서, 맛좋은 홍게의 감칠맛이 그대로!
#
# 든든 풍미 회덮밥
# 따라올 수 없는 참치 맛과 푸짐한 야채, 감칠 맛 매콤 소스, 누구나 알지만 특별한 맛
# 펼쳐보기
#  convenience_facilities_and_services: 콜키지 가능
# 유료
# 와인 페어링
# 무한 리필
# 포장
# 배달
# 예약
# 무선 인터넷
# \
# 반려동물 동반
# 단체 이용 가능
# 남/녀 화장실 구분
# 유아의자
# 대기공간
# 출입구 휠체어 이용가능
# 좌석 휠체어 이용가능
#
#  Parking: 주차가능
# 무료
#  sns: https://app.catchtable.co.kr/ct/shop/dowontuna_gangnam
# https://www.instagram.com/dowontuna.gangnam
#
#  review_like_this_part_output: "음식이 맛있어요"이 키워드를 선택한 인원933
# "재료가 신선해요"이 키워드를 선택한 인원718
# "친절해요"이 키워드를 선택한 인원477
# "메뉴 구성이 알차요"이 키워드를 선택한 인원418
# "코스요리가 알차요"이 키워드를 선택한 인원306
# "룸이 잘 되어있어요"이 키워드를 선택한 인원289
# "특별한 메뉴가 있어요"이 키워드를 선택한 인원263
# "대화하기 좋아요"이 키워드를 선택한 인원238
# "단체모임 하기 좋아요"이 키워드를 선택한 인원196
# "인테리어가 멋져요"이 키워드를 선택한 인원157
# "매장이 넓어요"이 키워드를 선택한 인원153
# "아늑해요"이 키워드를 선택한 인원150
# "특별한 날 가기 좋아요"이 키워드를 선택한 인원145
# "오래 머무르기 좋아요"이 키워드를 선택한 인원108
# "주차하기 편해요"이 키워드를 선택한 인원36
# "가성비가 좋아요"이 키워드를 선택한 인원35
# "양이 많아요"이 키워드를 선택한 인원23
# "매장이 청결해요"이 키워드를 선택한 인원19
# "차분한 분위기에요"이 키워드를 선택한 인원12
# "비싼 만큼 가치있어요"이 키워드를 선택한 인원11
# "혼밥하기 좋아요"이 키워드를 선택한 인원7
# "건강한 맛이에요"이 키워드를 선택한 인원7
# "음식이 빨리 나와요"이 키워드를 선택한 인원5
# "반찬이 잘 나와요"이 키워드를 선택한 인원4
# "잡내가 적어요"이 키워드를 선택한 인원3
# "술이 다양해요"이 키워드를 선택한 인원1
# "좌석이 편해요"이 키워드를 선택한 인원1
# "음료가 맛있어요"이 키워드를 선택한 인원1
# "현지 맛에 가까워요"이 키워드를 선택한 인원1
# "고기 질이 좋아요"이 키워드를 선택한 인원1
# "사진이 잘 나와요"이 키워드를 선택한 인원1
# "집중하기 좋아요"이 키워드를 선택한 인원1
#
#  menu: 최고급참치-혼골드(1인)(한정판매)대표참다랑어 끝판왕 적극추천합니다 대게, 간장게장, 전복, 홍게라면, 대하튀김 등 제공됩니다.119,000원
# 반반반초밥(황새치불,연어,참치)대표황홀합니다. 누구나 좋아하는 메뉴19,900원
# 맛있고 든든한 회덮밥대표한번만 먹어 본 사람은 없는 메뉴! 매니아 층이 많습니다. 전국최고의 회덮밥10,900원
# 도원특선초밥대표대박예감
# 계란,새우,장어,연어,참치16,900원
# 참연 정식(참치&연어, 점심)대표미친 조합 참치와 연어가 만났다
# 맛이 없을 수가 없네요
# 회18p 셀프초밥 구이 튀김 식사27,900원
# 혼마정식(1인)(점심)대표점심 정식 인기 탑
# 참다랑어회와 부족함 없는 사이드39,900원
# 참치무한리필-일품(1인)대표참다랑어 50%, 눈다랑어, 황새치 고급부위와 간장게장, 전복 등 제공합니다59,000원
# 최고급참치-혼골드싱글플레이트(1인)대표참치회 리필없이, 혼골드와 같은 구성입니다.99,000원
# 참치무한리필-VIP(1인)(한정판매)대표참다랑어80%, 황새치 뱃살과 간장게장, 전복과 대게, 홍게라면, 대하튀김 등이 제공됩니다89,000원
# 리틀도원456대표어린이 전용(고학년)
# 참치회,초밥(계란,유부,새우),튀김,우동
# 소중히 모시겠습니다.16,900원
# 도원A(2인세트)대표특정식(or참연정식) 2인(회 36p), 반반반초밥(12p),홍게라면83,900원
# 맛있는 조합 참게정식참치와 대게 간장게장까지139,000원
# 참치우니동풍미가득 혼마구로 아카미, 주도로와 녹진한 우니24,900원
# 일반정식(점심)참치회 무려 18pcs(참다랑어 25%) 와 부족함이 없는 사이드22,900원
# 참치물회(물회덮밥)히트예감! 날씨가 따뜻해 질 수록 폭발적인 인기를 얻을 물회! 참치물회17,900원
# </content>
# <document><content>store_name: 강남주막다방
#  category: 요리주점
#  new_open:
#  rating: 정보없음
#  visited_review: 방문자 리뷰 258
#  directions_text: 신사역에서 8번출구로 도보로 5분거리에 위치해 있으며 8번출구에서 직진 가로수길 입구 좌회전 하시면 전방 150m 우측에 롤링파스타건물 지하입니다.
# 내용 더보기
#  store_id: 1204418832
#  address: 서울 강남구 가로수길 16 덕암빌딩 지하1층
#  blog_review: 블로그 리뷰 219
#  phone_num: 0507-1399-0720
#  business_hours: 수(1/1)
# 휴무
# 목
# 16:00 - 03:00
# 02:00 라스트오더
# 금
# 16:00 - 03:00
# 02:00 라스트오더
# 토
# 16:00 - 03:00
# 02:00 라스트오더
# 일
# 16:30 - 01:30
# 00:30 라스트오더
# 월
# 16:00 - 03:00
# 02:00 라스트오더
# 화
# 16:00 - 03:00
# 02:00 라스트오더
#
#  info: 신사동 가로수길에 최고 안주 맛집!!
# 집밥같이 재료와 맛에 최선을 다한 요리를 다양하게 즐기면서 한잔 할 수 있는 레트로 스타일의 핫 플레이스 강남주막다방.
# DJ박스에 듣고 싶은 음악 신청도 하실 수 있고 홀과 분리된 공간에서 모임도 가능합니다.
# 스크린 골프 룸이 있어 지인분들과 라운딩도 즐기면서 다양한 음식도 드시면서 즐거운 시간 보낼 수 있어요~!!(룸은 예약 필수입니다^^)
#  convenience_facilities_and_services: 단체 이용 가능
# 무선 인터넷
# 남/녀 화장실 구분
# 예약
#
#  Parking: 주차가능
#  sns: https://booking.naver.com/?area=bmp
# https://www.instagram.com/kangnam777
#
#  review_like_this_part_output: "음식이 맛있어요"이 키워드를 선택한 인원212
# "친절해요"이 키워드를 선택한 인원130
# "단체모임 하기 좋아요"이 키워드를 선택한 인원116
# "음악이 좋아요"이 키워드를 선택한 인원107
# "기본 안주가 좋아요"이 키워드를 선택한 인원90
# "술이 다양해요"이 키워드를 선택한 인원65
# "대화하기 좋아요"이 키워드를 선택한 인원59
# "특별한 메뉴가 있어요"이 키워드를 선택한 인원54
# "가성비가 좋아요"이 키워드를 선택한 인원52
# "인테리어가 멋져요"이 키워드를 선택한 인원48
# "매장이 청결해요"이 키워드를 선택한 인원40
# "오래 머무르기 좋아요"이 키워드를 선택한 인원37
# "화장실이 깨끗해요"이 키워드를 선택한 인원26
# "매장이 넓어요"이 키워드를 선택한 인원21
# "메뉴 구성이 알차요"이 키워드를 선택한 인원12
# "파티하기 좋아요"이 키워드를 선택한 인원8
# "재료가 신선해요"이 키워드를 선택한 인원6
# "혼술하기 좋아요"이 키워드를 선택한 인원4
# "양이 많아요"이 키워드를 선택한 인원4
# "좌석이 편해요"이 키워드를 선택한 인원3
# "룸이 잘 되어있어요"이 키워드를 선택한 인원3
# "컨셉이 독특해요"이 키워드를 선택한 인원1
# "라이브공연이 훌륭해요"이 키워드를 선택한 인원1
# "주차하기 편해요"이 키워드를 선택한 인원1
# "건강한 맛이에요"이 키워드를 선택한 인원1
#
#  menu: 매칼닭볶음탕대표각종야채 듬뿍 들어간 매콤 칼칼한 닭볶음탕
# 술술 술을 부르는 최고안주!!39,000원
# 홍합탕대표냄비 한가득 푸짐한 홍합탕 국물이 끝내줘요!!22,000원
# 오뎅탕대표각종 다양한 어묵이 푸짐하게 홍합과 함께 시원한 국물로 소주가 술술 들어가는 시그니처 메뉴29,000원
# 밀푀유나베대표고기와 숙주와 야채가득 담백한 육수에 끓여 건져서 먹는 건강하고 담백한 요리!35,000원
# 고추장찌개대표한돈 목살고기와 감자와 야채 듬뿍 칼칼한 국물에 밥이 생각나는 국물요리25,000원
# 편백해물삼합찜대표편백찜기에 해물(오징어,전복,대하,가리비등)과 푸짐한 야채와 우삼겹을 넣어 찐 최고요리변동
# 겉바속촉가지튀김대표겉바속촉.. 말이 필요없는 고급일품요리
# 꼭 먹어봐야 하는 안주!!
# 수제소스 찍어 한입에19,000원
# 모듬전대표다양한 전 종류로 한상 푸짐한 안주(굴전,호박전,육전,감자전,동태전,옛날소세지,두부전 등)32,000원
# 굴전대표바다향기 가득한 싱싱한 굴로 만든 전변동
# 치즈감자채전대표바삭바삭하게 감자채를 부쳐서 모짜렐라 치즈를 한가득 올려 풍미가득한 맛을 느낄수 있어요23,000원
# 모듬조개탕대표가리비,홍합,바지락등 다양한 조개들로 가득 드실수 있는 조개탕29,000원
# 오징어숙회대표오징어숙회와 매콤새콤 야채무침과 곁들여 드시면 맛이 2배로 더 맛있어요!25,000원
# 닭갈비대표매콤 달콤 양념에 먹을수록 당기는 닭갈비!
# 각종야채와 떡등 함께 드시고 양념에 볶음밥 최고28,000원
# 두부 두루치기대표두부와 볶음김치 그리고 삼겹살 말이 필요없는 아는 그맛!! 술안주로 최고25,000원
# 국물떡볶이대표야채 듬뿍 들어간 국물떡볶이와 해장하세요~~!!(해물or야채 선택가능)25,000원
# </content>
# <document><content>store_name: 수지상회 강남1호점
#  category: 요리주점
#  new_open:
#  rating: 정보없음
#  visited_review: 방문자 리뷰 1,750
#  directions_text: 수지상회는 2층에 있습니다.
# 건물1층은 보승회관 입니다. 보승회관을 정면으로 바라보시고 우측 통로를 통해 건물 내부로 들어오셔서 계단 혹은 엘레베이터 이용하셔서 2층으로 올라오시면 하트 조명이 보이십니다. 문을 열고 들어오시면 건물 내부지만 충분한 개방감을 느끼실 수 있는 수지상회가 보이십니다.
#
# 2호선 강남역에서 내리셔서 12번 출구로 나오신 다음
# 왼쪽으로 돌아 내려오셔서 오른쪽 첫 골목으로 들오셔서
# 100m가량 들어오시면(세븐일레븐,빌리엔젤을 지나)
# 왼편 2층에 위치하고 있습니다.
#
# 강남역과 1분거리에 있는 오기도 편하고 집가기도 편한 강남억술집 수지상회에서 여러분을 기다리겠습니다
#
# 주차는 죄송스럽지만 따로 공간이 마련되어 있지 않습니다.
# 근처 유료 주차장 이용해주시면 감사하겠습니다!!
# 내용 더보기
#  store_id: 1810165759
#  address: 서울 강남구 테헤란로1길 17 2층
#  blog_review: 블로그 리뷰 2,361
#  phone_num: 0507-1366-6974
#  business_hours: 매일
# 16:00 - 05:00
#
#  info: 안녕하세요.
#
# @@@@인스타 맛집@@@@
# @@@SNS핫플@@@
# @@@분위기 맛집@@@
# @@@안주 맛집@@@
# @@@데이트 베스트 코스@@@
# @@@하이볼 맛집@@@
# @@@강남역술집@@@
# @@@강남술집@@@
#
# 매장 방문시 신분증 필수 지참인 부분 양해부탁드립니다.
#
# 수 많은 인플루언서들의 선택을 받은 강남1등 술집 수지상회 강남 1호점 인사드리겠습니다!!!
#
# 날이 더워지고, 추워지고, 비가오고, 눈이오고 어떤 상황에서도
#
# 굴하지 않고 문을 여는 강남역 술집!
#
# 지하철역에서 3분거리에 위치해서 막차 놓칠리 없고!
#
# 강남에서 제일 화장실 깨끗하고!!
#
# 모두가 만족하는 서비스를 제공해드리는 이 곳!
#
# 수지상회 강남점입니다.
#
# 봄엔 꽃향기를 맡으며!!
#
# 여름엔 시원하게!!
#
# 가을엔 선선한 바람을 맞으며!!
#
# 겨울엔 따뜻하게!!
#
# 연인과 데이트를 하기에도 좋고, 가족끼리 오랜만에 외식하기에도 좋고, 손님을 모시고 가도 좋고, 친구랑 놀러가기도 좋은 매장입니다.
#
# 항상 뻔한 음식과 뻔한 맛 뻔한 일상에 지치신 분들을 위해서 저희가 그동안 없었던 특별한 맛, 특별한 음식, 일상에서의 색다로움을 즐기실 수 있도록 준비했습니다.
#
# 항상 고객 여러분들을 생각하고 한분 한분 최선을 다해서 니즈를 맞춰드리는 저희가 강남에 왔습니다!!
#
# 취향저격 다양한 종류의 메뉴들!!
#
# 갈빗대 통째 드리는 **수지 우대 갈비**
# - 소의 가장 큰 갈빗대로 요즘 유행하는 그 소고기 맞습니다.
# 수비드로 조리된 족발 가득 담긴 ***학센 플레터***
# - 독일식 족발인 겉바속촉 족발을 한국에서 즐기실수있습니다.
# 매일 공수해온 채소로 준비한 **수지 샤브 전골**
# - 신선한 야채와 신선한 고기로 밀가루 하나 없는 건강한 전골입니다.
# 그 어떤 술집에서도 맛 볼수 없는 돼지 특수 부위 **항정수육**
# - 항정살 이젠 다들 아시죠? 그걸 수육으로 만들어서 촉촉하지만 겉은 바삭하게 만들어봤습니다.
# 술 먹으면서 몸까지 챙기는 양지와 스지가 들어간 **수지 스지탕**
# - 소의 힘줄 스지로 만드는 보양탕인데, 맛도 있어 해장도 가능
# 여기가 마라탕 집인지 술집인지 이젠 나도 헷갈리는 **마라전골**
# - 마라떡볶이, 마라탕 등 대한민국을 집어삼킨 마라
# 중국집에서 짬뽕 안시켜먹는 수지 직원들 최애 안주 ***차돌듬뿍짬뽕탕***
# - 다들 아시죠? 그 짬뽕 그대로 맞습니다 원팩? 안써요
# 시원시원한 *냉채수육*과 *냉채차돌*
# - 시원한 안주 생각나시잖아요 술먹다 보면 그때 드시죠
# 양 많고 저렴하게 준비된 갖가지 - 사이드 메뉴 -
# - 순살치킨, 간장치킨, 생과일화채, 멜론, 파인애플, 팥빙수, 감자튀김 등등 30여가지 사이드
# 식사를 책임질 수 있는 다양한 -식사 메뉴-
# - 참치주먹밥, 치킨마요덮밥, 김치볶음밥 등 10여가지 식사메뉴
#
# 안주 드시면서 드셔야 몸 건강히 잘 드실 수 있는거 아시죠??
#
# 수지 상회는 퀄리티, 서비스, 청결 3대 원칙을 준수하고 있으며 언제나 고객의 니즈를 파악하기 위해 노력하며 발전하고 있습니다.
#
# 강남역 최다 종류 주류 보유중입니다!!
#
# 수지상회의 특별한 시그니처 하이볼과 남여노소 불문하고
#
# 누구한테나 사랑받는 하이볼들이 수십종류 보유중입니다.
#
# 요즘 워라벨이 중요한 이시대에 가볍고 비싸지않게 맛있는
#
# 하이볼들로 지인들과 친구들과 직장동료들과 가족들과
#
# 행복하고, 즐거운 시간을 보내실 수 있도록 강남역술집 수지상회에서 준비하겠습니다.
#
# 고객님들은 몸만 오세요 나머진 저희가 할게요.
#
# @@ 예약시 참고해주세요.
# - 주말(금, 토) 예약시 18시 이후는 일주일전에 예약이 조기마감 될 수 있으니 양해부탁드립니다 :)
# - 예약 완료 후 10분 경과시 no-show 처리로 예약이 취소처리 될 수 있습니다. 변동사항 생기시면 매장으로 전화주세요 ^^
# - 인원 수 맞춰서 예약 주시고 인원수 제한이 걸리시면 따로 유선 연락주시기 바라겠습니다
#
# 오늘 하루도 고생 많으셨습니다. 항상 행복하시고 즐겁게 마시고 드실수 있도록 항상 노력하고 발전하는 수지상회가 되겠습니다. 감사합니다!
# 펼쳐보기
#  convenience_facilities_and_services: 콜키지 가능
# 유료
# 생일 혜택
# 단체 이용 가능
# 남/녀 화장실 구분
# 예약
# 대기공간
# 출입구 휠체어 이용가능
# 좌석 휠체어 이용가능
#
#  Parking: 주차가능
# 유료
# 최초 5분 300원
# 추가 요금 5분당 300원, 최대 100,000원
#  sns: https://blog.naver.com/sswp1020
# https://www.instagram.com/suji__gn
#
#  review_like_this_part_output: "음식이 맛있어요"이 키워드를 선택한 인원1229
# "친절해요"이 키워드를 선택한 인원698
# "인테리어가 멋져요"이 키워드를 선택한 인원687
# "술이 다양해요"이 키워드를 선택한 인원630
# "음악이 좋아요"이 키워드를 선택한 인원473
# "대화하기 좋아요"이 키워드를 선택한 인원448
# "기본 안주가 좋아요"이 키워드를 선택한 인원447
# "매장이 청결해요"이 키워드를 선택한 인원446
# "특별한 메뉴가 있어요"이 키워드를 선택한 인원334
# "단체모임 하기 좋아요"이 키워드를 선택한 인원333
# "가성비가 좋아요"이 키워드를 선택한 인원312
# "오래 머무르기 좋아요"이 키워드를 선택한 인원249
# "화장실이 깨끗해요"이 키워드를 선택한 인원189
# "매장이 넓어요"이 키워드를 선택한 인원55
# "메뉴 구성이 알차요"이 키워드를 선택한 인원44
# "혼술하기 좋아요"이 키워드를 선택한 인원26
# "양이 많아요"이 키워드를 선택한 인원15
# "주차하기 편해요"이 키워드를 선택한 인원12
# "사진이 잘 나와요"이 키워드를 선택한 인원11
# "음식이 빨리 나와요"이 키워드를 선택한 인원6
# "건강한 맛이에요"이 키워드를 선택한 인원6
# "좌석이 편해요"이 키워드를 선택한 인원5
# "아늑해요"이 키워드를 선택한 인원5
# "뷰가 좋아요"이 키워드를 선택한 인원5
# "컨셉이 독특해요"이 키워드를 선택한 인원4
# "비싼 만큼 가치있어요"이 키워드를 선택한 인원4
# "음료가 맛있어요"이 키워드를 선택한 인원3
# "재료가 신선해요"이 키워드를 선택한 인원3
# "야외공간이 멋져요"이 키워드를 선택한 인원2
# "파티하기 좋아요"이 키워드를 선택한 인원2
# "라이브공연이 훌륭해요"이 키워드를 선택한 인원1
# "특별한 날 가기 좋아요"이 키워드를 선택한 인원1
#
#  menu: 수지닭볶음탕대표26,900원
# 수지학센플레터대표수비드 조리된 돼지 앞발!!!!
# 독일식 슈바인 학센을 만나보세요!!!31,900원
# 수지 스지탕대표소 힘줄인 스지와 양지수육이 듬뿍 들어간 건강에도 좋고 맛도 좋은 먹은사람은 한번 더 먹는30,900원
# 수지양지수육한판대표사골국물에 촉촉히 적셔가면서 먹는 양지수육을 술집에서????!!!29,900원
# 수지 빨간 어묵탕대표해물 들어간 얼큰~~~한 빨간 어묵탕!!24,900원
# 내가제일잘나베대표롱치즈돈까스가 통으로 올라간 수지상회 돈까스 김치나베!!23,900원
# 수코바 숯불 치킨대표수코바 숯불 치킨!! 국내산 닭을 이용해 구운 숯불 치킨!!!!!!!!!23,900원
# 다양한 하이볼여기가 강남역 하이볼 성지!! 엄청나게 다양한 하이볼 라인업!변동
# 수지샤브마라전골마라가 세상을 지배했다. 수지상회 마저 점령한 마라전골 완자까지 올라가요 존맛탱..31,900원
# 전,전,전감자전, 부추전, 김치전변동
# 수지샤브전골밀푀유 베이스에 만두까지 퐁당 맑은 육수로 소주 꼴깍!!28,900원
# 마라떡볶이마라가 세상을 지배한다 마라떡볶이 출시!!!22,900원
# 차돌듬뿍짬뽕탕저희는 중국집에서 짬뽕 안시켜먹습니다. 이게 더 맛있거든요.22,900원
# 코찡냉채차돌불향을 입힌 우삼겹을 시원하게 냉채소스와 곁들여 먹는 간단하게 즐기기 좋은 안주21,900원
# 차돌떡볶이오랜시간 연구끝에 나온 특제소스로 만드는 매콜달콤한 떡볶이 위에 우삼겹까지 듬뿍20,900원
# </content>
# <document><content>store_name: 수지상회 강남1호점
#  category: 요리주점
#  new_open:
#  rating: 정보없음
#  visited_review: 방문자 리뷰 1,750
#  directions_text: 수지상회는 2층에 있습니다.
# 건물1층은 보승회관 입니다. 보승회관을 정면으로 바라보시고 우측 통로를 통해 건물 내부로 들어오셔서 계단 혹은 엘레베이터 이용하셔서 2층으로 올라오시면 하트 조명이 보이십니다. 문을 열고 들어오시면 건물 내부지만 충분한 개방감을 느끼실 수 있는 수지상회가 보이십니다.
#
# 2호선 강남역에서 내리셔서 12번 출구로 나오신 다음
# 왼쪽으로 돌아 내려오셔서 오른쪽 첫 골목으로 들오셔서
# 100m가량 들어오시면(세븐일레븐,빌리엔젤을 지나)
# 왼편 2층에 위치하고 있습니다.
#
# 강남역과 1분거리에 있는 오기도 편하고 집가기도 편한 강남억술집 수지상회에서 여러분을 기다리겠습니다
#
# 주차는 죄송스럽지만 따로 공간이 마련되어 있지 않습니다.
# 근처 유료 주차장 이용해주시면 감사하겠습니다!!
# 내용 더보기
#  store_id: 1810165759
#  address: 서울 강남구 테헤란로1길 17 2층
#  blog_review: 블로그 리뷰 2,362
#  phone_num: 0507-1366-6974
#  business_hours: 매일
# 16:00 - 05:00
#
#  info: 안녕하세요.
#
# @@@@인스타 맛집@@@@
# @@@SNS핫플@@@
# @@@분위기 맛집@@@
# @@@안주 맛집@@@
# @@@데이트 베스트 코스@@@
# @@@하이볼 맛집@@@
# @@@강남역술집@@@
# @@@강남술집@@@
#
# 매장 방문시 신분증 필수 지참인 부분 양해부탁드립니다.
#
# 수 많은 인플루언서들의 선택을 받은 강남1등 술집 수지상회 강남 1호점 인사드리겠습니다!!!
#
# 날이 더워지고, 추워지고, 비가오고, 눈이오고 어떤 상황에서도
#
# 굴하지 않고 문을 여는 강남역 술집!
#
# 지하철역에서 3분거리에 위치해서 막차 놓칠리 없고!
#
# 강남에서 제일 화장실 깨끗하고!!
#
# 모두가 만족하는 서비스를 제공해드리는 이 곳!
#
# 수지상회 강남점입니다.
#
# 봄엔 꽃향기를 맡으며!!
#
# 여름엔 시원하게!!
#
# 가을엔 선선한 바람을 맞으며!!
#
# 겨울엔 따뜻하게!!
#
# 연인과 데이트를 하기에도 좋고, 가족끼리 오랜만에 외식하기에도 좋고, 손님을 모시고 가도 좋고, 친구랑 놀러가기도 좋은 매장입니다.
#
# 항상 뻔한 음식과 뻔한 맛 뻔한 일상에 지치신 분들을 위해서 저희가 그동안 없었던 특별한 맛, 특별한 음식, 일상에서의 색다로움을 즐기실 수 있도록 준비했습니다.
#
# 항상 고객 여러분들을 생각하고 한분 한분 최선을 다해서 니즈를 맞춰드리는 저희가 강남에 왔습니다!!
#
# 취향저격 다양한 종류의 메뉴들!!
#
# 갈빗대 통째 드리는 **수지 우대 갈비**
# - 소의 가장 큰 갈빗대로 요즘 유행하는 그 소고기 맞습니다.
# 수비드로 조리된 족발 가득 담긴 ***학센 플레터***
# - 독일식 족발인 겉바속촉 족발을 한국에서 즐기실수있습니다.
# 매일 공수해온 채소로 준비한 **수지 샤브 전골**
# - 신선한 야채와 신선한 고기로 밀가루 하나 없는 건강한 전골입니다.
# 그 어떤 술집에서도 맛 볼수 없는 돼지 특수 부위 **항정수육**
# - 항정살 이젠 다들 아시죠? 그걸 수육으로 만들어서 촉촉하지만 겉은 바삭하게 만들어봤습니다.
# 술 먹으면서 몸까지 챙기는 양지와 스지가 들어간 **수지 스지탕**
# - 소의 힘줄 스지로 만드는 보양탕인데, 맛도 있어 해장도 가능
# 여기가 마라탕 집인지 술집인지 이젠 나도 헷갈리는 **마라전골**
# - 마라떡볶이, 마라탕 등 대한민국을 집어삼킨 마라
# 중국집에서 짬뽕 안시켜먹는 수지 직원들 최애 안주 ***차돌듬뿍짬뽕탕***
# - 다들 아시죠? 그 짬뽕 그대로 맞습니다 원팩? 안써요
# 시원시원한 *냉채수육*과 *냉채차돌*
# - 시원한 안주 생각나시잖아요 술먹다 보면 그때 드시죠
# 양 많고 저렴하게 준비된 갖가지 - 사이드 메뉴 -
# - 순살치킨, 간장치킨, 생과일화채, 멜론, 파인애플, 팥빙수, 감자튀김 등등 30여가지 사이드
# 식사를 책임질 수 있는 다양한 -식사 메뉴-
# - 참치주먹밥, 치킨마요덮밥, 김치볶음밥 등 10여가지 식사메뉴
#
# 안주 드시면서 드셔야 몸 건강히 잘 드실 수 있는거 아시죠??
#
# 수지 상회는 퀄리티, 서비스, 청결 3대 원칙을 준수하고 있으며 언제나 고객의 니즈를 파악하기 위해 노력하며 발전하고 있습니다.
#
# 강남역 최다 종류 주류 보유중입니다!!
#
# 수지상회의 특별한 시그니처 하이볼과 남여노소 불문하고
#
# 누구한테나 사랑받는 하이볼들이 수십종류 보유중입니다.
#
# 요즘 워라벨이 중요한 이시대에 가볍고 비싸지않게 맛있는
#
# 하이볼들로 지인들과 친구들과 직장동료들과 가족들과
#
# 행복하고, 즐거운 시간을 보내실 수 있도록 강남역술집 수지상회에서 준비하겠습니다.
#
# 고객님들은 몸만 오세요 나머진 저희가 할게요.
#
# @@ 예약시 참고해주세요.
# - 주말(금, 토) 예약시 18시 이후는 일주일전에 예약이 조기마감 될 수 있으니 양해부탁드립니다 :)
# - 예약 완료 후 10분 경과시 no-show 처리로 예약이 취소처리 될 수 있습니다. 변동사항 생기시면 매장으로 전화주세요 ^^
# - 인원 수 맞춰서 예약 주시고 인원수 제한이 걸리시면 따로 유선 연락주시기 바라겠습니다
#
# 오늘 하루도 고생 많으셨습니다. 항상 행복하시고 즐겁게 마시고 드실수 있도록 항상 노력하고 발전하는 수지상회가 되겠습니다. 감사합니다!
# 펼쳐보기
#  convenience_facilities_and_services: 콜키지 가능
# 유료
# 생일 혜택
# 단체 이용 가능
# 남/녀 화장실 구분
# 예약
# 대기공간
# 출입구 휠체어 이용가능
# 좌석 휠체어 이용가능
#
#  Parking: 주차가능
# 유료
# 최초 5분 300원
# 추가 요금 5분당 300원, 최대 100,000원
#  sns: https://blog.naver.com/sswp1020
# https://www.instagram.com/suji__gn
#
#  review_like_this_part_output: "음식이 맛있어요"이 키워드를 선택한 인원1228
# "친절해요"이 키워드를 선택한 인원697
# "인테리어가 멋져요"이 키워드를 선택한 인원687
# "술이 다양해요"이 키워드를 선택한 인원630
# "음악이 좋아요"이 키워드를 선택한 인원472
# "대화하기 좋아요"이 키워드를 선택한 인원448
# "기본 안주가 좋아요"이 키워드를 선택한 인원446
# "매장이 청결해요"이 키워드를 선택한 인원446
# "특별한 메뉴가 있어요"이 키워드를 선택한 인원334
# "단체모임 하기 좋아요"이 키워드를 선택한 인원333
# "가성비가 좋아요"이 키워드를 선택한 인원312
# "오래 머무르기 좋아요"이 키워드를 선택한 인원249
# "화장실이 깨끗해요"이 키워드를 선택한 인원188
# "매장이 넓어요"이 키워드를 선택한 인원55
# "메뉴 구성이 알차요"이 키워드를 선택한 인원44
# "혼술하기 좋아요"이 키워드를 선택한 인원26
# "양이 많아요"이 키워드를 선택한 인원15
# "주차하기 편해요"이 키워드를 선택한 인원12
# "사진이 잘 나와요"이 키워드를 선택한 인원11
# "음식이 빨리 나와요"이 키워드를 선택한 인원6
# "건강한 맛이에요"이 키워드를 선택한 인원6
# "좌석이 편해요"이 키워드를 선택한 인원5
# "아늑해요"이 키워드를 선택한 인원5
# "뷰가 좋아요"이 키워드를 선택한 인원5
# "컨셉이 독특해요"이 키워드를 선택한 인원4
# "비싼 만큼 가치있어요"이 키워드를 선택한 인원4
# "음료가 맛있어요"이 키워드를 선택한 인원3
# "재료가 신선해요"이 키워드를 선택한 인원3
# "야외공간이 멋져요"이 키워드를 선택한 인원2
# "파티하기 좋아요"이 키워드를 선택한 인원2
# "라이브공연이 훌륭해요"이 키워드를 선택한 인원1
# "특별한 날 가기 좋아요"이 키워드를 선택한 인원1
#
#  menu: 수지닭볶음탕대표26,900원
# 수지학센플레터대표수비드 조리된 돼지 앞발!!!!
# 독일식 슈바인 학센을 만나보세요!!!31,900원
# 수지 스지탕대표소 힘줄인 스지와 양지수육이 듬뿍 들어간 건강에도 좋고 맛도 좋은 먹은사람은 한번 더 먹는30,900원
# 수지양지수육한판대표사골국물에 촉촉히 적셔가면서 먹는 양지수육을 술집에서????!!!29,900원
# 수지 빨간 어묵탕대표해물 들어간 얼큰~~~한 빨간 어묵탕!!24,900원
# 내가제일잘나베대표롱치즈돈까스가 통으로 올라간 수지상회 돈까스 김치나베!!23,900원
# 수코바 숯불 치킨대표수코바 숯불 치킨!! 국내산 닭을 이용해 구운 숯불 치킨!!!!!!!!!23,900원
# 다양한 하이볼여기가 강남역 하이볼 성지!! 엄청나게 다양한 하이볼 라인업!변동
# 수지샤브마라전골마라가 세상을 지배했다. 수지상회 마저 점령한 마라전골 완자까지 올라가요 존맛탱..31,900원
# 전,전,전감자전, 부추전, 김치전변동
# 수지샤브전골밀푀유 베이스에 만두까지 퐁당 맑은 육수로 소주 꼴깍!!28,900원
# 마라떡볶이마라가 세상을 지배한다 마라떡볶이 출시!!!22,900원
# 차돌듬뿍짬뽕탕저희는 중국집에서 짬뽕 안시켜먹습니다. 이게 더 맛있거든요.22,900원
# 코찡냉채차돌불향을 입힌 우삼겹을 시원하게 냉채소스와 곁들여 먹는 간단하게 즐기기 좋은 안주21,900원
# 차돌떡볶이오랜시간 연구끝에 나온 특제소스로 만드는 매콜달콤한 떡볶이 위에 우삼겹까지 듬뿍20,900원
# </content>
# <document><content>store_name: 한판도 역삼점
#  category: 육류,고기요리
#  new_open:
#  rating: 정보없음
#  visited_review: 방문자 리뷰 1,879
#  directions_text: 한판도는 강남역과 역삼역 중간에 위치해 있습니다.
#
# 강남역 1번출구에서 나와서 지나 역삼역 방향으로 300미터 직진후(국기원사거리지나서 다음골목길) 우리은행 우측으로 50미터정도 들어오시면 한판도가 있습니다.
#
# 역삼역3번출구에서 나와 강남파이낸스빌딩 지나 하나은행 지나 우리은행 골목길로 좌회전 소울하다 호텔 바로 지나 고기집 한판도
#
# *강남역, 역삼역에 오시면, 가성비맛집 강남 고기집 한판도
# 주소: 서울시 강남구 테헤란로 10길 9 , 1층 한판도
# 1) 강남역 CGV에서 영화보고 강남역 거리에서 쇼핑하고 걸어서 10분 만에 도착! 강남역에서 도보 10분 이내 거리!
# 2) 역삼역 3번출구에서 도보 6분거리 이며, 역삼역맛집 고기집 한판도 가게 앞 무료주차 가능 (발렛없음) 원치과 주차장 저녁이후 가능!
# 내용 더보기
#  store_id: 1236412447
#  address: 서울 강남구 테헤란로10길 9 그랑프리빌딩 1층
#  blog_review: 블로그 리뷰 2,442
#  phone_num: 0507-1382-3959
#  business_hours: 화
# 11:30 - 22:00
# 14:00 - 16:00 브레이크타임
# 21:30 라스트오더
# 수(1/1)
# 새해 첫날16:30 - 21:00
# 목
# 11:30 - 22:00
# 14:00 - 16:00 브레이크타임
# 21:30 라스트오더
# 금
# 11:30 - 22:00
# 14:00 - 16:00 브레이크타임
# 21:30 라스트오더
# 토
# 16:30 - 21:00
# 20:30 라스트오더
# 일
# 정기휴무 (매주 일요일)
# 월
# 11:30 - 22:00
# 14:00 - 16:00 브레이크타임
# 21:30 라스트오더
#
#  info: Meets Lounge
# 고기와 라운지가 만나다,
# 강남역 고기집 한판도입니다.
# 100명 이하 단체 및 대관 가능 / 대형스크린 및 마이크 보유 / 강남주차장맛집/ 역삼주차장맛집
#
# 한판도 고기집 앞 주차장 무료이용가능 ( 원치과 주차장 저녁이후 사용가능)
#
# 단체모임 / 단체회식 / 회식맛집 / 삼겹살맛집 / 콜키지프리맛집
#
# 저희 한판도는 국내산 최고급 돼지를 합리적인 가격으로 한판에 제공하고 있습니다. 숯불구이로 퀄리티있는 목살 삼겹살을 드셔보세요 !!
#
# 저희 한판도는 고객의 기대를 뛰어넘는 혁신적인 라이프스타일과 엔터테인먼트 경험을 지속적으로 제공함으로써 젊음의 열정과 기운을 상기시키는 철학을 가지고 있습니다.
#
# 고객님들의 즐거운 한 끼 식사가 될 수 있게
# 음식뿐만 아니라 음악, 서비스에 항상 신경 쓰고 있습니다.
#
# 훈련받은 직원의 서비스와 친절함,
# 재즈 및 음악이 흘러나오는 매장에서는 라운지와 같은 분위기를 느끼실 수 있습니다.
#
# 무엇보다 고깃집은 맛이 중요합니다.
#
# 두툼하여 스테이크 같은 목살은 육즙이 풍부하여 소고기 같은 식감을 느끼실 수 있고,
# 마블링이 살아있는 삼겹살은 입속에서 녹아내리는 식감을 경험하실 수 있습니다.
#
# 고기와 함께 색다른 조합으로 드실 수 있는 활전복까지 판매하고 있습니다.
# 서울에서는 접하기 힘든 '고기+전복+김치' 삼합까지 합리적인 가격으로 제공하고 있습니다.
#
# 또 한 가지 포인트,
# 반찬 하나하나부터 된장찌개까지 모두 저희가 직접 만들고 있습니다.
# 35년 경력의 사우디아라비아 최고 주방장 출신 한국인 셰프의 노하우 레시피로 만든
# 된장찌개, 겉절이, 장아찌 그리고 보리쌈장까지!
# 반찬에서 부터 정성을 맛보실 수 있습니다.
# 또한 멜젓소스도 저희 가게의 별미입니다.
#
# 한판도 주류는 소주 맥주는 물론이거니와,
# 시원한 생맥주와 복분자,
# 술을 잘 못드시는 분들을 위한 논알콜 맥주,
# 직접 제작한 저칼로리 시그니처 와인까지 준비되어 있습니다.
#
# 시설이 깔끔하고 쾌적하여 강남 및 역삼 '단체 회식이나 모임 장소'로도 좋아 많은 회사원분들께서 찾아주고 계십니다.
# 약 90명까지 단체 예약이나 대관이 가능하며,
# 마이크 & 노래방 기기 & 빔 프로젝터도 있어 단체 회식, 행사 진행 모두 가능합니다.
# 가게 바로 앞엔 주차장이 있어 무료 주차가 가능하여 차를 가져오셔도 문제없습니다.
# '회사 동료들과 맛있는 고기를 먹으며 분위기까지 좋으면 좋겠다.' 하면 한판도!
#
# 위치는 강남역 1번 출구와 역삼역 3번 출구에서 도보로 5분 거리에 있어 대중교통을 이용하셔도 가깝습니다.
# 강남에서 데이트나 가족 모임, 회사 회식, 각종 모임을 하실 때 접근하기 좋은 위치에 있습니다.
#
# 예약 문의나 궁금한 점은 전화 주시면 친절하게 응대해 드리겠습니다!
#
# 오실 때마다 새롭게 발전하는 한판도가 되기 위해 고기 숙성, 메뉴 개발에 힘쓰고 있습니다. 언제나 노력하는 한판도가 되도록 하겠습니다.
#
# * 현재 콜키지프리 이벤트 진행 중 입니다. 와인잔, 아이스 바스켓, 오프너, 언더락잔 등 구비되어 있습니다. 콜키지프리를 이용하시면서 가성비있게 행복한 추억을 만드시길 바랍니다
#
# 한판도 대학로점
# Meets Lounge
# 고기와 라운지가 만나다,
# 대학로 고기집 한판도입니다.
# 50명 이하 단체 및 대관 가능 마이크 보유
#
# 혜화역 4번출구에서 도보 2분거리!! 서울대학병원 옆에 있는 대학로 CGV 대명길에 있습니다!! 가성비맛집으로 대학로삼겹살과 고기전복삼합을 즐겨보세요
# 펼쳐보기
#  convenience_facilities_and_services: 콜키지 가능
# 무료
# 와인 페어링
# 단체 이용 가능
# 예약
# 남/녀 화장실 구분
# 무선 인터넷
# 포장
# 출입구 휠체어 이용가능
# 좌석 휠체어 이용가능
#
#  Parking: 주차가능
# 무료
#  sns: https://app.catchtable.co.kr/ct/shop/hanpando
# https://www.instagram.com/hanpando.official/
#
#  review_like_this_part_output: "음식이 맛있어요"이 키워드를 선택한 인원1631
# "고기 질이 좋아요"이 키워드를 선택한 인원1117
# "친절해요"이 키워드를 선택한 인원698
# "단체모임 하기 좋아요"이 키워드를 선택한 인원665
# "매장이 넓어요"이 키워드를 선택한 인원654
# "매장이 청결해요"이 키워드를 선택한 인원437
# "인테리어가 멋져요"이 키워드를 선택한 인원345
# "양이 많아요"이 키워드를 선택한 인원333
# "특별한 메뉴가 있어요"이 키워드를 선택한 인원322
# "재료가 신선해요"이 키워드를 선택한 인원270
# "가성비가 좋아요"이 키워드를 선택한 인원201
# "직접 잘 구워줘요"이 키워드를 선택한 인원200
# "특별한 날 가기 좋아요"이 키워드를 선택한 인원85
# "주차하기 편해요"이 키워드를 선택한 인원74
# "메뉴 구성이 알차요"이 키워드를 선택한 인원65
# "화장실이 깨끗해요"이 키워드를 선택한 인원48
# "반찬이 잘 나와요"이 키워드를 선택한 인원47
# "잡내가 적어요"이 키워드를 선택한 인원46
# "뷰가 좋아요"이 키워드를 선택한 인원26
# "혼밥하기 좋아요"이 키워드를 선택한 인원24
# "건강한 맛이에요"이 키워드를 선택한 인원18
# "음식이 빨리 나와요"이 키워드를 선택한 인원9
# "아늑해요"이 키워드를 선택한 인원7
# "비싼 만큼 가치있어요"이 키워드를 선택한 인원6
# "컨셉이 독특해요"이 키워드를 선택한 인원4
# "차분한 분위기에요"이 키워드를 선택한 인원3
# "오래 머무르기 좋아요"이 키워드를 선택한 인원2
# "환기가 잘 돼요"이 키워드를 선택한 인원2
# "좌석이 편해요"이 키워드를 선택한 인원1
# "코스요리가 알차요"이 키워드를 선택한 인원1
#
#  menu: 한돈 전복세트+된장찌개대표한돈4종600g(삼겹살,목살,두항정살,가브리살)+전복5미+된찌79,000원
# 한돈 세트+된장찌개대표한돈 4종 600g(목살,삼겹살,두항정살,가브리살)+된장찌개69,000원
# 한판도 삼겹살 150g대표삼겹살을 처음에는 소금, 멜젓소스 앤 전복삼합으로 드셔보세요 강남역맛집 한판도 삼겹살!!18,000원
# 매일 당일손질 식재료 약속😊매일 아침마다 담그는 겉절이와 매운김치,
# 주문과 동시에 손질하는 신선한 전복을 판매합니다!무료
# 활전복 한 접시 (4미)살아있는 전복 4미를 주문과 동시에 손질해서 드립니다.
# '고기+김치+전복' 삼합 추천 메뉴12,000원
# 한판도 양념 본갈비 150g뼈삼겹에 자체 개발한 특제양념으로 밑간을 한
# 오직 한판도만의 시그니처 메뉴19,000원
# 한판도 목살 150g18,000원
# 한판도 두항정살 150g18,000원
# 한판도 가브리살 150g20,000원
# 한판도 이베리코 대패 150g18,000원
# [점심] 전복 회덮밥 정식강남역 역삼역 사이에 위치한 점심특선 !!!16,000원
# [점심] 삼겹살 정식고기와 김치찌개를 풍부하게 ! 점심도 한판도에서 고기먹자!! 강남역 역삼역 점심특선12,000원
# [점심] 부산밀면 + 삼겹살강남역맛집 역삼역 맛집 점심특선!! 한판도에서 가성비 있게 점심 먹자!!12,000원
# [점심] 부산밀면(비빔) + 삼겹살강남역맛집 역삼역 맛집 점심특선!! 한판도에서 가성비 있게 점심 먹자!!12,000원
# [점심] 전복된장찌개 정식강남역맛집 역삼역 맛집 점심특선!! 한판도에서 가성비 있게 점심 먹자!!12,000원
# </content>
# <document><content>store_name: 영동반점 논현점
#  category: 요리주점
#  new_open:
#  rating: 정보없음
#  visited_review: 방문자 리뷰 415
#  directions_text: 1. 자차 이용 시 (건물주차장 이용)
# 건물 1층에 건물주차장이 있습니다. 저희 매장이 대부분 사용하는 전용주차장입니다만, 주차대수가 한정적이다 보니 방문 전에 매장으로 연락주시면 주차자리 확인해 드릴게요.
#
# * 매장주소 : 서울특별시 강남구 논현동 160-11번지
#
# 2. 지하철 이용 시
# 신논현역 3번출구 또는 논현역 2번출구로 나오셔서 한신포차 방향 영동시장 술집 골목으로 내려오시다 보면, 오른쪽에 약국이 보입니다. 약국을 끼고 맛짱떡볶이 방향으로 100m 가량 들어오시면 저희 영동반점이 있습니다.
#
# 3. 버스 이용 시
# 강남대로 논현역 정류장(중앙차선)에 하차 후 영동시장 먹자골목 쪽으로 길 건너신 후 골목으로 150m가량 직진하시면 맛짱떡볶이 지나 저희 영동반점이 보이십니다.
# 내용 더보기
#  store_id: 1659532863
#  address: 서울 강남구 강남대로122길 31 루이스빌딩 1층
#  blog_review: 블로그 리뷰 312
#  phone_num: 0507-1396-5040
#  business_hours: 월
# 17:00 - 02:00
# 화
# 17:00 - 04:00
# 수
# 17:00 - 04:00
# 목
# 17:00 - 04:00
# 금
# 17:00 - 04:00
# 토
# 17:00 - 04:00
# 일
# 17:00 - 04:00
#
#  info: 싱가폴식 칠리크랩, 홍콩식 에그누들, 시리얼새우 등 쉽게 접할 수 없는 다양한 중화권 요리를 선별하여, 호텔급 퀄리티에 합리적인 가격으로 모십니다.
#
# 중국 4대 맥주, 각종 고량주 등 중화권 주류는 물론, 칭따오생맥주, 연맥세트, 국산맥주, 소주 등 취향에 맞게 드시도록 다양한 주류도 준비해 놓았어요.
#
# 물론 기본도 합니다. 짜장짬뽕탕수육도 팔아요. 고객님들이 그러시네요. 저희 집 짬뽕이 인생짬뽕이라고.
#
# 식자재도 신경 많이 쓰고 있습니다. 고기는 마장동에서 떼오고, 해산물은 가락시장에서 받아요.야채는 매일매일 준비하고, 소스류 전부 수제로 만듭니다. 절대 냉동제품으로 음식 만들어 안주로 내어 드리지 않아요.
#
# 특이하고 맛있는 음식을 안주 삼아,
# 분위기 맛집 영동반점에서,
# 특별한 기억을 남겨 보세요.
#
# 주차장 있구요, 방문 전에 미리 연락 한 번 주시면 자리 확인해 드릴게요. 전용주차장이지만 강남이다 보니 많이 넓지는 않네요.
#
# 10인이상 단체예약도 가능하십니다만, 먼저 예약이 있으면 안 될 수도 있으니 사전에 전화 문의 부탁드리겠습니다.
#
# 영업시간
# 월~일요일 오후 5시~새벽 3시
#
# 논현분위기맛집 / 논현고량주 / 주변맛집 / 근처맛집 / 신논현맛집 / 논현맛집 / 강남맛집 / 강남단체 / 논현역술집 / 신논현술집
# 펼쳐보기
#  convenience_facilities_and_services: 콜키지 가능
# 유료
# 단체 이용 가능
# 포장
# 무선 인터넷
# 예약
# \
# 반려동물 동반
# 남/녀 화장실 구분
#
#  Parking: 주차가능
# 무료
#  sns: https://www.instagram.com/yeongdong16011
# https://blog.naver.com/mijiman00
#
#  review_like_this_part_output: "음식이 맛있어요"이 키워드를 선택한 인원351
# "특별한 메뉴가 있어요"이 키워드를 선택한 인원175
# "기본 안주가 좋아요"이 키워드를 선택한 인원164
# "친절해요"이 키워드를 선택한 인원150
# "인테리어가 멋져요"이 키워드를 선택한 인원140
# "가성비가 좋아요"이 키워드를 선택한 인원123
# "대화하기 좋아요"이 키워드를 선택한 인원95
# "술이 다양해요"이 키워드를 선택한 인원83
# "음악이 좋아요"이 키워드를 선택한 인원76
# "매장이 청결해요"이 키워드를 선택한 인원69
# "단체모임 하기 좋아요"이 키워드를 선택한 인원51
# "오래 머무르기 좋아요"이 키워드를 선택한 인원31
# "혼술하기 좋아요"이 키워드를 선택한 인원15
# "메뉴 구성이 알차요"이 키워드를 선택한 인원15
# "양이 많아요"이 키워드를 선택한 인원13
# "화장실이 깨끗해요"이 키워드를 선택한 인원12
# "아늑해요"이 키워드를 선택한 인원10
# "음식이 빨리 나와요"이 키워드를 선택한 인원10
# "주차하기 편해요"이 키워드를 선택한 인원5
# "재료가 신선해요"이 키워드를 선택한 인원4
# "컨셉이 독특해요"이 키워드를 선택한 인원3
# "매장이 넓어요"이 키워드를 선택한 인원3
# "건강한 맛이에요"이 키워드를 선택한 인원3
# "차분한 분위기에요"이 키워드를 선택한 인원2
# "야외공간이 멋져요"이 키워드를 선택한 인원2
# "반려동물과 가기 좋아요"이 키워드를 선택한 인원2
# "사진이 잘 나와요"이 키워드를 선택한 인원2
# "뷰가 좋아요"이 키워드를 선택한 인원2
# "혼밥하기 좋아요"이 키워드를 선택한 인원1
#
#  menu: 싱가폴칠리크랩대표소스가 끝내줍니다. 밥 한 번 비벼드시면 그 맛에 놀라실 거에요.38,000원
# 유린기대표저희는 유린기 맛집이에요.18,000원
# 마파연두부대표부드러운 연두부와 14가지 재료로 만든 수제 마파스프16,000원
# 해물짬뽕대표손님들이 그러십니다. 인생짬뽕이라고.10,000원
# 홍콩식 에그누들볶음대표홍콩식인데 미국 로 메인으로 더 유명하죠. 매력쩌는 누들입니다.11,000원
# 흑후추 깐풍기대표흑후추소스가 대세라길래 만들어 봤어요. 정말 맛있네요.16,000원
# 등심탕수육마장동에서 떼온 큼직한 등심으로 튀겨요. 양배추를 올리니 상큼하고 더 맛있네요.22,000원
# 사천식 탕수육탕수육을 빨갛고 맵단 소스로 버무리면 사천식이 됩니다.22,000원
# 시리얼새우달콤바삭 비법 시리얼 가루로 버무린 왕새우튀김16,000원
# 칠리크림새우달콤한 칠리크림소스가 듬뿍 얹어진 왕새우튀김18,000원
# 해산물 짬뽕파스타파스타면으로 볶음짬뽕을 만들었더니 기가 막히네요.11,000원
# 삼선고기짜장양파보다 고기가 더 많아요.8,000원
# </content>
# ==================================================
#
# ==================================================
# 🔄 Node: retrieve_document_naver_yongsan 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# context_naver_yongsan:
# <document><content>store_name: 한남동그집 신사가로수길점
#  category: 요리주점
#  new_open:
#  rating: 별점 4.51
#  visited_review: 방문자 리뷰 154
#  directions_text: 압구정역 8번 출구에서 500m 신사동 방면으로 오시다 보면 우리은행 골목으로 들어 오신다음 첫번째 약국사거리를 끼고 오른쪽으로 오시면 중국집수2층 입니다.(노홍철씨 꿈과모험의홍철동산 옆)
#
# 신사역 8번 출구에서 가로수길로 들어 오셔서 신사동주민센터 방면으로 쭉들어 오시다가 스파오 골목으로 들어오시면 됩니다.
#
# 한잔의 추억을 기점으로 오른쪽 50m 거리에 있습니다.
# 코다차야를 기점으로 오른쪽 70m 거리에 있습니다.
# 내용 더보기
#  store_id: 1465865340
#  address: 서울 강남구 논현로175길 64 2층
#  blog_review: 블로그 리뷰 147
#  phone_num: 0507-1340-3123
#  business_hours: 월
# 17:00 - 02:00
# 화
# 17:00 - 02:00
# 수
# 17:00 - 02:00
# 목
# 17:00 - 02:00
# 금
# 17:00 - 03:00
# 토
# 17:00 - 03:00
# 일
# 17:00 - 02:00
#
#  info: 정보없음
#  convenience_facilities_and_services: 정보없음
#  Parking: 정보없음
#  sns: 정보없음
#  review_like_this_part_output: 정보없음
#  menu: 정보없음</content>
# <document><content>store_name: 제3한강교 한남
#  category: 포장마차
#  new_open:
#  rating: 정보없음
#  visited_review: 방문자 리뷰 36
#  directions_text: 순천향대학병원 150m
# 한남오거리 150m
# 유엔빌리지 300m
# 한남역 1번출구에서 400m
# 한남더힐 400m
# 한남동카페거리 500m
# 일신홀 500m
# 한강진역 820m
# 리움미술관 830m
# 블루스퀘어 850m
# 이태원가구거리 900m
# 이태원역 1km
# 이태원거리 1km
# 그랜드하얏트호텔 1km
# 몬드리안호텔 1.2km
# 용산구청 1.3km
# 옥수역 1.3km
# 녹사평역 1.7km
# 남산 2km
# 서빙고역 2km
# 용산가족공원 2.2km
# 국립극장 2.2km
# 국립중앙박물관 2.6km
#
# 한남오거리에서 순천향병원 뱡향으로 가시다가 kt매장을 끼고 좌회전 하세요.
# 그러면 역전할맥, 김종용누룽지통닭, 다원골뱅이, 압구정진주가 보이고요.
# 그 건너편에 1층에 푸른밤 한남이 있어요.
# 그 2층이 제3한강교 한남입니다.
# 내용 더보기
#  store_id: 1122828177
#  address: 서울 용산구 대사관로34길 13 2층
#  blog_review: 블로그 리뷰 5
#  phone_num: 0507-1417-0877
#  business_hours: 월
# 18:00 - 02:00
# 화
# 18:00 - 02:00
# 수
# 18:00 - 02:00
# 목
# 18:00 - 02:00
# 금
# 18:00 - 03:00
# 토
# 18:00 - 03:00
# 일
# 정기휴무 (매주 일요일)
#
#  info: 정보없음
#  convenience_facilities_and_services: 정보없음
#  Parking: 정보없음
#  sns: 정보없음
#  review_like_this_part_output: 정보없음
#  menu: 정보없음</content>
# <document><content>store_name: 구식당
#  category: 육류,고기요리
#  new_open:
#  rating: 정보없음
#  visited_review: 방문자 리뷰 179
#  directions_text: [ 대중교통 이용 시 ]
#
# 6호선 이태원역 3번 출구 '이태원역, 보광동 입구'에서 421,405,400번 버스 승차 후 > '보광동주민센터'에서 하차 후 > 도보 3분거리에 위치 하고 있습니다.
#
# 경의중앙선 한남역 1번 출구 '한남역, 용산노인종합복지관' 에서 용산01번 버스 승차 후 > '보광동주민센터' 에서 하차 후 > 도보 2분거리에 위치 하고 있습니다.
#
# [ 차량 이용 시 ]
#
# 네비게이션에 '구식당' 또는 '보광동 217-10' 검색하시어 오시면 가게 앞 2대 정도 주차 가능하십니다.
# 내용 더보기
#  store_id: 1277757948
#  address: 서울 용산구 장문로 83-1 1층
#  blog_review: 블로그 리뷰 209
#  phone_num: 0507-1335-4356
#  business_hours: 토(12/28)
# 휴무
# 일
# 16:00 - 22:00
# 21:30 라스트오더
# 월
# 16:00 - 22:00
# 21:30 라스트오더
# 화
# 16:00 - 22:00
# 21:30 라스트오더
# 수
# 16:00 - 22:00
# 21:30 라스트오더
# 목
# 16:00 - 22:00
# 21:30 라스트오더
# 금
# 16:00 - 22:00
# 21:30 라스트오더
#
#  info: 안녕하세요. 무항생제 1+등급 프리미엄 한돈과
# 제주흑돼지 특상 목살을 판매하는
# 보광동 고기맛집 '구식당' 입니다 :)
#
# 저희는 제주도 농장과 직접 계약하여 제주 흑돼지 특상목살과 무항생제 1+등급 프리미엄 한돈을
# 최고의 원육만 선별해서 공수 받고 있으며,
# 정말 깨끗하고 좋은 고기만을 사용 합니다.
#
# 제주 특상 목살을 제외한 고기는
# 모두 무항생제 1+등급의 원육만을 고집하며,
# 선별된 원육은 구식당만의 숙성 노하우로
# 숙성하여 고객님들께 제공합니다.
#
# 습식과 건조 교차 숙성을 통해특유의 풍미와
# 최고의 식감을 느끼실 수 있습니다.
#
# 구식당은 조금 덜 남더라도
# 깨끗하고 건강한 국내산 식자재를
# 최우선으로 사용하여 조리하고 있습니다.
#
# 보광동에서는 찾기 쉽지 않은 분위기와
# 깔끔함으로 고객님들께서 편리하게
# 이용할 수 있도록 최선을 다하고 있습니다.
#
# 또 전문 서버분들이 고기를 구워주는 방식으로
# 편안하게 식사를 하실 수 있습니다 :)
#
# [저희 대표 메뉴]
#
# -제주도 흑돼지 특상 목살 (시그니처 메뉴):
#
# 제주도 농장과 직접 계약하여 최고의 원육만을 선별해서 제공받는 서울 1등 목살 !!
# 흑돼지만의 지방맛이 달콤하다는 표현
# 즉, 인생 목살 한 점을 맛 보실 수 있습니다.
#
# -199 통정살
# -199 등심덧살
# -299 삼겹살
#
# [199시간/ 299시간] 습식숙성 + 건조숙성
# 9식당만의 특별한 교차 숙성 노하우
#
# 등 다양하고 맛있는 음식이 준비 되어있으니
# 메뉴판 참고 부탁드리겠습니다.
#
# [진행하고 있는 이벤트]
#
# -영수증 리뷰 작성 시!
# 이즈니버터계란밥 쿠폰 제공
#
# -숫자 9를 활용한 이벤트!
#
# -> 99년생, 9번째 손님, 구씨성을 가진 분들
# 9%씩 할인 해드리는 등
#
# 다양한 이벤트도 진행 중 입니다 :)
#
# [ 9식당의 다짐 ]
#
# '9식당'은 청결에 힘쓰겠습니다.
# '9식당'은 친절하게 봉사 하겠습니다.
# '9식당'은 초심을 잃지 않겠습니다.
# '9식당'은 언제나 사랑하겠습니다.
# '9식당'은 항상 재밌습니다.
# '9식당'은 그냥 다 잘하겠습니다.
#
# 용산역 고기 맛집이나 용산 회식장소를
# 찾으신다면 주저하지마시고
# 분위기 좋고 신선한 고기를 맛볼 수 있는
# 저희 '구식당' 로 오세요!
#
# 늘 기본을 지키기 위해 변함 없이 노력하며,
# 좋은 분위기에서 식사하실 수 있게
# 준비하겠습니다.
#
# 저희 '구식당'을 방문해주신 모든 고객님들께
# 만족을 드리기 위해 늘 최선을 다하겠습니다.
#
# 이상 용산 고기 맛집 '구식당' 이었습니다.
# 감사합니다!
# 펼쳐보기
#  convenience_facilities_and_services: 콜키지 가능
# 유료
# 포장
# 배달
# 예약
# 무선 인터넷
#
#  Parking: 주차 불가
#  sns: https://www.instagram.com/9sikdang/
#
#  review_like_this_part_output: "고기 질이 좋아요"이 키워드를 선택한 인원166
# "음식이 맛있어요"이 키워드를 선택한 인원158
# "친절해요"이 키워드를 선택한 인원95
# "직접 잘 구워줘요"이 키워드를 선택한 인원81
# "매장이 청결해요"이 키워드를 선택한 인원64
# "특별한 메뉴가 있어요"이 키워드를 선택한 인원54
# "인테리어가 멋져요"이 키워드를 선택한 인원52
# "양이 많아요"이 키워드를 선택한 인원27
# "가성비가 좋아요"이 키워드를 선택한 인원17
# "반찬이 잘 나와요"이 키워드를 선택한 인원15
# "재료가 신선해요"이 키워드를 선택한 인원13
# "메뉴 구성이 알차요"이 키워드를 선택한 인원10
# "매장이 넓어요"이 키워드를 선택한 인원7
# "잡내가 적어요"이 키워드를 선택한 인원6
# "단체모임 하기 좋아요"이 키워드를 선택한 인원6
# "건강한 맛이에요"이 키워드를 선택한 인원4
# "특별한 날 가기 좋아요"이 키워드를 선택한 인원3
# "차분한 분위기에요"이 키워드를 선택한 인원2
# "아늑해요"이 키워드를 선택한 인원2
# "비싼 만큼 가치있어요"이 키워드를 선택한 인원2
# "혼밥하기 좋아요"이 키워드를 선택한 인원1
# "음식이 빨리 나와요"이 키워드를 선택한 인원1
# "야외공간이 멋져요"이 키워드를 선택한 인원1
# "뷰가 좋아요"이 키워드를 선택한 인원1
#
#  menu: 제주 흑돼지 특상목살(한정판매)대표제주도 농장과 계약하여 공급받는 부드럽고 감칠맛이 다른 최상급의 목살19,000원
# 199 통정살 (한정판매)대표199시간 숙성한 육즙 팡팡 통 항정살
# (한정판매)19,000원
# 299 삼겹살대표299시간 숙성한 부드럽고 고소한 삼겹살17,000원
# 199 등심덧살199시간 숙성한 쫄깃 등심덧살18,000원
# 299 목살299시간 숙성한 부드러운 목살17,000원
# 모듬 한근삼겹+목살+통정살+등심덧살 모두맛보실수있습니다69,000원
# 속풀이쓰리고 찌개고기+고추참치+고추장 베이스의 속풀이 찌개9,000원
# 고기김치해장라면무항생제고기듬뿍 김치해장라면!7,000원
# 99샤베트 비빔면구식당만의 비법소스로 만든 시원한비빔면8,000원
# 이즈니버터계란밥4,000원
# 베럴 몽키즈(레드와인)구식당 레드와인 단독판매(쉬라즈)39,900원
# 하이볼크~~톡톡 시원 청량한 하이하이 하이볼!8,000원
# </content>
# <document><content>store_name: 군몽
#  category: 양식
#  new_open:
#  rating: 정보없음
#  visited_review: 방문자 리뷰 64
#  directions_text: <주차>
# -90m인근 '한남동730 주차장' (유료)
#
# <대중교통 이용시>
#
# -지하철
# 한강진역 3번 출구에서 직진하시다가 보이는 MLB 매장 옆 골목으로 내려오셔서 우회전 후 쭉 직진하시면 코너 2층에 저희 매장이 있습니다.
#
# -버스
# ...
#   "Parking": "주차 불가",
#   "sns": [
#     "https://app.catchtable.co.kr/ct/shop/thesikdang",
#     "https://thesicddang1.modoo.at/"
#   ],
#   "store의 좋은점": "다양한 메뉴와 고품질의 재료, 친절한 서비스.",
#   "menu": [
#     "꼬막정식",
#     "불맛쭈꾸미정식",
#     "장작불고기정식",
#     "랍스타정식",
#     "화덕피자",
#     "바지락칼국수"
#   ]
# }
# ```
# ==================================================
#
# ==================================================
# 🔄 Node: llm_Summary_gangnam 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# answer_llm_Summary_gangnam:
# ```json
# {
#   "store_name": "대진 도원참치 강남역점",
#   "category": "생선회",
#   "rating": "정보없음",
#   "directions_text": "자가용 이용 시 KG타워에서 주차 가능, 대중교통은 강남역 12번 출구에서 도보 30초.",
#   "store_id": "1008611365",
#   "address": "서울 강남구 테헤란로 113 목화밀라트 지하1층 도원참치 강남역",
#   "phone_num": "0507-1473-4588",
#   "business_hours": {
#     "월": "11:00 - 22:50",
#     "화": "11:00 - 22:50",
#     "수": "휴무",
#     "목": "11:00 - 22:50",
#     "금": "11:00 - 22:50",
#     "토": "11:00 - 22:50",
#     "일": "정기휴무"
#   },
#   "info": "신선하고 고급스러운 참치 회, 초밥, 대게, 전복 등을 제공하는 아늑한 룸식당.",
#   "convenience_facilities_and_services": [
#     "콜키지 가능",
#     "유료",
#     "와인 페어링",
#     "무한 리필",
#     "포장",
#     "배달",
#     "예약",
#     "무선 인터넷",
#     "반려동물 동반",
#     "단체 이용 가능",
#     "남/녀 화장실 구분",
#     "유아의자",
#     "대기공간",
#     "출입구 휠체어 이용가능",
#     "좌석 휠체어 이용가능"
#   ],
#   "Parking": "주차가능, 무료",
#   "sns": [
#     "https://app.catchtable.co.kr/ct/shop/dowontuna_gangnam",
#     "https://www.instagram.com/dowontuna.gangnam"
#   ],
#   "store의 좋은점": "신선한 재료와 다양한 메뉴 구성, 아늑한 분위기.",
#   "menu": [
#     "혼골드(1인)",
#     "VIP(1인)",
#     "일품(1인)",
#     "혼마정식(1인)",
#     "참연 정식(1인)",
#     "참치물회(물회덮밥)"
#   ]
# }
# ```
# ==================================================
#
# ==================================================
# 🔄 Node: llm_Summary_jongro 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# answer_llm_Summary_jongro:
# ```json
# [
#     {
#         "store_name": "창창",
#         "category": "중식당",
#         "rating": "정보없음",
#         "directions_text": "발렛파킹 후 이동, '창신12길 33' 앞에서 발렛, '종로 03번 마을버스'를 타고 '낙산 삼거리' 정류장에서 하차 후 도보.",
#         "store_id": "1903257210",
#         "address": "서울 종로구 창신12길 37 창창",
#         "phone_num": "0507-1370-3548",
#         "business_hours": "매일 11:30 - 21:00, 15:00 - 17:00 브레이크타임, 20:00 라스트오더",
#         "info": "정보없음",
#         "convenience_facilities_and_services": "정보없음",
#         "Parking": "정보없음",
#         "sns": "정보없음",
#         "store의 좋은점": "음식이 맛있어요, 인테리어가 멋져요, 뷰가 좋아요, 친절해요",
#         "menu": [
#             "까이포커플세트 65,000원",
#             "라즈지 28,000원",
#             "꿔바로우 21,000원",
#             "창창하이볼 12,000원",
#             "쇠고기우육면 17,000원",
#             "마늘종 자장면 14,000원",
#             "차돌박이 사천 탕면 15,000원",
#             "통삼겹 동파육 34,000원",
#             "중화냉면 17,000원",
#             "새우계란볶음밥 10,000원",
#             "창창 팝 만두 9,000원",
#             "짜사이 볶음밥 10,000원",
#             "오이 냉채 8,000원",
#             "오드레기 볶음 29,000원",
#             "연두부 튀김 14,000원"
#         ]
#     },
#     {
#         "store_name": "동베이 광화문점",
#         "category": "양꼬치",
#         "rating": "정보없음",
#         "directions_text": "광화문역에서 포시즌스 호텔 근처 20미터 내 육대장 건물 2층에 위치.",
#         "store_id": "1962205483",
#         "address": "서울 종로구 새문안로5길 8-1 2층 동베이 광화문점",
#         "phone_num": "0507-1402-8696",
#         "business_hours": "매일 10:00 - 24:00, 23:00 라스트오더",
#         "info": "양꼬치와 동북 요리 전문점",
#         "convenience_facilities_and_services": "비건 메뉴, 유기농 메뉴, 단체 이용 가능, 포장, 배달, 예약, 남/녀 화장실 구분",
#         "Parking": "주차 불가",
#         "sns": "https://app.catchtable.co.kr/ct/shop/dong_bey",
#         "store의 좋은점": "음식이 맛있어요, 가성비가 좋아요, 양이 많아요, 친절해요",
#         "menu": [
#             "훠궈 점심 특선 12,800원",
#             "양꼬치 16,000원",
#             "꿔바로우 20,000원",
#             "마라샹궈 28,000원",
#             "모듬 꼬치 세트 68,000원",
#             "즈란양고기 20,000원",
#             "지삼선 18,000원",
#             "마라탕 25,000원",
#             "라쯔지 28,000원",
#             "소갈빗살 꼬치 17,000원",
#             "양갈빗살 꼬치 18,000원",
#             "경장육슬 28,000원",
#             "어향가지 20,000원",
#             "마른고추 소고기 볶음 22,000원",
#             "향라 오징어 22,000원"
#         ]
#     },
#     {
#         "store_name": "홈보이서울",
#         "category": "중식당",
#         "rating": "별점 4.38",
#         "directions_text": "경복궁역 3-1번 출구로 나오신 후 다이소 건물 뒤쪽으로 도보 1분.",
#         "store_id": "1214831336",
#         "address": "서울 종로구 사직로 127-14 1층 홈보이서울",
#         "phone_num": "0507-1355-4371",
#         "business_hours": "화~금 11:30 - 22:00, 토~일 11:00 - 22:00, 월 11:30 - 22:00",
#         "info": "아메리칸 차이니즈 레스토랑",
#         "convenience_facilities_and_services": "단체 이용 가능, 무선 인터넷, 포장, 배달, 예약, 남/녀 화장실 구분",
#         "Parking": "주차가능",
#         "sns": "http://www.instagram.com/homeboy_seoul",
#         "store의 좋은점": "음식이 맛있어요, 인테리어가 멋져요, 특별한 메뉴가 있어요, 친절해요",
#         "menu": [
#             "몽골리안 포크 22,800원",
#             "오렌지 치킨 22,800원",
#             "2인 세트 A 52,800원",
#             "2인 세트 B 53,800원",
#             "3인 세트 79,800원",
#             "4인 세트 112,800원",
#             "중국식 오이무침 7,800원",
#             "공심채 볶음 14,800원",
#             "새우완탕스프 12,800원",
#             "스프링 롤 9,800/4pcs, 12,800/6pcs",
#             "스파이시 오렌지 치킨 24,800원",
#             "쿵파오 치킨 22,800원",
#             "반반 새우 25,800원",
#             "크림 새우 24,800원",
#             "칠리 새우 24,800원"
#         ]
#     },
#     {
#         "store_name": "신승관",
#         "category": "중식당",
#         "rating": "별점 4.29",
#         "directions_text": "종각역 1번 출구에서 광화문 방향으로, 르메이에르 건물 2층에 위치.",
#         "store_id": "12989948",
#         "address": "서울 종로구 종로 19 217호",
#         "phone_num": "02-735-9955",
#         "business_hours": "수~금 11:00 - 23:00, 월~화 11:00 - 23:00, 일 정기휴무",
#         "info": "1964년부터 운영 중인 중식당",
#         "convenience_facilities_and_services": "콜키지 가능, 무료, 생일 혜택, 단체 이용 가능, 무선 인터넷, 남/녀 화장실 구분, 유아의자, 포장, 예약, 장애인 휠체어 이용가능",
#         "Parking": "주차가능, 무료",
#         "sns": [
#             "https://m.blog.naver.com/wmedia77/223171955325",
#             "https://www.instagram.com/jongro_sinseungkwan"
#         ],
#         "store의 좋은점": "음식이 맛있어요, 친절해요, 단체모임 하기 좋아요, 재료가 신선해요",
#         "menu": [
#             "삼선짬뽕 14,000원",
#             "고추자장 10,000원",
#             "해물백짬뽕 14,000원",
#             "유슬볶음밥 13,000원",
#             "유산슬밥 16,000원",
#             "비취탕수육 25,000원",
#             "레몬크림중새우 변동",
#             "수제면보사 변동",
#             "깐소중새우 변동",
#             "탕수육 세트 36,000원",
#             "꿔바로우 세트 39,000원",
#             "깐풍기 세트 39,000원",
#             "유린기 세트 43,000원",
#             "깐소중새우 세트 43,000원",
#             "48,000 코스요리 48,000원"
#         ]
#     },
#     {
#         "store_name": "서울회관",
#         "category": "요리주점",
#         "rating": "별점 4.38",
#         "directions_text": "종각역 2번 출구에서 50m 직진 후 좌회전하여 서울회관 3층.",
#         "store_id": "1824175974",
#         "address": "서울 종로구 삼봉로 98 3층",
#         "phone_num": "02-722-2019",
#         "business_hours": "월~금 16:00 - 24:00, 일 정기휴무",
#         "info": "정보없음",
#         "convenience_facilities_and_services": "정보없음",
#         "Parking": "정보없음",
#         "sns": "정보없음",
#         "store의 좋은점": "음식이 맛있어요, 가성비가 좋아요, 단체모임 하기 좋아요, 인테리어가 멋져요",
#         "menu": [
#             "옛날 가마솥 통닭 16,000원",
#             "건강 충전 마늘 통닭 18,000원",
#             "유동골뱅이 무침 23,000원",
#             "맛 태서울회관 16,000원",
#             "대왕 돈가스 18,000원",
#             "국물 떡볶이 20,000원",
#             "해물 오뎅탕 23,000원",
#             "모듬 소시지 18,000원",
#             "모듬 감자튀김 16,000원"
#         ]
#     },
#     {
#         "store_name": "사직로 서울",
#         "category": "한식",
#         "rating": "정보없음",
#         "directions_text": "경복궁역 3-1번 출구로 나오신 후 다이소 건물 뒤쪽으로 도보 1분.",
#         "store_id": "1203679539",
#         "address": "서울 종로구 사직로 127-14 2층",
#         "phone_num": "0507-1345-4371",
#         "business_hours": "수~일 11:30 - 22:00, 브레이크타임 15:00 - 17:00",
#         "info": "경복궁과 서촌의 특별한 한식 경험",
#         "convenience_facilities_and_services": "콜키지 가능, 무료, 단체 이용 가능, 예약, 남/녀 화장실 구분, 배달, 포장, 대기공간, 무선 인터넷, 유아의자",
#         "Parking": "주차가능, 무료",
#         "sns": "https://www.instagram.com/sajikro_seoul",
#         "store의 좋은점": "음식이 맛있어요, 매장이 넓어요, 인테리어가 멋져요, 재료가 신선해요",
#         "menu": [
#             "참나무 소갈비 29,000원",
#             "평양물냉면 13,000원",
#             "참나무 불고기 (소) 22,000원",
#             "육개장 13,000원",
#             "어복전골(中) 38,000원",
#             "어복전골(大) 65,000원",
#             "차돌수육 25,000원",
#             "비빔냉면 13,000원",
#             "큰손만두 10,000원",
#             "미나리곰탕 15,000원",
#             "큰손만둣국 13,000원",
#             "온면 13,000원",
#             "미나리 무침 15,000원"
#         ]
#     }
# ]
# ```
# ==================================================
#
# ==================================================
# 🔄 Node: llm_Summary_opendata 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# answer_llm_Summary_opendata:
# ### 요약
#
# #### 심화숙 한지공방
# - 장소 이름: 심화숙 한지공방
# - 위치: 서울 종로구 북촌로 50 3층
# - 전화번호: 02-394-6533
# - 웹사이트 URL: None
# - 운영 날짜 및 시간: 3월~11월 10:00 ~ 18:00, 11월~2월 10:00 ~ 17:00 (월요일 및 명절 당일 휴무)
# - 교통정보: 3호선 안국역 2번 출구에서 약 800m (도보 13분)
# - 기타 편의 여부: None
# - 지원언어: None
#
# #### 쌈지길 체험공방
# - 장소 이름: 쌈지길 체험공방
# - 위치: 서울 종로구 관훈동 38 지하 1층
# - 전화번호: 02-736-6711
# - 웹사이트 URL: http://m.smartstore.naver.com/ssamzigil
# - 운영 날짜 및 시간: 10:30 - 20:30
# - 교통정보: 지하철 1호선 종각역 4번 출구에서 약 640m (도보 10분), 지하철 3호선 안국역 6번 출구에서 약 300m (도보 5분)
# - 기타 편의 여부: None
# - 지원언어: 한국어
#
# #### 세종문화회관
# - 장소 이름: 세종문화회관
# - 위치: 서울 종로구 세종로 81-3
# - 전화번호: 02-399-1000
# - 웹사이트 URL: https://www.sejongpac.or.kr/portal/main/main.do
# - 운영 날짜 및 시간: 공연에 따라 이용 시간이 다름, 현장 및 전화 예매 AM 09:00 ~ PM 08:00 (연중무휴)
# - 교통정보: 5호선 광화문역 8번 출구에서 약 270m (도보 5분), 3호선 경복궁역 6번 출구에서 약 640m (도보 12분)
# - 기타 편의 여부: None
# - 지원언어: None
#
# #### 북촌마을안내소
# - 장소 이름: 북촌마을안내소
# - 위치: 정독도서관 서울교육박물관 앞
# - 전화번호: 02-2148-4161
# - 웹사이트 URL: None
# - 운영 날짜 및 시간: 하절기 09:00 ~ 18:00, 동절기 09:00 ~ 18:00
# - 교통정보: None
# - 기타 편의 여부: 와이파이 및 인터넷 검색 가능
# - 지원언어: 영어, 일본어, 중국어
#
# #### 전통공예체험관
# - 장소 이름: 전통공예체험관
# - 위치: 서울 종로구 가회동 11-91
# - 전화번호: 02-741-2148
# - 웹사이트 URL: http://tour.jongno.go.kr/tour/main/contents.do?menuNo=110553
# - 운영 날짜 및 시간: 3~11월 AM 10:00 ~ PM 06:00, 11~2월 AM 10:00 ~ PM 05:00
# - 교통정보: 3호선 안국역 2번 출구에서 약 670m (도보 11분)
# - 기타 편의 여부: None
# - 지원언어: 한국어, 영어, 중국어, 일본어
#
# #### 청원산방
# - 장소 이름: 청원산방
# - 위치: 서울 종로구 계동 79-12
# - 전화번호: 02-715-3342
# - 웹사이트 URL: http://www.somokjang.com/
# - 운영 날짜 및 시간: 토 10:00~17:00 (예약제로 진행)
# - 교통정보: 3호선 안국역 3번 출구에서 약 430m (도보 6분)
# - 기타 편의 여부: None
# - 지원언어: None
#
# #### 나전과 옻칠
# - 장소 이름: 나전과 옻칠
# - 위치: 서울 종로구 계동 25
# - 전화번호: 070-8860-9880
# - 웹사이트 URL: https://blog.naver.com/krhg252017
# - 운영 날짜 및 시간: 11:00~17:00
# - 교통정보: 3호선 안국역 3번 출구에서 약 635m (도보 10분)
# - 기타 편의 여부: None
# - 지원언어: 한국어
#
# #### 동양방아간
# - 장소 이름: 동양방아간
# - 위치: 서울 종로구 부암동 244-5
# - 전화번호: 02-379-6987
# - 웹사이트 URL: None
# - 운영 날짜 및 시간: 09:00~17:00
# - 교통정보: 경복궁역 3번 출구에서 7022, 7012, 1020 지선버스 탑승 후 하차
# - 기타 편의 여부: None
# - 지원언어: None
#
# #### 창경궁
# - 장소 이름: 창경궁
# - 위치: 서울 종로구 와룡동 2-1
# - 전화번호: 02-762-4868
# - 웹사이트 URL: http://cgg.cha.go.kr/agapp/public/html/HtmlPage.do?pg=/cgg/06/greeting_01.jsp&pageNo=74000000&siteCd=CGG
# - 운영 날짜 및 시간: 09:00 ~ 21:00 (입장마감 20:00)
# - 교통정보: 4호선 혜화역 4번 출구에서 약 779m (도보 13분)
# - 기타 편의 여부: 장애인 전용 주차장, 장애인화장실, 장애인 안내(휠체어 대여 및 기타)
# - 지원언어: None
#
# #### 사직공원
# - 장소 이름: 사직공원
# - 위치: 서울 종로구 사직동 1-28
# - 전화번호: 02-2148-2835
# - 웹사이트 URL: http://parks.seoul.go.kr/parks/detailView.do?pIdx=106
# - 운영 날짜 및 시간: None
# - 교통정보: 3호선 경복궁역 1번 출구에서 약 337m (도보 6분)
# - 기타 편의 여부: None
# - 지원언어: None
#
# #### 서울김치문화체험관
# - 장소 이름: 서울김치문화체험관
# - 위치: 서울 중구 충무로2가 12-27 33-1
# - 전화번호: 02-318-7051
# - 웹사이트 URL: http://www.seoulkimchi.co.kr
# - 운영 날짜 및 시간: 10:30 - 19:00
# - 교통정보: 4호선 명동역 10번 출구
# - 기타 편의 여부: None
# - 지원언어: None
#
# #### 서울 중앙시장
# - 장소 이름: 서울 중앙시장
# - 위치: 서울 중구 황학동 442
# - 전화번호: 02-2232-9559
# - 웹사이트 URL: https://blog.naver.com/jungangmk
# - 운영 날짜 및 시간: 07:00 ~ 24:00
# - 교통정보: 2,6호선 신당역 2번출구에서 약 7m (도보 1분)
# - 기타 편의 여부: None
# - 지원언어: None
#
# #### 동대문 관광안내소
# - 장소 이름: 동대문 관광안내소
# - 위치: 서울 중구 을지로6가 18-21
# - 전화번호: +82-2-2236-9135
# - 웹사이트 URL: http://www.sta.or.kr
# - 운영 날짜 및 시간: 10:00 ~ 01:00
# - 교통정보: 2,4,5호선 동대문역사문화공원역 14번 출구에서 약 32m (도보 1분)
# - 기타 편의 여부: None
# - 지원언어: None
#
# #### 명동관광정보센터
# - 장소 이름: 명동관광정보센터
# - 위치: 하나금융그룹 명동사옥 별관 1층
# - 전화번호: 02-778-0333
# - 웹사이트 URL: https://korean.visitseoul.net/attractions/EBAA85EB8F99EAB480EAB491ECA095EBB3B4EC84BCED84B0_/11469
# - 운영 날짜 및 시간: 하절기 09:00 ~ 18:00, 동절기 09:00 ~ 18:00
# - 교통정보: None
# - 기타 편의 여부: None
# - 지원언어: 영어, 일본어, 중국어
#
# #### 명동실탄사격장
# - 장소 이름: 명동실탄사격장
# - 위치: 서울 중구 충무로2가 11-1 선샤인빌딩3층
# - 전화번호: 02-777-6604
# - 웹사이트 URL: https://booking.naver.com/booking/5/bizes/343394
# - 운영 날짜 및 시간: 평일 13:00 - 20:00, 주말/공휴일 11:00 - 20:00
# - 교통정보: 4호선 명동역 9번 출구에서 약 330m (도보 6분)
# - 기타 편의 여부: None
# - 지원언어: None
#
# #### 국립정동극장 세실
# - 장소 이름: 국립정동극장 세실
# - 위치: 서울 중구 정동 3-7
# - 전화번호: 02-751-1500
# - 웹사이트 URL: https://www.jeongdong.or.kr/portal/main/contents.do?menuNo=200109
# - 운영 날짜 및 시간: 고객지원실: 월요일~금요일 09:00~18:00
# - 교통정보: 1,2호선 시청역 3번 출구에서 약 132m (도보 2분)
# - 기타 편의 여부: None
# - 지원언어: None
#
# #### 시민청 관광안내소
# - 장소 이름: 시민청 관광안내소
# - 위치: 서울 중구 태평로1가 31
# - 전화번호: +82-2-739-7755
# - 웹사이트 URL: http://www.sta.or.kr
# - 운영 날짜 및 시간: 10:00~19:00 (일요일 휴관)
# - 교통정보: 1,2호선 시청역 4번 출구
# - 기타 편의 여부: None
# - 지원언어: None
#
# #### 남산공원
# - 장소 이름: 남산공원
# - 위치: 서울 중구 예장동 산5-85 남산제1별관
# - 전화번호: 02-3783-5900
# - 웹사이트 URL: http://parks.seoul.go.kr/namsan
# - 운영 날짜 및 시간: 상시개방
# - 교통정보: 4호선 회현역 4분 출구에서 약 923m (도보 20분), 4호선 명동역 3번 출구에서 약 846m (도보 18분)
# - 기타 편의 여부: None
# - 지원언어: None
#
# #### DDP 관광안내소
# - 장소 이름: DDP 관광안내소
# - 위치: 서울 중구 을지로7가 2-1
# - 전화번호: +82-2-2153-0307
# - 웹사이트 URL: http://www.sta.or.kr
# - 운영 날짜 및 시간: 10:00~19:00
# - 교통정보: 2,4,5호선 동대문역사문화공원역 1번 출구, 1호선 동대문역 8번 출구
# - 기타 편의 여부: None
# - 지원언어: None
# ==================================================
# []
#
# ==================================================
# 🔄 Node: llm_Schedule_answer 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# answer:
# 서울에서의 2박 3일 일정과 성형외과 방문을 고려한 여행 일정을 제안해드리겠습니다. 강남구와 종로구를 중심으로 동선을 최소화하여 계획을 세워보겠습니다.
#
# ### 1일차: 강남구
# - **아침**: 강남구에서의 아침은 가볍게 카페에서 시작해보세요. 강남역 근처에 있는 다양한 카페 중 하나를 선택하시면 좋습니다.
# - **오전**: 성형외과 방문 (강남구에 위치한 병원)
# - **점심**: [대진 도원참치 강남역점](https://app.catchtable.co.kr/ct/shop/dowontuna_gangnam)에서 신선한 참치 회와 초밥을 즐기세요.
# - **오후**: 강남역 주변 쇼핑 및 산책
# - **저녁**: 강남의 다양한 한식당 중 하나를 선택하여 저녁 식사를 즐기세요.
#
# ### 2일차: 종로구
# - **아침**: 종로구로 이동하여 북촌 한옥마을을 산책하며 아침을 시작하세요.
# - **오전**: [창경궁](http://cgg.cha.go.kr/agapp/public/html/HtmlPage.do?pg=/cgg/06/greeting_01.jsp&pageNo=74000000&siteCd=CGG) 방문
# - **점심**: [신승관](https://www.instagram.com/jongro_sinseungkwan)에서 전통 중식을 맛보세요.
# - **오후**: [세종문화회관](https://www.sejongpac.or.kr/portal/main/main.do)에서 전시나 공연 관람
# - **저녁**: [서울회관](https://www.instagram.com/jongro_sinseungkwan)에서 요리주점의 다양한 메뉴를 즐기세요.
#
# ### 3일차: 종로구
# - **아침**: [사직공원](http://parks.seoul.go.kr/parks/detailView.do?pIdx=106)에서 산책하며 하루를 시작하세요.
# - **오전**: [전통공예체험관](http://tour.jongno.go.kr/tour/main/contents.do?menuNo=110553)에서 전통 공예 체험
# - **점심**: [홈보이서울](http://www.instagram.com/homeboy_seoul)에서 아메리칸 차이니즈 요리를 즐기세요.
# - **오후**: [쌈지길 체험공방](http://m.smartstore.naver.com/ssamzigil)에서 다양한 체험 활동
# - **저녁**: 종로구의 다양한 식당 중 하나를 선택하여 저녁 식사를 마무리하세요.
#
# 이 일정은 강남구와 종로구를 중심으로 하여 성형외과 방문을 포함한 일정입니다. 필요에 따라 조정이 가능합니다. 추가적인 요청이 있으면 말씀해 주세요!
# ('user', '강남구와 종로구에 2박3일 방문하려고 하는데 중간에 성형외과를 방문 하려고해 일정을 만들어 줄 수 있어? ')
# ('assistant', '서울에서의 2박 3일 일정과 성형외과 방문을 고려한 여행 일정을 제안해드리겠습니다. 강남구와 종로구를 중심으로 동선을 최소화하여 계획을 세워보겠습니다.\n\n### 1일차: 강남구\n- **아침**: 강남구에서의 아침은 가볍게 카페에서 시작해보세요. 강남역 근처에 있는 다양한 카페 중 하나를 선택하시면 좋습니다.\n- **오전**: 성형외과 방문 (강남구에 위치한 병원)\n- **점심**: [대진 도원참치 강남역점](https://app.catchtable.co.kr/ct/shop/dowontuna_gangnam)에서 신선한 참치 회와 초밥을 즐기세요.\n- **오후**: 강남역 주변 쇼핑 및 산책\n- **저녁**: 강남의 다양한 한식당 중 하나를 선택하여 저녁 식사를 즐기세요.\n\n### 2일차: 종로구\n- **아침**: 종로구로 이동하여 북촌 한옥마을을 산책하며 아침을 시작하세요.\n- **오전**: [창경궁](http://cgg.cha.go.kr/agapp/public/html/HtmlPage.do?pg=/cgg/06/greeting_01.jsp&pageNo=74000000&siteCd=CGG) 방문\n- **점심**: [신승관](https://www.instagram.com/jongro_sinseungkwan)에서 전통 중식을 맛보세요.\n- **오후**: [세종문화회관](https://www.sejongpac.or.kr/portal/main/main.do)에서 전시나 공연 관람\n- **저녁**: [서울회관](https://www.instagram.com/jongro_sinseungkwan)에서 요리주점의 다양한 메뉴를 즐기세요.\n\n### 3일차: 종로구\n- **아침**: [사직공원](http://parks.seoul.go.kr/parks/detailView.do?pIdx=106)에서 산책하며 하루를 시작하세요.\n- **오전**: [전통공예체험관](http://tour.jongno.go.kr/tour/main/contents.do?menuNo=110553)에서 전통 공예 체험\n- **점심**: [홈보이서울](http://www.instagram.com/homeboy_seoul)에서 아메리칸 차이니즈 요리를 즐기세요.\n- **오후**: [쌈지길 체험공방](http://m.smartstore.naver.com/ssamzigil)에서 다양한 체험 활동\n- **저녁**: 종로구의 다양한 식당 중 하나를 선택하여 저녁 식사를 마무리하세요.\n\n이 일정은 강남구와 종로구를 중심으로 하여 성형외과 방문을 포함한 일정입니다. 필요에 따라 조정이 가능합니다. 추가적인 요청이 있으면 말씀해 주세요!')
# ==================================================

# %%
# API 키를 환경변수로 관리하기 위한 설정 파일
from dotenv import load_dotenv

# API 키 정보 로드
load_dotenv()
# Out:
# True

# %%
# LangSmith 추적을 설정합니다. https://smith.langchain.com
# !pip install -qU langchain-teddynote
# from langchain_teddynote import logging

# # 프로젝트 이름을 입력합니다.
# logging.langsmith("practice")

# %%
from langchain.vectorstores import FAISS
from langchain.embeddings import OpenAIEmbeddings

# Step 1: FAISS 인덱스 파일 로드
faiss_index_path = "Faiss/naver_map_gangnam_faiss"  # 저장된 Faiss 파일 경로
embeddings = OpenAIEmbeddings()  # 임베딩 객체 초기화

# 저장된 FAISS 인덱스를 불러와서 Retriever 생성
retriever_naver_gangnam = FAISS.load_local(faiss_index_path, embeddings,allow_dangerous_deserialization=True).as_retriever()

# 검색 매개변수 설정 (예: 검색 결과 상위 10개 반환)
retriever_naver_gangnam.search_kwargs = {"k": 8}
# Out:
# /var/folders/_v/g1qmsq595kq_fg_zv8n2022h0000gn/T/ipykernel_17281/1087435917.py:6: LangChainDeprecationWarning: The class `OpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import OpenAIEmbeddings``.
#   embeddings = OpenAIEmbeddings()  # 임베딩 객체 초기화

# %%
retriever_naver_gangnam.invoke('종로구 커피가 맛있는 카페를 추천해줘')
# Out:
# [Document(id='b0523fbb-6356-46d9-ac5e-afef0ae73bd4', metadata={'store_id': '1785227909', 'store_name': '카페로쥬 강남점'}, page_content='store_name: 카페로쥬 강남점 \n category: 카페 \n new_open:   \n rating: 별점 4.46 \n visited_review: 방문자 리뷰 680 \n directions_text: 휘문고등학교 맞은편 \n store_id: 1785227909 \n address: 서울 강남구 역삼로 552 KM빌딩 1층 \n blog_review: 블로그 리뷰 63 \n phone_num: 0507-1489-6022 \n business_hours: 화\n07:30 - 21:00\n20:10 라스트오더\n수(1/1)\n새해 첫날09:00 - 21:00\n목\n07:30 - 21:00\n20:10 라스트오더\n금\n07:30 - 21:00\n20:10 라스트오더\n토\n09:00 - 21:00\n20:10 라스트오더\n일\n09:00 - 21:00\n20:10 라스트오더\n월\n07:30 - 21:00\n20:10 라스트오더\n \n info: 건강을 생각하는 카페, 카페가 건강이 되다.\n\n건강을 당신의 삶 속에 라는 슬로건으로\n이롬의 건강 솔루션을 담아 이롬과 카페로쥬만의\n특별한 레시피 메뉴를 선보이고 있습니다.\n\n자연에서 온 64가지 원료를 담아 균형 있는 프리미엄 생식을\n건강하고 맛있게 체험하고, 풍부한 영양소를 챙길 수 있는 건강 음료카페입니다.\n\n카페로쥬는 소중한 당신의 삶을 위한 건강을 만듭니다.\n펼쳐보기 \n convenience_facilities_and_services: 편의시설 및 서비스 정보 없음 \n Parking: 주차 정보없음 \n sns: https://www.instagram.com/cafeloge_official/\n \n review_like_this_part_output: "커피가 맛있어요"이 키워드를 선택한 인원272\n"인테리어가 멋져요"이 키워드를 선택한 인원140\n"음료가 맛있어요"이 키워드를 선택한 인원123\n"대화하기 좋아요"이 키워드를 선택한 인원104\n"매장이 청결해요"이 키워드를 선택한 인원103\n"디저트가 맛있어요"이 키워드를 선택한 인원93\n"친절해요"이 키워드를 선택한 인원69\n"좌석이 편해요"이 키워드를 선택한 인원60\n"특별한 메뉴가 있어요"이 키워드를 선택한 인원53\n"집중하기 좋아요"이 키워드를 선택한 인원47\n"가성비가 좋아요"이 키워드를 선택한 인원38\n"뷰가 좋아요"이 키워드를 선택한 인원16\n"사진이 잘 나와요"이 키워드를 선택한 인원15\n"화장실이 깨끗해요"이 키워드를 선택한 인원14\n"매장이 넓어요"이 키워드를 선택한 인원9\n"건강한 맛이에요"이 키워드를 선택한 인원9\n"차분한 분위기에요"이 키워드를 선택한 인원3\n"아늑해요"이 키워드를 선택한 인원2\n"음식이 맛있어요"이 키워드를 선택한 인원2\n"주차하기 편해요"이 키워드를 선택한 인원2\n"오래 머무르기 좋아요"이 키워드를 선택한 인원2\n"빵이 맛있어요"이 키워드를 선택한 인원1\n"룸이 잘 되어있어요"이 키워드를 선택한 인원1\n"단체모임 하기 좋아요"이 키워드를 선택한 인원1\n \n menu: 아메리카노진한 에스프레소와 정수를 더해 깔끔하고 깊은 풍미를 자랑하는 로쥬만의 스페셜 원두 커피5,000원\n카페라떼에스프레소에 거품 우유를 더해 크리미하고 달콤한 맛을 느낄 수 있는 커피5,500원\n바닐라라떼에스프레소와 거품 우유에 바닐라 시럽을 더해 달콤하고 향긋한 맛을 느낄 수 있는 커피5,500원\n헤이즐넛라떼헤이즐넛 시럽이 더해진 에스프레소와 우유의 조화로 고소하고 달콤한 맛을 즐길 수 있는 커피5,500원\n카라멜마키아또에스프레소에 카라멜시럽과 메이플시럽, 우유의 조화로 달콤한 맛을 즐길 수 있는 커피5,500원\n돌체라떼에스프레소와 우유에 달콤한 연유가 더해져 크리미하고 달콤한 맛을 느낄 수 있는 커피5,500원\n카페모카에스프레소에 초콜릿 시럽과 우유를 더해 달콤하고 풍부한 초콜릿 맛을 느낄 수 있는 커피5,500원\n토피넛라떼토피넛과 에스프레소, 거품 우유가 어우러져 고소하고 달콤한 풍미를 즐길 수 있는 커피5,500원\n코코넛커피에스프레소와 코코넛 밀크, 연유가 어우러져 이국적이고 부드러운 맛을 느낄 수 있는 커피5,500원\n아인슈페너바닐라빈페이스트 휘핑크림이 올라간 에스프레소로, 크리미하고 달콤한 맛을 즐길 수 있는 커피6,000원\n캐모마일 페퍼민트티캐모마일의 부드러운 꽃향기와 페퍼민트의 상쾌함이 어우러진 편안함을 주는 차5,500원\n라벤더 페퍼민트티라벤더의 향긋함과 페퍼민트의 상쾌함이 조화를 이루어 스트레스를 완화해주는 차5,500원\n홍차[아쌈]깊고 진한 맛과 다양한 향이 어우러진 발효 찻잎으로 풍부한 티타임을 제공하는 홍차5,500원\n멀티생과일 주스신선한 과일을 블렌딩하여, 과일의 신선함과 영양을 그대로 담고 있는 건강음료7,000원\n케파주스신선한 케일과 달콤한 파인애플을 혼합하여 만든 건강 음료7,000원\n'),
#  Document(id='1bf173a2-413b-4c78-a4c0-1d73fe465a11', metadata={'store_id': '1785877248', 'store_name': '힉스커피'}, page_content='store_name: 힉스커피 \n category: 카페,디저트 \n new_open:   \n rating: 정보없음 \n visited_review: 방문자 리뷰 295 \n directions_text: CGV골목 언덕을 따라 쭉 올라오신 후 수많은 다른 카페를 지나 언덕을 오르시다가 GS25가 보이시면 많이 오셨습니다. 좀만 더 오시면 됩니다. 탈라코스메틱스파를 끼고 우회전하시면 \'힉스커피\'의 스텐 간판이 보입니다. 현대과학의 산물인 휴대폰의 GPS를 키고 네이버맵을 보며 오시길 추천드립니다.\n\n<지하철 이용 시>\n신논현역 4번 출구로 나오자마자 우회전 후, 약 420m를 걷습니다. 이후 백소정, 강남삼계탕이 보이면 두 갈래 길이 나오면 왼쪽 길로 갑니다. 이후 쭉 직진해서 약 480m를 쭉 걸어오시면\n\'힉스커피\'의 스텐 간판이 보입니다.\n\n<자차 이용 시>\n죄송하게도 주차가 불가합니다. 인근 역삼문화공원제2호 공영주차장(서울 강남구 테헤란로7길 32)을 이용해주세요.\n내용 더보기 \n store_id: 1785877248 \n address: 서울 강남구 강남대로110길 51 1층 \n blog_review: 블로그 리뷰 23 \n phone_num: 0507-1474-3130 \n business_hours: 월\n11:00 - 22:00\n21:30 라스트오더\n화\n11:00 - 22:00\n21:30 라스트오더\n수(1/1)\n새해 첫날 휴무\n목\n11:00 - 22:00\n21:30 라스트오더\n금\n11:00 - 22:00\n21:30 라스트오더\n토\n12:00 - 22:00\n21:30 라스트오더\n일\n12:00 - 22:00\n21:30 라스트오더\n \n info: 1. Great Coffee, Engineered by Science - 과학으로 완성한 특별한 메뉴\n맛있는 커피를 만들기 위해 원두 선정 부터 기기 선정, 추출 조건 세팅 등 수많은 고민과 실질적인 테스트를 하였습니다. 원두는 고소한 원두, 산미 있는 원두, 디카페인 원두를 쓰고 있으며, 커피 애호가를 위한 브루잉 존이 별도로 있습니다.\n또한, 목성, 지구, 토성, 화성, 달 등 태양계 행성, 위성을 모티브로한 힉스커피의 시그니처 커피와 디저트들은\n과학적 아이디어를 바탕으로, 정교하게 완성한 메뉴입니다.\n한 잔의 커피에 담긴 특별한 이야기를 지금 만나보세요.\n\n2. Awaken Your Curiosity - 바쁜 일상 속 호기심을 깨우는 작은 여유\n한 잔의 커피가 선물하는 작은 여유가 특별한 경험으로 이어지는 카페, 힉스커피에서 감성과 호기심을 깨워보세요.\n새로운 과학적 경험으로 바쁜 일상에 호기심과 활력을 줄 수 있는 공간입니다.\n\n3. Where Coffee Collides with Science - 과학과 커피가 만나는 공간, 힉스커피\n달의 표면과 화성을 모티브로 한 감각적인 공간, 힉스커피는\n강남역 11번 출구와 신논현역 4번 출구 사이에 위치한 도심 속에서 과학의 매력을 느낄 수 있는 카페입니다.\n과학과 커피가 어우러지는 특별한 순간을 힉스커피에서 만나보세요.\n펼쳐보기 \n convenience_facilities_and_services: 핸드드립\n포장\n배달\n단체 이용 가능\n남/녀 화장실 구분\n예약\n\\\n반려동물 동반\n \n Parking: 주차 불가 \n sns: https://www.instagram.com/higgs_coffee/\n \n review_like_this_part_output: "인테리어가 멋져요"이 키워드를 선택한 인원224\n"커피가 맛있어요"이 키워드를 선택한 인원211\n"디저트가 맛있어요"이 키워드를 선택한 인원179\n"특별한 메뉴가 있어요"이 키워드를 선택한 인원139\n"음료가 맛있어요"이 키워드를 선택한 인원115\n"친절해요"이 키워드를 선택한 인원101\n"사진이 잘 나와요"이 키워드를 선택한 인원77\n"대화하기 좋아요"이 키워드를 선택한 인원47\n"매장이 청결해요"이 키워드를 선택한 인원45\n"컨셉이 독특해요"이 키워드를 선택한 인원26\n"매장이 넓어요"이 키워드를 선택한 인원18\n"집중하기 좋아요"이 키워드를 선택한 인원10\n"화장실이 깨끗해요"이 키워드를 선택한 인원10\n"아늑해요"이 키워드를 선택한 인원8\n"메뉴 구성이 알차요"이 키워드를 선택한 인원7\n"가성비가 좋아요"이 키워드를 선택한 인원5\n"종류가 다양해요"이 키워드를 선택한 인원4\n"차분한 분위기에요"이 키워드를 선택한 인원3\n"음악이 좋아요"이 키워드를 선택한 인원3\n"뷰가 좋아요"이 키워드를 선택한 인원3\n"빵이 맛있어요"이 키워드를 선택한 인원2\n"좌석이 편해요"이 키워드를 선택한 인원2\n"음식이 빨리 나와요"이 키워드를 선택한 인원2\n"음식이 맛있어요"이 키워드를 선택한 인원2\n"비싼 만큼 가치있어요"이 키워드를 선택한 인원2\n"차가 맛있어요"이 키워드를 선택한 인원1\n \n menu: 지구 - 코코넛 크림 말차 라떼대표생명체가 거주하는 아름답고 창백한 푸른 점, 지구를 담은 코코넛 크림 말차 라떼7,500원\n목성 - 버터 스카치 크림 라떼대표태양계 행성 중 부피가 가장 큰 가스 행성, 목성의 신비를 컵에 담은 버터스카치 크림 라떼7,500원\n토성 - 라즈베리 아포가토대표145개의 위성을 가진 토성의 아름다운 고리에서 영감을 얻은 라즈베리 아포카토.8,000원\n달 - 흑임자 티라미수대표대한민국 유인 달 탐사를 간절히 응원하는 힉스커피의 역작, 달 흑임자 티라미수8,000원\n지구 - 말차 티라미수대표창백한 푸른 점, 지구를 담아낸 진하고 깊은 풍미의 힉스커피의 역작, 말차 티라미수8,000원\n화성 - 오리지널 티라미수대표인류의 화성 이주 시대를 꿈꾸게 하는 힉스커피의 역작, 화성 오리지널 티라미수7,500원\n티라미수 3종 플래터대표화성, 지구, 달을 모티브로 한 티라미수 3종 플래터14,000원\nmini 바스크 치즈 케이크3,500원\n우롱밀키 - 우롱차크리미한 우유 향이 느껴지는 부드럽고 개운한맛의 우롱차6,700원\n몬트리올 - 홍차메이플시럽의 진한 풍미가 느껴지는 홍차6,700원\n몰디브 - 녹차자몽, 라즈베리 그리고 파파야가 블렌딩 되어 상큼한 맛과 향이 느껴지는 녹차6,700원\n카모마일 오렌지 - 허브차레몬 그라스, 로즈힙 그리고 감귤이 블렌딩되어 향긋한 오렌지 향이 느껴지는 디카페인 허브차6,500원\n금성 - 매실 소르베 에이드국내산 매실수제청으로 만든 청량감 있는 에이드에 레몬소르베를 얹어 완성한 음료7,000원\n태양 - 레몬에이드태양처럼 밝고 상큼한 레몬 에이드로 갈증 해소와 기분 전환에 완벽한 음료7,000원\n트리 라떼 - 딸기 말차상큼한 딸기와 짙은 초록빛 말차가 조화를 이룬 아이스 라떼7,000원\n'),
#  Document(id='d2741677-19da-4e94-a989-ea859739ddd7', metadata={'store_id': '1208377887', 'store_name': '천장지구'}, page_content='store_name: 천장지구 \n category: 카페,디저트 \n new_open:   \n rating: 별점 4.7 \n visited_review: 방문자 리뷰 600 \n directions_text: 더채플앳청담 옆 건물 입니다.\n세븐일레븐 건물 2층에 위치하고 있습니다.\n아래 주소로 검색해 주세요\n언주로 150길 51 2층\n\n네이버 검색창에\n\'압구정 천장지구\' 또는\n\'강남 천장지구\' 검색\n혹은 압구정 카페로 검색하시고 천장지구 클릭하셔서 길찾기 버튼을\n누르시면 연동되는 지도로 쉽게 찾아 오실수 있습니다.\n도산공원에 위치한 쉑쉑버거 앞 신호등 건너 오시면 스타벅스 건물 뒤쪽에 저희 카페위치하고 있습니다\n\'더 채플 청담\' 예식장 후문쪽으로 도보 1분거리에 위치해 있습니다.\n내용 더보기 \n store_id: 1208377887 \n address: 서울 강남구 언주로150길 51 2층 \n blog_review: 블로그 리뷰 780 \n phone_num: 0507-1353-3324 \n business_hours: 월\n11:30 - 21:00\n화\n11:30 - 21:00\n수(1/1)\n새해 첫날12:00 - 20:30\n목\n11:30 - 21:00\n금\n11:30 - 21:00\n토\n12:00 - 21:00\n일\n12:00 - 20:30\n \n info: 카페 천장지구는 \'변화되지 안고 지속적인 것에대한 이야기\' 라는 함축적인 의미를 담고 있습니다. 촬영을 위한 대관 외에도 생일카페, 플리마켓, 단체파티 등의 팝업 협업도 가능하니, 편하게 문의주세요! (문의는 01024693324 문자나 전화 또는 인스타그램 @cheonjangjigu_seoul 로부탁드립니다.) \n convenience_facilities_and_services: 핸드드립\n로스터리\n단체 이용 가능\n포장\n\\\n반려동물 동반\n무선 인터넷\n남/녀 화장실 구분\n배달\n예약\n방문접수/출장\n \n Parking: 주차가능\n유료\n최초 10분 1000원\n추가 요금 10분당 1,000원, 최대 30,000원 \n sns: nan \n review_like_this_part_output: "인테리어가 멋져요"이 키워드를 선택한 인원325\n"커피가 맛있어요"이 키워드를 선택한 인원270\n"디저트가 맛있어요"이 키워드를 선택한 인원237\n"특별한 메뉴가 있어요"이 키워드를 선택한 인원198\n"음료가 맛있어요"이 키워드를 선택한 인원189\n"사진이 잘 나와요"이 키워드를 선택한 인원168\n"친절해요"이 키워드를 선택한 인원118\n"대화하기 좋아요"이 키워드를 선택한 인원104\n"좌석이 편해요"이 키워드를 선택한 인원76\n"매장이 청결해요"이 키워드를 선택한 인원32\n"가성비가 좋아요"이 키워드를 선택한 인원25\n"컨셉이 독특해요"이 키워드를 선택한 인원22\n"집중하기 좋아요"이 키워드를 선택한 인원22\n"음악이 좋아요"이 키워드를 선택한 인원18\n"아늑해요"이 키워드를 선택한 인원14\n"매장이 넓어요"이 키워드를 선택한 인원5\n"뷰가 좋아요"이 키워드를 선택한 인원5\n"화장실이 깨끗해요"이 키워드를 선택한 인원4\n"빵이 맛있어요"이 키워드를 선택한 인원3\n"반려동물과 가기 좋아요"이 키워드를 선택한 인원2\n"차분한 분위기에요"이 키워드를 선택한 인원1\n"음식이 빨리 나와요"이 키워드를 선택한 인원1\n"음식이 맛있어요"이 키워드를 선택한 인원1\n"주차하기 편해요"이 키워드를 선택한 인원1\n"파티하기 좋아요"이 키워드를 선택한 인원1\n"비싼 만큼 가치있어요"이 키워드를 선택한 인원1\n"특별한 날 가기 좋아요"이 키워드를 선택한 인원1\n"오래 머무르기 좋아요"이 키워드를 선택한 인원1\n"차가 맛있어요"이 키워드를 선택한 인원1\n"종류가 다양해요"이 키워드를 선택한 인원1\n \n menu: 무화과 에그 와플대표12,800원\n곤약 소다대표일곱가지 과일로 만든 다섯가지 곤약젤리가 들어가는 음료 입니다7,800원\n패스츄리크림브륄레대표패스츄리안에 커스터드 듬뿍10,500원\n백미소라떼대표흰된장이 커피와 만나 캐러멜과 같은 풍미를 냅니다.6,800원\n카페 오렌지대표커피+ 오렌지쥬스6,800원\n도미빵대표팥 붕어빵\n백앙금 붕어빵\n땅콩버터 붕어빵\n옥수수 붕어빵\n고기 붕어빵3,000원\n에그타르트대표3,000원\n버터라떼대표짭조름한 버터가 더해진 고소한\n커피음료 입니다.6,500원\n시멘트커피대표6,000원\n프렌치크로플대표크로플+아이스크림9,500원\n에그타르트 와플9,000원\n용과 홍콩와플용과와 홍시로 맛을낸 와플12,800원\n커피젤리시그니처블랜딩으로 내린 편하게 먹을수있는 커피젤리와 커피 젤라또6,800원\n호텔 파르페80년대 호텔 레스토랑 스타일 파르페\n꼬냑옵션을 추가해 파르페칵테일로도 드실수 있습니다.9,800원\n카페 레몬커피+ 시실리안 레몬 레이드(제로칼로리)5,800원\n'),
#  Document(id='14993abb-6362-4641-8b78-eb8c7ab26a74', metadata={'store_id': '1967411628', 'store_name': '카멜커피 도산점'}, page_content='store_name: 카멜커피 도산점 \n category: 카페,디저트 \n new_open:   \n rating: 별점 4.45 \n visited_review: 방문자 리뷰 2,255 \n directions_text:   \n store_id: 1967411628 \n address: 서울 강남구 도산대로45길 16-8 \n blog_review: 블로그 리뷰 1,832 \n phone_num: 0507-1486-1540 \n business_hours: 월\n10:00 - 21:00\n20:30 라스트오더\n화\n10:00 - 21:00\n20:30 라스트오더\n수(1/1)\n새해 첫날10:00 - 20:00\n목\n10:00 - 21:00\n20:30 라스트오더\n금\n10:00 - 21:00\n20:30 라스트오더\n토\n10:00 - 21:00\n20:30 라스트오더\n일\n10:00 - 21:00\n20:30 라스트오더\n \n info: 가게 정보 불러오기 실패 \n convenience_facilities_and_services: 핸드드립\n\\\n반려동물 동반\n \n Parking: 주차가능\n유료\n최초 60분 4000원\n추가 요금 10분당 1,000원, 최대 30,000원 \n sns: https://www.instagram.com/camelcoffee_kor\nhttps://cmlandco.kr/\n \n review_like_this_part_output: "커피가 맛있어요"이 키워드를 선택한 인원962\n"인테리어가 멋져요"이 키워드를 선택한 인원402\n"음료가 맛있어요"이 키워드를 선택한 인원251\n"특별한 메뉴가 있어요"이 키워드를 선택한 인원244\n"디저트가 맛있어요"이 키워드를 선택한 인원218\n"친절해요"이 키워드를 선택한 인원211\n"사진이 잘 나와요"이 키워드를 선택한 인원133\n"대화하기 좋아요"이 키워드를 선택한 인원101\n"매장이 청결해요"이 키워드를 선택한 인원59\n"뷰가 좋아요"이 키워드를 선택한 인원31\n"화장실이 깨끗해요"이 키워드를 선택한 인원28\n"가성비가 좋아요"이 키워드를 선택한 인원27\n"좌석이 편해요"이 키워드를 선택한 인원25\n"집중하기 좋아요"이 키워드를 선택한 인원13\n"아늑해요"이 키워드를 선택한 인원12\n"음악이 좋아요"이 키워드를 선택한 인원10\n"컨셉이 독특해요"이 키워드를 선택한 인원6\n"주차하기 편해요"이 키워드를 선택한 인원6\n"비싼 만큼 가치있어요"이 키워드를 선택한 인원5\n"차분한 분위기에요"이 키워드를 선택한 인원3\n"특별한 날 가기 좋아요"이 키워드를 선택한 인원2\n"빵이 맛있어요"이 키워드를 선택한 인원1\n"재료가 신선해요"이 키워드를 선택한 인원1\n"야외공간이 멋져요"이 키워드를 선택한 인원1\n"포장이 깔끔해요"이 키워드를 선택한 인원1\n"반려동물과 가기 좋아요"이 키워드를 선택한 인원1\n"매장이 넓어요"이 키워드를 선택한 인원1\n"오래 머무르기 좋아요"이 키워드를 선택한 인원1\n"건강한 맛이에요"이 키워드를 선택한 인원1\n \n menu: Camel Coffee (카멜커피)대표진한 라떼 (플랫화이트) 베이스에 실키한 크림이 얇게 올라간 시그니처 커피6,000원\nCCC (카멜 클래식 크림)대표카멜커피의 크림을 연상케 하는 순우유 크림이 가득 들어있는 시그니처 브레드5,000원\nAmericano (아메리카노)다크 초콜릿의 단맛과 견과류의 고소함이 느껴지는 커피5,500원\nLatte (라떼)견과류의 고소한 단맛에 부드러운 질감으로 밸런스 좋은 커피6,000원\nVanilla (바닐라라떼)직접 제조한 바닐라 시럽을 베이스로 부드럽고 달콤한 풍미가 느껴지는 커피6,500원\nFlat white (플랫화이트)고소하며 쌉싸름한 맛이 조화롭게 느껴지는 진한 라떼5,500원\nCappuccino (카푸치노)부드러운 거품을 시작으로 고소하며 쌉싸름한 맛이 조화롭게 느껴지는 클래식 카푸치노5,500원\nEspresso (에스프레소)카라멜 초콜릿 톤의 풍부한 단맛과 고소한 향미가 느껴지는 에스프레소4,000원\nConpanna (콘파냐)에스프레소 베이스에 즉석으로 제조한 크림을 올려 조화롭게 즐기실 수 있는 커피4,500원\nMSGR (미숫가루)12가지 곡물을 담은 클래식한 미숫가루7,000원\nCiapple tea (시나몬애플티)인공감미료가 첨가되지 않은 수제청으로 만든 시나몬애플티7,000원\nOrange Juice (오렌지주스)생오렌지를 착즙하여 만든 신선한 오렌지주스6,500원\nRedbean Latte (팥라떼)100% 국내산 통팥을 갈아넣은 달달한 팥라떼6,500원\nMilk Tea (밀크티)오랜시간 저온으로 침출한 루이보스 아몬드 밀크티 (디카페인)6,500원\nOat Milk (오트밀크)담백하고 고소한 오트밀크 (우유 대체)500원\n'),
#  Document(id='fb648a49-221b-4937-affd-c99f244e1457', metadata={'store_id': '1811247983', 'store_name': '까페띠노'}, page_content='store_name: 까페띠노 \n category: 카페,디저트 \n new_open:   \n rating: 별점 4.38 \n visited_review: 방문자 리뷰 138 \n directions_text: 문정역에서 도보 6분 이내,\n문정현대지식산업센터 B동에 위치 H비지니스센터와 마주보고 있는 길 사이에 위치해 있습니다.\n붉은 차양막을 찾아오세요 :)\n내용 더보기 \n store_id: 1811247983 \n address: 서울 송파구 법원로11길 11 문정현대지식산업센터 B동 1층 157-1호 \n blog_review: 블로그 리뷰 59 \n phone_num: 02-3400-0331 \n business_hours: 월\n08:00 - 17:00\n화\n08:00 - 17:00\n수(1/1)\n새해 첫날 휴무\n목\n08:00 - 17:00\n금\n08:00 - 17:00\n토\n정기휴무 (매주 토요일)\n일\n정기휴무 (매주 일요일)\n \n info: 누구에게나 생각만으로 행복한 여행의 기억들이 있습니다. 저에겐 생활이었고 일터였던 이탈리아가 그렇습니다.\n카푸치노로 아침을 열고, 일하다 잠시 커피 한 잔, 휴식이 필요할 때 짬을 내어 커피 한 잔, 동료와 함께 이야기를 나누며 한 잔...\n이 추억들로 지금 저에게 한 잔의 에스프레소가 이탈리아에 있었던 나를 기억하게 해주고, 기억 속 그곳으로 데려다주는\n열쇠가 되었습니다.\n\n저는 당신에게 까페띠노가 자신의 추억 속 행복했던 그 순간으로 갈 수 있는 공간이 되었으면 합니다.\n당장은 못하더라도 언젠간 다시 그곳에서 한 잔의 커피를 할 수 있을 때까지...\n펼쳐보기 \n convenience_facilities_and_services: 무선 인터넷\n포장\n\\\n반려동물 동반\n남/녀 화장실 구분\n \n Parking: 주차가능 \n sns: https://www.instagram.com/caffettino_espressobar\n \n review_like_this_part_output: "커피가 맛있어요"이 키워드를 선택한 인원94\n"친절해요"이 키워드를 선택한 인원40\n"음료가 맛있어요"이 키워드를 선택한 인원38\n"특별한 메뉴가 있어요"이 키워드를 선택한 인원34\n"인테리어가 멋져요"이 키워드를 선택한 인원24\n \n menu: 메따 에 메따대표벨벳같은 질감의 아주 고소한 라떼 :)4,600원\n까페라떼 바닐라 빈대표바닐라 빈으로 직접 시럽을 만듭니다. 바닐라 캐비어가 살아있는 까페띠노 시그니처 메뉴 입니다.4,800원\n까페 꼰 아라끼디대표달콤 고소한 땅콩버터크림을 올린 에스프레소메뉴 입니다. 부담스러웠던 에스프레소가 정말 맛있게 느껴지실거에요 :)2,700원\n드라이 카푸치노풍성한 구름거품의 카푸치노 입니다 :) 시나몬 토핑 또는 카카오 토핑 가능합니다3,500원\n에스프레소 마티니에스프레소와 깔루아, 보드카의 만남 :)6,500원\n아페롤 스프리츠이탈리아 국민 식전주, 오렌지향의 아페롤 스프리츠 입니다 :)8,000원\n애플 마티니사과향의 상큼달큼 마티니6,500원\n마티니 비앙코달달한 베르무트, 디저트 술 :)6,000원\n리얼 헤이즐넛 크림라떼헤이즐넛 향시럽이 아닌 100% 헤이즐넛 페이스트와 생크림으로 만든 크림이 올라간 라떼6,000원\n콜드브루 바닐라크림 아인슈패너초콜릿풍미의 콜드브루와 바닐라빈크림이 올라간 아인슈패너 :)5,500원\n아메리카노흑설탕같은 맛을 지니고 있는 원두를 사용합니다.3,200원\n까페라떼우유의 고소한과 어울리는 산미와 단맛이 살아 있는 원두를 사용합니다.3,900원\n까페라떼 돌체달달한 라떼가 마시고 싶을때, 뒷맛이 깔끔한 연유를 넣은 까페라뗴 돌체로 달달하게 맛있게 드세요!4,400원\n까페 도삐오흑설탕같은 맛을 지닌 에스프레소 입니다.1,800원\n까페 마끼아또에스프레소를 조금 부드럽게! 우유 점을 살짝 찍은 까페 마끼아또 한잔 어떠세요?2,200원\n'),
#  Document(id='e6516b95-1c97-4700-a9f1-9059fb34921b', metadata={'store_id': '1996711162', 'store_name': '커피랑도서관 가락시장역점'}, page_content='store_name: 커피랑도서관 가락시장역점 \n category: 스터디카페 \n new_open:   \n rating: 별점 4.67 \n visited_review: 방문자 리뷰 93 \n directions_text: 3,8호선 가락시장역점 8번출구 도보 2분거리에 위치해있습니다.\n[BBQ 문정동본사근처]\n[스타벅스 문정점근처]\n내용 더보기 \n store_id: 1996711162 \n address: 서울 송파구 중대로 60-6 5층 \n blog_review: 블로그 리뷰 164 \n phone_num: 070-8808-1140 \n business_hours: 매일\n00:00 - 24:00\n \n info: 커피랑도서관 가락시장역점은 매일 아침 직접 내려드리는 <고급 스타벅스 원두커피>와 함께 공부하실 수 있는 프리미엄 스터디 카페입니다.\n\n그윽한 커피향과 조용한 음악, 그리고 좋은 책들이 가득한 도서관형 스터디 카페입니다.\n평소 읽고 싶던 책들을 언제든 꺼내 읽어 볼 수 있고 사색에 잠길 수 있는, 문화와 집중이 공존하는 공간입니다.\n\n전체 유리창으로 이루어진 벽면과 유리창을 가득 채운 책들 사이로 스며드는 햇빛이 너무도 기분 좋은 무드를 형성합니다.\n\n공부에 집중을 도울 뿐만 아니라 이 공간에 머무는 것만으로도 정서적 안정감을 느끼실 수 있습니다.\n초록초록한 식물들과 공기청청기도 곳곳에 배치되어 있어 공기정화 뿐만 아니라 눈과 마음의 피로를 덜어 드립니다.\n\n넓은 오픈형 테이블과 분리된 개별형 책상,\n나란히 앉아서 공부할수 있는 커플석.\n졸리거나 스트레칭이 필요할 때 유용한 스텐딩형 테이블까지\n다양한 형태의 테이블을 기호에 맞게 그날의 기분에 맞게 선택해서 이용하실 수 있도록 누구에게나 모든 공간이 열려있습니다.\n\n뿐만 아니라 다양한 스터디룸(2,4,8인실)을 구비하고 있어\n과외, 상담, 그룹스터디, 비지니스 회의 등이 가능합니다.\n\n심야시간을 제외하고는 관리자가 상주하고 있는 철저한 유인 시스템의 스터디 카페입니다.\n또한 저희 커피랑도서관 가락시장역점은 핸드드립 커피 뿐만 아니라 다양한 음료를 무료로 제공해 드리고 있습니다.\n\n프린터를 구비하고 있어 인쇄물도 출력하실 수 있습니다.\n핸드폰 충전기 및 독서대,무소음마우스,담요등도 대여해 드립니다.\n장기 이용자분들을 위한 사물함도 넉넉하게 준비되어 있어 편리하게 이용하실 수 있습니다.\n저희 커피랑도서관 가락시장역점은 여러분의 소중한 시간과 열정을 응원합니다.\n찾아주신 모든 분들께 최선의 서비스로 보답하겠습니다.\n펼쳐보기 \n convenience_facilities_and_services: 예약\n단체 이용 가능\n무선 인터넷\n남/녀 화장실 구분\n \n Parking: 주차가능 \n sns: https://blog.naver.com/cll_garakstation_\n \n review_like_this_part_output: "집중하기 좋아요"이 키워드를 선택한 인원32\n"친절해요"이 키워드를 선택한 인원21\n"요금제가 잘 되어있어요"이 키워드를 선택한 인원19\n"가성비가 좋아요"이 키워드를 선택한 인원18\n"커피가 맛있어요"이 키워드를 선택한 인원16\n"분위기 관리가 철저해요"이 키워드를 선택한 인원14\n"차분한 분위기에요"이 키워드를 선택한 인원13\n"매장이 청결해요"이 키워드를 선택한 인원12\n"화장실이 깨끗해요"이 키워드를 선택한 인원12\n"인테리어가 멋져요"이 키워드를 선택한 인원7\n"룸이 잘 되어있어요"이 키워드를 선택한 인원5\n"매장이 넓어요"이 키워드를 선택한 인원5\n"좌석이 편해요"이 키워드를 선택한 인원2\n"비싼 만큼 가치있어요"이 키워드를 선택한 인원2\n"아늑해요"이 키워드를 선택한 인원1\n"디저트가 맛있어요"이 키워드를 선택한 인원1\n"조용해요"이 키워드를 선택한 인원1\n"개인 공간이 쾌적해요"이 키워드를 선택한 인원1\n"종류가 다양해요"이 키워드를 선택한 인원1\n \n menu: 첫방문 무료체험 4시간대표첫 방문 이용자는 무료로 4시간 체험이 가능합니다 ◡̎\n카운터에 문의해주세요 !무료\n2시간4,000원\n반일권(8시간)11,000원\n종일권(13시간)15,000원\n24시간(5주)200,000원\n선불할인권(5주)170,000원\n주말(4주)90,000원\n24시(2주)120,000원\n선불할인권(2주)125,000원\n'),
#  Document(id='5924342e-ce1e-4c30-beb3-ee44a80b9bf1', metadata={'store_id': '1038175420', 'store_name': '이디야커피 성남복정도서관점'}, page_content='store_name: 이디야커피 성남복정도서관점 \n category: 카페 \n new_open:   \n rating: 별점 4.53 \n visited_review: 방문자 리뷰 1,166 \n directions_text: 복정역2번출구 나와서 710m(도보10분) 복정동 분수광장앞에 위치하고 있습니다^^ \n store_id: 1038175420 \n address: 경기 성남시 수정구 복정로 121 1층 101호 \n blog_review: 블로그 리뷰 18 \n phone_num: 0507-1427-2575 \n business_hours: 월\n08:00 - 22:00\n21:50 라스트오더\n화\n08:00 - 22:00\n21:50 라스트오더\n수(1/1)\n새해 첫날09:00 - 22:00\n목\n08:00 - 22:00\n21:50 라스트오더\n금\n08:00 - 22:00\n21:50 라스트오더\n토\n09:00 - 22:00\n21:50 라스트오더\n일\n09:00 - 22:00\n21:50 라스트오더\n \n info: 이디야커피 성남복정도서관점 입니다.\n복정도서관 앞 먹자골목에 위치해 있습니다.\n매장 옆 분수광장, 공원 조성되어 있으며, 인근 공영주차장에 주차 가능하십니다. \n convenience_facilities_and_services: 포장\n단체 이용 가능\n무선 인터넷\n남/녀 화장실 구분\n배달\n대기공간\n장애인 휠체어 이용가능\n출입구 휠체어 이용가능\n장애인 주차구역\n \n Parking: 주차가능\n무료 \n sns: nan \n review_like_this_part_output: "커피가 맛있어요"이 키워드를 선택한 인원371\n"음료가 맛있어요"이 키워드를 선택한 인원186\n"친절해요"이 키워드를 선택한 인원149\n"대화하기 좋아요"이 키워드를 선택한 인원145\n"매장이 청결해요"이 키워드를 선택한 인원133\n"가성비가 좋아요"이 키워드를 선택한 인원122\n"디저트가 맛있어요"이 키워드를 선택한 인원111\n"좌석이 편해요"이 키워드를 선택한 인원98\n"인테리어가 멋져요"이 키워드를 선택한 인원55\n"집중하기 좋아요"이 키워드를 선택한 인원44\n"뷰가 좋아요"이 키워드를 선택한 인원42\n"특별한 메뉴가 있어요"이 키워드를 선택한 인원30\n"화장실이 깨끗해요"이 키워드를 선택한 인원30\n"매장이 넓어요"이 키워드를 선택한 인원14\n"사진이 잘 나와요"이 키워드를 선택한 인원12\n"주차하기 편해요"이 키워드를 선택한 인원6\n"양이 많아요"이 키워드를 선택한 인원2\n"차분한 분위기에요"이 키워드를 선택한 인원1\n"아이와 가기 좋아요"이 키워드를 선택한 인원1\n"메뉴 구성이 알차요"이 키워드를 선택한 인원1\n"오래 머무르기 좋아요"이 키워드를 선택한 인원1\n"단체모임 하기 좋아요"이 키워드를 선택한 인원1\n"종류가 다양해요"이 키워드를 선택한 인원1\n \n menu: (EX)ICED 카페 아메리카노더 커지고 더 깊어졌다. 구운 견과류의 고소한 향미와 다크초콜렛의 Bitter sweet 깊고 깔끔한 애프터테이스트가 특징인 이디야의 대표음료4,200원\n허니 카라멜 브레드은은한 시나몬과 진한 카라멜 코팅이 된 허니브레드에 휘핑크림을 더해 한결 부드러워진 맛의 허니브레드5,200원\n(EX)ICED 시그니처 라떼생크림이 함유되어 부드럽고 풍부한 시그니처밀크와 진하고 고소한 에스프레소가 조화를 이뤄 깊고 고소한 맛을 선사하는 특별한 라떼5,900원\n(EX)ICED 민트 모히또 라떼에스프레소와 은은한 민트향이 어우러진 신선하고 이국적인 풍미와 시그니처 밀크가 만들어내는 크리미한 바디감이 특징인 라떼6,100원\n(EX)ICED 홀리데이 레드뱅쇼스페인산 와인에 복분자 사과, 배, 레몬 등 다양한 과일을 더해 본연의 맛을 담아 풍성하고 다채로운 풍미를 진하게 느낄 수 있는 이디야만의 스페셜 논알콜 레드 뱅쇼5,900원\n(EX)ICED 윈터 화이트뱅쇼모스카토의 달콤한 풍미와, 이탈리아산 백포도의 향미를 겨울시즌 특별하게 즐길 수 있는 이디야만의 스페셜 논알콜 화이트 뱅쇼5,900원\n(EX)ICED 흑임자 크림 라떼부드러운 크림과 고소한 흑임자와 연유가 만나 달콤함과 고소함을 듬뿍 느낄 수 있는 음료5,700원\n(변우석)스틱커피 오리지널 아메리카노 20T커피 생산 최적지인 콜롬비아산 SD 인스턴트 BASE를 사용하였습니다. 감칠맛과 뛰어난 향기가 특징입니다. 이디야의 기술력이 녹아 있는 대표 비니스트. 오리지널에는 다 이유가 있습니다. 언제 어디서나 간편하게 물에 사르르 녹는 오리지널의 향을 즐겨보세요.4,700원\n(변우석)스틱커피 오리지널 아메리카노 80+20T커피 생산 최적지인 콜롬비아산 SD 인스턴트 BASE를 사용하였습니다. 감칠맛과 뛰어난 향기가 특징입니다. 이디야의 기술력이 녹아 있는 대표 비니스트. 오리지널에는 다 이유가 있습니다. 언제 어디서나 간편하게 물에 사르르 녹는 오리지널의 향을 즐겨보세요.16,400원\n(변우석)스틱커피 골드블렌드 30T무지방 우유가 함유된 크리머를 사용하여 깔끔한 끝맛과 라떼와 같은 부드러움을 느낄 수 있는 커피믹스(30T)5,400원\n(변우석)스틱커피 골드블렌드 100T무지방 우유가 함유된 크리머를 사용하여 깔끔한 끝맛과 라떼와 같은 부드러움을 느낄 수 있는 커피믹스(100T)14,700원\n(R)HOT 치이카와 생딸기 포멜로 티펀치\'치이카와\' 캐릭터 음료로 캐릭터의 분홍색을 표현한 딸기, 포멜로와 복숭아, 레몬의 상큼함을 동시에 즐길 수 있는 블렌딩티4,500원\n(R)ICED 치이카와 생딸기 포멜로 티펀치\'치이카와\' 캐릭터 음료로 캐릭터의 분홍색을 표현한 딸기, 포멜로와 복숭아, 레몬의 상큼함을 동시에 즐길 수 있는 블렌딩티4,500원\n(EX)HOT 치이카와 생딸기 포멜로 티펀치\'치이카와\' 캐릭터 음료로 캐릭터의 분홍색을 표현한 딸기, 포멜로와 복숭아, 레몬의 상큼함을 동시에 즐길 수 있는 블렌딩티5,500원\n(EX)ICED 치이카와 생딸기 포멜로 티펀치\'치이카와\' 캐릭터 음료로 캐릭터의 분홍색을 표현한 딸기, 포멜로와 복숭아, 레몬의 상큼함을 동시에 즐길 수 있는 블렌딩티5,500원\n(R)(가르마)생딸기 크런치 쉐이크\'가르마\'캐릭터 음료로 쉐이크의 밀키함과 딸기 과육의 풍미, 쿠키분태의 바삭한 식감을 느낄 수 있는 쉐이크5,900원\n(L)HOT 카페 아메리카노더 커지고 더 깊어졌다. 구운 견과류의 고소한 향미와 다크초콜렛의 Bitter sweet 깊고 깔끔한 애프터테이스트가 특징인 이디야의 대표음료3,200원\n(L)ICED 카페 아메리카노더 커지고 더 깊어졌다. 구운 견과류의 고소한 향미와 다크초콜렛의 Bitter sweet 깊고 깔끔한 애프터테이스트가 특징인 이디야의 대표음료3,200원\n(EX)HOT 카페 아메리카노더 커지고 더 깊어졌다. 구운 견과류의 고소한 향미와 다크초콜렛의 Bitter sweet 깊고 깔끔한 애프터테이스트가 특징인 이디야의 대표음료4,200원\n(EX)ICED 카페 아메리카노더 커지고 더 깊어졌다. 구운 견과류의 고소한 향미와 다크초콜렛의 Bitter sweet 깊고 깔끔한 애프터테이스트가 특징인 이디야의 대표음료4,200원\n(L)HOT 시그니처 라떼생크림이 함유되어 부드럽고 풍부한 시그니처밀크와 진하고 고소한 에스프레소가 조화를 이뤄 깊고 고소한 맛을 선사하는 특별한 라떼4,700원\n(Decaf)(L)HOT 카페 아메리카노풍부한 향미와 진한 단맛을 중심으로 긴 여운의 밸런스가 좋은 디카페인 아메리카노3,700원\n(Decaf)(L)ICED 카페 아메리카노풍부한 향미와 진한 단맛을 중심으로 긴 여운의 밸런스가 좋은 디카페인 아메리카노3,700원\n(Decaf)(EX)HOT 카페 아메리카노풍부한 향미와 진한 단맛을 중심으로 긴 여운의 밸런스가 좋은 디카페인 아메리카노4,700원\n(Decaf)(E ...
#  Document(id='5618b9f5-cfdc-4a93-bce5-5a89c31e185d', metadata={'store_id': '1440248212', 'store_name': '억셉트커피 양재점'}, page_content='store_name: 억셉트커피 양재점 \n category: 카페,디저트 \n new_open:   \n rating: 별점 4.55 \n visited_review: 방문자 리뷰 424 \n directions_text: 억셉트커피 양재점은 개포 119 맞은편에 위치해 있습니다.\n버스정류장[구룡사거리]에서 하차하신 후 육교와 횡단보도를\n조금 건너시며 5분 정도 걸어오시면 보이십니다.\n\n[양재시민의숲역에서 약 1.2km]\n\n자차로 방문해주시는 경우 카페 공식 주차장은 없으나,\n건물 입주자용 주차장이 비어있을 경우 주차하셔도 괜찮습니다.\n매장 옆에 주차하실 곳이 없는 경우 근처 [포이초등학교 주차장]을\n이용해주시길 바랍니다.\n내용 더보기 \n store_id: 1440248212 \n address: 서울 강남구 논현로10길 20 1층 억셉트커피 \n blog_review: 블로그 리뷰 57 \n phone_num: 0507-1361-4157 \n business_hours: 화\n08:00 - 18:00\n17:30 라스트오더\n수(1/1)\n새해 첫날 휴무\n목\n08:00 - 18:00\n17:30 라스트오더\n금\n08:00 - 18:00\n17:30 라스트오더\n토\n정기휴무 (매주 토요일)\n일\n정기휴무 (매주 일요일)\n월\n08:00 - 18:00\n17:30 라스트오더\n \n info: \'당신이 원하는 모든 것을 수용하고 받아들인다.\'\n\n라는 슬로건을 가지고 만든 로스팅 브랜드입니다.\n저희 것만 고집하지 않고 고객들의 NEEDS를 받아들이고\n수용하는 것을 모토로 하며 고객들의 신뢰를 쌓아갑니다.\n그 신뢰는 맹목적인 믿음이 아닌 서로 간의 신용을 바탕으로 하는\n신뢰라는 것을 뜻합니다.\n고객들과의 소통에 있어서 하나의 거짓도 없이 진실한 마음으로\n다가가면 고객들도 마음 깊숙이 저희를 받아들일 수 있다는 의미입니다.\n재료로 속이지 않으며, 말로 현혹시키지 않고 항상 진실되게 하고 있습니다.\nACCEPT에서는 항상 모든 로스팅 시 실시간으로 커피의 각 포인트를 조정하기 위해 모든 배치마다 컬러를 체크하여 평균치를 맞춰\n고객들이 항상 일률적인 커피 맛을 느낄 수 있게 하고 있습니다.\n\n또한 실시간으로 에스프레소, 아메리카노, 카페라떼, 드립 등으로 컵 테스트를 하며 최적의 로스팅을 할 수 있도록 Q/C를 위한 기자재들까지 준비해놓고 있습니다.\n펼쳐보기 \n convenience_facilities_and_services: 포장\n배달\n예약\n남/녀 화장실 구분\n단체 이용 가능\n\\\n반려동물 동반\n \n Parking: 주차 정보없음 \n sns: https://www.instagram.com/acceptcoffee_yangjae\nhttp://acceptcoffee.co.kr/\n \n review_like_this_part_output: "커피가 맛있어요"이 키워드를 선택한 인원269\n"음료가 맛있어요"이 키워드를 선택한 인원121\n"디저트가 맛있어요"이 키워드를 선택한 인원116\n"친절해요"이 키워드를 선택한 인원97\n"인테리어가 멋져요"이 키워드를 선택한 인원60\n"대화하기 좋아요"이 키워드를 선택한 인원57\n"매장이 청결해요"이 키워드를 선택한 인원49\n"집중하기 좋아요"이 키워드를 선택한 인원42\n"가성비가 좋아요"이 키워드를 선택한 인원33\n"특별한 메뉴가 있어요"이 키워드를 선택한 인원31\n"좌석이 편해요"이 키워드를 선택한 인원29\n"화장실이 깨끗해요"이 키워드를 선택한 인원18\n"사진이 잘 나와요"이 키워드를 선택한 인원12\n"아늑해요"이 키워드를 선택한 인원9\n"차분한 분위기에요"이 키워드를 선택한 인원5\n"뷰가 좋아요"이 키워드를 선택한 인원4\n"주차하기 편해요"이 키워드를 선택한 인원3\n"음식이 맛있어요"이 키워드를 선택한 인원2\n"음악이 좋아요"이 키워드를 선택한 인원2\n"야외공간이 멋져요"이 키워드를 선택한 인원2\n"빵이 맛있어요"이 키워드를 선택한 인원1\n"주문제작을 잘해줘요"이 키워드를 선택한 인원1\n"메뉴 구성이 알차요"이 키워드를 선택한 인원1\n"반려동물과 가기 좋아요"이 키워드를 선택한 인원1\n"오래 머무르기 좋아요"이 키워드를 선택한 인원1\n \n menu: 연금술커피(only ice)대표부드럽고 크리미한 질감을 즐길수있고 콜드브루와 바닐라에 은은함이 잘 어울리는 크림커피입니다6,500원\n텍스처라떼대표동물성 크림의 질감과 우유의 부드러움 그리고 달콤한 크림 치즈같은 뉘앙스를 느낄수있는 커피5,500원\n돌체화이트(onlyice)대표우유를 농축해서 만든 연유의 바닐라 시럽과 크림을 혼합하여 부드럽고 달콤한 커피5,500원\n너티블루스(onlyice)대표흑설탕과 헤이즐넛의 달콤함이 조화롭게 잘 어울리는 너티한 느낌을 잘 살려낸 달달한 커피5,500원\nC타입1kg대표500g 20,000원\n200g 9,800원\n다크초콜릿,와이니한산미,카카오의쌉싸름30,000원\nB타입1kg대표볶은견과류,캐러멜의단맛,오렌지산미\n500g 20,000원\n200g 9,800원30,000원\nF타입1kg대표은은한 꽃 차,열대과일산미,밀크초코단맛\n500g 20,000원\n200g 9,800원30,000원\nDecaf 500g대표흑설탕의 단맛이 좋고 군고구마 같은 뉘앙스가 인상적이고 작물에 특유의 고소함이 특징25,000원\n더치원액500ml대표13,000원\n에스프레소전문 로스터리답게 추출의 퀄리티 걱정하지마세요 정말 맛있는 에스프레소 경험 시켜드리겠습니다4,500원\n아메리카노블렌딩 C타입 B타입 F타입 선택이 가능합니다. 각 다른 매력으로 커피를 즐길수있습니다.4,500원\n더치아메리카노5,000원\n디카페인변경모든 커피 메뉴 디카페인 추가 가능 합니다500원\n오트밀크변경라떼 종류 <오트사이드 오트밀크>\n변경 가능 합니다.500원\n카페라떼5,000원\n')]

# %%
# Step 1: FAISS 인덱스 파일 로드
faiss_index_path = "Faiss/naver_map_jongro_faiss"  # 저장된 Faiss 파일 경로
embeddings = OpenAIEmbeddings()  # 임베딩 객체 초기화

# 저장된 FAISS 인덱스를 불러와서 Retriever 생성
retriever_naver_jongro = FAISS.load_local(faiss_index_path, embeddings,allow_dangerous_deserialization=True).as_retriever()

# 검색 매개변수 설정 (예: 검색 결과 상위 10개 반환)
retriever_naver_jongro.search_kwargs = {"k": 8}

# %%
# Step 1: FAISS 인덱스 파일 로드
faiss_index_path = "Faiss/naver_map_Junggu_faiss"  # 저장된 Faiss 파일 경로
embeddings = OpenAIEmbeddings()  # 임베딩 객체 초기화

# 저장된 FAISS 인덱스를 불러와서 Retriever 생성
retriever_naver_Junggu = FAISS.load_local(faiss_index_path, embeddings,allow_dangerous_deserialization=True).as_retriever()

# 검색 매개변수 설정 (예: 검색 결과 상위 10개 반환)
retriever_naver_Junggu.search_kwargs = {"k": 8}

# %%
# Step 1: FAISS 인덱스 파일 로드
faiss_index_path = "Faiss/naver_map_yongsan_faiss"  # 저장된 Faiss 파일 경로
embeddings = OpenAIEmbeddings()  # 임베딩 객체 초기화

# 저장된 FAISS 인덱스를 불러와서 Retriever 생성
retriever_naver_yongsan = FAISS.load_local(faiss_index_path, embeddings,allow_dangerous_deserialization=True).as_retriever()

# 검색 매개변수 설정 (예: 검색 결과 상위 10개 반환)
retriever_naver_yongsan.search_kwargs = {"k": 8}

# %%
retriever_naver_yongsan.invoke('카페')
# Out:
# [Document(id='ca8b40b9-d9fb-42ba-8375-352626fef952', metadata={'store_id': '1529139711', 'store_name': '카페 르상스'}, page_content='store_name: 카페 르상스 \n category: 카페,디저트 \n new_open:   \n rating: 정보없음 \n visited_review: 방문자 리뷰 449 \n directions_text: * 발렛 주차(Valet Parking) : 사운즈한남 지하1층 주차장\n<매장에서 결제시 등록하시면 됩니다.>\n\n* 캐치테이블 예약 : 와인 주문시만 예약이 가능합니다. 감사합니다.\n\n*이태원역 3번 출구 / 한강진역 3번 출구 / 한남역 1번 출구 (도보 10분)\n내용 더보기 \n store_id: 1529139711 \n address: 서울 용산구 대사관로 35 사운즈 한남 1층 \n blog_review: 블로그 리뷰 304 \n phone_num: 02-794-9009 \n business_hours: 매일\n10:00 - 22:00\n21:30 라스트오더\n \n info: CAFE LE SENS\nArtisan Bakery & Intelligentsia Coffee & Wine & Tea\n.\n<다섯가지 감각의 만족을 경험하는 공간, 카페 르상스>\n카페 르상스는 다섯 가지 감각의 만족을 경험한다는 의미로 베이커리와 커피, 와인과 핑거푸드 그리고 테라스와 음악으로 구성되어 일상에서의 즐거움과 여유를 전하는 복합 문화 공간입니다.\n\n프렌치 베이커리와 인텔리젠시아 스페셜티 커피, 나가사키 지역 장인의 고급 녹차로 만드는 티음료, 야외 테라스에서 즐기기 좋은 가볍고 편한 화이트 와인과 핑거푸드 그리고 실내에서 야외 테라스까지 퍼지는 음악으로 편안하고 즐거운 감각의 만족을 만들어갑니다.\n.\n< Artisan Bakery >\n프랑스 밀가루와 천연 발효종(르방)을 넣어 만든 전통 유럽빵(바게트, 치아바타 등) / 좋은 재료를 듬뿍 넣은 마들렌, 휘낭시에, 르뱅 쿠키 / 향긋한 풍미와 부드러운 식감을 가진 생식빵 / 바삭하면서 촉촉한 소금빵 / 잠봉뵈르 바게트 샌드위치, 분지로 카츠 샌드 등 다양한 샌드위치를 매일 아침 만들고 있습니다.\n\n< 인텔리젠시아 커피 INTELLIGENTSIA COFFEE >\n카페 르상스에서는 스페셜티 커피의 선구자이자 미국을 대표하는 3대 커피로 알려진 인텔리젠시아의 원두로 에스프레소를 내리고 있습니다.\n\n인텔리젠시아는 산지에서 수확한 커피를 각 계절에 가장 맛있는 제철 과일처럼 커피도 가장 맛있는 시기에 공급하는 인 시즌 커피 프로그램을 운영하고 있습니다. 선별한 최상급 생두로 로스팅과 블렌딩을 거치고 바리스타의 세심한 추출로 완벽한 에스프레소 한잔이 완성됩니다.\n\n미국 시카고에 위치한 인텔리젠시아 로스팅 웍스에서 로스팅 후 항공 운송으로 국내에 신선한 원두를 받아 커피가 가장 달콤하고 신선할 때 커피 본연의 맛과 향을 간직한 커피를 추출하고 있어요.\n\n훌륭한 밸런스로 입 안 가득 느껴지는 강렬한 향을 가진 인텔리젠시아 커피를 카페 르상스에서 만나보세요! 매장에 오시면 원두 구매도 가능합니다.\n.\n< 블랙캣 클래식 >\nBlack Cat Classic\n커피 체리의 은은한 산미와 브라운 슈가의 달콤한 향미, 훌륭한 밸런스와 풍미를 가진 커피\n\n< 오스쿠로 블렌드 >\nOscuro Blend\n풍부한 바디와 다크 초콜렛, 누가, 구운 헤이즐넛 뉘앙스를 가진 매력적인 커피\n\n< 디카프 블랙캣 에스프레소 >\nDecaf Black Cat Espresso\n원두가 가진 고유한 특징을 완벽하게 발현시킨 로스팅 기술로 코코아, 사과의 풍미를 가진 디카프 커피\n.\n\n다섯가지 감각의 만족을 경험하는 공간, 카페 르상스\n\n-한남동베이커리\n-한남동브런치\n-사운즈한남\n-한남동카페\n-한남동와인\n-테라스카페\n-TD\n펼쳐보기 \n convenience_facilities_and_services: 포장\n남/녀 화장실 구분\n예약\n배달\n무선 인터넷\n \n Parking: 주차가능\n무료 \n sns: https://catchtable.co.kr/cafelesens\nhttps://www.instagram.com/cafelesens\n \n review_like_this_part_output: "음식이 맛있어요"이 키워드를 선택한 인원161\n"인테리어가 멋져요"이 키워드를 선택한 인원145\n"친절해요"이 키워드를 선택한 인원94\n"특별한 메뉴가 있어요"이 키워드를 선택한 인원94\n"매장이 청결해요"이 키워드를 선택한 인원89\n"커피가 맛있어요"이 키워드를 선택한 인원76\n"디저트가 맛있어요"이 키워드를 선택한 인원69\n"뷰가 좋아요"이 키워드를 선택한 인원67\n"재료가 신선해요"이 키워드를 선택한 인원49\n"주차하기 편해요"이 키워드를 선택한 인원39\n"화장실이 깨끗해요"이 키워드를 선택한 인원33\n"대화하기 좋아요"이 키워드를 선택한 인원32\n"음료가 맛있어요"이 키워드를 선택한 인원27\n"매장이 넓어요"이 키워드를 선택한 인원26\n"야외공간이 멋져요"이 키워드를 선택한 인원25\n"양이 많아요"이 키워드를 선택한 인원19\n"특별한 날 가기 좋아요"이 키워드를 선택한 인원18\n"사진이 잘 나와요"이 키워드를 선택한 인원17\n"가성비가 좋아요"이 키워드를 선택한 인원17\n"아늑해요"이 키워드를 선택한 인원15\n"혼밥하기 좋아요"이 키워드를 선택한 인원10\n"단체모임 하기 좋아요"이 키워드를 선택한 인원10\n"차분한 분위기에요"이 키워드를 선택한 인원9\n"건강한 맛이에요"이 키워드를 선택한 인원6\n"비싼 만큼 가치있어요"이 키워드를 선택한 인원4\n"빵이 맛있어요"이 키워드를 선택한 인원3\n"음악이 좋아요"이 키워드를 선택한 인원3\n"컨셉이 독특해요"이 키워드를 선택한 인원2\n"메뉴 구성이 알차요"이 키워드를 선택한 인원2\n"반려동물과 가기 좋아요"이 키워드를 선택한 인원2\n"오래 머무르기 좋아요"이 키워드를 선택한 인원2\n"집중하기 좋아요"이 키워드를 선택한 인원2\n"차가 맛있어요"이 키워드를 선택한 인원1\n \n menu: 아메리카노대표인텔리젠시아 커피(스페셜티 커피 선구자/미국 3대커피) *3가지 원두: 클래식/다크/디카프5,500원\n[Winter Best] 슈톨렌 S대표럼과 와인 풍미가 스며든 건과일, 넛츠의 고소함, 은은한 시나몬 향을 담은 르상스 슈톨렌19,000원\n[Winter Best] 슈톨렌 L대표럼과 와인 풍미가 스며든 건과일, 넛츠의 고소함, 은은한 시나몬 향을\n담은 르상스 슈톨렌39,000원\n[Winter Best] 뱅쇼대표레드와인에 여러 과일, 시나몬을과 향신료를 넣어 따뜻하게 끓인 프랑스 음료9,500원\n르상스 크림 커피대표너티한 땅콩 크림과 인텔리젠시아 원두가 만나 고소하고 리치한 크림커피7,000원\n[오가와] 그린티 / 유자 그린티대표일본 차 장인 \'오가와 타카유키\'의 그린티 (전통 방식 그대로 덖어 감칠맛이 좋은 녹차)7,000원\n[오가와] 호지티대표일본 차 장인 \'오가와 타카유키\'의 호지티(녹차를 볶아 카페인 함량이 적고 구수한 차)7,000원\n[오가와] 말차 라떼대표*일본 장인의 말차+우유\n*옵션-오트밀/저지방 우유/에스프레소 샷 추가 +5007,500원\n[오가와] 호지 라떼대표*일본 장인의 호지차+우유\n*옵션-오트밀/저지방 우유/에스프레소 샷 추가 +5007,500원\n[WINE FOOD] 르상스 플래터대표6종 이상의 유럽 치즈를 중심으로 샤퀴테리 & 견과류 & 올리브29,000원\n[WINE FOOD]부라타무스 샐러드부라타 치즈 무스 & 마리네이트 토마토 &하몽25,000원\n[WINE FOOD] 올리브 & 하몽마리네이드된 다양한 종류의 올리브와 하몽18,000원\n리얼 초콜렛 (HOT / ICED)진한 벨기에 다크 초콜렛을 우유와 함께 그대로 녹여 꾸덕하고 진한 리얼 초콜렛8,000원\n오사쯔 라떼(고구마 라떼)달콤한 고구마와 우유를 베이스로 만든 담백한 오사쯔 라떼7,500원\n얼그레이 밀크티 ...
#  Document(id='e3674c9b-05ad-40b2-8976-be91c203a2c1', metadata={'store_id': '1529139711', 'store_name': '카페 르상스'}, page_content='store_name: 카페 르상스 \n category: 카페,디저트 \n new_open:   \n rating: 정보없음 \n visited_review: 방문자 리뷰 449 \n directions_text: * 발렛 주차(Valet Parking) : 사운즈한남 지하1층 주차장\n<매장에서 결제시 등록하시면 됩니다.>\n\n* 캐치테이블 예약 : 와인 주문시만 예약이 가능합니다. 감사합니다.\n\n*이태원역 3번 출구 / 한강진역 3번 출구 / 한남역 1번 출구 (도보 10분)\n내용 더보기 \n store_id: 1529139711 \n address: 서울 용산구 대사관로 35 사운즈 한남 1층 \n blog_review: 블로그 리뷰 304 \n phone_num: 02-794-9009 \n business_hours: 매일\n10:00 - 22:00\n21:30 라스트오더\n \n info: CAFE LE SENS\nArtisan Bakery & Intelligentsia Coffee & Wine & Tea\n.\n<다섯가지 감각의 만족을 경험하는 공간, 카페 르상스>\n카페 르상스는 다섯 가지 감각의 만족을 경험한다는 의미로 베이커리와 커피, 와인과 핑거푸드 그리고 테라스와 음악으로 구성되어 일상에서의 즐거움과 여유를 전하는 복합 문화 공간입니다.\n\n프렌치 베이커리와 인텔리젠시아 스페셜티 커피, 나가사키 지역 장인의 고급 녹차로 만드는 티음료, 야외 테라스에서 즐기기 좋은 가볍고 편한 화이트 와인과 핑거푸드 그리고 실내에서 야외 테라스까지 퍼지는 음악으로 편안하고 즐거운 감각의 만족을 만들어갑니다.\n.\n< Artisan Bakery >\n프랑스 밀가루와 천연 발효종(르방)을 넣어 만든 전통 유럽빵(바게트, 치아바타 등) / 좋은 재료를 듬뿍 넣은 마들렌, 휘낭시에, 르뱅 쿠키 / 향긋한 풍미와 부드러운 식감을 가진 생식빵 / 바삭하면서 촉촉한 소금빵 / 잠봉뵈르 바게트 샌드위치, 분지로 카츠 샌드 등 다양한 샌드위치를 매일 아침 만들고 있습니다.\n\n< 인텔리젠시아 커피 INTELLIGENTSIA COFFEE >\n카페 르상스에서는 스페셜티 커피의 선구자이자 미국을 대표하는 3대 커피로 알려진 인텔리젠시아의 원두로 에스프레소를 내리고 있습니다.\n\n인텔리젠시아는 산지에서 수확한 커피를 각 계절에 가장 맛있는 제철 과일처럼 커피도 가장 맛있는 시기에 공급하는 인 시즌 커피 프로그램을 운영하고 있습니다. 선별한 최상급 생두로 로스팅과 블렌딩을 거치고 바리스타의 세심한 추출로 완벽한 에스프레소 한잔이 완성됩니다.\n\n미국 시카고에 위치한 인텔리젠시아 로스팅 웍스에서 로스팅 후 항공 운송으로 국내에 신선한 원두를 받아 커피가 가장 달콤하고 신선할 때 커피 본연의 맛과 향을 간직한 커피를 추출하고 있어요.\n\n훌륭한 밸런스로 입 안 가득 느껴지는 강렬한 향을 가진 인텔리젠시아 커피를 카페 르상스에서 만나보세요! 매장에 오시면 원두 구매도 가능합니다.\n.\n< 블랙캣 클래식 >\nBlack Cat Classic\n커피 체리의 은은한 산미와 브라운 슈가의 달콤한 향미, 훌륭한 밸런스와 풍미를 가진 커피\n\n< 오스쿠로 블렌드 >\nOscuro Blend\n풍부한 바디와 다크 초콜렛, 누가, 구운 헤이즐넛 뉘앙스를 가진 매력적인 커피\n\n< 디카프 블랙캣 에스프레소 >\nDecaf Black Cat Espresso\n원두가 가진 고유한 특징을 완벽하게 발현시킨 로스팅 기술로 코코아, 사과의 풍미를 가진 디카프 커피\n.\n\n다섯가지 감각의 만족을 경험하는 공간, 카페 르상스\n\n-한남동베이커리\n-한남동브런치\n-사운즈한남\n-한남동카페\n-한남동와인\n-테라스카페\n-TD\n펼쳐보기 \n convenience_facilities_and_services: 포장\n남/녀 화장실 구분\n예약\n배달\n무선 인터넷\n \n Parking: 주차가능\n무료 \n sns: https://catchtable.co.kr/cafelesens\nhttps://www.instagram.com/cafelesens\n \n review_like_this_part_output: "음식이 맛있어요"이 키워드를 선택한 인원161\n"인테리어가 멋져요"이 키워드를 선택한 인원145\n"친절해요"이 키워드를 선택한 인원94\n"특별한 메뉴가 있어요"이 키워드를 선택한 인원94\n"매장이 청결해요"이 키워드를 선택한 인원89\n"커피가 맛있어요"이 키워드를 선택한 인원76\n"디저트가 맛있어요"이 키워드를 선택한 인원69\n"뷰가 좋아요"이 키워드를 선택한 인원67\n"재료가 신선해요"이 키워드를 선택한 인원49\n"주차하기 편해요"이 키워드를 선택한 인원39\n"화장실이 깨끗해요"이 키워드를 선택한 인원33\n"대화하기 좋아요"이 키워드를 선택한 인원32\n"음료가 맛있어요"이 키워드를 선택한 인원27\n"매장이 넓어요"이 키워드를 선택한 인원26\n"야외공간이 멋져요"이 키워드를 선택한 인원25\n"양이 많아요"이 키워드를 선택한 인원19\n"특별한 날 가기 좋아요"이 키워드를 선택한 인원18\n"사진이 잘 나와요"이 키워드를 선택한 인원17\n"가성비가 좋아요"이 키워드를 선택한 인원17\n"아늑해요"이 키워드를 선택한 인원15\n"혼밥하기 좋아요"이 키워드를 선택한 인원10\n"단체모임 하기 좋아요"이 키워드를 선택한 인원10\n"차분한 분위기에요"이 키워드를 선택한 인원9\n"건강한 맛이에요"이 키워드를 선택한 인원6\n"비싼 만큼 가치있어요"이 키워드를 선택한 인원4\n"빵이 맛있어요"이 키워드를 선택한 인원3\n"음악이 좋아요"이 키워드를 선택한 인원3\n"컨셉이 독특해요"이 키워드를 선택한 인원2\n"메뉴 구성이 알차요"이 키워드를 선택한 인원2\n"반려동물과 가기 좋아요"이 키워드를 선택한 인원2\n"오래 머무르기 좋아요"이 키워드를 선택한 인원2\n"집중하기 좋아요"이 키워드를 선택한 인원2\n"차가 맛있어요"이 키워드를 선택한 인원1\n \n menu: 아메리카노대표인텔리젠시아 커피(스페셜티 커피 선구자/미국 3대커피) *3가지 원두: 클래식/다크/디카프5,500원\n[Winter Best] 슈톨렌 S대표럼과 와인 풍미가 스며든 건과일, 넛츠의 고소함, 은은한 시나몬 향을 담은 르상스 슈톨렌19,000원\n[Winter Best] 슈톨렌 L대표럼과 와인 풍미가 스며든 건과일, 넛츠의 고소함, 은은한 시나몬 향을\n담은 르상스 슈톨렌39,000원\n[Winter Best] 뱅쇼대표레드와인에 여러 과일, 시나몬을과 향신료를 넣어 따뜻하게 끓인 프랑스 음료9,500원\n르상스 크림 커피대표너티한 땅콩 크림과 인텔리젠시아 원두가 만나 고소하고 리치한 크림커피7,000원\n[오가와] 그린티 / 유자 그린티대표일본 차 장인 \'오가와 타카유키\'의 그린티 (전통 방식 그대로 덖어 감칠맛이 좋은 녹차)7,000원\n[오가와] 호지티대표일본 차 장인 \'오가와 타카유키\'의 호지티(녹차를 볶아 카페인 함량이 적고 구수한 차)7,000원\n[오가와] 말차 라떼대표*일본 장인의 말차+우유\n*옵션-오트밀/저지방 우유/에스프레소 샷 추가 +5007,500원\n[오가와] 호지 라떼대표*일본 장인의 호지차+우유\n*옵션-오트밀/저지방 우유/에스프레소 샷 추가 +5007,500원\n[WINE FOOD] 르상스 플래터대표6종 이상의 유럽 치즈를 중심으로 샤퀴테리 & 견과류 & 올리브29,000원\n[WINE FOOD]부라타무스 샐러드부라타 치즈 무스 & 마리네이트 토마토 &하몽25,000원\n[WINE FOOD] 올리브 & 하몽마리네이드된 다양한 종류의 올리브와 하몽18,000원\n리얼 초콜렛 (HOT / ICED)진한 벨기에 다크 초콜렛을 우유와 함께 그대로 녹여 꾸덕하고 진한 리얼 초콜렛8,000원\n오사쯔 라떼(고구마 라떼)달콤한 고구마와 우유를 베이스로 만든 담백한 오사쯔 라떼7,500원\n얼그레이 밀크티 ...
#  Document(id='d573c06e-7995-4b9d-9da7-73d17bbb3d1d', metadata={'store_id': '1265789091', 'store_name': '카페포이어'}, page_content='store_name: 카페포이어 \n category: 카페,디저트 \n new_open:   \n rating: 정보없음 \n visited_review: 방문자 리뷰 137 \n directions_text: 이태원 역 3번 출구에서 보광로 쪽으로 걸어서 2분 거리\n\n이태원역 3번출구로 나오셔서 뒤돌아서\n\n바로 보이는 왼쪽길로 100m 이동하시면\n\n1층에 예쁜 테라스가있는\n\n카페포이어가 있습니다:)\n\n[네이버 맵]\n\n카페포이어\n보광로 120-2 을 검색해주세요\n내용 더보기 \n store_id: 1265789091 \n address: 서울 용산구 보광로 120-2 1층 \n blog_review: 블로그 리뷰 149 \n phone_num: 0507-1410-2588 \n business_hours: 금\n12:30 - 22:00\n21:30 라스트오더\n토\n12:30 - 22:00\n21:30 라스트오더\n일\n11:30 - 21:00\n20:30 라스트오더\n월\n11:30 - 21:00\n20:30 라스트오더\n화\n정기휴무 (매주 화요일)\n수\n11:30 - 21:00\n20:30 라스트오더\n목\n11:30 - 21:00\n20:30 라스트오더\n \n info: cafe foyer - 카페포이어\n\n안녕하세요 카페포이어 입니다\n\n카페는 편안하게 쉬어 가는 공간이라는 마음으로 공간을 디자인했습니다\n\n테이블을 많이 두기보다는\n\n간격을 넓히고 편안한 소파로 편안한 공간을 준비하고 싶었습니다\n\n실내공간은 부티크 호텔의 로비를 연상시키는 인테리어로\n\n야외테라스 공간은 넓은 소파를 두어 편안한 공간으로 준비했습니다\n\n앞으로도 모든 고객들이 편안하게 쉬어 갈 수 있는 foyer가 되겠습니다\n\nfoyer를 이용하시면서 미리 확인하시면 좋을 몇가지 말씀 드리겠습니다\n\n- 넓은 소파인데 단체석인가요?\n[ 아닙니다! 누구나 편하게 이용하시면 됩니다 ]\n\n- 애견 동반 가능 카페 입니다\n[ 소파/ 카페트 / 실내 자리만 피해주시면 감사하겠습니다 ]\n\n매장 내 차량 주차는 불가하지만\n자전거 / 유모차 / 오토바이는 매장입구 한켠에 주차 가능합니다\n\n저희 이름처럼 로비처럼 편안하게\n\n만남의 장소로 기억되길 바라며\n\n오늘도 foyer를 찾아주셔서 감사합니다\n펼쳐보기 \n convenience_facilities_and_services: \\\n반려동물 동반\n포장\n남/녀 화장실 구분\n배달\n무선 인터넷\n단체 이용 가능\n \n Parking: 주차 불가 \n sns: https://www.instagram.com/cafefoyer.seoul\n \n review_like_this_part_output: "커피가 맛있어요"이 키워드를 선택한 인원82\n"인테리어가 멋져요"이 키워드를 선택한 인원66\n"대화하기 좋아요"이 키워드를 선택한 인원34\n"사진이 잘 나와요"이 키워드를 선택한 인원31\n"음료가 맛있어요"이 키워드를 선택한 인원27\n"디저트가 맛있어요"이 키워드를 선택한 인원26\n"친절해요"이 키워드를 선택한 인원25\n"매장이 청결해요"이 키워드를 선택한 인원20\n"특별한 메뉴가 있어요"이 키워드를 선택한 인원11\n"화장실이 깨끗해요"이 키워드를 선택한 인원11\n"야외공간이 멋져요"이 키워드를 선택한 인원9\n"매장이 넓어요"이 키워드를 선택한 인원8\n"뷰가 좋아요"이 키워드를 선택한 인원7\n"좌석이 편해요"이 키워드를 선택한 인원6\n"집중하기 좋아요"이 키워드를 선택한 인원6\n"아늑해요"이 키워드를 선택한 인원5\n"가성비가 좋아요"이 키워드를 선택한 인원5\n"차분한 분위기에요"이 키워드를 선택한 인원2\n"음악이 좋아요"이 키워드를 선택한 인원2\n"반려동물과 가기 좋아요"이 키워드를 선택한 인원2\n"컨셉이 독특해요"이 키워드를 선택한 인원1\n"메뉴 구성이 알차요"이 키워드를 선택한 인원1\n"종류가 다양해요"이 키워드를 선택한 인원1\n \n menu: Tea+ramisu대표8,000원\nCarrot cake 당큰케이크9,000원\nChiffon cake 쉬폰케이크8,500원\nShakerato 사케라또6,500원\nSignature 시그니쳐 라떼7,000원\nLatte 라떼산미없는 원두 사용으로 더욱 더 고소한 라떼6,000원\nAmericano 아메리카노중강배전 원두의 고소함과 진함, 초콜릿의 맛을 느끼실 수 있습니다.5,500원\nEspresso 에스프레소5,500원\n'),
#  Document(id='0c57c6b4-0ac7-4c71-89e6-ad0bdc1f0692', metadata={'store_id': '1265789091', 'store_name': '카페포이어'}, page_content='store_name: 카페포이어 \n category: 카페,디저트 \n new_open:   \n rating: 정보없음 \n visited_review: 방문자 리뷰 137 \n directions_text: 이태원 역 3번 출구에서 보광로 쪽으로 걸어서 2분 거리\n\n이태원역 3번출구로 나오셔서 뒤돌아서\n\n바로 보이는 왼쪽길로 100m 이동하시면\n\n1층에 예쁜 테라스가있는\n\n카페포이어가 있습니다:)\n\n[네이버 맵]\n\n카페포이어\n보광로 120-2 을 검색해주세요\n내용 더보기 \n store_id: 1265789091 \n address: 서울 용산구 보광로 120-2 1층 \n blog_review: 블로그 리뷰 149 \n phone_num: 0507-1410-2588 \n business_hours: 월\n11:30 - 21:00\n20:30 라스트오더\n화\n정기휴무 (매주 화요일)\n수\n11:30 - 21:00\n20:30 라스트오더\n목\n11:30 - 21:00\n20:30 라스트오더\n금\n12:30 - 22:00\n21:30 라스트오더\n토\n12:30 - 22:00\n21:30 라스트오더\n일\n11:30 - 21:00\n20:30 라스트오더\n \n info: cafe foyer - 카페포이어\n\n안녕하세요 카페포이어 입니다\n\n카페는 편안하게 쉬어 가는 공간이라는 마음으로 공간을 디자인했습니다\n\n테이블을 많이 두기보다는\n\n간격을 넓히고 편안한 소파로 편안한 공간을 준비하고 싶었습니다\n\n실내공간은 부티크 호텔의 로비를 연상시키는 인테리어로\n\n야외테라스 공간은 넓은 소파를 두어 편안한 공간으로 준비했습니다\n\n앞으로도 모든 고객들이 편안하게 쉬어 갈 수 있는 foyer가 되겠습니다\n\nfoyer를 이용하시면서 미리 확인하시면 좋을 몇가지 말씀 드리겠습니다\n\n- 넓은 소파인데 단체석인가요?\n[ 아닙니다! 누구나 편하게 이용하시면 됩니다 ]\n\n- 애견 동반 가능 카페 입니다\n[ 소파/ 카페트 / 실내 자리만 피해주시면 감사하겠습니다 ]\n\n매장 내 차량 주차는 불가하지만\n자전거 / 유모차 / 오토바이는 매장입구 한켠에 주차 가능합니다\n\n저희 이름처럼 로비처럼 편안하게\n\n만남의 장소로 기억되길 바라며\n\n오늘도 foyer를 찾아주셔서 감사합니다\n펼쳐보기 \n convenience_facilities_and_services: \\\n반려동물 동반\n포장\n남/녀 화장실 구분\n배달\n무선 인터넷\n단체 이용 가능\n \n Parking: 주차 불가 \n sns: https://www.instagram.com/cafefoyer.seoul\n \n review_like_this_part_output: "커피가 맛있어요"이 키워드를 선택한 인원82\n"인테리어가 멋져요"이 키워드를 선택한 인원66\n"대화하기 좋아요"이 키워드를 선택한 인원34\n"사진이 잘 나와요"이 키워드를 선택한 인원31\n"음료가 맛있어요"이 키워드를 선택한 인원27\n"디저트가 맛있어요"이 키워드를 선택한 인원26\n"친절해요"이 키워드를 선택한 인원25\n"매장이 청결해요"이 키워드를 선택한 인원20\n"특별한 메뉴가 있어요"이 키워드를 선택한 인원11\n"화장실이 깨끗해요"이 키워드를 선택한 인원11\n"야외공간이 멋져요"이 키워드를 선택한 인원9\n"매장이 넓어요"이 키워드를 선택한 인원8\n"뷰가 좋아요"이 키워드를 선택한 인원7\n"좌석이 편해요"이 키워드를 선택한 인원6\n"집중하기 좋아요"이 키워드를 선택한 인원6\n"아늑해요"이 키워드를 선택한 인원5\n"가성비가 좋아요"이 키워드를 선택한 인원5\n"차분한 분위기에요"이 키워드를 선택한 인원2\n"음악이 좋아요"이 키워드를 선택한 인원2\n"반려동물과 가기 좋아요"이 키워드를 선택한 인원2\n"컨셉이 독특해요"이 키워드를 선택한 인원1\n"메뉴 구성이 알차요"이 키워드를 선택한 인원1\n"종류가 다양해요"이 키워드를 선택한 인원1\n \n menu: Tea+ramisu대표8,000원\nCarrot cake 당큰케이크9,000원\nChiffon cake 쉬폰케이크8,500원\nShakerato 사케라또6,500원\nSignature 시그니쳐 라떼7,000원\nLatte 라떼산미없는 원두 사용으로 더욱 더 고소한 라떼6,000원\nAmericano 아메리카노중강배전 원두의 고소함과 진함, 초콜릿의 맛을 느끼실 수 있습니다.5,500원\nEspresso 에스프레소5,500원\n'),
#  Document(id='e4229bb0-74c2-401e-a76d-343f85d57bd4', metadata={'store_id': '13456451', 'store_name': '카페나리노'}, page_content='store_name: 카페나리노 \n category: 카페,디저트 \n new_open:   \n rating: 별점 4.37 \n visited_review: 방문자 리뷰 378 \n directions_text: 도보이용시\n\n숙대입구역 2번출구 도보 9분.\n용산고등학교 사거리 기준 서울역 방면 30m 파란색 건물 빨간색 간판.\n\n버스 605번, 400번, 202번\n하차역 : 용산중고등학교\n내용 더보기 \n store_id: 13456451 \n address: 서울 용산구 후암로 6 카페나리노 1 & 2 층 \n blog_review: 블로그 리뷰 136 \n phone_num: 0507-1375-0575 \n business_hours: 토\n10:00 - 19:00\n일\n10:00 - 19:00\n월\n07:00 - 21:00\n화\n07:00 - 21:00\n수(1/1)\n새해 첫날10:00 - 19:00\n목\n07:00 - 21:00\n금\n07:00 - 21:00\n \n info: Since 2008,\n카페 나리노의 이야기는 시작됩니다.\n\n남산아래 위치한 후암동에서 시작한 \'카페나리노\'는 커피 고유의 맛을 표현하고자 연구하며 노력하는 로스터리 카페입니다.\n\n후암동에서 일하는 모든 분들에게 에너지를 드립니다.\n이른 아침 허기진 배를 채워줄 든든한 샌드위치,\n정신없는 업무로 당이 떨어질때 달콤한 쿠키를,\n퇴근까지 힘든 하루를 충전해줄 나리노 커피까지.\n\n하루하루 열심히 일하는 분들에게 아낌없이 응원하고 지원하겠습니다!\n\n찾아주셔서 늘 감사드립니다.\n펼쳐보기 \n convenience_facilities_and_services: 핸드드립\n로스터리\n단체 이용 가능\n예약\n무선 인터넷\n포장\n방문접수/출장\n \n Parking: 주차 불가 \n sns: https://www.instagram.com/narino__day\nhttp://pf.kakao.com/_wjMtT\n \n review_like_this_part_output: "커피가 맛있어요"이 키워드를 선택한 인원186\n"친절해요"이 키워드를 선택한 인원162\n"디저트가 맛있어요"이 키워드를 선택한 인원105\n"음료가 맛있어요"이 키워드를 선택한 인원93\n"대화하기 좋아요"이 키워드를 선택한 인원75\n"매장이 청결해요"이 키워드를 선택한 인원74\n"인테리어가 멋져요"이 키워드를 선택한 인원71\n"좌석이 편해요"이 키워드를 선택한 인원49\n"특별한 메뉴가 있어요"이 키워드를 선택한 인원41\n"집중하기 좋아요"이 키워드를 선택한 인원32\n"가성비가 좋아요"이 키워드를 선택한 인원30\n"사진이 잘 나와요"이 키워드를 선택한 인원18\n"음식이 맛있어요"이 키워드를 선택한 인원15\n"화장실이 깨끗해요"이 키워드를 선택한 인원12\n"아늑해요"이 키워드를 선택한 인원5\n"매장이 넓어요"이 키워드를 선택한 인원5\n"차분한 분위기에요"이 키워드를 선택한 인원3\n"재료가 신선해요"이 키워드를 선택한 인원3\n"주차하기 편해요"이 키워드를 선택한 인원3\n"단체모임 하기 좋아요"이 키워드를 선택한 인원3\n"뷰가 좋아요"이 키워드를 선택한 인원3\n"혼밥하기 좋아요"이 키워드를 선택한 인원2\n"양이 많아요"이 키워드를 선택한 인원2\n"메뉴 구성이 알차요"이 키워드를 선택한 인원2\n"음악이 좋아요"이 키워드를 선택한 인원2\n"오래 머무르기 좋아요"이 키워드를 선택한 인원2\n"빵이 맛있어요"이 키워드를 선택한 인원1\n"포장이 깔끔해요"이 키워드를 선택한 인원1\n"차가 맛있어요"이 키워드를 선택한 인원1\n \n menu: 아메리카노대표산미 없는 고소한 향과 진한 바디감을 가지고 있는 커피4,000원\n'),
#  Document(id='19889b99-9e99-4dd2-9be7-6c0cd30e6a73', metadata={'store_id': '1658052386', 'store_name': '카쩨'}, page_content='store_name: 카쩨 \n category: 카페,디저트 \n new_open:   \n rating: 정보없음 \n visited_review: 방문자 리뷰 26 \n directions_text: 이대역 언덕길에 있는 작은 카페\n\n책을 읽고 작업하기 좋은 아늑한 공간이 있습니다.\n\n- 영업시간과 주차는 인스타그램 공지를 확인해주세요!\n내용 더보기 \n store_id: 1658052386 \n address: 서울 서대문구 이화여대2길 26 1층 102, 103호 \n blog_review: 블로그 리뷰 9 \n phone_num: 0507-1434-1619 \n business_hours: 매일\n10:00 - 20:00\n \n info: 이대역 언덕길에 있는 작은 카페\n\n책을 읽고 작업하기 좋은 아늑한 공간이 있습니다.\n\n- 영업시간은 인스타그램 공지를 확인해주세요! \n convenience_facilities_and_services: 핸드드립\n무선 인터넷\n\\\n반려동물 동반\n포장\n \n Parking: 주차 불가 \n sns: https://www.instagram.com/katze_seoul\n \n review_like_this_part_output: "커피가 맛있어요"이 키워드를 선택한 인원24\n"인테리어가 멋져요"이 키워드를 선택한 인원19\n"친절해요"이 키워드를 선택한 인원14\n"사진이 잘 나와요"이 키워드를 선택한 인원9\n"집중하기 좋아요"이 키워드를 선택한 인원9\n"디저트가 맛있어요"이 키워드를 선택한 인원7\n"매장이 청결해요"이 키워드를 선택한 인원7\n"뷰가 좋아요"이 키워드를 선택한 인원7\n"아늑해요"이 키워드를 선택한 인원6\n"음료가 맛있어요"이 키워드를 선택한 인원4\n"가성비가 좋아요"이 키워드를 선택한 인원3\n"대화하기 좋아요"이 키워드를 선택한 인원3\n"차분한 분위기에요"이 키워드를 선택한 인원2\n"좌석이 편해요"이 키워드를 선택한 인원1\n"음악이 좋아요"이 키워드를 선택한 인원1\n"룸이 잘 되어있어요"이 키워드를 선택한 인원1\n \n menu: 카페라테대표라이트 로스팅 원두와 우유가 만나 산뜻함과 고소함이 느껴지는 카페라떼4,500원\n티라미수대표7,000원\n독일식 치크케이크독일 드레스덴 출신 셰프가 정직하게 직접 만든 건강한 디저트!변동\n아메리카노카쩨 블렌드로 내린 향긋하고 고소한 아메리카노4,000원\n아인슈페너6,200원\n삥블랙삥타이거님이 호주에서 바리스타로 일하던 시절 즐겨 마시던 롱블랙4,000원\n삥푸치노 (Only hot)에스프레소 위에 초코 파우더를 뿌려 부드러운 우유거품을 올린 카푸치노5,000원\n삥블렌드 (Filter coffee)삥타이거 구독자들 대환영^,^변동\n'),
#  Document(id='1fe425a6-d84b-4e7e-9826-f16d219761da', metadata={'store_id': '13456451', 'store_name': '카페나리노'}, page_content='store_name: 카페나리노 \n category: 카페,디저트 \n new_open:   \n rating: 별점 4.37 \n visited_review: 방문자 리뷰 378 \n directions_text: 도보이용시\n\n숙대입구역 2번출구 도보 9분.\n용산고등학교 사거리 기준 서울역 방면 30m 파란색 건물 빨간색 간판.\n\n버스 605번, 400번, 202번\n하차역 : 용산중고등학교\n내용 더보기 \n store_id: 13456451 \n address: 서울 용산구 후암로 6 카페나리노 1 & 2 층 \n blog_review: 블로그 리뷰 136 \n phone_num: 0507-1375-0575 \n business_hours: 목\n07:00 - 21:00\n금\n07:00 - 21:00\n토\n10:00 - 19:00\n일\n10:00 - 19:00\n월\n07:00 - 21:00\n화\n07:00 - 21:00\n수(1/1)\n새해 첫날10:00 - 19:00\n \n info: Since 2008,\n카페 나리노의 이야기는 시작됩니다.\n\n남산아래 위치한 후암동에서 시작한 \'카페나리노\'는 커피 고유의 맛을 표현하고자 연구하며 노력하는 로스터리 카페입니다.\n\n후암동에서 일하는 모든 분들에게 에너지를 드립니다.\n이른 아침 허기진 배를 채워줄 든든한 샌드위치,\n정신없는 업무로 당이 떨어질때 달콤한 쿠키를,\n퇴근까지 힘든 하루를 충전해줄 나리노 커피까지.\n\n하루하루 열심히 일하는 분들에게 아낌없이 응원하고 지원하겠습니다!\n\n찾아주셔서 늘 감사드립니다.\n펼쳐보기 \n convenience_facilities_and_services: 핸드드립\n로스터리\n단체 이용 가능\n예약\n무선 인터넷\n포장\n방문접수/출장\n \n Parking: 주차 불가 \n sns: https://www.instagram.com/narino__day\nhttp://pf.kakao.com/_wjMtT\n \n review_like_this_part_output: "커피가 맛있어요"이 키워드를 선택한 인원186\n"친절해요"이 키워드를 선택한 인원162\n"디저트가 맛있어요"이 키워드를 선택한 인원105\n"음료가 맛있어요"이 키워드를 선택한 인원93\n"대화하기 좋아요"이 키워드를 선택한 인원75\n"매장이 청결해요"이 키워드를 선택한 인원74\n"인테리어가 멋져요"이 키워드를 선택한 인원71\n"좌석이 편해요"이 키워드를 선택한 인원49\n"특별한 메뉴가 있어요"이 키워드를 선택한 인원41\n"집중하기 좋아요"이 키워드를 선택한 인원32\n"가성비가 좋아요"이 키워드를 선택한 인원30\n"사진이 잘 나와요"이 키워드를 선택한 인원18\n"음식이 맛있어요"이 키워드를 선택한 인원15\n"화장실이 깨끗해요"이 키워드를 선택한 인원12\n"아늑해요"이 키워드를 선택한 인원5\n"매장이 넓어요"이 키워드를 선택한 인원5\n"차분한 분위기에요"이 키워드를 선택한 인원3\n"재료가 신선해요"이 키워드를 선택한 인원3\n"주차하기 편해요"이 키워드를 선택한 인원3\n"단체모임 하기 좋아요"이 키워드를 선택한 인원3\n"뷰가 좋아요"이 키워드를 선택한 인원3\n"혼밥하기 좋아요"이 키워드를 선택한 인원2\n"양이 많아요"이 키워드를 선택한 인원2\n"메뉴 구성이 알차요"이 키워드를 선택한 인원2\n"음악이 좋아요"이 키워드를 선택한 인원2\n"오래 머무르기 좋아요"이 키워드를 선택한 인원2\n"빵이 맛있어요"이 키워드를 선택한 인원1\n"포장이 깔끔해요"이 키워드를 선택한 인원1\n"차가 맛있어요"이 키워드를 선택한 인원1\n \n menu: 아메리카노대표산미 없는 고소한 향과 진한 바디감을 가지고 있는 커피4,000원\n'),
#  Document(id='e56017af-77d8-41dd-a179-38d805aeb847', metadata={'store_id': '1337029487', 'store_name': '더 체임버'}, page_content='store_name: 더 체임버 \n category: 카페 \n new_open:   \n rating: 별점 4.41 \n visited_review: 방문자 리뷰 428 \n directions_text: 용산역 또는 신용산역으로 한강대교 쪽으로 걸어서 5분 정도 떨어진 육교 바로 옆에서 더 체임버를 찾아주세요! \n store_id: 1337029487 \n address: 서울 용산구 한강대로 51 \n blog_review: 블로그 리뷰 288 \n phone_num: 0507-1414-0325 \n business_hours: 목\n11:00 - 21:00\n20:30 라스트오더\n금\n11:00 - 21:00\n20:30 라스트오더\n토\n11:30 - 22:00\n21:30 라스트오더\n일\n11:30 - 20:00\n19:30 라스트오더\n월\n11:00 - 21:00\n20:30 라스트오더\n화\n11:00 - 21:00\n20:30 라스트오더\n수\n11:00 - 21:00\n20:30 라스트오더\n \n info: 더 체임버는 스페셜티 커피 전문점입니다. IN-HOUSE 로스터리인 더 로스팅 체임버 (TRC) 원두를 프로페셔널 브루잉 머신인 브루비 (BREWVIE)로 추출하여 선보이는 원두 쇼룸 카페 입니다.\n\n또한 BREWVIE의 공식 개발 파트너사 및 총괄 판매사로서, 브루비 머신 소개와 컨설팅을 진행하고 있습니다. 네이버 예약을 통해 언제든지 상담을 신청하실 수 있습니다. \n convenience_facilities_and_services: 무선 인터넷\n포장\n \n Parking: 주차 정보없음 \n sns: http://www.theroastingchamber.co.kr/\nhttps://smartstore.naver.com/theroastingchamber\nhttps://www.instagram.com/thechambercoffee\n \n review_like_this_part_output: "커피가 맛있어요"이 키워드를 선택한 인원229\n"인테리어가 멋져요"이 키워드를 선택한 인원99\n"친절해요"이 키워드를 선택한 인원87\n"매장이 청결해요"이 키워드를 선택한 인원79\n"음료가 맛있어요"이 키워드를 선택한 인원78\n"대화하기 좋아요"이 키워드를 선택한 인원59\n"특별한 메뉴가 있어요"이 키워드를 선택한 인원55\n"디저트가 맛있어요"이 키워드를 선택한 인원38\n"화장실이 깨끗해요"이 키워드를 선택한 인원27\n"사진이 잘 나와요"이 키워드를 선택한 인원22\n"뷰가 좋아요"이 키워드를 선택한 인원12\n"집중하기 좋아요"이 키워드를 선택한 인원10\n"가성비가 좋아요"이 키워드를 선택한 인원9\n"아늑해요"이 키워드를 선택한 인원7\n"좌석이 편해요"이 키워드를 선택한 인원5\n"차분한 분위기에요"이 키워드를 선택한 인원4\n"매장이 넓어요"이 키워드를 선택한 인원4\n"메뉴 구성이 알차요"이 키워드를 선택한 인원2\n"비싼 만큼 가치있어요"이 키워드를 선택한 인원2\n"건강한 맛이에요"이 키워드를 선택한 인원2\n"재료가 신선해요"이 키워드를 선택한 인원1\n"오래 머무르기 좋아요"이 키워드를 선택한 인원1\n"종류가 다양해요"이 키워드를 선택한 인원1\n \n menu: 브루잉 커피대표브루비로 추출한 싱글 오리진 스페셜티 커피변동\n브루-비쥬대표에티오피아 트와콕으로 내린 브루잉 커피, 얼그레이 크림, 팝핑캔디, 콘플라위티, 얼그레이티6,000원\n라떼5,500원\n바닐라빈 라떼마다가스카르산 바닐라빈으로 만든 수제시럽을 이용한 바닐라빈 라떼6,000원\n핑크로빈 밀크티마리아쥬 프레르 홍차로 만든 프루티한 수제 밀크티6,000원\n제주 말차 라떼제주 유기농 말차가루로 만든 말차라떼5,500원\n패션후르츠 에이드 (시즈널)직접 만든 패션후르츠 청.7,000원\n허니 케이크옻꿀 100%. 향긋하고 달콤한 허니 케이크6,500원\n헤이즐넛 초코 타르트에콰도르 56% 초콜렛과 헤이즐넛 필링이 고소한 타르트6,500원\n블루베리 크럼블 버터바쫄깃한 버터바, 그 위에 블루베리가 들어간 크럼블5,000원\n초콜렛 피칸 쿠기다크초콜렛과 고소한 피칸의 조합이 좋은 쫀득한 미국식 쿠키4,000원\n마리아쥬 프레르 홍차MARIAGE FRERE TEA6,000원\n루즈 프로방스 루이보스티무카페인 MARIAGE FRERE TEA6,000원\n카모마일 티RISHI 허브티6,000원\n')]

# %%
# Step 1: FAISS 인덱스 파일 로드
faiss_index_path = "Faiss/opendata_gangnam_all"  # 저장된 Faiss 파일 경로
embeddings = OpenAIEmbeddings()  # 임베딩 객체 초기화

# 저장된 FAISS 인덱스를 불러와서 Retriever 생성
retriever_opendata_gangnam = FAISS.load_local(faiss_index_path, embeddings,allow_dangerous_deserialization=True).as_retriever()

# 검색 매개변수 설정 (예: 검색 결과 상위 10개 반환)
retriever_opendata_gangnam.search_kwargs = {"k": 10}

# %%
# Step 1: FAISS 인덱스 파일 로드
faiss_index_path = "Faiss/opendata_jongro_all"  # 저장된 Faiss 파일 경로
embeddings = OpenAIEmbeddings()  # 임베딩 객체 초기화

# 저장된 FAISS 인덱스를 불러와서 Retriever 생성
retriever_opendata_jongro = FAISS.load_local(faiss_index_path, embeddings,allow_dangerous_deserialization=True).as_retriever()

# 검색 매개변수 설정 (예: 검색 결과 상위 10개 반환)
retriever_opendata_jongro.search_kwargs = {"k": 10}

# %%
# Step 1: FAISS 인덱스 파일 로드
faiss_index_path = "Faiss/opendata_junggu_all"  # 저장된 Faiss 파일 경로
embeddings = OpenAIEmbeddings()  # 임베딩 객체 초기화

# 저장된 FAISS 인덱스를 불러와서 Retriever 생성
retriever_opendata_junggu = FAISS.load_local(faiss_index_path, embeddings,allow_dangerous_deserialization=True).as_retriever()

# 검색 매개변수 설정 (예: 검색 결과 상위 10개 반환)
retriever_opendata_junggu.search_kwargs = {"k": 10}

# %%
# Step 1: FAISS 인덱스 파일 로드
faiss_index_path = "Faiss/opendata_yongsan_all"  # 저장된 Faiss 파일 경로
embeddings = OpenAIEmbeddings()  # 임베딩 객체 초기화

# 저장된 FAISS 인덱스를 불러와서 Retriever 생성
retriever_opendata_yongsan = FAISS.load_local(faiss_index_path, embeddings,allow_dangerous_deserialization=True).as_retriever()

# 검색 매개변수 설정 (예: 검색 결과 상위 10개 반환)
retriever_opendata_yongsan.search_kwargs = {"k": 10}

# %%
from typing import Annotated, TypedDict, List
from langgraph.graph.message import add_messages


# GraphState 상태 정의
class GraphState(TypedDict):
    question: Annotated[List[str], add_messages]  # 질문(누적되는 list)
    context_naver_gangnam: Annotated[str, "context_naver_gangnam"]  # 문서의 검색 결과
    context_naver_jongro: Annotated[str, "context_naver_jongro"]  # 문서의 검색 결과
    context_naver_Junggu: Annotated[str, "context_naver_Junggu"]  # 문서의 검색 결과
    context_naver_yongsan: Annotated[str, "context_naver_yongsan"]  # 문서의 검색 결과
    context_opendata: Annotated[str, "context_opendata"]  # 문서의 검색 결과
    context_web: Annotated[str, "context_web"]  # 문서의 검색 결과
    answer_llm_Summary_gangnam: Annotated[str, "answer_llm_Summary_gangnam"]  # 답변
    answer_llm_Summary_junggu: Annotated[str, "answer_llm_Summary_junggu"]  # 답변
    answer_llm_Summary_jongro: Annotated[str, "answer_llm_Summary_jongro"]  # 답변
    answer_llm_Summary_yongsan: Annotated[str, "answer_llm_Summary_yongsan"]  # 답변
    answer_llm_Summary_opendata: Annotated[str, "answer_llm_Summary_opendata"]  # 답변
    answer: Annotated[str, "Answer"]  # 답변
    messages: Annotated[list, add_messages]  # 메시지(누적되는 list)
    webOrRetriever: Annotated[str, "webOrRetriever"]  # 웹 or 리트리버 검색
    ScheduleOrplace: Annotated[str, "ScheduleOrplace"]  # 일정 or 장소
    location: Annotated[str, "location"]  # 지역 리스트

# %%
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from operator import itemgetter
# 프롬프트
prompt = PromptTemplate(
    template="""Create a travel itinerary bot that generates schedules based on user questions. The schedule should be divided into morning, lunch, and evening plans for each travel day, and for each time of day, recommend a restaurant and tourist attractions or streets.

Extract key details from the user's questions to create a travel itinerary. Identify dates, times, and activities, then structure a plan with specific restaurant and sightseeing recommendations for morning, lunch, and evening.

#유의사항

- 첫날에는 아침일정을 추천하지마.
- 추천했던 장소를 한번더 추천하지마.
- 아침, 점심, 저녁 이동 경로가 가까워야돼

# Steps

1. **Request Analysis**: Carefully analyze the user's input to understand the itinerary requirements, including any specified food or sightseeing preferences.
2. **Confirm Details**: Verify dates, times, locations, activity preferences, and any specific requests for restaurants or attractions.
3. **Create Itinerary**: Using confirmed details, write a structured schedule detailing morning, lunch, and evening sections for each day, recommending one restaurant and tourist attraction or street for each time slot.

# Output Format

- Provide a detailed itinerary in a bullet-point list or table format, itemizing each day's morning, lunch, and evening plans.

# Examples

**Input**: "용산구에 1박2일 방문 할 예정이야. 일정을 생성 해줄 수 있어?"

**Schedule**:
- 1일차

  - 점심: 점심 식사 장소: [점심 식사 장소] [음식점 주소] [영업 시간] [음식점 특징] [기타 정보] ,
         명소: [관광할 명소 또는 거리] [영업 시간] [명소 특징] [명소 위치] [기타 정보]
         카페 : [카페 주소] [영업 시간] [카페 정보] [카페 특징] 
  - 저녁: 저녁 식사 장소: [저녁 식사 장소] [음식점 주소] [음식점 특징] [기타 정보], 명소: [관광할 명소 또는 거리] [명소 특징] [명소 위치] [기타 정보]
        쇼핑몰 : [쇼핑몰 주소] [쇼핑몰 특징]
        숙소 : [숙소 위치] [숙소 정보] [숙소 특징] *숙소 정보 없으면 출력 하지 않기
- 2일차
  - 아침: 아침 식사 장소: [음식점 이름] [음식점 주소] [음식점 특징] [기타 정보]
         명소: [관광할 명소 또는 거리] [명소 특징] [명소 위치] [기타 정보]
  - 점심: 점심 식사 장소: [점심 식사 장소] [음식점 주소] [영업 시간] [음식점 특징] [기타 정보],
         명소: [관광할 명소 또는 거리] [영업 시간] [명소 특징] [명소 위치] [기타 정보]
         카페 : [카페 주소] [영업 시간] [카페 정보] [카페 특징]
  - 저녁: 저녁 식사 장소: [저녁 식사 장소] [음식점 주소] [음식점 특징] [기타 정보], 명소: [관광할 명소 또는 거리] [명소 특징] [명소 위치] [기타 정보]
        쇼핑몰 : [쇼핑몰 주소] [쇼핑몰 특징]
        숙소 : [숙소 위치] [숙소 정보] [숙소 특징] *숙소 정보 없으면 출력 하지 않기

# Notes

- Ensure that all parts of the itinerary are complete and relevant to the user's request.
- Attempt to clarify any ambiguous details related to time, location, or activity preferences.
- Include clear recommendations for restaurants and tourist attractions for each part of the day.


#답변언어 : 한국어

    # 장소 정보: {context}

    #사용자의 질문: {question}
    
    #이전 대화 내용 {chat_history} 
    """,
        input_variables=["context", "question"],
    )

# LLM
model = ChatOpenAI(model_name="gpt-4o",
                    temperature=0, streaming=True)

chain = (
    {
        "question": itemgetter("question"),
        # "context_web": itemgetter("context_web"),
        "context": itemgetter("context"),
        "chat_history": itemgetter("chat_history"),
    }
    | prompt
    | model
    | StrOutputParser()
)

# %%
prompt_place_search = PromptTemplate(
    template="""너는 입력받은 장소 정보를 정리하여 사용자의 질문에 맞는 정보를 출력해 주는 봇이야.
    장소의 정보를 잘 요약해서 출력해줘.
    장소를 출력할때 각 장소의 어떤 점이 좋은지도 간단하게 요약해서 알려줘.




    # 장소 정보: {context}

    #사용자의 질문: {question}
    
    #이전 대화 내용 {chat_history} 
    """,
        input_variables=["context", "question"],
    )

# LLM
model_place_search = ChatOpenAI(model_name="gpt-4o",
                    temperature=0, streaming=True)

chain_place_search = (
    {
        "question": itemgetter("question"),
        # "context_web": itemgetter("context_web"),
        "context": itemgetter("context"),
        "chat_history": itemgetter("chat_history"),
    }
    | prompt_place_search
    | model_place_search
    | StrOutputParser()
)

# %%
prompt_opendata_Summary = PromptTemplate(
    template="""너는 입력받은 내용을 요약해주는 봇이야.
    입력 받는 내용은 특정 장소의 특징을 알려주는 내용이야.

    요약은 다음과 같이 해줬으면 좋겠어.

    아래 항목에서 없는 데이터는 빼도 돼.

    - "장소 이름":
    - "위치" :
    - "전화번호" :
    - "웹사이트 URL" :
    - "운영 날짜 및 시간":
    - "교통정보"
    - "기타 편의 여부" :
    - "지원언어" :

    # 요약 해야할 내용: {answer_llm_Summary}


    """,
        input_variables=["answer_llm_Summary"],
    )


# LLM
model_summary = ChatOpenAI(model_name="gpt-4o-mini",
                    temperature=0, streaming=True)

chain_Summary_opendata = (
    # {
    #     "answer_llm_Summary": itemgetter("answer_llm_Summary_opendata")
    # }
    prompt_opendata_Summary
    | model_summary
    | StrOutputParser()
)

# %%
prompt_naver_Summary = PromptTemplate(
    template="""너는 입력받은 내용을 요약해주는 봇이야.
    입력 받는 내용은 특정 장소의 특징을 알려주는 내용이야.

    요약은 다음과 같이 해줬으면 좋겠어

       - "store_name": 
       - "category":  
       - "rating":  
       - "directions_text": 
       - "store_id": 
       - "address": 
       - "phone_num": 
       - "business_hours": 
       - "info": 
       - "convenience_facilities_and_services": 
       - "Parking": 
       - "sns": 
       - "store의 좋은점": 
       - "menu": 



    # 요약 해야할 내용: {answer_llm_Summary}


    """,
        input_variables=["answer_llm_Summary"],
    )


# LLM
model_summary = ChatOpenAI(model_name="gpt-4o-mini",
                    temperature=0, streaming=True)

chain_Summary_gangnam = (
    # {
    #     "answer_llm_Summary": itemgetter("answer_llm_Summary_gangnam")
    # }
    prompt_naver_Summary
    | model_summary
    | StrOutputParser()
)
chain_Summary_Junggu = (
    # {
    #     "answer_llm_Summary": itemgetter("answer_llm_Summary_junggu")
    # }
     prompt_naver_Summary
    | model_summary
    | StrOutputParser()
)
chain_Summary_jongro = (
    # {
    #     "answer_llm_Summary": itemgetter("answer_llm_Summary_jongro")
    # }
     prompt_naver_Summary
    | model_summary
    | StrOutputParser()
)
chain_Summary_yongsan = (
    # {
    #     "answer_llm_Summary": itemgetter("answer_llm_Summary_yongsan")
    # }
     prompt_naver_Summary
    | model_summary
    | StrOutputParser()
)

# %%
prompt_keyword = PromptTemplate(
    template="""
        사용자의 질문에서 중요 키워드를 추출하는 작업을 수행하세요.

        # Steps

        1. **질문 분석**: 사용자가 입력한 질문을 주의 깊게 읽고 분석합니다.
        2. **중요 키워드 식별**: 질문의 핵심 내용을 파악하고, 문장에서 중요한 의미를 지닌 단어, 구문, 또는 개념을 식별합니다.
        3. **키워드 추출**: 식별한 중요한 요소들을 키워드로 추출합니다.

        # Output Format

        - 추출된 중요 키워드를 콤마(,)로 구분한 리스트로 제공합니다.

        # Examples

        **Input**: "자동차 산업의 현재 트렌드와 미래 전망은 무엇인가요?"

        **Keywords**: "자동차 산업, 현재 트렌드, 미래 전망"

        **Input**: "Python을 사용한 머신러닝 알고리즘 구현 방법은?"

        #사용자의 질문 : {question}
    """,
        input_variables=["question"],
    )

model_keyword = ChatOpenAI(model_name="gpt-4o-mini",
                    temperature=0, streaming=True)

chain_keyword = (
    {
        "question": itemgetter("question"),
    }
    | prompt_keyword
    | model_keyword
    | StrOutputParser()
)

# %%
prompt_location = PromptTemplate(
    template="""너는 질문에 대해서 list를 반환해야돼.
    list에 들어갈 수 있는 str은 '용산구', '강남구', '중구', '종로구' 네가지가 있어.
    사용자가 질문을 하면 문장을 잘 보고 문장속의 지역을 추출해서 리스트에 넣어줘.
    만약 사용자의 질문에 '서울'을 방문 한다고 하면 리스트에 '용산구', '강남구', '중구', '종로구' 를 모두 넣어줘.
    사용자의 질문에 서울시가 아닌 다른지역을 물어보거나, 서울시에서도 '용산구', '강남구', '중구', '종로구'가 아닌 다른 지역을 물어보면 빈 리스트를 반환해.


    #입력 예시 : 1. 나는 서울시의 용산구를 방문 할거야 여행 계획을 세워 줄수 있어?, 
               2. 나는 종로구와 중구 일대를 방문하고 싶어 을지로는 꼭 가보고 싶은데 을지로 계획을 포함해서 여행 일정을 만들어 줄 수 있어?

    #대답 형식 예시 : ['종로구','강남구']


    #####
    입력 예시 1 : 나는 전라남도 여행을 계획중이야. 일정을 만들어 줄 수 있어?  
    답변 예시 1 : []

    #####

    #####
    입력 예시 2 : 나는 용산구와 종로구, 중구 일대를 관광하고 싶어 좋은 카페를 알고 싶은데 알려줄 수 있어?  
    답변 예시 2 : ['용산구','중구','종로구']

    #####

    #####
    입력 예시 3: 나는 서울시를 관광하고 싶어 1박2일 정도 방문하려고 하는데 일정을 만들어 줄 수 있어?
    답변 예시 3: ['용산구','중구','종로구','강남구']
    
    #####

    #####
    입력 예시 4 : 종로구에서 맛있는 고기집을 찾고 있어. 찾아줘
    답변 예시 4: ['종로구']

    #####


    #사용자의 질문: {question}

    """,
        input_variables=["question"],
    )

model_location = ChatOpenAI(model_name="gpt-4o-mini",
                    temperature=0, streaming=True)

chain_location = (
    {
        "question": itemgetter("question"),
    }
    | prompt_location
    | model_location
    | StrOutputParser()
)

# %%
prompt_sch_or_placeSearch = PromptTemplate(
    template="""너는 질문에 대해서 두가지의 옵션으로 대답하는 봇이야.
    너의 대답은 '일정', '장소검색' 두가지로만 대답할 수 있어.
    사용자가 질문을 하면 문맥을 잘 살펴서 사용자가 여행일정을 만들어 달라고 하면 '일정' 이라고 대답해야돼.
    그렇지 않으면 '장소검색' 를 출력해줘.

    #'일정' 출력 예시 : 1. 나는 서울시의 용산구를 방문 할거야 여행 계획을 세워 줄수 있어?, 2. 나는 종로구와 중구 일대를 방문하고 싶어 을지로는 꼭 가보고 싶은데 을지로 계획을 포함해서 여행 일정을 만들어 줄 수 있어?

    #대답 형식 : '일정' or '장소검색'

    #사용자의 질문: {question}
    

    """,
        input_variables=["question"],
    )

model_sch_or_placeSearch = ChatOpenAI(model_name="gpt-4o-mini",
                    temperature=0, streaming=True)

chain_sch_or_placeSearch = (
    {
        "question": itemgetter("question"),
    }
    | prompt_sch_or_placeSearch
    | model_sch_or_placeSearch
    | StrOutputParser()
)

# %%
prompt_Web_or_retriever = PromptTemplate(
    template=""" 너는 사용자의 질문에 대해서 두가지의 옵션으로 대답하는 봇이야.
    너의 대답은 'web', 'retriever' 두가지로만 대답할 수 있어.
    사용자가 질문을 하면 문맥을 잘 살펴서 웹에서 정보를 검색하기를 원하면 'web' 이라고 대답해야돼.
    그렇지 않으면 'retriever' 를 출력해줘. 

    #대답 형식 : 'web' or 'retriever'

    #사용자의 질문: {question}
    

    """,
        input_variables=["question"],
    )
model_web_check = ChatOpenAI(model_name="gpt-4o-mini",
                    temperature=0, streaming=True)

chain_Web_or_retriever = (
    {
        "question": itemgetter("question"),
    }
    | prompt_Web_or_retriever
    | model_web_check
    | StrOutputParser()
)

# %%
prompt_web = PromptTemplate(
    template="""너는 웹 검색을 통한 {context_web}의 내용를 종합해서 서울시의 중구,종로구,용산구,강남구 관광 일정을 추천해주는 봇이야.
    사용자의 질문에 따라서 여러가지 서울의 관광지, 식당, 숙소, 쇼핑몰 등을 추천해야해.
    처음에 사용자가 서울에 며칠동안 머무르는지 물어보고, 그에 따라서 관광 일정을 추천해주면 돼.
    그 다음 사용자가 서울에 오는 이유에 대해 파악하고 그에 맞는 여행 일정을 추천해주면 돼.
    대화하다가 추천한 여행 일정이 사용자의 마음에 들지 않아서 변경해달라고 하면 마음에 들지 않은 부분을
    캐치하고 그 부분들만 수정해서 다시 추천해주면 돼.
    일정 중간 중간 숙소나 식당, 쇼핑몰 등을 추천해주면 돼.

    어떤 장소가 궁금해서 물어본다면 특정 장소의 정보들을 정확하게 알려줘.
    (예:가게 정보, 메뉴, 별점, 위치, 연락처, 운영 시간, 리뷰 등)
    여행 일정에 대한 동선이 짧도록 추천해줘.
    언어는 사용자가 입력한 언어를 기준으로 알려줘. 
    화폐 기준도 사용자가 입력한 언어를 사용하는 국가의 화폐를 기준으로 적용해줘.


    - 너가 제공한 내용의 출처를 링크로 남겨줘

    # 웹 검색 정보 : {context_web}

    #사용자의 질문: {question}
    
    #이전 대화 내용 {chat_history} 
    """,
        input_variables=["context_web", "question"],
    )
#input_variables=["context_web","context_opendata","context_naver", "question"],
# LLM
model_web = ChatOpenAI(model_name="gpt-4o",
                    temperature=0, streaming=True)

chain_web = (
    {
        "question": itemgetter("question"),
        "context_web": itemgetter("context_web"),
        # "context_opendata": itemgetter("context_opendata"),
        # "context_naver": itemgetter("context_naver"),
        "chat_history": itemgetter("chat_history"),
    }
    | prompt_web
    | model_web
    | StrOutputParser()
)

# %%
from langchain_teddynote.messages import messages_to_history
from langchain_teddynote.tools.tavily import TavilySearch
import ast

# from rag.utils import format_docs
# 웹 검색 or 리트리버 검색
def web_or_retriever_check(state: GraphState) -> GraphState:
    
    response = chain_Web_or_retriever.invoke(
        {"question": state["question"][-1].content}
    )

    return {"webOrRetriever": response}

# 웹 리트리버 분기 체크하는 함수(router)
def is_web(state: GraphState) -> GraphState:
    if state["webOrRetriever"] == "web":
        return "web"
    else:
        return "retriever"

# 장소검색 or 일정 검색
def Schedule_or_place_check(state: GraphState) -> GraphState:
    # 관련성 체크를 실행("yes" or "no")
    response = chain_sch_or_placeSearch.invoke(
        {"question": state["question"][-1].content}
    )

    return {"ScheduleOrplace": response}


# 일정 장소검색 리트리버 분기 체크하는 함수(router)
def is_place(state: GraphState) -> GraphState:
    if state["ScheduleOrplace"] == "일정":
        return "일정"
    else:
        return "장소검색"
    
# 지역 판별
def location_check(state: GraphState) -> GraphState:
    # 관련성 체크를 실행("yes" or "no")
    response = chain_location.invoke(
        {"question": state["question"][-1].content}
    )

    return {"location": response}

    
# 문서 검색 노드--------------------------------------------------------------------------------------------------------------------------
def retrieve_document_naver(state: GraphState) -> GraphState:
    # 질문을 상태에서 가져옵니다.
    latest_question = state["question"][-1].content
    location_str = state['location']

    location = ast.literal_eval(location_str)

    # 문서에서 검색하여 관련성 있는 문서를 찾습니다.
    yongsan = '용산구'
    jonglo = '종로구'
    gangman = '강남구'
    junggu = '중구'
    retrieved_docs_yongsan = []
    retrieved_docs_jongro = []
    retrieved_docs_gangman = []
    retrieved_docs_junggu = []

    if yongsan in location:
        retrieved_docs_yongsan = retriever_naver_yongsan.invoke(latest_question)
        retrieved_docs_yongsan = "\n".join(
        [
            f"<document><content>{doc.page_content}</content>"
            for doc in retrieved_docs_yongsan
        ]
        )

    if jonglo in location:
        retrieved_docs_jongro = retriever_naver_jongro.invoke(latest_question)
        retrieved_docs_jongro = "\n".join(
        [
            f"<document><content>{doc.page_content}</content>"
            for doc in retrieved_docs_jongro
        ]
        )

    if gangman in location:
        retrieved_docs_gangman = retriever_naver_gangnam.invoke(latest_question)
        retrieved_docs_gangman = "\n".join(
        [
            f"<document><content>{doc.page_content}</content>"
            for doc in retrieved_docs_gangman
        ]
        )

    if junggu in location:
        retrieved_docs_junggu = retriever_naver_Junggu.invoke(latest_question)
        retrieved_docs_junggu = "\n".join(
        [
            f"<document><content>{doc.page_content}</content>"
            for doc in retrieved_docs_junggu
        ]
        )

    # 검색된 문서를 형식화합니다.(프롬프트 입력으로 넣어주기 위함)

        # 검색된 문서를 context 키에 저장합니다.
    return {"context_naver_gangnam": retrieved_docs_gangman,
            "context_naver_jongro": retrieved_docs_jongro,
            "context_naver_Junggu": retrieved_docs_junggu,
            "context_naver_yongsan": retrieved_docs_yongsan}

#------------------------------------------------------------------------------------------------------------------------------------------------


def retrieve_document_opendata(state: GraphState) -> GraphState:
    # 질문을 상태에서 가져옵니다.
    latest_question = state["question"][-1].content
    location_str = state['location']

    location = ast.literal_eval(location_str)

    doc_list = []
    # 문서에서 검색하여 관련성 있는 문서를 찾습니다.
    yongsan = '용산구'
    jonglo = '종로구'
    gangman = '강남구'
    junggu = '중구'
    retrieved_docs_yongsan = []
    retrieved_docs_jongro = []
    retrieved_docs_gangman = []
    retrieved_docs_junggu = []

    if yongsan in location:
        retrieved_docs_yongsan = retriever_opendata_yongsan.invoke(latest_question)

    if jonglo in location:
        retrieved_docs_jongro = retriever_opendata_jongro.invoke(latest_question)

    if gangman in location:
        retrieved_docs_gangman = retriever_opendata_gangnam.invoke(latest_question)

    if junggu in location:
        retrieved_docs_junggu = retriever_opendata_junggu.invoke(latest_question)

 
    doc_list.extend(retrieved_docs_yongsan)
    doc_list.extend(retrieved_docs_jongro)
    doc_list.extend(retrieved_docs_gangman)
    doc_list.extend(retrieved_docs_junggu)

    # 검색된 문서를 형식화합니다.(프롬프트 입력으로 넣어주기 위함)
    retrieved_docs = "\n".join(
        [
            f"<document><content>{doc.page_content}</content>"
            for doc in doc_list
        ]
)

    # 검색된 문서를 context 키에 저장합니다.
    return {"context_opendata": retrieved_docs}

# 요약 생성 노드----------------------------------------------------------------------------
def llm_Summary_naver(state: GraphState) -> GraphState:
    location_str = state['location']

    location = ast.literal_eval(location_str)

    yongsan = '용산구'
    jonglo = '종로구'
    gangman = '강남구'
    junggu = '중구'
    response_yongsan ='none'
    response_jongro ='none'
    response_junggu ='none'
    response_gangnam ='none'

    if yongsan in location:
        context_naver_yongsan = state["context_naver_yongsan"]

        # 체인을 호출하여 답변을 생성합니다.
        response_yongsan = chain_Summary_yongsan.invoke(
            {
                "answer_llm_Summary": context_naver_yongsan,
            }
        )
    # 생
    if jonglo in location:
        context_naver_jongro = state["context_naver_jongro"]

        # 체인을 호출하여 답변을 생성합니다.
        response_jongro = chain_Summary_jongro.invoke(
            {
                "answer_llm_Summary": context_naver_jongro,
            }
        )
    if gangman in location:
        context_naver_gangnam = state["context_naver_gangnam"]

        # 체인을 호출하여 답변을 생성합니다.
        response_gangnam = chain_Summary_gangnam.invoke(
            {
                "answer_llm_Summary": context_naver_gangnam,
            }
        )
    if junggu in location:
        context_naver_Junggu = state["context_naver_Junggu"]

        # 체인을 호출하여 답변을 생성합니다.
        response_junggu = chain_Summary_Junggu.invoke(
            {
                "answer_llm_Summary": context_naver_Junggu,
            }
        )
    
    # 생성된 답변, (유저의 질문, 답변) 메시지를 상태에 저장합니다.
    return {
        "answer_llm_Summary_gangnam": response_gangnam,
        "answer_llm_Summary_jongro": response_jongro,
        "answer_llm_Summary_junggu": response_junggu,
        "answer_llm_Summary_yongsan": response_yongsan
    } 


def llm_Summary_opendata(state: GraphState) -> GraphState:

    # 검색된 문서를 상태에서 가져옵니다.
    context_opendata = state["context_opendata"]

    # 체인을 호출하여 답변을 생성합니다.
    response = chain_Summary_opendata.invoke(
        {
            "answer_llm_Summary": context_opendata,
        }
    )
    # 생성된 답변, (유저의 질문, 답변) 메시지를 상태에 저장합니다.
    return {
        "answer_llm_Summary_opendata": response
    } 


# 요약 생성 노드 끝----------------------------------------------------------------------------



# 일정 생성 노드----------------------------------------------------------------------------

def llm_Schedule_answer(state: GraphState) -> GraphState:
    # 질문을 상태에서 가져옵니다.
    latest_question = state["question"][-1].content
    location_str = state['location']

    location = ast.literal_eval(location_str)

    Summary_list = []
    Summary_yongsan =[]
    Summary_jongro =[]
    Summary_gangman =[]
    Summary_junggu =[]
    # 문서에서 검색하여 관련성 있는 문서를 찾습니다.
    yongsan = '용산구'
    jonglo = '종로구'
    gangman = '강남구'
    junggu = '중구'

    if yongsan in location:
        Summary_yongsan = state["answer_llm_Summary_yongsan"]

    if jonglo in location:
        Summary_jongro = state["answer_llm_Summary_jongro"]

    if gangman in location:
        Summary_gangman = state["answer_llm_Summary_gangnam"]

    if junggu in location:
        Summary_junggu = state["answer_llm_Summary_junggu"]

   
    Summary_opendata = state["answer_llm_Summary_opendata"]

 
    Summary_list.extend(Summary_yongsan)
    Summary_list.extend(Summary_jongro)
    Summary_list.extend(Summary_gangman)
    Summary_list.extend(Summary_junggu)
    Summary_list.extend(Summary_opendata)

    # 검색된 문서를 형식화합니다.(프롬프트 입력으로 넣어주기 위함)
    retrieved_docs = "\n".join(
        [
            f"{doc}"
            for doc in Summary_list
        ]
    )

    # 체인을 호출하여 답변을 생성합니다.
    response = chain.invoke(
        {
            "question": latest_question,
            "context": retrieved_docs,
            "chat_history": messages_to_history(state["messages"]),
        }
    )
    # 생성된 답변, (유저의 질문, 답변) 메시지를 상태에 저장합니다.
    print(state["messages"])
    return {
        "answer": response,
        "messages": [("user", latest_question), ("assistant", response)],
    }
# 일정 생성 노드 끝----------------------------------------------------------------------------

# 장소 검색 노드 ----------------------------------------------------------------------------

def llm_place_answer(state: GraphState) -> GraphState:
    # 질문을 상태에서 가져옵니다.
    latest_question = state["question"][-1].content
    location_str = state['location']

    location = ast.literal_eval(location_str)

    Summary_list = []
    Summary_yongsan =[]
    Summary_jongro =[]
    Summary_gangman =[]
    Summary_junggu =[]
    # 문서에서 검색하여 관련성 있는 문서를 찾습니다.
    yongsan = '용산구'
    jonglo = '종로구'
    gangman = '강남구'
    junggu = '중구'

    if yongsan in location:
        Summary_yongsan = state["answer_llm_Summary_yongsan"]

    if jonglo in location:
        Summary_jongro = state["answer_llm_Summary_jongro"]

    if gangman in location:
        Summary_gangman = state["answer_llm_Summary_gangnam"]

    if junggu in location:
        Summary_junggu = state["answer_llm_Summary_junggu"]

   
    Summary_opendata = state["answer_llm_Summary_opendata"]

 
    Summary_list.extend(Summary_yongsan)
    Summary_list.extend(Summary_jongro)
    Summary_list.extend(Summary_gangman)
    Summary_list.extend(Summary_junggu)
    Summary_list.extend(Summary_opendata)

    # 검색된 문서를 형식화합니다.(프롬프트 입력으로 넣어주기 위함)
    retrieved_docs = "\n".join(
        [
            f"{doc}"
            for doc in Summary_list
        ]
    )

    # 체인을 호출하여 답변을 생성합니다.
    response = chain_place_search.invoke(
        {
            "question": latest_question,
            "context": retrieved_docs,
            "chat_history": messages_to_history(state["messages"]),
        }
    )
    # 생성된 답변, (유저의 질문, 답변) 메시지를 상태에 저장합니다.
    print(state["messages"])
    return {
        "answer": response,
        "messages": [("user", latest_question), ("assistant", response)],
    }

# 장소 검색 노드  끝----------------------------------------------------------------------------


# 웹 검색 답변 생성 노드
def llm_answer_web(state: GraphState) -> GraphState:
    # 질문을 상태에서 가져옵니다.
    latest_question = state["question"][-1].content
    # 검색된 문서를 상태에서 가져옵니다.
    # context_naver = state["context_naver"]
    # context_opendata = state["context_opendata"]
    context_web = state["context_web"]

    # 체인을 호출하여 답변을 생성합니다.
    response = chain_web.invoke(
        {
            "question": latest_question,
            "context_web": context_web,
            # "context_naver": context_naver,
            # "context_opendata": context_opendata,
            "chat_history": messages_to_history(state["messages"]),
        }
    )
    # 생성된 답변, (유저의 질문, 답변) 메시지를 상태에 저장합니다.
    print(state["messages"])
    return {
        "answer": response,
        "messages": [("user", latest_question), ("assistant", response)],
    }

# Web Search 노드
def web_search(state: GraphState) -> GraphState:
    # 검색 도구 생성
    tavily_tool = TavilySearch()

    search_query = state["question"][-1].content

    # 다양한 파라미터를 사용한 검색 예제
    search_result = tavily_tool.search(
        query=search_query,  # 검색 쿼리
        topic="general",  # 일반 주제
        max_results=2,  # 최대 검색 결과
        format_output=True,  # 결과 포맷팅
    )

    return {"context_web": search_result}

# %%
from langgraph.graph import END, StateGraph
from langgraph.checkpoint.memory import MemorySaver

# 그래프 생성
workflow = StateGraph(GraphState)

# 노드 정의
workflow.add_node("location_check", location_check)
workflow.add_node("retrieve_document_naver", retrieve_document_naver)
workflow.add_node("retrieve_opendata", retrieve_document_opendata)
workflow.add_node("llm_Summary_opendata", llm_Summary_opendata)
workflow.add_node("llm_Summary_naver", llm_Summary_naver)
workflow.add_node("llm_Schedule_answer", llm_Schedule_answer)
workflow.add_node("Schedule_or_place_check", Schedule_or_place_check)
workflow.add_node("llm_place_answer", llm_place_answer)


# 엣지 정의
# workflow.add_conditional_edges(
#     "web_Or_Retriever",  # 관련성 체크 노드에서 나온 결과를 is_relevant 함수에 전달합니다.
#     is_web,
#     {
#         "web": "web_search",  # 웹 검색을 요청하면 웹검색을 합니다
#         "retriever": "query_rewrite",  # 아니면 리트리버
#     },
# )
# 엣지 정의
workflow.add_conditional_edges(
    "Schedule_or_place_check",  
    is_place,
    {
        "일정": "llm_Schedule_answer",  #일정
        "장소검색": "llm_place_answer",  # 장소검색
    },
)

workflow.add_edge("location_check", "retrieve_document_naver")  # 검색 -> 답변
workflow.add_edge("location_check", "retrieve_opendata")  # 검색 -> 답변
workflow.add_edge("retrieve_document_naver", "llm_Summary_naver")  # 질문 -> 검색
workflow.add_edge("retrieve_opendata", "llm_Summary_opendata")  # 질문 -> 검색
workflow.add_edge("llm_Summary_naver", "Schedule_or_place_check") 
workflow.add_edge("llm_Summary_opendata", "Schedule_or_place_check") 

workflow.add_edge("llm_Schedule_answer", END)  # 답변 -> 종료
workflow.add_edge("llm_place_answer", END)  # 답변 -> 종료

# 그래프 진입점 설정
workflow.set_entry_point("location_check")

# 체크포인터 설정
memory = MemorySaver()

# 컴파일
app = workflow.compile(checkpointer=memory)

# %%
from langchain_teddynote.graphs import visualize_graph

visualize_graph(app)

# %%
# from langchain_core.runnables import RunnableConfig
# from langchain_teddynote.messages import invoke_graph, stream_graph, random_uuid

# # config 설정(재귀 최대 횟수, thread_id)
# config = RunnableConfig(recursion_limit=20, configurable={"thread_id": random_uuid()})

# %%
# inputs = GraphState(question="내가 직전에 한 질문이 뭐였지")

# %%
# print(res.get('answer'))

# %%
from langchain_core.runnables import RunnableConfig
from langchain_teddynote.messages import invoke_graph, stream_graph, random_uuid

# config 설정(재귀 최대 횟수, thread_id)
config = RunnableConfig(recursion_limit=20, configurable={"thread_id": random_uuid()})

# 질문 입력
inputs = GraphState(question="강남구 1박2일 일정 만들어줘")

# 그래프 실행
invoke_graph(app, inputs, config)
# Out:
# ==================================================
# 🔄 Node: location_check 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# location:
# ['강남구']
# ==================================================
#
# ==================================================
# 🔄 Node: retrieve_opendata 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# context_opendata:
# <document><content>관광안내소명: 강남관광정보센터
#  안내소위치명: 3호선 압구정역 6번 출구 도보 2분
#  안내소소개: 서울 및 강남 주요 관광명소ㆍ교통ㆍ음식ㆍ숙박ㆍ행사 관련 최신 정보를 영중일 다국어로 안내
#  부가서비스정보: 커뮤니케이션 공간+공유오피스+사무공간+체험존+휴게시설+로봇카페
#  휴무일: 토+일+공휴일
#  운영시작시각(하절기): 10:00
#  운영종료시각(하절기): 18:00
#  운영시작시각(동절기): 10:00
#  운영종료시각(동절기): 18:00
#  안내가능외국어: 영어, 일본어, 중국어, 러시아어
#  안내소전화번호: 02-1661-2230
#  소재지도로명주소: 서울특별시 강남구 압구정로 161, 1층
#  소재지지번주소: 서울특별시 강남구 압구정동 428, 1층
#  홈페이지주소: https://www.gangnam.go.kr/contents/tourgangnam/2/view.do?mid=FM010406
#  위도: 37.5268431
#  경도: 127.0270587</content>
# <document><content>상호명: 만나분식
#  콘텐츠URL: https://korean.visitseoul.net/attractions/202303/KOPu5th9n?utm_source=seoulopendata&utm_medium=attractions&utm_content=KOPu5th9n
#  주소:
#  신주소: 06284 서울 강남구 삼성로 212 (대치동, 은마아파트)
#  전화번호: 02-557-7040
#  팩스번호: None
#  웹사이트: None
#  운영시간: 매일 10:00 ~ 20:00
#  운영요일: None
#  휴무일: 매달 1, 3번째 일요일 정기 휴무 & 2, 4번째 월요일 휴무
#  교통정보: 3호선 대치역 3번 출구에서 10m
#  태그:  떡볶이, 은마상가,분식, 대치동,오래가게, 강남, 떡꼬치
#  장애인편의시설: None</content>
# <document><content>상호명: 카페먼데이투선데이
#  콘텐츠URL: https://korean.visitseoul.net/restaurants/카페먼데이투선데이1/KOP005525?utm_source=seoulopendata&utm_medium=restaurants&utm_content=KOP005525
#  주소: 135-517 서울특별시 강남구 청담동 93-13
#  신주소: 06016 서울특별시 강남구 도산대로67길 13-3 (청담동)
#  전화번호: 0507-1353-2217
#  웹사이트: None
#  운영시간: 월요일~목요일/일요일 10:30 ~ 23:00 금요일?토요일 10:30 ~ 24:00
#  교통정보: 수인분당선 압구정로데오역 5번 출구에서 약 571m (도보 8분)
#  홈페이지 언어: None
#  대표메뉴: 카페</content>
# <document><content>상호: 강남브이에스라인의원
#  대표자: 김보람
#  기관구분: 의원
#  주소: 서울특별시 강남구 역삼동 822-2 메다타워3층
#  타겟국가: 미국/일본/베트남/기타</content>
# <document><content>상호명: 난장캠프 [임시휴업]
#  콘텐츠URL: https://korean.visitseoul.net/restaurants/난장캠프/KOP026062?utm_source=seoulopendata&utm_medium=restaurants&utm_content=KOP026062
#  주소: 135-888 서울 강남구 신사동 519-26
#  신주소: 06034 서울 강남구 강남대로158길 27 (신사동)
#  전화번호: 02-3443-6466
#  웹사이트: https://nanjangcampgarosu.modoo.at/
#  운영시간: 평일 16:00~23:20 토 16:00~23:00 일 16:00~22:00
#  교통정보: 3호선 신사역 8번 출구 도보 10분
#  홈페이지 언어: None
#  대표메뉴: 참숯초벌 오겹살, 참숯초벌 목살</content>
# <document><content>상호: 헤이데이 의원
#  대표자: 이근택
#  기관구분: 의원
#  주소: 서울특별시 강남구 강남대로 374 (역삼동) 케이스퀘어 강남2 빌딩 지하1층
#  타겟국가: 미국/일본/중국</content>
# <document><content>상호: 강남에이스안과의원
#  대표자: 신경훈
#  기관구분: 의원
#  주소: 서울특별시 강남구 테헤란로 151 (역삼동, 역삼하이츠빌딩) 2층 강남에이스안과의원
#  타겟국가: 미국/일본/중국/중동/몽골</content>
# <document><content>상호: 강남케이뷰티성형외과의원
#  대표자: 유중석
#  기관구분: 의원
#  주소: 서울특별시 강남구 논현로171길 11 (신사동) 강남케이뷰티성형외과
#  타겟국가: 미국/중국/베트남</content>
# <document><content>상호명: 만나당
#  콘텐츠URL: https://korean.visitseoul.net/attractions/2023001/KOPv423hd?utm_source=seoulopendata&utm_medium=attractions&utm_content=KOPv423hd
#  주소: 06029 서울 강남구 신사동 550-9 1층 101호 만나당
#  신주소: 06029 서울 강남구 논현로175길 61 (신사동) 1층 101호 만나당
#  전화번호: 0507-1327-3312
#  팩스번호: None
#  웹사이트: https://mannadang.modoo.at/
#  운영시간: 월요일-토요일 10:00-18:00
#  운영요일: None
#  휴무일: 일요일
#  교통정보: 3호선 압구정역 5번 출구에서 약 498m (도보 7분)
#  태그: 수제, 궁중약과, 강남,오래가게, 약과, 압구정, 가로수길
#  장애인편의시설: None</content>
# <document><content>상호: 강남동일 한의원
#  대표자: 곽노규
#  기관구분: 한의원
#  주소: 서울특별시 강남구 봉은사로 471 (삼성동) 힐스테이트2단지상가 401,402호
#  타겟국가: 일본</content>
# ==================================================
#
# ==================================================
# 🔄 Node: retrieve_document_naver 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# context_naver_gangnam:
# <document><content>store_name: 수지상회 강남1호점
#  category: 요리주점
#  new_open:
#  rating: 정보없음
#  visited_review: 방문자 리뷰 1,750
#  directions_text: 수지상회는 2층에 있습니다.
# 건물1층은 보승회관 입니다. 보승회관을 정면으로 바라보시고 우측 통로를 통해 건물 내부로 들어오셔서 계단 혹은 엘레베이터 이용하셔서 2층으로 올라오시면 하트 조명이 보이십니다. 문을 열고 들어오시면 건물 내부지만 충분한 개방감을 느끼실 수 있는 수지상회가 보이십니다.
#
# 2호선 강남역에서 내리셔서 12번 출구로 나오신 다음
# 왼쪽으로 돌아 내려오셔서 오른쪽 첫 골목으로 들오셔서
# 100m가량 들어오시면(세븐일레븐,빌리엔젤을 지나)
# 왼편 2층에 위치하고 있습니다.
#
# 강남역과 1분거리에 있는 오기도 편하고 집가기도 편한 강남억술집 수지상회에서 여러분을 기다리겠습니다
#
# 주차는 죄송스럽지만 따로 공간이 마련되어 있지 않습니다.
# 근처 유료 주차장 이용해주시면 감사하겠습니다!!
# 내용 더보기
#  store_id: 1810165759
#  address: 서울 강남구 테헤란로1길 17 2층
#  blog_review: 블로그 리뷰 2,361
#  phone_num: 0507-1366-6974
#  business_hours: 매일
# 16:00 - 05:00
#
#  info: 안녕하세요.
#
# @@@@인스타 맛집@@@@
# @@@SNS핫플@@@
# @@@분위기 맛집@@@
# @@@안주 맛집@@@
# @@@데이트 베스트 코스@@@
# @@@하이볼 맛집@@@
# @@@강남역술집@@@
# @@@강남술집@@@
#
# 매장 방문시 신분증 필수 지참인 부분 양해부탁드립니다.
#
# 수 많은 인플루언서들의 선택을 받은 강남1등 술집 수지상회 강남 1호점 인사드리겠습니다!!!
#
# 날이 더워지고, 추워지고, 비가오고, 눈이오고 어떤 상황에서도
#
# 굴하지 않고 문을 여는 강남역 술집!
#
# 지하철역에서 3분거리에 위치해서 막차 놓칠리 없고!
#
# 강남에서 제일 화장실 깨끗하고!!
#
# 모두가 만족하는 서비스를 제공해드리는 이 곳!
#
# 수지상회 강남점입니다.
#
# 봄엔 꽃향기를 맡으며!!
#
# 여름엔 시원하게!!
#
# 가을엔 선선한 바람을 맞으며!!
#
# 겨울엔 따뜻하게!!
#
# 연인과 데이트를 하기에도 좋고, 가족끼리 오랜만에 외식하기에도 좋고, 손님을 모시고 가도 좋고, 친구랑 놀러가기도 좋은 매장입니다.
#
# 항상 뻔한 음식과 뻔한 맛 뻔한 일상에 지치신 분들을 위해서 저희가 그동안 없었던 특별한 맛, 특별한 음식, 일상에서의 색다로움을 즐기실 수 있도록 준비했습니다.
#
# 항상 고객 여러분들을 생각하고 한분 한분 최선을 다해서 니즈를 맞춰드리는 저희가 강남에 왔습니다!!
#
# 취향저격 다양한 종류의 메뉴들!!
#
# 갈빗대 통째 드리는 **수지 우대 갈비**
# - 소의 가장 큰 갈빗대로 요즘 유행하는 그 소고기 맞습니다.
# 수비드로 조리된 족발 가득 담긴 ***학센 플레터***
# - 독일식 족발인 겉바속촉 족발을 한국에서 즐기실수있습니다.
# 매일 공수해온 채소로 준비한 **수지 샤브 전골**
# - 신선한 야채와 신선한 고기로 밀가루 하나 없는 건강한 전골입니다.
# 그 어떤 술집에서도 맛 볼수 없는 돼지 특수 부위 **항정수육**
# - 항정살 이젠 다들 아시죠? 그걸 수육으로 만들어서 촉촉하지만 겉은 바삭하게 만들어봤습니다.
# 술 먹으면서 몸까지 챙기는 양지와 스지가 들어간 **수지 스지탕**
# - 소의 힘줄 스지로 만드는 보양탕인데, 맛도 있어 해장도 가능
# 여기가 마라탕 집인지 술집인지 이젠 나도 헷갈리는 **마라전골**
# - 마라떡볶이, 마라탕 등 대한민국을 집어삼킨 마라
# 중국집에서 짬뽕 안시켜먹는 수지 직원들 최애 안주 ***차돌듬뿍짬뽕탕***
# - 다들 아시죠? 그 짬뽕 그대로 맞습니다 원팩? 안써요
# 시원시원한 *냉채수육*과 *냉채차돌*
# - 시원한 안주 생각나시잖아요 술먹다 보면 그때 드시죠
# 양 많고 저렴하게 준비된 갖가지 - 사이드 메뉴 -
# - 순살치킨, 간장치킨, 생과일화채, 멜론, 파인애플, 팥빙수, 감자튀김 등등 30여가지 사이드
# 식사를 책임질 수 있는 다양한 -식사 메뉴-
# - 참치주먹밥, 치킨마요덮밥, 김치볶음밥 등 10여가지 식사메뉴
#
# 안주 드시면서 드셔야 몸 건강히 잘 드실 수 있는거 아시죠??
#
# 수지 상회는 퀄리티, 서비스, 청결 3대 원칙을 준수하고 있으며 언제나 고객의 니즈를 파악하기 위해 노력하며 발전하고 있습니다.
#
# 강남역 최다 종류 주류 보유중입니다!!
#
# 수지상회의 특별한 시그니처 하이볼과 남여노소 불문하고
#
# 누구한테나 사랑받는 하이볼들이 수십종류 보유중입니다.
#
# 요즘 워라벨이 중요한 이시대에 가볍고 비싸지않게 맛있는
#
# 하이볼들로 지인들과 친구들과 직장동료들과 가족들과
#
# 행복하고, 즐거운 시간을 보내실 수 있도록 강남역술집 수지상회에서 준비하겠습니다.
#
# 고객님들은 몸만 오세요 나머진 저희가 할게요.
#
# @@ 예약시 참고해주세요.
# - 주말(금, 토) 예약시 18시 이후는 일주일전에 예약이 조기마감 될 수 있으니 양해부탁드립니다 :)
# - 예약 완료 후 10분 경과시 no-show 처리로 예약이 취소처리 될 수 있습니다. 변동사항 생기시면 매장으로 전화주세요 ^^
# - 인원 수 맞춰서 예약 주시고 인원수 제한이 걸리시면 따로 유선 연락주시기 바라겠습니다
#
# 오늘 하루도 고생 많으셨습니다. 항상 행복하시고 즐겁게 마시고 드실수 있도록 항상 노력하고 발전하는 수지상회가 되겠습니다. 감사합니다!
# 펼쳐보기
#  convenience_facilities_and_services: 콜키지 가능
# 유료
# 생일 혜택
# 단체 이용 가능
# 남/녀 화장실 구분
# 예약
# 대기공간
# 출입구 휠체어 이용가능
# 좌석 휠체어 이용가능
#
#  Parking: 주차가능
# 유료
# 최초 5분 300원
# 추가 요금 5분당 300원, 최대 100,000원
#  sns: https://blog.naver.com/sswp1020
# https://www.instagram.com/suji__gn
#
#  review_like_this_part_output: "음식이 맛있어요"이 키워드를 선택한 인원1229
# "친절해요"이 키워드를 선택한 인원698
# "인테리어가 멋져요"이 키워드를 선택한 인원687
# "술이 다양해요"이 키워드를 선택한 인원630
# "음악이 좋아요"이 키워드를 선택한 인원473
# "대화하기 좋아요"이 키워드를 선택한 인원448
# "기본 안주가 좋아요"이 키워드를 선택한 인원447
# "매장이 청결해요"이 키워드를 선택한 인원446
# "특별한 메뉴가 있어요"이 키워드를 선택한 인원334
# "단체모임 하기 좋아요"이 키워드를 선택한 인원333
# "가성비가 좋아요"이 키워드를 선택한 인원312
# "오래 머무르기 좋아요"이 키워드를 선택한 인원249
# "화장실이 깨끗해요"이 키워드를 선택한 인원189
# "매장이 넓어요"이 키워드를 선택한 인원55
# "메뉴 구성이 알차요"이 키워드를 선택한 인원44
# "혼술하기 좋아요"이 키워드를 선택한 인원26
# "양이 많아요"이 키워드를 선택한 인원15
# "주차하기 편해요"이 키워드를 선택한 인원12
# "사진이 잘 나와요"이 키워드를 선택한 인원11
# "음식이 빨리 나와요"이 키워드를 선택한 인원6
# "건강한 맛이에요"이 키워드를 선택한 인원6
# "좌석이 편해요"이 키워드를 선택한 인원5
# "아늑해요"이 키워드를 선택한 인원5
# "뷰가 좋아요"이 키워드를 선택한 인원5
# "컨셉이 독특해요"이 키워드를 선택한 인원4
# "비싼 만큼 가치있어요"이 키워드를 선택한 인원4
# "음료가 맛있어요"이 키워드를 선택한 인원3
# "재료가 신선해요"이 키워드를 선택한 인원3
# "야외공간이 멋져요"이 키워드를 선택한 인원2
# "파티하기 좋아요"이 키워드를 선택한 인원2
# "라이브공연이 훌륭해요"이 키워드를 선택한 인원1
# "특별한 날 가기 좋아요"이 키워드를 선택한 인원1
#
#  menu: 수지닭볶음탕대표26,900원
# 수지학센플레터대표수비드 조리된 돼지 앞발!!!!
# 독일식 슈바인 학센을 만나보세요!!!31,900원
# 수지 스지탕대표소 힘줄인 스지와 양지수육이 듬뿍 들어간 건강에도 좋고 맛도 좋은 먹은사람은 한번 더 먹는30,900원
# 수지양지수육한판대표사골국물에 촉촉히 적셔가면서 먹는 양지수육을 술집에서????!!!29,900원
# 수지 빨간 어묵탕대표해물 들어간 얼큰~~~한 빨간 어묵탕!!24,900원
# 내가제일잘나베대표롱치즈돈까스가 통으로 올라간 수지상회 돈까스 김치나베!!23,900원
# 수코바 숯불 치킨대표수코바 숯불 치킨!! 국내산 닭을 이용해 구운 숯불 치킨!!!!!!!!!23,900원
# 다양한 하이볼여기가 강남역 하이볼 성지!! 엄청나게 다양한 하이볼 라인업!변동
# 수지샤브마라전골마라가 세상을 지배했다. 수지상회 마저 점령한 마라전골 완자까지 올라가요 존맛탱..31,900원
# 전,전,전감자전, 부추전, 김치전변동
# 수지샤브전골밀푀유 베이스에 만두까지 퐁당 맑은 육수로 소주 꼴깍!!28,900원
# 마라떡볶이마라가 세상을 지배한다 마라떡볶이 출시!!!22,900원
# 차돌듬뿍짬뽕탕저희는 중국집에서 짬뽕 안시켜먹습니다. 이게 더 맛있거든요.22,900원
# 코찡냉채차돌불향을 입힌 우삼겹을 시원하게 냉채소스와 곁들여 먹는 간단하게 즐기기 좋은 안주21,900원
# 차돌떡볶이오랜시간 연구끝에 나온 특제소스로 만드는 매콜달콤한 떡볶이 위에 우삼겹까지 듬뿍20,900원
# </content>
# <document><content>store_name: 수지상회 강남1호점
#  category: 요리주점
#  new_open:
#  rating: 정보없음
#  visited_review: 방문자 리뷰 1,750
#  directions_text: 수지상회는 2층에 있습니다.
# 건물1층은 보승회관 입니다. 보승회관을 정면으로 바라보시고 우측 통로를 통해 건물 내부로 들어오셔서 계단 혹은 엘레베이터 이용하셔서 2층으로 올라오시면 하트 조명이 보이십니다. 문을 열고 들어오시면 건물 내부지만 충분한 개방감을 느끼실 수 있는 수지상회가 보이십니다.
#
# 2호선 강남역에서 내리셔서 12번 출구로 나오신 다음
# 왼쪽으로 돌아 내려오셔서 오른쪽 첫 골목으로 들오셔서
# 100m가량 들어오시면(세븐일레븐,빌리엔젤을 지나)
# 왼편 2층에 위치하고 있습니다.
#
# 강남역과 1분거리에 있는 오기도 편하고 집가기도 편한 강남억술집 수지상회에서 여러분을 기다리겠습니다
#
# 주차는 죄송스럽지만 따로 공간이 마련되어 있지 않습니다.
# 근처 유료 주차장 이용해주시면 감사하겠습니다!!
# 내용 더보기
#  store_id: 1810165759
#  address: 서울 강남구 테헤란로1길 17 2층
#  blog_review: 블로그 리뷰 2,362
#  phone_num: 0507-1366-6974
#  business_hours: 매일
# 16:00 - 05:00
#
#  info: 안녕하세요.
#
# @@@@인스타 맛집@@@@
# @@@SNS핫플@@@
# @@@분위기 맛집@@@
# @@@안주 맛집@@@
# @@@데이트 베스트 코스@@@
# @@@하이볼 맛집@@@
# @@@강남역술집@@@
# @@@강남술집@@@
#
# 매장 방문시 신분증 필수 지참인 부분 양해부탁드립니다.
#
# 수 많은 인플루언서들의 선택을 받은 강남1등 술집 수지상회 강남 1호점 인사드리겠습니다!!!
#
# 날이 더워지고, 추워지고, 비가오고, 눈이오고 어떤 상황에서도
#
# 굴하지 않고 문을 여는 강남역 술집!
#
# 지하철역에서 3분거리에 위치해서 막차 놓칠리 없고!
#
# 강남에서 제일 화장실 깨끗하고!!
#
# 모두가 만족하는 서비스를 제공해드리는 이 곳!
#
# 수지상회 강남점입니다.
#
# 봄엔 꽃향기를 맡으며!!
#
# 여름엔 시원하게!!
#
# 가을엔 선선한 바람을 맞으며!!
#
# 겨울엔 따뜻하게!!
#
# 연인과 데이트를 하기에도 좋고, 가족끼리 오랜만에 외식하기에도 좋고, 손님을 모시고 가도 좋고, 친구랑 놀러가기도 좋은 매장입니다.
#
# 항상 뻔한 음식과 뻔한 맛 뻔한 일상에 지치신 분들을 위해서 저희가 그동안 없었던 특별한 맛, 특별한 음식, 일상에서의 색다로움을 즐기실 수 있도록 준비했습니다.
#
# 항상 고객 여러분들을 생각하고 한분 한분 최선을 다해서 니즈를 맞춰드리는 저희가 강남에 왔습니다!!
#
# 취향저격 다양한 종류의 메뉴들!!
#
# 갈빗대 통째 드리는 **수지 우대 갈비**
# - 소의 가장 큰 갈빗대로 요즘 유행하는 그 소고기 맞습니다.
# 수비드로 조리된 족발 가득 담긴 ***학센 플레터***
# - 독일식 족발인 겉바속촉 족발을 한국에서 즐기실수있습니다.
# 매일 공수해온 채소로 준비한 **수지 샤브 전골**
# - 신선한 야채와 신선한 고기로 밀가루 하나 없는 건강한 전골입니다.
# 그 어떤 술집에서도 맛 볼수 없는 돼지 특수 부위 **항정수육**
# - 항정살 이젠 다들 아시죠? 그걸 수육으로 만들어서 촉촉하지만 겉은 바삭하게 만들어봤습니다.
# 술 먹으면서 몸까지 챙기는 양지와 스지가 들어간 **수지 스지탕**
# - 소의 힘줄 스지로 만드는 보양탕인데, 맛도 있어 해장도 가능
# 여기가 마라탕 집인지 술집인지 이젠 나도 헷갈리는 **마라전골**
# - 마라떡볶이, 마라탕 등 대한민국을 집어삼킨 마라
# 중국집에서 짬뽕 안시켜먹는 수지 직원들 최애 안주 ***차돌듬뿍짬뽕탕***
# - 다들 아시죠? 그 짬뽕 그대로 맞습니다 원팩? 안써요
# 시원시원한 *냉채수육*과 *냉채차돌*
# - 시원한 안주 생각나시잖아요 술먹다 보면 그때 드시죠
# 양 많고 저렴하게 준비된 갖가지 - 사이드 메뉴 -
# - 순살치킨, 간장치킨, 생과일화채, 멜론, 파인애플, 팥빙수, 감자튀김 등등 30여가지 사이드
# 식사를 책임질 수 있는 다양한 -식사 메뉴-
# - 참치주먹밥, 치킨마요덮밥, 김치볶음밥 등 10여가지 식사메뉴
#
# 안주 드시면서 드셔야 몸 건강히 잘 드실 수 있는거 아시죠??
#
# 수지 상회는 퀄리티, 서비스, 청결 3대 원칙을 준수하고 있으며 언제나 고객의 니즈를 파악하기 위해 노력하며 발전하고 있습니다.
#
# 강남역 최다 종류 주류 보유중입니다!!
#
# 수지상회의 특별한 시그니처 하이볼과 남여노소 불문하고
#
# 누구한테나 사랑받는 하이볼들이 수십종류 보유중입니다.
#
# 요즘 워라벨이 중요한 이시대에 가볍고 비싸지않게 맛있는
#
# 하이볼들로 지인들과 친구들과 직장동료들과 가족들과
#
# 행복하고, 즐거운 시간을 보내실 수 있도록 강남역술집 수지상회에서 준비하겠습니다.
#
# 고객님들은 몸만 오세요 나머진 저희가 할게요.
#
# @@ 예약시 참고해주세요.
# - 주말(금, 토) 예약시 18시 이후는 일주일전에 예약이 조기마감 될 수 있으니 양해부탁드립니다 :)
# - 예약 완료 후 10분 경과시 no-show 처리로 예약이 취소처리 될 수 있습니다. 변동사항 생기시면 매장으로 전화주세요 ^^
# - 인원 수 맞춰서 예약 주시고 인원수 제한이 걸리시면 따로 유선 연락주시기 바라겠습니다
#
# 오늘 하루도 고생 많으셨습니다. 항상 행복하시고 즐겁게 마시고 드실수 있도록 항상 노력하고 발전하는 수지상회가 되겠습니다. 감사합니다!
# 펼쳐보기
#  convenience_facilities_and_services: 콜키지 가능
# 유료
# 생일 혜택
# 단체 이용 가능
# 남/녀 화장실 구분
# 예약
# 대기공간
# 출입구 휠체어 이용가능
# 좌석 휠체어 이용가능
#
#  Parking: 주차가능
# 유료
# 최초 5분 300원
# 추가 요금 5분당 300원, 최대 100,000원
#  sns: https://blog.naver.com/sswp1020
# https://www.instagram.com/suji__gn
#
#  review_like_this_part_output: "음식이 맛있어요"이 키워드를 선택한 인원1228
# "친절해요"이 키워드를 선택한 인원697
# "인테리어가 멋져요"이 키워드를 선택한 인원687
# "술이 다양해요"이 키워드를 선택한 인원630
# "음악이 좋아요"이 키워드를 선택한 인원472
# "대화하기 좋아요"이 키워드를 선택한 인원448
# "기본 안주가 좋아요"이 키워드를 선택한 인원446
# "매장이 청결해요"이 키워드를 선택한 인원446
# "특별한 메뉴가 있어요"이 키워드를 선택한 인원334
# "단체모임 하기 좋아요"이 키워드를 선택한 인원333
# "가성비가 좋아요"이 키워드를 선택한 인원312
# "오래 머무르기 좋아요"이 키워드를 선택한 인원249
# "화장실이 깨끗해요"이 키워드를 선택한 인원188
# "매장이 넓어요"이 키워드를 선택한 인원55
# "메뉴 구성이 알차요"이 키워드를 선택한 인원44
# "혼술하기 좋아요"이 키워드를 선택한 인원26
# "양이 많아요"이 키워드를 선택한 인원15
# "주차하기 편해요"이 키워드를 선택한 인원12
# "사진이 잘 나와요"이 키워드를 선택한 인원11
# "음식이 빨리 나와요"이 키워드를 선택한 인원6
# "건강한 맛이에요"이 키워드를 선택한 인원6
# "좌석이 편해요"이 키워드를 선택한 인원5
# "아늑해요"이 키워드를 선택한 인원5
# "뷰가 좋아요"이 키워드를 선택한 인원5
# "컨셉이 독특해요"이 키워드를 선택한 인원4
# "비싼 만큼 가치있어요"이 키워드를 선택한 인원4
# "음료가 맛있어요"이 키워드를 선택한 인원3
# "재료가 신선해요"이 키워드를 선택한 인원3
# "야외공간이 멋져요"이 키워드를 선택한 인원2
# "파티하기 좋아요"이 키워드를 선택한 인원2
# "라이브공연이 훌륭해요"이 키워드를 선택한 인원1
# "특별한 날 가기 좋아요"이 키워드를 선택한 인원1
#
#  menu: 수지닭볶음탕대표26,900원
# 수지학센플레터대표수비드 조리된 돼지 앞발!!!!
# 독일식 슈바인 학센을 만나보세요!!!31,900원
# 수지 스지탕대표소 힘줄인 스지와 양지수육이 듬뿍 들어간 건강에도 좋고 맛도 좋은 먹은사람은 한번 더 먹는30,900원
# 수지양지수육한판대표사골국물에 촉촉히 적셔가면서 먹는 양지수육을 술집에서????!!!29,900원
# 수지 빨간 어묵탕대표해물 들어간 얼큰~~~한 빨간 어묵탕!!24,900원
# 내가제일잘나베대표롱치즈돈까스가 통으로 올라간 수지상회 돈까스 김치나베!!23,900원
# 수코바 숯불 치킨대표수코바 숯불 치킨!! 국내산 닭을 이용해 구운 숯불 치킨!!!!!!!!!23,900원
# 다양한 하이볼여기가 강남역 하이볼 성지!! 엄청나게 다양한 하이볼 라인업!변동
# 수지샤브마라전골마라가 세상을 지배했다. 수지상회 마저 점령한 마라전골 완자까지 올라가요 존맛탱..31,900원
# 전,전,전감자전, 부추전, 김치전변동
# 수지샤브전골밀푀유 베이스에 만두까지 퐁당 맑은 육수로 소주 꼴깍!!28,900원
# 마라떡볶이마라가 세상을 지배한다 마라떡볶이 출시!!!22,900원
# 차돌듬뿍짬뽕탕저희는 중국집에서 짬뽕 안시켜먹습니다. 이게 더 맛있거든요.22,900원
# 코찡냉채차돌불향을 입힌 우삼겹을 시원하게 냉채소스와 곁들여 먹는 간단하게 즐기기 좋은 안주21,900원
# 차돌떡볶이오랜시간 연구끝에 나온 특제소스로 만드는 매콜달콤한 떡볶이 위에 우삼겹까지 듬뿍20,900원
# </content>
# <document><content>store_name: 강남주막다방
#  category: 요리주점
#  new_open:
#  rating: 정보없음
#  visited_review: 방문자 리뷰 258
#  directions_text: 신사역에서 8번출구로 도보로 5분거리에 위치해 있으며 8번출구에서 직진 가로수길 입구 좌회전 하시면 전방 150m 우측에 롤링파스타건물 지하입니다.
# 내용 더보기
#  store_id: 1204418832
#  address: 서울 강남구 가로수길 16 덕암빌딩 지하1층
#  blog_review: 블로그 리뷰 219
#  phone_num: 0507-1399-0720
#  business_hours: 수(1/1)
# 휴무
# 목
# 16:00 - 03:00
# 02:00 라스트오더
# 금
# 16:00 - 03:00
# 02:00 라스트오더
# 토
# 16:00 - 03:00
# 02:00 라스트오더
# 일
# 16:30 - 01:30
# 00:30 라스트오더
# 월
# 16:00 - 03:00
# 02:00 라스트오더
# 화
# 16:00 - 03:00
# 02:00 라스트오더
#
#  info: 신사동 가로수길에 최고 안주 맛집!!
# 집밥같이 재료와 맛에 최선을 다한 요리를 다양하게 즐기면서 한잔 할 수 있는 레트로 스타일의 핫 플레이스 강남주막다방.
# DJ박스에 듣고 싶은 음악 신청도 하실 수 있고 홀과 분리된 공간에서 모임도 가능합니다.
# 스크린 골프 룸이 있어 지인분들과 라운딩도 즐기면서 다양한 음식도 드시면서 즐거운 시간 보낼 수 있어요~!!(룸은 예약 필수입니다^^)
#  convenience_facilities_and_services: 단체 이용 가능
# 무선 인터넷
# 남/녀 화장실 구분
# 예약
#
#  Parking: 주차가능
#  sns: https://booking.naver.com/?area=bmp
# https://www.instagram.com/kangnam777
#
#  review_like_this_part_output: "음식이 맛있어요"이 키워드를 선택한 인원212
# "친절해요"이 키워드를 선택한 인원130
# "단체모임 하기 좋아요"이 키워드를 선택한 인원116
# "음악이 좋아요"이 키워드를 선택한 인원107
# "기본 안주가 좋아요"이 키워드를 선택한 인원90
# "술이 다양해요"이 키워드를 선택한 인원65
# "대화하기 좋아요"이 키워드를 선택한 인원59
# "특별한 메뉴가 있어요"이 키워드를 선택한 인원54
# "가성비가 좋아요"이 키워드를 선택한 인원52
# "인테리어가 멋져요"이 키워드를 선택한 인원48
# "매장이 청결해요"이 키워드를 선택한 인원40
# "오래 머무르기 좋아요"이 키워드를 선택한 인원37
# "화장실이 깨끗해요"이 키워드를 선택한 인원26
# "매장이 넓어요"이 키워드를 선택한 인원21
# "메뉴 구성이 알차요"이 키워드를 선택한 인원12
# "파티하기 좋아요"이 키워드를 선택한 인원8
# "재료가 신선해요"이 키워드를 선택한 인원6
# "혼술하기 좋아요"이 키워드를 선택한 인원4
# "양이 많아요"이 키워드를 선택한 인원4
# "좌석이 편해요"이 키워드를 선택한 인원3
# "룸이 잘 되어있어요"이 키워드를 선택한 인원3
# "컨셉이 독특해요"이 키워드를 선택한 인원1
# "라이브공연이 훌륭해요"이 키워드를 선택한 인원1
# "주차하기 편해요"이 키워드를 선택한 인원1
# "건강한 맛이에요"이 키워드를 선택한 인원1
#
#  menu: 매칼닭볶음탕대표각종야채 듬뿍 들어간 매콤 칼칼한 닭볶음탕
# 술술 술을 부르는 최고안주!!39,000원
# 홍합탕대표냄비 한가득 푸짐한 홍합탕 국물이 끝내줘요!!22,000원
# 오뎅탕대표각종 다양한 어묵이 푸짐하게 홍합과 함께 시원한 국물로 소주가 술술 들어가는 시그니처 메뉴29,000원
# 밀푀유나베대표고기와 숙주와 야채가득 담백한 육수에 끓여 건져서 먹는 건강하고 담백한 요리!35,000원
# 고추장찌개대표한돈 목살고기와 감자와 야채 듬뿍 칼칼한 국물에 밥이 생각나는 국물요리25,000원
# 편백해물삼합찜대표편백찜기에 해물(오징어,전복,대하,가리비등)과 푸짐한 야채와 우삼겹을 넣어 찐 최고요리변동
# 겉바속촉가지튀김대표겉바속촉.. 말이 필요없는 고급일품요리
# 꼭 먹어봐야 하는 안주!!
# 수제소스 찍어 한입에19,000원
# 모듬전대표다양한 전 종류로 한상 푸짐한 안주(굴전,호박전,육전,감자전,동태전,옛날소세지,두부전 등)32,000원
# 굴전대표바다향기 가득한 싱싱한 굴로 만든 전변동
# 치즈감자채전대표바삭바삭하게 감자채를 부쳐서 모짜렐라 치즈를 한가득 올려 풍미가득한 맛을 느낄수 있어요23,000원
# 모듬조개탕대표가리비,홍합,바지락등 다양한 조개들로 가득 드실수 있는 조개탕29,000원
# 오징어숙회대표오징어숙회와 매콤새콤 야채무침과 곁들여 드시면 맛이 2배로 더 맛있어요!25,000원
# 닭갈비대표매콤 달콤 양념에 먹을수록 당기는 닭갈비!
# 각종야채와 떡등 함께 드시고 양념에 볶음밥 최고28,000원
# 두부 두루치기대표두부와 볶음김치 그리고 삼겹살 말이 필요없는 아는 그맛!! 술안주로 최고25,000원
# 국물떡볶이대표야채 듬뿍 들어간 국물떡볶이와 해장하세요~~!!(해물or야채 선택가능)25,000원
# </content>
# <document><content>store_name: 먼데이투선데이 청담
#  category: 양식
#  new_open:
#  rating: 정보없음
#  visited_review: 방문자 리뷰 1,008
#  directions_text: 발렛 가능 (기본요금 2시간 5,000원 / 추가 10분당 1,000원)
# 단, 슈퍼카 기본요금 10,000원
#
# 343,4212번 버스 이용, 농협앞에서 하차.
# 농협 골목에서 50m 직진, 컷루스 옆에 위치
#
# 지하철 이용후 찾아오는길
#
# 압구정로데오역(신분당선) 3번출구에서 도보 10분
# 3번출구에서 250M 직진후 펜디매장에서 우회전
# 200M 볼트스테이크 하우스 까지 걸어오시면
# 미노트 매장이 보입니다.
# 여기서 우회전 하시면 먼데이투선데이 를 만날 수 있습니다.
#
# 네비게이션을 이용하여 찾아오실경우
# 티맵, 카카오네비 먼데이투선데이 로 검색후 주소를 선택하시면 됩니다.
#
# (서울시 강남구 도산대로67길 13-3 EMPRESS빌딩 B1층)
# 내용 더보기
#  store_id: 1766605714
#  address: 서울 강남구 도산대로67길 13-3 EMPRESS빌딩 B1층
#  blog_review: 블로그 리뷰 165
#  phone_num: 0507-1353-2217
#  business_hours: 화
# 08:00 - 02:00
# 01:30 라스트오더
# 수(1/1)
# 11:00 - 02:00
# 목
# 08:00 - 02:00
# 01:30 라스트오더
# 금
# 08:00 - 02:00
# 01:30 라스트오더
# 토
# 10:00 - 02:00
# 01:30 라스트오더
# 일
# 10:00 - 01:00
# 00:30 라스트오더
# 월
# 08:00 - 01:00
# 00:30 라스트오더
#
#  info: https://app.catchtable.co.kr/ct/shop/diningbar_mondaytosunday
#
# [브런치/디저트/ 레스토랑/ 주류페어링의 즐거움이 있는 먼데이투선데이]
#
# 와플, 로제 떡볶이 맛집이 청담에 있다?!
#
# 누구나 편하게 와서 머무를 수 있는 청담동 카페/레스토랑/와인바가 되길 원합니다.
#
# 탁 트인 테라스 공간에서 친구들과 안주와 함께 와인 한 잔
# 온가족이 모여 맛있는 디저트를 먹으며 커피 한 잔
# 어떠실까요?
#
# 많은 분들이 먼데이투선데이에 방문하셔서 편안한 시간을 보내고 도심 속 힐링 공간이 되길 바랍니다
# 펼쳐보기
#  convenience_facilities_and_services: 콜키지 가능
# 유료
# 무선 인터넷
# 남/녀 화장실 구분
# 예약
# 단체 이용 가능
# \
# 반려동물 동반
# 유아의자
# 포장
#
#  Parking: 주차가능
# 유료
# 최초 120분 5000원
# 추가 요금 10분당 1,000원, 최대 100,000원
#  sns: https://app.catchtable.co.kr/ct/shop/diningbar_mondaytosunday
# https://www.instagram.com/diningbar_mondaytosunday
#
#  review_like_this_part_output: "음식이 맛있어요"이 키워드를 선택한 인원808
# "인테리어가 멋져요"이 키워드를 선택한 인원708
# "매장이 넓어요"이 키워드를 선택한 인원438
# "친절해요"이 키워드를 선택한 인원408
# "재료가 신선해요"이 키워드를 선택한 인원276
# "매장이 청결해요"이 키워드를 선택한 인원206
# "특별한 메뉴가 있어요"이 키워드를 선택한 인원189
# "대화하기 좋아요"이 키워드를 선택한 인원105
# "양이 많아요"이 키워드를 선택한 인원99
# "단체모임 하기 좋아요"이 키워드를 선택한 인원91
# "디저트가 맛있어요"이 키워드를 선택한 인원61
# "커피가 맛있어요"이 키워드를 선택한 인원57
# "주차하기 편해요"이 키워드를 선택한 인원54
# "화장실이 깨끗해요"이 키워드를 선택한 인원54
# "사진이 잘 나와요"이 키워드를 선택한 인원51
# "뷰가 좋아요"이 키워드를 선택한 인원46
# "아늑해요"이 키워드를 선택한 인원45
# "음료가 맛있어요"이 키워드를 선택한 인원45
# "비싼 만큼 가치있어요"이 키워드를 선택한 인원37
# "차분한 분위기에요"이 키워드를 선택한 인원35
# "메뉴 구성이 알차요"이 키워드를 선택한 인원29
# "좌석이 편해요"이 키워드를 선택한 인원27
# "야외공간이 멋져요"이 키워드를 선택한 인원26
# "특별한 날 가기 좋아요"이 키워드를 선택한 인원21
# "가성비가 좋아요"이 키워드를 선택한 인원18
# "반려동물과 가기 좋아요"이 키워드를 선택한 인원17
# "혼밥하기 좋아요"이 키워드를 선택한 인원12
# "음악이 좋아요"이 키워드를 선택한 인원12
# "컨셉이 독특해요"이 키워드를 선택한 인원11
# "오래 머무르기 좋아요"이 키워드를 선택한 인원10
# "음식이 빨리 나와요"이 키워드를 선택한 인원6
# "건강한 맛이에요"이 키워드를 선택한 인원5
# "술이 다양해요"이 키워드를 선택한 인원4
# "룸이 잘 되어있어요"이 키워드를 선택한 인원3
# "집중하기 좋아요"이 키워드를 선택한 인원3
# "코스요리가 알차요"이 키워드를 선택한 인원2
# "아이와 가기 좋아요"이 키워드를 선택한 인원2
# "고기 질이 좋아요"이 키워드를 선택한 인원2
# "기본 안주가 좋아요"이 키워드를 선택한 인원1
#
#  menu: 한우 찹스테이크대표숙성한 채끝 등심을 이용해 여러가지 신선한 야채와 수제소스로 맛을낸 찹 스테이크39,000원
# 스파이시 씨푸드 파스탕대표신선한 꽃게와 해산물이 가득, 해장하기 좋은 매콤한 리가토니 파스탕28,000원
# 촉촉한 프렌치 토스트대표달걀과 버터로 촉촉하게 구워낸 먼투썬만의 시그니처 프렌치 토스트23,000원
# 우삼겹 로제 떡볶이대표고소하고 진한 소스가 매력적인 먼투썬만의 로제 떡볶이29,000원
# 먼투선 김치볶음밥대표삼겹살이 듬뿍 들어간 먼데이 투 선데이 김치볶음밥24,000원
# 카므라이스대표우삼겹이 들어간 카레와 오므라이스의 장점만 살린 먼데이투선데이 퓨전요리22,000원
# 버터새우 시저 샐러드대표버터풍미의 새우가 올려진 로메인 시저샐러드24,000원
# 트러플 허니 프렌치 후라이(감튀)대표트러플과 꿀을 코팅해 중독성이 강한 감자튀김20,000원
# 제철과일 생크림 케이크(딸기)대표먼투썬만의 레시피로 만든 생크림과 신선한 제철 과일과의 만남! 생크림 케이크 완추♥16,000원
# 브라우니와 바닐라 아이스크림대표부드러운 밀크초콜릿이 듬뿍 들어간 브라우니와 바닐라 아이스크림15,000원
# 한우 1++ No.9 채끝등심스테이크최상급 채끝 등심과 남해 보물초 시금치 그리고 경북 특산물 송향버섯이 올라간 스테이크73,000원
# 풀드포크&고구마퓨레긴 시간 훈연한 풀풀드포크와 부드러운 고구마무스의 만남, 깊고 따뜻한 풍미를 즐겨보세요!20,000원
# 치즈 곶감말이쫀득한 곶감 속에 치즈의 부드러움이 더해진 깊은 맛, 완벽한 밸런스!13,000원
# 과일 플레터신선한 과일들이 입안 가득 가득!16,000원
# 과일 치즈 올리브(+빵3slices)상큼한 과일과 고소한 치즈, 올리브가 어우러져, 한 입에 담긴 풍미의 향연!13,000원
# </content>
# <document><content>store_name: 단골손님 강남1호점
#  category: 요리주점
#  new_open:
#  rating: 정보없음
#  visited_review: 방문자 리뷰 1,411
#  directions_text: 강남역 2호선 11번 출구에서 나오셔서 190m 직진 하시면
#
# 우측에 메가박스시티가 보이실 겁니다.
#
# 아트박스를 끼시고 우회전 하신 다음에
#
# 10m 가량 언덕을 올라오시면 왼쪽 편에 이마트24가 보이십니다.
#
# 바로 보이는 사거리에서 좌회전 하셔서 15m 가량 올라오시면 오른편 2층에 단골손님이 위치하고 있습니다.
#
# 건물 1층은 놀부부대찌개 입니다. 오른쪽 계단입구로 올라오셔서,
#
# 여기까지 오시느리 다리가 아프신 고객님들을 위한
#
# 엘레베이터가 준비되어 있어요. 엘레베이터를 타고 2층을 꾹 눌러주세요. 내리시면 매장 입구가 바로 보이십니다.
#
# 자동문을 누르고 들어오시면 저희 이쁘고 잘생긴 친절한 직원들과 매니저님 점장님이 반겨주실겁니다. :)
#
# 오늘도 찾아주셔서 감사합니다. 단골손님 강남 1호점 입니다!!!
# 내용 더보기
#  store_id: 1562446785
#  address: 서울 강남구 테헤란로1길 40 2층
#  blog_review: 블로그 리뷰 187
#  phone_num: 0507-1347-9470
#  business_hours: 매일
# 16:00 - 03:00
#
#  info: 정보없음
#  convenience_facilities_and_services: 정보없음
#  Parking: 정보없음
#  sns: 정보없음
#  review_like_this_part_output: 정보없음
#  menu: 정보없음</content>
# <document><content>store_name: 치보 강남신사점
#  category: 일식당
#  new_open:
#  rating: 정보없음
#  visited_review: 방문자 리뷰 319
#  directions_text: 신사역 8번출구 3분거리, 가로수길 5분거리에 위치하여 있습니다.
#  store_id: 1150149433
#  address: 서울 강남구 강남대로154길 21 1층 101호
#  blog_review: 블로그 리뷰 287
#  phone_num: 0507-1432-1973
#  business_hours: 월
# 정기휴무 (매주 월요일)
# 화(12/31)
# 11:00 - 23:00
# 수(1/1)
# 새해 첫날11:00 - 22:00
# 목
# 11:00 - 22:00
# 15:00 - 17:00 브레이크타임
# 21:10 라스트오더
# 금
# 11:00 - 22:00
# 15:00 - 17:00 브레이크타임
# 21:10 라스트오더
# 토
# 11:00 - 22:00
# 21:10 라스트오더
# 일
# 11:00 - 22:00
# 21:10 라스트오더
#
#  info: 정보없음
#  convenience_facilities_and_services: 정보없음
#  Parking: 정보없음
#  sns: 정보없음
#  review_like_this_part_output: 정보없음
#  menu: 정보없음</content>
# <document><content>store_name: 단골손님 강남1호점
#  category: 요리주점
#  new_open:
#  rating: 정보없음
#  visited_review: 방문자 리뷰 1,412
#  directions_text: 강남역 2호선 11번 출구에서 나오셔서 190m 직진 하시면
#
# 우측에 메가박스시티가 보이실 겁니다.
#
# 아트박스를 끼시고 우회전 하신 다음에
#
# 10m 가량 언덕을 올라오시면 왼쪽 편에 이마트24가 보이십니다.
#
# 바로 보이는 사거리에서 좌회전 하셔서 15m 가량 올라오시면 오른편 2층에 단골손님이 위치하고 있습니다.
#
# 건물 1층은 놀부부대찌개 입니다. 오른쪽 계단입구로 올라오셔서,
#
# 여기까지 오시느리 다리가 아프신 고객님들을 위한
#
# 엘레베이터가 준비되어 있어요. 엘레베이터를 타고 2층을 꾹 눌러주세요. 내리시면 매장 입구가 바로 보이십니다.
#
# 자동문을 누르고 들어오시면 저희 이쁘고 잘생긴 친절한 직원들과 매니저님 점장님이 반겨주실겁니다. :)
#
# 오늘도 찾아주셔서 감사합니다. 단골손님 강남 1호점 입니다!!!
# 내용 더보기
#  store_id: 1562446785
#  address: 서울 강남구 테헤란로1길 40 2층
#  blog_review: 블로그 리뷰 187
#  phone_num: 0507-1347-9470
#  business_hours: 매일
# 16:00 - 03:00
#
#  info: 정보없음
#  convenience_facilities_and_services: 정보없음
#  Parking: 정보없음
#  sns: 정보없음
#  review_like_this_part_output: 정보없음
#  menu: 정보없음</content>
# <document><content>store_name: 강남지하상회
#  category: 술집
#  new_open:
#  rating: 정보없음
#  visited_review: 방문자 리뷰 49
#  directions_text: 메가박스 건물 뒤쪽에 있으며 엠투포차, 인쌩맥주, 워너비대구 건물 지하2층입니다 땀땀 옆 건물 ( 구 강남시장)
#  store_id: 1069277766
#  address: 서울 강남구 테헤란로1길 28-5 지하2층 강남지하상회
#  blog_review: 블로그 리뷰 56
#  phone_num: 0507-1484-0492
#  business_hours: 매일
# 17:00 - 02:00
# 01:30 라스트오더
#
#  info: 정보없음
#  convenience_facilities_and_services: 정보없음
#  Parking: 정보없음
#  sns: 정보없음
#  review_like_this_part_output: 정보없음
#  menu: 정보없음</content>
# ==================================================
#
# ==================================================
# 🔄 Node: llm_Summary_naver 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# answer_llm_Summary_gangnam:
# ```json
# {
#   "store_name": "수지상회 강남1호점",
#   "category": "요리주점",
#   "rating": "정보없음",
#   "directions_text": "수지상회는 2층에 있습니다. 2호선 강남역에서 12번 출구로 나오신 다음 왼쪽으로 돌아 내려오셔서 오른쪽 첫 골목으로 들어오시면 왼편 2층에 위치하고 있습니다.",
#   "store_id": "1810165759",
#   "address": "서울 강남구 테헤란로1길 17 2층",
#   "phone_num": "0507-1366-6974",
#   "business_hours": "매일 16:00 - 05:00",
#   "info": "안녕하세요. 인스타 맛집, SNS 핫플, 분위기 맛집, 안주 맛집 등으로 알려진 강남 1등 술집입니다. 다양한 메뉴와 청결한 화장실, 친절한 서비스로 고객을 맞이합니다.",
#   "convenience_facilities_and_services": "콜키지 가능, 유료, 생일 혜택, 단체 이용 가능, 남/녀 화장실 구분, 예약, 대기공간, 출입구 휠체어 이용가능, 좌석 휠체어 이용가능",
#   "Parking": "주차가능, 유료, 최초 5분 300원, 추가 요금 5분당 300원, 최대 100,000원",
#   "sns": "https://blog.naver.com/sswp1020, https://www.instagram.com/suji__gn",
#   "store의 좋은점": "다양한 메뉴와 청결한 화장실, 친절한 서비스, 강남역과 가까운 위치",
#   "menu": {
#     "수지닭볶음탕": "26,900원",
#     "수지학센플레터": "31,900원",
#     "수지 스지탕": "30,900원",
#     "수지양지수육한판": "29,900원",
#     "수지 빨간 어묵탕": "24,900원",
#     "내가제일잘나베": "23,900원",
#     "수코바 숯불 치킨": "23,900원",
#     "수지샤브마라전골": "31,900원",
#     "차돌듬뿍짬뽕탕": "22,900원"
#   }
# }
# ```
# answer_llm_Summary_jongro:
# none
# answer_llm_Summary_junggu:
# none
# answer_llm_Summary_yongsan:
# none
# ==================================================
#
# ==================================================
# 🔄 Node: llm_Summary_opendata 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# answer_llm_Summary_opendata:
# ### 요약
#
# - "장소 이름": 강남관광정보센터
# - "위치": 서울특별시 강남구 압구정로 161, 1층
# - "전화번호": 02-1661-2230
# - "웹사이트 URL": [강남관광정보센터](https://www.gangnam.go.kr/contents/tourgangnam/2/view.do?mid=FM010406)
# - "운영 날짜 및 시간": 하절기/동절기 10:00 ~ 18:00, 휴무일: 토, 일, 공휴일
# - "교통정보": 3호선 압구정역 6번 출구 도보 2분
# - "기타 편의 여부": 커뮤니케이션 공간, 공유오피스, 사무공간, 체험존, 휴게시설, 로봇카페
# - "지원언어": 영어, 일본어, 중국어, 러시아어
#
# ---
#
# - "장소 이름": 만나분식
# - "위치": 서울 강남구 삼성로 212 (대치동, 은마아파트)
# - "전화번호": 02-557-7040
# - "웹사이트 URL": [만나분식](https://korean.visitseoul.net/attractions/202303/KOPu5th9n?utm_source=seoulopendata&utm_medium=attractions&utm_content=KOPu5th9n)
# - "운영 날짜 및 시간": 매일 10:00 ~ 20:00, 휴무일: 매달 1, 3번째 일요일 정기 휴무 & 2, 4번째 월요일 휴무
# - "교통정보": 3호선 대치역 3번 출구에서 10m
# - "기타 편의 여부": 없음
# - "지원언어": 없음
#
# ---
#
# - "장소 이름": 카페먼데이투선데이
# - "위치": 서울특별시 강남구 도산대로67길 13-3 (청담동)
# - "전화번호": 0507-1353-2217
# - "웹사이트 URL": [카페먼데이투선데이](https://korean.visitseoul.net/restaurants/카페먼데이투선데이1/KOP005525?utm_source=seoulopendata&utm_medium=restaurants&utm_content=KOP005525)
# - "운영 날짜 및 시간": 월요일~목요일/일요일 10:30 ~ 23:00, 금요일/토요일 10:30 ~ 24:00
# - "교통정보": 수인분당선 압구정로데오역 5번 출구에서 약 571m (도보 8분)
# - "기타 편의 여부": 없음
# - "지원언어": 없음
#
# ---
#
# - "장소 이름": 난장캠프
# - "위치": 서울 강남구 강남대로158길 27 (신사동)
# - "전화번호": 02-3443-6466
# - "웹사이트 URL": [난장캠프](https://nanjangcampgarosu.modoo.at/)
# - "운영 날짜 및 시간": 평일 16:00~23:20, 토 16:00~23:00, 일 16:00~22:00
# - "교통정보": 3호선 신사역 8번 출구 도보 10분
# - "기타 편의 여부": 없음
# - "지원언어": 없음
#
# ---
#
# - "장소 이름": 만나당
# - "위치": 서울 강남구 논현로175길 61 (신사동) 1층 101호
# - "전화번호": 0507-1327-3312
# - "웹사이트 URL": [만나당](https://mannadang.modoo.at/)
# - "운영 날짜 및 시간": 월요일-토요일 10:00-18:00, 휴무일: 일요일
# - "교통정보": 3호선 압구정역 5번 출구에서 약 498m (도보 7분)
# - "기타 편의 여부": 없음
# - "지원언어": 없음
#
# ---
#
# 기타 의원 정보는 요약에서 제외하였습니다.
# ==================================================
#
# ==================================================
# 🔄 Node: Schedule_or_place_check 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# ScheduleOrplace:
# 일정
# ==================================================
# []
#
# ==================================================
# 🔄 Node: llm_Schedule_answer 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# answer:
# **강남구 1박 2일 여행 일정**
#
# - **1일차**
#
#   - **점심**
#     - **점심 식사 장소**: 만나분식
#       - **주소**: 서울 강남구 삼성로 212 (대치동, 은마아파트)
#       - **영업 시간**: 매일 10:00 ~ 20:00, 매달 1, 3번째 일요일 정기 휴무 & 2, 4번째 월요일 휴무
#       - **특징**: 전통적인 한국 분식 메뉴를 제공하는 곳
#     - **명소**: 강남관광정보센터
#       - **위치**: 서울특별시 강남구 압구정로 161, 1층
#       - **특징**: 다양한 관광 정보를 제공하며, 커뮤니케이션 공간과 체험존이 있음
#     - **카페**: 카페먼데이투선데이
#       - **주소**: 서울특별시 강남구 도산대로67길 13-3 (청담동)
#       - **영업 시간**: 월요일~목요일/일요일 10:30 ~ 23:00, 금요일/토요일 10:30 ~ 24:00
#       - **특징**: 아늑한 분위기의 카페
#
#   - **저녁**
#     - **저녁 식사 장소**: 난장캠프
#       - **주소**: 서울 강남구 강남대로158길 27 (신사동)
#       - **특징**: 다양한 주류와 안주를 즐길 수 있는 곳
#     - **명소**: 가로수길
#       - **특징**: 다양한 쇼핑과 맛집이 있는 거리
#     - **쇼핑몰**: 압구정 로데오 거리
#       - **특징**: 패션과 트렌드의 중심지
#     - **숙소**: [숙소 위치] [숙소 정보] [숙소 특징] *숙소 정보가 없으면 출력하지 않음
#
# - **2일차**
#
#   - **아침**
#     - **아침 식사 장소**: 만나당
#       - **주소**: 서울 강남구 논현로175길 61 (신사동) 1층 101호
#       - **특징**: 다양한 아침 메뉴를 제공
#     - **명소**: 압구정 로데오 거리
#       - **특징**: 다양한 패션 브랜드와 카페가 있는 거리
#
#   - **점심**
#     - **점심 식사 장소**: [점심 식사 장소] [음식점 주소] [영업 시간] [음식점 특징] [기타 정보]
#     - **명소**: [관광할 명소 또는 거리] [영업 시간] [명소 특징] [명소 위치] [기타 정보]
#     - **카페**: [카페 주소] [영업 시간] [카페 정보] [카페 특징]
#
#   - **저녁**
#     - **저녁 식사 장소**: [저녁 식사 장소] [음식점 주소] [음식점 특징] [기타 정보]
#     - **명소**: [관광할 명소 또는 거리] [명소 특징] [명소 위치] [기타 정보]
#     - **쇼핑몰**: [쇼핑몰 주소] [쇼핑몰 특징]
#     - **숙소**: [숙소 위치] [숙소 정보] [숙소 특징] *숙소 정보가 없으면 출력하지 않음
#
# 이 일정은 강남구 내에서의 이동을 최소화하여 편리한 여행을 할 수 있도록 구성되었습니다. 각 장소의 영업 시간과 위치를 확인하여 방문 계획을 세우세요. 즐거운 여행 되세요!
# ('user', '강남구 1박2일 일정 만들어줘')
# ('assistant', '**강남구 1박 2일 여행 일정**\n\n- **1일차**\n\n  - **점심**\n    - **점심 식사 장소**: 만나분식\n      - **주소**: 서울 강남구 삼성로 212 (대치동, 은마아파트)\n      - **영업 시간**: 매일 10:00 ~ 20:00, 매달 1, 3번째 일요일 정기 휴무 & 2, 4번째 월요일 휴무\n      - **특징**: 전통적인 한국 분식 메뉴를 제공하는 곳\n    - **명소**: 강남관광정보센터\n      - **위치**: 서울특별시 강남구 압구정로 161, 1층\n      - **특징**: 다양한 관광 정보를 제공하며, 커뮤니케이션 공간과 체험존이 있음\n    - **카페**: 카페먼데이투선데이\n      - **주소**: 서울특별시 강남구 도산대로67길 13-3 (청담동)\n      - **영업 시간**: 월요일~목요일/일요일 10:30 ~ 23:00, 금요일/토요일 10:30 ~ 24:00\n      - **특징**: 아늑한 분위기의 카페\n\n  - **저녁**\n    - **저녁 식사 장소**: 난장캠프\n      - **주소**: 서울 강남구 강남대로158길 27 (신사동)\n      - **특징**: 다양한 주류와 안주를 즐길 수 있는 곳\n    - **명소**: 가로수길\n      - **특징**: 다양한 쇼핑과 맛집이 있는 거리\n    - **쇼핑몰**: 압구정 로데오 거리\n      - **특징**: 패션과 트렌드의 중심지\n    - **숙소**: [숙소 위치] [숙소 정보] [숙소 특징] *숙소 정보가 없으면 출력하지 않음\n\n- **2일차**\n\n  - **아침**\n    - **아침 식사 장소**: 만나당\n      - **주소**: 서울 강남구 논현로175길 61 (신사동) 1층 101호\n      - **특징**: 다양한 아침 메뉴를 제공\n    - **명소**: 압구정 로데오 거리\n      - **특징**: 다양한 패션 브랜드와 카페가 있는 거리\n\n  - **점심**\n    - **점심 식사 장소**: [점심 식사 장소] [음식점 주소] [영업 시간] [음식점 특징] [기타 정보]\n    - **명소**: [관광할 명소 또는 거리] [영업 시간] [명소 특징] [명소 위치] [기타 정보]\n    - **카페**: [카페 주소] [영업 시간] [카페 정보] [카페 특징]\n\n  - **저녁**\n    - **저녁 식사 장소**: [저녁 식사 장소] [음식점 주소] [음식점 특징] [기타 정보]\n    - **명소**: [관광할 명소 또는 거리] [명소 특징] [명소 위치] [기타 정보]\n    - **쇼핑몰**: [쇼핑몰 주소] [쇼핑몰 특징]\n    - **숙소**: [숙소 위치] [숙소 정보] [숙소 특징] *숙소 정보가 없으면 출력하지 않음\n\n이 일정은 강남구 내에서의 이동을 최소화하여 편리한 여행을 할 수 있도록 구성되었습니다. 각 장소의 영업 시간과 위치를 확인하여 방문 계획을 세우세요. 즐거운 여행 되세요!')
# ==================================================

# %%
inputs = GraphState(question="방금 알려준 종로구의 카페 밀롱가는 주차가 가능해?")

# %%
res = app.invoke(input=inputs, config=config)
# Out:
# [HumanMessage(content='방금 알려준 종로구의 카페 밀롱가는 주차가 가능해?', additional_kwargs={}, response_metadata={}, id='5cb4880a-92aa-4d06-822d-db24efb09ae9'), AIMessage(content='밀롱가는 주차 정보가 제공되지 않았습니다. 따라서 주차 가능 여부에 대한 정보는 확인할 수 없습니다. 다만, 대중교통을 이용하여 경복궁역 3번 출구에서 접근할 수 있습니다.', additional_kwargs={}, response_metadata={}, id='f08ae18a-5387-4234-95e7-0471eaf63612'), HumanMessage(content='방금 알려준 종로구의 카페 밀롱가는 주차가 가능해?', additional_kwargs={}, response_metadata={}, id='4d871650-c7de-4d91-874b-75484f580069'), AIMessage(content='밀롱가는 종로구에 위치한 카페로, 아늑한 분위기와 독특한 인테리어가 매력적입니다. 이곳은 커피와 디저트가 맛있기로 유명하며, 조용한 환경에서 여유롭게 시간을 보낼 수 있는 장소입니다. 주차 정보는 제공되지 않았으므로, 대중교통을 이용하는 것이 좋습니다. 경복궁역 3번 출구에서 쉽게 접근할 수 있습니다.', additional_kwargs={}, response_metadata={}, id='98f477af-9335-42a6-8a5e-b45645af37cc')]

# %%
res.an

# %%
import time
import sys

# %%
def typewriter_effect(text, delay=0.05):
    """
    텍스트를 한 글자씩 출력하는 효과를 주는 함수.
    :param text: 출력할 문자열
    :param delay: 글자 출력 간의 딜레이 (초 단위)
    """
    for char in text:
        sys.stdout.write(char)  # 글자를 출력
        sys.stdout.flush()  # 출력 버퍼를 비워 즉시 표시
        time.sleep(delay)  # 딜레이 추가
    print()  # 줄 바꿈

# 사용 예제
text_to_display = "촤라락 출력되는 효과를 보여드립니다!"
typewriter_effect(res.get('answer'), delay=0.02)
# Out:
# 밀롱가는 종로구에 위치한 아늑한 분위기의 카페로, 독특한 인테리어와 함께 커피와 디저트가 맛있기로 유명합니다. 조용한 환경에서 여유롭게 시간을 보낼 수 있는 장소로 추천됩니다. 주차 정보는 제공되지 않아 대중교통을 이용하는 것이 좋으며, 경복궁역 3번 출구에서 쉽게 접근할 수 있습니다.

# %%
res.get('answer')
# Out:
# '밀롱가는 종로구에 위치한 아늑한 분위기의 카페로, 독특한 인테리어와 함께 커피와 디저트가 맛있기로 유명합니다. 조용한 환경에서 여유롭게 시간을 보낼 수 있는 장소로 추천됩니다. 주차 정보는 제공되지 않아 대중교통을 이용하는 것이 좋으며, 경복궁역 3번 출구에서 쉽게 접근할 수 있습니다.'

# %%
while(True):
    user_input = input('일정이나 장소를 물어 보세요 : ')
    # 질문 입력
    inputs = GraphState(question=user_input)

    res = app.invoke(input=inputs, config=config)

    typewriter_effect(res.get('answer'), delay=0.01)
# Out:
# [HumanMessage(content='방금 알려준 종로구의 카페 밀롱가는 주차가 가능해?', additional_kwargs={}, response_metadata={}, id='5cb4880a-92aa-4d06-822d-db24efb09ae9'), AIMessage(content='밀롱가는 주차 정보가 제공되지 않았습니다. 따라서 주차 가능 여부에 대한 정보는 확인할 수 없습니다. 다만, 대중교통을 이용하여 경복궁역 3번 출구에서 접근할 수 있습니다.', additional_kwargs={}, response_metadata={}, id='f08ae18a-5387-4234-95e7-0471eaf63612'), HumanMessage(content='방금 알려준 종로구의 카페 밀롱가는 주차가 가능해?', additional_kwargs={}, response_metadata={}, id='4d871650-c7de-4d91-874b-75484f580069'), AIMessage(content='밀롱가는 종로구에 위치한 카페로, 아늑한 분위기와 독특한 인테리어가 매력적입니다. 이곳은 커피와 디저트가 맛있기로 유명하며, 조용한 환경에서 여유롭게 시간을 보낼 수 있는 장소입니다. 주차 정보는 제공되지 않았으므로, 대중교통을 이용하는 것이 좋습니다. 경복궁역 3번 출구에서 쉽게 접근할 수 있습니다.', additional_kwargs={}, response_metadata={}, id='98f477af-9335-42a6-8a5e-b45645af37cc'), HumanMessage(content='방금 알려준 종로구의 카페 밀롱가는 주차가 가능해?', additional_kwargs={}, response_metadata={}, id='e1c54eeb-7492-4be9-a8c3-3659e97dd187'), AIMessage(content='밀롱가는 종로구에 위치한 아늑한 분위기의 카페로, 독특한 인테리어와 함께 커피와 디저트가 맛있기로 유명합니다. 조용한 환경에서 여유롭게 시간을 보낼 수 있는 장소로 추천됩니다. 주차 정보는 제공되지 않아 대중교통을 이용하는 것이 좋으며, 경복궁역 3번 출구에서 쉽게 접근할 수 있습니다.', additional_kwargs={}, response_metadata={}, id='4bbcbcab-05a7-43b9-832a-91cc06e7c1fa')]
# 종로구에서의 2박 3일 일정을 추천해드리겠습니다. 이 일정은 관광 명소, 맛집, 카페 등을 포함하여 동선을 최소화하도록 구성하였습니다.
#
# ### 1일차
# - **아침**: 북촌 한옥마을 산책
#   - 북촌마을안내소에서 시작하여 전통 한옥을 감상하며 산책하세요.
# - **점심**: 종로도담 (한식)
#   - 김치찜과 개성보쌈을 맛보세요.
# - **오후**: 서울공예박물관 방문
#   - 다양한 전시를 통해 한국 전통 공예를 체험할 수 있습니다.
# - **저녁**: 서울회관 (요리주점)
#   - 옛날 가마솥 통닭과 유동골뱅이 무침을 추천합니다.
#
# ### 2일차
# - **아침**: 떡박물관 방문
#   - 한국 전통 떡의 역사와 문화를 배울 수 있습니다.
# - **점심**: 오봉집 종로점 (한식)
#   - 직화낙지볶음과 프리미엄 가브리살 보쌈을 즐기세요.
# - **오후**: 쌈지길 체험공방
#   - 다양한 공예 체험을 통해 특별한 기념품을 만들어보세요.
# - **저녁**: 천년동안도 (BAR)
#   - 라이브 공연과 함께 다양한 음료를 즐기며 하루를 마무리하세요.
#
# ### 3일차
# - **아침**: 북촌목공예공방 체험
#   - 목공예 체험을 통해 특별한 경험을 쌓아보세요.
# - **점심**: 동베이 광화문점 (양꼬치)
#   - 양꼬치와 동북 요리를 맛보세요.
# - **오후**: 서울컬쳐라운지 방문
#   - 다양한 문화 콘텐츠를 즐길 수 있는 공간입니다.
# - **저녁**: 방이옥 종로 관철점 (육류, 고기요리)
#   - 다양한 고기 요리를 맛보며 여행을 마무리하세요.
#
# 이 일정이 마음에 드시길 바라며, 변경이 필요하시면 언제든지 말씀해 주세요!
# Traceback (most recent call last):
#
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/langraph/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "/var/folders/_v/g1qmsq595kq_fg_zv8n2022h0000gn/T/ipykernel_6197/578781410.py", line 6, in <cell line: 0>
#     res = app.invoke(input=inputs, config=config)
#
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/langraph/lib/python3.11/site-packages/langgraph/pregel/__init__.py", line 1936, in invoke
#     for chunk in self.stream(
#
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/langraph/lib/python3.11/site-packages/langgraph/pregel/__init__.py", line 1656, in stream
#     for _ in runner.tick(
#
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/langraph/lib/python3.11/site-packages/langgraph/pregel/runner.py", line 239, in tick
#     _panic_or_proceed(
#
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/langraph/lib/python3.11/site-packages/langgraph/pregel/runner.py", line 539, in _panic_or_proceed
#     raise exc
#
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/langraph/lib/python3.11/site-packages/langgraph/pregel/executor.py", line 76, in done
#     task.result()
#
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/langraph/lib/python3.11/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/langraph/lib/python3.11/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/langraph/lib/python3.11/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/langraph/lib/python3.11/site-packages/langgraph/pregel/retry.py", line 40, in run_with_retry
#     return task.proc.invoke(task.input, config)
#
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/langraph/lib/python3.11/site-packages/langgraph/utils/runnable.py", line 408, in invoke
#     input = step.invoke(input, config, **kwargs)
#
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/langraph/lib/python3.11/site-packages/langgraph/utils/runnable.py", line 184, in invoke
#     ret = context.run(self.func, input, **kwargs)
#
#   File "/var/folders/_v/g1qmsq595kq_fg_zv8n2022h0000gn/T/ipykernel_6197/2103715052.py", line 55, in retrieve_document_naver
#     location = ast.literal_eval(location_str)
#
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/langraph/lib/python3.11/ast.py", line 64, in literal_eval
#     node_or_string = parse(node_or_string.lstrip(" \t"), mode='eval')
#
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/langraph/lib/python3.11/ast.py", line 50, in parse
#     return compile(source, filename, mode, flags,
#
#   File "<unknown>", line 1
#     사용자의 질문: 그러면 방금 대답해준 2일차 점심으로 종로구 오봉집에 대한 자세한 정보를 알려줘
#          ^
# SyntaxError: invalid syntax
